# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/resnet101%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 15:12:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='resnet101', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.149959, Test Loss : 5.139970, Train Acc : 0.000000, Test Acc : 2.717391
# Iteration : 6 - Train Loss : 5.158997, Test Loss : 12.694623, Train Acc : 3.125000, Test Acc : 1.426630
# Iteration : 11 - Train Loss : 4.981216, Test Loss : 11.329296, Train Acc : 0.000000, Test Acc : 1.834239
# Iteration : 16 - Train Loss : 4.479652, Test Loss : 7.487477, Train Acc : 6.250000, Test Acc : 2.717391
# Best Model Saved
# Iteration : 21 - Train Loss : 4.314038, Test Loss : 9.187468, Train Acc : 12.500000, Test Acc : 2.785326
# Best Model Saved
# Iteration : 26 - Train Loss : 4.490305, Test Loss : 31.212109, Train Acc : 6.250000, Test Acc : 3.396739
# Best Model Saved
# Iteration : 31 - Train Loss : 3.972072, Test Loss : 4.382385, Train Acc : 6.250000, Test Acc : 4.823370
# Best Model Saved
# Iteration : 36 - Train Loss : 3.864398, Test Loss : 3.929370, Train Acc : 6.250000, Test Acc : 13.111413
# Iteration : 41 - Train Loss : 3.533565, Test Loss : 4.532555, Train Acc : 15.625000, Test Acc : 7.880435
# Iteration : 46 - Train Loss : 3.553682, Test Loss : 4.307930, Train Acc : 15.625000, Test Acc : 10.597826
# Best Model Saved
# Iteration : 51 - Train Loss : 3.072986, Test Loss : 3.591144, Train Acc : 18.750000, Test Acc : 17.255435
# Iteration : 56 - Train Loss : 3.440496, Test Loss : 3.893043, Train Acc : 9.375000, Test Acc : 12.160326
# Best Model Saved
# Iteration : 61 - Train Loss : 2.957534, Test Loss : 3.266625, Train Acc : 21.875000, Test Acc : 15.081522
# Best Model Saved
# Iteration : 66 - Train Loss : 2.940501, Test Loss : 3.041628, Train Acc : 28.125000, Test Acc : 20.176630
# Best Model Saved
# Iteration : 71 - Train Loss : 3.146616, Test Loss : 2.861878, Train Acc : 15.625000, Test Acc : 28.057065
# Iteration : 76 - Train Loss : 2.735721, Test Loss : 3.015035, Train Acc : 28.125000, Test Acc : 22.282609
# Iteration : 81 - Train Loss : 2.327119, Test Loss : 3.215541, Train Acc : 28.125000, Test Acc : 23.165761
# Best Model Saved
# Iteration : 86 - Train Loss : 2.539670, Test Loss : 2.541527, Train Acc : 31.250000, Test Acc : 26.834239
# Best Model Saved
# Iteration : 91 - Train Loss : 2.409667, Test Loss : 2.203548, Train Acc : 37.500000, Test Acc : 34.442935
# Best Model Saved
# Iteration : 96 - Train Loss : 2.434641, Test Loss : 2.264589, Train Acc : 34.375000, Test Acc : 34.782609
# Best Model Saved
# Iteration : 101 - Train Loss : 2.070918, Test Loss : 2.020078, Train Acc : 40.625000, Test Acc : 41.915761
# Iteration : 106 - Train Loss : 1.868751, Test Loss : 2.238004, Train Acc : 40.625000, Test Acc : 33.220109
# Best Model Saved
# Iteration : 111 - Train Loss : 2.183056, Test Loss : 1.909010, Train Acc : 34.375000, Test Acc : 43.478261
# Best Model Saved
# Iteration : 116 - Train Loss : 1.786593, Test Loss : 1.872671, Train Acc : 43.750000, Test Acc : 45.380435
# Best Model Saved
# Iteration : 121 - Train Loss : 1.599442, Test Loss : 1.856555, Train Acc : 40.625000, Test Acc : 44.565217
# Iteration : 126 - Train Loss : 1.586587, Test Loss : 2.190548, Train Acc : 65.625000, Test Acc : 35.869565
# Best Model Saved
# Iteration : 131 - Train Loss : 1.501908, Test Loss : 1.752869, Train Acc : 43.750000, Test Acc : 42.934783
# Best Model Saved
# Iteration : 136 - Train Loss : 1.426785, Test Loss : 1.603870, Train Acc : 50.000000, Test Acc : 51.222826
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 1.323369, Test Loss : 1.466168, Train Acc : 53.125000, Test Acc : 53.464674
# Iteration : 6 - Train Loss : 1.920822, Test Loss : 1.775271, Train Acc : 40.625000, Test Acc : 42.527174
# Iteration : 11 - Train Loss : 1.430249, Test Loss : 1.618262, Train Acc : 53.125000, Test Acc : 49.592391
# Iteration : 16 - Train Loss : 1.194827, Test Loss : 1.502255, Train Acc : 62.500000, Test Acc : 52.581522
# Best Model Saved
# Iteration : 21 - Train Loss : 1.334900, Test Loss : 1.232011, Train Acc : 65.625000, Test Acc : 57.608696
# Iteration : 26 - Train Loss : 1.316193, Test Loss : 1.649804, Train Acc : 50.000000, Test Acc : 51.902174
# Iteration : 31 - Train Loss : 1.067873, Test Loss : 1.821438, Train Acc : 68.750000, Test Acc : 48.301630
# Best Model Saved
# Iteration : 36 - Train Loss : 1.437272, Test Loss : 1.392041, Train Acc : 53.125000, Test Acc : 57.812500
# Best Model Saved
# Iteration : 41 - Train Loss : 0.966921, Test Loss : 1.149759, Train Acc : 65.625000, Test Acc : 64.741848
# Best Model Saved
# Iteration : 46 - Train Loss : 0.994066, Test Loss : 1.039980, Train Acc : 71.875000, Test Acc : 66.711957
# Iteration : 51 - Train Loss : 0.755549, Test Loss : 1.404164, Train Acc : 81.250000, Test Acc : 57.269022
# Iteration : 56 - Train Loss : 1.113043, Test Loss : 1.278891, Train Acc : 65.625000, Test Acc : 60.801630
# Iteration : 61 - Train Loss : 1.144430, Test Loss : 1.155288, Train Acc : 71.875000, Test Acc : 64.062500
# Iteration : 66 - Train Loss : 0.750047, Test Loss : 1.950556, Train Acc : 71.875000, Test Acc : 44.089674
# Iteration : 71 - Train Loss : 1.037071, Test Loss : 1.786877, Train Acc : 68.750000, Test Acc : 51.630435
# Best Model Saved
# Iteration : 76 - Train Loss : 0.951520, Test Loss : 0.983822, Train Acc : 71.875000, Test Acc : 68.342391
# Iteration : 81 - Train Loss : 0.934979, Test Loss : 1.096794, Train Acc : 62.500000, Test Acc : 65.013587
# Iteration : 86 - Train Loss : 0.666865, Test Loss : 1.099153, Train Acc : 78.125000, Test Acc : 63.654891
# Best Model Saved
# Iteration : 91 - Train Loss : 0.673608, Test Loss : 0.939613, Train Acc : 78.125000, Test Acc : 71.739130
# Best Model Saved
# Iteration : 96 - Train Loss : 0.808573, Test Loss : 0.815603, Train Acc : 78.125000, Test Acc : 74.592391
# Iteration : 101 - Train Loss : 0.715977, Test Loss : 0.980719, Train Acc : 81.250000, Test Acc : 66.983696
# Iteration : 106 - Train Loss : 0.532633, Test Loss : 1.240105, Train Acc : 87.500000, Test Acc : 62.228261
# Iteration : 111 - Train Loss : 0.913929, Test Loss : 1.091209, Train Acc : 68.750000, Test Acc : 66.440217
# Iteration : 116 - Train Loss : 1.013590, Test Loss : 0.995938, Train Acc : 78.125000, Test Acc : 68.750000
# Best Model Saved
# Iteration : 121 - Train Loss : 0.559805, Test Loss : 0.741841, Train Acc : 81.250000, Test Acc : 77.513587
# Iteration : 126 - Train Loss : 0.660790, Test Loss : 1.129681, Train Acc : 81.250000, Test Acc : 66.100543
# Best Model Saved
# Iteration : 131 - Train Loss : 0.402575, Test Loss : 0.655797, Train Acc : 96.875000, Test Acc : 78.600543
# Iteration : 136 - Train Loss : 0.568504, Test Loss : 0.769173, Train Acc : 81.250000, Test Acc : 75.339674
#
# Epoch 3 Started...
# Iteration : 1 - Train Loss : 0.580059, Test Loss : 0.764096, Train Acc : 81.250000, Test Acc : 76.222826
# Iteration : 6 - Train Loss : 0.392602, Test Loss : 0.742842, Train Acc : 87.500000, Test Acc : 75.951087
# Best Model Saved
# Iteration : 11 - Train Loss : 0.611600, Test Loss : 0.549075, Train Acc : 87.500000, Test Acc : 82.812500
# Iteration : 16 - Train Loss : 0.489914, Test Loss : 0.845753, Train Acc : 87.500000, Test Acc : 73.437500
# Iteration : 21 - Train Loss : 0.487512, Test Loss : 0.919549, Train Acc : 87.500000, Test Acc : 70.040761
# Iteration : 26 - Train Loss : 0.349670, Test Loss : 1.651605, Train Acc : 87.500000, Test Acc : 57.880435
# Iteration : 31 - Train Loss : 0.622555, Test Loss : 0.608173, Train Acc : 81.250000, Test Acc : 82.744565
# Iteration : 36 - Train Loss : 0.578973, Test Loss : 0.668564, Train Acc : 81.250000, Test Acc : 81.046196
# Iteration : 41 - Train Loss : 0.637042, Test Loss : 0.568319, Train Acc : 81.250000, Test Acc : 82.336957
# Iteration : 46 - Train Loss : 0.464943, Test Loss : 0.653781, Train Acc : 87.500000, Test Acc : 80.027174
# Iteration : 51 - Train Loss : 0.449102, Test Loss : 0.732468, Train Acc : 93.750000, Test Acc : 77.038043
# Best Model Saved
# Iteration : 56 - Train Loss : 0.395715, Test Loss : 0.442289, Train Acc : 87.500000, Test Acc : 87.296196
# Best Model Saved
# Iteration : 61 - Train Loss : 0.455485, Test Loss : 0.421208, Train Acc : 75.000000, Test Acc : 88.179348
# Iteration : 66 - Train Loss : 0.476963, Test Loss : 0.434905, Train Acc : 84.375000, Test Acc : 84.714674
# Best Model Saved
# Iteration : 71 - Train Loss : 0.522422, Test Loss : 0.416631, Train Acc : 78.125000, Test Acc : 87.364130
# Best Model Saved
# Iteration : 76 - Train Loss : 0.459001, Test Loss : 0.392842, Train Acc : 84.375000, Test Acc : 88.722826
# Iteration : 81 - Train Loss : 0.265826, Test Loss : 0.615783, Train Acc : 93.750000, Test Acc : 84.035326
# Iteration : 86 - Train Loss : 0.296242, Test Loss : 0.513122, Train Acc : 90.625000, Test Acc : 86.345109
# Best Model Saved
# Iteration : 91 - Train Loss : 0.327006, Test Loss : 0.372692, Train Acc : 90.625000, Test Acc : 88.043478
# Iteration : 96 - Train Loss : 0.250885, Test Loss : 0.413538, Train Acc : 90.625000, Test Acc : 87.975543
# Best Model Saved
# Iteration : 101 - Train Loss : 0.683173, Test Loss : 0.376089, Train Acc : 78.125000, Test Acc : 88.722826
# Iteration : 106 - Train Loss : 0.502246, Test Loss : 0.424166, Train Acc : 84.375000, Test Acc : 87.567935
# Iteration : 111 - Train Loss : 0.412723, Test Loss : 0.709692, Train Acc : 81.250000, Test Acc : 79.347826
# Iteration : 116 - Train Loss : 0.618359, Test Loss : 0.440843, Train Acc : 78.125000, Test Acc : 86.480978
# Iteration : 121 - Train Loss : 0.636485, Test Loss : 0.902912, Train Acc : 78.125000, Test Acc : 71.127717
# Iteration : 126 - Train Loss : 0.362632, Test Loss : 0.599478, Train Acc : 90.625000, Test Acc : 80.706522
# Iteration : 131 - Train Loss : 0.304173, Test Loss : 0.559082, Train Acc : 87.500000, Test Acc : 83.423913
# Iteration : 136 - Train Loss : 0.194199, Test Loss : 0.417083, Train Acc : 96.875000, Test Acc : 86.548913
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 0.319631, Test Loss : 0.533570, Train Acc : 87.500000, Test Acc : 81.250000
# Best Model Saved
# Iteration : 6 - Train Loss : 0.223892, Test Loss : 0.352225, Train Acc : 96.875000, Test Acc : 88.790761
# Iteration : 11 - Train Loss : 0.180844, Test Loss : 0.461383, Train Acc : 100.000000, Test Acc : 86.888587
# Iteration : 16 - Train Loss : 0.309375, Test Loss : 0.511336, Train Acc : 87.500000, Test Acc : 85.190217
# Iteration : 21 - Train Loss : 0.207598, Test Loss : 0.487275, Train Acc : 93.750000, Test Acc : 85.665761
# Iteration : 26 - Train Loss : 0.355666, Test Loss : 0.403122, Train Acc : 84.375000, Test Acc : 87.635870
# Best Model Saved
# Iteration : 31 - Train Loss : 0.270941, Test Loss : 0.295156, Train Acc : 87.500000, Test Acc : 90.489130
# Best Model Saved
# Iteration : 36 - Train Loss : 0.275824, Test Loss : 0.317717, Train Acc : 87.500000, Test Acc : 92.051630
# Iteration : 41 - Train Loss : 0.441009, Test Loss : 0.541576, Train Acc : 84.375000, Test Acc : 84.510870
# Iteration : 46 - Train Loss : 0.167899, Test Loss : 0.381044, Train Acc : 96.875000, Test Acc : 90.081522
# Iteration : 51 - Train Loss : 0.477188, Test Loss : 0.424408, Train Acc : 87.500000, Test Acc : 87.296196
# Iteration : 56 - Train Loss : 0.231528, Test Loss : 0.355844, Train Acc : 93.750000, Test Acc : 88.043478
# Iteration : 61 - Train Loss : 0.298879, Test Loss : 0.431618, Train Acc : 90.625000, Test Acc : 83.084239
# Iteration : 66 - Train Loss : 0.256568, Test Loss : 0.576701, Train Acc : 90.625000, Test Acc : 80.638587
# Iteration : 71 - Train Loss : 0.319138, Test Loss : 0.486833, Train Acc : 84.375000, Test Acc : 84.171196
# Best Model Saved
# Iteration : 76 - Train Loss : 0.345377, Test Loss : 0.275229, Train Acc : 90.625000, Test Acc : 91.711957
# Iteration : 81 - Train Loss : 0.313007, Test Loss : 0.365843, Train Acc : 90.625000, Test Acc : 89.334239
# Iteration : 86 - Train Loss : 0.247888, Test Loss : 0.947058, Train Acc : 90.625000, Test Acc : 73.097826
# Best Model Saved
# Iteration : 91 - Train Loss : 0.201749, Test Loss : 0.243043, Train Acc : 93.750000, Test Acc : 92.730978
# Iteration : 96 - Train Loss : 0.316598, Test Loss : 0.288899, Train Acc : 87.500000, Test Acc : 91.100543
# Iteration : 101 - Train Loss : 0.174224, Test Loss : 0.299260, Train Acc : 96.875000, Test Acc : 90.828804
# Iteration : 106 - Train Loss : 0.292222, Test Loss : 0.283126, Train Acc : 90.625000, Test Acc : 92.255435
# Iteration : 111 - Train Loss : 0.228619, Test Loss : 0.317096, Train Acc : 93.750000, Test Acc : 90.760870
# Iteration : 116 - Train Loss : 0.138774, Test Loss : 0.400631, Train Acc : 93.750000, Test Acc : 88.383152
# Iteration : 121 - Train Loss : 0.078593, Test Loss : 0.339282, Train Acc : 100.000000, Test Acc : 88.790761
# Iteration : 126 - Train Loss : 0.225661, Test Loss : 0.278014, Train Acc : 93.750000, Test Acc : 90.625000
# Iteration : 131 - Train Loss : 0.173574, Test Loss : 0.460725, Train Acc : 93.750000, Test Acc : 85.869565
# Iteration : 136 - Train Loss : 0.133559, Test Loss : 0.284881, Train Acc : 96.875000, Test Acc : 91.779891
#
# Epoch 5 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.179333, Test Loss : 0.215854, Train Acc : 93.750000, Test Acc : 93.817935
# Iteration : 6 - Train Loss : 0.086679, Test Loss : 0.275033, Train Acc : 96.875000, Test Acc : 92.798913
# Iteration : 11 - Train Loss : 0.196848, Test Loss : 0.570536, Train Acc : 90.625000, Test Acc : 83.831522
# Iteration : 16 - Train Loss : 0.234644, Test Loss : 0.335660, Train Acc : 90.625000, Test Acc : 89.538043
# Iteration : 21 - Train Loss : 0.415031, Test Loss : 0.219464, Train Acc : 84.375000, Test Acc : 93.274457
# Best Model Saved
# Iteration : 26 - Train Loss : 0.215046, Test Loss : 0.224516, Train Acc : 90.625000, Test Acc : 94.293478
# Iteration : 31 - Train Loss : 0.288523, Test Loss : 0.274743, Train Acc : 93.750000, Test Acc : 91.644022
# Best Model Saved
# Iteration : 36 - Train Loss : 0.228531, Test Loss : 0.208039, Train Acc : 93.750000, Test Acc : 93.206522
# Best Model Saved
# Iteration : 41 - Train Loss : 0.080769, Test Loss : 0.225800, Train Acc : 100.000000, Test Acc : 93.546196
# Best Model Saved
# Iteration : 46 - Train Loss : 0.065972, Test Loss : 0.154695, Train Acc : 100.000000, Test Acc : 94.429348
# Best Model Saved
# Iteration : 51 - Train Loss : 0.145285, Test Loss : 0.156438, Train Acc : 93.750000, Test Acc : 94.972826
# Best Model Saved
# Iteration : 56 - Train Loss : 0.200943, Test Loss : 0.168690, Train Acc : 96.875000, Test Acc : 95.380435
# Best Model Saved
# Iteration : 61 - Train Loss : 0.074817, Test Loss : 0.090479, Train Acc : 100.000000, Test Acc : 97.826087
# Iteration : 66 - Train Loss : 0.080098, Test Loss : 0.124370, Train Acc : 100.000000, Test Acc : 96.331522
# Iteration : 71 - Train Loss : 0.216434, Test Loss : 0.151562, Train Acc : 96.875000, Test Acc : 96.127717
# Iteration : 76 - Train Loss : 0.096213, Test Loss : 0.195429, Train Acc : 100.000000, Test Acc : 94.836957
# Iteration : 81 - Train Loss : 0.212309, Test Loss : 0.213653, Train Acc : 87.500000, Test Acc : 94.361413
# Iteration : 86 - Train Loss : 0.145014, Test Loss : 0.192444, Train Acc : 90.625000, Test Acc : 93.953804
# Iteration : 91 - Train Loss : 0.233100, Test Loss : 0.285253, Train Acc : 93.750000, Test Acc : 91.032609
# Iteration : 96 - Train Loss : 0.094748, Test Loss : 0.282508, Train Acc : 100.000000, Test Acc : 93.002717
# Iteration : 101 - Train Loss : 0.314883, Test Loss : 0.273232, Train Acc : 90.625000, Test Acc : 92.459239
# Iteration : 106 - Train Loss : 0.117003, Test Loss : 0.309563, Train Acc : 96.875000, Test Acc : 91.100543
# Iteration : 111 - Train Loss : 0.168089, Test Loss : 0.370613, Train Acc : 90.625000, Test Acc : 89.062500
# Iteration : 116 - Train Loss : 0.118152, Test Loss : 0.334076, Train Acc : 96.875000, Test Acc : 90.896739
# Iteration : 121 - Train Loss : 0.069236, Test Loss : 0.271404, Train Acc : 100.000000, Test Acc : 92.527174
# Iteration : 126 - Train Loss : 0.297592, Test Loss : 0.203497, Train Acc : 90.625000, Test Acc : 94.225543
# Iteration : 131 - Train Loss : 0.102289, Test Loss : 0.249476, Train Acc : 96.875000, Test Acc : 93.002717
# Iteration : 136 - Train Loss : 0.117873, Test Loss : 0.399614, Train Acc : 96.875000, Test Acc : 87.432065

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='resnet101', num_classes=157)
model.model.load_state_dict(torch.load('./4_60.pt'))
model.model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./resnet101_ImageNetStat_4_60.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    9.208194e-01  1.449273e-02  ...  8.216261e-09  9.974011e-07
# 1    3.919165e-04  2.608856e-06  ...  2.727288e-10  1.378908e-09
# 2    1.092163e-06  3.011156e-04  ...  1.364434e-08  2.349028e-10
# 3    7.655294e-07  2.703882e-04  ...  7.008514e-09  5.457079e-10
# 4    4.555955e-09  3.579930e-06  ...  2.867320e-08  1.785694e-10
# ..            ...           ...  ...           ...           ...
# 212  5.314159e-08  9.515480e-08  ...  9.592227e-05  4.891206e-03
# 213  8.756847e-11  1.555570e-09  ...  7.818949e-05  5.095206e-07
# 214  1.674904e-12  3.211824e-09  ...  9.929468e-01  1.426457e-11
# 215  2.921444e-10  1.195975e-06  ...  9.978218e-01  2.844309e-09
# 216  5.765381e-08  1.204937e-07  ...  1.760772e-07  9.270814e-01
#
# [217 rows x 157 columns]
