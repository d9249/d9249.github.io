# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/vgg19%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 03:10:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='vgg19', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
len(train_dataset.label_info)
# Out:
# 157

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.351724, Test Loss : 5.048479, Train Acc : 0.000000, Test Acc : 2.717391
# Best Model Saved
# Iteration : 6 - Train Loss : 5.050056, Test Loss : 5.029075, Train Acc : 0.000000, Test Acc : 2.377717
# Iteration : 11 - Train Loss : 5.029433, Test Loss : 5.030873, Train Acc : 0.000000, Test Acc : 0.543478
# Iteration : 16 - Train Loss : 5.307779, Test Loss : 5.038284, Train Acc : 0.000000, Test Acc : 0.407609
# Iteration : 21 - Train Loss : 5.046322, Test Loss : 5.033053, Train Acc : 3.125000, Test Acc : 0.611413
# Best Model Saved
# Iteration : 26 - Train Loss : 5.040135, Test Loss : 4.982711, Train Acc : 0.000000, Test Acc : 1.426630
# Best Model Saved
# Iteration : 31 - Train Loss : 5.045841, Test Loss : 5.044728, Train Acc : 0.000000, Test Acc : 1.494565
# Iteration : 36 - Train Loss : 5.053473, Test Loss : 5.046200, Train Acc : 0.000000, Test Acc : 1.494565
# Best Model Saved
# Iteration : 41 - Train Loss : 4.993096, Test Loss : 4.991823, Train Acc : 3.125000, Test Acc : 2.581522
# Best Model Saved
# Iteration : 46 - Train Loss : 4.823567, Test Loss : 4.813984, Train Acc : 3.125000, Test Acc : 4.144022
# Best Model Saved
# Iteration : 51 - Train Loss : 4.809861, Test Loss : 4.694723, Train Acc : 9.375000, Test Acc : 4.755435
# Iteration : 56 - Train Loss : 4.631875, Test Loss : 4.702728, Train Acc : 3.125000, Test Acc : 3.125000
# Best Model Saved
# Iteration : 61 - Train Loss : 4.679172, Test Loss : 4.444818, Train Acc : 6.250000, Test Acc : 5.706522
# Best Model Saved
# Iteration : 66 - Train Loss : 4.005092, Test Loss : 4.273530, Train Acc : 9.375000, Test Acc : 6.793478
# Best Model Saved
# Iteration : 71 - Train Loss : 4.287995, Test Loss : 4.084344, Train Acc : 0.000000, Test Acc : 7.540761
# Best Model Saved
# Iteration : 76 - Train Loss : 4.111125, Test Loss : 3.921211, Train Acc : 18.750000, Test Acc : 10.937500
# Best Model Saved
# Iteration : 81 - Train Loss : 3.988091, Test Loss : 3.610310, Train Acc : 9.375000, Test Acc : 15.692935
# Best Model Saved
# Iteration : 86 - Train Loss : 3.599059, Test Loss : 3.479732, Train Acc : 15.625000, Test Acc : 14.945652
# Best Model Saved
# Iteration : 91 - Train Loss : 3.525272, Test Loss : 3.392637, Train Acc : 18.750000, Test Acc : 19.021739
# Best Model Saved
# Iteration : 96 - Train Loss : 3.848765, Test Loss : 3.122165, Train Acc : 9.375000, Test Acc : 21.942935
# Best Model Saved
# Iteration : 101 - Train Loss : 2.869322, Test Loss : 3.042567, Train Acc : 34.375000, Test Acc : 23.641304
# Best Model Saved
# Iteration : 106 - Train Loss : 2.911361, Test Loss : 2.973425, Train Acc : 31.250000, Test Acc : 23.573370
# Best Model Saved
# Iteration : 111 - Train Loss : 2.983810, Test Loss : 2.819099, Train Acc : 15.625000, Test Acc : 21.671196
# Best Model Saved
# Iteration : 116 - Train Loss : 2.972149, Test Loss : 2.724492, Train Acc : 18.750000, Test Acc : 27.785326
# Best Model Saved
# Iteration : 121 - Train Loss : 2.299898, Test Loss : 2.557156, Train Acc : 31.250000, Test Acc : 28.125000
# Best Model Saved
# Iteration : 126 - Train Loss : 2.602676, Test Loss : 2.496774, Train Acc : 31.250000, Test Acc : 31.453804
# Best Model Saved
# Iteration : 131 - Train Loss : 2.084236, Test Loss : 2.181924, Train Acc : 34.375000, Test Acc : 36.480978
# Best Model Saved
# Iteration : 136 - Train Loss : 2.916820, Test Loss : 2.267324, Train Acc : 25.000000, Test Acc : 39.198370
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 2.621172, Test Loss : 2.032237, Train Acc : 37.500000, Test Acc : 43.342391
# Iteration : 6 - Train Loss : 2.590885, Test Loss : 2.170968, Train Acc : 37.500000, Test Acc : 38.451087
# Best Model Saved
# Iteration : 11 - Train Loss : 2.180496, Test Loss : 1.956509, Train Acc : 40.625000, Test Acc : 42.459239
# Best Model Saved
# Iteration : 16 - Train Loss : 2.378985, Test Loss : 1.867704, Train Acc : 43.750000, Test Acc : 45.516304
# Best Model Saved
# Iteration : 21 - Train Loss : 2.124592, Test Loss : 1.780117, Train Acc : 37.500000, Test Acc : 44.565217
# Best Model Saved
# Iteration : 26 - Train Loss : 2.159029, Test Loss : 1.780339, Train Acc : 37.500000, Test Acc : 45.923913
# Best Model Saved
# Iteration : 31 - Train Loss : 1.746111, Test Loss : 1.737403, Train Acc : 50.000000, Test Acc : 47.214674
# Best Model Saved
# Iteration : 36 - Train Loss : 2.032490, Test Loss : 1.735536, Train Acc : 40.625000, Test Acc : 48.505435
# Best Model Saved
# Iteration : 41 - Train Loss : 1.680814, Test Loss : 1.632596, Train Acc : 53.125000, Test Acc : 52.309783
# Iteration : 46 - Train Loss : 2.014640, Test Loss : 1.648489, Train Acc : 46.875000, Test Acc : 50.883152
# Best Model Saved
# Iteration : 51 - Train Loss : 1.878867, Test Loss : 1.533548, Train Acc : 43.750000, Test Acc : 55.366848
# Best Model Saved
# Iteration : 56 - Train Loss : 1.422655, Test Loss : 1.529880, Train Acc : 62.500000, Test Acc : 54.008152
# Best Model Saved
# Iteration : 61 - Train Loss : 1.745349, Test Loss : 1.490619, Train Acc : 43.750000, Test Acc : 54.008152
# Iteration : 66 - Train Loss : 1.936885, Test Loss : 1.510641, Train Acc : 31.250000, Test Acc : 53.328804
# Best Model Saved
# Iteration : 71 - Train Loss : 1.755873, Test Loss : 1.433459, Train Acc : 43.750000, Test Acc : 57.404891
# Best Model Saved
# Iteration : 76 - Train Loss : 1.815692, Test Loss : 1.375787, Train Acc : 53.125000, Test Acc : 61.616848
# Best Model Saved
# Iteration : 81 - Train Loss : 1.611334, Test Loss : 1.259488, Train Acc : 40.625000, Test Acc : 60.869565
# Iteration : 86 - Train Loss : 2.363924, Test Loss : 1.262557, Train Acc : 34.375000, Test Acc : 60.529891
# Iteration : 91 - Train Loss : 1.430555, Test Loss : 1.267773, Train Acc : 53.125000, Test Acc : 60.326087
# Best Model Saved
# Iteration : 96 - Train Loss : 1.525391, Test Loss : 1.264520, Train Acc : 43.750000, Test Acc : 61.345109
# Best Model Saved
# Iteration : 101 - Train Loss : 1.572067, Test Loss : 1.235678, Train Acc : 56.250000, Test Acc : 60.394022
# Best Model Saved
# Iteration : 106 - Train Loss : 1.380173, Test Loss : 1.186125, Train Acc : 59.375000, Test Acc : 63.519022
# Best Model Saved
# Iteration : 111 - Train Loss : 1.373304, Test Loss : 1.146893, Train Acc : 53.125000, Test Acc : 65.625000
# Best Model Saved
# Iteration : 116 - Train Loss : 1.035871, Test Loss : 1.071321, Train Acc : 65.625000, Test Acc : 68.274457
# Best Model Saved
# Iteration : 121 - Train Loss : 0.961825, Test Loss : 1.052236, Train Acc : 68.750000, Test Acc : 69.701087
# Best Model Saved
# Iteration : 126 - Train Loss : 1.930170, Test Loss : 0.988983, Train Acc : 53.125000, Test Acc : 69.565217
# Best Model Saved
# Iteration : 131 - Train Loss : 1.142853, Test Loss : 0.941631, Train Acc : 62.500000, Test Acc : 71.807065
# Iteration : 136 - Train Loss : 1.502446, Test Loss : 0.963247, Train Acc : 62.500000, Test Acc : 70.584239
#
# Epoch 3 Started...
# Iteration : 1 - Train Loss : 1.430092, Test Loss : 1.084642, Train Acc : 62.500000, Test Acc : 67.730978
# Iteration : 6 - Train Loss : 1.062428, Test Loss : 0.991891, Train Acc : 59.375000, Test Acc : 69.972826
# Best Model Saved
# Iteration : 11 - Train Loss : 0.869305, Test Loss : 0.938634, Train Acc : 78.125000, Test Acc : 70.720109
# Best Model Saved
# Iteration : 16 - Train Loss : 1.026317, Test Loss : 0.950447, Train Acc : 65.625000, Test Acc : 70.991848
# Best Model Saved
# Iteration : 21 - Train Loss : 0.859794, Test Loss : 0.896204, Train Acc : 71.875000, Test Acc : 74.388587
# Best Model Saved
# Iteration : 26 - Train Loss : 1.598379, Test Loss : 0.875587, Train Acc : 62.500000, Test Acc : 74.116848
# Best Model Saved
# Iteration : 31 - Train Loss : 0.771023, Test Loss : 0.750220, Train Acc : 68.750000, Test Acc : 76.902174
# Iteration : 36 - Train Loss : 0.585659, Test Loss : 0.860829, Train Acc : 71.875000, Test Acc : 71.807065
# Iteration : 41 - Train Loss : 1.060408, Test Loss : 0.865105, Train Acc : 65.625000, Test Acc : 73.165761
# Iteration : 46 - Train Loss : 1.035699, Test Loss : 0.850870, Train Acc : 62.500000, Test Acc : 74.456522
# Iteration : 51 - Train Loss : 0.646893, Test Loss : 0.777286, Train Acc : 78.125000, Test Acc : 74.728261
# Iteration : 56 - Train Loss : 1.215393, Test Loss : 0.787209, Train Acc : 46.875000, Test Acc : 75.475543
# Best Model Saved
# Iteration : 61 - Train Loss : 0.990499, Test Loss : 0.714060, Train Acc : 62.500000, Test Acc : 77.581522
# Best Model Saved
# Iteration : 66 - Train Loss : 0.595829, Test Loss : 0.678555, Train Acc : 87.500000, Test Acc : 79.891304
# Iteration : 71 - Train Loss : 1.048776, Test Loss : 0.707829, Train Acc : 59.375000, Test Acc : 78.736413
# Best Model Saved
# Iteration : 76 - Train Loss : 1.679549, Test Loss : 0.617856, Train Acc : 62.500000, Test Acc : 79.755435
# Iteration : 81 - Train Loss : 0.935334, Test Loss : 0.654254, Train Acc : 65.625000, Test Acc : 79.755435
# Iteration : 86 - Train Loss : 0.885007, Test Loss : 0.683730, Train Acc : 81.250000, Test Acc : 77.173913
# Iteration : 91 - Train Loss : 0.900767, Test Loss : 0.769821, Train Acc : 65.625000, Test Acc : 76.019022
# Best Model Saved
# Iteration : 96 - Train Loss : 0.941738, Test Loss : 0.543833, Train Acc : 59.375000, Test Acc : 82.948370
# Iteration : 101 - Train Loss : 0.732770, Test Loss : 0.665273, Train Acc : 78.125000, Test Acc : 78.804348
# Iteration : 106 - Train Loss : 0.532304, Test Loss : 0.563197, Train Acc : 81.250000, Test Acc : 81.182065
# Best Model Saved
# Iteration : 111 - Train Loss : 0.846021, Test Loss : 0.566335, Train Acc : 84.375000, Test Acc : 83.016304
# Best Model Saved
# Iteration : 116 - Train Loss : 0.787959, Test Loss : 0.537838, Train Acc : 75.000000, Test Acc : 82.201087
# Best Model Saved
# Iteration : 121 - Train Loss : 0.874237, Test Loss : 0.492267, Train Acc : 78.125000, Test Acc : 84.442935
# Best Model Saved
# Iteration : 126 - Train Loss : 0.815240, Test Loss : 0.467955, Train Acc : 71.875000, Test Acc : 84.782609
# Iteration : 131 - Train Loss : 0.645989, Test Loss : 0.573969, Train Acc : 81.250000, Test Acc : 84.782609
# Iteration : 136 - Train Loss : 0.637826, Test Loss : 0.507431, Train Acc : 84.375000, Test Acc : 83.763587
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 0.766132, Test Loss : 0.543975, Train Acc : 75.000000, Test Acc : 84.239130
# Best Model Saved
# Iteration : 6 - Train Loss : 0.362180, Test Loss : 0.497236, Train Acc : 90.625000, Test Acc : 85.461957
# Best Model Saved
# Iteration : 11 - Train Loss : 0.513661, Test Loss : 0.477279, Train Acc : 84.375000, Test Acc : 84.239130
# Best Model Saved
# Iteration : 16 - Train Loss : 0.708555, Test Loss : 0.440609, Train Acc : 78.125000, Test Acc : 87.296196
# Iteration : 21 - Train Loss : 0.562613, Test Loss : 0.475729, Train Acc : 84.375000, Test Acc : 85.869565
# Best Model Saved
# Iteration : 26 - Train Loss : 0.449082, Test Loss : 0.434843, Train Acc : 84.375000, Test Acc : 86.956522
# Iteration : 31 - Train Loss : 0.472523, Test Loss : 0.443791, Train Acc : 90.625000, Test Acc : 86.277174
# Iteration : 36 - Train Loss : 0.546102, Test Loss : 0.477492, Train Acc : 81.250000, Test Acc : 84.035326
# Best Model Saved
# Iteration : 41 - Train Loss : 0.425646, Test Loss : 0.402841, Train Acc : 90.625000, Test Acc : 86.752717
# Best Model Saved
# Iteration : 46 - Train Loss : 0.423625, Test Loss : 0.387617, Train Acc : 81.250000, Test Acc : 87.228261
# Best Model Saved
# Iteration : 51 - Train Loss : 0.758579, Test Loss : 0.398945, Train Acc : 78.125000, Test Acc : 87.771739
# Best Model Saved
# Iteration : 56 - Train Loss : 0.326966, Test Loss : 0.367957, Train Acc : 87.500000, Test Acc : 88.043478
# Iteration : 61 - Train Loss : 0.573108, Test Loss : 0.389155, Train Acc : 87.500000, Test Acc : 87.500000
# Best Model Saved
# Iteration : 66 - Train Loss : 0.470624, Test Loss : 0.344094, Train Acc : 81.250000, Test Acc : 89.538043
# Iteration : 71 - Train Loss : 0.528145, Test Loss : 0.362303, Train Acc : 87.500000, Test Acc : 88.315217
# Best Model Saved
# Iteration : 76 - Train Loss : 0.839747, Test Loss : 0.315919, Train Acc : 75.000000, Test Acc : 90.625000
# Iteration : 81 - Train Loss : 0.178506, Test Loss : 0.357193, Train Acc : 96.875000, Test Acc : 89.062500
# Iteration : 86 - Train Loss : 0.321763, Test Loss : 0.386491, Train Acc : 90.625000, Test Acc : 87.567935
# Iteration : 91 - Train Loss : 0.367363, Test Loss : 0.340679, Train Acc : 87.500000, Test Acc : 89.809783
# Iteration : 96 - Train Loss : 0.514895, Test Loss : 0.337247, Train Acc : 84.375000, Test Acc : 89.538043
# Best Model Saved
# Iteration : 101 - Train Loss : 0.623956, Test Loss : 0.315270, Train Acc : 78.125000, Test Acc : 90.692935
# Best Model Saved
# Iteration : 106 - Train Loss : 0.527029, Test Loss : 0.296106, Train Acc : 84.375000, Test Acc : 91.168478
# Iteration : 111 - Train Loss : 0.650425, Test Loss : 0.367725, Train Acc : 78.125000, Test Acc : 89.266304
# Iteration : 116 - Train Loss : 0.523953, Test Loss : 0.325892, Train Acc : 84.375000, Test Acc : 90.828804
# Iteration : 121 - Train Loss : 0.455465, Test Loss : 0.319665, Train Acc : 90.625000, Test Acc : 90.421196
# Best Model Saved
# Iteration : 126 - Train Loss : 0.568659, Test Loss : 0.301731, Train Acc : 78.125000, Test Acc : 91.304348
# Iteration : 131 - Train Loss : 0.360130, Test Loss : 0.341292, Train Acc : 87.500000, Test Acc : 89.605978
# Best Model Saved
# Iteration : 136 - Train Loss : 0.843399, Test Loss : 0.295714, Train Acc : 78.125000, Test Acc : 89.741848
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.677232, Test Loss : 0.332367, Train Acc : 78.125000, Test Acc : 89.062500
# Best Model Saved
# Iteration : 6 - Train Loss : 0.373001, Test Loss : 0.269796, Train Acc : 81.250000, Test Acc : 91.508152
# Best Model Saved
# Iteration : 11 - Train Loss : 0.364181, Test Loss : 0.236477, Train Acc : 84.375000, Test Acc : 91.847826
# Iteration : 16 - Train Loss : 0.385336, Test Loss : 0.285184, Train Acc : 87.500000, Test Acc : 90.013587
# Best Model Saved
# Iteration : 21 - Train Loss : 0.305702, Test Loss : 0.297979, Train Acc : 90.625000, Test Acc : 91.915761
# Best Model Saved
# Iteration : 26 - Train Loss : 0.329453, Test Loss : 0.282072, Train Acc : 90.625000, Test Acc : 90.964674
# Best Model Saved
# Iteration : 31 - Train Loss : 0.246477, Test Loss : 0.283347, Train Acc : 87.500000, Test Acc : 91.236413
# Best Model Saved
# Iteration : 36 - Train Loss : 0.489905, Test Loss : 0.258062, Train Acc : 81.250000, Test Acc : 92.119565
# Best Model Saved
# Iteration : 41 - Train Loss : 0.487053, Test Loss : 0.244949, Train Acc : 90.625000, Test Acc : 91.711957
# Best Model Saved
# Iteration : 46 - Train Loss : 0.227724, Test Loss : 0.222981, Train Acc : 93.750000, Test Acc : 92.187500
# Iteration : 51 - Train Loss : 0.611401, Test Loss : 0.285114, Train Acc : 75.000000, Test Acc : 90.692935
# Iteration : 56 - Train Loss : 0.722757, Test Loss : 0.276089, Train Acc : 78.125000, Test Acc : 91.236413
# Best Model Saved
# Iteration : 61 - Train Loss : 0.486920, Test Loss : 0.252999, Train Acc : 87.500000, Test Acc : 93.410326
# Iteration : 66 - Train Loss : 0.268388, Test Loss : 0.334303, Train Acc : 93.750000, Test Acc : 90.489130
# Best Model Saved
# Iteration : 71 - Train Loss : 0.322979, Test Loss : 0.239038, Train Acc : 90.625000, Test Acc : 92.187500
# Best Model Saved
# Iteration : 76 - Train Loss : 0.686622, Test Loss : 0.282314, Train Acc : 84.375000, Test Acc : 92.663043
# Iteration : 81 - Train Loss : 0.130450, Test Loss : 0.324864, Train Acc : 96.875000, Test Acc : 88.586957
# Iteration : 86 - Train Loss : 0.463097, Test Loss : 0.294551, Train Acc : 81.250000, Test Acc : 90.896739
# Iteration : 91 - Train Loss : 0.285641, Test Loss : 0.346994, Train Acc : 90.625000, Test Acc : 88.790761
# Best Model Saved
# Iteration : 96 - Train Loss : 0.487406, Test Loss : 0.274162, Train Acc : 87.500000, Test Acc : 91.847826
# Iteration : 101 - Train Loss : 0.320409, Test Loss : 0.284759, Train Acc : 93.750000, Test Acc : 91.644022
# Iteration : 106 - Train Loss : 0.387885, Test Loss : 0.325279, Train Acc : 84.375000, Test Acc : 89.266304
# Iteration : 111 - Train Loss : 0.320356, Test Loss : 0.293227, Train Acc : 84.375000, Test Acc : 91.508152
# Best Model Saved
# Iteration : 116 - Train Loss : 0.456447, Test Loss : 0.264036, Train Acc : 84.375000, Test Acc : 91.508152
# Iteration : 121 - Train Loss : 0.307659, Test Loss : 0.333977, Train Acc : 87.500000, Test Acc : 88.994565
# Iteration : 126 - Train Loss : 0.260852, Test Loss : 0.311497, Train Acc : 93.750000, Test Acc : 90.964674
# Best Model Saved
# Iteration : 131 - Train Loss : 0.407981, Test Loss : 0.199903, Train Acc : 84.375000, Test Acc : 93.342391
# Iteration : 136 - Train Loss : 0.609853, Test Loss : 0.245151, Train Acc : 84.375000, Test Acc : 90.625000

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='vgg19', num_classes=157)
model.model.load_state_dict(torch.load('./4_130.pt'))
model.model.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Linear(in_features=25088, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./vgg19_ImageNetStat_4_130_threshno.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    1.141322e-02  1.523970e-04  ...  9.065574e-18  1.883329e-25
# 1    8.067517e-11  3.638933e-10  ...  8.832218e-13  1.307148e-24
# 2    5.686781e-11  4.924123e-07  ...  3.301897e-08  2.304705e-18
# 3    3.662128e-10  1.878357e-07  ...  3.255646e-09  6.112556e-19
# 4    7.695410e-15  6.697342e-08  ...  5.664165e-07  2.915805e-16
# ..            ...           ...  ...           ...           ...
# 212  2.202477e-16  4.246545e-16  ...  8.761009e-13  1.715863e-02
# 213  1.746418e-13  2.732378e-10  ...  4.733311e-05  9.111088e-01
# 214  7.313483e-13  2.563312e-08  ...  9.916955e-01  5.738456e-09
# 215  2.030514e-13  2.100442e-08  ...  9.979601e-01  2.562388e-10
# 216  6.478708e-13  1.012957e-11  ...  4.484867e-05  7.330523e-03
#
# [217 rows x 157 columns]
