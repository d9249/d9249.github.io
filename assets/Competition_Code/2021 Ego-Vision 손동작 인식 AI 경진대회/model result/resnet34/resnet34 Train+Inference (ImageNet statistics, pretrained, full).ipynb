# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/resnet34%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Oct  7 12:50:18 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
# !cp /content/drive/MyDrive/pytorch_python/dataset.py .
# !cp /content/drive/MyDrive/pytorch_python/specific_augmentation.py .
# !cp /content/drive/MyDrive/pytorch_python/specific_dataset.py .
# !cp /content/drive/MyDrive/pytorch_python/specific_train.py .
# !cp /content/drive/MyDrive/pytorch_python/train.py .

# %%
from dataset import *
from train import *

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import torch, torchvision
import torchvision.transforms as transforms

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='resnet34', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
len(train_dataset.label_info)
# Out:
# 157

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.263317, Test Loss : 5.139393, Train Acc : 0.000000, Test Acc : 3.057065
# Best Model Saved
# Iteration : 6 - Train Loss : 4.701484, Test Loss : 4.984003, Train Acc : 25.000000, Test Acc : 7.676630
# Best Model Saved
# Iteration : 11 - Train Loss : 4.857776, Test Loss : 4.985889, Train Acc : 3.125000, Test Acc : 7.948370
# Best Model Saved
# Iteration : 16 - Train Loss : 4.324750, Test Loss : 4.494110, Train Acc : 12.500000, Test Acc : 12.703804
# Best Model Saved
# Iteration : 21 - Train Loss : 4.099883, Test Loss : 3.843465, Train Acc : 25.000000, Test Acc : 23.573370
# Best Model Saved
# Iteration : 26 - Train Loss : 3.737545, Test Loss : 3.438897, Train Acc : 34.375000, Test Acc : 29.823370
# Best Model Saved
# Iteration : 31 - Train Loss : 2.821028, Test Loss : 2.919857, Train Acc : 56.250000, Test Acc : 34.986413
# Best Model Saved
# Iteration : 36 - Train Loss : 2.782130, Test Loss : 2.671008, Train Acc : 31.250000, Test Acc : 36.345109
# Best Model Saved
# Iteration : 41 - Train Loss : 2.315968, Test Loss : 2.551464, Train Acc : 43.750000, Test Acc : 38.722826
# Best Model Saved
# Iteration : 46 - Train Loss : 2.283797, Test Loss : 2.332245, Train Acc : 56.250000, Test Acc : 43.342391
# Best Model Saved
# Iteration : 51 - Train Loss : 2.255382, Test Loss : 2.284831, Train Acc : 43.750000, Test Acc : 44.565217
# Best Model Saved
# Iteration : 56 - Train Loss : 2.404571, Test Loss : 2.208975, Train Acc : 21.875000, Test Acc : 44.089674
# Best Model Saved
# Iteration : 61 - Train Loss : 1.711522, Test Loss : 2.057713, Train Acc : 59.375000, Test Acc : 50.815217
# Best Model Saved
# Iteration : 66 - Train Loss : 1.729494, Test Loss : 1.887103, Train Acc : 53.125000, Test Acc : 56.114130
# Best Model Saved
# Iteration : 71 - Train Loss : 1.783106, Test Loss : 1.635454, Train Acc : 46.875000, Test Acc : 60.597826
# Best Model Saved
# Iteration : 76 - Train Loss : 1.286339, Test Loss : 1.502717, Train Acc : 75.000000, Test Acc : 63.926630
# Best Model Saved
# Iteration : 81 - Train Loss : 1.630517, Test Loss : 1.373786, Train Acc : 59.375000, Test Acc : 67.051630
# Best Model Saved
# Iteration : 86 - Train Loss : 1.203068, Test Loss : 1.451612, Train Acc : 71.875000, Test Acc : 67.595109
# Best Model Saved
# Iteration : 91 - Train Loss : 1.219025, Test Loss : 1.329258, Train Acc : 71.875000, Test Acc : 65.081522
# Best Model Saved
# Iteration : 96 - Train Loss : 0.791149, Test Loss : 1.048804, Train Acc : 90.625000, Test Acc : 75.203804
# Iteration : 101 - Train Loss : 0.872983, Test Loss : 1.160378, Train Acc : 90.625000, Test Acc : 73.097826
# Iteration : 106 - Train Loss : 0.945473, Test Loss : 1.104711, Train Acc : 81.250000, Test Acc : 70.855978
# Iteration : 111 - Train Loss : 0.741726, Test Loss : 1.053870, Train Acc : 84.375000, Test Acc : 73.165761
# Iteration : 116 - Train Loss : 0.784403, Test Loss : 1.250483, Train Acc : 78.125000, Test Acc : 66.915761
# Iteration : 121 - Train Loss : 0.710453, Test Loss : 1.109203, Train Acc : 84.375000, Test Acc : 73.165761
# Best Model Saved
# Iteration : 126 - Train Loss : 0.717483, Test Loss : 0.905372, Train Acc : 84.375000, Test Acc : 79.823370
# Iteration : 131 - Train Loss : 0.858737, Test Loss : 1.239642, Train Acc : 81.250000, Test Acc : 69.429348
# Best Model Saved
# Iteration : 136 - Train Loss : 0.730596, Test Loss : 0.790515, Train Acc : 78.125000, Test Acc : 80.230978
#
# Epoch 2 Started...
# Iteration : 1 - Train Loss : 0.715407, Test Loss : 1.060783, Train Acc : 78.125000, Test Acc : 71.195652
# Iteration : 6 - Train Loss : 0.784000, Test Loss : 0.925208, Train Acc : 71.875000, Test Acc : 75.543478
# Iteration : 11 - Train Loss : 0.557191, Test Loss : 0.986515, Train Acc : 84.375000, Test Acc : 73.709239
# Iteration : 16 - Train Loss : 0.554258, Test Loss : 0.900612, Train Acc : 84.375000, Test Acc : 75.747283
# Best Model Saved
# Iteration : 21 - Train Loss : 0.499246, Test Loss : 0.734770, Train Acc : 87.500000, Test Acc : 79.279891
# Best Model Saved
# Iteration : 26 - Train Loss : 0.414652, Test Loss : 0.713332, Train Acc : 90.625000, Test Acc : 81.182065
# Best Model Saved
# Iteration : 31 - Train Loss : 0.493172, Test Loss : 0.546589, Train Acc : 90.625000, Test Acc : 85.597826
# Best Model Saved
# Iteration : 36 - Train Loss : 0.517314, Test Loss : 0.470602, Train Acc : 84.375000, Test Acc : 89.334239
# Iteration : 41 - Train Loss : 0.622753, Test Loss : 0.574516, Train Acc : 78.125000, Test Acc : 85.394022
# Iteration : 46 - Train Loss : 0.483979, Test Loss : 0.600818, Train Acc : 87.500000, Test Acc : 82.812500
# Iteration : 51 - Train Loss : 0.335449, Test Loss : 0.586888, Train Acc : 90.625000, Test Acc : 84.510870
# Iteration : 56 - Train Loss : 0.474883, Test Loss : 0.705359, Train Acc : 90.625000, Test Acc : 81.725543
# Iteration : 61 - Train Loss : 0.290634, Test Loss : 0.558743, Train Acc : 96.875000, Test Acc : 83.288043
# Iteration : 66 - Train Loss : 0.500523, Test Loss : 0.545222, Train Acc : 81.250000, Test Acc : 85.054348
# Iteration : 71 - Train Loss : 0.637662, Test Loss : 0.640727, Train Acc : 81.250000, Test Acc : 81.861413
# Iteration : 76 - Train Loss : 0.434505, Test Loss : 0.610150, Train Acc : 90.625000, Test Acc : 83.967391
# Iteration : 81 - Train Loss : 0.427334, Test Loss : 0.712247, Train Acc : 84.375000, Test Acc : 80.366848
# Best Model Saved
# Iteration : 86 - Train Loss : 0.306210, Test Loss : 0.435814, Train Acc : 93.750000, Test Acc : 87.703804
# Iteration : 91 - Train Loss : 0.263785, Test Loss : 1.023787, Train Acc : 96.875000, Test Acc : 74.524457
# Best Model Saved
# Iteration : 96 - Train Loss : 0.232513, Test Loss : 0.406135, Train Acc : 96.875000, Test Acc : 89.877717
# Best Model Saved
# Iteration : 101 - Train Loss : 0.271806, Test Loss : 0.268114, Train Acc : 100.000000, Test Acc : 94.633152
# Iteration : 106 - Train Loss : 0.208837, Test Loss : 0.488754, Train Acc : 96.875000, Test Acc : 88.179348
# Iteration : 111 - Train Loss : 0.370114, Test Loss : 0.313790, Train Acc : 90.625000, Test Acc : 92.119565
# Iteration : 116 - Train Loss : 0.271408, Test Loss : 0.446762, Train Acc : 96.875000, Test Acc : 89.198370
# Iteration : 121 - Train Loss : 0.238365, Test Loss : 0.347725, Train Acc : 90.625000, Test Acc : 92.051630
# Iteration : 126 - Train Loss : 0.218085, Test Loss : 0.342841, Train Acc : 96.875000, Test Acc : 89.402174
# Iteration : 131 - Train Loss : 0.387948, Test Loss : 0.381477, Train Acc : 87.500000, Test Acc : 89.062500
# Iteration : 136 - Train Loss : 0.424020, Test Loss : 0.387436, Train Acc : 87.500000, Test Acc : 89.877717
#
# Epoch 3 Started...
# Iteration : 1 - Train Loss : 0.280645, Test Loss : 0.294522, Train Acc : 87.500000, Test Acc : 91.644022
# Iteration : 6 - Train Loss : 0.165326, Test Loss : 0.422552, Train Acc : 96.875000, Test Acc : 88.451087
# Best Model Saved
# Iteration : 11 - Train Loss : 0.270487, Test Loss : 0.203095, Train Acc : 93.750000, Test Acc : 95.720109
# Iteration : 16 - Train Loss : 0.242917, Test Loss : 0.225315, Train Acc : 93.750000, Test Acc : 95.040761
# Iteration : 21 - Train Loss : 0.288260, Test Loss : 0.250935, Train Acc : 84.375000, Test Acc : 93.750000
# Iteration : 26 - Train Loss : 0.240647, Test Loss : 0.210281, Train Acc : 90.625000, Test Acc : 94.769022
# Best Model Saved
# Iteration : 31 - Train Loss : 0.105957, Test Loss : 0.176784, Train Acc : 96.875000, Test Acc : 96.059783
# Best Model Saved
# Iteration : 36 - Train Loss : 0.178633, Test Loss : 0.174353, Train Acc : 93.750000, Test Acc : 96.807065
# Iteration : 41 - Train Loss : 0.217619, Test Loss : 0.305344, Train Acc : 93.750000, Test Acc : 93.478261
# Iteration : 46 - Train Loss : 0.094255, Test Loss : 0.294475, Train Acc : 100.000000, Test Acc : 94.565217
# Iteration : 51 - Train Loss : 0.197340, Test Loss : 0.243202, Train Acc : 96.875000, Test Acc : 93.546196
# Iteration : 56 - Train Loss : 0.151302, Test Loss : 0.193502, Train Acc : 96.875000, Test Acc : 94.972826
# Iteration : 61 - Train Loss : 0.104792, Test Loss : 0.295229, Train Acc : 96.875000, Test Acc : 91.508152
# Best Model Saved
# Iteration : 66 - Train Loss : 0.153919, Test Loss : 0.140511, Train Acc : 93.750000, Test Acc : 96.467391
# Best Model Saved
# Iteration : 71 - Train Loss : 0.181127, Test Loss : 0.130083, Train Acc : 93.750000, Test Acc : 97.010870
# Iteration : 76 - Train Loss : 0.093703, Test Loss : 0.162196, Train Acc : 96.875000, Test Acc : 96.059783
# Iteration : 81 - Train Loss : 0.115697, Test Loss : 0.180898, Train Acc : 96.875000, Test Acc : 95.991848
# Iteration : 86 - Train Loss : 0.231636, Test Loss : 0.173127, Train Acc : 96.875000, Test Acc : 95.788043
# Best Model Saved
# Iteration : 91 - Train Loss : 0.361468, Test Loss : 0.119454, Train Acc : 87.500000, Test Acc : 97.690217
# Iteration : 96 - Train Loss : 0.073273, Test Loss : 0.155731, Train Acc : 100.000000, Test Acc : 95.991848
# Iteration : 101 - Train Loss : 0.252214, Test Loss : 0.160379, Train Acc : 93.750000, Test Acc : 95.176630
# Iteration : 106 - Train Loss : 0.108285, Test Loss : 0.121216, Train Acc : 96.875000, Test Acc : 96.603261
# Iteration : 111 - Train Loss : 0.062563, Test Loss : 0.173300, Train Acc : 100.000000, Test Acc : 95.040761
# Iteration : 116 - Train Loss : 0.080419, Test Loss : 0.124154, Train Acc : 100.000000, Test Acc : 97.554348
# Best Model Saved
# Iteration : 121 - Train Loss : 0.129375, Test Loss : 0.101039, Train Acc : 96.875000, Test Acc : 98.505435
# Iteration : 126 - Train Loss : 0.053470, Test Loss : 0.194782, Train Acc : 100.000000, Test Acc : 96.331522
# Iteration : 131 - Train Loss : 0.136223, Test Loss : 0.167087, Train Acc : 96.875000, Test Acc : 95.652174
# Iteration : 136 - Train Loss : 0.180945, Test Loss : 0.216112, Train Acc : 96.875000, Test Acc : 93.817935
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 0.219999, Test Loss : 0.223380, Train Acc : 93.750000, Test Acc : 93.342391
# Iteration : 6 - Train Loss : 0.320019, Test Loss : 0.446234, Train Acc : 90.625000, Test Acc : 87.567935
# Iteration : 11 - Train Loss : 0.053016, Test Loss : 0.233302, Train Acc : 100.000000, Test Acc : 95.516304
# Iteration : 16 - Train Loss : 0.429914, Test Loss : 0.247957, Train Acc : 90.625000, Test Acc : 94.633152
# Iteration : 21 - Train Loss : 0.087839, Test Loss : 0.365802, Train Acc : 100.000000, Test Acc : 90.489130
# Iteration : 26 - Train Loss : 0.053930, Test Loss : 0.258299, Train Acc : 100.000000, Test Acc : 94.836957
# Iteration : 31 - Train Loss : 0.053816, Test Loss : 0.220961, Train Acc : 100.000000, Test Acc : 94.836957
# Iteration : 36 - Train Loss : 0.091480, Test Loss : 0.139002, Train Acc : 96.875000, Test Acc : 96.739130
# Iteration : 41 - Train Loss : 0.279090, Test Loss : 0.188907, Train Acc : 93.750000, Test Acc : 95.040761
# Iteration : 46 - Train Loss : 0.071841, Test Loss : 0.240167, Train Acc : 100.000000, Test Acc : 93.478261
# Iteration : 51 - Train Loss : 0.063080, Test Loss : 0.209581, Train Acc : 100.000000, Test Acc : 95.448370
# Iteration : 56 - Train Loss : 0.204735, Test Loss : 0.212171, Train Acc : 96.875000, Test Acc : 95.652174
# Iteration : 61 - Train Loss : 0.081237, Test Loss : 0.213276, Train Acc : 100.000000, Test Acc : 95.176630
# Iteration : 66 - Train Loss : 0.155338, Test Loss : 0.316048, Train Acc : 93.750000, Test Acc : 92.527174
# Iteration : 71 - Train Loss : 0.465789, Test Loss : 0.221175, Train Acc : 90.625000, Test Acc : 95.652174
# Iteration : 76 - Train Loss : 0.093586, Test Loss : 0.315901, Train Acc : 96.875000, Test Acc : 92.866848
# Iteration : 81 - Train Loss : 0.115305, Test Loss : 0.214633, Train Acc : 96.875000, Test Acc : 93.817935
# Iteration : 86 - Train Loss : 0.362815, Test Loss : 0.198073, Train Acc : 90.625000, Test Acc : 96.331522
# Iteration : 91 - Train Loss : 0.121997, Test Loss : 0.360671, Train Acc : 96.875000, Test Acc : 92.459239
# Iteration : 96 - Train Loss : 0.089997, Test Loss : 0.326329, Train Acc : 100.000000, Test Acc : 93.274457
# Iteration : 101 - Train Loss : 0.076656, Test Loss : 0.169885, Train Acc : 100.000000, Test Acc : 95.380435
# Iteration : 106 - Train Loss : 0.053574, Test Loss : 0.213571, Train Acc : 100.000000, Test Acc : 95.720109
# Iteration : 111 - Train Loss : 0.136568, Test Loss : 0.102891, Train Acc : 96.875000, Test Acc : 97.690217
# Iteration : 116 - Train Loss : 0.068516, Test Loss : 0.151653, Train Acc : 100.000000, Test Acc : 96.331522
# Iteration : 121 - Train Loss : 0.162106, Test Loss : 0.111513, Train Acc : 96.875000, Test Acc : 96.875000
# Iteration : 126 - Train Loss : 0.109189, Test Loss : 0.200307, Train Acc : 96.875000, Test Acc : 94.633152
# Best Model Saved
# Iteration : 131 - Train Loss : 0.043092, Test Loss : 0.092214, Train Acc : 100.000000, Test Acc : 97.350543
# Iteration : 136 - Train Loss : 0.176615, Test Loss : 0.195997, Train Acc : 96.875000, Test Acc : 95.244565
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.142227, Test Loss : 0.115723, Train Acc : 93.750000, Test Acc : 96.942935
# Iteration : 6 - Train Loss : 0.080756, Test Loss : 0.137307, Train Acc : 96.875000, Test Acc : 96.671196
# Iteration : 11 - Train Loss : 0.051296, Test Loss : 0.124649, Train Acc : 100.000000, Test Acc : 96.875000
# Best Model Saved
# Iteration : 16 - Train Loss : 0.037023, Test Loss : 0.083390, Train Acc : 100.000000, Test Acc : 98.165761
# Iteration : 21 - Train Loss : 0.091162, Test Loss : 0.128886, Train Acc : 100.000000, Test Acc : 97.622283
# Iteration : 26 - Train Loss : 0.121262, Test Loss : 0.142142, Train Acc : 96.875000, Test Acc : 96.603261
# Iteration : 31 - Train Loss : 0.364331, Test Loss : 0.208462, Train Acc : 93.750000, Test Acc : 95.855978
# Iteration : 36 - Train Loss : 0.054603, Test Loss : 0.194145, Train Acc : 100.000000, Test Acc : 95.855978
# Iteration : 41 - Train Loss : 0.050624, Test Loss : 0.147218, Train Acc : 100.000000, Test Acc : 95.855978
# Iteration : 46 - Train Loss : 0.051398, Test Loss : 0.156895, Train Acc : 100.000000, Test Acc : 94.904891
# Iteration : 51 - Train Loss : 0.047831, Test Loss : 0.156932, Train Acc : 100.000000, Test Acc : 95.652174
# Best Model Saved
# Iteration : 56 - Train Loss : 0.027739, Test Loss : 0.063211, Train Acc : 100.000000, Test Acc : 98.845109
# Best Model Saved
# Iteration : 61 - Train Loss : 0.028933, Test Loss : 0.047636, Train Acc : 100.000000, Test Acc : 99.116848
# Iteration : 66 - Train Loss : 0.024928, Test Loss : 0.077463, Train Acc : 100.000000, Test Acc : 98.233696
# Iteration : 71 - Train Loss : 0.022529, Test Loss : 0.085092, Train Acc : 100.000000, Test Acc : 97.961957
# Iteration : 76 - Train Loss : 0.020326, Test Loss : 0.100413, Train Acc : 100.000000, Test Acc : 97.622283
# Iteration : 81 - Train Loss : 0.020610, Test Loss : 0.063998, Train Acc : 100.000000, Test Acc : 98.573370
# Iteration : 86 - Train Loss : 0.034649, Test Loss : 0.069627, Train Acc : 100.000000, Test Acc : 98.505435
# Iteration : 91 - Train Loss : 0.034336, Test Loss : 0.053911, Train Acc : 100.000000, Test Acc : 98.505435
# Iteration : 96 - Train Loss : 0.032657, Test Loss : 0.078137, Train Acc : 100.000000, Test Acc : 97.758152
# Iteration : 101 - Train Loss : 0.018626, Test Loss : 0.086924, Train Acc : 100.000000, Test Acc : 98.233696
# Iteration : 106 - Train Loss : 0.160478, Test Loss : 0.054593, Train Acc : 96.875000, Test Acc : 98.641304
# Best Model Saved
# Iteration : 111 - Train Loss : 0.046200, Test Loss : 0.033692, Train Acc : 100.000000, Test Acc : 99.184783
# Best Model Saved
# Iteration : 116 - Train Loss : 0.028823, Test Loss : 0.020576, Train Acc : 100.000000, Test Acc : 99.660326
# Iteration : 121 - Train Loss : 0.031903, Test Loss : 0.041836, Train Acc : 100.000000, Test Acc : 98.845109
# Iteration : 126 - Train Loss : 0.013256, Test Loss : 0.026572, Train Acc : 100.000000, Test Acc : 99.320652
# Best Model Saved
# Iteration : 131 - Train Loss : 0.014043, Test Loss : 0.012509, Train Acc : 100.000000, Test Acc : 99.864130
# Iteration : 136 - Train Loss : 0.130147, Test Loss : 0.018826, Train Acc : 96.875000, Test Acc : 99.524457

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
import os, json, PIL
import pandas as pd

# %%
model = Baseline(model='resnet34', num_classes=157)
model.model.load_state_dict(torch.load('./4_130.pt'))
model.model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])


data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            # print(prediction)
            #if torch.max(prediction) > 0.9:
            #    prediction[torch.argmax(prediction)] = 1
            #    prediction[prediction < 1] = 0
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./ImageNetStat_4_130_threshno.csv', index=False)

# %%
print(len(predictions))
print(len(predictions[0]))
# Out:
# 217
# 157

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    1.366461e-01  7.237936e-04  ...  3.946944e-05  1.999894e-05
# 1    3.031993e-04  8.828874e-06  ...  8.671632e-06  4.664869e-07
# 2    1.104366e-04  1.663295e-03  ...  3.090917e-05  4.972014e-05
# 3    1.028770e-05  2.354617e-04  ...  1.189635e-06  1.067093e-05
# 4    7.966939e-07  1.431662e-05  ...  3.890009e-07  3.063631e-07
# ..            ...           ...  ...           ...           ...
# 212  3.112868e-08  1.128462e-08  ...  2.030404e-05  2.649511e-05
# 213  3.116373e-08  2.535245e-08  ...  9.744344e-07  1.343774e-07
# 214  1.978966e-08  5.644111e-07  ...  9.990149e-01  1.522397e-07
# 215  5.492369e-09  3.708147e-07  ...  9.996974e-01  8.605971e-08
# 216  1.386082e-08  5.666079e-09  ...  1.262487e-06  9.319859e-01
#
# [217 rows x 157 columns]
