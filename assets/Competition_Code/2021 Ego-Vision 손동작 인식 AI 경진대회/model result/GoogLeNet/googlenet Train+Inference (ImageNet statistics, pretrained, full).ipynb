# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/googlenet%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 09:42:28 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='googlenet', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.061329, Test Loss : 5.067383, Train Acc : 3.125000, Test Acc : 1.902174
# Best Model Saved
# Iteration : 6 - Train Loss : 5.049607, Test Loss : 4.976317, Train Acc : 0.000000, Test Acc : 2.038043
# Best Model Saved
# Iteration : 11 - Train Loss : 4.731086, Test Loss : 4.847094, Train Acc : 12.500000, Test Acc : 8.899457
# Best Model Saved
# Iteration : 16 - Train Loss : 4.692593, Test Loss : 4.658761, Train Acc : 12.500000, Test Acc : 5.978261
# Best Model Saved
# Iteration : 21 - Train Loss : 4.617763, Test Loss : 4.495786, Train Acc : 9.375000, Test Acc : 10.190217
# Best Model Saved
# Iteration : 26 - Train Loss : 4.377445, Test Loss : 4.243609, Train Acc : 6.250000, Test Acc : 16.847826
# Best Model Saved
# Iteration : 31 - Train Loss : 4.402074, Test Loss : 3.911682, Train Acc : 15.625000, Test Acc : 17.051630
# Best Model Saved
# Iteration : 36 - Train Loss : 3.915890, Test Loss : 3.718673, Train Acc : 21.875000, Test Acc : 21.467391
# Best Model Saved
# Iteration : 41 - Train Loss : 3.556398, Test Loss : 3.528513, Train Acc : 40.625000, Test Acc : 25.679348
# Best Model Saved
# Iteration : 46 - Train Loss : 3.523932, Test Loss : 3.310458, Train Acc : 21.875000, Test Acc : 32.269022
# Best Model Saved
# Iteration : 51 - Train Loss : 2.963724, Test Loss : 3.120573, Train Acc : 46.875000, Test Acc : 36.548913
# Best Model Saved
# Iteration : 56 - Train Loss : 3.201857, Test Loss : 2.927840, Train Acc : 43.750000, Test Acc : 37.228261
# Best Model Saved
# Iteration : 61 - Train Loss : 3.143734, Test Loss : 2.744062, Train Acc : 37.500000, Test Acc : 39.945652
# Best Model Saved
# Iteration : 66 - Train Loss : 2.848515, Test Loss : 2.559989, Train Acc : 43.750000, Test Acc : 43.885870
# Best Model Saved
# Iteration : 71 - Train Loss : 2.688936, Test Loss : 2.479212, Train Acc : 50.000000, Test Acc : 55.502717
# Best Model Saved
# Iteration : 76 - Train Loss : 2.288874, Test Loss : 2.312743, Train Acc : 59.375000, Test Acc : 53.125000
# Best Model Saved
# Iteration : 81 - Train Loss : 2.487136, Test Loss : 2.164547, Train Acc : 59.375000, Test Acc : 54.008152
# Best Model Saved
# Iteration : 86 - Train Loss : 2.073866, Test Loss : 1.954838, Train Acc : 62.500000, Test Acc : 59.578804
# Best Model Saved
# Iteration : 91 - Train Loss : 1.967645, Test Loss : 1.811897, Train Acc : 62.500000, Test Acc : 63.519022
# Best Model Saved
# Iteration : 96 - Train Loss : 2.137230, Test Loss : 1.784120, Train Acc : 43.750000, Test Acc : 64.402174
# Best Model Saved
# Iteration : 101 - Train Loss : 1.700539, Test Loss : 1.661621, Train Acc : 68.750000, Test Acc : 69.361413
# Best Model Saved
# Iteration : 106 - Train Loss : 1.789412, Test Loss : 1.451816, Train Acc : 65.625000, Test Acc : 71.671196
# Iteration : 111 - Train Loss : 1.684189, Test Loss : 1.534514, Train Acc : 59.375000, Test Acc : 69.701087
# Best Model Saved
# Iteration : 116 - Train Loss : 1.639611, Test Loss : 1.362302, Train Acc : 71.875000, Test Acc : 70.720109
# Best Model Saved
# Iteration : 121 - Train Loss : 1.380685, Test Loss : 1.199374, Train Acc : 81.250000, Test Acc : 77.853261
# Best Model Saved
# Iteration : 126 - Train Loss : 1.544455, Test Loss : 1.121400, Train Acc : 78.125000, Test Acc : 75.815217
# Best Model Saved
# Iteration : 131 - Train Loss : 1.222996, Test Loss : 1.008636, Train Acc : 75.000000, Test Acc : 79.891304
# Best Model Saved
# Iteration : 136 - Train Loss : 1.183729, Test Loss : 0.951999, Train Acc : 75.000000, Test Acc : 81.997283
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 1.098176, Test Loss : 0.875627, Train Acc : 84.375000, Test Acc : 81.657609
# Iteration : 6 - Train Loss : 0.868919, Test Loss : 0.906508, Train Acc : 87.500000, Test Acc : 80.230978
# Best Model Saved
# Iteration : 11 - Train Loss : 0.705429, Test Loss : 0.837209, Train Acc : 96.875000, Test Acc : 84.850543
# Best Model Saved
# Iteration : 16 - Train Loss : 0.895961, Test Loss : 0.837600, Train Acc : 90.625000, Test Acc : 85.937500
# Best Model Saved
# Iteration : 21 - Train Loss : 0.620657, Test Loss : 0.762970, Train Acc : 90.625000, Test Acc : 85.054348
# Best Model Saved
# Iteration : 26 - Train Loss : 0.717898, Test Loss : 0.719205, Train Acc : 90.625000, Test Acc : 87.092391
# Best Model Saved
# Iteration : 31 - Train Loss : 0.840133, Test Loss : 0.717428, Train Acc : 78.125000, Test Acc : 88.790761
# Best Model Saved
# Iteration : 36 - Train Loss : 0.596268, Test Loss : 0.694578, Train Acc : 93.750000, Test Acc : 89.741848
# Iteration : 41 - Train Loss : 0.538959, Test Loss : 0.795599, Train Acc : 93.750000, Test Acc : 87.703804
# Best Model Saved
# Iteration : 46 - Train Loss : 0.533671, Test Loss : 0.517368, Train Acc : 93.750000, Test Acc : 90.557065
# Iteration : 51 - Train Loss : 0.628207, Test Loss : 0.578424, Train Acc : 84.375000, Test Acc : 89.470109
# Best Model Saved
# Iteration : 56 - Train Loss : 0.484773, Test Loss : 0.451768, Train Acc : 90.625000, Test Acc : 91.508152
# Best Model Saved
# Iteration : 61 - Train Loss : 0.434538, Test Loss : 0.410899, Train Acc : 96.875000, Test Acc : 92.730978
# Best Model Saved
# Iteration : 66 - Train Loss : 0.494684, Test Loss : 0.428624, Train Acc : 90.625000, Test Acc : 92.934783
# Iteration : 71 - Train Loss : 0.382843, Test Loss : 0.432172, Train Acc : 96.875000, Test Acc : 90.625000
# Iteration : 76 - Train Loss : 0.436933, Test Loss : 0.430142, Train Acc : 96.875000, Test Acc : 91.372283
# Best Model Saved
# Iteration : 81 - Train Loss : 0.486676, Test Loss : 0.396758, Train Acc : 90.625000, Test Acc : 92.798913
# Best Model Saved
# Iteration : 86 - Train Loss : 0.336664, Test Loss : 0.374142, Train Acc : 87.500000, Test Acc : 93.817935
# Iteration : 91 - Train Loss : 0.257643, Test Loss : 0.377002, Train Acc : 100.000000, Test Acc : 93.546196
# Best Model Saved
# Iteration : 96 - Train Loss : 0.372470, Test Loss : 0.296529, Train Acc : 90.625000, Test Acc : 94.972826
# Best Model Saved
# Iteration : 101 - Train Loss : 0.403394, Test Loss : 0.258009, Train Acc : 96.875000, Test Acc : 96.127717
# Iteration : 106 - Train Loss : 0.361713, Test Loss : 0.340425, Train Acc : 93.750000, Test Acc : 94.361413
# Iteration : 111 - Train Loss : 0.341551, Test Loss : 0.300312, Train Acc : 87.500000, Test Acc : 94.904891
# Iteration : 116 - Train Loss : 0.475231, Test Loss : 0.296354, Train Acc : 93.750000, Test Acc : 93.750000
# Iteration : 121 - Train Loss : 0.307082, Test Loss : 0.265157, Train Acc : 96.875000, Test Acc : 94.972826
# Best Model Saved
# Iteration : 126 - Train Loss : 0.215298, Test Loss : 0.252564, Train Acc : 100.000000, Test Acc : 95.652174
# Best Model Saved
# Iteration : 131 - Train Loss : 0.286103, Test Loss : 0.204390, Train Acc : 96.875000, Test Acc : 96.467391
# Iteration : 136 - Train Loss : 0.300820, Test Loss : 0.279973, Train Acc : 90.625000, Test Acc : 94.225543
#
# Epoch 3 Started...
# Iteration : 1 - Train Loss : 0.248533, Test Loss : 0.254382, Train Acc : 96.875000, Test Acc : 94.972826
# Iteration : 6 - Train Loss : 0.373089, Test Loss : 0.297959, Train Acc : 93.750000, Test Acc : 94.021739
# Best Model Saved
# Iteration : 11 - Train Loss : 0.333689, Test Loss : 0.231059, Train Acc : 93.750000, Test Acc : 97.078804
# Best Model Saved
# Iteration : 16 - Train Loss : 0.289002, Test Loss : 0.192274, Train Acc : 93.750000, Test Acc : 96.535326
# Iteration : 21 - Train Loss : 0.187461, Test Loss : 0.226094, Train Acc : 100.000000, Test Acc : 95.720109
# Best Model Saved
# Iteration : 26 - Train Loss : 0.198567, Test Loss : 0.184712, Train Acc : 93.750000, Test Acc : 95.584239
# Best Model Saved
# Iteration : 31 - Train Loss : 0.103719, Test Loss : 0.147981, Train Acc : 100.000000, Test Acc : 97.350543
# Best Model Saved
# Iteration : 36 - Train Loss : 0.199617, Test Loss : 0.152274, Train Acc : 93.750000, Test Acc : 97.622283
# Iteration : 41 - Train Loss : 0.263990, Test Loss : 0.154666, Train Acc : 100.000000, Test Acc : 97.146739
# Iteration : 46 - Train Loss : 0.129594, Test Loss : 0.187125, Train Acc : 100.000000, Test Acc : 96.467391
# Best Model Saved
# Iteration : 51 - Train Loss : 0.128739, Test Loss : 0.137767, Train Acc : 100.000000, Test Acc : 98.369565
# Iteration : 56 - Train Loss : 0.182131, Test Loss : 0.220282, Train Acc : 96.875000, Test Acc : 96.671196
# Iteration : 61 - Train Loss : 0.143349, Test Loss : 0.246152, Train Acc : 96.875000, Test Acc : 95.448370
# Iteration : 66 - Train Loss : 0.287503, Test Loss : 0.154438, Train Acc : 93.750000, Test Acc : 97.078804
# Iteration : 71 - Train Loss : 0.148747, Test Loss : 0.151408, Train Acc : 96.875000, Test Acc : 97.622283
# Iteration : 76 - Train Loss : 0.161282, Test Loss : 0.148221, Train Acc : 96.875000, Test Acc : 96.807065
# Iteration : 81 - Train Loss : 0.157135, Test Loss : 0.281029, Train Acc : 96.875000, Test Acc : 93.138587
# Iteration : 86 - Train Loss : 0.144173, Test Loss : 0.286360, Train Acc : 96.875000, Test Acc : 93.274457
# Iteration : 91 - Train Loss : 0.141649, Test Loss : 0.175397, Train Acc : 96.875000, Test Acc : 96.942935
# Iteration : 96 - Train Loss : 0.140572, Test Loss : 0.159159, Train Acc : 96.875000, Test Acc : 97.554348
# Iteration : 101 - Train Loss : 0.180416, Test Loss : 0.162063, Train Acc : 96.875000, Test Acc : 97.010870
# Iteration : 106 - Train Loss : 0.115098, Test Loss : 0.159762, Train Acc : 100.000000, Test Acc : 96.942935
# Iteration : 111 - Train Loss : 0.126802, Test Loss : 0.153010, Train Acc : 100.000000, Test Acc : 97.622283
# Iteration : 116 - Train Loss : 0.130977, Test Loss : 0.163012, Train Acc : 100.000000, Test Acc : 95.516304
# Iteration : 121 - Train Loss : 0.233259, Test Loss : 0.186934, Train Acc : 96.875000, Test Acc : 95.584239
# Best Model Saved
# Iteration : 126 - Train Loss : 0.096763, Test Loss : 0.136017, Train Acc : 100.000000, Test Acc : 97.894022
# Iteration : 131 - Train Loss : 0.104014, Test Loss : 0.216492, Train Acc : 96.875000, Test Acc : 94.836957
# Best Model Saved
# Iteration : 136 - Train Loss : 0.068688, Test Loss : 0.126515, Train Acc : 100.000000, Test Acc : 97.961957
#
# Epoch 4 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.161953, Test Loss : 0.103392, Train Acc : 96.875000, Test Acc : 98.097826
# Best Model Saved
# Iteration : 6 - Train Loss : 0.094833, Test Loss : 0.077797, Train Acc : 96.875000, Test Acc : 98.777174
# Iteration : 11 - Train Loss : 0.063472, Test Loss : 0.086892, Train Acc : 100.000000, Test Acc : 98.301630
# Iteration : 16 - Train Loss : 0.037744, Test Loss : 0.129836, Train Acc : 100.000000, Test Acc : 97.214674
# Iteration : 21 - Train Loss : 0.104915, Test Loss : 0.084492, Train Acc : 100.000000, Test Acc : 98.097826
# Iteration : 26 - Train Loss : 0.105112, Test Loss : 0.118873, Train Acc : 96.875000, Test Acc : 97.554348
# Iteration : 31 - Train Loss : 0.079382, Test Loss : 0.083000, Train Acc : 100.000000, Test Acc : 97.961957
# Iteration : 36 - Train Loss : 0.058222, Test Loss : 0.111941, Train Acc : 100.000000, Test Acc : 97.010870
# Iteration : 41 - Train Loss : 0.084675, Test Loss : 0.114945, Train Acc : 100.000000, Test Acc : 96.331522
# Iteration : 46 - Train Loss : 0.127596, Test Loss : 0.081748, Train Acc : 93.750000, Test Acc : 98.233696
# Iteration : 51 - Train Loss : 0.132055, Test Loss : 0.174414, Train Acc : 96.875000, Test Acc : 95.652174
# Iteration : 56 - Train Loss : 0.056402, Test Loss : 0.106230, Train Acc : 100.000000, Test Acc : 97.894022
# Iteration : 61 - Train Loss : 0.049375, Test Loss : 0.184433, Train Acc : 100.000000, Test Acc : 96.399457
# Iteration : 66 - Train Loss : 0.248628, Test Loss : 0.136860, Train Acc : 93.750000, Test Acc : 97.554348
# Iteration : 71 - Train Loss : 0.182095, Test Loss : 0.104355, Train Acc : 96.875000, Test Acc : 98.029891
# Iteration : 76 - Train Loss : 0.187816, Test Loss : 0.124508, Train Acc : 90.625000, Test Acc : 96.739130
# Iteration : 81 - Train Loss : 0.241743, Test Loss : 0.078828, Train Acc : 93.750000, Test Acc : 98.505435
# Iteration : 86 - Train Loss : 0.052764, Test Loss : 0.137547, Train Acc : 100.000000, Test Acc : 96.467391
# Iteration : 91 - Train Loss : 0.084419, Test Loss : 0.127154, Train Acc : 100.000000, Test Acc : 97.214674
# Iteration : 96 - Train Loss : 0.058820, Test Loss : 0.122608, Train Acc : 100.000000, Test Acc : 97.078804
# Iteration : 101 - Train Loss : 0.049783, Test Loss : 0.096310, Train Acc : 100.000000, Test Acc : 97.894022
# Iteration : 106 - Train Loss : 0.050725, Test Loss : 0.175824, Train Acc : 100.000000, Test Acc : 97.282609
# Iteration : 111 - Train Loss : 0.054857, Test Loss : 0.079210, Train Acc : 100.000000, Test Acc : 98.437500
# Iteration : 116 - Train Loss : 0.121704, Test Loss : 0.083508, Train Acc : 93.750000, Test Acc : 98.301630
# Iteration : 121 - Train Loss : 0.112202, Test Loss : 0.102670, Train Acc : 96.875000, Test Acc : 97.826087
# Iteration : 126 - Train Loss : 0.037311, Test Loss : 0.142341, Train Acc : 100.000000, Test Acc : 96.535326
# Iteration : 131 - Train Loss : 0.164199, Test Loss : 0.169214, Train Acc : 96.875000, Test Acc : 96.603261
# Iteration : 136 - Train Loss : 0.129885, Test Loss : 0.098887, Train Acc : 96.875000, Test Acc : 98.165761
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.057782, Test Loss : 0.094269, Train Acc : 100.000000, Test Acc : 97.554348
# Iteration : 6 - Train Loss : 0.061871, Test Loss : 0.078302, Train Acc : 100.000000, Test Acc : 98.369565
# Iteration : 11 - Train Loss : 0.052292, Test Loss : 0.083897, Train Acc : 100.000000, Test Acc : 98.301630
# Best Model Saved
# Iteration : 16 - Train Loss : 0.034525, Test Loss : 0.050431, Train Acc : 100.000000, Test Acc : 99.456522
# Best Model Saved
# Iteration : 21 - Train Loss : 0.045339, Test Loss : 0.035295, Train Acc : 100.000000, Test Acc : 99.524457
# Best Model Saved
# Iteration : 26 - Train Loss : 0.025690, Test Loss : 0.027006, Train Acc : 100.000000, Test Acc : 99.524457
# Best Model Saved
# Iteration : 31 - Train Loss : 0.055892, Test Loss : 0.019011, Train Acc : 100.000000, Test Acc : 99.728261
# Iteration : 36 - Train Loss : 0.046534, Test Loss : 0.021146, Train Acc : 100.000000, Test Acc : 99.592391
# Iteration : 41 - Train Loss : 0.026768, Test Loss : 0.025205, Train Acc : 100.000000, Test Acc : 99.456522
# Iteration : 46 - Train Loss : 0.035947, Test Loss : 0.028932, Train Acc : 100.000000, Test Acc : 99.184783
# Iteration : 51 - Train Loss : 0.042592, Test Loss : 0.039062, Train Acc : 100.000000, Test Acc : 99.252717
# Iteration : 56 - Train Loss : 0.027678, Test Loss : 0.055482, Train Acc : 100.000000, Test Acc : 98.777174
# Iteration : 61 - Train Loss : 0.040735, Test Loss : 0.036406, Train Acc : 100.000000, Test Acc : 99.048913
# Iteration : 66 - Train Loss : 0.191396, Test Loss : 0.043838, Train Acc : 96.875000, Test Acc : 99.252717
# Iteration : 71 - Train Loss : 0.034449, Test Loss : 0.048924, Train Acc : 100.000000, Test Acc : 98.709239
# Iteration : 76 - Train Loss : 0.028904, Test Loss : 0.067705, Train Acc : 100.000000, Test Acc : 98.369565
# Iteration : 81 - Train Loss : 0.070075, Test Loss : 0.062756, Train Acc : 96.875000, Test Acc : 98.505435
# Iteration : 86 - Train Loss : 0.020955, Test Loss : 0.058119, Train Acc : 100.000000, Test Acc : 98.845109
# Iteration : 91 - Train Loss : 0.043812, Test Loss : 0.042312, Train Acc : 100.000000, Test Acc : 99.116848
# Iteration : 96 - Train Loss : 0.023090, Test Loss : 0.033051, Train Acc : 100.000000, Test Acc : 98.980978
# Iteration : 101 - Train Loss : 0.038123, Test Loss : 0.044679, Train Acc : 100.000000, Test Acc : 98.369565
# Iteration : 106 - Train Loss : 0.018830, Test Loss : 0.027019, Train Acc : 100.000000, Test Acc : 99.320652
# Iteration : 111 - Train Loss : 0.024151, Test Loss : 0.048042, Train Acc : 100.000000, Test Acc : 98.709239
# Iteration : 116 - Train Loss : 0.057503, Test Loss : 0.057141, Train Acc : 96.875000, Test Acc : 98.845109
# Iteration : 121 - Train Loss : 0.034490, Test Loss : 0.055665, Train Acc : 100.000000, Test Acc : 99.048913
# Iteration : 126 - Train Loss : 0.060454, Test Loss : 0.064422, Train Acc : 100.000000, Test Acc : 98.709239
# Iteration : 131 - Train Loss : 0.067936, Test Loss : 0.144596, Train Acc : 100.000000, Test Acc : 96.535326
# Iteration : 136 - Train Loss : 0.031175, Test Loss : 0.142369, Train Acc : 100.000000, Test Acc : 96.875000

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='googlenet', num_classes=157)
model.model.load_state_dict(torch.load('./4_30.pt'))
model.model.eval()
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./googlenet_ImageNetStat_4_30.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0   Label_1   Label_2  ...  Label_193  Label_194     Label_195
# 0    5.539809e-01  0.008045  0.000318  ...   0.000067   0.000029  1.934490e-05
# 1    2.095108e-04  0.000015  0.000023  ...   0.000002   0.000002  2.265765e-06
# 2    9.225801e-04  0.009336  0.001042  ...   0.000016   0.000017  3.130403e-06
# 3    1.427380e-04  0.000957  0.000136  ...   0.000001   0.000001  6.020099e-07
# 4    1.775183e-05  0.000166  0.005565  ...   0.000004   0.000004  1.095516e-06
# ..            ...       ...       ...  ...        ...        ...           ...
# 212  2.890200e-06  0.000005  0.000007  ...   0.000303   0.000069  3.698506e-05
# 213  7.502743e-06  0.000014  0.000002  ...   0.991826   0.000206  4.648002e-06
# 214  5.868749e-07  0.000003  0.000005  ...   0.000510   0.995836  5.179538e-07
# 215  7.345798e-06  0.000031  0.000015  ...   0.004863   0.980848  1.181021e-06
# 216  1.882754e-06  0.000009  0.000003  ...   0.000265   0.000149  8.425871e-01
#
# [217 rows x 157 columns]
