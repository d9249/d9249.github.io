# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/BatchSize_32_DenseNet121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 19:54:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 8

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='densenet121', num_classes=len(train_dataset.label_info), print_freq=5, save=True)

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.090020, Test Loss : 5.127831, Train Acc : 0.000000, Test Acc : 2.581522
# Best Model Saved
# Iteration : 6 - Train Loss : 5.059343, Test Loss : 4.933393, Train Acc : 6.250000, Test Acc : 5.434783
# Best Model Saved
# Iteration : 11 - Train Loss : 4.324400, Test Loss : 4.627605, Train Acc : 15.625000, Test Acc : 7.540761
# Best Model Saved
# Iteration : 16 - Train Loss : 4.394860, Test Loss : 4.295653, Train Acc : 6.250000, Test Acc : 13.994565
# Best Model Saved
# Iteration : 21 - Train Loss : 4.484623, Test Loss : 4.047744, Train Acc : 3.125000, Test Acc : 16.440217
# Best Model Saved
# Iteration : 26 - Train Loss : 4.106350, Test Loss : 3.694409, Train Acc : 18.750000, Test Acc : 23.777174
# Best Model Saved
# Iteration : 31 - Train Loss : 3.690440, Test Loss : 3.503090, Train Acc : 18.750000, Test Acc : 26.358696
# Best Model Saved
# Iteration : 36 - Train Loss : 3.393407, Test Loss : 3.176632, Train Acc : 25.000000, Test Acc : 28.464674
# Best Model Saved
# Iteration : 41 - Train Loss : 2.820421, Test Loss : 3.079023, Train Acc : 34.375000, Test Acc : 29.144022
# Best Model Saved
# Iteration : 46 - Train Loss : 2.891789, Test Loss : 2.847660, Train Acc : 28.125000, Test Acc : 32.608696
# Best Model Saved
# Iteration : 51 - Train Loss : 2.500391, Test Loss : 2.737542, Train Acc : 50.000000, Test Acc : 45.855978
# Best Model Saved
# Iteration : 56 - Train Loss : 2.593704, Test Loss : 2.493480, Train Acc : 53.125000, Test Acc : 48.165761
# Best Model Saved
# Iteration : 61 - Train Loss : 2.350560, Test Loss : 2.325545, Train Acc : 43.750000, Test Acc : 52.173913
# Best Model Saved
# Iteration : 66 - Train Loss : 2.548268, Test Loss : 2.183514, Train Acc : 40.625000, Test Acc : 55.434783
# Best Model Saved
# Iteration : 71 - Train Loss : 2.129056, Test Loss : 1.984224, Train Acc : 59.375000, Test Acc : 57.540761
# Best Model Saved
# Iteration : 76 - Train Loss : 2.060403, Test Loss : 1.920247, Train Acc : 59.375000, Test Acc : 62.228261
# Best Model Saved
# Iteration : 81 - Train Loss : 2.057032, Test Loss : 1.723669, Train Acc : 46.875000, Test Acc : 65.557065
# Best Model Saved
# Iteration : 86 - Train Loss : 1.391930, Test Loss : 1.526829, Train Acc : 78.125000, Test Acc : 66.032609
# Best Model Saved
# Iteration : 91 - Train Loss : 1.373144, Test Loss : 1.424061, Train Acc : 75.000000, Test Acc : 70.923913
# Best Model Saved
# Iteration : 96 - Train Loss : 1.233895, Test Loss : 1.342789, Train Acc : 78.125000, Test Acc : 70.652174
# Best Model Saved
# Iteration : 101 - Train Loss : 1.347136, Test Loss : 1.331664, Train Acc : 68.750000, Test Acc : 74.184783
# Iteration : 106 - Train Loss : 1.175938, Test Loss : 1.338317, Train Acc : 75.000000, Test Acc : 72.282609
# Best Model Saved
# Iteration : 111 - Train Loss : 1.243116, Test Loss : 1.226157, Train Acc : 59.375000, Test Acc : 73.029891
# Best Model Saved
# Iteration : 116 - Train Loss : 1.189894, Test Loss : 1.172848, Train Acc : 84.375000, Test Acc : 75.135870
# Best Model Saved
# Iteration : 121 - Train Loss : 1.334822, Test Loss : 1.017724, Train Acc : 75.000000, Test Acc : 81.657609
# Best Model Saved
# Iteration : 126 - Train Loss : 0.881039, Test Loss : 1.008496, Train Acc : 87.500000, Test Acc : 76.766304
# Best Model Saved
# Iteration : 131 - Train Loss : 1.160898, Test Loss : 0.895885, Train Acc : 71.875000, Test Acc : 81.114130
# Best Model Saved
# Iteration : 136 - Train Loss : 0.901657, Test Loss : 0.831076, Train Acc : 87.500000, Test Acc : 83.016304
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.837082, Test Loss : 0.773834, Train Acc : 81.250000, Test Acc : 87.703804
# Iteration : 6 - Train Loss : 0.536236, Test Loss : 0.856785, Train Acc : 96.875000, Test Acc : 85.665761
# Best Model Saved
# Iteration : 11 - Train Loss : 0.590216, Test Loss : 0.757769, Train Acc : 93.750000, Test Acc : 85.733696
# Best Model Saved
# Iteration : 16 - Train Loss : 0.618809, Test Loss : 0.732242, Train Acc : 93.750000, Test Acc : 85.597826
# Best Model Saved
# Iteration : 21 - Train Loss : 0.517664, Test Loss : 0.712368, Train Acc : 87.500000, Test Acc : 81.453804
# Best Model Saved
# Iteration : 26 - Train Loss : 0.645466, Test Loss : 0.507662, Train Acc : 87.500000, Test Acc : 88.315217
# Iteration : 31 - Train Loss : 0.874949, Test Loss : 0.617932, Train Acc : 84.375000, Test Acc : 83.763587
# Best Model Saved
# Iteration : 36 - Train Loss : 0.468605, Test Loss : 0.566459, Train Acc : 90.625000, Test Acc : 90.217391
# Iteration : 41 - Train Loss : 0.456059, Test Loss : 0.616419, Train Acc : 96.875000, Test Acc : 86.616848
# Best Model Saved
# Iteration : 46 - Train Loss : 0.496101, Test Loss : 0.444092, Train Acc : 96.875000, Test Acc : 91.100543
# Iteration : 51 - Train Loss : 0.367029, Test Loss : 0.444458, Train Acc : 87.500000, Test Acc : 90.964674
# Best Model Saved
# Iteration : 56 - Train Loss : 0.546741, Test Loss : 0.379184, Train Acc : 84.375000, Test Acc : 93.070652
# Iteration : 61 - Train Loss : 0.472933, Test Loss : 0.436598, Train Acc : 87.500000, Test Acc : 91.304348
# Iteration : 66 - Train Loss : 0.505454, Test Loss : 0.392852, Train Acc : 90.625000, Test Acc : 92.119565
# Iteration : 71 - Train Loss : 0.335205, Test Loss : 0.444036, Train Acc : 100.000000, Test Acc : 91.372283
# Iteration : 76 - Train Loss : 0.345779, Test Loss : 0.479513, Train Acc : 93.750000, Test Acc : 89.266304
# Iteration : 81 - Train Loss : 0.352195, Test Loss : 0.418077, Train Acc : 96.875000, Test Acc : 91.915761
# Iteration : 86 - Train Loss : 0.342457, Test Loss : 0.402397, Train Acc : 93.750000, Test Acc : 90.692935
# Best Model Saved
# Iteration : 91 - Train Loss : 0.399537, Test Loss : 0.366486, Train Acc : 93.750000, Test Acc : 91.576087
# Best Model Saved
# Iteration : 96 - Train Loss : 0.418760, Test Loss : 0.334347, Train Acc : 90.625000, Test Acc : 93.546196
# Best Model Saved
# Iteration : 101 - Train Loss : 0.299596, Test Loss : 0.315100, Train Acc : 93.750000, Test Acc : 93.410326
# Iteration : 106 - Train Loss : 0.388827, Test Loss : 0.365475, Train Acc : 93.750000, Test Acc : 92.051630
# Best Model Saved
# Iteration : 111 - Train Loss : 0.402136, Test Loss : 0.294058, Train Acc : 90.625000, Test Acc : 93.817935
# Best Model Saved
# Iteration : 116 - Train Loss : 0.379074, Test Loss : 0.242316, Train Acc : 96.875000, Test Acc : 93.750000
# Iteration : 121 - Train Loss : 0.455119, Test Loss : 0.304885, Train Acc : 87.500000, Test Acc : 91.644022
# Best Model Saved
# Iteration : 126 - Train Loss : 0.376243, Test Loss : 0.309419, Train Acc : 93.750000, Test Acc : 93.817935
# Best Model Saved
# Iteration : 131 - Train Loss : 0.250170, Test Loss : 0.235861, Train Acc : 93.750000, Test Acc : 94.972826
# Best Model Saved
# Iteration : 136 - Train Loss : 0.390987, Test Loss : 0.206966, Train Acc : 87.500000, Test Acc : 97.418478
#
# Epoch 3 Started...
# Iteration : 1 - Train Loss : 0.187485, Test Loss : 0.297297, Train Acc : 96.875000, Test Acc : 94.361413
# Iteration : 6 - Train Loss : 0.202636, Test Loss : 0.210327, Train Acc : 96.875000, Test Acc : 96.807065
# Iteration : 11 - Train Loss : 0.203993, Test Loss : 0.226437, Train Acc : 100.000000, Test Acc : 95.244565
# Iteration : 16 - Train Loss : 0.116376, Test Loss : 0.221438, Train Acc : 100.000000, Test Acc : 95.516304
# Iteration : 21 - Train Loss : 0.257321, Test Loss : 0.226484, Train Acc : 90.625000, Test Acc : 94.565217
# Iteration : 26 - Train Loss : 0.337066, Test Loss : 0.218896, Train Acc : 90.625000, Test Acc : 94.769022
# Iteration : 31 - Train Loss : 0.185018, Test Loss : 0.240102, Train Acc : 96.875000, Test Acc : 95.040761
# Best Model Saved
# Iteration : 36 - Train Loss : 0.154149, Test Loss : 0.190692, Train Acc : 96.875000, Test Acc : 96.535326
# Best Model Saved
# Iteration : 41 - Train Loss : 0.155880, Test Loss : 0.162935, Train Acc : 96.875000, Test Acc : 96.739130
# Iteration : 46 - Train Loss : 0.076343, Test Loss : 0.197867, Train Acc : 100.000000, Test Acc : 95.855978
# Iteration : 51 - Train Loss : 0.179302, Test Loss : 0.163496, Train Acc : 96.875000, Test Acc : 96.671196
# Best Model Saved
# Iteration : 56 - Train Loss : 0.139393, Test Loss : 0.183129, Train Acc : 96.875000, Test Acc : 97.078804
# Iteration : 61 - Train Loss : 0.124500, Test Loss : 0.185302, Train Acc : 96.875000, Test Acc : 97.010870
# Iteration : 66 - Train Loss : 0.106700, Test Loss : 0.186117, Train Acc : 100.000000, Test Acc : 96.059783
# Iteration : 71 - Train Loss : 0.111502, Test Loss : 0.269244, Train Acc : 100.000000, Test Acc : 93.070652
# Iteration : 76 - Train Loss : 0.112552, Test Loss : 0.198273, Train Acc : 100.000000, Test Acc : 95.652174
# Best Model Saved
# Iteration : 81 - Train Loss : 0.120006, Test Loss : 0.158018, Train Acc : 96.875000, Test Acc : 96.195652
# Iteration : 86 - Train Loss : 0.191924, Test Loss : 0.185197, Train Acc : 93.750000, Test Acc : 94.633152
# Iteration : 91 - Train Loss : 0.119506, Test Loss : 0.216868, Train Acc : 100.000000, Test Acc : 94.904891
# Best Model Saved
# Iteration : 96 - Train Loss : 0.179556, Test Loss : 0.101249, Train Acc : 96.875000, Test Acc : 98.369565
# Iteration : 101 - Train Loss : 0.207527, Test Loss : 0.156820, Train Acc : 93.750000, Test Acc : 96.331522
# Iteration : 106 - Train Loss : 0.129326, Test Loss : 0.112865, Train Acc : 96.875000, Test Acc : 97.554348
# Iteration : 111 - Train Loss : 0.250185, Test Loss : 0.108532, Train Acc : 96.875000, Test Acc : 97.282609
# Best Model Saved
# Iteration : 116 - Train Loss : 0.151173, Test Loss : 0.091968, Train Acc : 96.875000, Test Acc : 98.641304
# Best Model Saved
# Iteration : 121 - Train Loss : 0.049516, Test Loss : 0.076856, Train Acc : 100.000000, Test Acc : 98.777174
# Iteration : 126 - Train Loss : 0.070537, Test Loss : 0.107466, Train Acc : 100.000000, Test Acc : 97.622283
# Iteration : 131 - Train Loss : 0.113177, Test Loss : 0.146016, Train Acc : 96.875000, Test Acc : 96.467391
# Iteration : 136 - Train Loss : 0.086689, Test Loss : 0.153758, Train Acc : 100.000000, Test Acc : 96.059783
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 0.211715, Test Loss : 0.128165, Train Acc : 90.625000, Test Acc : 97.622283
# Iteration : 6 - Train Loss : 0.104769, Test Loss : 0.154039, Train Acc : 96.875000, Test Acc : 96.535326
# Iteration : 11 - Train Loss : 0.112591, Test Loss : 0.167058, Train Acc : 100.000000, Test Acc : 96.875000
# Iteration : 16 - Train Loss : 0.184799, Test Loss : 0.086523, Train Acc : 96.875000, Test Acc : 98.369565
# Best Model Saved
# Iteration : 21 - Train Loss : 0.046796, Test Loss : 0.080278, Train Acc : 100.000000, Test Acc : 98.845109
# Best Model Saved
# Iteration : 26 - Train Loss : 0.059654, Test Loss : 0.075442, Train Acc : 100.000000, Test Acc : 98.369565
# Best Model Saved
# Iteration : 31 - Train Loss : 0.177951, Test Loss : 0.056813, Train Acc : 96.875000, Test Acc : 98.980978
# Iteration : 36 - Train Loss : 0.152322, Test Loss : 0.104020, Train Acc : 96.875000, Test Acc : 98.165761
# Iteration : 41 - Train Loss : 0.057153, Test Loss : 0.452488, Train Acc : 100.000000, Test Acc : 89.741848
# Iteration : 46 - Train Loss : 0.112481, Test Loss : 0.366393, Train Acc : 100.000000, Test Acc : 90.013587
# Iteration : 51 - Train Loss : 0.140053, Test Loss : 0.196876, Train Acc : 96.875000, Test Acc : 94.904891
# Iteration : 56 - Train Loss : 0.255406, Test Loss : 0.184422, Train Acc : 93.750000, Test Acc : 95.380435
# Iteration : 61 - Train Loss : 0.150184, Test Loss : 0.220738, Train Acc : 93.750000, Test Acc : 94.904891
# Iteration : 66 - Train Loss : 0.208557, Test Loss : 0.240800, Train Acc : 93.750000, Test Acc : 94.701087
# Iteration : 71 - Train Loss : 0.211775, Test Loss : 0.268193, Train Acc : 93.750000, Test Acc : 93.138587
# Iteration : 76 - Train Loss : 0.104403, Test Loss : 0.141547, Train Acc : 100.000000, Test Acc : 96.467391
# Iteration : 81 - Train Loss : 0.145005, Test Loss : 0.144388, Train Acc : 100.000000, Test Acc : 96.875000
# Iteration : 86 - Train Loss : 0.113513, Test Loss : 0.141449, Train Acc : 100.000000, Test Acc : 96.399457
# Iteration : 91 - Train Loss : 0.129185, Test Loss : 0.086757, Train Acc : 96.875000, Test Acc : 98.437500
# Iteration : 96 - Train Loss : 0.076813, Test Loss : 0.158152, Train Acc : 100.000000, Test Acc : 95.380435
# Iteration : 101 - Train Loss : 0.094553, Test Loss : 0.150850, Train Acc : 100.000000, Test Acc : 96.399457
# Iteration : 106 - Train Loss : 0.079212, Test Loss : 0.178831, Train Acc : 100.000000, Test Acc : 96.127717
# Iteration : 111 - Train Loss : 0.113265, Test Loss : 0.292587, Train Acc : 96.875000, Test Acc : 93.750000
# Iteration : 116 - Train Loss : 0.123624, Test Loss : 0.332053, Train Acc : 100.000000, Test Acc : 92.119565
# Iteration : 121 - Train Loss : 0.343340, Test Loss : 0.188518, Train Acc : 90.625000, Test Acc : 95.720109
# Iteration : 126 - Train Loss : 0.260788, Test Loss : 0.247678, Train Acc : 90.625000, Test Acc : 93.953804
# Iteration : 131 - Train Loss : 0.143038, Test Loss : 0.198344, Train Acc : 96.875000, Test Acc : 95.991848
# Iteration : 136 - Train Loss : 0.259953, Test Loss : 0.114364, Train Acc : 90.625000, Test Acc : 96.399457
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.058064, Test Loss : 0.118458, Train Acc : 100.000000, Test Acc : 97.214674
# Iteration : 6 - Train Loss : 0.061879, Test Loss : 0.167716, Train Acc : 100.000000, Test Acc : 95.652174
# Iteration : 11 - Train Loss : 0.097706, Test Loss : 0.234013, Train Acc : 96.875000, Test Acc : 94.701087
# Iteration : 16 - Train Loss : 0.352649, Test Loss : 0.145178, Train Acc : 90.625000, Test Acc : 96.331522
# Iteration : 21 - Train Loss : 0.049083, Test Loss : 0.105246, Train Acc : 100.000000, Test Acc : 97.826087
# Iteration : 26 - Train Loss : 0.095778, Test Loss : 0.096000, Train Acc : 100.000000, Test Acc : 98.029891
# Iteration : 31 - Train Loss : 0.244156, Test Loss : 0.241973, Train Acc : 96.875000, Test Acc : 94.361413
# Iteration : 36 - Train Loss : 0.063350, Test Loss : 0.073233, Train Acc : 100.000000, Test Acc : 98.233696
# Iteration : 41 - Train Loss : 0.100586, Test Loss : 0.091991, Train Acc : 100.000000, Test Acc : 98.097826
# Best Model Saved
# Iteration : 46 - Train Loss : 0.068229, Test Loss : 0.058991, Train Acc : 96.875000, Test Acc : 99.252717
# Iteration : 51 - Train Loss : 0.051224, Test Loss : 0.061258, Train Acc : 100.000000, Test Acc : 98.845109
# Iteration : 56 - Train Loss : 0.103630, Test Loss : 0.067642, Train Acc : 96.875000, Test Acc : 98.437500
# Iteration : 61 - Train Loss : 0.067584, Test Loss : 0.103500, Train Acc : 100.000000, Test Acc : 98.233696
# Iteration : 66 - Train Loss : 0.073807, Test Loss : 0.065214, Train Acc : 100.000000, Test Acc : 98.845109
# Iteration : 71 - Train Loss : 0.080370, Test Loss : 0.131314, Train Acc : 100.000000, Test Acc : 97.010870
# Iteration : 76 - Train Loss : 0.059729, Test Loss : 0.095881, Train Acc : 100.000000, Test Acc : 97.622283
# Iteration : 81 - Train Loss : 0.087023, Test Loss : 0.062763, Train Acc : 96.875000, Test Acc : 98.709239
# Iteration : 86 - Train Loss : 0.057786, Test Loss : 0.062110, Train Acc : 100.000000, Test Acc : 98.505435
# Best Model Saved
# Iteration : 91 - Train Loss : 0.055253, Test Loss : 0.040337, Train Acc : 100.000000, Test Acc : 98.913043
# Best Model Saved
# Iteration : 96 - Train Loss : 0.140528, Test Loss : 0.036771, Train Acc : 96.875000, Test Acc : 99.320652
# Iteration : 101 - Train Loss : 0.034667, Test Loss : 0.273559, Train Acc : 100.000000, Test Acc : 93.614130
# Iteration : 106 - Train Loss : 0.030844, Test Loss : 0.086800, Train Acc : 100.000000, Test Acc : 97.826087
# Iteration : 111 - Train Loss : 0.030286, Test Loss : 0.132392, Train Acc : 100.000000, Test Acc : 96.331522
# Iteration : 116 - Train Loss : 0.035100, Test Loss : 0.077672, Train Acc : 100.000000, Test Acc : 97.894022
# Iteration : 121 - Train Loss : 0.165635, Test Loss : 0.044761, Train Acc : 96.875000, Test Acc : 99.048913
# Best Model Saved
# Iteration : 126 - Train Loss : 0.098942, Test Loss : 0.032766, Train Acc : 96.875000, Test Acc : 99.592391
# Best Model Saved
# Iteration : 131 - Train Loss : 0.044062, Test Loss : 0.033768, Train Acc : 100.000000, Test Acc : 99.796196
# Iteration : 136 - Train Loss : 0.028307, Test Loss : 0.039241, Train Acc : 100.000000, Test Acc : 99.320652

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='densenet121', num_classes=157)
model.model.load_state_dict(torch.load('./4_130.pt'))
model.model.eval()
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./densenet121_4_4_130.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...  Label_194     Label_195
# 0    8.678947e-01  7.689136e-03  ...   0.000002  6.938843e-07
# 1    3.827260e-03  2.803014e-04  ...   0.000001  7.990895e-07
# 2    6.586339e-03  6.002508e-02  ...   0.000052  7.038833e-05
# 3    3.118858e-03  1.992053e-02  ...   0.000027  8.686486e-05
# 4    7.001619e-05  7.517673e-04  ...   0.000004  7.223719e-06
# ..            ...           ...  ...        ...           ...
# 212  2.326473e-05  4.828615e-06  ...   0.000109  1.504748e-03
# 213  2.502904e-08  7.096286e-09  ...   0.000009  3.895384e-06
# 214  1.701599e-06  8.949551e-06  ...   0.912599  3.665375e-04
# 215  1.298017e-06  2.958690e-06  ...   0.935232  1.692173e-04
# 216  7.580608e-07  1.216503e-06  ...   0.000103  9.622114e-01
#
# [217 rows x 157 columns]
