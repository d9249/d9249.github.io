# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/squeezenet1_1%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 03:10:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Dropout(p=0.5, inplace=False),
            nn.Conv2d(512, num_classes, kernel_size=(1, 1), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(output_size=(1, 1)),
        )
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='squeezenet1_1', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-b8a52dc0.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_1-b8a52dc0.pth
#   0%|          | 0.00/4.73M [00:00<?, ?B/s]

# %%
len(train_dataset.label_info)
# Out:
# 157

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.447302, Test Loss : 5.086867, Train Acc : 0.000000, Test Acc : 1.426630
# Iteration : 6 - Train Loss : 5.032979, Test Loss : 5.093157, Train Acc : 0.000000, Test Acc : 0.883152
# Best Model Saved
# Iteration : 11 - Train Loss : 5.054926, Test Loss : 5.039493, Train Acc : 0.000000, Test Acc : 0.951087
# Best Model Saved
# Iteration : 16 - Train Loss : 5.045074, Test Loss : 5.039034, Train Acc : 0.000000, Test Acc : 1.086957
# Best Model Saved
# Iteration : 21 - Train Loss : 5.061540, Test Loss : 5.048045, Train Acc : 3.125000, Test Acc : 1.902174
# Best Model Saved
# Iteration : 26 - Train Loss : 5.043754, Test Loss : 5.037418, Train Acc : 3.125000, Test Acc : 1.970109
# Best Model Saved
# Iteration : 31 - Train Loss : 5.039242, Test Loss : 5.034522, Train Acc : 0.000000, Test Acc : 1.086957
# Best Model Saved
# Iteration : 36 - Train Loss : 5.018495, Test Loss : 5.013576, Train Acc : 3.125000, Test Acc : 1.970109
# Best Model Saved
# Iteration : 41 - Train Loss : 5.082825, Test Loss : 4.988575, Train Acc : 0.000000, Test Acc : 2.513587
# Best Model Saved
# Iteration : 46 - Train Loss : 5.048973, Test Loss : 4.956886, Train Acc : 0.000000, Test Acc : 2.241848
# Best Model Saved
# Iteration : 51 - Train Loss : 4.936254, Test Loss : 4.920501, Train Acc : 0.000000, Test Acc : 1.494565
# Best Model Saved
# Iteration : 56 - Train Loss : 4.913233, Test Loss : 4.933225, Train Acc : 9.375000, Test Acc : 2.717391
# Best Model Saved
# Iteration : 61 - Train Loss : 4.927546, Test Loss : 4.925923, Train Acc : 0.000000, Test Acc : 1.970109
# Best Model Saved
# Iteration : 66 - Train Loss : 4.880091, Test Loss : 4.895158, Train Acc : 0.000000, Test Acc : 1.698370
# Iteration : 71 - Train Loss : 4.878461, Test Loss : 4.910936, Train Acc : 3.125000, Test Acc : 1.562500
# Best Model Saved
# Iteration : 76 - Train Loss : 4.757633, Test Loss : 4.889576, Train Acc : 0.000000, Test Acc : 1.562500
# Best Model Saved
# Iteration : 81 - Train Loss : 4.895216, Test Loss : 4.875983, Train Acc : 0.000000, Test Acc : 3.057065
# Best Model Saved
# Iteration : 86 - Train Loss : 5.029115, Test Loss : 4.867954, Train Acc : 3.125000, Test Acc : 1.902174
# Best Model Saved
# Iteration : 91 - Train Loss : 4.855810, Test Loss : 4.829711, Train Acc : 0.000000, Test Acc : 2.377717
# Best Model Saved
# Iteration : 96 - Train Loss : 4.729600, Test Loss : 4.822620, Train Acc : 0.000000, Test Acc : 2.038043
# Best Model Saved
# Iteration : 101 - Train Loss : 4.630296, Test Loss : 4.735221, Train Acc : 0.000000, Test Acc : 2.649457
# Iteration : 106 - Train Loss : 4.897649, Test Loss : 4.751374, Train Acc : 3.125000, Test Acc : 1.698370
# Best Model Saved
# Iteration : 111 - Train Loss : 4.625453, Test Loss : 4.707431, Train Acc : 0.000000, Test Acc : 3.600543
# Best Model Saved
# Iteration : 116 - Train Loss : 4.660254, Test Loss : 4.667377, Train Acc : 6.250000, Test Acc : 2.105978
# Best Model Saved
# Iteration : 121 - Train Loss : 4.582714, Test Loss : 4.649700, Train Acc : 6.250000, Test Acc : 2.309783
# Best Model Saved
# Iteration : 126 - Train Loss : 4.661270, Test Loss : 4.578073, Train Acc : 0.000000, Test Acc : 3.668478
# Best Model Saved
# Iteration : 131 - Train Loss : 4.540246, Test Loss : 4.575576, Train Acc : 6.250000, Test Acc : 2.921196
# Best Model Saved
# Iteration : 136 - Train Loss : 4.515135, Test Loss : 4.476118, Train Acc : 3.125000, Test Acc : 3.328804
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 4.186017, Test Loss : 4.456584, Train Acc : 3.125000, Test Acc : 4.891304
# Best Model Saved
# Iteration : 6 - Train Loss : 4.281459, Test Loss : 4.412291, Train Acc : 3.125000, Test Acc : 4.551630
# Best Model Saved
# Iteration : 11 - Train Loss : 4.340509, Test Loss : 4.313649, Train Acc : 0.000000, Test Acc : 4.891304
# Best Model Saved
# Iteration : 16 - Train Loss : 4.231045, Test Loss : 4.376781, Train Acc : 6.250000, Test Acc : 6.250000
# Iteration : 21 - Train Loss : 4.543930, Test Loss : 4.388868, Train Acc : 9.375000, Test Acc : 4.279891
# Best Model Saved
# Iteration : 26 - Train Loss : 4.131005, Test Loss : 4.310066, Train Acc : 3.125000, Test Acc : 5.570652
# Best Model Saved
# Iteration : 31 - Train Loss : 3.873977, Test Loss : 4.174110, Train Acc : 21.875000, Test Acc : 5.910326
# Best Model Saved
# Iteration : 36 - Train Loss : 4.157010, Test Loss : 4.145472, Train Acc : 6.250000, Test Acc : 9.510870
# Iteration : 41 - Train Loss : 4.270400, Test Loss : 4.200163, Train Acc : 9.375000, Test Acc : 6.929348
# Best Model Saved
# Iteration : 46 - Train Loss : 4.158505, Test Loss : 4.080534, Train Acc : 9.375000, Test Acc : 6.385870
# Best Model Saved
# Iteration : 51 - Train Loss : 4.162078, Test Loss : 4.039960, Train Acc : 3.125000, Test Acc : 7.880435
# Best Model Saved
# Iteration : 56 - Train Loss : 3.723947, Test Loss : 3.917240, Train Acc : 15.625000, Test Acc : 9.918478
# Best Model Saved
# Iteration : 61 - Train Loss : 3.733335, Test Loss : 3.871528, Train Acc : 9.375000, Test Acc : 10.529891
# Iteration : 66 - Train Loss : 4.419618, Test Loss : 3.945925, Train Acc : 0.000000, Test Acc : 8.695652
# Best Model Saved
# Iteration : 71 - Train Loss : 3.983608, Test Loss : 3.859892, Train Acc : 12.500000, Test Acc : 11.684783
# Best Model Saved
# Iteration : 76 - Train Loss : 3.724714, Test Loss : 3.818052, Train Acc : 3.125000, Test Acc : 8.220109
# Best Model Saved
# Iteration : 81 - Train Loss : 3.422814, Test Loss : 3.842430, Train Acc : 15.625000, Test Acc : 10.869565
# Best Model Saved
# Iteration : 86 - Train Loss : 3.677831, Test Loss : 3.778483, Train Acc : 18.750000, Test Acc : 8.355978
# Best Model Saved
# Iteration : 91 - Train Loss : 4.172794, Test Loss : 3.722416, Train Acc : 9.375000, Test Acc : 8.559783
# Best Model Saved
# Iteration : 96 - Train Loss : 3.617332, Test Loss : 3.582930, Train Acc : 12.500000, Test Acc : 11.956522
# Best Model Saved
# Iteration : 101 - Train Loss : 3.479676, Test Loss : 3.524657, Train Acc : 12.500000, Test Acc : 15.081522
# Best Model Saved
# Iteration : 106 - Train Loss : 3.644085, Test Loss : 3.441389, Train Acc : 12.500000, Test Acc : 15.625000
# Best Model Saved
# Iteration : 111 - Train Loss : 3.520525, Test Loss : 3.354376, Train Acc : 21.875000, Test Acc : 17.051630
# Best Model Saved
# Iteration : 116 - Train Loss : 3.714715, Test Loss : 3.344295, Train Acc : 18.750000, Test Acc : 18.750000
# Iteration : 121 - Train Loss : 3.451114, Test Loss : 3.388663, Train Acc : 15.625000, Test Acc : 15.149457
# Best Model Saved
# Iteration : 126 - Train Loss : 3.351506, Test Loss : 3.179550, Train Acc : 15.625000, Test Acc : 18.206522
# Best Model Saved
# Iteration : 131 - Train Loss : 3.681459, Test Loss : 3.007383, Train Acc : 9.375000, Test Acc : 21.195652
# Best Model Saved
# Iteration : 136 - Train Loss : 3.434485, Test Loss : 3.088636, Train Acc : 9.375000, Test Acc : 23.505435
#
# Epoch 3 Started...
# Iteration : 1 - Train Loss : 3.250708, Test Loss : 3.182240, Train Acc : 25.000000, Test Acc : 20.244565
# Best Model Saved
# Iteration : 6 - Train Loss : 3.234071, Test Loss : 3.150576, Train Acc : 25.000000, Test Acc : 23.709239
# Best Model Saved
# Iteration : 11 - Train Loss : 3.062483, Test Loss : 3.092468, Train Acc : 28.125000, Test Acc : 19.157609
# Best Model Saved
# Iteration : 16 - Train Loss : 3.668145, Test Loss : 3.134868, Train Acc : 6.250000, Test Acc : 20.108696
# Best Model Saved
# Iteration : 21 - Train Loss : 3.400942, Test Loss : 3.102285, Train Acc : 15.625000, Test Acc : 19.021739
# Best Model Saved
# Iteration : 26 - Train Loss : 2.994496, Test Loss : 2.907272, Train Acc : 15.625000, Test Acc : 24.456522
# Iteration : 31 - Train Loss : 3.329224, Test Loss : 2.972368, Train Acc : 21.875000, Test Acc : 20.991848
# Best Model Saved
# Iteration : 36 - Train Loss : 2.403636, Test Loss : 2.818961, Train Acc : 28.125000, Test Acc : 26.970109
# Iteration : 41 - Train Loss : 3.055090, Test Loss : 2.923351, Train Acc : 28.125000, Test Acc : 25.747283
# Iteration : 46 - Train Loss : 3.012306, Test Loss : 3.062818, Train Acc : 18.750000, Test Acc : 22.622283
# Iteration : 51 - Train Loss : 3.158113, Test Loss : 2.952960, Train Acc : 18.750000, Test Acc : 24.660326
# Best Model Saved
# Iteration : 56 - Train Loss : 3.122629, Test Loss : 2.766874, Train Acc : 15.625000, Test Acc : 28.057065
# Best Model Saved
# Iteration : 61 - Train Loss : 2.704076, Test Loss : 2.609217, Train Acc : 21.875000, Test Acc : 28.600543
# Best Model Saved
# Iteration : 66 - Train Loss : 2.042678, Test Loss : 2.446068, Train Acc : 37.500000, Test Acc : 32.065217
# Iteration : 71 - Train Loss : 2.465676, Test Loss : 2.576159, Train Acc : 31.250000, Test Acc : 31.317935
# Iteration : 76 - Train Loss : 2.322650, Test Loss : 2.624621, Train Acc : 40.625000, Test Acc : 29.211957
# Best Model Saved
# Iteration : 81 - Train Loss : 2.509214, Test Loss : 2.464114, Train Acc : 34.375000, Test Acc : 34.850543
# Iteration : 86 - Train Loss : 2.841377, Test Loss : 2.497475, Train Acc : 31.250000, Test Acc : 34.646739
# Iteration : 91 - Train Loss : 2.312845, Test Loss : 2.551950, Train Acc : 43.750000, Test Acc : 31.521739
# Best Model Saved
# Iteration : 96 - Train Loss : 2.974443, Test Loss : 2.281705, Train Acc : 12.500000, Test Acc : 35.529891
# Best Model Saved
# Iteration : 101 - Train Loss : 2.530548, Test Loss : 2.089303, Train Acc : 21.875000, Test Acc : 39.198370
# Best Model Saved
# Iteration : 106 - Train Loss : 2.394695, Test Loss : 2.119261, Train Acc : 37.500000, Test Acc : 40.760870
# Iteration : 111 - Train Loss : 2.253078, Test Loss : 2.124187, Train Acc : 37.500000, Test Acc : 40.421196
# Iteration : 116 - Train Loss : 2.146823, Test Loss : 2.274763, Train Acc : 43.750000, Test Acc : 35.529891
# Iteration : 121 - Train Loss : 3.005320, Test Loss : 2.236778, Train Acc : 15.625000, Test Acc : 39.334239
# Best Model Saved
# Iteration : 126 - Train Loss : 1.758215, Test Loss : 2.071513, Train Acc : 56.250000, Test Acc : 42.391304
# Best Model Saved
# Iteration : 131 - Train Loss : 2.040035, Test Loss : 2.095401, Train Acc : 40.625000, Test Acc : 45.991848
# Iteration : 136 - Train Loss : 2.069672, Test Loss : 2.158880, Train Acc : 37.500000, Test Acc : 38.179348
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 2.406468, Test Loss : 2.196611, Train Acc : 28.125000, Test Acc : 39.538043
# Iteration : 6 - Train Loss : 2.486825, Test Loss : 2.124697, Train Acc : 18.750000, Test Acc : 35.394022
# Best Model Saved
# Iteration : 11 - Train Loss : 2.044733, Test Loss : 1.883562, Train Acc : 50.000000, Test Acc : 46.535326
# Best Model Saved
# Iteration : 16 - Train Loss : 1.692372, Test Loss : 1.831083, Train Acc : 43.750000, Test Acc : 45.244565
# Best Model Saved
# Iteration : 21 - Train Loss : 1.698030, Test Loss : 1.795980, Train Acc : 50.000000, Test Acc : 46.467391
# Iteration : 26 - Train Loss : 1.810692, Test Loss : 1.870096, Train Acc : 40.625000, Test Acc : 45.923913
# Iteration : 31 - Train Loss : 1.956626, Test Loss : 1.988727, Train Acc : 46.875000, Test Acc : 42.459239
# Best Model Saved
# Iteration : 36 - Train Loss : 1.771210, Test Loss : 1.758234, Train Acc : 53.125000, Test Acc : 50.883152
# Best Model Saved
# Iteration : 41 - Train Loss : 1.921422, Test Loss : 1.619312, Train Acc : 50.000000, Test Acc : 54.279891
# Iteration : 46 - Train Loss : 1.836867, Test Loss : 1.693961, Train Acc : 46.875000, Test Acc : 49.388587
# Best Model Saved
# Iteration : 51 - Train Loss : 1.509517, Test Loss : 1.578703, Train Acc : 53.125000, Test Acc : 52.038043
# Iteration : 56 - Train Loss : 1.576639, Test Loss : 1.600881, Train Acc : 46.875000, Test Acc : 51.019022
# Best Model Saved
# Iteration : 61 - Train Loss : 1.877722, Test Loss : 1.529063, Train Acc : 34.375000, Test Acc : 55.366848
# Best Model Saved
# Iteration : 66 - Train Loss : 1.835152, Test Loss : 1.542466, Train Acc : 46.875000, Test Acc : 57.269022
# Best Model Saved
# Iteration : 71 - Train Loss : 1.785367, Test Loss : 1.432911, Train Acc : 59.375000, Test Acc : 58.355978
# Best Model Saved
# Iteration : 76 - Train Loss : 1.785715, Test Loss : 1.380256, Train Acc : 40.625000, Test Acc : 58.967391
# Iteration : 81 - Train Loss : 1.227945, Test Loss : 1.441639, Train Acc : 62.500000, Test Acc : 56.385870
# Iteration : 86 - Train Loss : 1.253376, Test Loss : 1.411932, Train Acc : 62.500000, Test Acc : 58.695652
# Best Model Saved
# Iteration : 91 - Train Loss : 1.174129, Test Loss : 1.306806, Train Acc : 62.500000, Test Acc : 61.888587
# Best Model Saved
# Iteration : 96 - Train Loss : 1.631050, Test Loss : 1.222663, Train Acc : 59.375000, Test Acc : 64.130435
# Best Model Saved
# Iteration : 101 - Train Loss : 1.149733, Test Loss : 1.215616, Train Acc : 53.125000, Test Acc : 62.907609
# Best Model Saved
# Iteration : 106 - Train Loss : 1.181441, Test Loss : 1.130136, Train Acc : 59.375000, Test Acc : 65.149457
# Best Model Saved
# Iteration : 111 - Train Loss : 1.458048, Test Loss : 1.121469, Train Acc : 53.125000, Test Acc : 64.130435
# Best Model Saved
# Iteration : 116 - Train Loss : 1.392733, Test Loss : 1.006278, Train Acc : 56.250000, Test Acc : 67.798913
# Iteration : 121 - Train Loss : 1.219781, Test Loss : 1.399389, Train Acc : 65.625000, Test Acc : 58.084239
# Iteration : 126 - Train Loss : 1.093238, Test Loss : 1.138941, Train Acc : 59.375000, Test Acc : 65.149457
# Iteration : 131 - Train Loss : 1.133799, Test Loss : 1.194397, Train Acc : 71.875000, Test Acc : 63.451087
# Best Model Saved
# Iteration : 136 - Train Loss : 1.239896, Test Loss : 1.013294, Train Acc : 65.625000, Test Acc : 68.410326
#
# Epoch 5 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 1.400501, Test Loss : 0.981844, Train Acc : 59.375000, Test Acc : 69.633152
# Iteration : 6 - Train Loss : 1.239530, Test Loss : 1.050537, Train Acc : 65.625000, Test Acc : 68.682065
# Iteration : 11 - Train Loss : 1.037523, Test Loss : 1.062030, Train Acc : 75.000000, Test Acc : 68.070652
# Iteration : 16 - Train Loss : 0.871644, Test Loss : 1.126479, Train Acc : 71.875000, Test Acc : 66.236413
# Iteration : 21 - Train Loss : 1.487656, Test Loss : 1.040193, Train Acc : 59.375000, Test Acc : 68.138587
# Best Model Saved
# Iteration : 26 - Train Loss : 0.926116, Test Loss : 0.845724, Train Acc : 71.875000, Test Acc : 74.252717
# Iteration : 31 - Train Loss : 0.645579, Test Loss : 0.884256, Train Acc : 84.375000, Test Acc : 72.758152
# Iteration : 36 - Train Loss : 1.154148, Test Loss : 0.898468, Train Acc : 62.500000, Test Acc : 71.331522
# Iteration : 41 - Train Loss : 0.823888, Test Loss : 0.878926, Train Acc : 78.125000, Test Acc : 73.913043
# Iteration : 46 - Train Loss : 0.630140, Test Loss : 1.002745, Train Acc : 84.375000, Test Acc : 70.923913
# Iteration : 51 - Train Loss : 1.102168, Test Loss : 1.037313, Train Acc : 62.500000, Test Acc : 67.798913
# Iteration : 56 - Train Loss : 1.220051, Test Loss : 0.894317, Train Acc : 65.625000, Test Acc : 71.671196
# Iteration : 61 - Train Loss : 1.237900, Test Loss : 0.948447, Train Acc : 62.500000, Test Acc : 72.010870
# Best Model Saved
# Iteration : 66 - Train Loss : 0.889157, Test Loss : 0.806834, Train Acc : 71.875000, Test Acc : 75.815217
# Iteration : 71 - Train Loss : 0.700758, Test Loss : 0.886775, Train Acc : 81.250000, Test Acc : 71.535326
# Iteration : 76 - Train Loss : 0.851824, Test Loss : 0.916022, Train Acc : 75.000000, Test Acc : 72.554348
# Iteration : 81 - Train Loss : 1.285975, Test Loss : 0.812616, Train Acc : 62.500000, Test Acc : 73.709239
# Best Model Saved
# Iteration : 86 - Train Loss : 0.953951, Test Loss : 0.752280, Train Acc : 71.875000, Test Acc : 76.358696
# Best Model Saved
# Iteration : 91 - Train Loss : 0.985786, Test Loss : 0.689005, Train Acc : 68.750000, Test Acc : 76.630435
# Best Model Saved
# Iteration : 96 - Train Loss : 0.733670, Test Loss : 0.699310, Train Acc : 78.125000, Test Acc : 78.057065
# Best Model Saved
# Iteration : 101 - Train Loss : 0.746216, Test Loss : 0.634112, Train Acc : 78.125000, Test Acc : 80.570652
# Iteration : 106 - Train Loss : 0.752796, Test Loss : 0.687670, Train Acc : 78.125000, Test Acc : 79.619565
# Iteration : 111 - Train Loss : 0.897044, Test Loss : 0.672633, Train Acc : 78.125000, Test Acc : 77.513587
# Iteration : 116 - Train Loss : 0.748001, Test Loss : 0.722434, Train Acc : 78.125000, Test Acc : 76.562500
# Iteration : 121 - Train Loss : 0.652393, Test Loss : 0.680151, Train Acc : 84.375000, Test Acc : 78.532609
# Best Model Saved
# Iteration : 126 - Train Loss : 0.637286, Test Loss : 0.634142, Train Acc : 71.875000, Test Acc : 80.910326
# Iteration : 131 - Train Loss : 0.538069, Test Loss : 0.716212, Train Acc : 84.375000, Test Acc : 78.192935
# Iteration : 136 - Train Loss : 1.048965, Test Loss : 0.840940, Train Acc : 65.625000, Test Acc : 73.980978

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='squeezenet1_1', num_classes=157)
model.model.load_state_dict(torch.load('./4_125.pt'))
model.model.eval()
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (6): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (9): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 157, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./squeezenet1_1_ImageNetStat_4_125_threshno.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    2.076513e-01  1.810155e-01  ...  1.343978e-05  1.127088e-06
# 1    3.039020e-03  5.990278e-05  ...  4.024293e-06  1.195255e-08
# 2    9.272111e-05  8.189913e-02  ...  4.431075e-06  8.602250e-09
# 3    1.044657e-05  3.019336e-02  ...  3.735633e-06  2.210563e-09
# 4    3.129131e-07  4.456594e-03  ...  3.719116e-07  4.101404e-10
# ..            ...           ...  ...           ...           ...
# 212  4.428468e-10  3.594072e-10  ...  3.564707e-08  1.643076e-05
# 213  1.592261e-08  1.714468e-07  ...  3.848308e-05  5.619671e-07
# 214  8.543034e-09  1.354471e-08  ...  9.684367e-01  7.906725e-07
# 215  4.412408e-08  2.652275e-07  ...  9.521498e-01  4.932985e-07
# 216  1.547268e-09  5.190701e-10  ...  2.362532e-09  3.830514e-01
#
# [217 rows x 157 columns]
