# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/vgg16%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 03:09:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='vgg16', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
len(train_dataset.label_info)
# Out:
# 157

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.082029, Test Loss : 5.092179, Train Acc : 0.000000, Test Acc : 7.472826
# Best Model Saved
# Iteration : 6 - Train Loss : 4.912651, Test Loss : 4.917810, Train Acc : 3.125000, Test Acc : 4.076087
# Best Model Saved
# Iteration : 11 - Train Loss : 4.769143, Test Loss : 4.651772, Train Acc : 0.000000, Test Acc : 3.804348
# Best Model Saved
# Iteration : 16 - Train Loss : 4.670034, Test Loss : 4.548372, Train Acc : 0.000000, Test Acc : 6.182065
# Best Model Saved
# Iteration : 21 - Train Loss : 4.471207, Test Loss : 4.032630, Train Acc : 12.500000, Test Acc : 7.744565
# Best Model Saved
# Iteration : 26 - Train Loss : 3.937797, Test Loss : 3.729564, Train Acc : 12.500000, Test Acc : 8.831522
# Best Model Saved
# Iteration : 31 - Train Loss : 3.414273, Test Loss : 3.712384, Train Acc : 18.750000, Test Acc : 13.043478
# Best Model Saved
# Iteration : 36 - Train Loss : 3.675832, Test Loss : 3.330672, Train Acc : 15.625000, Test Acc : 16.779891
# Best Model Saved
# Iteration : 41 - Train Loss : 3.840005, Test Loss : 3.234916, Train Acc : 3.125000, Test Acc : 17.730978
# Best Model Saved
# Iteration : 46 - Train Loss : 3.431772, Test Loss : 2.962468, Train Acc : 12.500000, Test Acc : 20.652174
# Best Model Saved
# Iteration : 51 - Train Loss : 2.640387, Test Loss : 2.886182, Train Acc : 31.250000, Test Acc : 23.233696
# Best Model Saved
# Iteration : 56 - Train Loss : 2.969615, Test Loss : 2.606377, Train Acc : 25.000000, Test Acc : 26.834239
# Best Model Saved
# Iteration : 61 - Train Loss : 2.777788, Test Loss : 2.452521, Train Acc : 21.875000, Test Acc : 30.502717
# Best Model Saved
# Iteration : 66 - Train Loss : 2.779732, Test Loss : 2.365571, Train Acc : 18.750000, Test Acc : 31.657609
# Best Model Saved
# Iteration : 71 - Train Loss : 2.911429, Test Loss : 2.157596, Train Acc : 21.875000, Test Acc : 36.820652
# Iteration : 76 - Train Loss : 2.579081, Test Loss : 2.227555, Train Acc : 12.500000, Test Acc : 34.578804
# Best Model Saved
# Iteration : 81 - Train Loss : 2.329728, Test Loss : 2.024177, Train Acc : 25.000000, Test Acc : 39.266304
# Best Model Saved
# Iteration : 86 - Train Loss : 2.153701, Test Loss : 1.968708, Train Acc : 46.875000, Test Acc : 40.013587
# Best Model Saved
# Iteration : 91 - Train Loss : 2.009171, Test Loss : 1.831286, Train Acc : 28.125000, Test Acc : 44.836957
# Best Model Saved
# Iteration : 96 - Train Loss : 2.302353, Test Loss : 1.737069, Train Acc : 40.625000, Test Acc : 45.176630
# Best Model Saved
# Iteration : 101 - Train Loss : 1.756347, Test Loss : 1.721340, Train Acc : 43.750000, Test Acc : 45.448370
# Best Model Saved
# Iteration : 106 - Train Loss : 2.193508, Test Loss : 1.704138, Train Acc : 43.750000, Test Acc : 45.516304
# Best Model Saved
# Iteration : 111 - Train Loss : 1.433963, Test Loss : 1.442681, Train Acc : 53.125000, Test Acc : 51.358696
# Best Model Saved
# Iteration : 116 - Train Loss : 1.723507, Test Loss : 1.356714, Train Acc : 37.500000, Test Acc : 57.269022
# Iteration : 121 - Train Loss : 1.875693, Test Loss : 1.397629, Train Acc : 40.625000, Test Acc : 56.385870
# Best Model Saved
# Iteration : 126 - Train Loss : 1.469685, Test Loss : 1.337857, Train Acc : 50.000000, Test Acc : 54.959239
# Best Model Saved
# Iteration : 131 - Train Loss : 1.320774, Test Loss : 1.306947, Train Acc : 59.375000, Test Acc : 56.997283
# Best Model Saved
# Iteration : 136 - Train Loss : 2.191089, Test Loss : 1.248739, Train Acc : 31.250000, Test Acc : 61.820652
#
# Epoch 2 Started...
# Iteration : 1 - Train Loss : 1.124208, Test Loss : 1.286569, Train Acc : 68.750000, Test Acc : 60.733696
# Best Model Saved
# Iteration : 6 - Train Loss : 1.073039, Test Loss : 1.132362, Train Acc : 62.500000, Test Acc : 63.247283
# Best Model Saved
# Iteration : 11 - Train Loss : 1.184451, Test Loss : 1.016583, Train Acc : 46.875000, Test Acc : 66.032609
# Best Model Saved
# Iteration : 16 - Train Loss : 0.961409, Test Loss : 1.077976, Train Acc : 75.000000, Test Acc : 68.546196
# Best Model Saved
# Iteration : 21 - Train Loss : 1.056233, Test Loss : 1.043423, Train Acc : 59.375000, Test Acc : 67.459239
# Best Model Saved
# Iteration : 26 - Train Loss : 1.042024, Test Loss : 1.007131, Train Acc : 65.625000, Test Acc : 68.546196
# Best Model Saved
# Iteration : 31 - Train Loss : 1.072557, Test Loss : 0.991797, Train Acc : 71.875000, Test Acc : 68.682065
# Best Model Saved
# Iteration : 36 - Train Loss : 1.081266, Test Loss : 0.933961, Train Acc : 65.625000, Test Acc : 71.399457
# Iteration : 41 - Train Loss : 1.387019, Test Loss : 1.078515, Train Acc : 65.625000, Test Acc : 69.157609
# Iteration : 46 - Train Loss : 1.564663, Test Loss : 1.017555, Train Acc : 62.500000, Test Acc : 65.760870
# Best Model Saved
# Iteration : 51 - Train Loss : 1.121400, Test Loss : 0.750012, Train Acc : 59.375000, Test Acc : 75.815217
# Iteration : 56 - Train Loss : 1.202873, Test Loss : 0.771725, Train Acc : 56.250000, Test Acc : 74.660326
# Best Model Saved
# Iteration : 61 - Train Loss : 0.559779, Test Loss : 0.577753, Train Acc : 81.250000, Test Acc : 80.163043
# Best Model Saved
# Iteration : 66 - Train Loss : 0.908598, Test Loss : 0.489579, Train Acc : 65.625000, Test Acc : 83.491848
# Iteration : 71 - Train Loss : 0.696300, Test Loss : 0.528649, Train Acc : 78.125000, Test Acc : 83.152174
# Iteration : 76 - Train Loss : 0.797218, Test Loss : 0.570349, Train Acc : 71.875000, Test Acc : 81.182065
# Best Model Saved
# Iteration : 81 - Train Loss : 0.755655, Test Loss : 0.470042, Train Acc : 81.250000, Test Acc : 84.510870
# Iteration : 86 - Train Loss : 0.893275, Test Loss : 0.522990, Train Acc : 78.125000, Test Acc : 83.152174
# Iteration : 91 - Train Loss : 0.504118, Test Loss : 0.578545, Train Acc : 84.375000, Test Acc : 82.404891
# Iteration : 96 - Train Loss : 0.626832, Test Loss : 0.537531, Train Acc : 75.000000, Test Acc : 82.133152
# Best Model Saved
# Iteration : 101 - Train Loss : 0.627845, Test Loss : 0.439450, Train Acc : 75.000000, Test Acc : 85.461957
# Best Model Saved
# Iteration : 106 - Train Loss : 0.742738, Test Loss : 0.382477, Train Acc : 78.125000, Test Acc : 86.752717
# Best Model Saved
# Iteration : 111 - Train Loss : 0.260389, Test Loss : 0.384437, Train Acc : 93.750000, Test Acc : 88.111413
# Iteration : 116 - Train Loss : 0.954883, Test Loss : 0.484318, Train Acc : 71.875000, Test Acc : 84.375000
# Iteration : 121 - Train Loss : 0.654843, Test Loss : 0.397703, Train Acc : 78.125000, Test Acc : 86.752717
# Best Model Saved
# Iteration : 126 - Train Loss : 0.281879, Test Loss : 0.353302, Train Acc : 90.625000, Test Acc : 87.839674
# Iteration : 131 - Train Loss : 0.584523, Test Loss : 0.366389, Train Acc : 81.250000, Test Acc : 87.567935
# Iteration : 136 - Train Loss : 0.406107, Test Loss : 0.366488, Train Acc : 87.500000, Test Acc : 86.277174
#
# Epoch 3 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.302379, Test Loss : 0.321086, Train Acc : 87.500000, Test Acc : 88.586957
# Iteration : 6 - Train Loss : 0.351503, Test Loss : 0.347581, Train Acc : 90.625000, Test Acc : 88.451087
# Iteration : 11 - Train Loss : 0.391764, Test Loss : 0.327579, Train Acc : 87.500000, Test Acc : 88.247283
# Best Model Saved
# Iteration : 16 - Train Loss : 0.617348, Test Loss : 0.335883, Train Acc : 78.125000, Test Acc : 88.858696
# Best Model Saved
# Iteration : 21 - Train Loss : 0.355773, Test Loss : 0.321297, Train Acc : 84.375000, Test Acc : 89.130435
# Best Model Saved
# Iteration : 26 - Train Loss : 0.452801, Test Loss : 0.274594, Train Acc : 87.500000, Test Acc : 90.896739
# Iteration : 31 - Train Loss : 0.266381, Test Loss : 0.309589, Train Acc : 87.500000, Test Acc : 89.538043
# Best Model Saved
# Iteration : 36 - Train Loss : 0.270912, Test Loss : 0.241983, Train Acc : 93.750000, Test Acc : 92.119565
# Best Model Saved
# Iteration : 41 - Train Loss : 0.431143, Test Loss : 0.226959, Train Acc : 90.625000, Test Acc : 93.342391
# Iteration : 46 - Train Loss : 0.457798, Test Loss : 0.277519, Train Acc : 84.375000, Test Acc : 91.236413
# Iteration : 51 - Train Loss : 0.434220, Test Loss : 0.361513, Train Acc : 87.500000, Test Acc : 88.858696
# Iteration : 56 - Train Loss : 0.451764, Test Loss : 0.322983, Train Acc : 84.375000, Test Acc : 89.741848
# Iteration : 61 - Train Loss : 0.175835, Test Loss : 0.259107, Train Acc : 93.750000, Test Acc : 92.187500
# Iteration : 66 - Train Loss : 0.622693, Test Loss : 0.246715, Train Acc : 81.250000, Test Acc : 92.595109
# Iteration : 71 - Train Loss : 0.399213, Test Loss : 0.258663, Train Acc : 84.375000, Test Acc : 92.663043
# Iteration : 76 - Train Loss : 0.301502, Test Loss : 0.249849, Train Acc : 87.500000, Test Acc : 92.459239
# Iteration : 81 - Train Loss : 0.214477, Test Loss : 0.227143, Train Acc : 93.750000, Test Acc : 92.527174
# Best Model Saved
# Iteration : 86 - Train Loss : 0.134056, Test Loss : 0.227952, Train Acc : 96.875000, Test Acc : 93.478261
# Best Model Saved
# Iteration : 91 - Train Loss : 0.475486, Test Loss : 0.221577, Train Acc : 93.750000, Test Acc : 92.798913
# Iteration : 96 - Train Loss : 0.207082, Test Loss : 0.295518, Train Acc : 93.750000, Test Acc : 90.625000
# Best Model Saved
# Iteration : 101 - Train Loss : 0.098147, Test Loss : 0.216736, Train Acc : 100.000000, Test Acc : 93.342391
# Best Model Saved
# Iteration : 106 - Train Loss : 0.151542, Test Loss : 0.205013, Train Acc : 90.625000, Test Acc : 93.817935
# Best Model Saved
# Iteration : 111 - Train Loss : 0.580289, Test Loss : 0.169061, Train Acc : 90.625000, Test Acc : 94.157609
# Best Model Saved
# Iteration : 116 - Train Loss : 0.474810, Test Loss : 0.147063, Train Acc : 87.500000, Test Acc : 94.565217
# Best Model Saved
# Iteration : 121 - Train Loss : 0.211923, Test Loss : 0.159190, Train Acc : 93.750000, Test Acc : 94.972826
# Iteration : 126 - Train Loss : 0.266902, Test Loss : 0.169271, Train Acc : 93.750000, Test Acc : 94.565217
# Best Model Saved
# Iteration : 131 - Train Loss : 0.427873, Test Loss : 0.155013, Train Acc : 87.500000, Test Acc : 94.836957
# Iteration : 136 - Train Loss : 0.326966, Test Loss : 0.190024, Train Acc : 84.375000, Test Acc : 93.614130
#
# Epoch 4 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.341182, Test Loss : 0.108187, Train Acc : 93.750000, Test Acc : 95.991848
# Iteration : 6 - Train Loss : 0.220357, Test Loss : 0.137367, Train Acc : 93.750000, Test Acc : 95.516304
# Iteration : 11 - Train Loss : 0.315309, Test Loss : 0.178323, Train Acc : 84.375000, Test Acc : 93.070652
# Iteration : 16 - Train Loss : 0.325149, Test Loss : 0.263986, Train Acc : 84.375000, Test Acc : 91.915761
# Iteration : 21 - Train Loss : 0.331000, Test Loss : 0.177559, Train Acc : 96.875000, Test Acc : 94.157609
# Iteration : 26 - Train Loss : 0.159802, Test Loss : 0.165735, Train Acc : 93.750000, Test Acc : 95.244565
# Iteration : 31 - Train Loss : 0.109411, Test Loss : 0.196551, Train Acc : 93.750000, Test Acc : 94.361413
# Iteration : 36 - Train Loss : 0.078600, Test Loss : 0.196799, Train Acc : 96.875000, Test Acc : 93.953804
# Iteration : 41 - Train Loss : 0.116015, Test Loss : 0.174791, Train Acc : 96.875000, Test Acc : 94.769022
# Iteration : 46 - Train Loss : 0.298877, Test Loss : 0.184150, Train Acc : 90.625000, Test Acc : 94.293478
# Iteration : 51 - Train Loss : 0.113069, Test Loss : 0.137772, Train Acc : 96.875000, Test Acc : 95.176630
# Iteration : 56 - Train Loss : 0.245485, Test Loss : 0.169083, Train Acc : 87.500000, Test Acc : 94.021739
# Iteration : 61 - Train Loss : 0.076362, Test Loss : 0.186575, Train Acc : 96.875000, Test Acc : 94.633152
# Iteration : 66 - Train Loss : 0.283471, Test Loss : 0.169443, Train Acc : 90.625000, Test Acc : 95.176630
# Iteration : 71 - Train Loss : 0.204013, Test Loss : 0.148641, Train Acc : 90.625000, Test Acc : 95.176630
# Best Model Saved
# Iteration : 76 - Train Loss : 0.100297, Test Loss : 0.099947, Train Acc : 100.000000, Test Acc : 96.807065
# Best Model Saved
# Iteration : 81 - Train Loss : 0.158798, Test Loss : 0.091849, Train Acc : 96.875000, Test Acc : 97.146739
# Best Model Saved
# Iteration : 86 - Train Loss : 0.156382, Test Loss : 0.090031, Train Acc : 93.750000, Test Acc : 97.350543
# Iteration : 91 - Train Loss : 0.079653, Test Loss : 0.090864, Train Acc : 96.875000, Test Acc : 97.350543
# Best Model Saved
# Iteration : 96 - Train Loss : 0.090882, Test Loss : 0.050412, Train Acc : 100.000000, Test Acc : 98.641304
# Iteration : 101 - Train Loss : 0.203934, Test Loss : 0.124626, Train Acc : 93.750000, Test Acc : 96.127717
# Iteration : 106 - Train Loss : 0.174522, Test Loss : 0.111454, Train Acc : 96.875000, Test Acc : 96.671196
# Iteration : 111 - Train Loss : 0.190347, Test Loss : 0.074175, Train Acc : 90.625000, Test Acc : 97.146739
# Iteration : 116 - Train Loss : 0.184592, Test Loss : 0.128226, Train Acc : 93.750000, Test Acc : 96.059783
# Iteration : 121 - Train Loss : 0.169318, Test Loss : 0.148013, Train Acc : 96.875000, Test Acc : 95.448370
# Iteration : 126 - Train Loss : 0.143568, Test Loss : 0.090606, Train Acc : 93.750000, Test Acc : 97.214674
# Iteration : 131 - Train Loss : 0.123813, Test Loss : 0.073706, Train Acc : 93.750000, Test Acc : 98.029891
# Iteration : 136 - Train Loss : 0.093495, Test Loss : 0.091194, Train Acc : 93.750000, Test Acc : 96.671196
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.045503, Test Loss : 0.107484, Train Acc : 100.000000, Test Acc : 96.467391
# Iteration : 6 - Train Loss : 0.504273, Test Loss : 0.101841, Train Acc : 90.625000, Test Acc : 96.739130
# Iteration : 11 - Train Loss : 0.108075, Test Loss : 0.087906, Train Acc : 96.875000, Test Acc : 97.350543
# Iteration : 16 - Train Loss : 0.096100, Test Loss : 0.088513, Train Acc : 96.875000, Test Acc : 97.894022
# Iteration : 21 - Train Loss : 0.076006, Test Loss : 0.076329, Train Acc : 96.875000, Test Acc : 97.826087
# Iteration : 26 - Train Loss : 0.436966, Test Loss : 0.063738, Train Acc : 87.500000, Test Acc : 98.165761
# Best Model Saved
# Iteration : 31 - Train Loss : 0.032167, Test Loss : 0.050349, Train Acc : 100.000000, Test Acc : 98.369565
# Best Model Saved
# Iteration : 36 - Train Loss : 0.067256, Test Loss : 0.037363, Train Acc : 100.000000, Test Acc : 99.116848
# Iteration : 41 - Train Loss : 0.006499, Test Loss : 0.050163, Train Acc : 100.000000, Test Acc : 98.505435
# Iteration : 46 - Train Loss : 0.304383, Test Loss : 0.068159, Train Acc : 90.625000, Test Acc : 98.029891
# Iteration : 51 - Train Loss : 0.090856, Test Loss : 0.056811, Train Acc : 93.750000, Test Acc : 98.029891
# Iteration : 56 - Train Loss : 0.130103, Test Loss : 0.069300, Train Acc : 93.750000, Test Acc : 97.961957
# Iteration : 61 - Train Loss : 0.346109, Test Loss : 0.061010, Train Acc : 90.625000, Test Acc : 97.758152
# Iteration : 66 - Train Loss : 0.049706, Test Loss : 0.121787, Train Acc : 96.875000, Test Acc : 96.671196
# Iteration : 71 - Train Loss : 0.281424, Test Loss : 0.097271, Train Acc : 93.750000, Test Acc : 97.690217
# Iteration : 76 - Train Loss : 0.029730, Test Loss : 0.070603, Train Acc : 100.000000, Test Acc : 97.418478
# Iteration : 81 - Train Loss : 0.352870, Test Loss : 0.057083, Train Acc : 90.625000, Test Acc : 98.029891
# Iteration : 86 - Train Loss : 0.100365, Test Loss : 0.054216, Train Acc : 96.875000, Test Acc : 97.961957
# Iteration : 91 - Train Loss : 0.108994, Test Loss : 0.076460, Train Acc : 96.875000, Test Acc : 97.758152
# Iteration : 96 - Train Loss : 0.363304, Test Loss : 0.063875, Train Acc : 90.625000, Test Acc : 97.486413
# Iteration : 101 - Train Loss : 0.019711, Test Loss : 0.062375, Train Acc : 100.000000, Test Acc : 98.845109
# Iteration : 106 - Train Loss : 0.048275, Test Loss : 0.063469, Train Acc : 96.875000, Test Acc : 98.437500
# Iteration : 111 - Train Loss : 0.143996, Test Loss : 0.067617, Train Acc : 93.750000, Test Acc : 98.641304
# Iteration : 116 - Train Loss : 0.147232, Test Loss : 0.098326, Train Acc : 96.875000, Test Acc : 97.622283
# Iteration : 121 - Train Loss : 0.046702, Test Loss : 0.103075, Train Acc : 100.000000, Test Acc : 97.486413
# Iteration : 126 - Train Loss : 0.213254, Test Loss : 0.103439, Train Acc : 93.750000, Test Acc : 96.671196
# Iteration : 131 - Train Loss : 0.159837, Test Loss : 0.085530, Train Acc : 93.750000, Test Acc : 97.486413
# Iteration : 136 - Train Loss : 0.082852, Test Loss : 0.098879, Train Acc : 96.875000, Test Acc : 97.010870

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='vgg16', num_classes=157)
model.model.load_state_dict(torch.load('./4_35.pt'))
model.model.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Linear(in_features=25088, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./vgg16_ImageNetStat_4_35_threshno.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    9.822558e-03  7.745684e-01  ...  5.258306e-12  5.064011e-13
# 1    2.292953e-06  2.897417e-07  ...  5.130524e-15  3.413377e-16
# 2    4.261138e-11  4.048171e-07  ...  4.984391e-12  8.994958e-14
# 3    2.293829e-09  1.506015e-05  ...  1.708856e-11  3.705169e-14
# 4    1.117411e-13  3.029602e-06  ...  2.435836e-13  2.378863e-14
# ..            ...           ...  ...           ...           ...
# 212  8.100681e-17  1.965848e-16  ...  6.132172e-13  1.970423e-07
# 213  2.575982e-16  1.563940e-17  ...  1.989317e-07  8.536145e-10
# 214  2.835942e-21  1.204073e-13  ...  9.998835e-01  5.083938e-12
# 215  5.381427e-15  1.082007e-10  ...  9.901606e-01  3.856891e-10
# 216  2.902116e-13  3.423413e-13  ...  4.903351e-14  9.897429e-01
#
# [217 rows x 157 columns]
