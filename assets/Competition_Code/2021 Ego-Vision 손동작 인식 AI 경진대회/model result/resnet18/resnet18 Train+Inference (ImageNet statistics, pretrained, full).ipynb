# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Oct  6 01:21:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    30W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir open_data
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
# !cp /content/drive/MyDrive/pytorch_python/dataset.py .
# !cp /content/drive/MyDrive/pytorch_python/specific_augmentation.py .
# !cp /content/drive/MyDrive/pytorch_python/specific_dataset.py .
# !cp /content/drive/MyDrive/pytorch_python/specific_train.py .
# !cp /content/drive/MyDrive/pytorch_python/train.py .

# %%
from dataset import *
from train import *

import matplotlib.pyplot as plt

import torch, torchvision
import torchvision.transforms as transforms

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
batch_size = 32


train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])


train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='resnet18', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.331439, Test Loss : 5.100182, Train Acc : 0.000000, Test Acc : 4.008152
# Best Model Saved
# Iteration : 6 - Train Loss : 4.383166, Test Loss : 4.887671, Train Acc : 18.750000, Test Acc : 9.510870
# Best Model Saved
# Iteration : 11 - Train Loss : 4.655477, Test Loss : 4.555688, Train Acc : 9.375000, Test Acc : 13.043478
# Best Model Saved
# Iteration : 16 - Train Loss : 4.032270, Test Loss : 4.111346, Train Acc : 28.125000, Test Acc : 17.595109
# Best Model Saved
# Iteration : 21 - Train Loss : 3.794269, Test Loss : 3.936154, Train Acc : 12.500000, Test Acc : 21.059783
# Best Model Saved
# Iteration : 26 - Train Loss : 3.509107, Test Loss : 3.348192, Train Acc : 28.125000, Test Acc : 29.008152
# Best Model Saved
# Iteration : 31 - Train Loss : 3.088334, Test Loss : 3.114473, Train Acc : 37.500000, Test Acc : 37.500000
# Best Model Saved
# Iteration : 36 - Train Loss : 2.920362, Test Loss : 2.802448, Train Acc : 43.750000, Test Acc : 40.081522
# Best Model Saved
# Iteration : 41 - Train Loss : 2.710353, Test Loss : 2.502194, Train Acc : 40.625000, Test Acc : 47.010870
# Best Model Saved
# Iteration : 46 - Train Loss : 2.116813, Test Loss : 2.276010, Train Acc : 68.750000, Test Acc : 52.377717
# Best Model Saved
# Iteration : 51 - Train Loss : 2.698927, Test Loss : 2.025941, Train Acc : 34.375000, Test Acc : 52.649457
# Best Model Saved
# Iteration : 56 - Train Loss : 2.045572, Test Loss : 1.825611, Train Acc : 62.500000, Test Acc : 59.239130
# Best Model Saved
# Iteration : 61 - Train Loss : 1.557806, Test Loss : 1.555577, Train Acc : 75.000000, Test Acc : 66.711957
# Best Model Saved
# Iteration : 66 - Train Loss : 1.624096, Test Loss : 1.438701, Train Acc : 68.750000, Test Acc : 66.711957
# Best Model Saved
# Iteration : 71 - Train Loss : 1.541344, Test Loss : 1.316016, Train Acc : 68.750000, Test Acc : 70.923913
# Best Model Saved
# Iteration : 76 - Train Loss : 1.359102, Test Loss : 1.242668, Train Acc : 75.000000, Test Acc : 74.932065
# Best Model Saved
# Iteration : 81 - Train Loss : 1.459007, Test Loss : 1.340035, Train Acc : 71.875000, Test Acc : 77.173913
# Best Model Saved
# Iteration : 86 - Train Loss : 1.185396, Test Loss : 1.229837, Train Acc : 78.125000, Test Acc : 76.834239
# Best Model Saved
# Iteration : 91 - Train Loss : 1.029614, Test Loss : 1.028230, Train Acc : 78.125000, Test Acc : 81.250000
# Best Model Saved
# Iteration : 96 - Train Loss : 1.183163, Test Loss : 0.967712, Train Acc : 78.125000, Test Acc : 80.978261
# Best Model Saved
# Iteration : 101 - Train Loss : 0.928014, Test Loss : 0.845874, Train Acc : 81.250000, Test Acc : 82.540761
# Iteration : 106 - Train Loss : 0.917283, Test Loss : 1.070297, Train Acc : 81.250000, Test Acc : 79.755435
# Best Model Saved
# Iteration : 111 - Train Loss : 0.991801, Test Loss : 0.811706, Train Acc : 81.250000, Test Acc : 84.103261
# Best Model Saved
# Iteration : 116 - Train Loss : 0.606514, Test Loss : 0.799169, Train Acc : 90.625000, Test Acc : 85.869565
# Iteration : 121 - Train Loss : 0.685751, Test Loss : 1.041745, Train Acc : 81.250000, Test Acc : 82.201087
# Best Model Saved
# Iteration : 126 - Train Loss : 0.773242, Test Loss : 0.644976, Train Acc : 81.250000, Test Acc : 88.926630
# Best Model Saved
# Iteration : 131 - Train Loss : 0.501564, Test Loss : 0.602927, Train Acc : 90.625000, Test Acc : 86.956522
# Best Model Saved
# Iteration : 136 - Train Loss : 0.572856, Test Loss : 0.534483, Train Acc : 90.625000, Test Acc : 89.062500
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.388731, Test Loss : 0.506933, Train Acc : 93.750000, Test Acc : 90.421196
# Best Model Saved
# Iteration : 6 - Train Loss : 0.414189, Test Loss : 0.528890, Train Acc : 90.625000, Test Acc : 90.760870
# Best Model Saved
# Iteration : 11 - Train Loss : 0.385607, Test Loss : 0.497721, Train Acc : 87.500000, Test Acc : 88.858696
# Iteration : 16 - Train Loss : 0.470774, Test Loss : 0.587072, Train Acc : 84.375000, Test Acc : 88.858696
# Best Model Saved
# Iteration : 21 - Train Loss : 0.430603, Test Loss : 0.500527, Train Acc : 93.750000, Test Acc : 93.138587
# Best Model Saved
# Iteration : 26 - Train Loss : 0.292634, Test Loss : 0.323613, Train Acc : 93.750000, Test Acc : 95.380435
# Best Model Saved
# Iteration : 31 - Train Loss : 0.318016, Test Loss : 0.306168, Train Acc : 87.500000, Test Acc : 93.614130
# Best Model Saved
# Iteration : 36 - Train Loss : 0.323948, Test Loss : 0.289822, Train Acc : 90.625000, Test Acc : 94.361413
# Iteration : 41 - Train Loss : 0.248293, Test Loss : 0.347738, Train Acc : 96.875000, Test Acc : 92.730978
# Iteration : 46 - Train Loss : 0.177621, Test Loss : 0.307442, Train Acc : 100.000000, Test Acc : 93.682065
# Best Model Saved
# Iteration : 51 - Train Loss : 0.272358, Test Loss : 0.282888, Train Acc : 93.750000, Test Acc : 93.478261
# Best Model Saved
# Iteration : 56 - Train Loss : 0.297930, Test Loss : 0.246119, Train Acc : 90.625000, Test Acc : 96.331522
# Iteration : 61 - Train Loss : 0.156996, Test Loss : 0.363814, Train Acc : 96.875000, Test Acc : 94.157609
# Iteration : 66 - Train Loss : 0.218338, Test Loss : 0.376864, Train Acc : 96.875000, Test Acc : 90.557065
# Best Model Saved
# Iteration : 71 - Train Loss : 0.176349, Test Loss : 0.215589, Train Acc : 93.750000, Test Acc : 94.972826
# Iteration : 76 - Train Loss : 0.370225, Test Loss : 0.233881, Train Acc : 93.750000, Test Acc : 94.361413
# Iteration : 81 - Train Loss : 0.459186, Test Loss : 0.408494, Train Acc : 93.750000, Test Acc : 91.236413
# Iteration : 86 - Train Loss : 0.181084, Test Loss : 0.455340, Train Acc : 96.875000, Test Acc : 92.119565
# Iteration : 91 - Train Loss : 0.224800, Test Loss : 0.345220, Train Acc : 96.875000, Test Acc : 93.478261
# Best Model Saved
# Iteration : 96 - Train Loss : 0.244473, Test Loss : 0.263988, Train Acc : 93.750000, Test Acc : 95.788043
# Best Model Saved
# Iteration : 101 - Train Loss : 0.335125, Test Loss : 0.245267, Train Acc : 90.625000, Test Acc : 97.214674
# Best Model Saved
# Iteration : 106 - Train Loss : 0.309707, Test Loss : 0.223145, Train Acc : 93.750000, Test Acc : 96.399457
# Iteration : 111 - Train Loss : 0.151245, Test Loss : 0.233781, Train Acc : 100.000000, Test Acc : 96.059783
# Best Model Saved
# Iteration : 116 - Train Loss : 0.176079, Test Loss : 0.229095, Train Acc : 96.875000, Test Acc : 96.535326
# Iteration : 121 - Train Loss : 0.159991, Test Loss : 0.239539, Train Acc : 96.875000, Test Acc : 94.497283
# Best Model Saved
# Iteration : 126 - Train Loss : 0.084453, Test Loss : 0.216382, Train Acc : 100.000000, Test Acc : 96.263587
# Best Model Saved
# Iteration : 131 - Train Loss : 0.105389, Test Loss : 0.212670, Train Acc : 96.875000, Test Acc : 97.010870
# Best Model Saved
# Iteration : 136 - Train Loss : 0.184655, Test Loss : 0.147936, Train Acc : 96.875000, Test Acc : 97.622283
#
# Epoch 3 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.064517, Test Loss : 0.140635, Train Acc : 100.000000, Test Acc : 97.214674
# Best Model Saved
# Iteration : 6 - Train Loss : 0.122807, Test Loss : 0.141097, Train Acc : 96.875000, Test Acc : 97.894022
# Best Model Saved
# Iteration : 11 - Train Loss : 0.094094, Test Loss : 0.074792, Train Acc : 100.000000, Test Acc : 99.116848
# Best Model Saved
# Iteration : 16 - Train Loss : 0.085361, Test Loss : 0.066568, Train Acc : 100.000000, Test Acc : 99.592391
# Iteration : 21 - Train Loss : 0.093508, Test Loss : 0.101016, Train Acc : 100.000000, Test Acc : 98.709239
# Iteration : 26 - Train Loss : 0.112641, Test Loss : 0.070955, Train Acc : 93.750000, Test Acc : 98.845109
# Iteration : 31 - Train Loss : 0.137488, Test Loss : 0.110161, Train Acc : 96.875000, Test Acc : 97.758152
# Iteration : 36 - Train Loss : 0.210068, Test Loss : 0.091246, Train Acc : 96.875000, Test Acc : 97.961957
# Iteration : 41 - Train Loss : 0.056754, Test Loss : 0.134875, Train Acc : 100.000000, Test Acc : 97.146739
# Iteration : 46 - Train Loss : 0.061795, Test Loss : 0.115003, Train Acc : 100.000000, Test Acc : 97.758152
# Iteration : 51 - Train Loss : 0.109116, Test Loss : 0.115984, Train Acc : 96.875000, Test Acc : 98.029891
# Iteration : 56 - Train Loss : 0.063418, Test Loss : 0.116707, Train Acc : 100.000000, Test Acc : 98.233696
# Iteration : 61 - Train Loss : 0.092560, Test Loss : 0.190203, Train Acc : 100.000000, Test Acc : 95.040761
# Iteration : 66 - Train Loss : 0.063495, Test Loss : 0.142882, Train Acc : 100.000000, Test Acc : 96.603261
# Iteration : 71 - Train Loss : 0.054543, Test Loss : 0.164953, Train Acc : 100.000000, Test Acc : 97.282609
# Iteration : 76 - Train Loss : 0.104749, Test Loss : 0.160126, Train Acc : 96.875000, Test Acc : 97.418478
# Iteration : 81 - Train Loss : 0.123481, Test Loss : 0.092675, Train Acc : 100.000000, Test Acc : 98.709239
# Iteration : 86 - Train Loss : 0.046381, Test Loss : 0.098520, Train Acc : 100.000000, Test Acc : 98.369565
# Iteration : 91 - Train Loss : 0.046226, Test Loss : 0.101694, Train Acc : 100.000000, Test Acc : 97.961957
# Best Model Saved
# Iteration : 96 - Train Loss : 0.095603, Test Loss : 0.049403, Train Acc : 100.000000, Test Acc : 99.184783
# Iteration : 101 - Train Loss : 0.058794, Test Loss : 0.100806, Train Acc : 100.000000, Test Acc : 98.301630
# Iteration : 106 - Train Loss : 0.052516, Test Loss : 0.065091, Train Acc : 100.000000, Test Acc : 98.777174
# Iteration : 111 - Train Loss : 0.036881, Test Loss : 0.063028, Train Acc : 100.000000, Test Acc : 99.116848
# Best Model Saved
# Iteration : 116 - Train Loss : 0.130298, Test Loss : 0.043161, Train Acc : 96.875000, Test Acc : 99.116848
# Iteration : 121 - Train Loss : 0.063105, Test Loss : 0.114754, Train Acc : 100.000000, Test Acc : 97.282609
# Iteration : 126 - Train Loss : 0.211286, Test Loss : 0.209899, Train Acc : 96.875000, Test Acc : 96.127717
# Iteration : 131 - Train Loss : 0.088566, Test Loss : 0.124178, Train Acc : 96.875000, Test Acc : 97.894022
# Iteration : 136 - Train Loss : 0.084684, Test Loss : 0.146368, Train Acc : 96.875000, Test Acc : 97.894022
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 0.266115, Test Loss : 0.144818, Train Acc : 93.750000, Test Acc : 97.894022
# Iteration : 6 - Train Loss : 0.035380, Test Loss : 0.077504, Train Acc : 100.000000, Test Acc : 98.573370
# Iteration : 11 - Train Loss : 0.078017, Test Loss : 0.073381, Train Acc : 96.875000, Test Acc : 98.437500
# Iteration : 16 - Train Loss : 0.037741, Test Loss : 0.230409, Train Acc : 100.000000, Test Acc : 95.720109
# Iteration : 21 - Train Loss : 0.035932, Test Loss : 0.082267, Train Acc : 100.000000, Test Acc : 98.641304
# Iteration : 26 - Train Loss : 0.084508, Test Loss : 0.120731, Train Acc : 96.875000, Test Acc : 97.690217
# Iteration : 31 - Train Loss : 0.057742, Test Loss : 0.107055, Train Acc : 100.000000, Test Acc : 98.029891
# Iteration : 36 - Train Loss : 0.036825, Test Loss : 0.134535, Train Acc : 100.000000, Test Acc : 97.690217
# Iteration : 41 - Train Loss : 0.032129, Test Loss : 0.086153, Train Acc : 100.000000, Test Acc : 98.573370
# Best Model Saved
# Iteration : 46 - Train Loss : 0.032877, Test Loss : 0.044991, Train Acc : 100.000000, Test Acc : 99.320652
# Best Model Saved
# Iteration : 51 - Train Loss : 0.154060, Test Loss : 0.035172, Train Acc : 93.750000, Test Acc : 99.592391
# Iteration : 56 - Train Loss : 0.031045, Test Loss : 0.125270, Train Acc : 100.000000, Test Acc : 97.690217
# Iteration : 61 - Train Loss : 0.059085, Test Loss : 0.067093, Train Acc : 100.000000, Test Acc : 99.388587
# Iteration : 66 - Train Loss : 0.033681, Test Loss : 0.048129, Train Acc : 100.000000, Test Acc : 99.116848
# Iteration : 71 - Train Loss : 0.036169, Test Loss : 0.037979, Train Acc : 100.000000, Test Acc : 99.388587
# Iteration : 76 - Train Loss : 0.069177, Test Loss : 0.046223, Train Acc : 96.875000, Test Acc : 98.980978
# Iteration : 81 - Train Loss : 0.025324, Test Loss : 0.036380, Train Acc : 100.000000, Test Acc : 99.320652
# Best Model Saved
# Iteration : 86 - Train Loss : 0.018983, Test Loss : 0.035107, Train Acc : 100.000000, Test Acc : 99.388587
# Best Model Saved
# Iteration : 91 - Train Loss : 0.026564, Test Loss : 0.034151, Train Acc : 100.000000, Test Acc : 99.388587
# Iteration : 96 - Train Loss : 0.058258, Test Loss : 0.072155, Train Acc : 96.875000, Test Acc : 98.097826
# Iteration : 101 - Train Loss : 0.139226, Test Loss : 0.075103, Train Acc : 96.875000, Test Acc : 98.029891
# Iteration : 106 - Train Loss : 0.037044, Test Loss : 0.073695, Train Acc : 100.000000, Test Acc : 97.894022
# Iteration : 111 - Train Loss : 0.080050, Test Loss : 0.053094, Train Acc : 93.750000, Test Acc : 98.505435
# Best Model Saved
# Iteration : 116 - Train Loss : 0.027854, Test Loss : 0.032118, Train Acc : 100.000000, Test Acc : 99.456522
# Iteration : 121 - Train Loss : 0.060643, Test Loss : 0.042085, Train Acc : 100.000000, Test Acc : 99.252717
# Iteration : 126 - Train Loss : 0.023662, Test Loss : 0.038126, Train Acc : 100.000000, Test Acc : 99.252717
# Iteration : 131 - Train Loss : 0.029423, Test Loss : 0.039268, Train Acc : 100.000000, Test Acc : 99.116848
# Iteration : 136 - Train Loss : 0.013945, Test Loss : 0.060583, Train Acc : 100.000000, Test Acc : 98.301630
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.181935, Test Loss : 0.039226, Train Acc : 96.875000, Test Acc : 98.845109
# Iteration : 6 - Train Loss : 0.049582, Test Loss : 0.089484, Train Acc : 100.000000, Test Acc : 98.573370
# Iteration : 11 - Train Loss : 0.026295, Test Loss : 0.116125, Train Acc : 100.000000, Test Acc : 97.894022
# Iteration : 16 - Train Loss : 0.021549, Test Loss : 0.052744, Train Acc : 100.000000, Test Acc : 98.777174
# Iteration : 21 - Train Loss : 0.029957, Test Loss : 0.039675, Train Acc : 100.000000, Test Acc : 99.116848
# Best Model Saved
# Iteration : 26 - Train Loss : 0.051181, Test Loss : 0.028094, Train Acc : 96.875000, Test Acc : 99.524457
# Best Model Saved
# Iteration : 31 - Train Loss : 0.069096, Test Loss : 0.025370, Train Acc : 96.875000, Test Acc : 99.388587
# Best Model Saved
# Iteration : 36 - Train Loss : 0.042236, Test Loss : 0.015688, Train Acc : 100.000000, Test Acc : 99.728261
# Iteration : 41 - Train Loss : 0.011679, Test Loss : 0.019750, Train Acc : 100.000000, Test Acc : 99.660326
# Iteration : 46 - Train Loss : 0.141182, Test Loss : 0.028134, Train Acc : 96.875000, Test Acc : 99.184783
# Best Model Saved
# Iteration : 51 - Train Loss : 0.010493, Test Loss : 0.013323, Train Acc : 100.000000, Test Acc : 99.728261
# Best Model Saved
# Iteration : 56 - Train Loss : 0.017548, Test Loss : 0.011830, Train Acc : 100.000000, Test Acc : 99.796196
# Iteration : 61 - Train Loss : 0.014281, Test Loss : 0.012051, Train Acc : 100.000000, Test Acc : 99.728261
# Best Model Saved
# Iteration : 66 - Train Loss : 0.015485, Test Loss : 0.011143, Train Acc : 100.000000, Test Acc : 99.728261
# Best Model Saved
# Iteration : 71 - Train Loss : 0.011315, Test Loss : 0.010586, Train Acc : 100.000000, Test Acc : 99.796196
# Best Model Saved
# Iteration : 76 - Train Loss : 0.009015, Test Loss : 0.009186, Train Acc : 100.000000, Test Acc : 99.796196
# Best Model Saved
# Iteration : 81 - Train Loss : 0.008388, Test Loss : 0.009167, Train Acc : 100.000000, Test Acc : 99.864130
# Best Model Saved
# Iteration : 86 - Train Loss : 0.006535, Test Loss : 0.009135, Train Acc : 100.000000, Test Acc : 99.864130
# Best Model Saved
# Iteration : 91 - Train Loss : 0.007960, Test Loss : 0.008392, Train Acc : 100.000000, Test Acc : 99.864130
# Iteration : 96 - Train Loss : 0.006164, Test Loss : 0.012655, Train Acc : 100.000000, Test Acc : 99.660326
# Iteration : 101 - Train Loss : 0.007819, Test Loss : 0.018835, Train Acc : 100.000000, Test Acc : 99.524457
# Iteration : 106 - Train Loss : 0.009022, Test Loss : 0.028498, Train Acc : 100.000000, Test Acc : 99.252717
# Iteration : 111 - Train Loss : 0.006656, Test Loss : 0.009653, Train Acc : 100.000000, Test Acc : 99.796196
# Iteration : 116 - Train Loss : 0.009663, Test Loss : 0.075222, Train Acc : 100.000000, Test Acc : 98.301630
# Iteration : 121 - Train Loss : 0.071958, Test Loss : 0.030688, Train Acc : 96.875000, Test Acc : 99.524457
# Iteration : 126 - Train Loss : 0.013400, Test Loss : 0.040450, Train Acc : 100.000000, Test Acc : 98.845109
# Iteration : 131 - Train Loss : 0.022331, Test Loss : 0.083402, Train Acc : 100.000000, Test Acc : 98.233696
# Iteration : 136 - Train Loss : 0.016193, Test Loss : 0.170811, Train Acc : 100.000000, Test Acc : 97.214674

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
import os, json, PIL
import pandas as pd

# %%
model = Baseline(model='resnet18', num_classes=157)
model.model.load_state_dict(torch.load('./4_90.pt'))
model.model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=157, bias=True)
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])


data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            #if torch.max(prediction) > 0.9:
            #    prediction[torch.argmax(prediction)] = 1
            #    prediction[prediction < 1] = 0
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
display(sample_submission.head())
sample_submission.to_csv('./ImageNetStat_4_90_threshno.csv', index=False)
# Out:
#    Image_Path   Label_0   Label_1  ...  Label_193     Label_194     Label_195
# 0  ./test\649  0.446346  0.024354  ...   0.000077  9.670572e-05  2.613702e-04
# 1  ./test\650  0.000065  0.000028  ...   0.000005  9.355502e-07  1.127273e-06
# 2  ./test\651  0.000255  0.000607  ...   0.000047  1.444349e-05  1.369846e-05
# 3  ./test\652  0.000178  0.000803  ...   0.000021  4.018057e-06  5.966293e-06
# 4  ./test\653  0.000008  0.000028  ...   0.000004  1.036787e-05  9.281457e-07
#
# [5 rows x 158 columns]
