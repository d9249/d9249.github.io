# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/vgg11%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 03:10:06 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='vgg11', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11-8a719046.pth" to /root/.cache/torch/hub/checkpoints/vgg11-8a719046.pth
#   0%|          | 0.00/507M [00:00<?, ?B/s]

# %%
len(train_dataset.label_info)
# Out:
# 157

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.061795, Test Loss : 5.432635, Train Acc : 0.000000, Test Acc : 0.951087
# Best Model Saved
# Iteration : 6 - Train Loss : 5.036833, Test Loss : 5.036214, Train Acc : 3.125000, Test Acc : 2.853261
# Best Model Saved
# Iteration : 11 - Train Loss : 5.024395, Test Loss : 5.018197, Train Acc : 0.000000, Test Acc : 1.562500
# Best Model Saved
# Iteration : 16 - Train Loss : 5.026354, Test Loss : 5.033237, Train Acc : 0.000000, Test Acc : 1.766304
# Best Model Saved
# Iteration : 21 - Train Loss : 4.975035, Test Loss : 4.949827, Train Acc : 6.250000, Test Acc : 1.970109
# Iteration : 26 - Train Loss : 5.036010, Test Loss : 5.036776, Train Acc : 3.125000, Test Acc : 1.834239
# Iteration : 31 - Train Loss : 4.895987, Test Loss : 5.018653, Train Acc : 3.125000, Test Acc : 1.086957
# Iteration : 36 - Train Loss : 5.061173, Test Loss : 5.031781, Train Acc : 3.125000, Test Acc : 0.951087
# Iteration : 41 - Train Loss : 5.031747, Test Loss : 5.012446, Train Acc : 0.000000, Test Acc : 0.951087
# Best Model Saved
# Iteration : 46 - Train Loss : 4.928736, Test Loss : 4.882384, Train Acc : 0.000000, Test Acc : 0.951087
# Best Model Saved
# Iteration : 51 - Train Loss : 4.920044, Test Loss : 4.820389, Train Acc : 9.375000, Test Acc : 2.649457
# Best Model Saved
# Iteration : 56 - Train Loss : 4.854829, Test Loss : 4.815950, Train Acc : 3.125000, Test Acc : 2.989130
# Best Model Saved
# Iteration : 61 - Train Loss : 4.742057, Test Loss : 4.716992, Train Acc : 3.125000, Test Acc : 3.125000
# Best Model Saved
# Iteration : 66 - Train Loss : 5.019125, Test Loss : 4.705172, Train Acc : 3.125000, Test Acc : 2.853261
# Best Model Saved
# Iteration : 71 - Train Loss : 4.778729, Test Loss : 4.521281, Train Acc : 6.250000, Test Acc : 3.872283
# Best Model Saved
# Iteration : 76 - Train Loss : 4.292764, Test Loss : 4.334602, Train Acc : 6.250000, Test Acc : 4.279891
# Best Model Saved
# Iteration : 81 - Train Loss : 4.373367, Test Loss : 4.303678, Train Acc : 0.000000, Test Acc : 5.298913
# Best Model Saved
# Iteration : 86 - Train Loss : 4.198677, Test Loss : 4.085377, Train Acc : 6.250000, Test Acc : 5.298913
# Best Model Saved
# Iteration : 91 - Train Loss : 4.118340, Test Loss : 3.947340, Train Acc : 0.000000, Test Acc : 6.521739
# Best Model Saved
# Iteration : 96 - Train Loss : 4.068222, Test Loss : 3.893928, Train Acc : 0.000000, Test Acc : 6.182065
# Best Model Saved
# Iteration : 101 - Train Loss : 4.142878, Test Loss : 3.792397, Train Acc : 3.125000, Test Acc : 5.978261
# Best Model Saved
# Iteration : 106 - Train Loss : 4.295066, Test Loss : 3.721527, Train Acc : 9.375000, Test Acc : 7.269022
# Best Model Saved
# Iteration : 111 - Train Loss : 4.236773, Test Loss : 3.613348, Train Acc : 6.250000, Test Acc : 8.355978
# Best Model Saved
# Iteration : 116 - Train Loss : 3.538847, Test Loss : 3.527967, Train Acc : 9.375000, Test Acc : 8.016304
# Best Model Saved
# Iteration : 121 - Train Loss : 3.482464, Test Loss : 3.513086, Train Acc : 12.500000, Test Acc : 7.948370
# Best Model Saved
# Iteration : 126 - Train Loss : 3.428103, Test Loss : 3.404405, Train Acc : 3.125000, Test Acc : 8.831522
# Best Model Saved
# Iteration : 131 - Train Loss : 3.484097, Test Loss : 3.393454, Train Acc : 15.625000, Test Acc : 9.918478
# Best Model Saved
# Iteration : 136 - Train Loss : 3.561040, Test Loss : 3.351277, Train Acc : 3.125000, Test Acc : 8.967391
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 3.100059, Test Loss : 3.264883, Train Acc : 6.250000, Test Acc : 10.054348
# Best Model Saved
# Iteration : 6 - Train Loss : 3.332009, Test Loss : 3.212725, Train Acc : 3.125000, Test Acc : 11.888587
# Best Model Saved
# Iteration : 11 - Train Loss : 3.463487, Test Loss : 3.211035, Train Acc : 3.125000, Test Acc : 9.986413
# Best Model Saved
# Iteration : 16 - Train Loss : 3.224469, Test Loss : 3.168738, Train Acc : 6.250000, Test Acc : 10.529891
# Best Model Saved
# Iteration : 21 - Train Loss : 2.986262, Test Loss : 3.083019, Train Acc : 15.625000, Test Acc : 13.790761
# Best Model Saved
# Iteration : 26 - Train Loss : 2.967481, Test Loss : 2.996337, Train Acc : 28.125000, Test Acc : 15.964674
# Best Model Saved
# Iteration : 31 - Train Loss : 2.989284, Test Loss : 2.952866, Train Acc : 6.250000, Test Acc : 17.798913
# Best Model Saved
# Iteration : 36 - Train Loss : 3.143192, Test Loss : 2.920915, Train Acc : 9.375000, Test Acc : 17.459239
# Best Model Saved
# Iteration : 41 - Train Loss : 3.514760, Test Loss : 2.919924, Train Acc : 0.000000, Test Acc : 18.274457
# Best Model Saved
# Iteration : 46 - Train Loss : 3.393086, Test Loss : 2.794047, Train Acc : 15.625000, Test Acc : 19.836957
# Best Model Saved
# Iteration : 51 - Train Loss : 2.743776, Test Loss : 2.777080, Train Acc : 15.625000, Test Acc : 19.293478
# Best Model Saved
# Iteration : 56 - Train Loss : 3.014453, Test Loss : 2.804181, Train Acc : 12.500000, Test Acc : 20.244565
# Best Model Saved
# Iteration : 61 - Train Loss : 2.849735, Test Loss : 2.661386, Train Acc : 15.625000, Test Acc : 20.788043
# Best Model Saved
# Iteration : 66 - Train Loss : 2.965551, Test Loss : 2.551853, Train Acc : 9.375000, Test Acc : 23.845109
# Iteration : 71 - Train Loss : 2.859367, Test Loss : 2.610813, Train Acc : 28.125000, Test Acc : 21.807065
# Best Model Saved
# Iteration : 76 - Train Loss : 2.739557, Test Loss : 2.539482, Train Acc : 18.750000, Test Acc : 24.660326
# Best Model Saved
# Iteration : 81 - Train Loss : 2.347276, Test Loss : 2.366428, Train Acc : 31.250000, Test Acc : 25.611413
# Best Model Saved
# Iteration : 86 - Train Loss : 2.451792, Test Loss : 2.356789, Train Acc : 31.250000, Test Acc : 28.872283
# Best Model Saved
# Iteration : 91 - Train Loss : 2.566826, Test Loss : 2.368617, Train Acc : 25.000000, Test Acc : 30.366848
# Best Model Saved
# Iteration : 96 - Train Loss : 2.443440, Test Loss : 2.326922, Train Acc : 21.875000, Test Acc : 29.483696
# Best Model Saved
# Iteration : 101 - Train Loss : 2.908534, Test Loss : 2.168919, Train Acc : 18.750000, Test Acc : 33.695652
# Best Model Saved
# Iteration : 106 - Train Loss : 2.220735, Test Loss : 2.124728, Train Acc : 25.000000, Test Acc : 33.831522
# Best Model Saved
# Iteration : 111 - Train Loss : 2.546177, Test Loss : 2.089688, Train Acc : 21.875000, Test Acc : 32.744565
# Iteration : 116 - Train Loss : 2.302844, Test Loss : 2.157313, Train Acc : 28.125000, Test Acc : 30.978261
# Best Model Saved
# Iteration : 121 - Train Loss : 2.241908, Test Loss : 2.123045, Train Acc : 28.125000, Test Acc : 33.084239
# Best Model Saved
# Iteration : 126 - Train Loss : 2.007842, Test Loss : 1.941688, Train Acc : 40.625000, Test Acc : 38.790761
# Best Model Saved
# Iteration : 131 - Train Loss : 2.446308, Test Loss : 1.859294, Train Acc : 15.625000, Test Acc : 39.877717
# Best Model Saved
# Iteration : 136 - Train Loss : 2.212139, Test Loss : 1.818630, Train Acc : 28.125000, Test Acc : 41.711957
#
# Epoch 3 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 1.940953, Test Loss : 1.740329, Train Acc : 37.500000, Test Acc : 44.021739
# Best Model Saved
# Iteration : 6 - Train Loss : 2.153084, Test Loss : 1.759628, Train Acc : 40.625000, Test Acc : 44.904891
# Iteration : 11 - Train Loss : 2.071807, Test Loss : 1.826239, Train Acc : 28.125000, Test Acc : 39.877717
# Best Model Saved
# Iteration : 16 - Train Loss : 2.047983, Test Loss : 1.755021, Train Acc : 31.250000, Test Acc : 43.138587
# Best Model Saved
# Iteration : 21 - Train Loss : 1.988075, Test Loss : 1.748312, Train Acc : 34.375000, Test Acc : 45.788043
# Best Model Saved
# Iteration : 26 - Train Loss : 2.039453, Test Loss : 1.667377, Train Acc : 46.875000, Test Acc : 47.214674
# Iteration : 31 - Train Loss : 2.242587, Test Loss : 1.714902, Train Acc : 31.250000, Test Acc : 45.312500
# Best Model Saved
# Iteration : 36 - Train Loss : 1.654935, Test Loss : 1.632158, Train Acc : 37.500000, Test Acc : 48.777174
# Best Model Saved
# Iteration : 41 - Train Loss : 2.081270, Test Loss : 1.583432, Train Acc : 28.125000, Test Acc : 46.807065
# Best Model Saved
# Iteration : 46 - Train Loss : 2.131121, Test Loss : 1.514912, Train Acc : 40.625000, Test Acc : 48.437500
# Iteration : 51 - Train Loss : 1.848480, Test Loss : 1.599209, Train Acc : 40.625000, Test Acc : 47.622283
# Best Model Saved
# Iteration : 56 - Train Loss : 2.214886, Test Loss : 1.471315, Train Acc : 28.125000, Test Acc : 51.426630
# Iteration : 61 - Train Loss : 1.652434, Test Loss : 1.566175, Train Acc : 50.000000, Test Acc : 50.407609
# Iteration : 66 - Train Loss : 1.895372, Test Loss : 1.553278, Train Acc : 34.375000, Test Acc : 49.048913
# Best Model Saved
# Iteration : 71 - Train Loss : 1.418647, Test Loss : 1.430561, Train Acc : 56.250000, Test Acc : 54.008152
# Iteration : 76 - Train Loss : 1.878060, Test Loss : 1.458640, Train Acc : 43.750000, Test Acc : 50.543478
# Best Model Saved
# Iteration : 81 - Train Loss : 1.684015, Test Loss : 1.413840, Train Acc : 50.000000, Test Acc : 51.698370
# Best Model Saved
# Iteration : 86 - Train Loss : 1.945433, Test Loss : 1.367608, Train Acc : 31.250000, Test Acc : 54.687500
# Iteration : 91 - Train Loss : 1.673801, Test Loss : 1.424298, Train Acc : 43.750000, Test Acc : 52.717391
# Best Model Saved
# Iteration : 96 - Train Loss : 1.613538, Test Loss : 1.258375, Train Acc : 43.750000, Test Acc : 60.054348
# Iteration : 101 - Train Loss : 1.564723, Test Loss : 1.275929, Train Acc : 43.750000, Test Acc : 56.997283
# Iteration : 106 - Train Loss : 1.119450, Test Loss : 1.275077, Train Acc : 65.625000, Test Acc : 58.627717
# Best Model Saved
# Iteration : 111 - Train Loss : 1.782287, Test Loss : 1.253108, Train Acc : 50.000000, Test Acc : 57.676630
# Best Model Saved
# Iteration : 116 - Train Loss : 1.824394, Test Loss : 1.234480, Train Acc : 40.625000, Test Acc : 57.608696
# Best Model Saved
# Iteration : 121 - Train Loss : 1.898816, Test Loss : 1.188879, Train Acc : 40.625000, Test Acc : 58.084239
# Best Model Saved
# Iteration : 126 - Train Loss : 1.283518, Test Loss : 1.117707, Train Acc : 59.375000, Test Acc : 62.771739
# Best Model Saved
# Iteration : 131 - Train Loss : 1.132850, Test Loss : 1.066308, Train Acc : 62.500000, Test Acc : 60.733696
# Iteration : 136 - Train Loss : 1.072621, Test Loss : 1.196952, Train Acc : 59.375000, Test Acc : 60.258152
#
# Epoch 4 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 1.459340, Test Loss : 1.008673, Train Acc : 56.250000, Test Acc : 65.421196
# Iteration : 6 - Train Loss : 1.194974, Test Loss : 1.084715, Train Acc : 62.500000, Test Acc : 62.907609
# Iteration : 11 - Train Loss : 1.095470, Test Loss : 1.093624, Train Acc : 56.250000, Test Acc : 63.383152
# Iteration : 16 - Train Loss : 1.740316, Test Loss : 1.160475, Train Acc : 37.500000, Test Acc : 59.986413
# Best Model Saved
# Iteration : 21 - Train Loss : 0.968675, Test Loss : 1.024303, Train Acc : 75.000000, Test Acc : 65.625000
# Best Model Saved
# Iteration : 26 - Train Loss : 1.630973, Test Loss : 0.962315, Train Acc : 40.625000, Test Acc : 65.625000
# Best Model Saved
# Iteration : 31 - Train Loss : 1.135136, Test Loss : 0.901068, Train Acc : 65.625000, Test Acc : 68.002717
# Best Model Saved
# Iteration : 36 - Train Loss : 1.106325, Test Loss : 0.879050, Train Acc : 56.250000, Test Acc : 70.176630
# Best Model Saved
# Iteration : 41 - Train Loss : 1.061774, Test Loss : 0.863124, Train Acc : 71.875000, Test Acc : 71.942935
# Iteration : 46 - Train Loss : 1.408849, Test Loss : 0.990509, Train Acc : 62.500000, Test Acc : 66.440217
# Iteration : 51 - Train Loss : 1.182580, Test Loss : 0.885761, Train Acc : 65.625000, Test Acc : 70.176630
# Best Model Saved
# Iteration : 56 - Train Loss : 1.161747, Test Loss : 0.849375, Train Acc : 62.500000, Test Acc : 71.399457
# Best Model Saved
# Iteration : 61 - Train Loss : 1.143021, Test Loss : 0.848452, Train Acc : 62.500000, Test Acc : 69.972826
# Best Model Saved
# Iteration : 66 - Train Loss : 0.924014, Test Loss : 0.900017, Train Acc : 75.000000, Test Acc : 71.603261
# Best Model Saved
# Iteration : 71 - Train Loss : 1.179463, Test Loss : 0.819940, Train Acc : 68.750000, Test Acc : 73.845109
# Iteration : 76 - Train Loss : 0.925008, Test Loss : 0.916861, Train Acc : 65.625000, Test Acc : 70.380435
# Iteration : 81 - Train Loss : 1.425801, Test Loss : 0.903492, Train Acc : 50.000000, Test Acc : 68.410326
# Best Model Saved
# Iteration : 86 - Train Loss : 1.337558, Test Loss : 0.741518, Train Acc : 50.000000, Test Acc : 75.067935
# Iteration : 91 - Train Loss : 0.850962, Test Loss : 0.930238, Train Acc : 71.875000, Test Acc : 68.206522
# Iteration : 96 - Train Loss : 1.106184, Test Loss : 0.832932, Train Acc : 59.375000, Test Acc : 72.350543
# Iteration : 101 - Train Loss : 0.787675, Test Loss : 0.747028, Train Acc : 75.000000, Test Acc : 74.864130
# Best Model Saved
# Iteration : 106 - Train Loss : 0.856151, Test Loss : 0.686399, Train Acc : 65.625000, Test Acc : 77.309783
# Best Model Saved
# Iteration : 111 - Train Loss : 1.427680, Test Loss : 0.681082, Train Acc : 59.375000, Test Acc : 76.698370
# Best Model Saved
# Iteration : 116 - Train Loss : 0.813696, Test Loss : 0.661370, Train Acc : 71.875000, Test Acc : 78.192935
# Best Model Saved
# Iteration : 121 - Train Loss : 0.825838, Test Loss : 0.630718, Train Acc : 75.000000, Test Acc : 78.668478
# Best Model Saved
# Iteration : 126 - Train Loss : 1.008020, Test Loss : 0.590925, Train Acc : 65.625000, Test Acc : 79.687500
# Iteration : 131 - Train Loss : 1.232564, Test Loss : 0.682032, Train Acc : 59.375000, Test Acc : 75.815217
# Iteration : 136 - Train Loss : 1.125726, Test Loss : 0.777048, Train Acc : 59.375000, Test Acc : 74.320652
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.556800, Test Loss : 0.794151, Train Acc : 87.500000, Test Acc : 72.078804
# Iteration : 6 - Train Loss : 1.044313, Test Loss : 0.664576, Train Acc : 81.250000, Test Acc : 78.872283
# Iteration : 11 - Train Loss : 0.896396, Test Loss : 0.665095, Train Acc : 68.750000, Test Acc : 77.105978
# Best Model Saved
# Iteration : 16 - Train Loss : 0.646753, Test Loss : 0.585687, Train Acc : 84.375000, Test Acc : 80.502717
# Best Model Saved
# Iteration : 21 - Train Loss : 1.187304, Test Loss : 0.582110, Train Acc : 59.375000, Test Acc : 79.959239
# Iteration : 26 - Train Loss : 0.720431, Test Loss : 0.606211, Train Acc : 75.000000, Test Acc : 79.415761
# Best Model Saved
# Iteration : 31 - Train Loss : 0.708529, Test Loss : 0.572351, Train Acc : 71.875000, Test Acc : 80.774457
# Best Model Saved
# Iteration : 36 - Train Loss : 0.878599, Test Loss : 0.567683, Train Acc : 68.750000, Test Acc : 79.823370
# Best Model Saved
# Iteration : 41 - Train Loss : 0.955880, Test Loss : 0.526508, Train Acc : 71.875000, Test Acc : 82.608696
# Best Model Saved
# Iteration : 46 - Train Loss : 1.015169, Test Loss : 0.502028, Train Acc : 59.375000, Test Acc : 82.269022
# Best Model Saved
# Iteration : 51 - Train Loss : 0.485169, Test Loss : 0.472865, Train Acc : 81.250000, Test Acc : 81.929348
# Best Model Saved
# Iteration : 56 - Train Loss : 0.761380, Test Loss : 0.496801, Train Acc : 78.125000, Test Acc : 82.133152
# Iteration : 61 - Train Loss : 0.752150, Test Loss : 0.613537, Train Acc : 71.875000, Test Acc : 79.823370
# Iteration : 66 - Train Loss : 0.567145, Test Loss : 0.647301, Train Acc : 81.250000, Test Acc : 78.736413
# Best Model Saved
# Iteration : 71 - Train Loss : 0.561764, Test Loss : 0.510268, Train Acc : 78.125000, Test Acc : 83.084239
# Best Model Saved
# Iteration : 76 - Train Loss : 0.484472, Test Loss : 0.457355, Train Acc : 84.375000, Test Acc : 84.782609
# Best Model Saved
# Iteration : 81 - Train Loss : 0.841272, Test Loss : 0.383717, Train Acc : 68.750000, Test Acc : 87.228261
# Best Model Saved
# Iteration : 86 - Train Loss : 0.567752, Test Loss : 0.379678, Train Acc : 90.625000, Test Acc : 86.752717
# Iteration : 91 - Train Loss : 1.044923, Test Loss : 0.459455, Train Acc : 65.625000, Test Acc : 82.948370
# Iteration : 96 - Train Loss : 1.083752, Test Loss : 0.571719, Train Acc : 71.875000, Test Acc : 82.269022
# Iteration : 101 - Train Loss : 1.035296, Test Loss : 0.478863, Train Acc : 68.750000, Test Acc : 84.918478
# Iteration : 106 - Train Loss : 0.487313, Test Loss : 0.483327, Train Acc : 90.625000, Test Acc : 85.190217
# Iteration : 111 - Train Loss : 0.523832, Test Loss : 0.452027, Train Acc : 87.500000, Test Acc : 85.529891
# Best Model Saved
# Iteration : 116 - Train Loss : 0.322259, Test Loss : 0.410014, Train Acc : 93.750000, Test Acc : 87.024457
# Best Model Saved
# Iteration : 121 - Train Loss : 0.629179, Test Loss : 0.387237, Train Acc : 71.875000, Test Acc : 88.247283
# Best Model Saved
# Iteration : 126 - Train Loss : 0.917368, Test Loss : 0.374215, Train Acc : 71.875000, Test Acc : 87.907609
# Best Model Saved
# Iteration : 131 - Train Loss : 0.344703, Test Loss : 0.425834, Train Acc : 90.625000, Test Acc : 87.975543
# Iteration : 136 - Train Loss : 1.251008, Test Loss : 0.445134, Train Acc : 71.875000, Test Acc : 86.752717

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='vgg11', num_classes=157)
model.model.load_state_dict(torch.load('./4_130.pt'))
model.model.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=157, bias=True)
#   )
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./vgg11_ImageNetStat_4_130_threshno.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    6.690457e-02  7.376035e-01  ...  3.239124e-06  1.466208e-06
# 1    8.108421e-12  6.525623e-10  ...  1.046522e-14  3.476962e-15
# 2    9.832866e-11  9.702067e-08  ...  9.737284e-12  4.492463e-13
# 3    2.983491e-10  3.013989e-07  ...  4.577166e-11  1.856915e-12
# 4    2.733253e-08  2.456597e-05  ...  1.773846e-06  1.851232e-08
# ..            ...           ...  ...           ...           ...
# 212  3.988314e-05  2.073675e-04  ...  1.800643e-02  8.674045e-04
# 213  8.982739e-12  5.720499e-10  ...  3.767434e-03  4.263088e-08
# 214  7.255812e-14  2.220819e-10  ...  9.988543e-01  5.195790e-09
# 215  3.886675e-10  2.159507e-07  ...  9.916649e-01  1.550300e-07
# 216  1.725681e-11  1.034019e-09  ...  1.544949e-05  4.936863e-01
#
# [217 rows x 157 columns]
