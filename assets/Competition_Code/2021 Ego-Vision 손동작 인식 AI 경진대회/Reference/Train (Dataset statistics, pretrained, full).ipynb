# %%
from dataset import *
from train import *

import matplotlib.pyplot as plt

import torch, torchvision
import torchvision.transforms as transforms

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
batch_size = 32


train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.3005, 0.3035, 0.2712], std=[0.1519, 0.1252, 0.0996])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.3005, 0.3035, 0.2712], std=[0.1519, 0.1252, 0.0996])])


train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='resnet18', num_classes=157, save=True)

# %%
epochs = 7
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.249459, Test Loss : 5.109067, Train Acc : 0.000000, Test Acc : 2.864939
# Best Model Saved
# Iteration : 11 - Train Loss : 4.031849, Test Loss : 4.672749, Train Acc : 31.250000, Test Acc : 12.960437
# Best Model Saved
# Iteration : 21 - Train Loss : 3.815476, Test Loss : 3.549507, Train Acc : 25.000000, Test Acc : 23.465211
# Best Model Saved
# Iteration : 31 - Train Loss : 3.064058, Test Loss : 2.919316, Train Acc : 43.750000, Test Acc : 41.746248
# Best Model Saved
# Iteration : 41 - Train Loss : 2.386063, Test Loss : 2.553350, Train Acc : 46.875000, Test Acc : 42.769441
# Best Model Saved
# Iteration : 51 - Train Loss : 1.837353, Test Loss : 1.901541, Train Acc : 65.625000, Test Acc : 54.365621
# Best Model Saved
# Iteration : 61 - Train Loss : 1.884588, Test Loss : 1.891347, Train Acc : 68.750000, Test Acc : 61.050477
# Best Model Saved
# Iteration : 71 - Train Loss : 1.823428, Test Loss : 1.497376, Train Acc : 50.000000, Test Acc : 67.189632
# Best Model Saved
# Iteration : 81 - Train Loss : 1.391782, Test Loss : 1.092168, Train Acc : 75.000000, Test Acc : 74.556617
# Best Model Saved
# Iteration : 91 - Train Loss : 1.159505, Test Loss : 1.081508, Train Acc : 78.125000, Test Acc : 77.216917
# Best Model Saved
# Iteration : 101 - Train Loss : 1.029654, Test Loss : 0.880454, Train Acc : 68.750000, Test Acc : 80.763984
# Best Model Saved
# Iteration : 111 - Train Loss : 0.855351, Test Loss : 0.742713, Train Acc : 75.000000, Test Acc : 84.856753
# Best Model Saved
# Iteration : 121 - Train Loss : 0.561488, Test Loss : 0.671841, Train Acc : 93.750000, Test Acc : 89.222374
# Iteration : 131 - Train Loss : 0.494871, Test Loss : 0.678619, Train Acc : 96.875000, Test Acc : 87.244202
#
# Epoch 2 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.395220, Test Loss : 0.492409, Train Acc : 93.750000, Test Acc : 92.496589
# Best Model Saved
# Iteration : 11 - Train Loss : 0.415596, Test Loss : 0.452638, Train Acc : 87.500000, Test Acc : 92.564802
# Best Model Saved
# Iteration : 21 - Train Loss : 0.380861, Test Loss : 0.330258, Train Acc : 93.750000, Test Acc : 94.952251
# Iteration : 31 - Train Loss : 0.310992, Test Loss : 0.356454, Train Acc : 96.875000, Test Acc : 92.155525
# Best Model Saved
# Iteration : 41 - Train Loss : 0.204194, Test Loss : 0.287962, Train Acc : 96.875000, Test Acc : 93.587995
# Iteration : 51 - Train Loss : 0.271976, Test Loss : 0.439015, Train Acc : 93.750000, Test Acc : 91.746248
# Best Model Saved
# Iteration : 61 - Train Loss : 0.254284, Test Loss : 0.236560, Train Acc : 90.625000, Test Acc : 95.975443
# Iteration : 71 - Train Loss : 0.183894, Test Loss : 0.270003, Train Acc : 96.875000, Test Acc : 95.497954
# Best Model Saved
# Iteration : 81 - Train Loss : 0.223269, Test Loss : 0.223635, Train Acc : 90.625000, Test Acc : 95.497954
# Best Model Saved
# Iteration : 91 - Train Loss : 0.254625, Test Loss : 0.177010, Train Acc : 90.625000, Test Acc : 96.589359
# Iteration : 101 - Train Loss : 0.197067, Test Loss : 0.193193, Train Acc : 96.875000, Test Acc : 95.907231
# Best Model Saved
# Iteration : 111 - Train Loss : 0.116364, Test Loss : 0.128458, Train Acc : 100.000000, Test Acc : 97.544338
# Iteration : 121 - Train Loss : 0.150252, Test Loss : 0.222277, Train Acc : 96.875000, Test Acc : 96.452933
# Iteration : 131 - Train Loss : 0.124048, Test Loss : 0.208611, Train Acc : 100.000000, Test Acc : 96.180082
#
# Epoch 3 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 0.116589, Test Loss : 0.145689, Train Acc : 96.875000, Test Acc : 97.885402
# Iteration : 11 - Train Loss : 0.207003, Test Loss : 0.229075, Train Acc : 93.750000, Test Acc : 94.611187
# Best Model Saved
# Iteration : 21 - Train Loss : 0.087541, Test Loss : 0.144760, Train Acc : 100.000000, Test Acc : 97.066849
# Best Model Saved
# Iteration : 31 - Train Loss : 0.057733, Test Loss : 0.104599, Train Acc : 100.000000, Test Acc : 98.362892
# Iteration : 41 - Train Loss : 0.069226, Test Loss : 0.417626, Train Acc : 100.000000, Test Acc : 90.723056
# Iteration : 51 - Train Loss : 0.086055, Test Loss : 0.206010, Train Acc : 100.000000, Test Acc : 95.497954
# Iteration : 61 - Train Loss : 0.077474, Test Loss : 0.140761, Train Acc : 100.000000, Test Acc : 97.407913
# Iteration : 71 - Train Loss : 0.077135, Test Loss : 0.159777, Train Acc : 96.875000, Test Acc : 97.135061
# Best Model Saved
# Iteration : 81 - Train Loss : 0.040368, Test Loss : 0.095258, Train Acc : 100.000000, Test Acc : 98.908595
# Iteration : 91 - Train Loss : 0.077378, Test Loss : 0.105525, Train Acc : 100.000000, Test Acc : 98.431105
# Best Model Saved
# Iteration : 101 - Train Loss : 0.043994, Test Loss : 0.082890, Train Acc : 100.000000, Test Acc : 98.567531
# Best Model Saved
# Iteration : 111 - Train Loss : 0.044263, Test Loss : 0.066182, Train Acc : 100.000000, Test Acc : 98.635744
# Best Model Saved
# Iteration : 121 - Train Loss : 0.025541, Test Loss : 0.073376, Train Acc : 100.000000, Test Acc : 99.045020
# Best Model Saved
# Iteration : 131 - Train Loss : 0.027084, Test Loss : 0.043538, Train Acc : 100.000000, Test Acc : 99.454297
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 0.071398, Test Loss : 0.125757, Train Acc : 96.875000, Test Acc : 98.431105
# Iteration : 11 - Train Loss : 0.056602, Test Loss : 0.071710, Train Acc : 100.000000, Test Acc : 98.431105
# Iteration : 21 - Train Loss : 0.044273, Test Loss : 0.053459, Train Acc : 100.000000, Test Acc : 99.113233
# Iteration : 31 - Train Loss : 0.051176, Test Loss : 0.080453, Train Acc : 100.000000, Test Acc : 98.226467
# Iteration : 41 - Train Loss : 0.067665, Test Loss : 0.068307, Train Acc : 100.000000, Test Acc : 99.181446
# Best Model Saved
# Iteration : 51 - Train Loss : 0.039180, Test Loss : 0.040986, Train Acc : 100.000000, Test Acc : 99.727149
# Best Model Saved
# Iteration : 61 - Train Loss : 0.020849, Test Loss : 0.025565, Train Acc : 100.000000, Test Acc : 99.727149
# Iteration : 71 - Train Loss : 0.022558, Test Loss : 0.039574, Train Acc : 100.000000, Test Acc : 99.386085
# Iteration : 81 - Train Loss : 0.028045, Test Loss : 0.057711, Train Acc : 100.000000, Test Acc : 99.113233
# Iteration : 91 - Train Loss : 0.034462, Test Loss : 0.156512, Train Acc : 100.000000, Test Acc : 96.998636
# Iteration : 101 - Train Loss : 0.036505, Test Loss : 0.178145, Train Acc : 100.000000, Test Acc : 95.225102
# Iteration : 111 - Train Loss : 0.160668, Test Loss : 0.170293, Train Acc : 96.875000, Test Acc : 95.975443
# Iteration : 121 - Train Loss : 0.036225, Test Loss : 0.136826, Train Acc : 100.000000, Test Acc : 98.226467
# Iteration : 131 - Train Loss : 0.246590, Test Loss : 0.059260, Train Acc : 93.750000, Test Acc : 99.386085
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 0.032608, Test Loss : 0.074629, Train Acc : 100.000000, Test Acc : 98.772169
# Iteration : 11 - Train Loss : 0.026397, Test Loss : 0.066825, Train Acc : 100.000000, Test Acc : 98.567531
# Iteration : 21 - Train Loss : 0.017664, Test Loss : 0.038085, Train Acc : 100.000000, Test Acc : 99.454297
# Iteration : 31 - Train Loss : 0.022588, Test Loss : 0.043777, Train Acc : 100.000000, Test Acc : 99.317872
# Iteration : 41 - Train Loss : 0.016404, Test Loss : 0.036682, Train Acc : 100.000000, Test Acc : 99.454297
# Best Model Saved
# Iteration : 51 - Train Loss : 0.015088, Test Loss : 0.017475, Train Acc : 100.000000, Test Acc : 99.727149
# Iteration : 61 - Train Loss : 0.011843, Test Loss : 0.025665, Train Acc : 100.000000, Test Acc : 99.249659
# Iteration : 71 - Train Loss : 0.020623, Test Loss : 0.039981, Train Acc : 100.000000, Test Acc : 99.249659
# Iteration : 81 - Train Loss : 0.011675, Test Loss : 0.041522, Train Acc : 100.000000, Test Acc : 99.249659
# Iteration : 91 - Train Loss : 0.208286, Test Loss : 0.056278, Train Acc : 93.750000, Test Acc : 99.113233
# Iteration : 101 - Train Loss : 0.016567, Test Loss : 0.046069, Train Acc : 100.000000, Test Acc : 99.045020
# Iteration : 111 - Train Loss : 0.019126, Test Loss : 0.064431, Train Acc : 100.000000, Test Acc : 98.703956
# Iteration : 121 - Train Loss : 0.097009, Test Loss : 0.103383, Train Acc : 100.000000, Test Acc : 98.772169
# Iteration : 131 - Train Loss : 0.060611, Test Loss : 0.076475, Train Acc : 100.000000, Test Acc : 98.635744
#
# Epoch 6 Started...
# Iteration : 1 - Train Loss : 0.021460, Test Loss : 0.035506, Train Acc : 100.000000, Test Acc : 99.590723
# Iteration : 11 - Train Loss : 0.034810, Test Loss : 0.098241, Train Acc : 100.000000, Test Acc : 98.431105
# Iteration : 21 - Train Loss : 0.022537, Test Loss : 0.050641, Train Acc : 100.000000, Test Acc : 98.635744
# Iteration : 31 - Train Loss : 0.027258, Test Loss : 0.066125, Train Acc : 100.000000, Test Acc : 99.113233
# Iteration : 41 - Train Loss : 0.018709, Test Loss : 0.032934, Train Acc : 100.000000, Test Acc : 99.727149
# Iteration : 51 - Train Loss : 0.009295, Test Loss : 0.062938, Train Acc : 100.000000, Test Acc : 98.976808
# Iteration : 61 - Train Loss : 0.026969, Test Loss : 0.056482, Train Acc : 100.000000, Test Acc : 98.976808
# Iteration : 71 - Train Loss : 0.020239, Test Loss : 0.103091, Train Acc : 100.000000, Test Acc : 97.953615
# Iteration : 81 - Train Loss : 0.232048, Test Loss : 0.071007, Train Acc : 96.875000, Test Acc : 98.158254
# Iteration : 91 - Train Loss : 0.021449, Test Loss : 0.025679, Train Acc : 100.000000, Test Acc : 99.386085
# Iteration : 101 - Train Loss : 0.157737, Test Loss : 0.090866, Train Acc : 96.875000, Test Acc : 98.431105
# Iteration : 111 - Train Loss : 0.045974, Test Loss : 0.136188, Train Acc : 100.000000, Test Acc : 97.817190
# Iteration : 121 - Train Loss : 0.169968, Test Loss : 0.199817, Train Acc : 93.750000, Test Acc : 96.521146
# Iteration : 131 - Train Loss : 0.053533, Test Loss : 0.249429, Train Acc : 100.000000, Test Acc : 95.156889
#
# Epoch 7 Started...
# Iteration : 1 - Train Loss : 0.591787, Test Loss : 0.243058, Train Acc : 90.625000, Test Acc : 95.361528
# Iteration : 11 - Train Loss : 0.173067, Test Loss : 0.416105, Train Acc : 93.750000, Test Acc : 90.586630
# Iteration : 21 - Train Loss : 0.198381, Test Loss : 0.555767, Train Acc : 93.750000, Test Acc : 84.447476
# Iteration : 31 - Train Loss : 0.076575, Test Loss : 0.303800, Train Acc : 96.875000, Test Acc : 91.405184
# Iteration : 41 - Train Loss : 0.114887, Test Loss : 0.183261, Train Acc : 96.875000, Test Acc : 95.770805
# Iteration : 51 - Train Loss : 0.035236, Test Loss : 0.113820, Train Acc : 100.000000, Test Acc : 98.090041
# Iteration : 61 - Train Loss : 0.035566, Test Loss : 0.338134, Train Acc : 100.000000, Test Acc : 92.087312
# Iteration : 71 - Train Loss : 0.058686, Test Loss : 0.402878, Train Acc : 100.000000, Test Acc : 89.699864
# Iteration : 81 - Train Loss : 0.054124, Test Loss : 0.230603, Train Acc : 100.000000, Test Acc : 94.338336
# Iteration : 91 - Train Loss : 0.088116, Test Loss : 0.375529, Train Acc : 96.875000, Test Acc : 91.473397
# Iteration : 101 - Train Loss : 0.092252, Test Loss : 0.319613, Train Acc : 100.000000, Test Acc : 92.360164
# Iteration : 111 - Train Loss : 0.047933, Test Loss : 0.254823, Train Acc : 100.000000, Test Acc : 94.542974
# Iteration : 121 - Train Loss : 0.089953, Test Loss : 0.137273, Train Acc : 96.875000, Test Acc : 96.657572
# Iteration : 131 - Train Loss : 0.135657, Test Loss : 0.090597, Train Acc : 96.875000, Test Acc : 97.680764

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()
