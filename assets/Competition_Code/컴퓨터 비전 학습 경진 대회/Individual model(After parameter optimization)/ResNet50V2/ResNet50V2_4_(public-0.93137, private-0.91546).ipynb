# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/ResNet50V2_4_(public_%2C_private_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Sep 26 09:44:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
model_save = 'ResNet50V2_4'
Target_model = 'ResNet50V2_model'
Target_predict = 'ResNet50V2_predict'
Target_acc = 'ResNet50V2_acc'
Target_val = 'ResNet50V2_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.ResNet50V2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 48s 103ms/step - loss: 1.9249 - accuracy: 0.3416 - val_loss: 9.8269 - val_accuracy: 0.0946
#
# Epoch 00001: val_accuracy improved from -inf to 0.09459, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 23s 98ms/step - loss: 1.2921 - accuracy: 0.5626 - val_loss: 4.4812 - val_accuracy: 0.3378
#
# Epoch 00002: val_accuracy improved from 0.09459 to 0.33784, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 3/500
# 238/238 [==============================] - 24s 101ms/step - loss: 1.0608 - accuracy: 0.6489 - val_loss: 7.2413 - val_accuracy: 0.1824
#
# Epoch 00003: val_accuracy did not improve from 0.33784
# Epoch 4/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.9956 - accuracy: 0.6663 - val_loss: 2.1433 - val_accuracy: 0.4662
#
# Epoch 00004: val_accuracy improved from 0.33784 to 0.46622, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 5/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.8715 - accuracy: 0.6995 - val_loss: 1.3381 - val_accuracy: 0.6351
#
# Epoch 00005: val_accuracy improved from 0.46622 to 0.63514, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 6/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.7935 - accuracy: 0.7263 - val_loss: 1.6619 - val_accuracy: 0.5473
#
# Epoch 00006: val_accuracy did not improve from 0.63514
# Epoch 7/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.7036 - accuracy: 0.7637 - val_loss: 0.8747 - val_accuracy: 0.7568
#
# Epoch 00007: val_accuracy improved from 0.63514 to 0.75676, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 8/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.6938 - accuracy: 0.7784 - val_loss: 6.2570 - val_accuracy: 0.1284
#
# Epoch 00008: val_accuracy did not improve from 0.75676
# Epoch 9/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.6976 - accuracy: 0.7721 - val_loss: 0.4995 - val_accuracy: 0.8378
#
# Epoch 00009: val_accuracy improved from 0.75676 to 0.83784, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 10/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.5896 - accuracy: 0.8047 - val_loss: 0.5494 - val_accuracy: 0.8108
#
# Epoch 00010: val_accuracy did not improve from 0.83784
# Epoch 11/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.5233 - accuracy: 0.8268 - val_loss: 0.7072 - val_accuracy: 0.7973
#
# Epoch 00011: val_accuracy did not improve from 0.83784
# Epoch 12/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.5483 - accuracy: 0.8095 - val_loss: 1.5663 - val_accuracy: 0.5676
#
# Epoch 00012: val_accuracy did not improve from 0.83784
# Epoch 13/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.5443 - accuracy: 0.8068 - val_loss: 1.1289 - val_accuracy: 0.6959
#
# Epoch 00013: val_accuracy did not improve from 0.83784
# Epoch 14/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.4574 - accuracy: 0.8458 - val_loss: 0.9111 - val_accuracy: 0.7162
#
# Epoch 00014: val_accuracy did not improve from 0.83784
# Epoch 15/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.4619 - accuracy: 0.8447 - val_loss: 0.5445 - val_accuracy: 0.8378
#
# Epoch 00015: val_accuracy did not improve from 0.83784
# Epoch 16/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.4511 - accuracy: 0.8558 - val_loss: 2.9447 - val_accuracy: 0.4257
#
# Epoch 00016: val_accuracy did not improve from 0.83784
# Epoch 17/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.4289 - accuracy: 0.8532 - val_loss: 0.6691 - val_accuracy: 0.7905
#
# Epoch 00017: val_accuracy did not improve from 0.83784
# Epoch 18/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.4463 - accuracy: 0.8532 - val_loss: 2.8592 - val_accuracy: 0.4595
#
# Epoch 00018: val_accuracy did not improve from 0.83784
# Epoch 19/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3738 - accuracy: 0.8768 - val_loss: 0.6972 - val_accuracy: 0.7973
#
# Epoch 00019: val_accuracy did not improve from 0.83784
# Epoch 20/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.3856 - accuracy: 0.8732 - val_loss: 0.5151 - val_accuracy: 0.8041
#
# Epoch 00020: val_accuracy did not improve from 0.83784
# Epoch 21/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3611 - accuracy: 0.8753 - val_loss: 0.6935 - val_accuracy: 0.8041
#
# Epoch 00021: val_accuracy did not improve from 0.83784
# Epoch 22/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3556 - accuracy: 0.8821 - val_loss: 0.7106 - val_accuracy: 0.8176
#
# Epoch 00022: val_accuracy did not improve from 0.83784
# Epoch 23/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.2805 - accuracy: 0.9100 - val_loss: 0.4280 - val_accuracy: 0.8378
#
# Epoch 00023: val_accuracy did not improve from 0.83784
# Epoch 24/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3478 - accuracy: 0.8895 - val_loss: 0.5862 - val_accuracy: 0.8311
#
# Epoch 00024: val_accuracy did not improve from 0.83784
# Epoch 25/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3312 - accuracy: 0.8989 - val_loss: 0.6077 - val_accuracy: 0.8176
#
# Epoch 00025: val_accuracy did not improve from 0.83784
# Epoch 26/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.2688 - accuracy: 0.9074 - val_loss: 0.4214 - val_accuracy: 0.8649
#
# Epoch 00026: val_accuracy improved from 0.83784 to 0.86486, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 27/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3115 - accuracy: 0.8932 - val_loss: 0.6605 - val_accuracy: 0.8108
#
# Epoch 00027: val_accuracy did not improve from 0.86486
# Epoch 28/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.2681 - accuracy: 0.9137 - val_loss: 0.4302 - val_accuracy: 0.8716
#
# Epoch 00028: val_accuracy improved from 0.86486 to 0.87162, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 29/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.2364 - accuracy: 0.9195 - val_loss: 0.6293 - val_accuracy: 0.8176
#
# Epoch 00029: val_accuracy did not improve from 0.87162
# Epoch 30/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.2544 - accuracy: 0.9116 - val_loss: 0.3360 - val_accuracy: 0.8784
#
# Epoch 00030: val_accuracy improved from 0.87162 to 0.87838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 31/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.3056 - accuracy: 0.8968 - val_loss: 0.9052 - val_accuracy: 0.7500
#
# Epoch 00031: val_accuracy did not improve from 0.87838
# Epoch 32/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.2000 - accuracy: 0.9289 - val_loss: 0.6983 - val_accuracy: 0.8176
#
# Epoch 00032: val_accuracy did not improve from 0.87838
# Epoch 33/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.2434 - accuracy: 0.9174 - val_loss: 0.3793 - val_accuracy: 0.8784
#
# Epoch 00033: val_accuracy did not improve from 0.87838
# Epoch 34/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1912 - accuracy: 0.9332 - val_loss: 0.4264 - val_accuracy: 0.8716
#
# Epoch 00034: val_accuracy did not improve from 0.87838
# Epoch 35/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.2137 - accuracy: 0.9274 - val_loss: 0.3213 - val_accuracy: 0.8784
#
# Epoch 00035: val_accuracy did not improve from 0.87838
# Epoch 36/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.2536 - accuracy: 0.9221 - val_loss: 0.3891 - val_accuracy: 0.8784
#
# Epoch 00036: val_accuracy did not improve from 0.87838
# Epoch 37/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1492 - accuracy: 0.9495 - val_loss: 0.3911 - val_accuracy: 0.8649
#
# Epoch 00037: val_accuracy did not improve from 0.87838
# Epoch 38/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1590 - accuracy: 0.9474 - val_loss: 0.4541 - val_accuracy: 0.8446
#
# Epoch 00038: val_accuracy did not improve from 0.87838
# Epoch 39/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.2139 - accuracy: 0.9232 - val_loss: 0.4117 - val_accuracy: 0.8851
#
# Epoch 00039: val_accuracy improved from 0.87838 to 0.88514, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 40/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1862 - accuracy: 0.9374 - val_loss: 0.4244 - val_accuracy: 0.8919
#
# Epoch 00040: val_accuracy improved from 0.88514 to 0.89189, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 41/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.1700 - accuracy: 0.9447 - val_loss: 0.4795 - val_accuracy: 0.8784
#
# Epoch 00041: val_accuracy did not improve from 0.89189
# Epoch 42/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.2261 - accuracy: 0.9295 - val_loss: 0.4084 - val_accuracy: 0.8716
#
# Epoch 00042: val_accuracy did not improve from 0.89189
# Epoch 43/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.1445 - accuracy: 0.9542 - val_loss: 0.4893 - val_accuracy: 0.8649
#
# Epoch 00043: val_accuracy did not improve from 0.89189
# Epoch 44/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1481 - accuracy: 0.9495 - val_loss: 0.5619 - val_accuracy: 0.8446
#
# Epoch 00044: val_accuracy did not improve from 0.89189
# Epoch 45/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1553 - accuracy: 0.9468 - val_loss: 0.6292 - val_accuracy: 0.8514
#
# Epoch 00045: val_accuracy did not improve from 0.89189
# Epoch 46/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1312 - accuracy: 0.9521 - val_loss: 0.2832 - val_accuracy: 0.9054
#
# Epoch 00046: val_accuracy improved from 0.89189 to 0.90541, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 47/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1219 - accuracy: 0.9553 - val_loss: 0.4701 - val_accuracy: 0.8311
#
# Epoch 00047: val_accuracy did not improve from 0.90541
# Epoch 48/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.1526 - accuracy: 0.9447 - val_loss: 0.3000 - val_accuracy: 0.8919
#
# Epoch 00048: val_accuracy did not improve from 0.90541
# Epoch 49/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1170 - accuracy: 0.9632 - val_loss: 0.3538 - val_accuracy: 0.8919
#
# Epoch 00049: val_accuracy did not improve from 0.90541
# Epoch 50/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1433 - accuracy: 0.9516 - val_loss: 0.6467 - val_accuracy: 0.8243
#
# Epoch 00050: val_accuracy did not improve from 0.90541
# Epoch 51/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1431 - accuracy: 0.9537 - val_loss: 0.4813 - val_accuracy: 0.8581
#
# Epoch 00051: val_accuracy did not improve from 0.90541
# Epoch 52/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1395 - accuracy: 0.9526 - val_loss: 0.3380 - val_accuracy: 0.8986
#
# Epoch 00052: val_accuracy did not improve from 0.90541
# Epoch 53/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1132 - accuracy: 0.9589 - val_loss: 0.3305 - val_accuracy: 0.9054
#
# Epoch 00053: val_accuracy did not improve from 0.90541
# Epoch 54/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1505 - accuracy: 0.9505 - val_loss: 0.3983 - val_accuracy: 0.9054
#
# Epoch 00054: val_accuracy did not improve from 0.90541
# Epoch 55/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1082 - accuracy: 0.9600 - val_loss: 0.5884 - val_accuracy: 0.8716
#
# Epoch 00055: val_accuracy did not improve from 0.90541
# Epoch 56/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0999 - accuracy: 0.9663 - val_loss: 0.4734 - val_accuracy: 0.8986
#
# Epoch 00056: val_accuracy did not improve from 0.90541
# Epoch 57/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0992 - accuracy: 0.9663 - val_loss: 0.4516 - val_accuracy: 0.8784
#
# Epoch 00057: val_accuracy did not improve from 0.90541
# Epoch 58/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1025 - accuracy: 0.9674 - val_loss: 1.6493 - val_accuracy: 0.6689
#
# Epoch 00058: val_accuracy did not improve from 0.90541
# Epoch 59/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1049 - accuracy: 0.9647 - val_loss: 8.9748 - val_accuracy: 0.2365
#
# Epoch 00059: val_accuracy did not improve from 0.90541
# Epoch 60/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0703 - accuracy: 0.9726 - val_loss: 0.5244 - val_accuracy: 0.8649
#
# Epoch 00060: val_accuracy did not improve from 0.90541
# Epoch 61/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1075 - accuracy: 0.9653 - val_loss: 0.4906 - val_accuracy: 0.8851
#
# Epoch 00061: val_accuracy did not improve from 0.90541
# Epoch 62/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0904 - accuracy: 0.9700 - val_loss: 0.4595 - val_accuracy: 0.8716
#
# Epoch 00062: val_accuracy did not improve from 0.90541
# Epoch 63/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1327 - accuracy: 0.9532 - val_loss: 0.5164 - val_accuracy: 0.8581
#
# Epoch 00063: val_accuracy did not improve from 0.90541
# Epoch 64/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0497 - accuracy: 0.9816 - val_loss: 0.4410 - val_accuracy: 0.8986
#
# Epoch 00064: val_accuracy did not improve from 0.90541
# Epoch 65/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0354 - accuracy: 0.9889 - val_loss: 0.5285 - val_accuracy: 0.8514
#
# Epoch 00065: val_accuracy did not improve from 0.90541
# Epoch 66/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0949 - accuracy: 0.9668 - val_loss: 0.4698 - val_accuracy: 0.8784
#
# Epoch 00066: val_accuracy did not improve from 0.90541
# Epoch 67/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0989 - accuracy: 0.9674 - val_loss: 0.7996 - val_accuracy: 0.8514
#
# Epoch 00067: val_accuracy did not improve from 0.90541
# Epoch 68/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1094 - accuracy: 0.9611 - val_loss: 0.3530 - val_accuracy: 0.9054
#
# Epoch 00068: val_accuracy did not improve from 0.90541
# Epoch 69/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0747 - accuracy: 0.9753 - val_loss: 0.4310 - val_accuracy: 0.8851
#
# Epoch 00069: val_accuracy did not improve from 0.90541
# Epoch 70/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.1117 - accuracy: 0.9584 - val_loss: 0.5628 - val_accuracy: 0.8716
#
# Epoch 00070: val_accuracy did not improve from 0.90541
# Epoch 71/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0862 - accuracy: 0.9700 - val_loss: 0.3315 - val_accuracy: 0.9054
#
# Epoch 00071: val_accuracy did not improve from 0.90541
# Epoch 72/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0609 - accuracy: 0.9816 - val_loss: 0.4715 - val_accuracy: 0.8784
#
# Epoch 00072: val_accuracy did not improve from 0.90541
# Epoch 73/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0576 - accuracy: 0.9795 - val_loss: 0.2783 - val_accuracy: 0.9257
#
# Epoch 00073: val_accuracy improved from 0.90541 to 0.92568, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 74/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0708 - accuracy: 0.9747 - val_loss: 0.6097 - val_accuracy: 0.8851
#
# Epoch 00074: val_accuracy did not improve from 0.92568
# Epoch 75/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0799 - accuracy: 0.9758 - val_loss: 0.2689 - val_accuracy: 0.9324
#
# Epoch 00075: val_accuracy improved from 0.92568 to 0.93243, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 76/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0674 - accuracy: 0.9784 - val_loss: 2.0198 - val_accuracy: 0.6216
#
# Epoch 00076: val_accuracy did not improve from 0.93243
# Epoch 77/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0671 - accuracy: 0.9779 - val_loss: 0.4129 - val_accuracy: 0.9122
#
# Epoch 00077: val_accuracy did not improve from 0.93243
# Epoch 78/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0645 - accuracy: 0.9821 - val_loss: 0.4795 - val_accuracy: 0.8649
#
# Epoch 00078: val_accuracy did not improve from 0.93243
# Epoch 79/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0649 - accuracy: 0.9774 - val_loss: 0.5664 - val_accuracy: 0.8716
#
# Epoch 00079: val_accuracy did not improve from 0.93243
# Epoch 80/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.1000 - accuracy: 0.9647 - val_loss: 0.4586 - val_accuracy: 0.8851
#
# Epoch 00080: val_accuracy did not improve from 0.93243
# Epoch 81/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0525 - accuracy: 0.9789 - val_loss: 0.4605 - val_accuracy: 0.9189
#
# Epoch 00081: val_accuracy did not improve from 0.93243
# Epoch 82/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0621 - accuracy: 0.9805 - val_loss: 0.5398 - val_accuracy: 0.8446
#
# Epoch 00082: val_accuracy did not improve from 0.93243
# Epoch 83/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0617 - accuracy: 0.9826 - val_loss: 0.4521 - val_accuracy: 0.8514
#
# Epoch 00083: val_accuracy did not improve from 0.93243
# Epoch 84/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0581 - accuracy: 0.9816 - val_loss: 0.6439 - val_accuracy: 0.8243
#
# Epoch 00084: val_accuracy did not improve from 0.93243
# Epoch 85/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0480 - accuracy: 0.9858 - val_loss: 0.6184 - val_accuracy: 0.8784
#
# Epoch 00085: val_accuracy did not improve from 0.93243
# Epoch 86/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0592 - accuracy: 0.9784 - val_loss: 0.7248 - val_accuracy: 0.8446
#
# Epoch 00086: val_accuracy did not improve from 0.93243
# Epoch 87/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0799 - accuracy: 0.9679 - val_loss: 0.5355 - val_accuracy: 0.8716
#
# Epoch 00087: val_accuracy did not improve from 0.93243
# Epoch 88/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0358 - accuracy: 0.9900 - val_loss: 0.4520 - val_accuracy: 0.8986
#
# Epoch 00088: val_accuracy did not improve from 0.93243
# Epoch 89/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0394 - accuracy: 0.9905 - val_loss: 0.4720 - val_accuracy: 0.8919
#
# Epoch 00089: val_accuracy did not improve from 0.93243
# Epoch 90/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0470 - accuracy: 0.9826 - val_loss: 0.5451 - val_accuracy: 0.8649
#
# Epoch 00090: val_accuracy did not improve from 0.93243
# Epoch 91/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0523 - accuracy: 0.9821 - val_loss: 0.4295 - val_accuracy: 0.8851
#
# Epoch 00091: val_accuracy did not improve from 0.93243
# Epoch 92/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0624 - accuracy: 0.9805 - val_loss: 0.5523 - val_accuracy: 0.8581
#
# Epoch 00092: val_accuracy did not improve from 0.93243
# Epoch 93/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0969 - accuracy: 0.9647 - val_loss: 0.5093 - val_accuracy: 0.8851
#
# Epoch 00093: val_accuracy did not improve from 0.93243
# Epoch 94/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0529 - accuracy: 0.9816 - val_loss: 0.4021 - val_accuracy: 0.9122
#
# Epoch 00094: val_accuracy did not improve from 0.93243
# Epoch 95/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0512 - accuracy: 0.9832 - val_loss: 0.5923 - val_accuracy: 0.8716
#
# Epoch 00095: val_accuracy did not improve from 0.93243
# Epoch 96/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0707 - accuracy: 0.9753 - val_loss: 0.7015 - val_accuracy: 0.8649
#
# Epoch 00096: val_accuracy did not improve from 0.93243
# Epoch 97/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.4732 - val_accuracy: 0.8919
#
# Epoch 00097: val_accuracy did not improve from 0.93243
# Epoch 98/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0392 - accuracy: 0.9858 - val_loss: 0.7344 - val_accuracy: 0.8176
#
# Epoch 00098: val_accuracy did not improve from 0.93243
# Epoch 99/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0466 - accuracy: 0.9842 - val_loss: 0.6091 - val_accuracy: 0.8446
#
# Epoch 00099: val_accuracy did not improve from 0.93243
# Epoch 100/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0602 - accuracy: 0.9768 - val_loss: 0.6160 - val_accuracy: 0.8649
#
# Epoch 00100: val_accuracy did not improve from 0.93243
# Epoch 101/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0499 - accuracy: 0.9837 - val_loss: 0.3053 - val_accuracy: 0.9324
#
# Epoch 00101: val_accuracy did not improve from 0.93243
# Epoch 102/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0430 - accuracy: 0.9858 - val_loss: 0.4477 - val_accuracy: 0.8986
#
# Epoch 00102: val_accuracy did not improve from 0.93243
# Epoch 103/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0229 - accuracy: 0.9916 - val_loss: 0.5149 - val_accuracy: 0.8919
#
# Epoch 00103: val_accuracy did not improve from 0.93243
# Epoch 104/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0331 - accuracy: 0.9863 - val_loss: 0.4933 - val_accuracy: 0.8514
#
# Epoch 00104: val_accuracy did not improve from 0.93243
# Epoch 105/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0545 - accuracy: 0.9842 - val_loss: 0.5153 - val_accuracy: 0.8581
#
# Epoch 00105: val_accuracy did not improve from 0.93243
# Epoch 106/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0468 - accuracy: 0.9863 - val_loss: 0.5558 - val_accuracy: 0.8851
#
# Epoch 00106: val_accuracy did not improve from 0.93243
# Epoch 107/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0409 - accuracy: 0.9858 - val_loss: 0.5539 - val_accuracy: 0.8716
#
# Epoch 00107: val_accuracy did not improve from 0.93243
# Epoch 108/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.5513 - val_accuracy: 0.8446
#
# Epoch 00108: val_accuracy did not improve from 0.93243
# Epoch 109/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0465 - accuracy: 0.9858 - val_loss: 0.6444 - val_accuracy: 0.8851
#
# Epoch 00109: val_accuracy did not improve from 0.93243
# Epoch 110/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0678 - accuracy: 0.9800 - val_loss: 0.6151 - val_accuracy: 0.8716
#
# Epoch 00110: val_accuracy did not improve from 0.93243
# Epoch 111/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0371 - accuracy: 0.9868 - val_loss: 0.5429 - val_accuracy: 0.8851
#
# Epoch 00111: val_accuracy did not improve from 0.93243
# Epoch 112/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0316 - accuracy: 0.9916 - val_loss: 0.5119 - val_accuracy: 0.8649
#
# Epoch 00112: val_accuracy did not improve from 0.93243
# Epoch 113/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0485 - accuracy: 0.9868 - val_loss: 0.6597 - val_accuracy: 0.8446
#
# Epoch 00113: val_accuracy did not improve from 0.93243
# Epoch 114/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0489 - accuracy: 0.9853 - val_loss: 0.4969 - val_accuracy: 0.8784
#
# Epoch 00114: val_accuracy did not improve from 0.93243
# Epoch 115/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0394 - accuracy: 0.9879 - val_loss: 0.5264 - val_accuracy: 0.8784
#
# Epoch 00115: val_accuracy did not improve from 0.93243
# Epoch 116/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0358 - accuracy: 0.9895 - val_loss: 0.4580 - val_accuracy: 0.8919
#
# Epoch 00116: val_accuracy did not improve from 0.93243
# Epoch 117/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0309 - accuracy: 0.9900 - val_loss: 0.5774 - val_accuracy: 0.8649
#
# Epoch 00117: val_accuracy did not improve from 0.93243
# Epoch 118/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0548 - accuracy: 0.9800 - val_loss: 0.3465 - val_accuracy: 0.8986
#
# Epoch 00118: val_accuracy did not improve from 0.93243
# Epoch 119/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0370 - accuracy: 0.9889 - val_loss: 0.4125 - val_accuracy: 0.9054
#
# Epoch 00119: val_accuracy did not improve from 0.93243
# Epoch 120/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0502 - accuracy: 0.9863 - val_loss: 0.6360 - val_accuracy: 0.8716
#
# Epoch 00120: val_accuracy did not improve from 0.93243
# Epoch 121/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.5091 - val_accuracy: 0.9054
#
# Epoch 00121: val_accuracy did not improve from 0.93243
# Epoch 122/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.5309 - val_accuracy: 0.8851
#
# Epoch 00122: val_accuracy did not improve from 0.93243
# Epoch 123/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0286 - accuracy: 0.9889 - val_loss: 0.5698 - val_accuracy: 0.8919
#
# Epoch 00123: val_accuracy did not improve from 0.93243
# Epoch 124/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 0.4534 - val_accuracy: 0.8851
#
# Epoch 00124: val_accuracy did not improve from 0.93243
# Epoch 125/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0446 - accuracy: 0.9821 - val_loss: 0.4806 - val_accuracy: 0.8919
#
# Epoch 00125: val_accuracy did not improve from 0.93243
# Epoch 126/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0444 - accuracy: 0.9842 - val_loss: 0.4472 - val_accuracy: 0.8919
#
# Epoch 00126: val_accuracy did not improve from 0.93243
# Epoch 127/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.5686 - val_accuracy: 0.8716
#
# Epoch 00127: val_accuracy did not improve from 0.93243
# Epoch 128/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0682 - accuracy: 0.9805 - val_loss: 0.5394 - val_accuracy: 0.8784
#
# Epoch 00128: val_accuracy did not improve from 0.93243
# Epoch 129/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0355 - accuracy: 0.9905 - val_loss: 0.7187 - val_accuracy: 0.8041
#
# Epoch 00129: val_accuracy did not improve from 0.93243
# Epoch 130/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0416 - accuracy: 0.9837 - val_loss: 0.3798 - val_accuracy: 0.9054
#
# Epoch 00130: val_accuracy did not improve from 0.93243
# Epoch 131/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0262 - accuracy: 0.9911 - val_loss: 0.5474 - val_accuracy: 0.8784
#
# Epoch 00131: val_accuracy did not improve from 0.93243
# Epoch 132/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0262 - accuracy: 0.9932 - val_loss: 0.6653 - val_accuracy: 0.8851
#
# Epoch 00132: val_accuracy did not improve from 0.93243
# Epoch 133/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0890 - accuracy: 0.9732 - val_loss: 0.5305 - val_accuracy: 0.8851
#
# Epoch 00133: val_accuracy did not improve from 0.93243
# Epoch 134/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0241 - accuracy: 0.9911 - val_loss: 0.3544 - val_accuracy: 0.9122
#
# Epoch 00134: val_accuracy did not improve from 0.93243
# Epoch 135/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0177 - accuracy: 0.9926 - val_loss: 0.4797 - val_accuracy: 0.8986
#
# Epoch 00135: val_accuracy did not improve from 0.93243
# Epoch 136/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0294 - accuracy: 0.9895 - val_loss: 0.7369 - val_accuracy: 0.8243
#
# Epoch 00136: val_accuracy did not improve from 0.93243
# Epoch 137/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.4596 - val_accuracy: 0.9054
#
# Epoch 00137: val_accuracy did not improve from 0.93243
# Epoch 138/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.4108 - val_accuracy: 0.9054
#
# Epoch 00138: val_accuracy did not improve from 0.93243
# Epoch 139/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0256 - accuracy: 0.9900 - val_loss: 0.5127 - val_accuracy: 0.8784
#
# Epoch 00139: val_accuracy did not improve from 0.93243
# Epoch 140/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0345 - accuracy: 0.9863 - val_loss: 0.3816 - val_accuracy: 0.9257
#
# Epoch 00140: val_accuracy did not improve from 0.93243
# Epoch 141/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.2669 - val_accuracy: 0.8986
#
# Epoch 00141: val_accuracy did not improve from 0.93243
# Epoch 142/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.4579 - val_accuracy: 0.8919
#
# Epoch 00142: val_accuracy did not improve from 0.93243
# Epoch 143/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0468 - accuracy: 0.9832 - val_loss: 0.4832 - val_accuracy: 0.9189
#
# Epoch 00143: val_accuracy did not improve from 0.93243
# Epoch 144/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0651 - accuracy: 0.9863 - val_loss: 0.9520 - val_accuracy: 0.8311
#
# Epoch 00144: val_accuracy did not improve from 0.93243
# Epoch 145/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0651 - accuracy: 0.9816 - val_loss: 0.5476 - val_accuracy: 0.8784
#
# Epoch 00145: val_accuracy did not improve from 0.93243
# Epoch 146/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0243 - accuracy: 0.9905 - val_loss: 0.4327 - val_accuracy: 0.8986
#
# Epoch 00146: val_accuracy did not improve from 0.93243
# Epoch 147/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0243 - accuracy: 0.9911 - val_loss: 0.4186 - val_accuracy: 0.9054
#
# Epoch 00147: val_accuracy did not improve from 0.93243
# Epoch 148/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0262 - accuracy: 0.9900 - val_loss: 0.5041 - val_accuracy: 0.8986
#
# Epoch 00148: val_accuracy did not improve from 0.93243
# Epoch 149/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 0.4424 - val_accuracy: 0.9189
#
# Epoch 00149: val_accuracy did not improve from 0.93243
# Epoch 150/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.8617 - val_accuracy: 0.8514
#
# Epoch 00150: val_accuracy did not improve from 0.93243
# Epoch 151/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.5602 - val_accuracy: 0.8784
#
# Epoch 00151: val_accuracy did not improve from 0.93243
# Epoch 152/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.4773 - val_accuracy: 0.8919
#
# Epoch 00152: val_accuracy did not improve from 0.93243
# Epoch 153/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.6205 - val_accuracy: 0.8784
#
# Epoch 00153: val_accuracy did not improve from 0.93243
# Epoch 154/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0319 - accuracy: 0.9874 - val_loss: 0.4690 - val_accuracy: 0.8986
#
# Epoch 00154: val_accuracy did not improve from 0.93243
# Epoch 155/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0182 - accuracy: 0.9953 - val_loss: 0.4033 - val_accuracy: 0.9122
#
# Epoch 00155: val_accuracy did not improve from 0.93243
# Epoch 156/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.4691 - val_accuracy: 0.8851
#
# Epoch 00156: val_accuracy did not improve from 0.93243
# Epoch 157/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0175 - accuracy: 0.9932 - val_loss: 0.4016 - val_accuracy: 0.8986
#
# Epoch 00157: val_accuracy did not improve from 0.93243
# Epoch 158/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0427 - accuracy: 0.9816 - val_loss: 0.3956 - val_accuracy: 0.9189
#
# Epoch 00158: val_accuracy did not improve from 0.93243
# Epoch 159/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0205 - accuracy: 0.9942 - val_loss: 0.4748 - val_accuracy: 0.8851
#
# Epoch 00159: val_accuracy did not improve from 0.93243
# Epoch 160/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.4848 - val_accuracy: 0.8919
#
# Epoch 00160: val_accuracy did not improve from 0.93243
# Epoch 161/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0363 - accuracy: 0.9879 - val_loss: 0.9697 - val_accuracy: 0.8514
#
# Epoch 00161: val_accuracy did not improve from 0.93243
# Epoch 162/500
# 238/238 [==============================] - 24s 101ms/step - loss: 0.0406 - accuracy: 0.9858 - val_loss: 0.4024 - val_accuracy: 0.9189
#
# Epoch 00162: val_accuracy did not improve from 0.93243
# Epoch 163/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.8496 - val_accuracy: 0.8649
#
# Epoch 00163: val_accuracy did not improve from 0.93243
# Epoch 164/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0328 - accuracy: 0.9905 - val_loss: 0.5665 - val_accuracy: 0.8716
#
# Epoch 00164: val_accuracy did not improve from 0.93243
# Epoch 165/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.5615 - val_accuracy: 0.8649
#
# Epoch 00165: val_accuracy did not improve from 0.93243
# Epoch 166/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0220 - accuracy: 0.9947 - val_loss: 0.5389 - val_accuracy: 0.8649
#
# Epoch 00166: val_accuracy did not improve from 0.93243
# Epoch 167/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 0.4751 - val_accuracy: 0.9122
#
# Epoch 00167: val_accuracy did not improve from 0.93243
# Epoch 168/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0229 - accuracy: 0.9937 - val_loss: 0.5237 - val_accuracy: 0.8986
#
# Epoch 00168: val_accuracy did not improve from 0.93243
# Epoch 169/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0209 - accuracy: 0.9958 - val_loss: 0.3727 - val_accuracy: 0.9122
#
# Epoch 00169: val_accuracy did not improve from 0.93243
# Epoch 170/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0270 - accuracy: 0.9921 - val_loss: 0.8842 - val_accuracy: 0.8378
#
# Epoch 00170: val_accuracy did not improve from 0.93243
# Epoch 171/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0494 - accuracy: 0.9858 - val_loss: 0.6232 - val_accuracy: 0.8784
#
# Epoch 00171: val_accuracy did not improve from 0.93243
# Epoch 172/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0282 - accuracy: 0.9916 - val_loss: 0.4475 - val_accuracy: 0.8919
#
# Epoch 00172: val_accuracy did not improve from 0.93243
# Epoch 173/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.5984 - val_accuracy: 0.8919
#
# Epoch 00173: val_accuracy did not improve from 0.93243
# Epoch 174/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0311 - accuracy: 0.9900 - val_loss: 0.5648 - val_accuracy: 0.8716
#
# Epoch 00174: val_accuracy did not improve from 0.93243
# Epoch 175/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0209 - accuracy: 0.9921 - val_loss: 0.4552 - val_accuracy: 0.9054
#
# Epoch 00175: val_accuracy did not improve from 0.93243
# Epoch 176/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.5697 - val_accuracy: 0.8851
#
# Epoch 00176: val_accuracy did not improve from 0.93243
# Epoch 177/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0179 - accuracy: 0.9926 - val_loss: 0.7202 - val_accuracy: 0.8919
#
# Epoch 00177: val_accuracy did not improve from 0.93243
# Epoch 178/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0177 - accuracy: 0.9926 - val_loss: 0.5559 - val_accuracy: 0.8851
#
# Epoch 00178: val_accuracy did not improve from 0.93243
# Epoch 179/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 0.5908 - val_accuracy: 0.8649
#
# Epoch 00179: val_accuracy did not improve from 0.93243
# Epoch 180/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0318 - accuracy: 0.9905 - val_loss: 0.4592 - val_accuracy: 0.8784
#
# Epoch 00180: val_accuracy did not improve from 0.93243
# Epoch 181/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0375 - accuracy: 0.9895 - val_loss: 0.4325 - val_accuracy: 0.8784
#
# Epoch 00181: val_accuracy did not improve from 0.93243
# Epoch 182/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0279 - accuracy: 0.9895 - val_loss: 0.6160 - val_accuracy: 0.8784
#
# Epoch 00182: val_accuracy did not improve from 0.93243
# Epoch 183/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0172 - accuracy: 0.9932 - val_loss: 0.4472 - val_accuracy: 0.8986
#
# Epoch 00183: val_accuracy did not improve from 0.93243
# Epoch 184/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0196 - accuracy: 0.9958 - val_loss: 0.4443 - val_accuracy: 0.9054
#
# Epoch 00184: val_accuracy did not improve from 0.93243
# Epoch 185/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0051 - accuracy: 0.9995 - val_loss: 0.5024 - val_accuracy: 0.8784
#
# Epoch 00185: val_accuracy did not improve from 0.93243
# Epoch 186/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.3221 - val_accuracy: 0.8986
#
# Epoch 00186: val_accuracy did not improve from 0.93243
# Epoch 187/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 0.5113 - val_accuracy: 0.9189
#
# Epoch 00187: val_accuracy did not improve from 0.93243
# Epoch 188/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0230 - accuracy: 0.9916 - val_loss: 0.4689 - val_accuracy: 0.8851
#
# Epoch 00188: val_accuracy did not improve from 0.93243
# Epoch 189/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.5465 - val_accuracy: 0.8784
#
# Epoch 00189: val_accuracy did not improve from 0.93243
# Epoch 190/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.6510 - val_accuracy: 0.8716
#
# Epoch 00190: val_accuracy did not improve from 0.93243
# Epoch 191/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.5820 - val_accuracy: 0.8919
#
# Epoch 00191: val_accuracy did not improve from 0.93243
# Epoch 192/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.4820 - val_accuracy: 0.9054
#
# Epoch 00192: val_accuracy did not improve from 0.93243
# Epoch 193/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.6486 - val_accuracy: 0.8784
#
# Epoch 00193: val_accuracy did not improve from 0.93243
# Epoch 194/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0532 - accuracy: 0.9826 - val_loss: 0.6163 - val_accuracy: 0.8649
#
# Epoch 00194: val_accuracy did not improve from 0.93243
# Epoch 195/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0543 - accuracy: 0.9842 - val_loss: 0.5861 - val_accuracy: 0.8716
#
# Epoch 00195: val_accuracy did not improve from 0.93243
# Epoch 196/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0408 - accuracy: 0.9858 - val_loss: 0.2593 - val_accuracy: 0.9122
#
# Epoch 00196: val_accuracy did not improve from 0.93243
# Epoch 197/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0188 - accuracy: 0.9974 - val_loss: 0.4457 - val_accuracy: 0.8986
#
# Epoch 00197: val_accuracy did not improve from 0.93243
# Epoch 198/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.3491 - val_accuracy: 0.9122
#
# Epoch 00198: val_accuracy did not improve from 0.93243
# Epoch 199/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.9054
#
# Epoch 00199: val_accuracy did not improve from 0.93243
# Epoch 200/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0393 - accuracy: 0.9889 - val_loss: 0.4265 - val_accuracy: 0.9054
#
# Epoch 00200: val_accuracy did not improve from 0.93243
# Epoch 201/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0308 - accuracy: 0.9911 - val_loss: 0.4844 - val_accuracy: 0.8919
#
# Epoch 00201: val_accuracy did not improve from 0.93243
# Epoch 202/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.4005 - val_accuracy: 0.9324
#
# Epoch 00202: val_accuracy did not improve from 0.93243
# Epoch 203/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 0.3718 - val_accuracy: 0.9189
#
# Epoch 00203: val_accuracy did not improve from 0.93243
# Epoch 204/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.5179 - val_accuracy: 0.8851
#
# Epoch 00204: val_accuracy did not improve from 0.93243
# Epoch 205/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0350 - accuracy: 0.9895 - val_loss: 0.3068 - val_accuracy: 0.9324
#
# Epoch 00205: val_accuracy did not improve from 0.93243
# Epoch 206/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.3113 - val_accuracy: 0.9189
#
# Epoch 00206: val_accuracy did not improve from 0.93243
# Epoch 207/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.3775 - val_accuracy: 0.9054
#
# Epoch 00207: val_accuracy did not improve from 0.93243
# Epoch 208/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.3789 - val_accuracy: 0.9392
#
# Epoch 00208: val_accuracy improved from 0.93243 to 0.93919, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 209/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.4932 - val_accuracy: 0.8986
#
# Epoch 00209: val_accuracy did not improve from 0.93919
# Epoch 210/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.3130 - val_accuracy: 0.9459
#
# Epoch 00210: val_accuracy improved from 0.93919 to 0.94595, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_4.h5
# Epoch 211/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.3875 - val_accuracy: 0.9392
#
# Epoch 00211: val_accuracy did not improve from 0.94595
# Epoch 212/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9189
#
# Epoch 00212: val_accuracy did not improve from 0.94595
# Epoch 213/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.9459
#
# Epoch 00213: val_accuracy did not improve from 0.94595
# Epoch 214/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0414 - accuracy: 0.9874 - val_loss: 0.5779 - val_accuracy: 0.8649
#
# Epoch 00214: val_accuracy did not improve from 0.94595
# Epoch 215/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0392 - accuracy: 0.9842 - val_loss: 0.6405 - val_accuracy: 0.8919
#
# Epoch 00215: val_accuracy did not improve from 0.94595
# Epoch 216/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.3894 - val_accuracy: 0.9189
#
# Epoch 00216: val_accuracy did not improve from 0.94595
# Epoch 217/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0168 - accuracy: 0.9963 - val_loss: 0.4292 - val_accuracy: 0.8919
#
# Epoch 00217: val_accuracy did not improve from 0.94595
# Epoch 218/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.4487 - val_accuracy: 0.8986
#
# Epoch 00218: val_accuracy did not improve from 0.94595
# Epoch 219/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0425 - accuracy: 0.9858 - val_loss: 0.4990 - val_accuracy: 0.9054
#
# Epoch 00219: val_accuracy did not improve from 0.94595
# Epoch 220/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0439 - accuracy: 0.9858 - val_loss: 0.3769 - val_accuracy: 0.9054
#
# Epoch 00220: val_accuracy did not improve from 0.94595
# Epoch 221/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0128 - accuracy: 0.9968 - val_loss: 0.3832 - val_accuracy: 0.9122
#
# Epoch 00221: val_accuracy did not improve from 0.94595
# Epoch 222/500
# 238/238 [==============================] - 24s 103ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.3690 - val_accuracy: 0.9189
#
# Epoch 00222: val_accuracy did not improve from 0.94595
# Epoch 223/500
# 238/238 [==============================] - 24s 102ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.4474 - val_accuracy: 0.8986
#
# Epoch 00223: val_accuracy did not improve from 0.94595
# Epoch 224/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.4324 - val_accuracy: 0.8986
#
# Epoch 00224: val_accuracy did not improve from 0.94595
# Epoch 225/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0211 - accuracy: 0.9932 - val_loss: 0.5968 - val_accuracy: 0.8986
#
# Epoch 00225: val_accuracy did not improve from 0.94595
# Epoch 226/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0146 - accuracy: 0.9958 - val_loss: 0.4023 - val_accuracy: 0.8919
#
# Epoch 00226: val_accuracy did not improve from 0.94595
# Epoch 227/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.4268 - val_accuracy: 0.9122
#
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.94595
# Epoch 423/500
# 238/238 [==============================] - 25s 103ms/step - loss: 0.0029 - accuracy: 0.9984 - val_loss: 0.4074 - val_accuracy: 0.9054
#
# Epoch 00423: val_accuracy did not improve from 0.94595
# Epoch 424/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.7674 - val_accuracy: 0.8649
#
# Epoch 00424: val_accuracy did not improve from 0.94595
# Epoch 425/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.5582 - val_accuracy: 0.8784
#
# Epoch 00425: val_accuracy did not improve from 0.94595
# Epoch 426/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.3351 - val_accuracy: 0.9257
#
# Epoch 00426: val_accuracy did not improve from 0.94595
# Epoch 427/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0036 - accuracy: 0.9979 - val_loss: 0.3502 - val_accuracy: 0.9257
#
# Epoch 00427: val_accuracy did not improve from 0.94595
# Epoch 428/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.4682 - val_accuracy: 0.9122
#
# Epoch 00428: val_accuracy did not improve from 0.94595
# Epoch 429/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.4430 - val_accuracy: 0.8986
#
# Epoch 00429: val_accuracy did not improve from 0.94595
# Epoch 430/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0066 - accuracy: 0.9968 - val_loss: 0.5547 - val_accuracy: 0.9189
#
# Epoch 00430: val_accuracy did not improve from 0.94595
# Epoch 431/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6360 - val_accuracy: 0.9122
#
# Epoch 00431: val_accuracy did not improve from 0.94595
# Epoch 432/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.6295 - val_accuracy: 0.8986
#
# Epoch 00432: val_accuracy did not improve from 0.94595
# Epoch 433/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.4651 - val_accuracy: 0.9122
#
# Epoch 00433: val_accuracy did not improve from 0.94595
# Epoch 434/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.5251 - val_accuracy: 0.8919
#
# Epoch 00434: val_accuracy did not improve from 0.94595
# Epoch 435/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.4662 - val_accuracy: 0.8716
#
# Epoch 00435: val_accuracy did not improve from 0.94595
# Epoch 436/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.5042 - val_accuracy: 0.9257
#
# Epoch 00436: val_accuracy did not improve from 0.94595
# Epoch 437/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0056 - accuracy: 0.9968 - val_loss: 0.5215 - val_accuracy: 0.9189
#
# Epoch 00437: val_accuracy did not improve from 0.94595
# Epoch 438/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0028 - accuracy: 0.9984 - val_loss: 0.3877 - val_accuracy: 0.9392
#
# Epoch 00438: val_accuracy did not improve from 0.94595
# Epoch 439/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.6352 - val_accuracy: 0.8649
#
# Epoch 00439: val_accuracy did not improve from 0.94595
# Epoch 440/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.5057 - val_accuracy: 0.8919
#
# Epoch 00440: val_accuracy did not improve from 0.94595
# Epoch 441/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.6362 - val_accuracy: 0.9054
#
# Epoch 00441: val_accuracy did not improve from 0.94595
# Epoch 442/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.5230 - val_accuracy: 0.9054
#
# Epoch 00442: val_accuracy did not improve from 0.94595
# Epoch 443/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.5704 - val_accuracy: 0.8986
#
# Epoch 00443: val_accuracy did not improve from 0.94595
# Epoch 444/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.8026 - val_accuracy: 0.8716
#
# Epoch 00444: val_accuracy did not improve from 0.94595
# Epoch 445/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.6444 - val_accuracy: 0.8986
#
# Epoch 00445: val_accuracy did not improve from 0.94595
# Epoch 446/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 1.1204 - val_accuracy: 0.8446
#
# Epoch 00446: val_accuracy did not improve from 0.94595
# Epoch 447/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0091 - accuracy: 0.9979 - val_loss: 0.4563 - val_accuracy: 0.9122
#
# Epoch 00447: val_accuracy did not improve from 0.94595
# Epoch 448/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.6353 - val_accuracy: 0.9054
#
# Epoch 00448: val_accuracy did not improve from 0.94595
# Epoch 449/500
# 238/238 [==============================] - 25s 107ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.5784 - val_accuracy: 0.8986
#
# Epoch 00449: val_accuracy did not improve from 0.94595
# Epoch 450/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.5730 - val_accuracy: 0.9189
#
# Epoch 00450: val_accuracy did not improve from 0.94595
# Epoch 451/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.4892 - val_accuracy: 0.8919
#
# Epoch 00451: val_accuracy did not improve from 0.94595
# Epoch 452/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.2950 - val_accuracy: 0.9392
#
# Epoch 00452: val_accuracy did not improve from 0.94595
# Epoch 453/500
# 238/238 [==============================] - 25s 104ms/step - loss: 6.2069e-04 - accuracy: 1.0000 - val_loss: 0.4524 - val_accuracy: 0.9324
#
# Epoch 00453: val_accuracy did not improve from 0.94595
# Epoch 454/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.4551 - val_accuracy: 0.9122
#
# Epoch 00454: val_accuracy did not improve from 0.94595
# Epoch 455/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0546 - accuracy: 0.9889 - val_loss: 0.4763 - val_accuracy: 0.9054
#
# Epoch 00455: val_accuracy did not improve from 0.94595
# Epoch 456/500
# 238/238 [==============================] - 26s 108ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.4515 - val_accuracy: 0.8986
#
# Epoch 00456: val_accuracy did not improve from 0.94595
# Epoch 457/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0021 - accuracy: 0.9989 - val_loss: 0.5726 - val_accuracy: 0.8986
#
# Epoch 00457: val_accuracy did not improve from 0.94595
# Epoch 458/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.4504 - val_accuracy: 0.9054
#
# Epoch 00458: val_accuracy did not improve from 0.94595
# Epoch 459/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6460 - val_accuracy: 0.8851
#
# Epoch 00459: val_accuracy did not improve from 0.94595
# Epoch 460/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.5448 - val_accuracy: 0.9054
#
# Epoch 00460: val_accuracy did not improve from 0.94595
# Epoch 461/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.5605 - val_accuracy: 0.9257
#
# Epoch 00461: val_accuracy did not improve from 0.94595
# Epoch 462/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.4006 - val_accuracy: 0.9189
#
# Epoch 00462: val_accuracy did not improve from 0.94595
# Epoch 463/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.4423 - val_accuracy: 0.9257
#
# Epoch 00463: val_accuracy did not improve from 0.94595
# Epoch 464/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0265 - accuracy: 0.9921 - val_loss: 0.9373 - val_accuracy: 0.8581
#
# Epoch 00464: val_accuracy did not improve from 0.94595
# Epoch 465/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0164 - accuracy: 0.9932 - val_loss: 0.5970 - val_accuracy: 0.9054
#
# Epoch 00465: val_accuracy did not improve from 0.94595
# Epoch 466/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.5311 - val_accuracy: 0.8986
#
# Epoch 00466: val_accuracy did not improve from 0.94595
# Epoch 467/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9324
#
# Epoch 00467: val_accuracy did not improve from 0.94595
# Epoch 468/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.5808 - val_accuracy: 0.8784
#
# Epoch 00468: val_accuracy did not improve from 0.94595
# Epoch 469/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.5508 - val_accuracy: 0.8919
#
# Epoch 00469: val_accuracy did not improve from 0.94595
# Epoch 470/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4549 - val_accuracy: 0.9054
#
# Epoch 00470: val_accuracy did not improve from 0.94595
# Epoch 471/500
# 238/238 [==============================] - 25s 107ms/step - loss: 7.2445e-04 - accuracy: 1.0000 - val_loss: 0.4450 - val_accuracy: 0.9122
#
# Epoch 00471: val_accuracy did not improve from 0.94595
# Epoch 472/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0021 - accuracy: 0.9989 - val_loss: 0.3162 - val_accuracy: 0.9257
#
# Epoch 00472: val_accuracy did not improve from 0.94595
# Epoch 473/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3722 - val_accuracy: 0.9189
#
# Epoch 00473: val_accuracy did not improve from 0.94595
# Epoch 474/500
# 238/238 [==============================] - 25s 105ms/step - loss: 7.3937e-04 - accuracy: 1.0000 - val_loss: 0.3963 - val_accuracy: 0.9392
#
# Epoch 00474: val_accuracy did not improve from 0.94595
# Epoch 475/500
# 238/238 [==============================] - 25s 105ms/step - loss: 4.3361e-04 - accuracy: 1.0000 - val_loss: 0.5155 - val_accuracy: 0.9189
#
# Epoch 00475: val_accuracy did not improve from 0.94595
# Epoch 476/500
# 238/238 [==============================] - 25s 104ms/step - loss: 3.9145e-04 - accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.8986
#
# Epoch 00476: val_accuracy did not improve from 0.94595
# Epoch 477/500
# 238/238 [==============================] - 25s 105ms/step - loss: 9.7488e-04 - accuracy: 1.0000 - val_loss: 0.4626 - val_accuracy: 0.9054
#
# Epoch 00477: val_accuracy did not improve from 0.94595
# Epoch 478/500
# 238/238 [==============================] - 25s 107ms/step - loss: 0.0140 - accuracy: 0.9968 - val_loss: 0.6884 - val_accuracy: 0.8986
#
# Epoch 00478: val_accuracy did not improve from 0.94595
# Epoch 479/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0234 - accuracy: 0.9926 - val_loss: 0.5290 - val_accuracy: 0.8986
#
# Epoch 00479: val_accuracy did not improve from 0.94595
# Epoch 480/500
# 238/238 [==============================] - 26s 107ms/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.5630 - val_accuracy: 0.8919
#
# Epoch 00480: val_accuracy did not improve from 0.94595
# Epoch 481/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0168 - accuracy: 0.9963 - val_loss: 0.5111 - val_accuracy: 0.9189
#
# Epoch 00481: val_accuracy did not improve from 0.94595
# Epoch 482/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.6767 - val_accuracy: 0.8919
#
# Epoch 00482: val_accuracy did not improve from 0.94595
# Epoch 483/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.6037 - val_accuracy: 0.9122
#
# Epoch 00483: val_accuracy did not improve from 0.94595
# Epoch 484/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0092 - accuracy: 0.9953 - val_loss: 0.5844 - val_accuracy: 0.9054
#
# Epoch 00484: val_accuracy did not improve from 0.94595
# Epoch 485/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.5104 - val_accuracy: 0.9054
#
# Epoch 00485: val_accuracy did not improve from 0.94595
# Epoch 486/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0093 - accuracy: 0.9958 - val_loss: 0.5778 - val_accuracy: 0.8716
#
# Epoch 00486: val_accuracy did not improve from 0.94595
# Epoch 487/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.4739 - val_accuracy: 0.9189
#
# Epoch 00487: val_accuracy did not improve from 0.94595
# Epoch 488/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.5887 - val_accuracy: 0.8851
#
# Epoch 00488: val_accuracy did not improve from 0.94595
# Epoch 489/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.5456 - val_accuracy: 0.9189
#
# Epoch 00489: val_accuracy did not improve from 0.94595
# Epoch 490/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.6388 - val_accuracy: 0.9054
#
# Epoch 00490: val_accuracy did not improve from 0.94595
# Epoch 491/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.3536 - val_accuracy: 0.9392
#
# Epoch 00491: val_accuracy did not improve from 0.94595
# Epoch 492/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.9392
#
# Epoch 00492: val_accuracy did not improve from 0.94595
# Epoch 493/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0019 - accuracy: 0.9989 - val_loss: 0.3760 - val_accuracy: 0.9257
#
# Epoch 00493: val_accuracy did not improve from 0.94595
# Epoch 494/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0090 - accuracy: 0.9963 - val_loss: 0.5930 - val_accuracy: 0.9189
#
# Epoch 00494: val_accuracy did not improve from 0.94595
# Epoch 495/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0022 - accuracy: 0.9989 - val_loss: 0.4314 - val_accuracy: 0.8986
#
# Epoch 00495: val_accuracy did not improve from 0.94595
# Epoch 496/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.8313 - val_accuracy: 0.8919
#
# Epoch 00496: val_accuracy did not improve from 0.94595
# Epoch 497/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0288 - accuracy: 0.9932 - val_loss: 0.7465 - val_accuracy: 0.8986
#
# Epoch 00497: val_accuracy did not improve from 0.94595
# Epoch 498/500
# 238/238 [==============================] - 25s 106ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.5401 - val_accuracy: 0.9189
#
# Epoch 00498: val_accuracy did not improve from 0.94595
# Epoch 499/500
# 238/238 [==============================] - 25s 105ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.6902 - val_accuracy: 0.9122
#
# Epoch 00499: val_accuracy did not improve from 0.94595
# Epoch 500/500
# 238/238 [==============================] - 25s 104ms/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 0.5380 - val_accuracy: 0.9324
#
# Epoch 00500: val_accuracy did not improve from 0.94595

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': True, 'detail': 'Success'}
