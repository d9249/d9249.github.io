# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/ResNet50V2_3_(public-0.92156%2C%20private-0.91822).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Sep 25 00:27:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
model_save = 'ResNet50V2_3'
Target_model = 'ResNet50V2_model'
Target_predict = 'ResNet50V2_predict'
Target_acc = 'ResNet50V2_acc'
Target_val = 'ResNet50V2_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.ResNet50V2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 36s 64ms/step - loss: 1.9773 - accuracy: 0.3242 - val_loss: 9.9131 - val_accuracy: 0.0811
#
# Epoch 00001: val_accuracy improved from -inf to 0.08108, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 14s 60ms/step - loss: 1.3422 - accuracy: 0.5532 - val_loss: 4.3742 - val_accuracy: 0.2635
#
# Epoch 00002: val_accuracy improved from 0.08108 to 0.26351, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 3/500
# 238/238 [==============================] - 14s 60ms/step - loss: 1.1266 - accuracy: 0.6268 - val_loss: 7.7210 - val_accuracy: 0.1419
#
# Epoch 00003: val_accuracy did not improve from 0.26351
# Epoch 4/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.9916 - accuracy: 0.6732 - val_loss: 9.5389 - val_accuracy: 0.1216
#
# Epoch 00004: val_accuracy did not improve from 0.26351
# Epoch 5/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.9360 - accuracy: 0.6847 - val_loss: 1.3351 - val_accuracy: 0.6351
#
# Epoch 00005: val_accuracy improved from 0.26351 to 0.63514, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 6/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.7855 - accuracy: 0.7395 - val_loss: 0.7933 - val_accuracy: 0.7635
#
# Epoch 00006: val_accuracy improved from 0.63514 to 0.76351, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 7/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.7109 - accuracy: 0.7721 - val_loss: 11.1784 - val_accuracy: 0.0946
#
# Epoch 00007: val_accuracy did not improve from 0.76351
# Epoch 8/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.7118 - accuracy: 0.7695 - val_loss: 0.8380 - val_accuracy: 0.7500
#
# Epoch 00008: val_accuracy did not improve from 0.76351
# Epoch 9/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.6513 - accuracy: 0.7868 - val_loss: 12.4243 - val_accuracy: 0.1689
#
# Epoch 00009: val_accuracy did not improve from 0.76351
# Epoch 10/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.6213 - accuracy: 0.7995 - val_loss: 0.5002 - val_accuracy: 0.8041
#
# Epoch 00010: val_accuracy improved from 0.76351 to 0.80405, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 11/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.5281 - accuracy: 0.8168 - val_loss: 1.5406 - val_accuracy: 0.6216
#
# Epoch 00011: val_accuracy did not improve from 0.80405
# Epoch 12/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.5260 - accuracy: 0.8258 - val_loss: 0.6520 - val_accuracy: 0.7973
#
# Epoch 00012: val_accuracy did not improve from 0.80405
# Epoch 13/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.5081 - accuracy: 0.8326 - val_loss: 0.6826 - val_accuracy: 0.7770
#
# Epoch 00013: val_accuracy did not improve from 0.80405
# Epoch 14/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.5060 - accuracy: 0.8353 - val_loss: 0.4833 - val_accuracy: 0.8243
#
# Epoch 00014: val_accuracy improved from 0.80405 to 0.82432, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 15/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4344 - accuracy: 0.8621 - val_loss: 0.6255 - val_accuracy: 0.7973
#
# Epoch 00015: val_accuracy did not improve from 0.82432
# Epoch 16/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.4707 - accuracy: 0.8484 - val_loss: 0.4719 - val_accuracy: 0.8446
#
# Epoch 00016: val_accuracy improved from 0.82432 to 0.84459, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 17/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4141 - accuracy: 0.8668 - val_loss: 1.4446 - val_accuracy: 0.5878
#
# Epoch 00017: val_accuracy did not improve from 0.84459
# Epoch 18/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4654 - accuracy: 0.8458 - val_loss: 0.4107 - val_accuracy: 0.8784
#
# Epoch 00018: val_accuracy improved from 0.84459 to 0.87838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 19/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3477 - accuracy: 0.8811 - val_loss: 0.6013 - val_accuracy: 0.8041
#
# Epoch 00019: val_accuracy did not improve from 0.87838
# Epoch 20/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3788 - accuracy: 0.8689 - val_loss: 0.4870 - val_accuracy: 0.8581
#
# Epoch 00020: val_accuracy did not improve from 0.87838
# Epoch 21/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3236 - accuracy: 0.8905 - val_loss: 0.7022 - val_accuracy: 0.7500
#
# Epoch 00021: val_accuracy did not improve from 0.87838
# Epoch 22/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3537 - accuracy: 0.8905 - val_loss: 0.4394 - val_accuracy: 0.8446
#
# Epoch 00022: val_accuracy did not improve from 0.87838
# Epoch 23/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3097 - accuracy: 0.8911 - val_loss: 1.0687 - val_accuracy: 0.7297
#
# Epoch 00023: val_accuracy did not improve from 0.87838
# Epoch 24/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3677 - accuracy: 0.8732 - val_loss: 0.4231 - val_accuracy: 0.8784
#
# Epoch 00024: val_accuracy did not improve from 0.87838
# Epoch 25/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.2916 - accuracy: 0.9047 - val_loss: 0.3520 - val_accuracy: 0.8784
#
# Epoch 00025: val_accuracy did not improve from 0.87838
# Epoch 26/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3061 - accuracy: 0.8974 - val_loss: 3.6199 - val_accuracy: 0.3919
#
# Epoch 00026: val_accuracy did not improve from 0.87838
# Epoch 27/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2690 - accuracy: 0.9184 - val_loss: 0.8319 - val_accuracy: 0.8108
#
# Epoch 00027: val_accuracy did not improve from 0.87838
# Epoch 28/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2392 - accuracy: 0.9174 - val_loss: 0.2598 - val_accuracy: 0.9054
#
# Epoch 00028: val_accuracy improved from 0.87838 to 0.90541, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 29/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2730 - accuracy: 0.9111 - val_loss: 0.4792 - val_accuracy: 0.8514
#
# Epoch 00029: val_accuracy did not improve from 0.90541
# Epoch 30/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2238 - accuracy: 0.9279 - val_loss: 0.4109 - val_accuracy: 0.8446
#
# Epoch 00030: val_accuracy did not improve from 0.90541
# Epoch 31/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2576 - accuracy: 0.9142 - val_loss: 0.6717 - val_accuracy: 0.7838
#
# Epoch 00031: val_accuracy did not improve from 0.90541
# Epoch 32/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2322 - accuracy: 0.9153 - val_loss: 0.5018 - val_accuracy: 0.8851
#
# Epoch 00032: val_accuracy did not improve from 0.90541
# Epoch 33/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2495 - accuracy: 0.9153 - val_loss: 2.1914 - val_accuracy: 0.6081
#
# Epoch 00033: val_accuracy did not improve from 0.90541
# Epoch 34/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2558 - accuracy: 0.9153 - val_loss: 0.4332 - val_accuracy: 0.8378
#
# Epoch 00034: val_accuracy did not improve from 0.90541
# Epoch 35/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1910 - accuracy: 0.9379 - val_loss: 0.5036 - val_accuracy: 0.8446
#
# Epoch 00035: val_accuracy did not improve from 0.90541
# Epoch 36/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2005 - accuracy: 0.9305 - val_loss: 0.5123 - val_accuracy: 0.8446
#
# Epoch 00036: val_accuracy did not improve from 0.90541
# Epoch 37/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2238 - accuracy: 0.9211 - val_loss: 1.1231 - val_accuracy: 0.7568
#
# Epoch 00037: val_accuracy did not improve from 0.90541
# Epoch 38/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2103 - accuracy: 0.9289 - val_loss: 0.5359 - val_accuracy: 0.8716
#
# Epoch 00038: val_accuracy did not improve from 0.90541
# Epoch 39/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1793 - accuracy: 0.9421 - val_loss: 0.3633 - val_accuracy: 0.8851
#
# Epoch 00039: val_accuracy did not improve from 0.90541
# Epoch 40/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1876 - accuracy: 0.9368 - val_loss: 0.6681 - val_accuracy: 0.7973
#
# Epoch 00040: val_accuracy did not improve from 0.90541
# Epoch 41/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1432 - accuracy: 0.9489 - val_loss: 0.4919 - val_accuracy: 0.8581
#
# Epoch 00041: val_accuracy did not improve from 0.90541
# Epoch 42/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1548 - accuracy: 0.9447 - val_loss: 0.4567 - val_accuracy: 0.8919
#
# Epoch 00042: val_accuracy did not improve from 0.90541
# Epoch 43/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1420 - accuracy: 0.9511 - val_loss: 2.8326 - val_accuracy: 0.6351
#
# Epoch 00043: val_accuracy did not improve from 0.90541
# Epoch 44/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1556 - accuracy: 0.9447 - val_loss: 0.4349 - val_accuracy: 0.8649
#
# Epoch 00044: val_accuracy did not improve from 0.90541
# Epoch 45/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1388 - accuracy: 0.9553 - val_loss: 0.3349 - val_accuracy: 0.8716
#
# Epoch 00045: val_accuracy did not improve from 0.90541
# Epoch 46/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1362 - accuracy: 0.9547 - val_loss: 0.3028 - val_accuracy: 0.8986
#
# Epoch 00046: val_accuracy did not improve from 0.90541
# Epoch 47/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2004 - accuracy: 0.9316 - val_loss: 0.3411 - val_accuracy: 0.8784
#
# Epoch 00047: val_accuracy did not improve from 0.90541
# Epoch 48/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1397 - accuracy: 0.9511 - val_loss: 0.6427 - val_accuracy: 0.8514
#
# Epoch 00048: val_accuracy did not improve from 0.90541
# Epoch 49/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1288 - accuracy: 0.9579 - val_loss: 0.3996 - val_accuracy: 0.8919
#
# Epoch 00049: val_accuracy did not improve from 0.90541
# Epoch 50/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0750 - accuracy: 0.9737 - val_loss: 0.7491 - val_accuracy: 0.8581
#
# Epoch 00050: val_accuracy did not improve from 0.90541
# Epoch 51/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1416 - accuracy: 0.9547 - val_loss: 0.3067 - val_accuracy: 0.8919
#
# Epoch 00051: val_accuracy did not improve from 0.90541
# Epoch 52/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1391 - accuracy: 0.9579 - val_loss: 0.7075 - val_accuracy: 0.8311
#
# Epoch 00052: val_accuracy did not improve from 0.90541
# Epoch 53/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1261 - accuracy: 0.9637 - val_loss: 0.3525 - val_accuracy: 0.8649
#
# Epoch 00053: val_accuracy did not improve from 0.90541
# Epoch 54/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1082 - accuracy: 0.9637 - val_loss: 0.3427 - val_accuracy: 0.9257
#
# Epoch 00054: val_accuracy improved from 0.90541 to 0.92568, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 55/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1229 - accuracy: 0.9595 - val_loss: 0.4070 - val_accuracy: 0.8851
#
# Epoch 00055: val_accuracy did not improve from 0.92568
# Epoch 56/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0914 - accuracy: 0.9684 - val_loss: 0.5109 - val_accuracy: 0.8311
#
# Epoch 00056: val_accuracy did not improve from 0.92568
# Epoch 57/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1194 - accuracy: 0.9579 - val_loss: 0.4447 - val_accuracy: 0.8784
#
# Epoch 00057: val_accuracy did not improve from 0.92568
# Epoch 58/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0883 - accuracy: 0.9726 - val_loss: 0.4313 - val_accuracy: 0.8581
#
# Epoch 00058: val_accuracy did not improve from 0.92568
# Epoch 59/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1018 - accuracy: 0.9653 - val_loss: 1.6015 - val_accuracy: 0.7095
#
# Epoch 00059: val_accuracy did not improve from 0.92568
# Epoch 60/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1452 - accuracy: 0.9511 - val_loss: 0.4594 - val_accuracy: 0.8649
#
# Epoch 00060: val_accuracy did not improve from 0.92568
# Epoch 61/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1057 - accuracy: 0.9637 - val_loss: 0.4513 - val_accuracy: 0.8581
#
# Epoch 00061: val_accuracy did not improve from 0.92568
# Epoch 62/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.0759 - accuracy: 0.9742 - val_loss: 0.8507 - val_accuracy: 0.8041
#
# Epoch 00062: val_accuracy did not improve from 0.92568
# Epoch 63/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0551 - accuracy: 0.9816 - val_loss: 0.3792 - val_accuracy: 0.9054
#
# Epoch 00063: val_accuracy did not improve from 0.92568
# Epoch 64/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0663 - accuracy: 0.9742 - val_loss: 0.6754 - val_accuracy: 0.8378
#
# Epoch 00064: val_accuracy did not improve from 0.92568
# Epoch 65/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1110 - accuracy: 0.9647 - val_loss: 0.4557 - val_accuracy: 0.9054
#
# Epoch 00065: val_accuracy did not improve from 0.92568
# Epoch 66/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1233 - accuracy: 0.9558 - val_loss: 0.5300 - val_accuracy: 0.8514
#
# Epoch 00066: val_accuracy did not improve from 0.92568
# Epoch 67/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1036 - accuracy: 0.9626 - val_loss: 0.5220 - val_accuracy: 0.8514
#
# Epoch 00067: val_accuracy did not improve from 0.92568
# Epoch 68/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0697 - accuracy: 0.9789 - val_loss: 0.4825 - val_accuracy: 0.8919
#
# Epoch 00068: val_accuracy did not improve from 0.92568
# Epoch 69/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0733 - accuracy: 0.9721 - val_loss: 0.4447 - val_accuracy: 0.8784
#
# Epoch 00069: val_accuracy did not improve from 0.92568
# Epoch 70/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0758 - accuracy: 0.9721 - val_loss: 0.4081 - val_accuracy: 0.8784
#
# Epoch 00070: val_accuracy did not improve from 0.92568
# Epoch 71/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.0509 - accuracy: 0.9874 - val_loss: 0.5574 - val_accuracy: 0.8784
#
# Epoch 00071: val_accuracy did not improve from 0.92568
# Epoch 72/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0606 - accuracy: 0.9763 - val_loss: 0.3686 - val_accuracy: 0.9122
#
# Epoch 00072: val_accuracy did not improve from 0.92568
# Epoch 73/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1037 - accuracy: 0.9647 - val_loss: 0.5403 - val_accuracy: 0.8851
#
# Epoch 00073: val_accuracy did not improve from 0.92568
# Epoch 74/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0453 - accuracy: 0.9863 - val_loss: 0.4170 - val_accuracy: 0.8784
#
# Epoch 00074: val_accuracy did not improve from 0.92568
# Epoch 75/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0604 - accuracy: 0.9816 - val_loss: 0.4616 - val_accuracy: 0.9122
#
# Epoch 00075: val_accuracy did not improve from 0.92568
# Epoch 76/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1057 - accuracy: 0.9658 - val_loss: 0.3174 - val_accuracy: 0.9257
#
# Epoch 00076: val_accuracy did not improve from 0.92568
# Epoch 77/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0488 - accuracy: 0.9816 - val_loss: 0.4420 - val_accuracy: 0.8784
#
# Epoch 00077: val_accuracy did not improve from 0.92568
# Epoch 78/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0687 - accuracy: 0.9784 - val_loss: 0.5827 - val_accuracy: 0.8243
#
# Epoch 00078: val_accuracy did not improve from 0.92568
# Epoch 79/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0966 - accuracy: 0.9647 - val_loss: 0.5915 - val_accuracy: 0.8446
#
# Epoch 00079: val_accuracy did not improve from 0.92568
# Epoch 80/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0979 - accuracy: 0.9679 - val_loss: 0.7594 - val_accuracy: 0.8581
#
# Epoch 00080: val_accuracy did not improve from 0.92568
# Epoch 81/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0432 - accuracy: 0.9826 - val_loss: 0.4417 - val_accuracy: 0.8851
#
# Epoch 00081: val_accuracy did not improve from 0.92568
# Epoch 82/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0617 - accuracy: 0.9816 - val_loss: 0.4837 - val_accuracy: 0.8784
#
# Epoch 00082: val_accuracy did not improve from 0.92568
# Epoch 83/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0476 - accuracy: 0.9868 - val_loss: 0.4112 - val_accuracy: 0.8784
#
# Epoch 00083: val_accuracy did not improve from 0.92568
# Epoch 84/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0408 - accuracy: 0.9847 - val_loss: 0.6953 - val_accuracy: 0.8851
#
# Epoch 00084: val_accuracy did not improve from 0.92568
# Epoch 85/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0448 - accuracy: 0.9853 - val_loss: 0.5888 - val_accuracy: 0.8784
#
# Epoch 00085: val_accuracy did not improve from 0.92568
# Epoch 86/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0603 - accuracy: 0.9763 - val_loss: 0.4577 - val_accuracy: 0.9122
#
# Epoch 00086: val_accuracy did not improve from 0.92568
# Epoch 87/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0903 - accuracy: 0.9721 - val_loss: 1.8429 - val_accuracy: 0.7432
#
# Epoch 00087: val_accuracy did not improve from 0.92568
# Epoch 88/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0823 - accuracy: 0.9737 - val_loss: 0.7841 - val_accuracy: 0.8378
#
# Epoch 00088: val_accuracy did not improve from 0.92568
# Epoch 89/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0602 - accuracy: 0.9784 - val_loss: 0.4446 - val_accuracy: 0.8851
#
# Epoch 00089: val_accuracy did not improve from 0.92568
# Epoch 90/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.3876 - val_accuracy: 0.8716
#
# Epoch 00090: val_accuracy did not improve from 0.92568
# Epoch 91/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0560 - accuracy: 0.9800 - val_loss: 0.5977 - val_accuracy: 0.8784
#
# Epoch 00091: val_accuracy did not improve from 0.92568
# Epoch 92/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0389 - accuracy: 0.9842 - val_loss: 0.4541 - val_accuracy: 0.8986
#
# Epoch 00092: val_accuracy did not improve from 0.92568
# Epoch 93/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0619 - accuracy: 0.9789 - val_loss: 0.4260 - val_accuracy: 0.8851
#
# Epoch 00093: val_accuracy did not improve from 0.92568
# Epoch 94/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 0.5332 - val_accuracy: 0.8514
#
# Epoch 00094: val_accuracy did not improve from 0.92568
# Epoch 95/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0690 - accuracy: 0.9726 - val_loss: 0.4036 - val_accuracy: 0.8784
#
# Epoch 00095: val_accuracy did not improve from 0.92568
# Epoch 96/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0449 - accuracy: 0.9863 - val_loss: 0.4556 - val_accuracy: 0.8919
#
# Epoch 00096: val_accuracy did not improve from 0.92568
# Epoch 97/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0280 - accuracy: 0.9916 - val_loss: 0.3879 - val_accuracy: 0.8919
#
# Epoch 00097: val_accuracy did not improve from 0.92568
# Epoch 98/500
# 238/238 [==============================] - 14s 59ms/step - loss: 0.0396 - accuracy: 0.9868 - val_loss: 0.3395 - val_accuracy: 0.9122
#
# Epoch 00098: val_accuracy did not improve from 0.92568
# Epoch 99/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0867 - accuracy: 0.9716 - val_loss: 0.9034 - val_accuracy: 0.8514
#
# Epoch 00099: val_accuracy did not improve from 0.92568
# Epoch 100/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0840 - accuracy: 0.9711 - val_loss: 0.4240 - val_accuracy: 0.9122
#
# Epoch 00100: val_accuracy did not improve from 0.92568
# Epoch 101/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.3756 - val_accuracy: 0.9189
#
# Epoch 00101: val_accuracy did not improve from 0.92568
# Epoch 102/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0657 - accuracy: 0.9789 - val_loss: 0.5072 - val_accuracy: 0.9122
#
# Epoch 00102: val_accuracy did not improve from 0.92568
# Epoch 103/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0675 - accuracy: 0.9774 - val_loss: 0.7569 - val_accuracy: 0.8446
#
# Epoch 00103: val_accuracy did not improve from 0.92568
# Epoch 104/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0471 - accuracy: 0.9874 - val_loss: 0.4790 - val_accuracy: 0.8919
#
# Epoch 00104: val_accuracy did not improve from 0.92568
# Epoch 105/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0253 - accuracy: 0.9911 - val_loss: 0.5371 - val_accuracy: 0.8919
#
# Epoch 00105: val_accuracy did not improve from 0.92568
# Epoch 106/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0448 - accuracy: 0.9863 - val_loss: 0.4760 - val_accuracy: 0.8649
#
# Epoch 00106: val_accuracy did not improve from 0.92568
# Epoch 107/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0508 - accuracy: 0.9853 - val_loss: 0.3779 - val_accuracy: 0.8851
#
# Epoch 00107: val_accuracy did not improve from 0.92568
# Epoch 108/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0370 - accuracy: 0.9879 - val_loss: 0.5310 - val_accuracy: 0.8716
#
# Epoch 00108: val_accuracy did not improve from 0.92568
# Epoch 109/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0329 - accuracy: 0.9884 - val_loss: 0.3222 - val_accuracy: 0.9324
#
# Epoch 00109: val_accuracy improved from 0.92568 to 0.93243, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 110/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0270 - accuracy: 0.9932 - val_loss: 0.5508 - val_accuracy: 0.8446
#
# Epoch 00110: val_accuracy did not improve from 0.93243
# Epoch 111/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0302 - accuracy: 0.9911 - val_loss: 0.6182 - val_accuracy: 0.8784
#
# Epoch 00111: val_accuracy did not improve from 0.93243
# Epoch 112/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.5347 - val_accuracy: 0.8851
#
# Epoch 00112: val_accuracy did not improve from 0.93243
# Epoch 113/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0470 - accuracy: 0.9853 - val_loss: 0.6709 - val_accuracy: 0.8649
#
# Epoch 00113: val_accuracy did not improve from 0.93243
# Epoch 114/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0515 - accuracy: 0.9826 - val_loss: 0.6530 - val_accuracy: 0.8514
#
# Epoch 00114: val_accuracy did not improve from 0.93243
# Epoch 115/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0241 - accuracy: 0.9921 - val_loss: 0.5703 - val_accuracy: 0.8851
#
# Epoch 00115: val_accuracy did not improve from 0.93243
# Epoch 116/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0295 - accuracy: 0.9932 - val_loss: 0.4424 - val_accuracy: 0.8919
#
# Epoch 00116: val_accuracy did not improve from 0.93243
# Epoch 117/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0458 - accuracy: 0.9868 - val_loss: 0.2212 - val_accuracy: 0.9459
#
# Epoch 00117: val_accuracy improved from 0.93243 to 0.94595, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_3.h5
# Epoch 118/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0388 - accuracy: 0.9889 - val_loss: 0.6774 - val_accuracy: 0.8446
#
# Epoch 00118: val_accuracy did not improve from 0.94595
# Epoch 119/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0364 - accuracy: 0.9858 - val_loss: 0.6178 - val_accuracy: 0.8378
#
# Epoch 00119: val_accuracy did not improve from 0.94595
# Epoch 120/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0584 - accuracy: 0.9789 - val_loss: 0.4289 - val_accuracy: 0.8986
#
# Epoch 00120: val_accuracy did not improve from 0.94595
# Epoch 121/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0498 - accuracy: 0.9832 - val_loss: 0.5023 - val_accuracy: 0.8649
#
# Epoch 00121: val_accuracy did not improve from 0.94595
# Epoch 122/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.4154 - val_accuracy: 0.9189
#
# Epoch 00122: val_accuracy did not improve from 0.94595
# Epoch 123/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0297 - accuracy: 0.9905 - val_loss: 0.3994 - val_accuracy: 0.9122
#
# Epoch 00123: val_accuracy did not improve from 0.94595
# Epoch 124/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.4737 - val_accuracy: 0.8986
#
# Epoch 00124: val_accuracy did not improve from 0.94595
# Epoch 125/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0478 - accuracy: 0.9832 - val_loss: 0.6191 - val_accuracy: 0.8851
#
# Epoch 00125: val_accuracy did not improve from 0.94595
# Epoch 126/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.4307 - val_accuracy: 0.8919
#
# Epoch 00126: val_accuracy did not improve from 0.94595
# Epoch 127/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 0.8414 - val_accuracy: 0.8446
#
# Epoch 00127: val_accuracy did not improve from 0.94595
# Epoch 128/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0354 - accuracy: 0.9879 - val_loss: 0.6602 - val_accuracy: 0.8716
#
# Epoch 00128: val_accuracy did not improve from 0.94595
# Epoch 129/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0585 - accuracy: 0.9821 - val_loss: 0.8040 - val_accuracy: 0.8378
#
# Epoch 00129: val_accuracy did not improve from 0.94595
# Epoch 130/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0425 - accuracy: 0.9847 - val_loss: 0.6018 - val_accuracy: 0.8649
#
# Epoch 00130: val_accuracy did not improve from 0.94595
# Epoch 131/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0501 - accuracy: 0.9821 - val_loss: 0.5349 - val_accuracy: 0.8716
#
# Epoch 00131: val_accuracy did not improve from 0.94595
# Epoch 132/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0321 - accuracy: 0.9900 - val_loss: 0.5180 - val_accuracy: 0.8851
#
# Epoch 00132: val_accuracy did not improve from 0.94595
# Epoch 133/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0242 - accuracy: 0.9911 - val_loss: 0.6221 - val_accuracy: 0.8581
#
# Epoch 00133: val_accuracy did not improve from 0.94595
# Epoch 134/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.7630 - val_accuracy: 0.8311
#
# Epoch 00134: val_accuracy did not improve from 0.94595
# Epoch 135/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0367 - accuracy: 0.9863 - val_loss: 7.8284 - val_accuracy: 0.3716
#
# Epoch 00135: val_accuracy did not improve from 0.94595
# Epoch 136/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.5616 - val_accuracy: 0.8784
#
# Epoch 00136: val_accuracy did not improve from 0.94595
# Epoch 137/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0188 - accuracy: 0.9932 - val_loss: 0.4631 - val_accuracy: 0.8851
#
# Epoch 00137: val_accuracy did not improve from 0.94595
# Epoch 138/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0191 - accuracy: 0.9942 - val_loss: 0.3305 - val_accuracy: 0.9189
#
# Epoch 00138: val_accuracy did not improve from 0.94595
# Epoch 139/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0479 - accuracy: 0.9832 - val_loss: 0.4152 - val_accuracy: 0.8986
#
# Epoch 00139: val_accuracy did not improve from 0.94595
# Epoch 140/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.5569 - val_accuracy: 0.8716
#
# Epoch 00140: val_accuracy did not improve from 0.94595
# Epoch 141/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0447 - accuracy: 0.9858 - val_loss: 0.5880 - val_accuracy: 0.8716
#
# Epoch 00141: val_accuracy did not improve from 0.94595
# Epoch 142/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0501 - accuracy: 0.9847 - val_loss: 0.5065 - val_accuracy: 0.8851
#
# Epoch 00142: val_accuracy did not improve from 0.94595
# Epoch 143/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.3964 - val_accuracy: 0.9257
#
# Epoch 00143: val_accuracy did not improve from 0.94595
# Epoch 144/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0269 - accuracy: 0.9911 - val_loss: 0.4491 - val_accuracy: 0.8986
#
# Epoch 00144: val_accuracy did not improve from 0.94595
# Epoch 145/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0110 - accuracy: 0.9953 - val_loss: 0.3283 - val_accuracy: 0.9189
#
# Epoch 00145: val_accuracy did not improve from 0.94595
# Epoch 146/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.4923 - val_accuracy: 0.8986
#
# Epoch 00146: val_accuracy did not improve from 0.94595
# Epoch 147/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0341 - accuracy: 0.9911 - val_loss: 0.6616 - val_accuracy: 0.8514
#
# Epoch 00147: val_accuracy did not improve from 0.94595
# Epoch 148/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0540 - accuracy: 0.9816 - val_loss: 0.4218 - val_accuracy: 0.9122
#
# Epoch 00148: val_accuracy did not improve from 0.94595
# Epoch 149/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.2761 - val_accuracy: 0.9324
#
# Epoch 00149: val_accuracy did not improve from 0.94595
# Epoch 150/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.4676 - val_accuracy: 0.8986
#
# Epoch 00150: val_accuracy did not improve from 0.94595
# Epoch 151/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0309 - accuracy: 0.9895 - val_loss: 0.4400 - val_accuracy: 0.8851
#
# Epoch 00151: val_accuracy did not improve from 0.94595
# Epoch 152/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.5206 - val_accuracy: 0.8851
#
# Epoch 00152: val_accuracy did not improve from 0.94595
# Epoch 153/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0270 - accuracy: 0.9926 - val_loss: 0.4642 - val_accuracy: 0.9122
#
# Epoch 00153: val_accuracy did not improve from 0.94595
# Epoch 154/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.3302 - val_accuracy: 0.8919
#
# Epoch 00154: val_accuracy did not improve from 0.94595
# Epoch 155/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0353 - accuracy: 0.9868 - val_loss: 0.4772 - val_accuracy: 0.8784
#
# Epoch 00155: val_accuracy did not improve from 0.94595
# Epoch 156/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.5147 - val_accuracy: 0.8716
#
# Epoch 00156: val_accuracy did not improve from 0.94595
# Epoch 157/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 0.4343 - val_accuracy: 0.9054
#
# Epoch 00157: val_accuracy did not improve from 0.94595
# Epoch 158/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0475 - accuracy: 0.9853 - val_loss: 0.4488 - val_accuracy: 0.9189
#
# Epoch 00158: val_accuracy did not improve from 0.94595
# Epoch 159/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0386 - accuracy: 0.9858 - val_loss: 0.4050 - val_accuracy: 0.8784
#
# Epoch 00159: val_accuracy did not improve from 0.94595
# Epoch 160/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0237 - accuracy: 0.9911 - val_loss: 0.4198 - val_accuracy: 0.8784
#
# Epoch 00160: val_accuracy did not improve from 0.94595
# Epoch 161/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0236 - accuracy: 0.9932 - val_loss: 0.5759 - val_accuracy: 0.8919
#
# Epoch 00161: val_accuracy did not improve from 0.94595
# Epoch 162/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0549 - accuracy: 0.9805 - val_loss: 2.2554 - val_accuracy: 0.6757
#
# Epoch 00162: val_accuracy did not improve from 0.94595
# Epoch 163/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.5083 - val_accuracy: 0.8919
#
# Epoch 00163: val_accuracy did not improve from 0.94595
# Epoch 164/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 0.2229 - val_accuracy: 0.9459
#
# Epoch 00164: val_accuracy did not improve from 0.94595
# Epoch 165/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.6133 - val_accuracy: 0.8851
#
# Epoch 00165: val_accuracy did not improve from 0.94595
# Epoch 166/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.5637 - val_accuracy: 0.8919
#
# Epoch 00166: val_accuracy did not improve from 0.94595
# Epoch 167/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.4979 - val_accuracy: 0.8919
#
# Epoch 00167: val_accuracy did not improve from 0.94595
# Epoch 168/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0771 - accuracy: 0.9789 - val_loss: 0.6860 - val_accuracy: 0.8784
#
# Epoch 00168: val_accuracy did not improve from 0.94595
# Epoch 169/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0504 - accuracy: 0.9821 - val_loss: 0.4956 - val_accuracy: 0.9122
#
# Epoch 00169: val_accuracy did not improve from 0.94595
# Epoch 170/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.7068 - val_accuracy: 0.8784
#
# Epoch 00170: val_accuracy did not improve from 0.94595
# Epoch 171/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0195 - accuracy: 0.9905 - val_loss: 5.6029 - val_accuracy: 0.4595
#
# Epoch 00171: val_accuracy did not improve from 0.94595
# Epoch 172/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0322 - accuracy: 0.9900 - val_loss: 0.9170 - val_accuracy: 0.8378
#
# Epoch 00172: val_accuracy did not improve from 0.94595
# Epoch 173/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.3916 - val_accuracy: 0.8986
#
# Epoch 00173: val_accuracy did not improve from 0.94595
# Epoch 174/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.2632 - val_accuracy: 0.9324
#
# Epoch 00174: val_accuracy did not improve from 0.94595
# Epoch 175/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0184 - accuracy: 0.9932 - val_loss: 0.3792 - val_accuracy: 0.9054
#
# Epoch 00175: val_accuracy did not improve from 0.94595
# Epoch 176/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0174 - accuracy: 0.9953 - val_loss: 0.6798 - val_accuracy: 0.8311
#
# Epoch 00176: val_accuracy did not improve from 0.94595
# Epoch 177/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.3944 - val_accuracy: 0.9054
#
# Epoch 00177: val_accuracy did not improve from 0.94595
# Epoch 178/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0376 - accuracy: 0.9905 - val_loss: 0.4351 - val_accuracy: 0.8851
#
# Epoch 00178: val_accuracy did not improve from 0.94595
# Epoch 179/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.5556 - val_accuracy: 0.8784
#
# Epoch 00179: val_accuracy did not improve from 0.94595
# Epoch 180/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.5990 - val_accuracy: 0.8581
#
# Epoch 00180: val_accuracy did not improve from 0.94595
# Epoch 181/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0253 - accuracy: 0.9932 - val_loss: 0.6635 - val_accuracy: 0.8514
#
# Epoch 00181: val_accuracy did not improve from 0.94595
# Epoch 182/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.6219 - val_accuracy: 0.8851
#
# Epoch 00182: val_accuracy did not improve from 0.94595
# Epoch 183/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0402 - accuracy: 0.9874 - val_loss: 0.3939 - val_accuracy: 0.8784
#
# Epoch 00183: val_accuracy did not improve from 0.94595
# Epoch 184/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0419 - accuracy: 0.9858 - val_loss: 0.6774 - val_accuracy: 0.8514
#
# Epoch 00184: val_accuracy did not improve from 0.94595
# Epoch 185/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0248 - accuracy: 0.9911 - val_loss: 0.4847 - val_accuracy: 0.8784
#
# Epoch 00185: val_accuracy did not improve from 0.94595
# Epoch 186/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.3252 - val_accuracy: 0.9189
#
# Epoch 00186: val_accuracy did not improve from 0.94595
# Epoch 187/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.4579 - val_accuracy: 0.8716
#
# Epoch 00187: val_accuracy did not improve from 0.94595
# Epoch 188/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0340 - accuracy: 0.9905 - val_loss: 0.7755 - val_accuracy: 0.8514
#
# Epoch 00188: val_accuracy did not improve from 0.94595
# Epoch 189/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0404 - accuracy: 0.9858 - val_loss: 0.5023 - val_accuracy: 0.8649
#
# Epoch 00189: val_accuracy did not improve from 0.94595
# Epoch 190/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0298 - accuracy: 0.9921 - val_loss: 0.3405 - val_accuracy: 0.9189
#
# Epoch 00190: val_accuracy did not improve from 0.94595
# Epoch 191/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.3515 - val_accuracy: 0.9122
#
# Epoch 00191: val_accuracy did not improve from 0.94595
# Epoch 192/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0303 - accuracy: 0.9889 - val_loss: 1.0914 - val_accuracy: 0.8243
#
# Epoch 00192: val_accuracy did not improve from 0.94595
# Epoch 193/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0412 - accuracy: 0.9895 - val_loss: 0.4054 - val_accuracy: 0.8919
#
# Epoch 00193: val_accuracy did not improve from 0.94595
# Epoch 194/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.4333 - val_accuracy: 0.8986
#
# Epoch 00194: val_accuracy did not improve from 0.94595
# Epoch 195/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0075 - accuracy: 0.9989 - val_loss: 0.4686 - val_accuracy: 0.8919
#
# Epoch 00195: val_accuracy did not improve from 0.94595
# Epoch 196/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0217 - accuracy: 0.9921 - val_loss: 0.6923 - val_accuracy: 0.8716
#
# Epoch 00196: val_accuracy did not improve from 0.94595
# Epoch 197/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 0.3684 - val_accuracy: 0.9189
#
# Epoch 00197: val_accuracy did not improve from 0.94595
# Epoch 198/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.6009 - val_accuracy: 0.8716
#
# Epoch 00198: val_accuracy did not improve from 0.94595
# Epoch 199/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.3185 - val_accuracy: 0.9189
#
# Epoch 00199: val_accuracy did not improve from 0.94595
# Epoch 200/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.5886 - val_accuracy: 0.8716
#
# Epoch 00200: val_accuracy did not improve from 0.94595
# Epoch 201/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0146 - accuracy: 0.9979 - val_loss: 0.3362 - val_accuracy: 0.9054
#
# Epoch 00201: val_accuracy did not improve from 0.94595
# Epoch 202/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 0.4147 - val_accuracy: 0.9054
#
# Epoch 00202: val_accuracy did not improve from 0.94595
# Epoch 203/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0262 - accuracy: 0.9942 - val_loss: 0.5777 - val_accuracy: 0.8514
#
# Epoch 00203: val_accuracy did not improve from 0.94595
# Epoch 204/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0115 - accuracy: 0.9947 - val_loss: 0.8084 - val_accuracy: 0.8243
#
# Epoch 00204: val_accuracy did not improve from 0.94595
# Epoch 205/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.6119 - val_accuracy: 0.8716
#
# Epoch 00205: val_accuracy did not improve from 0.94595
# Epoch 206/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0249 - accuracy: 0.9926 - val_loss: 0.4948 - val_accuracy: 0.9122
#
# Epoch 00206: val_accuracy did not improve from 0.94595
# Epoch 207/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0389 - accuracy: 0.9826 - val_loss: 0.4751 - val_accuracy: 0.8986
#
# Epoch 00207: val_accuracy did not improve from 0.94595
# Epoch 208/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0254 - accuracy: 0.9937 - val_loss: 0.5128 - val_accuracy: 0.9189
#
# Epoch 00208: val_accuracy did not improve from 0.94595
# Epoch 209/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.4576 - val_accuracy: 0.8716
#
# Epoch 00209: val_accuracy did not improve from 0.94595
# Epoch 210/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.5151 - val_accuracy: 0.8716
#
# Epoch 00210: val_accuracy did not improve from 0.94595
# Epoch 211/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0326 - accuracy: 0.9900 - val_loss: 0.9085 - val_accuracy: 0.8311
#
# Epoch 00211: val_accuracy did not improve from 0.94595
# Epoch 212/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.4165 - val_accuracy: 0.8716
#
# Epoch 00212: val_accuracy did not improve from 0.94595
# Epoch 213/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0126 - accuracy: 0.9953 - val_loss: 0.4906 - val_accuracy: 0.8851
#
# Epoch 00213: val_accuracy did not improve from 0.94595
# Epoch 214/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.5124 - val_accuracy: 0.8919
#
# Epoch 00214: val_accuracy did not improve from 0.94595
# Epoch 215/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.4358 - val_accuracy: 0.9054
#
# Epoch 00215: val_accuracy did not improve from 0.94595
# Epoch 216/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5029 - val_accuracy: 0.8919
#
# Epoch 00216: val_accuracy did not improve from 0.94595
# Epoch 217/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.3851 - val_accuracy: 0.8986
#
# Epoch 00217: val_accuracy did not improve from 0.94595
# Epoch 218/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0363 - accuracy: 0.9921 - val_loss: 0.4796 - val_accuracy: 0.8986
#
# Epoch 00218: val_accuracy did not improve from 0.94595
# Epoch 219/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0245 - accuracy: 0.9942 - val_loss: 0.6440 - val_accuracy: 0.8851
#
# Epoch 00219: val_accuracy did not improve from 0.94595
# Epoch 220/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0111 - accuracy: 0.9974 - val_loss: 0.5150 - val_accuracy: 0.8784
#
# Epoch 00220: val_accuracy did not improve from 0.94595
# Epoch 221/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 0.4832 - val_accuracy: 0.8851
#
# Epoch 00221: val_accuracy did not improve from 0.94595
# Epoch 222/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.5577 - val_accuracy: 0.8919
#
# Epoch 00222: val_accuracy did not improve from 0.94595
# Epoch 223/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.4062 - val_accuracy: 0.8851
#
# Epoch 00223: val_accuracy did not improve from 0.94595
# Epoch 224/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0391 - accuracy: 0.9921 - val_loss: 0.4821 - val_accuracy: 0.8784
#
# Epoch 00224: val_accuracy did not improve from 0.94595
# Epoch 225/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0205 - accuracy: 0.9947 - val_loss: 0.5442 - val_accuracy: 0.9122
#
# Epoch 00225: val_accuracy did not improve from 0.94595
# Epoch 226/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0342 - accuracy: 0.9905 - val_loss: 0.5837 - val_accuracy: 0.8514
#
# Epoch 00226: val_accuracy did not improve from 0.94595
# Epoch 227/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.4921 - val_accuracy: 0.8784
#
# Epoch 00227: val_accuracy did not improve from 0.94595
# Epoch 228/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.4108 - val_accuracy: 0.8851
#
# Epoch 00228: val_accuracy did not improve from 0.94595
# Epoch 229/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9189
#
# Epoch 00229: val_accuracy did not improve from 0.94595
# Epoch 230/500
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.96622
# Epoch 423/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0076 - accuracy: 0.9968 - val_loss: 0.4994 - val_accuracy: 0.9122
#
# Epoch 00423: val_accuracy did not improve from 0.96622
# Epoch 424/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.2737 - val_accuracy: 0.9324
#
# Epoch 00424: val_accuracy did not improve from 0.96622
# Epoch 425/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.4360 - val_accuracy: 0.9257
#
# Epoch 00425: val_accuracy did not improve from 0.96622
# Epoch 426/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0034 - accuracy: 0.9984 - val_loss: 0.4120 - val_accuracy: 0.9054
#
# Epoch 00426: val_accuracy did not improve from 0.96622
# Epoch 427/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.3821 - val_accuracy: 0.9392
#
# Epoch 00427: val_accuracy did not improve from 0.96622
# Epoch 428/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.3165 - val_accuracy: 0.9324
#
# Epoch 00428: val_accuracy did not improve from 0.96622
# Epoch 429/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0133 - accuracy: 0.9974 - val_loss: 0.8515 - val_accuracy: 0.8716
#
# Epoch 00429: val_accuracy did not improve from 0.96622
# Epoch 430/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.6915 - val_accuracy: 0.8514
#
# Epoch 00430: val_accuracy did not improve from 0.96622
# Epoch 431/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.5102 - val_accuracy: 0.9122
#
# Epoch 00431: val_accuracy did not improve from 0.96622
# Epoch 432/500
# 238/238 [==============================] - 14s 60ms/step - loss: 8.1106e-04 - accuracy: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.9122
#
# Epoch 00432: val_accuracy did not improve from 0.96622
# Epoch 433/500
# 238/238 [==============================] - 14s 60ms/step - loss: 7.4661e-04 - accuracy: 1.0000 - val_loss: 0.3829 - val_accuracy: 0.9189
#
# Epoch 00433: val_accuracy did not improve from 0.96622
# Epoch 434/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.8620 - val_accuracy: 0.8716
#
# Epoch 00434: val_accuracy did not improve from 0.96622
# Epoch 435/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.6082 - val_accuracy: 0.9122
#
# Epoch 00435: val_accuracy did not improve from 0.96622
# Epoch 436/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.5407 - val_accuracy: 0.8784
#
# Epoch 00436: val_accuracy did not improve from 0.96622
# Epoch 437/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.4382 - val_accuracy: 0.9257
#
# Epoch 00437: val_accuracy did not improve from 0.96622
# Epoch 438/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0142 - accuracy: 0.9979 - val_loss: 0.6161 - val_accuracy: 0.9257
#
# Epoch 00438: val_accuracy did not improve from 0.96622
# Epoch 439/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.4387 - val_accuracy: 0.9189
#
# Epoch 00439: val_accuracy did not improve from 0.96622
# Epoch 440/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0111 - accuracy: 0.9958 - val_loss: 0.5330 - val_accuracy: 0.9324
#
# Epoch 00440: val_accuracy did not improve from 0.96622
# Epoch 441/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0135 - accuracy: 0.9968 - val_loss: 0.6303 - val_accuracy: 0.9054
#
# Epoch 00441: val_accuracy did not improve from 0.96622
# Epoch 442/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.5170 - val_accuracy: 0.8919
#
# Epoch 00442: val_accuracy did not improve from 0.96622
# Epoch 443/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.4923 - val_accuracy: 0.9189
#
# Epoch 00443: val_accuracy did not improve from 0.96622
# Epoch 444/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.5117 - val_accuracy: 0.9122
#
# Epoch 00444: val_accuracy did not improve from 0.96622
# Epoch 445/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.6083 - val_accuracy: 0.8919
#
# Epoch 00445: val_accuracy did not improve from 0.96622
# Epoch 446/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0221 - accuracy: 0.9947 - val_loss: 0.4139 - val_accuracy: 0.9122
#
# Epoch 00446: val_accuracy did not improve from 0.96622
# Epoch 447/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.3165 - val_accuracy: 0.9324
#
# Epoch 00447: val_accuracy did not improve from 0.96622
# Epoch 448/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.7956 - val_accuracy: 0.8784
#
# Epoch 00448: val_accuracy did not improve from 0.96622
# Epoch 449/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.3373 - val_accuracy: 0.9189
#
# Epoch 00449: val_accuracy did not improve from 0.96622
# Epoch 450/500
# 238/238 [==============================] - 14s 60ms/step - loss: 3.8549e-04 - accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.9122
#
# Epoch 00450: val_accuracy did not improve from 0.96622
# Epoch 451/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.2654 - val_accuracy: 0.9392
#
# Epoch 00451: val_accuracy did not improve from 0.96622
# Epoch 452/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 1.0127 - val_accuracy: 0.8446
#
# Epoch 00452: val_accuracy did not improve from 0.96622
# Epoch 453/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.4140 - val_accuracy: 0.8919
#
# Epoch 00453: val_accuracy did not improve from 0.96622
# Epoch 454/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.4388 - val_accuracy: 0.8851
#
# Epoch 00454: val_accuracy did not improve from 0.96622
# Epoch 455/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3446 - val_accuracy: 0.9189
#
# Epoch 00455: val_accuracy did not improve from 0.96622
# Epoch 456/500
# 238/238 [==============================] - 14s 60ms/step - loss: 6.6193e-04 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.8919
#
# Epoch 00456: val_accuracy did not improve from 0.96622
# Epoch 457/500
# 238/238 [==============================] - 14s 60ms/step - loss: 6.8586e-04 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9257
#
# Epoch 00457: val_accuracy did not improve from 0.96622
# Epoch 458/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.5435 - val_accuracy: 0.9054
#
# Epoch 00458: val_accuracy did not improve from 0.96622
# Epoch 459/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.4695 - val_accuracy: 0.8986
#
# Epoch 00459: val_accuracy did not improve from 0.96622
# Epoch 460/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0308 - accuracy: 0.9911 - val_loss: 0.5939 - val_accuracy: 0.8784
#
# Epoch 00460: val_accuracy did not improve from 0.96622
# Epoch 461/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0156 - accuracy: 0.9942 - val_loss: 0.4716 - val_accuracy: 0.9189
#
# Epoch 00461: val_accuracy did not improve from 0.96622
# Epoch 462/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.5104 - val_accuracy: 0.9122
#
# Epoch 00462: val_accuracy did not improve from 0.96622
# Epoch 463/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.4958 - val_accuracy: 0.8851
#
# Epoch 00463: val_accuracy did not improve from 0.96622
# Epoch 464/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.4627 - val_accuracy: 0.8919
#
# Epoch 00464: val_accuracy did not improve from 0.96622
# Epoch 465/500
# 238/238 [==============================] - 14s 60ms/step - loss: 9.4692e-04 - accuracy: 1.0000 - val_loss: 0.3569 - val_accuracy: 0.9324
#
# Epoch 00465: val_accuracy did not improve from 0.96622
# Epoch 466/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.4241 - val_accuracy: 0.8986
#
# Epoch 00466: val_accuracy did not improve from 0.96622
# Epoch 467/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0160 - accuracy: 0.9963 - val_loss: 0.4019 - val_accuracy: 0.9122
#
# Epoch 00467: val_accuracy did not improve from 0.96622
# Epoch 468/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.3508 - val_accuracy: 0.9324
#
# Epoch 00468: val_accuracy did not improve from 0.96622
# Epoch 469/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.6949 - val_accuracy: 0.9122
#
# Epoch 00469: val_accuracy did not improve from 0.96622
# Epoch 470/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.4042 - val_accuracy: 0.9392
#
# Epoch 00470: val_accuracy did not improve from 0.96622
# Epoch 471/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.5254 - val_accuracy: 0.9189
#
# Epoch 00471: val_accuracy did not improve from 0.96622
# Epoch 472/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.7318 - val_accuracy: 0.8919
#
# Epoch 00472: val_accuracy did not improve from 0.96622
# Epoch 473/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0074 - accuracy: 0.9963 - val_loss: 0.8327 - val_accuracy: 0.8986
#
# Epoch 00473: val_accuracy did not improve from 0.96622
# Epoch 474/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0349 - accuracy: 0.9921 - val_loss: 0.8731 - val_accuracy: 0.8581
#
# Epoch 00474: val_accuracy did not improve from 0.96622
# Epoch 475/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.3611 - val_accuracy: 0.9324
#
# Epoch 00475: val_accuracy did not improve from 0.96622
# Epoch 476/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.3661 - val_accuracy: 0.9257
#
# Epoch 00476: val_accuracy did not improve from 0.96622
# Epoch 477/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.9324
#
# Epoch 00477: val_accuracy did not improve from 0.96622
# Epoch 478/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.4034 - val_accuracy: 0.9324
#
# Epoch 00478: val_accuracy did not improve from 0.96622
# Epoch 479/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.9459
#
# Epoch 00479: val_accuracy did not improve from 0.96622
# Epoch 480/500
# 238/238 [==============================] - 14s 60ms/step - loss: 9.7425e-04 - accuracy: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.9122
#
# Epoch 00480: val_accuracy did not improve from 0.96622
# Epoch 481/500
# 238/238 [==============================] - 14s 60ms/step - loss: 6.9057e-04 - accuracy: 1.0000 - val_loss: 0.4203 - val_accuracy: 0.9054
#
# Epoch 00481: val_accuracy did not improve from 0.96622
# Epoch 482/500
# 238/238 [==============================] - 14s 60ms/step - loss: 5.7856e-04 - accuracy: 1.0000 - val_loss: 0.4648 - val_accuracy: 0.9054
#
# Epoch 00482: val_accuracy did not improve from 0.96622
# Epoch 483/500
# 238/238 [==============================] - 14s 60ms/step - loss: 4.3329e-04 - accuracy: 1.0000 - val_loss: 0.3601 - val_accuracy: 0.9189
#
# Epoch 00483: val_accuracy did not improve from 0.96622
# Epoch 484/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0153 - accuracy: 0.9963 - val_loss: 0.5617 - val_accuracy: 0.8716
#
# Epoch 00484: val_accuracy did not improve from 0.96622
# Epoch 485/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.4612 - val_accuracy: 0.9257
#
# Epoch 00485: val_accuracy did not improve from 0.96622
# Epoch 486/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0096 - accuracy: 0.9958 - val_loss: 0.4742 - val_accuracy: 0.9122
#
# Epoch 00486: val_accuracy did not improve from 0.96622
# Epoch 487/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.6552 - val_accuracy: 0.8851
#
# Epoch 00487: val_accuracy did not improve from 0.96622
# Epoch 488/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.4874 - val_accuracy: 0.8919
#
# Epoch 00488: val_accuracy did not improve from 0.96622
# Epoch 489/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.3502 - val_accuracy: 0.9324
#
# Epoch 00489: val_accuracy did not improve from 0.96622
# Epoch 490/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.5463 - val_accuracy: 0.9054
#
# Epoch 00490: val_accuracy did not improve from 0.96622
# Epoch 491/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0097 - accuracy: 0.9979 - val_loss: 0.4058 - val_accuracy: 0.9392
#
# Epoch 00491: val_accuracy did not improve from 0.96622
# Epoch 492/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0043 - accuracy: 0.9979 - val_loss: 0.4391 - val_accuracy: 0.8986
#
# Epoch 00492: val_accuracy did not improve from 0.96622
# Epoch 493/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.4635 - val_accuracy: 0.8986
#
# Epoch 00493: val_accuracy did not improve from 0.96622
# Epoch 494/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.4343 - val_accuracy: 0.9189
#
# Epoch 00494: val_accuracy did not improve from 0.96622
# Epoch 495/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.4302 - val_accuracy: 0.9257
#
# Epoch 00495: val_accuracy did not improve from 0.96622
# Epoch 496/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0183 - accuracy: 0.9963 - val_loss: 0.5864 - val_accuracy: 0.8919
#
# Epoch 00496: val_accuracy did not improve from 0.96622
# Epoch 497/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0081 - accuracy: 0.9979 - val_loss: 0.3345 - val_accuracy: 0.9527
#
# Epoch 00497: val_accuracy did not improve from 0.96622
# Epoch 498/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.2993 - val_accuracy: 0.9527
#
# Epoch 00498: val_accuracy did not improve from 0.96622
# Epoch 499/500
# 238/238 [==============================] - 14s 60ms/step - loss: 6.1421e-04 - accuracy: 1.0000 - val_loss: 0.4350 - val_accuracy: 0.9392
#
# Epoch 00499: val_accuracy did not improve from 0.96622
# Epoch 500/500
# 238/238 [==============================] - 14s 60ms/step - loss: 7.8899e-04 - accuracy: 1.0000 - val_loss: 0.4261 - val_accuracy: 0.9257
#
# Epoch 00500: val_accuracy did not improve from 0.96622

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    'iDeal9',
    # dodo9249@gmail.com 팀이름
    # 'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': True, 'detail': 'Success'}
