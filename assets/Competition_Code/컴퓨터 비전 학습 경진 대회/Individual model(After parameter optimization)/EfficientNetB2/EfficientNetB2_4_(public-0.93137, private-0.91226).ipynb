# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/EfficientNetB2_4_(public-%2C%20private-).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Sep 28 19:36:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
nunbering = '2'
model_save = 'EfficientNetB' + nunbering + '_4'
Target_model = 'EfficientNetB' + nunbering + '_model'
Target_predict = 'EfficientNetB' + nunbering + '_predict'
Target_acc = 'EfficientNetB' + nunbering + '_acc'
Target_val = 'EfficientNetB' + nunbering + '_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.EfficientNetB2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 55s 120ms/step - loss: 3.4662 - accuracy: 0.1295 - val_loss: 2.8573 - val_accuracy: 0.1014
#
# Epoch 00001: val_accuracy improved from -inf to 0.10135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 27s 112ms/step - loss: 2.4374 - accuracy: 0.1695 - val_loss: 2.9308 - val_accuracy: 0.1014
#
# Epoch 00002: val_accuracy did not improve from 0.10135
# Epoch 3/500
# 238/238 [==============================] - 27s 112ms/step - loss: 2.0664 - accuracy: 0.2768 - val_loss: 2.4118 - val_accuracy: 0.1284
#
# Epoch 00003: val_accuracy improved from 0.10135 to 0.12838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 4/500
# 238/238 [==============================] - 27s 112ms/step - loss: 1.6540 - accuracy: 0.4316 - val_loss: 2.0582 - val_accuracy: 0.3986
#
# Epoch 00004: val_accuracy improved from 0.12838 to 0.39865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 5/500
# 238/238 [==============================] - 27s 111ms/step - loss: 1.3252 - accuracy: 0.5611 - val_loss: 1.2018 - val_accuracy: 0.6284
#
# Epoch 00005: val_accuracy improved from 0.39865 to 0.62838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 6/500
# 238/238 [==============================] - 27s 112ms/step - loss: 1.1026 - accuracy: 0.6437 - val_loss: 0.6340 - val_accuracy: 0.7770
#
# Epoch 00006: val_accuracy improved from 0.62838 to 0.77703, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 7/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.9168 - accuracy: 0.7042 - val_loss: 0.8657 - val_accuracy: 0.7297
#
# Epoch 00007: val_accuracy did not improve from 0.77703
# Epoch 8/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.8168 - accuracy: 0.7311 - val_loss: 1.2555 - val_accuracy: 0.6216
#
# Epoch 00008: val_accuracy did not improve from 0.77703
# Epoch 9/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.7370 - accuracy: 0.7621 - val_loss: 2.8890 - val_accuracy: 0.3041
#
# Epoch 00009: val_accuracy did not improve from 0.77703
# Epoch 10/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.6603 - accuracy: 0.7874 - val_loss: 0.9689 - val_accuracy: 0.7297
#
# Epoch 00010: val_accuracy did not improve from 0.77703
# Epoch 11/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.6004 - accuracy: 0.8026 - val_loss: 4.1482 - val_accuracy: 0.3378
#
# Epoch 00011: val_accuracy did not improve from 0.77703
# Epoch 12/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.5923 - accuracy: 0.8126 - val_loss: 0.8359 - val_accuracy: 0.7230
#
# Epoch 00012: val_accuracy did not improve from 0.77703
# Epoch 13/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.5172 - accuracy: 0.8389 - val_loss: 1.2081 - val_accuracy: 0.6419
#
# Epoch 00013: val_accuracy did not improve from 0.77703
# Epoch 14/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.4764 - accuracy: 0.8400 - val_loss: 0.5857 - val_accuracy: 0.8108
#
# Epoch 00014: val_accuracy improved from 0.77703 to 0.81081, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 15/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.5047 - accuracy: 0.8337 - val_loss: 0.4971 - val_accuracy: 0.8514
#
# Epoch 00015: val_accuracy improved from 0.81081 to 0.85135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 16/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.4803 - accuracy: 0.8468 - val_loss: 1.7484 - val_accuracy: 0.5000
#
# Epoch 00016: val_accuracy did not improve from 0.85135
# Epoch 17/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.4606 - accuracy: 0.8495 - val_loss: 0.6651 - val_accuracy: 0.7500
#
# Epoch 00017: val_accuracy did not improve from 0.85135
# Epoch 18/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.4357 - accuracy: 0.8668 - val_loss: 0.6267 - val_accuracy: 0.8378
#
# Epoch 00018: val_accuracy did not improve from 0.85135
# Epoch 19/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.3907 - accuracy: 0.8737 - val_loss: 0.3955 - val_accuracy: 0.8649
#
# Epoch 00019: val_accuracy improved from 0.85135 to 0.86486, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 20/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.4189 - accuracy: 0.8637 - val_loss: 0.5620 - val_accuracy: 0.8311
#
# Epoch 00020: val_accuracy did not improve from 0.86486
# Epoch 21/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.3869 - accuracy: 0.8795 - val_loss: 0.5720 - val_accuracy: 0.7838
#
# Epoch 00021: val_accuracy did not improve from 0.86486
# Epoch 22/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.3658 - accuracy: 0.8842 - val_loss: 1.2527 - val_accuracy: 0.6689
#
# Epoch 00022: val_accuracy did not improve from 0.86486
# Epoch 23/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.3248 - accuracy: 0.8900 - val_loss: 0.9491 - val_accuracy: 0.7297
#
# Epoch 00023: val_accuracy did not improve from 0.86486
# Epoch 24/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.3466 - accuracy: 0.8884 - val_loss: 3.5187 - val_accuracy: 0.2568
#
# Epoch 00024: val_accuracy did not improve from 0.86486
# Epoch 25/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.3164 - accuracy: 0.9042 - val_loss: 0.5960 - val_accuracy: 0.8514
#
# Epoch 00025: val_accuracy did not improve from 0.86486
# Epoch 26/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.2821 - accuracy: 0.9153 - val_loss: 1.1861 - val_accuracy: 0.7162
#
# Epoch 00026: val_accuracy did not improve from 0.86486
# Epoch 27/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.3111 - accuracy: 0.9079 - val_loss: 0.3938 - val_accuracy: 0.8919
#
# Epoch 00027: val_accuracy improved from 0.86486 to 0.89189, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 28/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2754 - accuracy: 0.9111 - val_loss: 1.0059 - val_accuracy: 0.7500
#
# Epoch 00028: val_accuracy did not improve from 0.89189
# Epoch 29/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2772 - accuracy: 0.9105 - val_loss: 0.7488 - val_accuracy: 0.8176
#
# Epoch 00029: val_accuracy did not improve from 0.89189
# Epoch 30/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2668 - accuracy: 0.9047 - val_loss: 0.7963 - val_accuracy: 0.8108
#
# Epoch 00030: val_accuracy did not improve from 0.89189
# Epoch 31/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.2573 - accuracy: 0.9168 - val_loss: 0.4505 - val_accuracy: 0.8581
#
# Epoch 00031: val_accuracy did not improve from 0.89189
# Epoch 32/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.2863 - accuracy: 0.9158 - val_loss: 1.7593 - val_accuracy: 0.5068
#
# Epoch 00032: val_accuracy did not improve from 0.89189
# Epoch 33/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.2147 - accuracy: 0.9353 - val_loss: 2.6348 - val_accuracy: 0.4189
#
# Epoch 00033: val_accuracy did not improve from 0.89189
# Epoch 34/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2638 - accuracy: 0.9163 - val_loss: 0.8035 - val_accuracy: 0.8041
#
# Epoch 00034: val_accuracy did not improve from 0.89189
# Epoch 35/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.2275 - accuracy: 0.9253 - val_loss: 0.5322 - val_accuracy: 0.8716
#
# Epoch 00035: val_accuracy did not improve from 0.89189
# Epoch 36/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2208 - accuracy: 0.9305 - val_loss: 2.2059 - val_accuracy: 0.5676
#
# Epoch 00036: val_accuracy did not improve from 0.89189
# Epoch 37/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2204 - accuracy: 0.9326 - val_loss: 6.9843 - val_accuracy: 0.1824
#
# Epoch 00037: val_accuracy did not improve from 0.89189
# Epoch 38/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.2218 - accuracy: 0.9226 - val_loss: 0.4945 - val_accuracy: 0.8446
#
# Epoch 00038: val_accuracy did not improve from 0.89189
# Epoch 39/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.1593 - accuracy: 0.9474 - val_loss: 0.6871 - val_accuracy: 0.8311
#
# Epoch 00039: val_accuracy did not improve from 0.89189
# Epoch 40/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.1869 - accuracy: 0.9400 - val_loss: 1.5212 - val_accuracy: 0.6014
#
# Epoch 00040: val_accuracy did not improve from 0.89189
# Epoch 41/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.2004 - accuracy: 0.9337 - val_loss: 0.3513 - val_accuracy: 0.9122
#
# Epoch 00041: val_accuracy improved from 0.89189 to 0.91216, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 42/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.1954 - accuracy: 0.9395 - val_loss: 0.3365 - val_accuracy: 0.8851
#
# Epoch 00042: val_accuracy did not improve from 0.91216
# Epoch 43/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1611 - accuracy: 0.9447 - val_loss: 0.9667 - val_accuracy: 0.7770
#
# Epoch 00043: val_accuracy did not improve from 0.91216
# Epoch 44/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1782 - accuracy: 0.9495 - val_loss: 0.8944 - val_accuracy: 0.8243
#
# Epoch 00044: val_accuracy did not improve from 0.91216
# Epoch 45/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1616 - accuracy: 0.9495 - val_loss: 0.3226 - val_accuracy: 0.8919
#
# Epoch 00045: val_accuracy did not improve from 0.91216
# Epoch 46/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1528 - accuracy: 0.9489 - val_loss: 1.3850 - val_accuracy: 0.7365
#
# Epoch 00046: val_accuracy did not improve from 0.91216
# Epoch 47/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1728 - accuracy: 0.9453 - val_loss: 0.4766 - val_accuracy: 0.8649
#
# Epoch 00047: val_accuracy did not improve from 0.91216
# Epoch 48/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1591 - accuracy: 0.9500 - val_loss: 0.6943 - val_accuracy: 0.8378
#
# Epoch 00048: val_accuracy did not improve from 0.91216
# Epoch 49/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.1453 - accuracy: 0.9511 - val_loss: 0.4339 - val_accuracy: 0.8581
#
# Epoch 00049: val_accuracy did not improve from 0.91216
# Epoch 50/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1759 - accuracy: 0.9442 - val_loss: 0.8234 - val_accuracy: 0.8378
#
# Epoch 00050: val_accuracy did not improve from 0.91216
# Epoch 51/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1319 - accuracy: 0.9616 - val_loss: 0.4213 - val_accuracy: 0.8784
#
# Epoch 00051: val_accuracy did not improve from 0.91216
# Epoch 52/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.1224 - accuracy: 0.9605 - val_loss: 0.4988 - val_accuracy: 0.8784
#
# Epoch 00052: val_accuracy did not improve from 0.91216
# Epoch 53/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1285 - accuracy: 0.9589 - val_loss: 0.5258 - val_accuracy: 0.8919
#
# Epoch 00053: val_accuracy did not improve from 0.91216
# Epoch 54/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1251 - accuracy: 0.9568 - val_loss: 5.2641 - val_accuracy: 0.3378
#
# Epoch 00054: val_accuracy did not improve from 0.91216
# Epoch 55/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1613 - accuracy: 0.9500 - val_loss: 2.4878 - val_accuracy: 0.5811
#
# Epoch 00055: val_accuracy did not improve from 0.91216
# Epoch 56/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.1389 - accuracy: 0.9600 - val_loss: 0.6516 - val_accuracy: 0.8243
#
# Epoch 00056: val_accuracy did not improve from 0.91216
# Epoch 57/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1185 - accuracy: 0.9584 - val_loss: 0.6163 - val_accuracy: 0.8581
#
# Epoch 00057: val_accuracy did not improve from 0.91216
# Epoch 58/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0918 - accuracy: 0.9732 - val_loss: 1.0016 - val_accuracy: 0.7973
#
# Epoch 00058: val_accuracy did not improve from 0.91216
# Epoch 59/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0894 - accuracy: 0.9700 - val_loss: 1.1563 - val_accuracy: 0.7297
#
# Epoch 00059: val_accuracy did not improve from 0.91216
# Epoch 60/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1198 - accuracy: 0.9621 - val_loss: 0.6042 - val_accuracy: 0.8851
#
# Epoch 00060: val_accuracy did not improve from 0.91216
# Epoch 61/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1416 - accuracy: 0.9542 - val_loss: 0.5143 - val_accuracy: 0.8514
#
# Epoch 00061: val_accuracy did not improve from 0.91216
# Epoch 62/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.1013 - accuracy: 0.9647 - val_loss: 0.4908 - val_accuracy: 0.8784
#
# Epoch 00062: val_accuracy did not improve from 0.91216
# Epoch 63/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.1240 - accuracy: 0.9658 - val_loss: 2.2266 - val_accuracy: 0.6419
#
# Epoch 00063: val_accuracy did not improve from 0.91216
# Epoch 64/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0876 - accuracy: 0.9695 - val_loss: 1.6365 - val_accuracy: 0.6959
#
# Epoch 00064: val_accuracy did not improve from 0.91216
# Epoch 65/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0965 - accuracy: 0.9658 - val_loss: 0.6656 - val_accuracy: 0.8649
#
# Epoch 00065: val_accuracy did not improve from 0.91216
# Epoch 66/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.1115 - accuracy: 0.9626 - val_loss: 0.6762 - val_accuracy: 0.8108
#
# Epoch 00066: val_accuracy did not improve from 0.91216
# Epoch 67/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1343 - accuracy: 0.9616 - val_loss: 0.3701 - val_accuracy: 0.9054
#
# Epoch 00067: val_accuracy did not improve from 0.91216
# Epoch 68/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0989 - accuracy: 0.9689 - val_loss: 0.4482 - val_accuracy: 0.8851
#
# Epoch 00068: val_accuracy did not improve from 0.91216
# Epoch 69/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1213 - accuracy: 0.9621 - val_loss: 0.8558 - val_accuracy: 0.8311
#
# Epoch 00069: val_accuracy did not improve from 0.91216
# Epoch 70/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0817 - accuracy: 0.9742 - val_loss: 0.4559 - val_accuracy: 0.8851
#
# Epoch 00070: val_accuracy did not improve from 0.91216
# Epoch 71/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.1068 - accuracy: 0.9658 - val_loss: 0.7195 - val_accuracy: 0.8311
#
# Epoch 00071: val_accuracy did not improve from 0.91216
# Epoch 72/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0922 - accuracy: 0.9684 - val_loss: 0.4922 - val_accuracy: 0.9054
#
# Epoch 00072: val_accuracy did not improve from 0.91216
# Epoch 73/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0829 - accuracy: 0.9747 - val_loss: 0.7759 - val_accuracy: 0.8446
#
# Epoch 00073: val_accuracy did not improve from 0.91216
# Epoch 74/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.1218 - accuracy: 0.9626 - val_loss: 1.6793 - val_accuracy: 0.6622
#
# Epoch 00074: val_accuracy did not improve from 0.91216
# Epoch 75/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0841 - accuracy: 0.9768 - val_loss: 0.4261 - val_accuracy: 0.9054
#
# Epoch 00075: val_accuracy did not improve from 0.91216
# Epoch 76/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0605 - accuracy: 0.9816 - val_loss: 0.4757 - val_accuracy: 0.8986
#
# Epoch 00076: val_accuracy did not improve from 0.91216
# Epoch 77/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.1010 - accuracy: 0.9716 - val_loss: 2.6736 - val_accuracy: 0.6622
#
# Epoch 00077: val_accuracy did not improve from 0.91216
# Epoch 78/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0954 - accuracy: 0.9668 - val_loss: 1.8442 - val_accuracy: 0.6149
#
# Epoch 00078: val_accuracy did not improve from 0.91216
# Epoch 79/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0967 - accuracy: 0.9658 - val_loss: 0.6198 - val_accuracy: 0.8919
#
# Epoch 00079: val_accuracy did not improve from 0.91216
# Epoch 80/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0950 - accuracy: 0.9695 - val_loss: 0.6709 - val_accuracy: 0.8784
#
# Epoch 00080: val_accuracy did not improve from 0.91216
# Epoch 81/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.1032 - accuracy: 0.9668 - val_loss: 1.2948 - val_accuracy: 0.7095
#
# Epoch 00081: val_accuracy did not improve from 0.91216
# Epoch 82/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0891 - accuracy: 0.9742 - val_loss: 1.3525 - val_accuracy: 0.7297
#
# Epoch 00082: val_accuracy did not improve from 0.91216
# Epoch 83/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0780 - accuracy: 0.9711 - val_loss: 0.9332 - val_accuracy: 0.8514
#
# Epoch 00083: val_accuracy did not improve from 0.91216
# Epoch 84/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0673 - accuracy: 0.9805 - val_loss: 0.6196 - val_accuracy: 0.8716
#
# Epoch 00084: val_accuracy did not improve from 0.91216
# Epoch 85/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0553 - accuracy: 0.9811 - val_loss: 0.4710 - val_accuracy: 0.8716
#
# Epoch 00085: val_accuracy did not improve from 0.91216
# Epoch 86/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0825 - accuracy: 0.9732 - val_loss: 0.4008 - val_accuracy: 0.9122
#
# Epoch 00086: val_accuracy did not improve from 0.91216
# Epoch 87/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0747 - accuracy: 0.9753 - val_loss: 1.0013 - val_accuracy: 0.8243
#
# Epoch 00087: val_accuracy did not improve from 0.91216
# Epoch 88/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0414 - accuracy: 0.9889 - val_loss: 0.5052 - val_accuracy: 0.9054
#
# Epoch 00088: val_accuracy did not improve from 0.91216
# Epoch 89/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0890 - accuracy: 0.9705 - val_loss: 7.1913 - val_accuracy: 0.0946
#
# Epoch 00089: val_accuracy did not improve from 0.91216
# Epoch 90/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0902 - accuracy: 0.9732 - val_loss: 0.6107 - val_accuracy: 0.8986
#
# Epoch 00090: val_accuracy did not improve from 0.91216
# Epoch 91/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0548 - accuracy: 0.9853 - val_loss: 0.5975 - val_accuracy: 0.8784
#
# Epoch 00091: val_accuracy did not improve from 0.91216
# Epoch 92/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0503 - accuracy: 0.9837 - val_loss: 0.3832 - val_accuracy: 0.9122
#
# Epoch 00092: val_accuracy did not improve from 0.91216
# Epoch 93/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0617 - accuracy: 0.9800 - val_loss: 0.4669 - val_accuracy: 0.8851
#
# Epoch 00093: val_accuracy did not improve from 0.91216
# Epoch 94/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0446 - accuracy: 0.9837 - val_loss: 1.5417 - val_accuracy: 0.7635
#
# Epoch 00094: val_accuracy did not improve from 0.91216
# Epoch 95/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0853 - accuracy: 0.9768 - val_loss: 0.5068 - val_accuracy: 0.8851
#
# Epoch 00095: val_accuracy did not improve from 0.91216
# Epoch 96/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0729 - accuracy: 0.9805 - val_loss: 0.6188 - val_accuracy: 0.8649
#
# Epoch 00096: val_accuracy did not improve from 0.91216
# Epoch 97/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0934 - accuracy: 0.9695 - val_loss: 0.5080 - val_accuracy: 0.8851
#
# Epoch 00097: val_accuracy did not improve from 0.91216
# Epoch 98/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0657 - accuracy: 0.9811 - val_loss: 0.3738 - val_accuracy: 0.9324
#
# Epoch 00098: val_accuracy improved from 0.91216 to 0.93243, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 99/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0702 - accuracy: 0.9779 - val_loss: 0.5684 - val_accuracy: 0.8784
#
# Epoch 00099: val_accuracy did not improve from 0.93243
# Epoch 100/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0713 - accuracy: 0.9774 - val_loss: 0.5303 - val_accuracy: 0.8919
#
# Epoch 00100: val_accuracy did not improve from 0.93243
# Epoch 101/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0475 - accuracy: 0.9863 - val_loss: 0.4191 - val_accuracy: 0.8851
#
# Epoch 00101: val_accuracy did not improve from 0.93243
# Epoch 102/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0799 - accuracy: 0.9726 - val_loss: 0.5944 - val_accuracy: 0.8514
#
# Epoch 00102: val_accuracy did not improve from 0.93243
# Epoch 103/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0521 - accuracy: 0.9837 - val_loss: 0.5185 - val_accuracy: 0.8986
#
# Epoch 00103: val_accuracy did not improve from 0.93243
# Epoch 104/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0753 - accuracy: 0.9784 - val_loss: 0.6225 - val_accuracy: 0.8784
#
# Epoch 00104: val_accuracy did not improve from 0.93243
# Epoch 105/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0482 - accuracy: 0.9821 - val_loss: 0.4448 - val_accuracy: 0.8986
#
# Epoch 00105: val_accuracy did not improve from 0.93243
# Epoch 106/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0605 - accuracy: 0.9805 - val_loss: 0.6149 - val_accuracy: 0.8851
#
# Epoch 00106: val_accuracy did not improve from 0.93243
# Epoch 107/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0680 - accuracy: 0.9795 - val_loss: 1.7026 - val_accuracy: 0.7162
#
# Epoch 00107: val_accuracy did not improve from 0.93243
# Epoch 108/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0714 - accuracy: 0.9774 - val_loss: 0.6589 - val_accuracy: 0.9054
#
# Epoch 00108: val_accuracy did not improve from 0.93243
# Epoch 109/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0549 - accuracy: 0.9800 - val_loss: 0.7662 - val_accuracy: 0.8851
#
# Epoch 00109: val_accuracy did not improve from 0.93243
# Epoch 110/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0443 - accuracy: 0.9847 - val_loss: 0.4401 - val_accuracy: 0.9054
#
# Epoch 00110: val_accuracy did not improve from 0.93243
# Epoch 111/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0431 - accuracy: 0.9879 - val_loss: 0.4574 - val_accuracy: 0.8986
#
# Epoch 00111: val_accuracy did not improve from 0.93243
# Epoch 112/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0483 - accuracy: 0.9842 - val_loss: 0.7980 - val_accuracy: 0.8649
#
# Epoch 00112: val_accuracy did not improve from 0.93243
# Epoch 113/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0605 - accuracy: 0.9837 - val_loss: 1.7615 - val_accuracy: 0.7095
#
# Epoch 00113: val_accuracy did not improve from 0.93243
# Epoch 114/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0866 - accuracy: 0.9747 - val_loss: 3.4319 - val_accuracy: 0.3851
#
# Epoch 00114: val_accuracy did not improve from 0.93243
# Epoch 115/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0610 - accuracy: 0.9784 - val_loss: 0.8285 - val_accuracy: 0.8446
#
# Epoch 00115: val_accuracy did not improve from 0.93243
# Epoch 116/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0534 - accuracy: 0.9842 - val_loss: 0.3845 - val_accuracy: 0.9054
#
# Epoch 00116: val_accuracy did not improve from 0.93243
# Epoch 117/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.7038 - val_accuracy: 0.8716
#
# Epoch 00117: val_accuracy did not improve from 0.93243
# Epoch 118/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0525 - accuracy: 0.9837 - val_loss: 0.6864 - val_accuracy: 0.8784
#
# Epoch 00118: val_accuracy did not improve from 0.93243
# Epoch 119/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0622 - accuracy: 0.9821 - val_loss: 0.4821 - val_accuracy: 0.8919
#
# Epoch 00119: val_accuracy did not improve from 0.93243
# Epoch 120/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0425 - accuracy: 0.9847 - val_loss: 1.2153 - val_accuracy: 0.7568
#
# Epoch 00120: val_accuracy did not improve from 0.93243
# Epoch 121/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0397 - accuracy: 0.9884 - val_loss: 1.9574 - val_accuracy: 0.6892
#
# Epoch 00121: val_accuracy did not improve from 0.93243
# Epoch 122/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0352 - accuracy: 0.9889 - val_loss: 2.3814 - val_accuracy: 0.6351
#
# Epoch 00122: val_accuracy did not improve from 0.93243
# Epoch 123/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0677 - accuracy: 0.9763 - val_loss: 0.5513 - val_accuracy: 0.8986
#
# Epoch 00123: val_accuracy did not improve from 0.93243
# Epoch 124/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0443 - accuracy: 0.9842 - val_loss: 0.4790 - val_accuracy: 0.9257
#
# Epoch 00124: val_accuracy did not improve from 0.93243
# Epoch 125/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0533 - accuracy: 0.9837 - val_loss: 0.7497 - val_accuracy: 0.8784
#
# Epoch 00125: val_accuracy did not improve from 0.93243
# Epoch 126/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0713 - accuracy: 0.9753 - val_loss: 0.8765 - val_accuracy: 0.8581
#
# Epoch 00126: val_accuracy did not improve from 0.93243
# Epoch 127/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0611 - accuracy: 0.9826 - val_loss: 0.5532 - val_accuracy: 0.8716
#
# Epoch 00127: val_accuracy did not improve from 0.93243
# Epoch 128/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0343 - accuracy: 0.9874 - val_loss: 0.6172 - val_accuracy: 0.8514
#
# Epoch 00128: val_accuracy did not improve from 0.93243
# Epoch 129/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0531 - accuracy: 0.9821 - val_loss: 0.7087 - val_accuracy: 0.8851
#
# Epoch 00129: val_accuracy did not improve from 0.93243
# Epoch 130/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0464 - accuracy: 0.9842 - val_loss: 0.6103 - val_accuracy: 0.8986
#
# Epoch 00130: val_accuracy did not improve from 0.93243
# Epoch 131/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0435 - accuracy: 0.9895 - val_loss: 0.4929 - val_accuracy: 0.8716
#
# Epoch 00131: val_accuracy did not improve from 0.93243
# Epoch 132/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0376 - accuracy: 0.9889 - val_loss: 0.6384 - val_accuracy: 0.8919
#
# Epoch 00132: val_accuracy did not improve from 0.93243
# Epoch 133/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0401 - accuracy: 0.9884 - val_loss: 0.4501 - val_accuracy: 0.9054
#
# Epoch 00133: val_accuracy did not improve from 0.93243
# Epoch 134/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0196 - accuracy: 0.9947 - val_loss: 0.6352 - val_accuracy: 0.8919
#
# Epoch 00134: val_accuracy did not improve from 0.93243
# Epoch 135/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0711 - accuracy: 0.9763 - val_loss: 0.5737 - val_accuracy: 0.8716
#
# Epoch 00135: val_accuracy did not improve from 0.93243
# Epoch 136/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0380 - accuracy: 0.9842 - val_loss: 0.6560 - val_accuracy: 0.8716
#
# Epoch 00136: val_accuracy did not improve from 0.93243
# Epoch 137/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0533 - accuracy: 0.9847 - val_loss: 0.5869 - val_accuracy: 0.8784
#
# Epoch 00137: val_accuracy did not improve from 0.93243
# Epoch 138/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0527 - accuracy: 0.9853 - val_loss: 0.6059 - val_accuracy: 0.8784
#
# Epoch 00138: val_accuracy did not improve from 0.93243
# Epoch 139/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 1.5405 - val_accuracy: 0.7500
#
# Epoch 00139: val_accuracy did not improve from 0.93243
# Epoch 140/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0334 - accuracy: 0.9911 - val_loss: 0.5197 - val_accuracy: 0.8851
#
# Epoch 00140: val_accuracy did not improve from 0.93243
# Epoch 141/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.6168 - val_accuracy: 0.8784
#
# Epoch 00141: val_accuracy did not improve from 0.93243
# Epoch 142/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0912 - accuracy: 0.9753 - val_loss: 0.6132 - val_accuracy: 0.8784
#
# Epoch 00142: val_accuracy did not improve from 0.93243
# Epoch 143/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0361 - accuracy: 0.9853 - val_loss: 0.6693 - val_accuracy: 0.8784
#
# Epoch 00143: val_accuracy did not improve from 0.93243
# Epoch 144/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.8186 - val_accuracy: 0.8514
#
# Epoch 00144: val_accuracy did not improve from 0.93243
# Epoch 145/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0678 - accuracy: 0.9795 - val_loss: 0.6104 - val_accuracy: 0.8716
#
# Epoch 00145: val_accuracy did not improve from 0.93243
# Epoch 146/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0573 - accuracy: 0.9800 - val_loss: 0.9067 - val_accuracy: 0.8514
#
# Epoch 00146: val_accuracy did not improve from 0.93243
# Epoch 147/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0334 - accuracy: 0.9900 - val_loss: 0.6684 - val_accuracy: 0.9189
#
# Epoch 00147: val_accuracy did not improve from 0.93243
# Epoch 148/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0240 - accuracy: 0.9932 - val_loss: 0.7353 - val_accuracy: 0.8716
#
# Epoch 00148: val_accuracy did not improve from 0.93243
# Epoch 149/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0639 - accuracy: 0.9826 - val_loss: 0.5420 - val_accuracy: 0.8919
#
# Epoch 00149: val_accuracy did not improve from 0.93243
# Epoch 150/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.4892 - val_accuracy: 0.9189
#
# Epoch 00150: val_accuracy did not improve from 0.93243
# Epoch 151/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0350 - accuracy: 0.9884 - val_loss: 0.6813 - val_accuracy: 0.8919
#
# Epoch 00151: val_accuracy did not improve from 0.93243
# Epoch 152/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0222 - accuracy: 0.9916 - val_loss: 0.7289 - val_accuracy: 0.9122
#
# Epoch 00152: val_accuracy did not improve from 0.93243
# Epoch 153/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0528 - accuracy: 0.9863 - val_loss: 1.1006 - val_accuracy: 0.8041
#
# Epoch 00153: val_accuracy did not improve from 0.93243
# Epoch 154/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0653 - accuracy: 0.9842 - val_loss: 0.5663 - val_accuracy: 0.8919
#
# Epoch 00154: val_accuracy did not improve from 0.93243
# Epoch 155/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0411 - accuracy: 0.9847 - val_loss: 0.6143 - val_accuracy: 0.8986
#
# Epoch 00155: val_accuracy did not improve from 0.93243
# Epoch 156/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0269 - accuracy: 0.9905 - val_loss: 0.6719 - val_accuracy: 0.8581
#
# Epoch 00156: val_accuracy did not improve from 0.93243
# Epoch 157/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0208 - accuracy: 0.9942 - val_loss: 0.6135 - val_accuracy: 0.8784
#
# Epoch 00157: val_accuracy did not improve from 0.93243
# Epoch 158/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0504 - accuracy: 0.9837 - val_loss: 0.4711 - val_accuracy: 0.9054
#
# Epoch 00158: val_accuracy did not improve from 0.93243
# Epoch 159/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0427 - accuracy: 0.9858 - val_loss: 3.2041 - val_accuracy: 0.6081
#
# Epoch 00159: val_accuracy did not improve from 0.93243
# Epoch 160/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0413 - accuracy: 0.9889 - val_loss: 2.4571 - val_accuracy: 0.5608
#
# Epoch 00160: val_accuracy did not improve from 0.93243
# Epoch 161/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0285 - accuracy: 0.9921 - val_loss: 0.5484 - val_accuracy: 0.8851
#
# Epoch 00161: val_accuracy did not improve from 0.93243
# Epoch 162/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 0.8596 - val_accuracy: 0.8581
#
# Epoch 00162: val_accuracy did not improve from 0.93243
# Epoch 163/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0673 - accuracy: 0.9811 - val_loss: 1.0226 - val_accuracy: 0.7770
#
# Epoch 00163: val_accuracy did not improve from 0.93243
# Epoch 164/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0570 - accuracy: 0.9800 - val_loss: 1.7725 - val_accuracy: 0.7230
#
# Epoch 00164: val_accuracy did not improve from 0.93243
# Epoch 165/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.9842 - val_accuracy: 0.8784
#
# Epoch 00165: val_accuracy did not improve from 0.93243
# Epoch 166/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0568 - accuracy: 0.9842 - val_loss: 0.6286 - val_accuracy: 0.8716
#
# Epoch 00166: val_accuracy did not improve from 0.93243
# Epoch 167/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0349 - accuracy: 0.9874 - val_loss: 0.7455 - val_accuracy: 0.8986
#
# Epoch 00167: val_accuracy did not improve from 0.93243
# Epoch 168/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0347 - accuracy: 0.9879 - val_loss: 0.5501 - val_accuracy: 0.8986
#
# Epoch 00168: val_accuracy did not improve from 0.93243
# Epoch 169/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.5183 - val_accuracy: 0.8784
#
# Epoch 00169: val_accuracy did not improve from 0.93243
# Epoch 170/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0383 - accuracy: 0.9879 - val_loss: 0.9298 - val_accuracy: 0.8378
#
# Epoch 00170: val_accuracy did not improve from 0.93243
# Epoch 171/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0328 - accuracy: 0.9916 - val_loss: 1.9753 - val_accuracy: 0.6959
#
# Epoch 00171: val_accuracy did not improve from 0.93243
# Epoch 172/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0307 - accuracy: 0.9889 - val_loss: 1.0180 - val_accuracy: 0.8311
#
# Epoch 00172: val_accuracy did not improve from 0.93243
# Epoch 173/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.5990 - val_accuracy: 0.8784
#
# Epoch 00173: val_accuracy did not improve from 0.93243
# Epoch 174/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0507 - accuracy: 0.9863 - val_loss: 0.4908 - val_accuracy: 0.8716
#
# Epoch 00174: val_accuracy did not improve from 0.93243
# Epoch 175/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0314 - accuracy: 0.9884 - val_loss: 0.5412 - val_accuracy: 0.8716
#
# Epoch 00175: val_accuracy did not improve from 0.93243
# Epoch 176/500
# 238/238 [==============================] - 26s 110ms/step - loss: 0.0239 - accuracy: 0.9916 - val_loss: 0.6760 - val_accuracy: 0.9054
#
# Epoch 00176: val_accuracy did not improve from 0.93243
# Epoch 177/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0340 - accuracy: 0.9889 - val_loss: 0.9762 - val_accuracy: 0.8514
#
# Epoch 00177: val_accuracy did not improve from 0.93243
# Epoch 178/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 3.3419 - val_accuracy: 0.5676
#
# Epoch 00178: val_accuracy did not improve from 0.93243
# Epoch 179/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0275 - accuracy: 0.9889 - val_loss: 0.5473 - val_accuracy: 0.9054
#
# Epoch 00179: val_accuracy did not improve from 0.93243
# Epoch 180/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0320 - accuracy: 0.9879 - val_loss: 1.8318 - val_accuracy: 0.7568
#
# Epoch 00180: val_accuracy did not improve from 0.93243
# Epoch 181/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0455 - accuracy: 0.9863 - val_loss: 0.6828 - val_accuracy: 0.9122
#
# Epoch 00181: val_accuracy did not improve from 0.93243
# Epoch 182/500
# 238/238 [==============================] - 26s 111ms/step - loss: 0.0428 - accuracy: 0.9895 - val_loss: 0.8199 - val_accuracy: 0.8784
#
# Epoch 00182: val_accuracy did not improve from 0.93243
# Epoch 183/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0425 - accuracy: 0.9884 - val_loss: 0.7924 - val_accuracy: 0.8581
#
# Epoch 00183: val_accuracy did not improve from 0.93243
# Epoch 184/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0257 - accuracy: 0.9900 - val_loss: 3.2647 - val_accuracy: 0.6081
#
# Epoch 00184: val_accuracy did not improve from 0.93243
# Epoch 185/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0159 - accuracy: 0.9942 - val_loss: 0.5361 - val_accuracy: 0.9054
#
# Epoch 00185: val_accuracy did not improve from 0.93243
# Epoch 186/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0323 - accuracy: 0.9911 - val_loss: 0.7780 - val_accuracy: 0.8716
#
# Epoch 00186: val_accuracy did not improve from 0.93243
# Epoch 187/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0696 - accuracy: 0.9789 - val_loss: 0.6785 - val_accuracy: 0.8851
#
# Epoch 00187: val_accuracy did not improve from 0.93243
# Epoch 188/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0246 - accuracy: 0.9937 - val_loss: 0.4314 - val_accuracy: 0.9054
#
# Epoch 00188: val_accuracy did not improve from 0.93243
# Epoch 189/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0237 - accuracy: 0.9937 - val_loss: 0.6488 - val_accuracy: 0.8986
#
# Epoch 00189: val_accuracy did not improve from 0.93243
# Epoch 190/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0320 - accuracy: 0.9884 - val_loss: 0.7158 - val_accuracy: 0.8986
#
# Epoch 00190: val_accuracy did not improve from 0.93243
# Epoch 191/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 0.5745 - val_accuracy: 0.8986
#
# Epoch 00191: val_accuracy did not improve from 0.93243
# Epoch 192/500
# 238/238 [==============================] - 27s 111ms/step - loss: 0.0166 - accuracy: 0.9947 - val_loss: 0.4759 - val_accuracy: 0.9189
#
# Epoch 00192: val_accuracy did not improve from 0.93243
# Epoch 193/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0472 - accuracy: 0.9837 - val_loss: 0.5122 - val_accuracy: 0.9054
#
# Epoch 00193: val_accuracy did not improve from 0.93243
# Epoch 194/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0367 - accuracy: 0.9895 - val_loss: 0.5718 - val_accuracy: 0.8784
#
# Epoch 00194: val_accuracy did not improve from 0.93243
# Epoch 195/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0305 - accuracy: 0.9911 - val_loss: 0.6462 - val_accuracy: 0.9392
#
# Epoch 00195: val_accuracy improved from 0.93243 to 0.93919, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_4.h5
# Epoch 196/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0499 - accuracy: 0.9826 - val_loss: 2.5397 - val_accuracy: 0.5811
#
# Epoch 00196: val_accuracy did not improve from 0.93919
# Epoch 197/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0316 - accuracy: 0.9889 - val_loss: 0.7870 - val_accuracy: 0.8311
#
# Epoch 00197: val_accuracy did not improve from 0.93919
# Epoch 198/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0261 - accuracy: 0.9911 - val_loss: 0.5040 - val_accuracy: 0.9257
#
# Epoch 00198: val_accuracy did not improve from 0.93919
# Epoch 199/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 0.5446 - val_accuracy: 0.8919
#
# Epoch 00199: val_accuracy did not improve from 0.93919
# Epoch 200/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 0.6190 - val_accuracy: 0.9054
#
# Epoch 00200: val_accuracy did not improve from 0.93919
# Epoch 201/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0221 - accuracy: 0.9911 - val_loss: 0.4873 - val_accuracy: 0.9392
#
# Epoch 00201: val_accuracy did not improve from 0.93919
# Epoch 202/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0477 - accuracy: 0.9863 - val_loss: 0.8564 - val_accuracy: 0.8649
#
# Epoch 00202: val_accuracy did not improve from 0.93919
# Epoch 203/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0422 - accuracy: 0.9874 - val_loss: 0.5449 - val_accuracy: 0.8919
#
# Epoch 00203: val_accuracy did not improve from 0.93919
# Epoch 204/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.5788 - val_accuracy: 0.9257
#
# Epoch 00204: val_accuracy did not improve from 0.93919
# Epoch 205/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.6105 - val_accuracy: 0.9054
#
# Epoch 00205: val_accuracy did not improve from 0.93919
# Epoch 206/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0263 - accuracy: 0.9921 - val_loss: 0.5561 - val_accuracy: 0.9189
#
# Epoch 00206: val_accuracy did not improve from 0.93919
# Epoch 207/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0502 - accuracy: 0.9858 - val_loss: 2.0671 - val_accuracy: 0.7365
#
# Epoch 00207: val_accuracy did not improve from 0.93919
# Epoch 208/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 0.4794 - val_accuracy: 0.8986
#
# Epoch 00208: val_accuracy did not improve from 0.93919
# Epoch 209/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0319 - accuracy: 0.9884 - val_loss: 0.4833 - val_accuracy: 0.9054
#
# Epoch 00209: val_accuracy did not improve from 0.93919
# Epoch 210/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.5043 - val_accuracy: 0.9054
#
# Epoch 00210: val_accuracy did not improve from 0.93919
# Epoch 211/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0351 - accuracy: 0.9895 - val_loss: 0.5793 - val_accuracy: 0.8919
#
# Epoch 00211: val_accuracy did not improve from 0.93919
# Epoch 212/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0181 - accuracy: 0.9916 - val_loss: 0.6574 - val_accuracy: 0.9054
#
# Epoch 00212: val_accuracy did not improve from 0.93919
# Epoch 213/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0745 - accuracy: 0.9811 - val_loss: 0.7220 - val_accuracy: 0.8378
#
# Epoch 00213: val_accuracy did not improve from 0.93919
# Epoch 214/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0353 - accuracy: 0.9889 - val_loss: 0.4883 - val_accuracy: 0.9122
#
# Epoch 00214: val_accuracy did not improve from 0.93919
# Epoch 215/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0149 - accuracy: 0.9937 - val_loss: 0.4553 - val_accuracy: 0.9257
#
# Epoch 00215: val_accuracy did not improve from 0.93919
# Epoch 216/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0292 - accuracy: 0.9916 - val_loss: 0.7274 - val_accuracy: 0.8716
#
# Epoch 00216: val_accuracy did not improve from 0.93919
# Epoch 217/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0171 - accuracy: 0.9953 - val_loss: 0.5064 - val_accuracy: 0.9122
#
# Epoch 00217: val_accuracy did not improve from 0.93919
# Epoch 218/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.3350 - val_accuracy: 0.9257
#
# Epoch 00218: val_accuracy did not improve from 0.93919
# Epoch 219/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.4623 - val_accuracy: 0.8716
#
# Epoch 00219: val_accuracy did not improve from 0.93919
# Epoch 220/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0251 - accuracy: 0.9932 - val_loss: 0.4159 - val_accuracy: 0.9324
#
# Epoch 00220: val_accuracy did not improve from 0.93919
# Epoch 221/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0416 - accuracy: 0.9863 - val_loss: 0.7242 - val_accuracy: 0.8716
#
# Epoch 00221: val_accuracy did not improve from 0.93919
# Epoch 222/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0373 - accuracy: 0.9884 - val_loss: 0.5332 - val_accuracy: 0.8716
#
# Epoch 00222: val_accuracy did not improve from 0.93919
# Epoch 223/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0249 - accuracy: 0.9884 - val_loss: 1.9632 - val_accuracy: 0.7500
#
# Epoch 00223: val_accuracy did not improve from 0.93919
# Epoch 224/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0332 - accuracy: 0.9889 - val_loss: 0.5140 - val_accuracy: 0.9324
#
# Epoch 00224: val_accuracy did not improve from 0.93919
# Epoch 225/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0281 - accuracy: 0.9889 - val_loss: 0.7236 - val_accuracy: 0.8514
#
# Epoch 00225: val_accuracy did not improve from 0.93919
# Epoch 226/500
# 238/238 [==============================] - 27s 112ms/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.9309 - val_accuracy: 0.8784
#
# Epoch 00226: val_accuracy did not improve from 0.93919
# Epoch 227/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0262 - accuracy: 0.9921 - val_loss: 1.5102 - val_accuracy: 0.7838
#
# Epoch 00227: val_accuracy did not improve from 0.93919
# Epoch 228/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0228 - accuracy: 0.9926 - val_loss: 1.5553 - val_accuracy: 0.7500
#
# Epoch 00228: val_accuracy did not improve from 0.93919
# Epoch 229/500
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.94595
# Epoch 423/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0085 - accuracy: 0.9989 - val_loss: 0.7621 - val_accuracy: 0.8784
#
# Epoch 00423: val_accuracy did not improve from 0.94595
# Epoch 424/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 0.8033 - val_accuracy: 0.8919
#
# Epoch 00424: val_accuracy did not improve from 0.94595
# Epoch 425/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0241 - accuracy: 0.9932 - val_loss: 0.6958 - val_accuracy: 0.9054
#
# Epoch 00425: val_accuracy did not improve from 0.94595
# Epoch 426/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.8513 - val_accuracy: 0.8716
#
# Epoch 00426: val_accuracy did not improve from 0.94595
# Epoch 427/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0311 - accuracy: 0.9905 - val_loss: 0.8185 - val_accuracy: 0.8919
#
# Epoch 00427: val_accuracy did not improve from 0.94595
# Epoch 428/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0285 - accuracy: 0.9921 - val_loss: 0.6969 - val_accuracy: 0.8919
#
# Epoch 00428: val_accuracy did not improve from 0.94595
# Epoch 429/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0206 - accuracy: 0.9942 - val_loss: 0.7145 - val_accuracy: 0.8919
#
# Epoch 00429: val_accuracy did not improve from 0.94595
# Epoch 430/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0212 - accuracy: 0.9958 - val_loss: 0.8268 - val_accuracy: 0.8919
#
# Epoch 00430: val_accuracy did not improve from 0.94595
# Epoch 431/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0070 - accuracy: 0.9968 - val_loss: 0.7552 - val_accuracy: 0.8851
#
# Epoch 00431: val_accuracy did not improve from 0.94595
# Epoch 432/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 0.7267 - val_accuracy: 0.8919
#
# Epoch 00432: val_accuracy did not improve from 0.94595
# Epoch 433/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0186 - accuracy: 0.9953 - val_loss: 0.7138 - val_accuracy: 0.8784
#
# Epoch 00433: val_accuracy did not improve from 0.94595
# Epoch 434/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 0.7888 - val_accuracy: 0.8716
#
# Epoch 00434: val_accuracy did not improve from 0.94595
# Epoch 435/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0105 - accuracy: 0.9947 - val_loss: 0.8232 - val_accuracy: 0.8581
#
# Epoch 00435: val_accuracy did not improve from 0.94595
# Epoch 436/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 1.1112 - val_accuracy: 0.8851
#
# Epoch 00436: val_accuracy did not improve from 0.94595
# Epoch 437/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0068 - accuracy: 0.9958 - val_loss: 0.8191 - val_accuracy: 0.8851
#
# Epoch 00437: val_accuracy did not improve from 0.94595
# Epoch 438/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.7911 - val_accuracy: 0.8851
#
# Epoch 00438: val_accuracy did not improve from 0.94595
# Epoch 439/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.8449 - val_accuracy: 0.8649
#
# Epoch 00439: val_accuracy did not improve from 0.94595
# Epoch 440/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.7747 - val_accuracy: 0.8986
#
# Epoch 00440: val_accuracy did not improve from 0.94595
# Epoch 441/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0366 - accuracy: 0.9905 - val_loss: 2.2317 - val_accuracy: 0.7568
#
# Epoch 00441: val_accuracy did not improve from 0.94595
# Epoch 442/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0424 - accuracy: 0.9884 - val_loss: 0.8985 - val_accuracy: 0.8716
#
# Epoch 00442: val_accuracy did not improve from 0.94595
# Epoch 443/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0355 - accuracy: 0.9884 - val_loss: 0.5311 - val_accuracy: 0.9122
#
# Epoch 00443: val_accuracy did not improve from 0.94595
# Epoch 444/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0269 - accuracy: 0.9916 - val_loss: 0.5583 - val_accuracy: 0.9054
#
# Epoch 00444: val_accuracy did not improve from 0.94595
# Epoch 445/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0142 - accuracy: 0.9968 - val_loss: 0.6807 - val_accuracy: 0.9054
#
# Epoch 00445: val_accuracy did not improve from 0.94595
# Epoch 446/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0144 - accuracy: 0.9958 - val_loss: 1.1680 - val_accuracy: 0.8311
#
# Epoch 00446: val_accuracy did not improve from 0.94595
# Epoch 447/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 0.5061 - val_accuracy: 0.9122
#
# Epoch 00447: val_accuracy did not improve from 0.94595
# Epoch 448/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.5649 - val_accuracy: 0.8919
#
# Epoch 00448: val_accuracy did not improve from 0.94595
# Epoch 449/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5731 - val_accuracy: 0.9122
#
# Epoch 00449: val_accuracy did not improve from 0.94595
# Epoch 450/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.6124 - val_accuracy: 0.9054
#
# Epoch 00450: val_accuracy did not improve from 0.94595
# Epoch 451/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0173 - accuracy: 0.9963 - val_loss: 0.7725 - val_accuracy: 0.8919
#
# Epoch 00451: val_accuracy did not improve from 0.94595
# Epoch 452/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.7502 - val_accuracy: 0.8919
#
# Epoch 00452: val_accuracy did not improve from 0.94595
# Epoch 453/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0202 - accuracy: 0.9953 - val_loss: 0.9767 - val_accuracy: 0.8716
#
# Epoch 00453: val_accuracy did not improve from 0.94595
# Epoch 454/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.7007 - val_accuracy: 0.9189
#
# Epoch 00454: val_accuracy did not improve from 0.94595
# Epoch 455/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0256 - accuracy: 0.9932 - val_loss: 1.5212 - val_accuracy: 0.8243
#
# Epoch 00455: val_accuracy did not improve from 0.94595
# Epoch 456/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0176 - accuracy: 0.9916 - val_loss: 0.8156 - val_accuracy: 0.9122
#
# Epoch 00456: val_accuracy did not improve from 0.94595
# Epoch 457/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.9841 - val_accuracy: 0.8919
#
# Epoch 00457: val_accuracy did not improve from 0.94595
# Epoch 458/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0149 - accuracy: 0.9942 - val_loss: 0.4784 - val_accuracy: 0.9189
#
# Epoch 00458: val_accuracy did not improve from 0.94595
# Epoch 459/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.9519 - val_accuracy: 0.8784
#
# Epoch 00459: val_accuracy did not improve from 0.94595
# Epoch 460/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 0.7370 - val_accuracy: 0.8784
#
# Epoch 00460: val_accuracy did not improve from 0.94595
# Epoch 461/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.7600 - val_accuracy: 0.8986
#
# Epoch 00461: val_accuracy did not improve from 0.94595
# Epoch 462/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.8130 - val_accuracy: 0.8784
#
# Epoch 00462: val_accuracy did not improve from 0.94595
# Epoch 463/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.8493 - val_accuracy: 0.8986
#
# Epoch 00463: val_accuracy did not improve from 0.94595
# Epoch 464/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 0.5299 - val_accuracy: 0.9122
#
# Epoch 00464: val_accuracy did not improve from 0.94595
# Epoch 465/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.9711 - val_accuracy: 0.8581
#
# Epoch 00465: val_accuracy did not improve from 0.94595
# Epoch 466/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.7321 - val_accuracy: 0.8919
#
# Epoch 00466: val_accuracy did not improve from 0.94595
# Epoch 467/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.9209 - val_accuracy: 0.8986
#
# Epoch 00467: val_accuracy did not improve from 0.94595
# Epoch 468/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.6885 - val_accuracy: 0.8851
#
# Epoch 00468: val_accuracy did not improve from 0.94595
# Epoch 469/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.6347 - val_accuracy: 0.9054
#
# Epoch 00469: val_accuracy did not improve from 0.94595
# Epoch 470/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0132 - accuracy: 0.9942 - val_loss: 1.1436 - val_accuracy: 0.8514
#
# Epoch 00470: val_accuracy did not improve from 0.94595
# Epoch 471/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.9316 - val_accuracy: 0.8851
#
# Epoch 00471: val_accuracy did not improve from 0.94595
# Epoch 472/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.7323 - val_accuracy: 0.8851
#
# Epoch 00472: val_accuracy did not improve from 0.94595
# Epoch 473/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0293 - accuracy: 0.9905 - val_loss: 0.8150 - val_accuracy: 0.8649
#
# Epoch 00473: val_accuracy did not improve from 0.94595
# Epoch 474/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.4870 - val_accuracy: 0.9324
#
# Epoch 00474: val_accuracy did not improve from 0.94595
# Epoch 475/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 2.8153 - val_accuracy: 0.7027
#
# Epoch 00475: val_accuracy did not improve from 0.94595
# Epoch 476/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0161 - accuracy: 0.9958 - val_loss: 0.7997 - val_accuracy: 0.8851
#
# Epoch 00476: val_accuracy did not improve from 0.94595
# Epoch 477/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0086 - accuracy: 0.9979 - val_loss: 0.6849 - val_accuracy: 0.9189
#
# Epoch 00477: val_accuracy did not improve from 0.94595
# Epoch 478/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 11.1116 - val_accuracy: 0.1216
#
# Epoch 00478: val_accuracy did not improve from 0.94595
# Epoch 479/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.9077 - val_accuracy: 0.8514
#
# Epoch 00479: val_accuracy did not improve from 0.94595
# Epoch 480/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.8710 - val_accuracy: 0.8919
#
# Epoch 00480: val_accuracy did not improve from 0.94595
# Epoch 481/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0094 - accuracy: 0.9963 - val_loss: 0.7697 - val_accuracy: 0.8986
#
# Epoch 00481: val_accuracy did not improve from 0.94595
# Epoch 482/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.7836 - val_accuracy: 0.8986
#
# Epoch 00482: val_accuracy did not improve from 0.94595
# Epoch 483/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 1.3379 - val_accuracy: 0.8176
#
# Epoch 00483: val_accuracy did not improve from 0.94595
# Epoch 484/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0151 - accuracy: 0.9968 - val_loss: 0.7696 - val_accuracy: 0.8851
#
# Epoch 00484: val_accuracy did not improve from 0.94595
# Epoch 485/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.8425 - val_accuracy: 0.8986
#
# Epoch 00485: val_accuracy did not improve from 0.94595
# Epoch 486/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.7747 - val_accuracy: 0.9054
#
# Epoch 00486: val_accuracy did not improve from 0.94595
# Epoch 487/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0053 - accuracy: 0.9974 - val_loss: 0.7379 - val_accuracy: 0.8851
#
# Epoch 00487: val_accuracy did not improve from 0.94595
# Epoch 488/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.7083 - val_accuracy: 0.8784
#
# Epoch 00488: val_accuracy did not improve from 0.94595
# Epoch 489/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0430 - accuracy: 0.9905 - val_loss: 3.8201 - val_accuracy: 0.5946
#
# Epoch 00489: val_accuracy did not improve from 0.94595
# Epoch 490/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.5618 - val_accuracy: 0.9054
#
# Epoch 00490: val_accuracy did not improve from 0.94595
# Epoch 491/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0134 - accuracy: 0.9958 - val_loss: 0.5457 - val_accuracy: 0.9189
#
# Epoch 00491: val_accuracy did not improve from 0.94595
# Epoch 492/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0120 - accuracy: 0.9968 - val_loss: 0.4820 - val_accuracy: 0.9257
#
# Epoch 00492: val_accuracy did not improve from 0.94595
# Epoch 493/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0207 - accuracy: 0.9942 - val_loss: 0.6363 - val_accuracy: 0.9189
#
# Epoch 00493: val_accuracy did not improve from 0.94595
# Epoch 494/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0233 - accuracy: 0.9942 - val_loss: 0.6732 - val_accuracy: 0.9054
#
# Epoch 00494: val_accuracy did not improve from 0.94595
# Epoch 495/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0129 - accuracy: 0.9968 - val_loss: 0.5267 - val_accuracy: 0.9054
#
# Epoch 00495: val_accuracy did not improve from 0.94595
# Epoch 496/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.6467 - val_accuracy: 0.9189
#
# Epoch 00496: val_accuracy did not improve from 0.94595
# Epoch 497/500
# 238/238 [==============================] - 27s 113ms/step - loss: 0.0080 - accuracy: 0.9963 - val_loss: 0.4851 - val_accuracy: 0.9122
#
# Epoch 00497: val_accuracy did not improve from 0.94595
# Epoch 498/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 2.8304 - val_accuracy: 0.6622
#
# Epoch 00498: val_accuracy did not improve from 0.94595
# Epoch 499/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0133 - accuracy: 0.9947 - val_loss: 0.5482 - val_accuracy: 0.9054
#
# Epoch 00499: val_accuracy did not improve from 0.94595
# Epoch 500/500
# 238/238 [==============================] - 27s 114ms/step - loss: 0.0348 - accuracy: 0.9921 - val_loss: 0.7954 - val_accuracy: 0.8716
#
# Epoch 00500: val_accuracy did not improve from 0.94595

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    # 'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # meanideal96@gamil.com
    # 'iDeal02',
    # dodo402298@gmail.com
    'mean01',
    # d9249.acc002@gmail.com
    # 'mean02',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': False, 'detail': 'Over max submission count of Daily. 일일 제출 가능한 최대 횟수가 초과 되었습니다.'}
