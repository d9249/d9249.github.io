# %%
# !nvidia-smi
# Out:
# Tue Sep 28 19:18:26 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
nunbering = '2'
model_save = 'EfficientNetB' + nunbering + '_2'
Target_model = 'EfficientNetB' + nunbering + '_model'
Target_predict = 'EfficientNetB' + nunbering + '_predict'
Target_acc = 'EfficientNetB' + nunbering + '_acc'
Target_val = 'EfficientNetB' + nunbering + '_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.EfficientNetB2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 67s 161ms/step - loss: 3.3569 - accuracy: 0.1374 - val_loss: 2.5212 - val_accuracy: 0.1014
#
# Epoch 00001: val_accuracy improved from -inf to 0.10135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 36s 150ms/step - loss: 2.2183 - accuracy: 0.2337 - val_loss: 2.8996 - val_accuracy: 0.1149
#
# Epoch 00002: val_accuracy improved from 0.10135 to 0.11486, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 3/500
# 238/238 [==============================] - 36s 152ms/step - loss: 1.8218 - accuracy: 0.3663 - val_loss: 2.6751 - val_accuracy: 0.1014
#
# Epoch 00003: val_accuracy did not improve from 0.11486
# Epoch 4/500
# 238/238 [==============================] - 36s 152ms/step - loss: 1.4228 - accuracy: 0.5168 - val_loss: 1.1403 - val_accuracy: 0.6081
#
# Epoch 00004: val_accuracy improved from 0.11486 to 0.60811, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 5/500
# 238/238 [==============================] - 37s 154ms/step - loss: 1.0645 - accuracy: 0.6447 - val_loss: 1.2509 - val_accuracy: 0.5541
#
# Epoch 00005: val_accuracy did not improve from 0.60811
# Epoch 6/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.9192 - accuracy: 0.6989 - val_loss: 3.0822 - val_accuracy: 0.2568
#
# Epoch 00006: val_accuracy did not improve from 0.60811
# Epoch 7/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.8152 - accuracy: 0.7342 - val_loss: 2.8083 - val_accuracy: 0.2568
#
# Epoch 00007: val_accuracy did not improve from 0.60811
# Epoch 8/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.7154 - accuracy: 0.7611 - val_loss: 0.7784 - val_accuracy: 0.7230
#
# Epoch 00008: val_accuracy improved from 0.60811 to 0.72297, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 9/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.6450 - accuracy: 0.7879 - val_loss: 0.7246 - val_accuracy: 0.8041
#
# Epoch 00009: val_accuracy improved from 0.72297 to 0.80405, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 10/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.5720 - accuracy: 0.8158 - val_loss: 1.0683 - val_accuracy: 0.6892
#
# Epoch 00010: val_accuracy did not improve from 0.80405
# Epoch 11/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.5880 - accuracy: 0.8242 - val_loss: 0.6197 - val_accuracy: 0.8176
#
# Epoch 00011: val_accuracy improved from 0.80405 to 0.81757, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 12/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.5507 - accuracy: 0.8221 - val_loss: 0.5817 - val_accuracy: 0.8243
#
# Epoch 00012: val_accuracy improved from 0.81757 to 0.82432, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 13/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.5250 - accuracy: 0.8384 - val_loss: 0.9665 - val_accuracy: 0.7703
#
# Epoch 00013: val_accuracy did not improve from 0.82432
# Epoch 14/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.5008 - accuracy: 0.8400 - val_loss: 0.9152 - val_accuracy: 0.7905
#
# Epoch 00014: val_accuracy did not improve from 0.82432
# Epoch 15/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.4491 - accuracy: 0.8532 - val_loss: 0.4587 - val_accuracy: 0.8514
#
# Epoch 00015: val_accuracy improved from 0.82432 to 0.85135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 16/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.4606 - accuracy: 0.8511 - val_loss: 0.6169 - val_accuracy: 0.8514
#
# Epoch 00016: val_accuracy did not improve from 0.85135
# Epoch 17/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3828 - accuracy: 0.8737 - val_loss: 0.4420 - val_accuracy: 0.8851
#
# Epoch 00017: val_accuracy improved from 0.85135 to 0.88514, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 18/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.3757 - accuracy: 0.8832 - val_loss: 3.1144 - val_accuracy: 0.3784
#
# Epoch 00018: val_accuracy did not improve from 0.88514
# Epoch 19/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3888 - accuracy: 0.8732 - val_loss: 2.8920 - val_accuracy: 0.3986
#
# Epoch 00019: val_accuracy did not improve from 0.88514
# Epoch 20/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.4281 - accuracy: 0.8684 - val_loss: 0.4480 - val_accuracy: 0.8581
#
# Epoch 00020: val_accuracy did not improve from 0.88514
# Epoch 21/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.3743 - accuracy: 0.8784 - val_loss: 0.4221 - val_accuracy: 0.8716
#
# Epoch 00021: val_accuracy did not improve from 0.88514
# Epoch 22/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3438 - accuracy: 0.8884 - val_loss: 0.4130 - val_accuracy: 0.8649
#
# Epoch 00022: val_accuracy did not improve from 0.88514
# Epoch 23/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3323 - accuracy: 0.8921 - val_loss: 0.8835 - val_accuracy: 0.7703
#
# Epoch 00023: val_accuracy did not improve from 0.88514
# Epoch 24/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2872 - accuracy: 0.9047 - val_loss: 0.5644 - val_accuracy: 0.8243
#
# Epoch 00024: val_accuracy did not improve from 0.88514
# Epoch 25/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3273 - accuracy: 0.8911 - val_loss: 0.3520 - val_accuracy: 0.8649
#
# Epoch 00025: val_accuracy did not improve from 0.88514
# Epoch 26/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2949 - accuracy: 0.9079 - val_loss: 0.6626 - val_accuracy: 0.7905
#
# Epoch 00026: val_accuracy did not improve from 0.88514
# Epoch 27/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2744 - accuracy: 0.9195 - val_loss: 1.0477 - val_accuracy: 0.6689
#
# Epoch 00027: val_accuracy did not improve from 0.88514
# Epoch 28/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2867 - accuracy: 0.9100 - val_loss: 0.6581 - val_accuracy: 0.8311
#
# Epoch 00028: val_accuracy did not improve from 0.88514
# Epoch 29/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.2450 - accuracy: 0.9263 - val_loss: 0.5261 - val_accuracy: 0.8378
#
# Epoch 00029: val_accuracy did not improve from 0.88514
# Epoch 30/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.3000 - accuracy: 0.9042 - val_loss: 0.5098 - val_accuracy: 0.8311
#
# Epoch 00030: val_accuracy did not improve from 0.88514
# Epoch 31/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2464 - accuracy: 0.9221 - val_loss: 0.4802 - val_accuracy: 0.8581
#
# Epoch 00031: val_accuracy did not improve from 0.88514
# Epoch 32/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2492 - accuracy: 0.9268 - val_loss: 0.4460 - val_accuracy: 0.8514
#
# Epoch 00032: val_accuracy did not improve from 0.88514
# Epoch 33/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2562 - accuracy: 0.9216 - val_loss: 0.8810 - val_accuracy: 0.7297
#
# Epoch 00033: val_accuracy did not improve from 0.88514
# Epoch 34/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2305 - accuracy: 0.9253 - val_loss: 0.4676 - val_accuracy: 0.8851
#
# Epoch 00034: val_accuracy did not improve from 0.88514
# Epoch 35/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.2245 - accuracy: 0.9353 - val_loss: 0.5916 - val_accuracy: 0.8581
#
# Epoch 00035: val_accuracy did not improve from 0.88514
# Epoch 36/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1988 - accuracy: 0.9395 - val_loss: 0.6588 - val_accuracy: 0.8311
#
# Epoch 00036: val_accuracy did not improve from 0.88514
# Epoch 37/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2426 - accuracy: 0.9189 - val_loss: 0.6765 - val_accuracy: 0.7635
#
# Epoch 00037: val_accuracy did not improve from 0.88514
# Epoch 38/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2102 - accuracy: 0.9289 - val_loss: 0.3249 - val_accuracy: 0.8851
#
# Epoch 00038: val_accuracy did not improve from 0.88514
# Epoch 39/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1734 - accuracy: 0.9437 - val_loss: 0.5160 - val_accuracy: 0.8986
#
# Epoch 00039: val_accuracy improved from 0.88514 to 0.89865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 40/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.1884 - accuracy: 0.9479 - val_loss: 0.6522 - val_accuracy: 0.8514
#
# Epoch 00040: val_accuracy did not improve from 0.89865
# Epoch 41/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2138 - accuracy: 0.9326 - val_loss: 0.7840 - val_accuracy: 0.8378
#
# Epoch 00041: val_accuracy did not improve from 0.89865
# Epoch 42/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1241 - accuracy: 0.9611 - val_loss: 0.4182 - val_accuracy: 0.8851
#
# Epoch 00042: val_accuracy did not improve from 0.89865
# Epoch 43/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1615 - accuracy: 0.9479 - val_loss: 0.6888 - val_accuracy: 0.8311
#
# Epoch 00043: val_accuracy did not improve from 0.89865
# Epoch 44/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1541 - accuracy: 0.9500 - val_loss: 0.7162 - val_accuracy: 0.8176
#
# Epoch 00044: val_accuracy did not improve from 0.89865
# Epoch 45/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1904 - accuracy: 0.9453 - val_loss: 0.4972 - val_accuracy: 0.8851
#
# Epoch 00045: val_accuracy did not improve from 0.89865
# Epoch 46/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1528 - accuracy: 0.9458 - val_loss: 0.3951 - val_accuracy: 0.8919
#
# Epoch 00046: val_accuracy did not improve from 0.89865
# Epoch 47/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1433 - accuracy: 0.9589 - val_loss: 0.8605 - val_accuracy: 0.7500
#
# Epoch 00047: val_accuracy did not improve from 0.89865
# Epoch 48/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1517 - accuracy: 0.9521 - val_loss: 2.1322 - val_accuracy: 0.5946
#
# Epoch 00048: val_accuracy did not improve from 0.89865
# Epoch 49/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1618 - accuracy: 0.9468 - val_loss: 0.3556 - val_accuracy: 0.8919
#
# Epoch 00049: val_accuracy did not improve from 0.89865
# Epoch 50/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1459 - accuracy: 0.9574 - val_loss: 0.4585 - val_accuracy: 0.8716
#
# Epoch 00050: val_accuracy did not improve from 0.89865
# Epoch 51/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1445 - accuracy: 0.9547 - val_loss: 0.9556 - val_accuracy: 0.7770
#
# Epoch 00051: val_accuracy did not improve from 0.89865
# Epoch 52/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1259 - accuracy: 0.9653 - val_loss: 1.3361 - val_accuracy: 0.7432
#
# Epoch 00052: val_accuracy did not improve from 0.89865
# Epoch 53/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1019 - accuracy: 0.9658 - val_loss: 0.4569 - val_accuracy: 0.8851
#
# Epoch 00053: val_accuracy did not improve from 0.89865
# Epoch 54/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1575 - accuracy: 0.9521 - val_loss: 0.4640 - val_accuracy: 0.8716
#
# Epoch 00054: val_accuracy did not improve from 0.89865
# Epoch 55/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0970 - accuracy: 0.9679 - val_loss: 1.4034 - val_accuracy: 0.7568
#
# Epoch 00055: val_accuracy did not improve from 0.89865
# Epoch 56/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1391 - accuracy: 0.9516 - val_loss: 3.5273 - val_accuracy: 0.3716
#
# Epoch 00056: val_accuracy did not improve from 0.89865
# Epoch 57/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1223 - accuracy: 0.9611 - val_loss: 0.4556 - val_accuracy: 0.8716
#
# Epoch 00057: val_accuracy did not improve from 0.89865
# Epoch 58/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1352 - accuracy: 0.9542 - val_loss: 0.4548 - val_accuracy: 0.8851
#
# Epoch 00058: val_accuracy did not improve from 0.89865
# Epoch 59/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1139 - accuracy: 0.9668 - val_loss: 1.7009 - val_accuracy: 0.6081
#
# Epoch 00059: val_accuracy did not improve from 0.89865
# Epoch 60/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1076 - accuracy: 0.9674 - val_loss: 1.0877 - val_accuracy: 0.7432
#
# Epoch 00060: val_accuracy did not improve from 0.89865
# Epoch 61/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1125 - accuracy: 0.9611 - val_loss: 1.1579 - val_accuracy: 0.7703
#
# Epoch 00061: val_accuracy did not improve from 0.89865
# Epoch 62/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1256 - accuracy: 0.9595 - val_loss: 1.8875 - val_accuracy: 0.6149
#
# Epoch 00062: val_accuracy did not improve from 0.89865
# Epoch 63/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1194 - accuracy: 0.9626 - val_loss: 0.3823 - val_accuracy: 0.8986
#
# Epoch 00063: val_accuracy did not improve from 0.89865
# Epoch 64/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1349 - accuracy: 0.9574 - val_loss: 0.4453 - val_accuracy: 0.8649
#
# Epoch 00064: val_accuracy did not improve from 0.89865
# Epoch 65/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0596 - accuracy: 0.9747 - val_loss: 1.3515 - val_accuracy: 0.7230
#
# Epoch 00065: val_accuracy did not improve from 0.89865
# Epoch 66/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0689 - accuracy: 0.9753 - val_loss: 1.1617 - val_accuracy: 0.7432
#
# Epoch 00066: val_accuracy did not improve from 0.89865
# Epoch 67/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1541 - accuracy: 0.9489 - val_loss: 1.4947 - val_accuracy: 0.6824
#
# Epoch 00067: val_accuracy did not improve from 0.89865
# Epoch 68/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0865 - accuracy: 0.9732 - val_loss: 0.5628 - val_accuracy: 0.8243
#
# Epoch 00068: val_accuracy did not improve from 0.89865
# Epoch 69/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0733 - accuracy: 0.9753 - val_loss: 0.5179 - val_accuracy: 0.9054
#
# Epoch 00069: val_accuracy improved from 0.89865 to 0.90541, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 70/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0818 - accuracy: 0.9768 - val_loss: 0.4272 - val_accuracy: 0.9054
#
# Epoch 00070: val_accuracy did not improve from 0.90541
# Epoch 71/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0794 - accuracy: 0.9758 - val_loss: 0.5256 - val_accuracy: 0.8851
#
# Epoch 00071: val_accuracy did not improve from 0.90541
# Epoch 72/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1224 - accuracy: 0.9595 - val_loss: 0.4630 - val_accuracy: 0.8919
#
# Epoch 00072: val_accuracy did not improve from 0.90541
# Epoch 73/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1229 - accuracy: 0.9637 - val_loss: 0.3575 - val_accuracy: 0.8986
#
# Epoch 00073: val_accuracy did not improve from 0.90541
# Epoch 74/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0686 - accuracy: 0.9768 - val_loss: 0.5682 - val_accuracy: 0.8919
#
# Epoch 00074: val_accuracy did not improve from 0.90541
# Epoch 75/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1010 - accuracy: 0.9684 - val_loss: 0.5345 - val_accuracy: 0.8919
#
# Epoch 00075: val_accuracy did not improve from 0.90541
# Epoch 76/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0560 - accuracy: 0.9821 - val_loss: 0.6638 - val_accuracy: 0.8716
#
# Epoch 00076: val_accuracy did not improve from 0.90541
# Epoch 77/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0736 - accuracy: 0.9774 - val_loss: 0.6079 - val_accuracy: 0.8514
#
# Epoch 00077: val_accuracy did not improve from 0.90541
# Epoch 78/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0775 - accuracy: 0.9779 - val_loss: 0.4639 - val_accuracy: 0.8919
#
# Epoch 00078: val_accuracy did not improve from 0.90541
# Epoch 79/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0578 - accuracy: 0.9795 - val_loss: 0.4319 - val_accuracy: 0.8649
#
# Epoch 00079: val_accuracy did not improve from 0.90541
# Epoch 80/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0949 - accuracy: 0.9689 - val_loss: 1.3932 - val_accuracy: 0.7568
#
# Epoch 00080: val_accuracy did not improve from 0.90541
# Epoch 81/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0557 - accuracy: 0.9826 - val_loss: 0.5485 - val_accuracy: 0.8784
#
# Epoch 00081: val_accuracy did not improve from 0.90541
# Epoch 82/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0885 - accuracy: 0.9732 - val_loss: 0.5445 - val_accuracy: 0.8851
#
# Epoch 00082: val_accuracy did not improve from 0.90541
# Epoch 83/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0861 - accuracy: 0.9747 - val_loss: 0.5492 - val_accuracy: 0.8784
#
# Epoch 00083: val_accuracy did not improve from 0.90541
# Epoch 84/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0753 - accuracy: 0.9753 - val_loss: 0.4856 - val_accuracy: 0.9054
#
# Epoch 00084: val_accuracy did not improve from 0.90541
# Epoch 85/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0627 - accuracy: 0.9821 - val_loss: 0.5885 - val_accuracy: 0.8986
#
# Epoch 00085: val_accuracy did not improve from 0.90541
# Epoch 86/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.1029 - accuracy: 0.9695 - val_loss: 0.5808 - val_accuracy: 0.8446
#
# Epoch 00086: val_accuracy did not improve from 0.90541
# Epoch 87/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0735 - accuracy: 0.9737 - val_loss: 0.4374 - val_accuracy: 0.8851
#
# Epoch 00087: val_accuracy did not improve from 0.90541
# Epoch 88/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0690 - accuracy: 0.9779 - val_loss: 0.4406 - val_accuracy: 0.8919
#
# Epoch 00088: val_accuracy did not improve from 0.90541
# Epoch 89/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0629 - accuracy: 0.9805 - val_loss: 0.4954 - val_accuracy: 0.9054
#
# Epoch 00089: val_accuracy did not improve from 0.90541
# Epoch 90/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0812 - accuracy: 0.9716 - val_loss: 0.3745 - val_accuracy: 0.8649
#
# Epoch 00090: val_accuracy did not improve from 0.90541
# Epoch 91/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0916 - accuracy: 0.9779 - val_loss: 0.5321 - val_accuracy: 0.8919
#
# Epoch 00091: val_accuracy did not improve from 0.90541
# Epoch 92/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0691 - accuracy: 0.9805 - val_loss: 1.9701 - val_accuracy: 0.6351
#
# Epoch 00092: val_accuracy did not improve from 0.90541
# Epoch 93/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0696 - accuracy: 0.9784 - val_loss: 0.6808 - val_accuracy: 0.8784
#
# Epoch 00093: val_accuracy did not improve from 0.90541
# Epoch 94/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0541 - accuracy: 0.9816 - val_loss: 0.7392 - val_accuracy: 0.8649
#
# Epoch 00094: val_accuracy did not improve from 0.90541
# Epoch 95/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0606 - accuracy: 0.9789 - val_loss: 0.7065 - val_accuracy: 0.8649
#
# Epoch 00095: val_accuracy did not improve from 0.90541
# Epoch 96/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0612 - accuracy: 0.9768 - val_loss: 0.4996 - val_accuracy: 0.8986
#
# Epoch 00096: val_accuracy did not improve from 0.90541
# Epoch 97/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0440 - accuracy: 0.9842 - val_loss: 0.5555 - val_accuracy: 0.8919
#
# Epoch 00097: val_accuracy did not improve from 0.90541
# Epoch 98/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0561 - accuracy: 0.9811 - val_loss: 0.9099 - val_accuracy: 0.8311
#
# Epoch 00098: val_accuracy did not improve from 0.90541
# Epoch 99/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0609 - accuracy: 0.9811 - val_loss: 0.4836 - val_accuracy: 0.8919
#
# Epoch 00099: val_accuracy did not improve from 0.90541
# Epoch 100/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0478 - accuracy: 0.9842 - val_loss: 0.5995 - val_accuracy: 0.8919
#
# Epoch 00100: val_accuracy did not improve from 0.90541
# Epoch 101/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0466 - accuracy: 0.9837 - val_loss: 1.2662 - val_accuracy: 0.7838
#
# Epoch 00101: val_accuracy did not improve from 0.90541
# Epoch 102/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0634 - accuracy: 0.9842 - val_loss: 0.7050 - val_accuracy: 0.8514
#
# Epoch 00102: val_accuracy did not improve from 0.90541
# Epoch 103/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0660 - accuracy: 0.9795 - val_loss: 0.6750 - val_accuracy: 0.8581
#
# Epoch 00103: val_accuracy did not improve from 0.90541
# Epoch 104/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0449 - accuracy: 0.9895 - val_loss: 0.7705 - val_accuracy: 0.8581
#
# Epoch 00104: val_accuracy did not improve from 0.90541
# Epoch 105/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0558 - accuracy: 0.9800 - val_loss: 0.6039 - val_accuracy: 0.8919
#
# Epoch 00105: val_accuracy did not improve from 0.90541
# Epoch 106/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0897 - accuracy: 0.9732 - val_loss: 0.7590 - val_accuracy: 0.8446
#
# Epoch 00106: val_accuracy did not improve from 0.90541
# Epoch 107/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0433 - accuracy: 0.9889 - val_loss: 0.4407 - val_accuracy: 0.8784
#
# Epoch 00107: val_accuracy did not improve from 0.90541
# Epoch 108/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0555 - accuracy: 0.9779 - val_loss: 0.7442 - val_accuracy: 0.8581
#
# Epoch 00108: val_accuracy did not improve from 0.90541
# Epoch 109/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0430 - accuracy: 0.9858 - val_loss: 0.5660 - val_accuracy: 0.8784
#
# Epoch 00109: val_accuracy did not improve from 0.90541
# Epoch 110/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0607 - accuracy: 0.9821 - val_loss: 0.5608 - val_accuracy: 0.8851
#
# Epoch 00110: val_accuracy did not improve from 0.90541
# Epoch 111/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0249 - accuracy: 0.9895 - val_loss: 0.5857 - val_accuracy: 0.8649
#
# Epoch 00111: val_accuracy did not improve from 0.90541
# Epoch 112/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0467 - accuracy: 0.9842 - val_loss: 0.5608 - val_accuracy: 0.8649
#
# Epoch 00112: val_accuracy did not improve from 0.90541
# Epoch 113/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0519 - accuracy: 0.9847 - val_loss: 0.4995 - val_accuracy: 0.8851
#
# Epoch 00113: val_accuracy did not improve from 0.90541
# Epoch 114/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0636 - accuracy: 0.9795 - val_loss: 0.7770 - val_accuracy: 0.8919
#
# Epoch 00114: val_accuracy did not improve from 0.90541
# Epoch 115/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0486 - accuracy: 0.9853 - val_loss: 0.8023 - val_accuracy: 0.8581
#
# Epoch 00115: val_accuracy did not improve from 0.90541
# Epoch 116/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0296 - accuracy: 0.9911 - val_loss: 0.4981 - val_accuracy: 0.9122
#
# Epoch 00116: val_accuracy improved from 0.90541 to 0.91216, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 117/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0418 - accuracy: 0.9868 - val_loss: 0.6033 - val_accuracy: 0.8649
#
# Epoch 00117: val_accuracy did not improve from 0.91216
# Epoch 118/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0418 - accuracy: 0.9863 - val_loss: 0.5776 - val_accuracy: 0.8649
#
# Epoch 00118: val_accuracy did not improve from 0.91216
# Epoch 119/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0967 - accuracy: 0.9732 - val_loss: 1.4371 - val_accuracy: 0.6824
#
# Epoch 00119: val_accuracy did not improve from 0.91216
# Epoch 120/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0485 - accuracy: 0.9847 - val_loss: 0.4249 - val_accuracy: 0.9122
#
# Epoch 00120: val_accuracy did not improve from 0.91216
# Epoch 121/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0515 - accuracy: 0.9800 - val_loss: 0.4485 - val_accuracy: 0.8986
#
# Epoch 00121: val_accuracy did not improve from 0.91216
# Epoch 122/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0262 - accuracy: 0.9921 - val_loss: 0.6033 - val_accuracy: 0.8919
#
# Epoch 00122: val_accuracy did not improve from 0.91216
# Epoch 123/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0616 - accuracy: 0.9816 - val_loss: 0.8518 - val_accuracy: 0.8784
#
# Epoch 00123: val_accuracy did not improve from 0.91216
# Epoch 124/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0369 - accuracy: 0.9889 - val_loss: 0.6522 - val_accuracy: 0.8784
#
# Epoch 00124: val_accuracy did not improve from 0.91216
# Epoch 125/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0447 - accuracy: 0.9889 - val_loss: 4.5935 - val_accuracy: 0.3581
#
# Epoch 00125: val_accuracy did not improve from 0.91216
# Epoch 126/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0393 - accuracy: 0.9868 - val_loss: 0.4379 - val_accuracy: 0.9257
#
# Epoch 00126: val_accuracy improved from 0.91216 to 0.92568, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 127/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0609 - accuracy: 0.9784 - val_loss: 1.6582 - val_accuracy: 0.7162
#
# Epoch 00127: val_accuracy did not improve from 0.92568
# Epoch 128/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0521 - accuracy: 0.9811 - val_loss: 0.5693 - val_accuracy: 0.8716
#
# Epoch 00128: val_accuracy did not improve from 0.92568
# Epoch 129/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0429 - accuracy: 0.9826 - val_loss: 0.6586 - val_accuracy: 0.8716
#
# Epoch 00129: val_accuracy did not improve from 0.92568
# Epoch 130/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0235 - accuracy: 0.9916 - val_loss: 0.6592 - val_accuracy: 0.8919
#
# Epoch 00130: val_accuracy did not improve from 0.92568
# Epoch 131/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.6552 - val_accuracy: 0.8919
#
# Epoch 00131: val_accuracy did not improve from 0.92568
# Epoch 132/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0378 - accuracy: 0.9874 - val_loss: 0.7112 - val_accuracy: 0.8919
#
# Epoch 00132: val_accuracy did not improve from 0.92568
# Epoch 133/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0600 - accuracy: 0.9826 - val_loss: 0.7473 - val_accuracy: 0.8784
#
# Epoch 00133: val_accuracy did not improve from 0.92568
# Epoch 134/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0529 - accuracy: 0.9842 - val_loss: 0.6071 - val_accuracy: 0.8919
#
# Epoch 00134: val_accuracy did not improve from 0.92568
# Epoch 135/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0572 - accuracy: 0.9842 - val_loss: 0.7848 - val_accuracy: 0.8851
#
# Epoch 00135: val_accuracy did not improve from 0.92568
# Epoch 136/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0525 - accuracy: 0.9837 - val_loss: 0.6044 - val_accuracy: 0.8784
#
# Epoch 00136: val_accuracy did not improve from 0.92568
# Epoch 137/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0520 - accuracy: 0.9811 - val_loss: 0.5416 - val_accuracy: 0.9122
#
# Epoch 00137: val_accuracy did not improve from 0.92568
# Epoch 138/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0473 - accuracy: 0.9837 - val_loss: 0.6796 - val_accuracy: 0.8784
#
# Epoch 00138: val_accuracy did not improve from 0.92568
# Epoch 139/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0323 - accuracy: 0.9921 - val_loss: 0.5929 - val_accuracy: 0.9054
#
# Epoch 00139: val_accuracy did not improve from 0.92568
# Epoch 140/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.5189 - val_accuracy: 0.8851
#
# Epoch 00140: val_accuracy did not improve from 0.92568
# Epoch 141/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0267 - accuracy: 0.9900 - val_loss: 0.5860 - val_accuracy: 0.9257
#
# Epoch 00141: val_accuracy did not improve from 0.92568
# Epoch 142/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0404 - accuracy: 0.9826 - val_loss: 0.7080 - val_accuracy: 0.8784
#
# Epoch 00142: val_accuracy did not improve from 0.92568
# Epoch 143/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0506 - accuracy: 0.9853 - val_loss: 0.6774 - val_accuracy: 0.8649
#
# Epoch 00143: val_accuracy did not improve from 0.92568
# Epoch 144/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0670 - accuracy: 0.9779 - val_loss: 0.6625 - val_accuracy: 0.9054
#
# Epoch 00144: val_accuracy did not improve from 0.92568
# Epoch 145/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0490 - accuracy: 0.9853 - val_loss: 0.5012 - val_accuracy: 0.9257
#
# Epoch 00145: val_accuracy did not improve from 0.92568
# Epoch 146/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.5251 - val_accuracy: 0.9189
#
# Epoch 00146: val_accuracy did not improve from 0.92568
# Epoch 147/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0473 - accuracy: 0.9884 - val_loss: 0.7651 - val_accuracy: 0.8649
#
# Epoch 00147: val_accuracy did not improve from 0.92568
# Epoch 148/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0284 - accuracy: 0.9905 - val_loss: 0.5552 - val_accuracy: 0.9122
#
# Epoch 00148: val_accuracy did not improve from 0.92568
# Epoch 149/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0222 - accuracy: 0.9911 - val_loss: 0.6415 - val_accuracy: 0.9054
#
# Epoch 00149: val_accuracy did not improve from 0.92568
# Epoch 150/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0359 - accuracy: 0.9879 - val_loss: 0.5012 - val_accuracy: 0.9257
#
# Epoch 00150: val_accuracy did not improve from 0.92568
# Epoch 151/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0472 - accuracy: 0.9847 - val_loss: 0.3961 - val_accuracy: 0.9054
#
# Epoch 00151: val_accuracy did not improve from 0.92568
# Epoch 152/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0350 - accuracy: 0.9884 - val_loss: 0.6515 - val_accuracy: 0.8514
#
# Epoch 00152: val_accuracy did not improve from 0.92568
# Epoch 153/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0394 - accuracy: 0.9889 - val_loss: 0.5471 - val_accuracy: 0.9122
#
# Epoch 00153: val_accuracy did not improve from 0.92568
# Epoch 154/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0514 - accuracy: 0.9868 - val_loss: 0.5289 - val_accuracy: 0.8784
#
# Epoch 00154: val_accuracy did not improve from 0.92568
# Epoch 155/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.5671 - val_accuracy: 0.8649
#
# Epoch 00155: val_accuracy did not improve from 0.92568
# Epoch 156/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.3860 - val_accuracy: 0.9054
#
# Epoch 00156: val_accuracy did not improve from 0.92568
# Epoch 157/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0424 - accuracy: 0.9911 - val_loss: 0.7952 - val_accuracy: 0.8649
#
# Epoch 00157: val_accuracy did not improve from 0.92568
# Epoch 158/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0470 - accuracy: 0.9863 - val_loss: 0.5573 - val_accuracy: 0.9054
#
# Epoch 00158: val_accuracy did not improve from 0.92568
# Epoch 159/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0345 - accuracy: 0.9900 - val_loss: 0.7019 - val_accuracy: 0.8784
#
# Epoch 00159: val_accuracy did not improve from 0.92568
# Epoch 160/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0531 - accuracy: 0.9795 - val_loss: 0.6593 - val_accuracy: 0.9054
#
# Epoch 00160: val_accuracy did not improve from 0.92568
# Epoch 161/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0294 - accuracy: 0.9900 - val_loss: 0.6280 - val_accuracy: 0.9054
#
# Epoch 00161: val_accuracy did not improve from 0.92568
# Epoch 162/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0409 - accuracy: 0.9858 - val_loss: 0.4748 - val_accuracy: 0.9054
#
# Epoch 00162: val_accuracy did not improve from 0.92568
# Epoch 163/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0430 - accuracy: 0.9863 - val_loss: 0.6235 - val_accuracy: 0.8851
#
# Epoch 00163: val_accuracy did not improve from 0.92568
# Epoch 164/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0399 - accuracy: 0.9863 - val_loss: 0.6097 - val_accuracy: 0.8851
#
# Epoch 00164: val_accuracy did not improve from 0.92568
# Epoch 165/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0320 - accuracy: 0.9921 - val_loss: 0.6664 - val_accuracy: 0.8851
#
# Epoch 00165: val_accuracy did not improve from 0.92568
# Epoch 166/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0481 - accuracy: 0.9900 - val_loss: 0.5205 - val_accuracy: 0.8986
#
# Epoch 00166: val_accuracy did not improve from 0.92568
# Epoch 167/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0334 - accuracy: 0.9879 - val_loss: 0.5355 - val_accuracy: 0.8919
#
# Epoch 00167: val_accuracy did not improve from 0.92568
# Epoch 168/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0341 - accuracy: 0.9868 - val_loss: 0.4786 - val_accuracy: 0.8986
#
# Epoch 00168: val_accuracy did not improve from 0.92568
# Epoch 169/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.3872 - val_accuracy: 0.9122
#
# Epoch 00169: val_accuracy did not improve from 0.92568
# Epoch 170/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0414 - accuracy: 0.9816 - val_loss: 1.4693 - val_accuracy: 0.7432
#
# Epoch 00170: val_accuracy did not improve from 0.92568
# Epoch 171/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0229 - accuracy: 0.9921 - val_loss: 0.5009 - val_accuracy: 0.9189
#
# Epoch 00171: val_accuracy did not improve from 0.92568
# Epoch 172/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.3492 - val_accuracy: 0.9257
#
# Epoch 00172: val_accuracy did not improve from 0.92568
# Epoch 173/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0427 - accuracy: 0.9868 - val_loss: 0.7705 - val_accuracy: 0.8986
#
# Epoch 00173: val_accuracy did not improve from 0.92568
# Epoch 174/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0410 - accuracy: 0.9863 - val_loss: 0.6741 - val_accuracy: 0.8986
#
# Epoch 00174: val_accuracy did not improve from 0.92568
# Epoch 175/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.4310 - val_accuracy: 0.9257
#
# Epoch 00175: val_accuracy did not improve from 0.92568
# Epoch 176/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.5633 - val_accuracy: 0.9054
#
# Epoch 00176: val_accuracy did not improve from 0.92568
# Epoch 177/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0452 - accuracy: 0.9853 - val_loss: 0.4699 - val_accuracy: 0.9054
#
# Epoch 00177: val_accuracy did not improve from 0.92568
# Epoch 178/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0671 - accuracy: 0.9832 - val_loss: 0.4333 - val_accuracy: 0.9054
#
# Epoch 00178: val_accuracy did not improve from 0.92568
# Epoch 179/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0436 - accuracy: 0.9853 - val_loss: 0.5004 - val_accuracy: 0.9054
#
# Epoch 00179: val_accuracy did not improve from 0.92568
# Epoch 180/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0337 - accuracy: 0.9853 - val_loss: 0.6528 - val_accuracy: 0.8784
#
# Epoch 00180: val_accuracy did not improve from 0.92568
# Epoch 181/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.4248 - val_accuracy: 0.9324
#
# Epoch 00181: val_accuracy improved from 0.92568 to 0.93243, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 182/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0324 - accuracy: 0.9921 - val_loss: 0.6424 - val_accuracy: 0.8919
#
# Epoch 00182: val_accuracy did not improve from 0.93243
# Epoch 183/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0158 - accuracy: 0.9932 - val_loss: 0.6028 - val_accuracy: 0.8986
#
# Epoch 00183: val_accuracy did not improve from 0.93243
# Epoch 184/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.6112 - val_accuracy: 0.8716
#
# Epoch 00184: val_accuracy did not improve from 0.93243
# Epoch 185/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0416 - accuracy: 0.9874 - val_loss: 0.6422 - val_accuracy: 0.8851
#
# Epoch 00185: val_accuracy did not improve from 0.93243
# Epoch 186/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0362 - accuracy: 0.9868 - val_loss: 0.5057 - val_accuracy: 0.8986
#
# Epoch 00186: val_accuracy did not improve from 0.93243
# Epoch 187/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0274 - accuracy: 0.9926 - val_loss: 0.5702 - val_accuracy: 0.9054
#
# Epoch 00187: val_accuracy did not improve from 0.93243
# Epoch 188/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0389 - accuracy: 0.9858 - val_loss: 0.4685 - val_accuracy: 0.8919
#
# Epoch 00188: val_accuracy did not improve from 0.93243
# Epoch 189/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.5248 - val_accuracy: 0.8986
#
# Epoch 00189: val_accuracy did not improve from 0.93243
# Epoch 190/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0266 - accuracy: 0.9921 - val_loss: 0.4819 - val_accuracy: 0.9054
#
# Epoch 00190: val_accuracy did not improve from 0.93243
# Epoch 191/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0353 - accuracy: 0.9853 - val_loss: 0.8164 - val_accuracy: 0.8919
#
# Epoch 00191: val_accuracy did not improve from 0.93243
# Epoch 192/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0213 - accuracy: 0.9953 - val_loss: 0.6663 - val_accuracy: 0.8784
#
# Epoch 00192: val_accuracy did not improve from 0.93243
# Epoch 193/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.6598 - val_accuracy: 0.8851
#
# Epoch 00193: val_accuracy did not improve from 0.93243
# Epoch 194/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0298 - accuracy: 0.9911 - val_loss: 0.6537 - val_accuracy: 0.8716
#
# Epoch 00194: val_accuracy did not improve from 0.93243
# Epoch 195/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0261 - accuracy: 0.9916 - val_loss: 0.7074 - val_accuracy: 0.8986
#
# Epoch 00195: val_accuracy did not improve from 0.93243
# Epoch 196/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0310 - accuracy: 0.9911 - val_loss: 0.6584 - val_accuracy: 0.8514
#
# Epoch 00196: val_accuracy did not improve from 0.93243
# Epoch 197/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0419 - accuracy: 0.9863 - val_loss: 0.8502 - val_accuracy: 0.8514
#
# Epoch 00197: val_accuracy did not improve from 0.93243
# Epoch 198/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0202 - accuracy: 0.9905 - val_loss: 0.7614 - val_accuracy: 0.8716
#
# Epoch 00198: val_accuracy did not improve from 0.93243
# Epoch 199/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.7437 - val_accuracy: 0.8851
#
# Epoch 00199: val_accuracy did not improve from 0.93243
# Epoch 200/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0318 - accuracy: 0.9911 - val_loss: 0.4501 - val_accuracy: 0.9189
#
# Epoch 00200: val_accuracy did not improve from 0.93243
# Epoch 201/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0252 - accuracy: 0.9953 - val_loss: 0.6022 - val_accuracy: 0.8716
#
# Epoch 00201: val_accuracy did not improve from 0.93243
# Epoch 202/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0326 - accuracy: 0.9900 - val_loss: 0.4384 - val_accuracy: 0.9392
#
# Epoch 00202: val_accuracy improved from 0.93243 to 0.93919, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_2.h5
# Epoch 203/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0281 - accuracy: 0.9921 - val_loss: 0.4802 - val_accuracy: 0.9122
#
# Epoch 00203: val_accuracy did not improve from 0.93919
# Epoch 204/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0251 - accuracy: 0.9916 - val_loss: 0.5528 - val_accuracy: 0.9122
#
# Epoch 00204: val_accuracy did not improve from 0.93919
# Epoch 205/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.5378 - val_accuracy: 0.9324
#
# Epoch 00205: val_accuracy did not improve from 0.93919
# Epoch 206/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0246 - accuracy: 0.9905 - val_loss: 2.0242 - val_accuracy: 0.6892
#
# Epoch 00206: val_accuracy did not improve from 0.93919
# Epoch 207/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0449 - accuracy: 0.9842 - val_loss: 0.6579 - val_accuracy: 0.8986
#
# Epoch 00207: val_accuracy did not improve from 0.93919
# Epoch 208/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0238 - accuracy: 0.9926 - val_loss: 0.5928 - val_accuracy: 0.9257
#
# Epoch 00208: val_accuracy did not improve from 0.93919
# Epoch 209/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0366 - accuracy: 0.9895 - val_loss: 0.6453 - val_accuracy: 0.9189
#
# Epoch 00209: val_accuracy did not improve from 0.93919
# Epoch 210/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.5618 - val_accuracy: 0.9257
#
# Epoch 00210: val_accuracy did not improve from 0.93919
# Epoch 211/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0197 - accuracy: 0.9926 - val_loss: 0.4662 - val_accuracy: 0.9257
#
# Epoch 00211: val_accuracy did not improve from 0.93919
# Epoch 212/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.5050 - val_accuracy: 0.9122
#
# Epoch 00212: val_accuracy did not improve from 0.93919
# Epoch 213/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 0.4185 - val_accuracy: 0.9257
#
# Epoch 00213: val_accuracy did not improve from 0.93919
# Epoch 214/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0364 - accuracy: 0.9905 - val_loss: 0.6519 - val_accuracy: 0.8851
#
# Epoch 00214: val_accuracy did not improve from 0.93919
# Epoch 215/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0457 - accuracy: 0.9847 - val_loss: 0.8086 - val_accuracy: 0.8784
#
# Epoch 00215: val_accuracy did not improve from 0.93919
# Epoch 216/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.6998 - val_accuracy: 0.8649
#
# Epoch 00216: val_accuracy did not improve from 0.93919
# Epoch 217/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0320 - accuracy: 0.9921 - val_loss: 0.7741 - val_accuracy: 0.9189
#
# Epoch 00217: val_accuracy did not improve from 0.93919
# Epoch 218/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0501 - accuracy: 0.9868 - val_loss: 0.5332 - val_accuracy: 0.8919
#
# Epoch 00218: val_accuracy did not improve from 0.93919
# Epoch 219/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0403 - accuracy: 0.9889 - val_loss: 0.4531 - val_accuracy: 0.9324
#
# Epoch 00219: val_accuracy did not improve from 0.93919
# Epoch 220/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 0.5574 - val_accuracy: 0.9054
#
# Epoch 00220: val_accuracy did not improve from 0.93919
# Epoch 221/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.5079 - val_accuracy: 0.9257
#
# Epoch 00221: val_accuracy did not improve from 0.93919
# Epoch 222/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0222 - accuracy: 0.9926 - val_loss: 0.6618 - val_accuracy: 0.8986
#
# Epoch 00222: val_accuracy did not improve from 0.93919
# Epoch 223/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.7651 - val_accuracy: 0.8919
#
# Epoch 00223: val_accuracy did not improve from 0.93919
# Epoch 224/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0183 - accuracy: 0.9926 - val_loss: 0.6603 - val_accuracy: 0.8986
#
# Epoch 00224: val_accuracy did not improve from 0.93919
# Epoch 225/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 0.5006 - val_accuracy: 0.9257
#
# Epoch 00225: val_accuracy did not improve from 0.93919
# Epoch 226/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.6862 - val_accuracy: 0.8919
#
# Epoch 00226: val_accuracy did not improve from 0.93919
# Epoch 227/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0255 - accuracy: 0.9942 - val_loss: 0.6437 - val_accuracy: 0.9257
#
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.93919
# Epoch 423/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.7135 - val_accuracy: 0.9122
#
# Epoch 00423: val_accuracy did not improve from 0.93919
# Epoch 424/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0224 - accuracy: 0.9937 - val_loss: 1.1358 - val_accuracy: 0.8716
#
# Epoch 00424: val_accuracy did not improve from 0.93919
# Epoch 425/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.5548 - val_accuracy: 0.9257
#
# Epoch 00425: val_accuracy did not improve from 0.93919
# Epoch 426/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.7867 - val_accuracy: 0.8851
#
# Epoch 00426: val_accuracy did not improve from 0.93919
# Epoch 427/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.7904 - val_accuracy: 0.8851
#
# Epoch 00427: val_accuracy did not improve from 0.93919
# Epoch 428/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0087 - accuracy: 0.9953 - val_loss: 0.6439 - val_accuracy: 0.9054
#
# Epoch 00428: val_accuracy did not improve from 0.93919
# Epoch 429/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.8724 - val_accuracy: 0.8784
#
# Epoch 00429: val_accuracy did not improve from 0.93919
# Epoch 430/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.6158 - val_accuracy: 0.9257
#
# Epoch 00430: val_accuracy did not improve from 0.93919
# Epoch 431/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0307 - accuracy: 0.9932 - val_loss: 0.7028 - val_accuracy: 0.9054
#
# Epoch 00431: val_accuracy did not improve from 0.93919
# Epoch 432/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0082 - accuracy: 0.9968 - val_loss: 0.6016 - val_accuracy: 0.9257
#
# Epoch 00432: val_accuracy did not improve from 0.93919
# Epoch 433/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.8310 - val_accuracy: 0.9122
#
# Epoch 00433: val_accuracy did not improve from 0.93919
# Epoch 434/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0123 - accuracy: 0.9947 - val_loss: 0.6060 - val_accuracy: 0.9189
#
# Epoch 00434: val_accuracy did not improve from 0.93919
# Epoch 435/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 1.0259 - val_accuracy: 0.8851
#
# Epoch 00435: val_accuracy did not improve from 0.93919
# Epoch 436/500
# 238/238 [==============================] - 39s 162ms/step - loss: 0.0240 - accuracy: 0.9932 - val_loss: 0.7130 - val_accuracy: 0.8986
#
# Epoch 00436: val_accuracy did not improve from 0.93919
# Epoch 437/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.6973 - val_accuracy: 0.9054
#
# Epoch 00437: val_accuracy did not improve from 0.93919
# Epoch 438/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.9136 - val_accuracy: 0.8581
#
# Epoch 00438: val_accuracy did not improve from 0.93919
# Epoch 439/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.7471 - val_accuracy: 0.8986
#
# Epoch 00439: val_accuracy did not improve from 0.93919
# Epoch 440/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0279 - accuracy: 0.9942 - val_loss: 0.6006 - val_accuracy: 0.8919
#
# Epoch 00440: val_accuracy did not improve from 0.93919
# Epoch 441/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0232 - accuracy: 0.9947 - val_loss: 0.9015 - val_accuracy: 0.8784
#
# Epoch 00441: val_accuracy did not improve from 0.93919
# Epoch 442/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0091 - accuracy: 0.9958 - val_loss: 0.8274 - val_accuracy: 0.8919
#
# Epoch 00442: val_accuracy did not improve from 0.93919
# Epoch 443/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.7163 - val_accuracy: 0.8919
#
# Epoch 00443: val_accuracy did not improve from 0.93919
# Epoch 444/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.7099 - val_accuracy: 0.8784
#
# Epoch 00444: val_accuracy did not improve from 0.93919
# Epoch 445/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0238 - accuracy: 0.9953 - val_loss: 0.6392 - val_accuracy: 0.8986
#
# Epoch 00445: val_accuracy did not improve from 0.93919
# Epoch 446/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.6703 - val_accuracy: 0.8986
#
# Epoch 00446: val_accuracy did not improve from 0.93919
# Epoch 447/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.7676 - val_accuracy: 0.8716
#
# Epoch 00447: val_accuracy did not improve from 0.93919
# Epoch 448/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0072 - accuracy: 0.9989 - val_loss: 0.7023 - val_accuracy: 0.8919
#
# Epoch 00448: val_accuracy did not improve from 0.93919
# Epoch 449/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 0.8518 - val_accuracy: 0.8919
#
# Epoch 00449: val_accuracy did not improve from 0.93919
# Epoch 450/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0061 - accuracy: 0.9974 - val_loss: 0.6558 - val_accuracy: 0.8919
#
# Epoch 00450: val_accuracy did not improve from 0.93919
# Epoch 451/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.5138 - val_accuracy: 0.9392
#
# Epoch 00451: val_accuracy did not improve from 0.93919
# Epoch 452/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0145 - accuracy: 0.9968 - val_loss: 0.9044 - val_accuracy: 0.8784
#
# Epoch 00452: val_accuracy did not improve from 0.93919
# Epoch 453/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.6536 - val_accuracy: 0.9054
#
# Epoch 00453: val_accuracy did not improve from 0.93919
# Epoch 454/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0065 - accuracy: 0.9989 - val_loss: 0.7611 - val_accuracy: 0.9122
#
# Epoch 00454: val_accuracy did not improve from 0.93919
# Epoch 455/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0080 - accuracy: 0.9984 - val_loss: 0.5248 - val_accuracy: 0.9122
#
# Epoch 00455: val_accuracy did not improve from 0.93919
# Epoch 456/500
# 238/238 [==============================] - 38s 157ms/step - loss: 0.0094 - accuracy: 0.9958 - val_loss: 0.7750 - val_accuracy: 0.8919
#
# Epoch 00456: val_accuracy did not improve from 0.93919
# Epoch 457/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.6451 - val_accuracy: 0.9054
#
# Epoch 00457: val_accuracy did not improve from 0.93919
# Epoch 458/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0387 - accuracy: 0.9900 - val_loss: 0.5828 - val_accuracy: 0.9122
#
# Epoch 00458: val_accuracy did not improve from 0.93919
# Epoch 459/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0203 - accuracy: 0.9932 - val_loss: 0.5406 - val_accuracy: 0.9324
#
# Epoch 00459: val_accuracy did not improve from 0.93919
# Epoch 460/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0312 - accuracy: 0.9932 - val_loss: 0.4745 - val_accuracy: 0.8986
#
# Epoch 00460: val_accuracy did not improve from 0.93919
# Epoch 461/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.5550 - val_accuracy: 0.9189
#
# Epoch 00461: val_accuracy did not improve from 0.93919
# Epoch 462/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.7107 - val_accuracy: 0.9054
#
# Epoch 00462: val_accuracy did not improve from 0.93919
# Epoch 463/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.5774 - val_accuracy: 0.9054
#
# Epoch 00463: val_accuracy did not improve from 0.93919
# Epoch 464/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0141 - accuracy: 0.9947 - val_loss: 0.8175 - val_accuracy: 0.8716
#
# Epoch 00464: val_accuracy did not improve from 0.93919
# Epoch 465/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0292 - accuracy: 0.9926 - val_loss: 0.6750 - val_accuracy: 0.9054
#
# Epoch 00465: val_accuracy did not improve from 0.93919
# Epoch 466/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0274 - accuracy: 0.9926 - val_loss: 0.5941 - val_accuracy: 0.9189
#
# Epoch 00466: val_accuracy did not improve from 0.93919
# Epoch 467/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.4891 - val_accuracy: 0.8986
#
# Epoch 00467: val_accuracy did not improve from 0.93919
# Epoch 468/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0058 - accuracy: 0.9995 - val_loss: 0.5377 - val_accuracy: 0.9122
#
# Epoch 00468: val_accuracy did not improve from 0.93919
# Epoch 469/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 2.5824 - val_accuracy: 0.6757
#
# Epoch 00469: val_accuracy did not improve from 0.93919
# Epoch 470/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0074 - accuracy: 0.9963 - val_loss: 0.5269 - val_accuracy: 0.9054
#
# Epoch 00470: val_accuracy did not improve from 0.93919
# Epoch 471/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.6364 - val_accuracy: 0.8986
#
# Epoch 00471: val_accuracy did not improve from 0.93919
# Epoch 472/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0099 - accuracy: 0.9958 - val_loss: 0.6257 - val_accuracy: 0.9122
#
# Epoch 00472: val_accuracy did not improve from 0.93919
# Epoch 473/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.5884 - val_accuracy: 0.9257
#
# Epoch 00473: val_accuracy did not improve from 0.93919
# Epoch 474/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.7852 - val_accuracy: 0.8784
#
# Epoch 00474: val_accuracy did not improve from 0.93919
# Epoch 475/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.7573 - val_accuracy: 0.9054
#
# Epoch 00475: val_accuracy did not improve from 0.93919
# Epoch 476/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0034 - accuracy: 0.9979 - val_loss: 0.7388 - val_accuracy: 0.9122
#
# Epoch 00476: val_accuracy did not improve from 0.93919
# Epoch 477/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0180 - accuracy: 0.9926 - val_loss: 1.3115 - val_accuracy: 0.8378
#
# Epoch 00477: val_accuracy did not improve from 0.93919
# Epoch 478/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0298 - accuracy: 0.9905 - val_loss: 6.0213 - val_accuracy: 0.5473
#
# Epoch 00478: val_accuracy did not improve from 0.93919
# Epoch 479/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 1.9282 - val_accuracy: 0.7432
#
# Epoch 00479: val_accuracy did not improve from 0.93919
# Epoch 480/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 0.7823 - val_accuracy: 0.8716
#
# Epoch 00480: val_accuracy did not improve from 0.93919
# Epoch 481/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0358 - accuracy: 0.9921 - val_loss: 0.5858 - val_accuracy: 0.9054
#
# Epoch 00481: val_accuracy did not improve from 0.93919
# Epoch 482/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.6382 - val_accuracy: 0.9324
#
# Epoch 00482: val_accuracy did not improve from 0.93919
# Epoch 483/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.6518 - val_accuracy: 0.9189
#
# Epoch 00483: val_accuracy did not improve from 0.93919
# Epoch 484/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0228 - accuracy: 0.9942 - val_loss: 0.6537 - val_accuracy: 0.9054
#
# Epoch 00484: val_accuracy did not improve from 0.93919
# Epoch 485/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0243 - accuracy: 0.9926 - val_loss: 0.6397 - val_accuracy: 0.9122
#
# Epoch 00485: val_accuracy did not improve from 0.93919
# Epoch 486/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0063 - accuracy: 0.9968 - val_loss: 0.7804 - val_accuracy: 0.8851
#
# Epoch 00486: val_accuracy did not improve from 0.93919
# Epoch 487/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.8643 - val_accuracy: 0.9054
#
# Epoch 00487: val_accuracy did not improve from 0.93919
# Epoch 488/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.8058 - val_accuracy: 0.8986
#
# Epoch 00488: val_accuracy did not improve from 0.93919
# Epoch 489/500
# 238/238 [==============================] - 38s 158ms/step - loss: 8.4787e-04 - accuracy: 1.0000 - val_loss: 0.7196 - val_accuracy: 0.9054
#
# Epoch 00489: val_accuracy did not improve from 0.93919
# Epoch 490/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0121 - accuracy: 0.9942 - val_loss: 0.8227 - val_accuracy: 0.8851
#
# Epoch 00490: val_accuracy did not improve from 0.93919
# Epoch 491/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.7633 - val_accuracy: 0.9122
#
# Epoch 00491: val_accuracy did not improve from 0.93919
# Epoch 492/500
# 238/238 [==============================] - 39s 162ms/step - loss: 0.0223 - accuracy: 0.9932 - val_loss: 0.7011 - val_accuracy: 0.8919
#
# Epoch 00492: val_accuracy did not improve from 0.93919
# Epoch 493/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0114 - accuracy: 0.9984 - val_loss: 0.4726 - val_accuracy: 0.9392
#
# Epoch 00493: val_accuracy did not improve from 0.93919
# Epoch 494/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0151 - accuracy: 0.9958 - val_loss: 0.8627 - val_accuracy: 0.8919
#
# Epoch 00494: val_accuracy did not improve from 0.93919
# Epoch 495/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0097 - accuracy: 0.9953 - val_loss: 0.6778 - val_accuracy: 0.8986
#
# Epoch 00495: val_accuracy did not improve from 0.93919
# Epoch 496/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0197 - accuracy: 0.9921 - val_loss: 0.5999 - val_accuracy: 0.9189
#
# Epoch 00496: val_accuracy did not improve from 0.93919
# Epoch 497/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.7972 - val_accuracy: 0.8986
#
# Epoch 00497: val_accuracy did not improve from 0.93919
# Epoch 498/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0150 - accuracy: 0.9953 - val_loss: 0.8472 - val_accuracy: 0.8919
#
# Epoch 00498: val_accuracy did not improve from 0.93919
# Epoch 499/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.4852 - val_accuracy: 0.9392
#
# Epoch 00499: val_accuracy did not improve from 0.93919
# Epoch 500/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.6655 - val_accuracy: 0.9122
#
# Epoch 00500: val_accuracy did not improve from 0.93919

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    # 'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # meanideal96@gamil.com
    # 'iDeal02',
    # dodo402298@gmail.com
    'mean01',
    # d9249.acc002@gmail.com
    # 'mean02',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': False, 'detail': 'Over max submission count of Daily. 일일 제출 가능한 최대 횟수가 초과 되었습니다.'}
