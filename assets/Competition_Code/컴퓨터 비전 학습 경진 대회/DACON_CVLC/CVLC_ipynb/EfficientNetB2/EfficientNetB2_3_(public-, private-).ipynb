# %%
# !nvidia-smi
# Out:
# Tue Sep 28 19:18:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
nunbering = '2'
model_save = 'EfficientNetB' + nunbering + '_3'
Target_model = 'EfficientNetB' + nunbering + '_model'
Target_predict = 'EfficientNetB' + nunbering + '_predict'
Target_acc = 'EfficientNetB' + nunbering + '_acc'
Target_val = 'EfficientNetB' + nunbering + '_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.EfficientNetB2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 67s 160ms/step - loss: 3.4275 - accuracy: 0.1300 - val_loss: 4.2687 - val_accuracy: 0.0946
#
# Epoch 00001: val_accuracy improved from -inf to 0.09459, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 36s 151ms/step - loss: 2.2312 - accuracy: 0.2300 - val_loss: 4.0132 - val_accuracy: 0.1014
#
# Epoch 00002: val_accuracy improved from 0.09459 to 0.10135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 3/500
# 238/238 [==============================] - 36s 152ms/step - loss: 1.7853 - accuracy: 0.3816 - val_loss: 2.1559 - val_accuracy: 0.3311
#
# Epoch 00003: val_accuracy improved from 0.10135 to 0.33108, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 4/500
# 238/238 [==============================] - 36s 152ms/step - loss: 1.3922 - accuracy: 0.5421 - val_loss: 3.8887 - val_accuracy: 0.1622
#
# Epoch 00004: val_accuracy did not improve from 0.33108
# Epoch 5/500
# 238/238 [==============================] - 36s 152ms/step - loss: 1.1607 - accuracy: 0.6163 - val_loss: 0.8860 - val_accuracy: 0.6689
#
# Epoch 00005: val_accuracy improved from 0.33108 to 0.66892, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 6/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.9225 - accuracy: 0.6895 - val_loss: 2.4602 - val_accuracy: 0.3378
#
# Epoch 00006: val_accuracy did not improve from 0.66892
# Epoch 7/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.8050 - accuracy: 0.7400 - val_loss: 0.8595 - val_accuracy: 0.7162
#
# Epoch 00007: val_accuracy improved from 0.66892 to 0.71622, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 8/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.6960 - accuracy: 0.7753 - val_loss: 1.2409 - val_accuracy: 0.6622
#
# Epoch 00008: val_accuracy did not improve from 0.71622
# Epoch 9/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.6829 - accuracy: 0.7847 - val_loss: 1.0993 - val_accuracy: 0.6757
#
# Epoch 00009: val_accuracy did not improve from 0.71622
# Epoch 10/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.5849 - accuracy: 0.8153 - val_loss: 0.6180 - val_accuracy: 0.7838
#
# Epoch 00010: val_accuracy improved from 0.71622 to 0.78378, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 11/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.6046 - accuracy: 0.7937 - val_loss: 1.0661 - val_accuracy: 0.7230
#
# Epoch 00011: val_accuracy did not improve from 0.78378
# Epoch 12/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.5124 - accuracy: 0.8305 - val_loss: 0.8889 - val_accuracy: 0.7365
#
# Epoch 00012: val_accuracy did not improve from 0.78378
# Epoch 13/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.5114 - accuracy: 0.8411 - val_loss: 0.5492 - val_accuracy: 0.8108
#
# Epoch 00013: val_accuracy improved from 0.78378 to 0.81081, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 14/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.5204 - accuracy: 0.8426 - val_loss: 0.5116 - val_accuracy: 0.8446
#
# Epoch 00014: val_accuracy improved from 0.81081 to 0.84459, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 15/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.4260 - accuracy: 0.8705 - val_loss: 0.8737 - val_accuracy: 0.7770
#
# Epoch 00015: val_accuracy did not improve from 0.84459
# Epoch 16/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.4330 - accuracy: 0.8705 - val_loss: 0.7846 - val_accuracy: 0.7500
#
# Epoch 00016: val_accuracy did not improve from 0.84459
# Epoch 17/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.4266 - accuracy: 0.8584 - val_loss: 0.5201 - val_accuracy: 0.8378
#
# Epoch 00017: val_accuracy did not improve from 0.84459
# Epoch 18/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.4469 - accuracy: 0.8537 - val_loss: 0.4902 - val_accuracy: 0.8446
#
# Epoch 00018: val_accuracy did not improve from 0.84459
# Epoch 19/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3478 - accuracy: 0.8868 - val_loss: 0.4042 - val_accuracy: 0.8716
#
# Epoch 00019: val_accuracy improved from 0.84459 to 0.87162, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 20/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.4049 - accuracy: 0.8737 - val_loss: 0.3655 - val_accuracy: 0.8784
#
# Epoch 00020: val_accuracy improved from 0.87162 to 0.87838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 21/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.3406 - accuracy: 0.8963 - val_loss: 2.2889 - val_accuracy: 0.4527
#
# Epoch 00021: val_accuracy did not improve from 0.87838
# Epoch 22/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.3472 - accuracy: 0.8853 - val_loss: 1.1065 - val_accuracy: 0.7703
#
# Epoch 00022: val_accuracy did not improve from 0.87838
# Epoch 23/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3471 - accuracy: 0.8916 - val_loss: 0.9505 - val_accuracy: 0.7635
#
# Epoch 00023: val_accuracy did not improve from 0.87838
# Epoch 24/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3366 - accuracy: 0.8889 - val_loss: 0.5364 - val_accuracy: 0.8108
#
# Epoch 00024: val_accuracy did not improve from 0.87838
# Epoch 25/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.2865 - accuracy: 0.9053 - val_loss: 1.0768 - val_accuracy: 0.7162
#
# Epoch 00025: val_accuracy did not improve from 0.87838
# Epoch 26/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2854 - accuracy: 0.9074 - val_loss: 0.5270 - val_accuracy: 0.8446
#
# Epoch 00026: val_accuracy did not improve from 0.87838
# Epoch 27/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.3228 - accuracy: 0.9016 - val_loss: 0.6369 - val_accuracy: 0.8446
#
# Epoch 00027: val_accuracy did not improve from 0.87838
# Epoch 28/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2736 - accuracy: 0.9121 - val_loss: 0.6415 - val_accuracy: 0.8176
#
# Epoch 00028: val_accuracy did not improve from 0.87838
# Epoch 29/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2902 - accuracy: 0.9105 - val_loss: 0.6840 - val_accuracy: 0.8311
#
# Epoch 00029: val_accuracy did not improve from 0.87838
# Epoch 30/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2493 - accuracy: 0.9216 - val_loss: 0.9102 - val_accuracy: 0.8108
#
# Epoch 00030: val_accuracy did not improve from 0.87838
# Epoch 31/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2529 - accuracy: 0.9253 - val_loss: 3.2578 - val_accuracy: 0.3581
#
# Epoch 00031: val_accuracy did not improve from 0.87838
# Epoch 32/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2481 - accuracy: 0.9179 - val_loss: 0.4076 - val_accuracy: 0.8986
#
# Epoch 00032: val_accuracy improved from 0.87838 to 0.89865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 33/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.2428 - accuracy: 0.9274 - val_loss: 1.5359 - val_accuracy: 0.6419
#
# Epoch 00033: val_accuracy did not improve from 0.89865
# Epoch 34/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2641 - accuracy: 0.9179 - val_loss: 0.5220 - val_accuracy: 0.8514
#
# Epoch 00034: val_accuracy did not improve from 0.89865
# Epoch 35/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1923 - accuracy: 0.9395 - val_loss: 0.6920 - val_accuracy: 0.8378
#
# Epoch 00035: val_accuracy did not improve from 0.89865
# Epoch 36/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2027 - accuracy: 0.9363 - val_loss: 2.4012 - val_accuracy: 0.5270
#
# Epoch 00036: val_accuracy did not improve from 0.89865
# Epoch 37/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.2371 - accuracy: 0.9211 - val_loss: 1.1019 - val_accuracy: 0.7500
#
# Epoch 00037: val_accuracy did not improve from 0.89865
# Epoch 38/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.2040 - accuracy: 0.9416 - val_loss: 0.9045 - val_accuracy: 0.8176
#
# Epoch 00038: val_accuracy did not improve from 0.89865
# Epoch 39/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1946 - accuracy: 0.9342 - val_loss: 0.5273 - val_accuracy: 0.8784
#
# Epoch 00039: val_accuracy did not improve from 0.89865
# Epoch 40/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.2189 - accuracy: 0.9316 - val_loss: 3.9117 - val_accuracy: 0.2838
#
# Epoch 00040: val_accuracy did not improve from 0.89865
# Epoch 41/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1883 - accuracy: 0.9379 - val_loss: 1.4830 - val_accuracy: 0.6757
#
# Epoch 00041: val_accuracy did not improve from 0.89865
# Epoch 42/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1920 - accuracy: 0.9421 - val_loss: 3.5436 - val_accuracy: 0.3581
#
# Epoch 00042: val_accuracy did not improve from 0.89865
# Epoch 43/500
# 238/238 [==============================] - 36s 150ms/step - loss: 0.1844 - accuracy: 0.9463 - val_loss: 0.4221 - val_accuracy: 0.8919
#
# Epoch 00043: val_accuracy did not improve from 0.89865
# Epoch 44/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1737 - accuracy: 0.9442 - val_loss: 0.8513 - val_accuracy: 0.8041
#
# Epoch 00044: val_accuracy did not improve from 0.89865
# Epoch 45/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1653 - accuracy: 0.9479 - val_loss: 5.0272 - val_accuracy: 0.1824
#
# Epoch 00045: val_accuracy did not improve from 0.89865
# Epoch 46/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1565 - accuracy: 0.9437 - val_loss: 2.0771 - val_accuracy: 0.6419
#
# Epoch 00046: val_accuracy did not improve from 0.89865
# Epoch 47/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1867 - accuracy: 0.9384 - val_loss: 0.8320 - val_accuracy: 0.7838
#
# Epoch 00047: val_accuracy did not improve from 0.89865
# Epoch 48/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1542 - accuracy: 0.9521 - val_loss: 0.5976 - val_accuracy: 0.8446
#
# Epoch 00048: val_accuracy did not improve from 0.89865
# Epoch 49/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1734 - accuracy: 0.9374 - val_loss: 0.5522 - val_accuracy: 0.8514
#
# Epoch 00049: val_accuracy did not improve from 0.89865
# Epoch 50/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1289 - accuracy: 0.9611 - val_loss: 0.3396 - val_accuracy: 0.9054
#
# Epoch 00050: val_accuracy improved from 0.89865 to 0.90541, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 51/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.1260 - accuracy: 0.9600 - val_loss: 0.6909 - val_accuracy: 0.8581
#
# Epoch 00051: val_accuracy did not improve from 0.90541
# Epoch 52/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1426 - accuracy: 0.9579 - val_loss: 0.4749 - val_accuracy: 0.8851
#
# Epoch 00052: val_accuracy did not improve from 0.90541
# Epoch 53/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1274 - accuracy: 0.9547 - val_loss: 2.7008 - val_accuracy: 0.5676
#
# Epoch 00053: val_accuracy did not improve from 0.90541
# Epoch 54/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1377 - accuracy: 0.9605 - val_loss: 1.6124 - val_accuracy: 0.6689
#
# Epoch 00054: val_accuracy did not improve from 0.90541
# Epoch 55/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1486 - accuracy: 0.9526 - val_loss: 0.3993 - val_accuracy: 0.8851
#
# Epoch 00055: val_accuracy did not improve from 0.90541
# Epoch 56/500
# 238/238 [==============================] - 36s 151ms/step - loss: 0.1230 - accuracy: 0.9589 - val_loss: 2.9582 - val_accuracy: 0.4054
#
# Epoch 00056: val_accuracy did not improve from 0.90541
# Epoch 57/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0977 - accuracy: 0.9705 - val_loss: 0.6089 - val_accuracy: 0.8514
#
# Epoch 00057: val_accuracy did not improve from 0.90541
# Epoch 58/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1378 - accuracy: 0.9605 - val_loss: 0.6947 - val_accuracy: 0.8378
#
# Epoch 00058: val_accuracy did not improve from 0.90541
# Epoch 59/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1375 - accuracy: 0.9589 - val_loss: 0.5116 - val_accuracy: 0.8649
#
# Epoch 00059: val_accuracy did not improve from 0.90541
# Epoch 60/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.1134 - accuracy: 0.9632 - val_loss: 0.7113 - val_accuracy: 0.8446
#
# Epoch 00060: val_accuracy did not improve from 0.90541
# Epoch 61/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0897 - accuracy: 0.9732 - val_loss: 0.4387 - val_accuracy: 0.9189
#
# Epoch 00061: val_accuracy improved from 0.90541 to 0.91892, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 62/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1068 - accuracy: 0.9674 - val_loss: 1.2324 - val_accuracy: 0.7905
#
# Epoch 00062: val_accuracy did not improve from 0.91892
# Epoch 63/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0968 - accuracy: 0.9642 - val_loss: 0.6374 - val_accuracy: 0.8716
#
# Epoch 00063: val_accuracy did not improve from 0.91892
# Epoch 64/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0941 - accuracy: 0.9721 - val_loss: 2.4023 - val_accuracy: 0.5473
#
# Epoch 00064: val_accuracy did not improve from 0.91892
# Epoch 65/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1400 - accuracy: 0.9568 - val_loss: 0.4058 - val_accuracy: 0.9189
#
# Epoch 00065: val_accuracy did not improve from 0.91892
# Epoch 66/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0967 - accuracy: 0.9674 - val_loss: 0.5044 - val_accuracy: 0.8784
#
# Epoch 00066: val_accuracy did not improve from 0.91892
# Epoch 67/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0870 - accuracy: 0.9726 - val_loss: 0.6135 - val_accuracy: 0.8919
#
# Epoch 00067: val_accuracy did not improve from 0.91892
# Epoch 68/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0849 - accuracy: 0.9705 - val_loss: 0.2876 - val_accuracy: 0.9257
#
# Epoch 00068: val_accuracy improved from 0.91892 to 0.92568, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 69/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1128 - accuracy: 0.9668 - val_loss: 1.5967 - val_accuracy: 0.6014
#
# Epoch 00069: val_accuracy did not improve from 0.92568
# Epoch 70/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0725 - accuracy: 0.9747 - val_loss: 0.5881 - val_accuracy: 0.8649
#
# Epoch 00070: val_accuracy did not improve from 0.92568
# Epoch 71/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1454 - accuracy: 0.9521 - val_loss: 0.6312 - val_accuracy: 0.8919
#
# Epoch 00071: val_accuracy did not improve from 0.92568
# Epoch 72/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.1095 - accuracy: 0.9626 - val_loss: 0.5843 - val_accuracy: 0.8986
#
# Epoch 00072: val_accuracy did not improve from 0.92568
# Epoch 73/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0630 - accuracy: 0.9789 - val_loss: 0.3500 - val_accuracy: 0.9189
#
# Epoch 00073: val_accuracy did not improve from 0.92568
# Epoch 74/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0903 - accuracy: 0.9732 - val_loss: 0.4132 - val_accuracy: 0.8851
#
# Epoch 00074: val_accuracy did not improve from 0.92568
# Epoch 75/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0576 - accuracy: 0.9789 - val_loss: 0.3631 - val_accuracy: 0.9392
#
# Epoch 00075: val_accuracy improved from 0.92568 to 0.93919, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_3.h5
# Epoch 76/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0910 - accuracy: 0.9716 - val_loss: 0.8332 - val_accuracy: 0.8378
#
# Epoch 00076: val_accuracy did not improve from 0.93919
# Epoch 77/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0806 - accuracy: 0.9726 - val_loss: 0.4510 - val_accuracy: 0.8986
#
# Epoch 00077: val_accuracy did not improve from 0.93919
# Epoch 78/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0997 - accuracy: 0.9658 - val_loss: 0.4793 - val_accuracy: 0.8784
#
# Epoch 00078: val_accuracy did not improve from 0.93919
# Epoch 79/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.1052 - accuracy: 0.9668 - val_loss: 0.4489 - val_accuracy: 0.8716
#
# Epoch 00079: val_accuracy did not improve from 0.93919
# Epoch 80/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0821 - accuracy: 0.9711 - val_loss: 0.6297 - val_accuracy: 0.8649
#
# Epoch 00080: val_accuracy did not improve from 0.93919
# Epoch 81/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0827 - accuracy: 0.9716 - val_loss: 0.5048 - val_accuracy: 0.8851
#
# Epoch 00081: val_accuracy did not improve from 0.93919
# Epoch 82/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0745 - accuracy: 0.9753 - val_loss: 0.4506 - val_accuracy: 0.9324
#
# Epoch 00082: val_accuracy did not improve from 0.93919
# Epoch 83/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0944 - accuracy: 0.9758 - val_loss: 0.5812 - val_accuracy: 0.8851
#
# Epoch 00083: val_accuracy did not improve from 0.93919
# Epoch 84/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0486 - accuracy: 0.9832 - val_loss: 0.4202 - val_accuracy: 0.9257
#
# Epoch 00084: val_accuracy did not improve from 0.93919
# Epoch 85/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0620 - accuracy: 0.9800 - val_loss: 0.3482 - val_accuracy: 0.9122
#
# Epoch 00085: val_accuracy did not improve from 0.93919
# Epoch 86/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0592 - accuracy: 0.9826 - val_loss: 0.6590 - val_accuracy: 0.8581
#
# Epoch 00086: val_accuracy did not improve from 0.93919
# Epoch 87/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0965 - accuracy: 0.9684 - val_loss: 0.4801 - val_accuracy: 0.8986
#
# Epoch 00087: val_accuracy did not improve from 0.93919
# Epoch 88/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0587 - accuracy: 0.9826 - val_loss: 0.4117 - val_accuracy: 0.9054
#
# Epoch 00088: val_accuracy did not improve from 0.93919
# Epoch 89/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0870 - accuracy: 0.9705 - val_loss: 0.4732 - val_accuracy: 0.9122
#
# Epoch 00089: val_accuracy did not improve from 0.93919
# Epoch 90/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0708 - accuracy: 0.9795 - val_loss: 0.6215 - val_accuracy: 0.8986
#
# Epoch 00090: val_accuracy did not improve from 0.93919
# Epoch 91/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0719 - accuracy: 0.9795 - val_loss: 1.5151 - val_accuracy: 0.7365
#
# Epoch 00091: val_accuracy did not improve from 0.93919
# Epoch 92/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0648 - accuracy: 0.9847 - val_loss: 0.7024 - val_accuracy: 0.8378
#
# Epoch 00092: val_accuracy did not improve from 0.93919
# Epoch 93/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.1022 - accuracy: 0.9653 - val_loss: 0.5065 - val_accuracy: 0.8986
#
# Epoch 00093: val_accuracy did not improve from 0.93919
# Epoch 94/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0650 - accuracy: 0.9784 - val_loss: 0.5185 - val_accuracy: 0.8851
#
# Epoch 00094: val_accuracy did not improve from 0.93919
# Epoch 95/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0556 - accuracy: 0.9847 - val_loss: 0.4046 - val_accuracy: 0.9054
#
# Epoch 00095: val_accuracy did not improve from 0.93919
# Epoch 96/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0556 - accuracy: 0.9832 - val_loss: 0.7884 - val_accuracy: 0.8784
#
# Epoch 00096: val_accuracy did not improve from 0.93919
# Epoch 97/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0514 - accuracy: 0.9821 - val_loss: 0.5538 - val_accuracy: 0.8851
#
# Epoch 00097: val_accuracy did not improve from 0.93919
# Epoch 98/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0930 - accuracy: 0.9742 - val_loss: 0.5277 - val_accuracy: 0.8851
#
# Epoch 00098: val_accuracy did not improve from 0.93919
# Epoch 99/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0794 - accuracy: 0.9774 - val_loss: 0.4624 - val_accuracy: 0.8919
#
# Epoch 00099: val_accuracy did not improve from 0.93919
# Epoch 100/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0418 - accuracy: 0.9863 - val_loss: 0.5338 - val_accuracy: 0.9189
#
# Epoch 00100: val_accuracy did not improve from 0.93919
# Epoch 101/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0692 - accuracy: 0.9795 - val_loss: 0.3843 - val_accuracy: 0.9189
#
# Epoch 00101: val_accuracy did not improve from 0.93919
# Epoch 102/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0365 - accuracy: 0.9874 - val_loss: 0.3549 - val_accuracy: 0.9122
#
# Epoch 00102: val_accuracy did not improve from 0.93919
# Epoch 103/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0476 - accuracy: 0.9858 - val_loss: 0.5144 - val_accuracy: 0.9054
#
# Epoch 00103: val_accuracy did not improve from 0.93919
# Epoch 104/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0614 - accuracy: 0.9774 - val_loss: 0.9660 - val_accuracy: 0.8514
#
# Epoch 00104: val_accuracy did not improve from 0.93919
# Epoch 105/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0690 - accuracy: 0.9732 - val_loss: 3.0070 - val_accuracy: 0.5203
#
# Epoch 00105: val_accuracy did not improve from 0.93919
# Epoch 106/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0498 - accuracy: 0.9847 - val_loss: 0.5745 - val_accuracy: 0.9189
#
# Epoch 00106: val_accuracy did not improve from 0.93919
# Epoch 107/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0579 - accuracy: 0.9837 - val_loss: 0.6680 - val_accuracy: 0.8986
#
# Epoch 00107: val_accuracy did not improve from 0.93919
# Epoch 108/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0746 - accuracy: 0.9779 - val_loss: 0.5440 - val_accuracy: 0.9054
#
# Epoch 00108: val_accuracy did not improve from 0.93919
# Epoch 109/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0737 - accuracy: 0.9758 - val_loss: 0.4565 - val_accuracy: 0.9054
#
# Epoch 00109: val_accuracy did not improve from 0.93919
# Epoch 110/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0302 - accuracy: 0.9900 - val_loss: 0.4282 - val_accuracy: 0.9054
#
# Epoch 00110: val_accuracy did not improve from 0.93919
# Epoch 111/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0381 - accuracy: 0.9879 - val_loss: 1.3956 - val_accuracy: 0.7838
#
# Epoch 00111: val_accuracy did not improve from 0.93919
# Epoch 112/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0847 - accuracy: 0.9732 - val_loss: 0.6254 - val_accuracy: 0.8716
#
# Epoch 00112: val_accuracy did not improve from 0.93919
# Epoch 113/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0572 - accuracy: 0.9832 - val_loss: 0.5100 - val_accuracy: 0.9189
#
# Epoch 00113: val_accuracy did not improve from 0.93919
# Epoch 114/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0358 - accuracy: 0.9858 - val_loss: 0.4647 - val_accuracy: 0.9054
#
# Epoch 00114: val_accuracy did not improve from 0.93919
# Epoch 115/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0447 - accuracy: 0.9853 - val_loss: 0.6127 - val_accuracy: 0.9054
#
# Epoch 00115: val_accuracy did not improve from 0.93919
# Epoch 116/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0436 - accuracy: 0.9879 - val_loss: 0.8387 - val_accuracy: 0.8716
#
# Epoch 00116: val_accuracy did not improve from 0.93919
# Epoch 117/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0352 - accuracy: 0.9905 - val_loss: 0.5742 - val_accuracy: 0.9122
#
# Epoch 00117: val_accuracy did not improve from 0.93919
# Epoch 118/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0742 - accuracy: 0.9789 - val_loss: 0.5216 - val_accuracy: 0.8851
#
# Epoch 00118: val_accuracy did not improve from 0.93919
# Epoch 119/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0578 - accuracy: 0.9832 - val_loss: 0.5088 - val_accuracy: 0.9189
#
# Epoch 00119: val_accuracy did not improve from 0.93919
# Epoch 120/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0682 - accuracy: 0.9800 - val_loss: 0.7142 - val_accuracy: 0.8716
#
# Epoch 00120: val_accuracy did not improve from 0.93919
# Epoch 121/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0532 - accuracy: 0.9816 - val_loss: 0.6168 - val_accuracy: 0.8919
#
# Epoch 00121: val_accuracy did not improve from 0.93919
# Epoch 122/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0512 - accuracy: 0.9853 - val_loss: 0.8762 - val_accuracy: 0.8176
#
# Epoch 00122: val_accuracy did not improve from 0.93919
# Epoch 123/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0597 - accuracy: 0.9821 - val_loss: 0.6027 - val_accuracy: 0.8919
#
# Epoch 00123: val_accuracy did not improve from 0.93919
# Epoch 124/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0645 - accuracy: 0.9789 - val_loss: 0.7290 - val_accuracy: 0.8919
#
# Epoch 00124: val_accuracy did not improve from 0.93919
# Epoch 125/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0369 - accuracy: 0.9858 - val_loss: 0.7268 - val_accuracy: 0.8851
#
# Epoch 00125: val_accuracy did not improve from 0.93919
# Epoch 126/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0345 - accuracy: 0.9905 - val_loss: 0.6953 - val_accuracy: 0.9054
#
# Epoch 00126: val_accuracy did not improve from 0.93919
# Epoch 127/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0259 - accuracy: 0.9932 - val_loss: 0.8283 - val_accuracy: 0.8581
#
# Epoch 00127: val_accuracy did not improve from 0.93919
# Epoch 128/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0605 - accuracy: 0.9821 - val_loss: 0.8375 - val_accuracy: 0.8378
#
# Epoch 00128: val_accuracy did not improve from 0.93919
# Epoch 129/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0789 - accuracy: 0.9795 - val_loss: 0.6820 - val_accuracy: 0.8649
#
# Epoch 00129: val_accuracy did not improve from 0.93919
# Epoch 130/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0421 - accuracy: 0.9853 - val_loss: 0.4410 - val_accuracy: 0.9122
#
# Epoch 00130: val_accuracy did not improve from 0.93919
# Epoch 131/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 0.5711 - val_accuracy: 0.8784
#
# Epoch 00131: val_accuracy did not improve from 0.93919
# Epoch 132/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0637 - accuracy: 0.9832 - val_loss: 0.5751 - val_accuracy: 0.8649
#
# Epoch 00132: val_accuracy did not improve from 0.93919
# Epoch 133/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0899 - accuracy: 0.9716 - val_loss: 0.5667 - val_accuracy: 0.8649
#
# Epoch 00133: val_accuracy did not improve from 0.93919
# Epoch 134/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0292 - accuracy: 0.9905 - val_loss: 0.4407 - val_accuracy: 0.9054
#
# Epoch 00134: val_accuracy did not improve from 0.93919
# Epoch 135/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0572 - accuracy: 0.9805 - val_loss: 0.7963 - val_accuracy: 0.8649
#
# Epoch 00135: val_accuracy did not improve from 0.93919
# Epoch 136/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0328 - accuracy: 0.9884 - val_loss: 0.5089 - val_accuracy: 0.8851
#
# Epoch 00136: val_accuracy did not improve from 0.93919
# Epoch 137/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 0.8239 - val_accuracy: 0.8716
#
# Epoch 00137: val_accuracy did not improve from 0.93919
# Epoch 138/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0539 - accuracy: 0.9800 - val_loss: 0.6211 - val_accuracy: 0.8784
#
# Epoch 00138: val_accuracy did not improve from 0.93919
# Epoch 139/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0497 - accuracy: 0.9816 - val_loss: 0.4194 - val_accuracy: 0.9054
#
# Epoch 00139: val_accuracy did not improve from 0.93919
# Epoch 140/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 1.1049 - val_accuracy: 0.7905
#
# Epoch 00140: val_accuracy did not improve from 0.93919
# Epoch 141/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0517 - accuracy: 0.9842 - val_loss: 0.8570 - val_accuracy: 0.8243
#
# Epoch 00141: val_accuracy did not improve from 0.93919
# Epoch 142/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0427 - accuracy: 0.9858 - val_loss: 0.5264 - val_accuracy: 0.9054
#
# Epoch 00142: val_accuracy did not improve from 0.93919
# Epoch 143/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0635 - accuracy: 0.9853 - val_loss: 0.7817 - val_accuracy: 0.8716
#
# Epoch 00143: val_accuracy did not improve from 0.93919
# Epoch 144/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0600 - accuracy: 0.9789 - val_loss: 0.5802 - val_accuracy: 0.8986
#
# Epoch 00144: val_accuracy did not improve from 0.93919
# Epoch 145/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 0.5739 - val_accuracy: 0.8986
#
# Epoch 00145: val_accuracy did not improve from 0.93919
# Epoch 146/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0303 - accuracy: 0.9900 - val_loss: 0.3934 - val_accuracy: 0.9392
#
# Epoch 00146: val_accuracy did not improve from 0.93919
# Epoch 147/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0633 - accuracy: 0.9847 - val_loss: 0.5149 - val_accuracy: 0.8649
#
# Epoch 00147: val_accuracy did not improve from 0.93919
# Epoch 148/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0566 - accuracy: 0.9784 - val_loss: 0.8773 - val_accuracy: 0.8243
#
# Epoch 00148: val_accuracy did not improve from 0.93919
# Epoch 149/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0422 - accuracy: 0.9858 - val_loss: 0.6766 - val_accuracy: 0.8784
#
# Epoch 00149: val_accuracy did not improve from 0.93919
# Epoch 150/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0213 - accuracy: 0.9932 - val_loss: 0.5416 - val_accuracy: 0.8986
#
# Epoch 00150: val_accuracy did not improve from 0.93919
# Epoch 151/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0222 - accuracy: 0.9963 - val_loss: 0.4233 - val_accuracy: 0.9054
#
# Epoch 00151: val_accuracy did not improve from 0.93919
# Epoch 152/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0505 - accuracy: 0.9837 - val_loss: 0.6395 - val_accuracy: 0.8649
#
# Epoch 00152: val_accuracy did not improve from 0.93919
# Epoch 153/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0321 - accuracy: 0.9905 - val_loss: 0.4366 - val_accuracy: 0.9189
#
# Epoch 00153: val_accuracy did not improve from 0.93919
# Epoch 154/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0447 - accuracy: 0.9889 - val_loss: 0.6196 - val_accuracy: 0.8851
#
# Epoch 00154: val_accuracy did not improve from 0.93919
# Epoch 155/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0658 - accuracy: 0.9821 - val_loss: 0.6303 - val_accuracy: 0.8784
#
# Epoch 00155: val_accuracy did not improve from 0.93919
# Epoch 156/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.5850 - val_accuracy: 0.9122
#
# Epoch 00156: val_accuracy did not improve from 0.93919
# Epoch 157/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0356 - accuracy: 0.9900 - val_loss: 0.6304 - val_accuracy: 0.8716
#
# Epoch 00157: val_accuracy did not improve from 0.93919
# Epoch 158/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0338 - accuracy: 0.9879 - val_loss: 0.5956 - val_accuracy: 0.8716
#
# Epoch 00158: val_accuracy did not improve from 0.93919
# Epoch 159/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0473 - accuracy: 0.9858 - val_loss: 0.6181 - val_accuracy: 0.8919
#
# Epoch 00159: val_accuracy did not improve from 0.93919
# Epoch 160/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0417 - accuracy: 0.9879 - val_loss: 0.5127 - val_accuracy: 0.9054
#
# Epoch 00160: val_accuracy did not improve from 0.93919
# Epoch 161/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0337 - accuracy: 0.9874 - val_loss: 0.5729 - val_accuracy: 0.9054
#
# Epoch 00161: val_accuracy did not improve from 0.93919
# Epoch 162/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0421 - accuracy: 0.9868 - val_loss: 0.8872 - val_accuracy: 0.8784
#
# Epoch 00162: val_accuracy did not improve from 0.93919
# Epoch 163/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0279 - accuracy: 0.9937 - val_loss: 0.6092 - val_accuracy: 0.8851
#
# Epoch 00163: val_accuracy did not improve from 0.93919
# Epoch 164/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0406 - accuracy: 0.9874 - val_loss: 0.4796 - val_accuracy: 0.9257
#
# Epoch 00164: val_accuracy did not improve from 0.93919
# Epoch 165/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0288 - accuracy: 0.9916 - val_loss: 0.7032 - val_accuracy: 0.8851
#
# Epoch 00165: val_accuracy did not improve from 0.93919
# Epoch 166/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0375 - accuracy: 0.9879 - val_loss: 0.7020 - val_accuracy: 0.8851
#
# Epoch 00166: val_accuracy did not improve from 0.93919
# Epoch 167/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0467 - accuracy: 0.9832 - val_loss: 0.5744 - val_accuracy: 0.8784
#
# Epoch 00167: val_accuracy did not improve from 0.93919
# Epoch 168/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0271 - accuracy: 0.9900 - val_loss: 0.7534 - val_accuracy: 0.8581
#
# Epoch 00168: val_accuracy did not improve from 0.93919
# Epoch 169/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.5788 - val_accuracy: 0.8784
#
# Epoch 00169: val_accuracy did not improve from 0.93919
# Epoch 170/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0539 - accuracy: 0.9832 - val_loss: 0.7631 - val_accuracy: 0.8784
#
# Epoch 00170: val_accuracy did not improve from 0.93919
# Epoch 171/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0404 - accuracy: 0.9874 - val_loss: 0.5938 - val_accuracy: 0.8851
#
# Epoch 00171: val_accuracy did not improve from 0.93919
# Epoch 172/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.4921 - val_accuracy: 0.9257
#
# Epoch 00172: val_accuracy did not improve from 0.93919
# Epoch 173/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0292 - accuracy: 0.9900 - val_loss: 0.5555 - val_accuracy: 0.8784
#
# Epoch 00173: val_accuracy did not improve from 0.93919
# Epoch 174/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.4785 - val_accuracy: 0.8919
#
# Epoch 00174: val_accuracy did not improve from 0.93919
# Epoch 175/500
# 238/238 [==============================] - 36s 152ms/step - loss: 0.0268 - accuracy: 0.9900 - val_loss: 0.6748 - val_accuracy: 0.8919
#
# Epoch 00175: val_accuracy did not improve from 0.93919
# Epoch 176/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0296 - accuracy: 0.9916 - val_loss: 0.5696 - val_accuracy: 0.8986
#
# Epoch 00176: val_accuracy did not improve from 0.93919
# Epoch 177/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0384 - accuracy: 0.9868 - val_loss: 0.9252 - val_accuracy: 0.8514
#
# Epoch 00177: val_accuracy did not improve from 0.93919
# Epoch 178/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0325 - accuracy: 0.9895 - val_loss: 0.5711 - val_accuracy: 0.9189
#
# Epoch 00178: val_accuracy did not improve from 0.93919
# Epoch 179/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0252 - accuracy: 0.9905 - val_loss: 0.5878 - val_accuracy: 0.9054
#
# Epoch 00179: val_accuracy did not improve from 0.93919
# Epoch 180/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0306 - accuracy: 0.9900 - val_loss: 0.7577 - val_accuracy: 0.8784
#
# Epoch 00180: val_accuracy did not improve from 0.93919
# Epoch 181/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0398 - accuracy: 0.9868 - val_loss: 0.7549 - val_accuracy: 0.8716
#
# Epoch 00181: val_accuracy did not improve from 0.93919
# Epoch 182/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0602 - accuracy: 0.9826 - val_loss: 0.4322 - val_accuracy: 0.9257
#
# Epoch 00182: val_accuracy did not improve from 0.93919
# Epoch 183/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0409 - accuracy: 0.9858 - val_loss: 0.5113 - val_accuracy: 0.9189
#
# Epoch 00183: val_accuracy did not improve from 0.93919
# Epoch 184/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0192 - accuracy: 0.9953 - val_loss: 0.4302 - val_accuracy: 0.8986
#
# Epoch 00184: val_accuracy did not improve from 0.93919
# Epoch 185/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0174 - accuracy: 0.9937 - val_loss: 0.5744 - val_accuracy: 0.8919
#
# Epoch 00185: val_accuracy did not improve from 0.93919
# Epoch 186/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0231 - accuracy: 0.9911 - val_loss: 0.7608 - val_accuracy: 0.8851
#
# Epoch 00186: val_accuracy did not improve from 0.93919
# Epoch 187/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.5486 - val_accuracy: 0.9257
#
# Epoch 00187: val_accuracy did not improve from 0.93919
# Epoch 188/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0268 - accuracy: 0.9926 - val_loss: 0.5448 - val_accuracy: 0.8919
#
# Epoch 00188: val_accuracy did not improve from 0.93919
# Epoch 189/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.8252 - val_accuracy: 0.8784
#
# Epoch 00189: val_accuracy did not improve from 0.93919
# Epoch 190/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0485 - accuracy: 0.9832 - val_loss: 0.5611 - val_accuracy: 0.9054
#
# Epoch 00190: val_accuracy did not improve from 0.93919
# Epoch 191/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0514 - accuracy: 0.9826 - val_loss: 0.5599 - val_accuracy: 0.9122
#
# Epoch 00191: val_accuracy did not improve from 0.93919
# Epoch 192/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0489 - accuracy: 0.9868 - val_loss: 0.9525 - val_accuracy: 0.8514
#
# Epoch 00192: val_accuracy did not improve from 0.93919
# Epoch 193/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0332 - accuracy: 0.9889 - val_loss: 0.7756 - val_accuracy: 0.8919
#
# Epoch 00193: val_accuracy did not improve from 0.93919
# Epoch 194/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0580 - accuracy: 0.9832 - val_loss: 0.4643 - val_accuracy: 0.9054
#
# Epoch 00194: val_accuracy did not improve from 0.93919
# Epoch 195/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0255 - accuracy: 0.9900 - val_loss: 0.5243 - val_accuracy: 0.9122
#
# Epoch 00195: val_accuracy did not improve from 0.93919
# Epoch 196/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.5174 - val_accuracy: 0.8986
#
# Epoch 00196: val_accuracy did not improve from 0.93919
# Epoch 197/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.6280 - val_accuracy: 0.8986
#
# Epoch 00197: val_accuracy did not improve from 0.93919
# Epoch 198/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 0.7741 - val_accuracy: 0.8919
#
# Epoch 00198: val_accuracy did not improve from 0.93919
# Epoch 199/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0401 - accuracy: 0.9868 - val_loss: 0.6119 - val_accuracy: 0.8919
#
# Epoch 00199: val_accuracy did not improve from 0.93919
# Epoch 200/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.5806 - val_accuracy: 0.8986
#
# Epoch 00200: val_accuracy did not improve from 0.93919
# Epoch 201/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0468 - accuracy: 0.9858 - val_loss: 0.5960 - val_accuracy: 0.9054
#
# Epoch 00201: val_accuracy did not improve from 0.93919
# Epoch 202/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0384 - accuracy: 0.9868 - val_loss: 0.5821 - val_accuracy: 0.8986
#
# Epoch 00202: val_accuracy did not improve from 0.93919
# Epoch 203/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0272 - accuracy: 0.9911 - val_loss: 0.4812 - val_accuracy: 0.9054
#
# Epoch 00203: val_accuracy did not improve from 0.93919
# Epoch 204/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0255 - accuracy: 0.9947 - val_loss: 0.8489 - val_accuracy: 0.8784
#
# Epoch 00204: val_accuracy did not improve from 0.93919
# Epoch 205/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0164 - accuracy: 0.9932 - val_loss: 0.7319 - val_accuracy: 0.9054
#
# Epoch 00205: val_accuracy did not improve from 0.93919
# Epoch 206/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.5514 - val_accuracy: 0.8986
#
# Epoch 00206: val_accuracy did not improve from 0.93919
# Epoch 207/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0303 - accuracy: 0.9874 - val_loss: 0.7577 - val_accuracy: 0.8851
#
# Epoch 00207: val_accuracy did not improve from 0.93919
# Epoch 208/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0279 - accuracy: 0.9889 - val_loss: 0.5313 - val_accuracy: 0.9122
#
# Epoch 00208: val_accuracy did not improve from 0.93919
# Epoch 209/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0234 - accuracy: 0.9953 - val_loss: 0.6891 - val_accuracy: 0.8784
#
# Epoch 00209: val_accuracy did not improve from 0.93919
# Epoch 210/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.5961 - val_accuracy: 0.8919
#
# Epoch 00210: val_accuracy did not improve from 0.93919
# Epoch 211/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0443 - accuracy: 0.9868 - val_loss: 0.6696 - val_accuracy: 0.8784
#
# Epoch 00211: val_accuracy did not improve from 0.93919
# Epoch 212/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.6020 - val_accuracy: 0.9054
#
# Epoch 00212: val_accuracy did not improve from 0.93919
# Epoch 213/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0282 - accuracy: 0.9905 - val_loss: 0.7700 - val_accuracy: 0.8649
#
# Epoch 00213: val_accuracy did not improve from 0.93919
# Epoch 214/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0239 - accuracy: 0.9911 - val_loss: 0.6344 - val_accuracy: 0.8784
#
# Epoch 00214: val_accuracy did not improve from 0.93919
# Epoch 215/500
# 238/238 [==============================] - 36s 153ms/step - loss: 0.0151 - accuracy: 0.9932 - val_loss: 0.3867 - val_accuracy: 0.9257
#
# Epoch 00215: val_accuracy did not improve from 0.93919
# Epoch 216/500
# 238/238 [==============================] - 37s 153ms/step - loss: 0.0392 - accuracy: 0.9884 - val_loss: 0.7621 - val_accuracy: 0.8851
#
# Epoch 00216: val_accuracy did not improve from 0.93919
# Epoch 217/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0448 - accuracy: 0.9863 - val_loss: 0.5807 - val_accuracy: 0.8919
#
# Epoch 00217: val_accuracy did not improve from 0.93919
# Epoch 218/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0322 - accuracy: 0.9916 - val_loss: 0.5896 - val_accuracy: 0.9122
#
# Epoch 00218: val_accuracy did not improve from 0.93919
# Epoch 219/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0332 - accuracy: 0.9905 - val_loss: 0.4218 - val_accuracy: 0.9122
#
# Epoch 00219: val_accuracy did not improve from 0.93919
# Epoch 220/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0225 - accuracy: 0.9926 - val_loss: 0.6763 - val_accuracy: 0.8649
#
# Epoch 00220: val_accuracy did not improve from 0.93919
# Epoch 221/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 0.4672 - val_accuracy: 0.8919
#
# Epoch 00221: val_accuracy did not improve from 0.93919
# Epoch 222/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.6806 - val_accuracy: 0.8784
#
# Epoch 00222: val_accuracy did not improve from 0.93919
# Epoch 223/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0544 - accuracy: 0.9847 - val_loss: 0.6819 - val_accuracy: 0.8919
#
# Epoch 00223: val_accuracy did not improve from 0.93919
# Epoch 224/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0286 - accuracy: 0.9884 - val_loss: 0.5737 - val_accuracy: 0.9189
#
# Epoch 00224: val_accuracy did not improve from 0.93919
# Epoch 225/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0282 - accuracy: 0.9932 - val_loss: 0.5793 - val_accuracy: 0.9189
#
# Epoch 00225: val_accuracy did not improve from 0.93919
# Epoch 226/500
# 238/238 [==============================] - 37s 154ms/step - loss: 0.0568 - accuracy: 0.9853 - val_loss: 0.5576 - val_accuracy: 0.8784
#
# Epoch 00226: val_accuracy did not improve from 0.93919
# Epoch 227/500
# 238/238 [==============================] - 37s 155ms/step - loss: 0.0199 - accuracy: 0.9947 - val_loss: 0.6343 - val_accuracy: 0.9054
#
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.95270
# Epoch 423/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0335 - accuracy: 0.9905 - val_loss: 0.6116 - val_accuracy: 0.8986
#
# Epoch 00423: val_accuracy did not improve from 0.95270
# Epoch 424/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0286 - accuracy: 0.9911 - val_loss: 0.5698 - val_accuracy: 0.8986
#
# Epoch 00424: val_accuracy did not improve from 0.95270
# Epoch 425/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0280 - accuracy: 0.9916 - val_loss: 0.6650 - val_accuracy: 0.8851
#
# Epoch 00425: val_accuracy did not improve from 0.95270
# Epoch 426/500
# 238/238 [==============================] - 37s 156ms/step - loss: 0.0187 - accuracy: 0.9958 - val_loss: 0.8541 - val_accuracy: 0.8784
#
# Epoch 00426: val_accuracy did not improve from 0.95270
# Epoch 427/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.6816 - val_accuracy: 0.9054
#
# Epoch 00427: val_accuracy did not improve from 0.95270
# Epoch 428/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.6136 - val_accuracy: 0.9122
#
# Epoch 00428: val_accuracy did not improve from 0.95270
# Epoch 429/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0390 - accuracy: 0.9900 - val_loss: 0.8215 - val_accuracy: 0.8986
#
# Epoch 00429: val_accuracy did not improve from 0.95270
# Epoch 430/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0219 - accuracy: 0.9942 - val_loss: 0.5710 - val_accuracy: 0.9257
#
# Epoch 00430: val_accuracy did not improve from 0.95270
# Epoch 431/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.8346 - val_accuracy: 0.8986
#
# Epoch 00431: val_accuracy did not improve from 0.95270
# Epoch 432/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0079 - accuracy: 0.9963 - val_loss: 0.8380 - val_accuracy: 0.9189
#
# Epoch 00432: val_accuracy did not improve from 0.95270
# Epoch 433/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.8660 - val_accuracy: 0.9122
#
# Epoch 00433: val_accuracy did not improve from 0.95270
# Epoch 434/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 0.7821 - val_accuracy: 0.9054
#
# Epoch 00434: val_accuracy did not improve from 0.95270
# Epoch 435/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.7048 - val_accuracy: 0.9257
#
# Epoch 00435: val_accuracy did not improve from 0.95270
# Epoch 436/500
# 238/238 [==============================] - 38s 157ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.7322 - val_accuracy: 0.8986
#
# Epoch 00436: val_accuracy did not improve from 0.95270
# Epoch 437/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.8409 - val_accuracy: 0.9054
#
# Epoch 00437: val_accuracy did not improve from 0.95270
# Epoch 438/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0146 - accuracy: 0.9958 - val_loss: 0.9166 - val_accuracy: 0.8784
#
# Epoch 00438: val_accuracy did not improve from 0.95270
# Epoch 439/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.8124 - val_accuracy: 0.9189
#
# Epoch 00439: val_accuracy did not improve from 0.95270
# Epoch 440/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0178 - accuracy: 0.9963 - val_loss: 0.8137 - val_accuracy: 0.9054
#
# Epoch 00440: val_accuracy did not improve from 0.95270
# Epoch 441/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0134 - accuracy: 0.9947 - val_loss: 0.8436 - val_accuracy: 0.8919
#
# Epoch 00441: val_accuracy did not improve from 0.95270
# Epoch 442/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.6019 - val_accuracy: 0.9189
#
# Epoch 00442: val_accuracy did not improve from 0.95270
# Epoch 443/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.6874 - val_accuracy: 0.9257
#
# Epoch 00443: val_accuracy did not improve from 0.95270
# Epoch 444/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0141 - accuracy: 0.9942 - val_loss: 0.7761 - val_accuracy: 0.8784
#
# Epoch 00444: val_accuracy did not improve from 0.95270
# Epoch 445/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0083 - accuracy: 0.9963 - val_loss: 0.7341 - val_accuracy: 0.8986
#
# Epoch 00445: val_accuracy did not improve from 0.95270
# Epoch 446/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0231 - accuracy: 0.9947 - val_loss: 0.9127 - val_accuracy: 0.8986
#
# Epoch 00446: val_accuracy did not improve from 0.95270
# Epoch 447/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0150 - accuracy: 0.9947 - val_loss: 0.5023 - val_accuracy: 0.9459
#
# Epoch 00447: val_accuracy did not improve from 0.95270
# Epoch 448/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0266 - accuracy: 0.9932 - val_loss: 0.7572 - val_accuracy: 0.9257
#
# Epoch 00448: val_accuracy did not improve from 0.95270
# Epoch 449/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.6331 - val_accuracy: 0.9122
#
# Epoch 00449: val_accuracy did not improve from 0.95270
# Epoch 450/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 1.0651 - val_accuracy: 0.8851
#
# Epoch 00450: val_accuracy did not improve from 0.95270
# Epoch 451/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0255 - accuracy: 0.9942 - val_loss: 0.7767 - val_accuracy: 0.8851
#
# Epoch 00451: val_accuracy did not improve from 0.95270
# Epoch 452/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0146 - accuracy: 0.9963 - val_loss: 0.7396 - val_accuracy: 0.8986
#
# Epoch 00452: val_accuracy did not improve from 0.95270
# Epoch 453/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0313 - accuracy: 0.9926 - val_loss: 0.9891 - val_accuracy: 0.9054
#
# Epoch 00453: val_accuracy did not improve from 0.95270
# Epoch 454/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.6674 - val_accuracy: 0.8919
#
# Epoch 00454: val_accuracy did not improve from 0.95270
# Epoch 455/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.8332 - val_accuracy: 0.8919
#
# Epoch 00455: val_accuracy did not improve from 0.95270
# Epoch 456/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.7664 - val_accuracy: 0.9054
#
# Epoch 00456: val_accuracy did not improve from 0.95270
# Epoch 457/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.7740 - val_accuracy: 0.9122
#
# Epoch 00457: val_accuracy did not improve from 0.95270
# Epoch 458/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.7193 - val_accuracy: 0.9122
#
# Epoch 00458: val_accuracy did not improve from 0.95270
# Epoch 459/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.7620 - val_accuracy: 0.8986
#
# Epoch 00459: val_accuracy did not improve from 0.95270
# Epoch 460/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.8639 - val_accuracy: 0.9189
#
# Epoch 00460: val_accuracy did not improve from 0.95270
# Epoch 461/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.9313 - val_accuracy: 0.9054
#
# Epoch 00461: val_accuracy did not improve from 0.95270
# Epoch 462/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 1.0398 - val_accuracy: 0.8851
#
# Epoch 00462: val_accuracy did not improve from 0.95270
# Epoch 463/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0152 - accuracy: 0.9942 - val_loss: 0.8528 - val_accuracy: 0.9054
#
# Epoch 00463: val_accuracy did not improve from 0.95270
# Epoch 464/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0122 - accuracy: 0.9947 - val_loss: 0.9989 - val_accuracy: 0.8919
#
# Epoch 00464: val_accuracy did not improve from 0.95270
# Epoch 465/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0138 - accuracy: 0.9968 - val_loss: 0.8953 - val_accuracy: 0.8851
#
# Epoch 00465: val_accuracy did not improve from 0.95270
# Epoch 466/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0289 - accuracy: 0.9921 - val_loss: 0.7206 - val_accuracy: 0.8851
#
# Epoch 00466: val_accuracy did not improve from 0.95270
# Epoch 467/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0270 - accuracy: 0.9953 - val_loss: 0.6269 - val_accuracy: 0.8986
#
# Epoch 00467: val_accuracy did not improve from 0.95270
# Epoch 468/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.7321 - val_accuracy: 0.8851
#
# Epoch 00468: val_accuracy did not improve from 0.95270
# Epoch 469/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.8338 - val_accuracy: 0.8784
#
# Epoch 00469: val_accuracy did not improve from 0.95270
# Epoch 470/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0123 - accuracy: 0.9947 - val_loss: 0.5674 - val_accuracy: 0.9257
#
# Epoch 00470: val_accuracy did not improve from 0.95270
# Epoch 471/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.7200 - val_accuracy: 0.8919
#
# Epoch 00471: val_accuracy did not improve from 0.95270
# Epoch 472/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0281 - accuracy: 0.9937 - val_loss: 0.5513 - val_accuracy: 0.9122
#
# Epoch 00472: val_accuracy did not improve from 0.95270
# Epoch 473/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0198 - accuracy: 0.9953 - val_loss: 0.7972 - val_accuracy: 0.8649
#
# Epoch 00473: val_accuracy did not improve from 0.95270
# Epoch 474/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.6576 - val_accuracy: 0.9054
#
# Epoch 00474: val_accuracy did not improve from 0.95270
# Epoch 475/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.7221 - val_accuracy: 0.9054
#
# Epoch 00475: val_accuracy did not improve from 0.95270
# Epoch 476/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0150 - accuracy: 0.9963 - val_loss: 1.2521 - val_accuracy: 0.8108
#
# Epoch 00476: val_accuracy did not improve from 0.95270
# Epoch 477/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.6565 - val_accuracy: 0.9257
#
# Epoch 00477: val_accuracy did not improve from 0.95270
# Epoch 478/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0146 - accuracy: 0.9953 - val_loss: 0.7314 - val_accuracy: 0.8784
#
# Epoch 00478: val_accuracy did not improve from 0.95270
# Epoch 479/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0231 - accuracy: 0.9958 - val_loss: 0.7661 - val_accuracy: 0.8851
#
# Epoch 00479: val_accuracy did not improve from 0.95270
# Epoch 480/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.8210 - val_accuracy: 0.9054
#
# Epoch 00480: val_accuracy did not improve from 0.95270
# Epoch 481/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0220 - accuracy: 0.9942 - val_loss: 0.6138 - val_accuracy: 0.9257
#
# Epoch 00481: val_accuracy did not improve from 0.95270
# Epoch 482/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0166 - accuracy: 0.9921 - val_loss: 0.8845 - val_accuracy: 0.8919
#
# Epoch 00482: val_accuracy did not improve from 0.95270
# Epoch 483/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0222 - accuracy: 0.9947 - val_loss: 0.8626 - val_accuracy: 0.8851
#
# Epoch 00483: val_accuracy did not improve from 0.95270
# Epoch 484/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.8563 - val_accuracy: 0.8784
#
# Epoch 00484: val_accuracy did not improve from 0.95270
# Epoch 485/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.9478 - val_accuracy: 0.8581
#
# Epoch 00485: val_accuracy did not improve from 0.95270
# Epoch 486/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.7487 - val_accuracy: 0.9054
#
# Epoch 00486: val_accuracy did not improve from 0.95270
# Epoch 487/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.6877 - val_accuracy: 0.8986
#
# Epoch 00487: val_accuracy did not improve from 0.95270
# Epoch 488/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0102 - accuracy: 0.9963 - val_loss: 0.6464 - val_accuracy: 0.8986
#
# Epoch 00488: val_accuracy did not improve from 0.95270
# Epoch 489/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.6891 - val_accuracy: 0.8851
#
# Epoch 00489: val_accuracy did not improve from 0.95270
# Epoch 490/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0108 - accuracy: 0.9958 - val_loss: 0.6064 - val_accuracy: 0.8919
#
# Epoch 00490: val_accuracy did not improve from 0.95270
# Epoch 491/500
# 238/238 [==============================] - 38s 161ms/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 1.0794 - val_accuracy: 0.8581
#
# Epoch 00491: val_accuracy did not improve from 0.95270
# Epoch 492/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0320 - accuracy: 0.9937 - val_loss: 0.4602 - val_accuracy: 0.9257
#
# Epoch 00492: val_accuracy did not improve from 0.95270
# Epoch 493/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0113 - accuracy: 0.9979 - val_loss: 0.3922 - val_accuracy: 0.9122
#
# Epoch 00493: val_accuracy did not improve from 0.95270
# Epoch 494/500
# 238/238 [==============================] - 37s 157ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.7210 - val_accuracy: 0.8851
#
# Epoch 00494: val_accuracy did not improve from 0.95270
# Epoch 495/500
# 238/238 [==============================] - 38s 158ms/step - loss: 0.0127 - accuracy: 0.9968 - val_loss: 0.7216 - val_accuracy: 0.8851
#
# Epoch 00495: val_accuracy did not improve from 0.95270
# Epoch 496/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.6876 - val_accuracy: 0.9122
#
# Epoch 00496: val_accuracy did not improve from 0.95270
# Epoch 497/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.5328 - val_accuracy: 0.9122
#
# Epoch 00497: val_accuracy did not improve from 0.95270
# Epoch 498/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0138 - accuracy: 0.9942 - val_loss: 0.6380 - val_accuracy: 0.8851
#
# Epoch 00498: val_accuracy did not improve from 0.95270
# Epoch 499/500
# 238/238 [==============================] - 38s 160ms/step - loss: 0.0128 - accuracy: 0.9942 - val_loss: 0.8417 - val_accuracy: 0.8919
#
# Epoch 00499: val_accuracy did not improve from 0.95270
# Epoch 500/500
# 238/238 [==============================] - 38s 159ms/step - loss: 0.0281 - accuracy: 0.9926 - val_loss: 0.8018 - val_accuracy: 0.8784
#
# Epoch 00500: val_accuracy did not improve from 0.95270

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    # 'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # meanideal96@gamil.com
    # 'iDeal02',
    # dodo402298@gmail.com
    'mean01',
    # d9249.acc002@gmail.com
    # 'mean02',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': False, 'detail': 'Over max submission count of Daily. 일일 제출 가능한 최대 횟수가 초과 되었습니다.'}
