# %%
# !nvidia-smi
# Out:
# Tue Sep 28 19:09:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
nunbering = '2'
model_save = 'EfficientNetB' + nunbering + '_1'
Target_model = 'EfficientNetB' + nunbering + '_model'
Target_predict = 'EfficientNetB' + nunbering + '_predict'
Target_acc = 'EfficientNetB' + nunbering + '_acc'
Target_val = 'EfficientNetB' + nunbering + '_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.EfficientNetB2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 59s 136ms/step - loss: 3.4243 - accuracy: 0.1326 - val_loss: 2.7079 - val_accuracy: 0.1014
#
# Epoch 00001: val_accuracy improved from -inf to 0.10135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 30s 128ms/step - loss: 2.2715 - accuracy: 0.2311 - val_loss: 4.2398 - val_accuracy: 0.0946
#
# Epoch 00002: val_accuracy did not improve from 0.10135
# Epoch 3/500
# 238/238 [==============================] - 30s 127ms/step - loss: 1.9203 - accuracy: 0.3289 - val_loss: 3.4787 - val_accuracy: 0.1216
#
# Epoch 00003: val_accuracy improved from 0.10135 to 0.12162, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 4/500
# 238/238 [==============================] - 30s 127ms/step - loss: 1.4559 - accuracy: 0.4989 - val_loss: 1.2819 - val_accuracy: 0.6284
#
# Epoch 00004: val_accuracy improved from 0.12162 to 0.62838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 5/500
# 238/238 [==============================] - 30s 127ms/step - loss: 1.1265 - accuracy: 0.6168 - val_loss: 2.0411 - val_accuracy: 0.4459
#
# Epoch 00005: val_accuracy did not improve from 0.62838
# Epoch 6/500
# 238/238 [==============================] - 30s 127ms/step - loss: 1.0110 - accuracy: 0.6742 - val_loss: 9.4596 - val_accuracy: 0.0878
#
# Epoch 00006: val_accuracy did not improve from 0.62838
# Epoch 7/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.8564 - accuracy: 0.7368 - val_loss: 0.7793 - val_accuracy: 0.7365
#
# Epoch 00007: val_accuracy improved from 0.62838 to 0.73649, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 8/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.7324 - accuracy: 0.7547 - val_loss: 0.7526 - val_accuracy: 0.6959
#
# Epoch 00008: val_accuracy did not improve from 0.73649
# Epoch 9/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.6957 - accuracy: 0.7753 - val_loss: 0.8617 - val_accuracy: 0.7500
#
# Epoch 00009: val_accuracy improved from 0.73649 to 0.75000, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 10/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.6233 - accuracy: 0.7995 - val_loss: 0.8070 - val_accuracy: 0.7568
#
# Epoch 00010: val_accuracy improved from 0.75000 to 0.75676, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 11/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.5933 - accuracy: 0.8158 - val_loss: 0.5098 - val_accuracy: 0.8176
#
# Epoch 00011: val_accuracy improved from 0.75676 to 0.81757, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 12/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.5418 - accuracy: 0.8163 - val_loss: 0.6439 - val_accuracy: 0.7905
#
# Epoch 00012: val_accuracy did not improve from 0.81757
# Epoch 13/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.4863 - accuracy: 0.8411 - val_loss: 2.0283 - val_accuracy: 0.5405
#
# Epoch 00013: val_accuracy did not improve from 0.81757
# Epoch 14/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.4813 - accuracy: 0.8389 - val_loss: 2.7039 - val_accuracy: 0.4054
#
# Epoch 00014: val_accuracy did not improve from 0.81757
# Epoch 15/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.4672 - accuracy: 0.8537 - val_loss: 0.8644 - val_accuracy: 0.7500
#
# Epoch 00015: val_accuracy did not improve from 0.81757
# Epoch 16/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.3958 - accuracy: 0.8758 - val_loss: 0.6590 - val_accuracy: 0.7770
#
# Epoch 00016: val_accuracy did not improve from 0.81757
# Epoch 17/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.4271 - accuracy: 0.8579 - val_loss: 0.6620 - val_accuracy: 0.7500
#
# Epoch 00017: val_accuracy did not improve from 0.81757
# Epoch 18/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.4005 - accuracy: 0.8763 - val_loss: 1.4320 - val_accuracy: 0.6689
#
# Epoch 00018: val_accuracy did not improve from 0.81757
# Epoch 19/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.3616 - accuracy: 0.8847 - val_loss: 0.6367 - val_accuracy: 0.8108
#
# Epoch 00019: val_accuracy did not improve from 0.81757
# Epoch 20/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.3628 - accuracy: 0.8826 - val_loss: 0.6652 - val_accuracy: 0.8108
#
# Epoch 00020: val_accuracy did not improve from 0.81757
# Epoch 21/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.3696 - accuracy: 0.8826 - val_loss: 0.5242 - val_accuracy: 0.8716
#
# Epoch 00021: val_accuracy improved from 0.81757 to 0.87162, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 22/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.3546 - accuracy: 0.8953 - val_loss: 0.6836 - val_accuracy: 0.8108
#
# Epoch 00022: val_accuracy did not improve from 0.87162
# Epoch 23/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2930 - accuracy: 0.9079 - val_loss: 1.7386 - val_accuracy: 0.5473
#
# Epoch 00023: val_accuracy did not improve from 0.87162
# Epoch 24/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2859 - accuracy: 0.9095 - val_loss: 0.5782 - val_accuracy: 0.8311
#
# Epoch 00024: val_accuracy did not improve from 0.87162
# Epoch 25/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.2882 - accuracy: 0.9111 - val_loss: 0.4894 - val_accuracy: 0.8446
#
# Epoch 00025: val_accuracy did not improve from 0.87162
# Epoch 26/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.3132 - accuracy: 0.9005 - val_loss: 0.4003 - val_accuracy: 0.8784
#
# Epoch 00026: val_accuracy improved from 0.87162 to 0.87838, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 27/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.3271 - accuracy: 0.8979 - val_loss: 0.6638 - val_accuracy: 0.8176
#
# Epoch 00027: val_accuracy did not improve from 0.87838
# Epoch 28/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2772 - accuracy: 0.9126 - val_loss: 0.4412 - val_accuracy: 0.8581
#
# Epoch 00028: val_accuracy did not improve from 0.87838
# Epoch 29/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2930 - accuracy: 0.9105 - val_loss: 0.4809 - val_accuracy: 0.8716
#
# Epoch 00029: val_accuracy did not improve from 0.87838
# Epoch 30/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2536 - accuracy: 0.9163 - val_loss: 0.6879 - val_accuracy: 0.8108
#
# Epoch 00030: val_accuracy did not improve from 0.87838
# Epoch 31/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2467 - accuracy: 0.9247 - val_loss: 4.1436 - val_accuracy: 0.1959
#
# Epoch 00031: val_accuracy did not improve from 0.87838
# Epoch 32/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2394 - accuracy: 0.9342 - val_loss: 0.4861 - val_accuracy: 0.8851
#
# Epoch 00032: val_accuracy improved from 0.87838 to 0.88514, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 33/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2233 - accuracy: 0.9284 - val_loss: 0.3140 - val_accuracy: 0.8986
#
# Epoch 00033: val_accuracy improved from 0.88514 to 0.89865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 34/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.2330 - accuracy: 0.9211 - val_loss: 1.0919 - val_accuracy: 0.7770
#
# Epoch 00034: val_accuracy did not improve from 0.89865
# Epoch 35/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.2703 - accuracy: 0.9100 - val_loss: 0.4577 - val_accuracy: 0.8784
#
# Epoch 00035: val_accuracy did not improve from 0.89865
# Epoch 36/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.2287 - accuracy: 0.9242 - val_loss: 0.6301 - val_accuracy: 0.8446
#
# Epoch 00036: val_accuracy did not improve from 0.89865
# Epoch 37/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1991 - accuracy: 0.9321 - val_loss: 1.4841 - val_accuracy: 0.6419
#
# Epoch 00037: val_accuracy did not improve from 0.89865
# Epoch 38/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.2203 - accuracy: 0.9274 - val_loss: 0.4115 - val_accuracy: 0.8649
#
# Epoch 00038: val_accuracy did not improve from 0.89865
# Epoch 39/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1929 - accuracy: 0.9347 - val_loss: 0.5856 - val_accuracy: 0.8446
#
# Epoch 00039: val_accuracy did not improve from 0.89865
# Epoch 40/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1811 - accuracy: 0.9332 - val_loss: 3.8629 - val_accuracy: 0.3378
#
# Epoch 00040: val_accuracy did not improve from 0.89865
# Epoch 41/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1866 - accuracy: 0.9384 - val_loss: 2.5522 - val_accuracy: 0.5203
#
# Epoch 00041: val_accuracy did not improve from 0.89865
# Epoch 42/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.1678 - accuracy: 0.9521 - val_loss: 0.4662 - val_accuracy: 0.8851
#
# Epoch 00042: val_accuracy did not improve from 0.89865
# Epoch 43/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1927 - accuracy: 0.9421 - val_loss: 0.5460 - val_accuracy: 0.8311
#
# Epoch 00043: val_accuracy did not improve from 0.89865
# Epoch 44/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1516 - accuracy: 0.9495 - val_loss: 1.1326 - val_accuracy: 0.6824
#
# Epoch 00044: val_accuracy did not improve from 0.89865
# Epoch 45/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1967 - accuracy: 0.9400 - val_loss: 0.3522 - val_accuracy: 0.8919
#
# Epoch 00045: val_accuracy did not improve from 0.89865
# Epoch 46/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1704 - accuracy: 0.9416 - val_loss: 1.6121 - val_accuracy: 0.7027
#
# Epoch 00046: val_accuracy did not improve from 0.89865
# Epoch 47/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1250 - accuracy: 0.9574 - val_loss: 0.4247 - val_accuracy: 0.8986
#
# Epoch 00047: val_accuracy did not improve from 0.89865
# Epoch 48/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1545 - accuracy: 0.9574 - val_loss: 0.6602 - val_accuracy: 0.8716
#
# Epoch 00048: val_accuracy did not improve from 0.89865
# Epoch 49/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1083 - accuracy: 0.9647 - val_loss: 2.1580 - val_accuracy: 0.6081
#
# Epoch 00049: val_accuracy did not improve from 0.89865
# Epoch 50/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1376 - accuracy: 0.9537 - val_loss: 0.4923 - val_accuracy: 0.8851
#
# Epoch 00050: val_accuracy did not improve from 0.89865
# Epoch 51/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1517 - accuracy: 0.9458 - val_loss: 2.8222 - val_accuracy: 0.5676
#
# Epoch 00051: val_accuracy did not improve from 0.89865
# Epoch 52/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1727 - accuracy: 0.9484 - val_loss: 4.9481 - val_accuracy: 0.2500
#
# Epoch 00052: val_accuracy did not improve from 0.89865
# Epoch 53/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1574 - accuracy: 0.9505 - val_loss: 0.4834 - val_accuracy: 0.8851
#
# Epoch 00053: val_accuracy did not improve from 0.89865
# Epoch 54/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1244 - accuracy: 0.9621 - val_loss: 0.6679 - val_accuracy: 0.8446
#
# Epoch 00054: val_accuracy did not improve from 0.89865
# Epoch 55/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1364 - accuracy: 0.9563 - val_loss: 0.4668 - val_accuracy: 0.8581
#
# Epoch 00055: val_accuracy did not improve from 0.89865
# Epoch 56/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0998 - accuracy: 0.9716 - val_loss: 0.5736 - val_accuracy: 0.8581
#
# Epoch 00056: val_accuracy did not improve from 0.89865
# Epoch 57/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1093 - accuracy: 0.9626 - val_loss: 0.5447 - val_accuracy: 0.8784
#
# Epoch 00057: val_accuracy did not improve from 0.89865
# Epoch 58/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1313 - accuracy: 0.9568 - val_loss: 0.6448 - val_accuracy: 0.8649
#
# Epoch 00058: val_accuracy did not improve from 0.89865
# Epoch 59/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1070 - accuracy: 0.9716 - val_loss: 1.5891 - val_accuracy: 0.7095
#
# Epoch 00059: val_accuracy did not improve from 0.89865
# Epoch 60/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1101 - accuracy: 0.9679 - val_loss: 0.5039 - val_accuracy: 0.8919
#
# Epoch 00060: val_accuracy did not improve from 0.89865
# Epoch 61/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1319 - accuracy: 0.9553 - val_loss: 3.5679 - val_accuracy: 0.3581
#
# Epoch 00061: val_accuracy did not improve from 0.89865
# Epoch 62/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1196 - accuracy: 0.9647 - val_loss: 0.4253 - val_accuracy: 0.8716
#
# Epoch 00062: val_accuracy did not improve from 0.89865
# Epoch 63/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1223 - accuracy: 0.9637 - val_loss: 0.3486 - val_accuracy: 0.9054
#
# Epoch 00063: val_accuracy improved from 0.89865 to 0.90541, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 64/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.1057 - accuracy: 0.9689 - val_loss: 0.3278 - val_accuracy: 0.9122
#
# Epoch 00064: val_accuracy improved from 0.90541 to 0.91216, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 65/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1108 - accuracy: 0.9658 - val_loss: 0.6026 - val_accuracy: 0.8784
#
# Epoch 00065: val_accuracy did not improve from 0.91216
# Epoch 66/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0702 - accuracy: 0.9800 - val_loss: 0.4513 - val_accuracy: 0.8649
#
# Epoch 00066: val_accuracy did not improve from 0.91216
# Epoch 67/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0976 - accuracy: 0.9679 - val_loss: 1.0021 - val_accuracy: 0.7568
#
# Epoch 00067: val_accuracy did not improve from 0.91216
# Epoch 68/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0929 - accuracy: 0.9695 - val_loss: 0.4269 - val_accuracy: 0.8784
#
# Epoch 00068: val_accuracy did not improve from 0.91216
# Epoch 69/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0924 - accuracy: 0.9695 - val_loss: 0.5162 - val_accuracy: 0.9054
#
# Epoch 00069: val_accuracy did not improve from 0.91216
# Epoch 70/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.1158 - accuracy: 0.9684 - val_loss: 0.5874 - val_accuracy: 0.8581
#
# Epoch 00070: val_accuracy did not improve from 0.91216
# Epoch 71/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1191 - accuracy: 0.9637 - val_loss: 0.4792 - val_accuracy: 0.8919
#
# Epoch 00071: val_accuracy did not improve from 0.91216
# Epoch 72/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1114 - accuracy: 0.9684 - val_loss: 0.4263 - val_accuracy: 0.9189
#
# Epoch 00072: val_accuracy improved from 0.91216 to 0.91892, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 73/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0703 - accuracy: 0.9747 - val_loss: 0.4016 - val_accuracy: 0.8919
#
# Epoch 00073: val_accuracy did not improve from 0.91892
# Epoch 74/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0738 - accuracy: 0.9758 - val_loss: 0.4729 - val_accuracy: 0.8919
#
# Epoch 00074: val_accuracy did not improve from 0.91892
# Epoch 75/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0820 - accuracy: 0.9721 - val_loss: 0.4821 - val_accuracy: 0.8919
#
# Epoch 00075: val_accuracy did not improve from 0.91892
# Epoch 76/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0766 - accuracy: 0.9768 - val_loss: 0.2405 - val_accuracy: 0.9257
#
# Epoch 00076: val_accuracy improved from 0.91892 to 0.92568, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 77/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0781 - accuracy: 0.9716 - val_loss: 0.8131 - val_accuracy: 0.8851
#
# Epoch 00077: val_accuracy did not improve from 0.92568
# Epoch 78/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.1063 - accuracy: 0.9689 - val_loss: 0.6063 - val_accuracy: 0.8716
#
# Epoch 00078: val_accuracy did not improve from 0.92568
# Epoch 79/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0646 - accuracy: 0.9800 - val_loss: 0.3796 - val_accuracy: 0.8986
#
# Epoch 00079: val_accuracy did not improve from 0.92568
# Epoch 80/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0741 - accuracy: 0.9726 - val_loss: 0.4983 - val_accuracy: 0.9122
#
# Epoch 00080: val_accuracy did not improve from 0.92568
# Epoch 81/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.1113 - accuracy: 0.9732 - val_loss: 0.6303 - val_accuracy: 0.8581
#
# Epoch 00081: val_accuracy did not improve from 0.92568
# Epoch 82/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0702 - accuracy: 0.9789 - val_loss: 0.5230 - val_accuracy: 0.8986
#
# Epoch 00082: val_accuracy did not improve from 0.92568
# Epoch 83/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0662 - accuracy: 0.9768 - val_loss: 0.5451 - val_accuracy: 0.8919
#
# Epoch 00083: val_accuracy did not improve from 0.92568
# Epoch 84/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0724 - accuracy: 0.9742 - val_loss: 0.5368 - val_accuracy: 0.8851
#
# Epoch 00084: val_accuracy did not improve from 0.92568
# Epoch 85/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0953 - accuracy: 0.9711 - val_loss: 3.2014 - val_accuracy: 0.4257
#
# Epoch 00085: val_accuracy did not improve from 0.92568
# Epoch 86/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0829 - accuracy: 0.9758 - val_loss: 0.4929 - val_accuracy: 0.8851
#
# Epoch 00086: val_accuracy did not improve from 0.92568
# Epoch 87/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0490 - accuracy: 0.9842 - val_loss: 0.5161 - val_accuracy: 0.8784
#
# Epoch 00087: val_accuracy did not improve from 0.92568
# Epoch 88/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0914 - accuracy: 0.9732 - val_loss: 1.1040 - val_accuracy: 0.7635
#
# Epoch 00088: val_accuracy did not improve from 0.92568
# Epoch 89/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0602 - accuracy: 0.9837 - val_loss: 0.6503 - val_accuracy: 0.8784
#
# Epoch 00089: val_accuracy did not improve from 0.92568
# Epoch 90/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0865 - accuracy: 0.9721 - val_loss: 0.4001 - val_accuracy: 0.9122
#
# Epoch 00090: val_accuracy did not improve from 0.92568
# Epoch 91/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0486 - accuracy: 0.9842 - val_loss: 0.4409 - val_accuracy: 0.8919
#
# Epoch 00091: val_accuracy did not improve from 0.92568
# Epoch 92/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0575 - accuracy: 0.9842 - val_loss: 0.7765 - val_accuracy: 0.8649
#
# Epoch 00092: val_accuracy did not improve from 0.92568
# Epoch 93/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0801 - accuracy: 0.9774 - val_loss: 0.4580 - val_accuracy: 0.8986
#
# Epoch 00093: val_accuracy did not improve from 0.92568
# Epoch 94/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0469 - accuracy: 0.9847 - val_loss: 0.4429 - val_accuracy: 0.8919
#
# Epoch 00094: val_accuracy did not improve from 0.92568
# Epoch 95/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0731 - accuracy: 0.9732 - val_loss: 0.7181 - val_accuracy: 0.8581
#
# Epoch 00095: val_accuracy did not improve from 0.92568
# Epoch 96/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0658 - accuracy: 0.9800 - val_loss: 0.6475 - val_accuracy: 0.8784
#
# Epoch 00096: val_accuracy did not improve from 0.92568
# Epoch 97/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.3463 - val_accuracy: 0.9324
#
# Epoch 00097: val_accuracy improved from 0.92568 to 0.93243, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 98/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0800 - accuracy: 0.9747 - val_loss: 2.0849 - val_accuracy: 0.5811
#
# Epoch 00098: val_accuracy did not improve from 0.93243
# Epoch 99/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0671 - accuracy: 0.9795 - val_loss: 2.4693 - val_accuracy: 0.4865
#
# Epoch 00099: val_accuracy did not improve from 0.93243
# Epoch 100/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0415 - accuracy: 0.9837 - val_loss: 0.5303 - val_accuracy: 0.8851
#
# Epoch 00100: val_accuracy did not improve from 0.93243
# Epoch 101/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0805 - accuracy: 0.9721 - val_loss: 0.7220 - val_accuracy: 0.8581
#
# Epoch 00101: val_accuracy did not improve from 0.93243
# Epoch 102/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0819 - accuracy: 0.9726 - val_loss: 0.5404 - val_accuracy: 0.9054
#
# Epoch 00102: val_accuracy did not improve from 0.93243
# Epoch 103/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 0.3982 - val_accuracy: 0.9459
#
# Epoch 00103: val_accuracy improved from 0.93243 to 0.94595, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB2_1.h5
# Epoch 104/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0559 - accuracy: 0.9847 - val_loss: 1.2745 - val_accuracy: 0.7905
#
# Epoch 00104: val_accuracy did not improve from 0.94595
# Epoch 105/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.5501 - val_accuracy: 0.8986
#
# Epoch 00105: val_accuracy did not improve from 0.94595
# Epoch 106/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0886 - accuracy: 0.9768 - val_loss: 0.6464 - val_accuracy: 0.8716
#
# Epoch 00106: val_accuracy did not improve from 0.94595
# Epoch 107/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0650 - accuracy: 0.9763 - val_loss: 0.3978 - val_accuracy: 0.9189
#
# Epoch 00107: val_accuracy did not improve from 0.94595
# Epoch 108/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0577 - accuracy: 0.9800 - val_loss: 0.5701 - val_accuracy: 0.8919
#
# Epoch 00108: val_accuracy did not improve from 0.94595
# Epoch 109/500
# 238/238 [==============================] - 30s 126ms/step - loss: 0.0596 - accuracy: 0.9800 - val_loss: 0.7938 - val_accuracy: 0.8649
#
# Epoch 00109: val_accuracy did not improve from 0.94595
# Epoch 110/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0875 - accuracy: 0.9768 - val_loss: 0.4265 - val_accuracy: 0.9122
#
# Epoch 00110: val_accuracy did not improve from 0.94595
# Epoch 111/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0493 - accuracy: 0.9842 - val_loss: 0.5171 - val_accuracy: 0.8919
#
# Epoch 00111: val_accuracy did not improve from 0.94595
# Epoch 112/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0234 - accuracy: 0.9942 - val_loss: 0.6511 - val_accuracy: 0.8851
#
# Epoch 00112: val_accuracy did not improve from 0.94595
# Epoch 113/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0466 - accuracy: 0.9832 - val_loss: 0.4085 - val_accuracy: 0.9054
#
# Epoch 00113: val_accuracy did not improve from 0.94595
# Epoch 114/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0365 - accuracy: 0.9853 - val_loss: 4.1246 - val_accuracy: 0.4527
#
# Epoch 00114: val_accuracy did not improve from 0.94595
# Epoch 115/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0595 - accuracy: 0.9821 - val_loss: 0.7284 - val_accuracy: 0.8851
#
# Epoch 00115: val_accuracy did not improve from 0.94595
# Epoch 116/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0317 - accuracy: 0.9900 - val_loss: 3.9098 - val_accuracy: 0.5135
#
# Epoch 00116: val_accuracy did not improve from 0.94595
# Epoch 117/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0567 - accuracy: 0.9832 - val_loss: 0.6410 - val_accuracy: 0.8919
#
# Epoch 00117: val_accuracy did not improve from 0.94595
# Epoch 118/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0521 - accuracy: 0.9821 - val_loss: 0.4957 - val_accuracy: 0.9257
#
# Epoch 00118: val_accuracy did not improve from 0.94595
# Epoch 119/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0603 - accuracy: 0.9795 - val_loss: 0.7310 - val_accuracy: 0.8108
#
# Epoch 00119: val_accuracy did not improve from 0.94595
# Epoch 120/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0537 - accuracy: 0.9832 - val_loss: 0.4603 - val_accuracy: 0.9054
#
# Epoch 00120: val_accuracy did not improve from 0.94595
# Epoch 121/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0456 - accuracy: 0.9832 - val_loss: 0.5022 - val_accuracy: 0.8851
#
# Epoch 00121: val_accuracy did not improve from 0.94595
# Epoch 122/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0266 - accuracy: 0.9895 - val_loss: 0.5525 - val_accuracy: 0.8919
#
# Epoch 00122: val_accuracy did not improve from 0.94595
# Epoch 123/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0492 - accuracy: 0.9847 - val_loss: 0.6473 - val_accuracy: 0.8986
#
# Epoch 00123: val_accuracy did not improve from 0.94595
# Epoch 124/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 5.7111 - val_accuracy: 0.2973
#
# Epoch 00124: val_accuracy did not improve from 0.94595
# Epoch 125/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0481 - accuracy: 0.9811 - val_loss: 0.6121 - val_accuracy: 0.8716
#
# Epoch 00125: val_accuracy did not improve from 0.94595
# Epoch 126/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0441 - accuracy: 0.9842 - val_loss: 0.9225 - val_accuracy: 0.8514
#
# Epoch 00126: val_accuracy did not improve from 0.94595
# Epoch 127/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0475 - accuracy: 0.9868 - val_loss: 0.4259 - val_accuracy: 0.9122
#
# Epoch 00127: val_accuracy did not improve from 0.94595
# Epoch 128/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0304 - accuracy: 0.9916 - val_loss: 0.6790 - val_accuracy: 0.8514
#
# Epoch 00128: val_accuracy did not improve from 0.94595
# Epoch 129/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0421 - accuracy: 0.9853 - val_loss: 0.6401 - val_accuracy: 0.8919
#
# Epoch 00129: val_accuracy did not improve from 0.94595
# Epoch 130/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0408 - accuracy: 0.9874 - val_loss: 2.9713 - val_accuracy: 0.5878
#
# Epoch 00130: val_accuracy did not improve from 0.94595
# Epoch 131/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0585 - accuracy: 0.9842 - val_loss: 0.5397 - val_accuracy: 0.9054
#
# Epoch 00131: val_accuracy did not improve from 0.94595
# Epoch 132/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0293 - accuracy: 0.9921 - val_loss: 0.6022 - val_accuracy: 0.9324
#
# Epoch 00132: val_accuracy did not improve from 0.94595
# Epoch 133/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0690 - accuracy: 0.9805 - val_loss: 0.6799 - val_accuracy: 0.8514
#
# Epoch 00133: val_accuracy did not improve from 0.94595
# Epoch 134/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0444 - accuracy: 0.9863 - val_loss: 0.7348 - val_accuracy: 0.8716
#
# Epoch 00134: val_accuracy did not improve from 0.94595
# Epoch 135/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.4650 - val_accuracy: 0.8986
#
# Epoch 00135: val_accuracy did not improve from 0.94595
# Epoch 136/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0301 - accuracy: 0.9889 - val_loss: 0.9021 - val_accuracy: 0.8514
#
# Epoch 00136: val_accuracy did not improve from 0.94595
# Epoch 137/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0519 - accuracy: 0.9847 - val_loss: 0.7951 - val_accuracy: 0.8649
#
# Epoch 00137: val_accuracy did not improve from 0.94595
# Epoch 138/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0594 - accuracy: 0.9826 - val_loss: 0.4284 - val_accuracy: 0.9324
#
# Epoch 00138: val_accuracy did not improve from 0.94595
# Epoch 139/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0502 - accuracy: 0.9816 - val_loss: 0.6154 - val_accuracy: 0.8986
#
# Epoch 00139: val_accuracy did not improve from 0.94595
# Epoch 140/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0530 - accuracy: 0.9853 - val_loss: 0.7262 - val_accuracy: 0.8581
#
# Epoch 00140: val_accuracy did not improve from 0.94595
# Epoch 141/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0233 - accuracy: 0.9916 - val_loss: 1.0152 - val_accuracy: 0.8311
#
# Epoch 00141: val_accuracy did not improve from 0.94595
# Epoch 142/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0242 - accuracy: 0.9895 - val_loss: 0.8536 - val_accuracy: 0.8716
#
# Epoch 00142: val_accuracy did not improve from 0.94595
# Epoch 143/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0166 - accuracy: 0.9958 - val_loss: 0.6201 - val_accuracy: 0.9054
#
# Epoch 00143: val_accuracy did not improve from 0.94595
# Epoch 144/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0232 - accuracy: 0.9921 - val_loss: 3.1749 - val_accuracy: 0.5473
#
# Epoch 00144: val_accuracy did not improve from 0.94595
# Epoch 145/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0905 - accuracy: 0.9742 - val_loss: 0.7371 - val_accuracy: 0.8581
#
# Epoch 00145: val_accuracy did not improve from 0.94595
# Epoch 146/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0612 - accuracy: 0.9832 - val_loss: 0.5733 - val_accuracy: 0.9189
#
# Epoch 00146: val_accuracy did not improve from 0.94595
# Epoch 147/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0283 - accuracy: 0.9926 - val_loss: 0.7711 - val_accuracy: 0.8716
#
# Epoch 00147: val_accuracy did not improve from 0.94595
# Epoch 148/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.5735 - val_accuracy: 0.8784
#
# Epoch 00148: val_accuracy did not improve from 0.94595
# Epoch 149/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0292 - accuracy: 0.9911 - val_loss: 0.3324 - val_accuracy: 0.9122
#
# Epoch 00149: val_accuracy did not improve from 0.94595
# Epoch 150/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0468 - accuracy: 0.9832 - val_loss: 0.3908 - val_accuracy: 0.8986
#
# Epoch 00150: val_accuracy did not improve from 0.94595
# Epoch 151/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.5190 - val_accuracy: 0.8919
#
# Epoch 00151: val_accuracy did not improve from 0.94595
# Epoch 152/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0421 - accuracy: 0.9874 - val_loss: 0.4769 - val_accuracy: 0.8784
#
# Epoch 00152: val_accuracy did not improve from 0.94595
# Epoch 153/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0231 - accuracy: 0.9932 - val_loss: 0.5201 - val_accuracy: 0.9054
#
# Epoch 00153: val_accuracy did not improve from 0.94595
# Epoch 154/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0619 - accuracy: 0.9816 - val_loss: 0.7615 - val_accuracy: 0.8784
#
# Epoch 00154: val_accuracy did not improve from 0.94595
# Epoch 155/500
# 238/238 [==============================] - 30s 127ms/step - loss: 0.0535 - accuracy: 0.9811 - val_loss: 0.4366 - val_accuracy: 0.9189
#
# Epoch 00155: val_accuracy did not improve from 0.94595
# Epoch 156/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0240 - accuracy: 0.9895 - val_loss: 0.5588 - val_accuracy: 0.8649
#
# Epoch 00156: val_accuracy did not improve from 0.94595
# Epoch 157/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.5050 - val_accuracy: 0.8784
#
# Epoch 00157: val_accuracy did not improve from 0.94595
# Epoch 158/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0304 - accuracy: 0.9921 - val_loss: 1.0423 - val_accuracy: 0.8311
#
# Epoch 00158: val_accuracy did not improve from 0.94595
# Epoch 159/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0567 - accuracy: 0.9816 - val_loss: 0.6450 - val_accuracy: 0.8986
#
# Epoch 00159: val_accuracy did not improve from 0.94595
# Epoch 160/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0439 - accuracy: 0.9863 - val_loss: 0.6893 - val_accuracy: 0.8851
#
# Epoch 00160: val_accuracy did not improve from 0.94595
# Epoch 161/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0418 - accuracy: 0.9874 - val_loss: 0.5966 - val_accuracy: 0.9122
#
# Epoch 00161: val_accuracy did not improve from 0.94595
# Epoch 162/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0307 - accuracy: 0.9895 - val_loss: 2.9621 - val_accuracy: 0.4459
#
# Epoch 00162: val_accuracy did not improve from 0.94595
# Epoch 163/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0373 - accuracy: 0.9879 - val_loss: 0.7052 - val_accuracy: 0.8851
#
# Epoch 00163: val_accuracy did not improve from 0.94595
# Epoch 164/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0500 - accuracy: 0.9826 - val_loss: 0.6040 - val_accuracy: 0.8986
#
# Epoch 00164: val_accuracy did not improve from 0.94595
# Epoch 165/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0338 - accuracy: 0.9905 - val_loss: 0.4994 - val_accuracy: 0.9189
#
# Epoch 00165: val_accuracy did not improve from 0.94595
# Epoch 166/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0327 - accuracy: 0.9879 - val_loss: 0.8061 - val_accuracy: 0.8784
#
# Epoch 00166: val_accuracy did not improve from 0.94595
# Epoch 167/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0336 - accuracy: 0.9884 - val_loss: 0.4109 - val_accuracy: 0.9392
#
# Epoch 00167: val_accuracy did not improve from 0.94595
# Epoch 168/500
# 238/238 [==============================] - 30s 128ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.5098 - val_accuracy: 0.8986
#
# Epoch 00168: val_accuracy did not improve from 0.94595
# Epoch 169/500
# 238/238 [==============================] - 31s 128ms/step - loss: 0.0500 - accuracy: 0.9853 - val_loss: 2.6674 - val_accuracy: 0.6689
#
# Epoch 00169: val_accuracy did not improve from 0.94595
# Epoch 170/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0624 - accuracy: 0.9821 - val_loss: 3.2229 - val_accuracy: 0.4595
#
# Epoch 00170: val_accuracy did not improve from 0.94595
# Epoch 171/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0371 - accuracy: 0.9858 - val_loss: 0.7197 - val_accuracy: 0.8851
#
# Epoch 00171: val_accuracy did not improve from 0.94595
# Epoch 172/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0277 - accuracy: 0.9911 - val_loss: 0.6831 - val_accuracy: 0.8784
#
# Epoch 00172: val_accuracy did not improve from 0.94595
# Epoch 173/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0201 - accuracy: 0.9926 - val_loss: 0.5443 - val_accuracy: 0.8986
#
# Epoch 00173: val_accuracy did not improve from 0.94595
# Epoch 174/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 0.3733 - val_accuracy: 0.9054
#
# Epoch 00174: val_accuracy did not improve from 0.94595
# Epoch 175/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.4220 - val_accuracy: 0.9189
#
# Epoch 00175: val_accuracy did not improve from 0.94595
# Epoch 176/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0433 - accuracy: 0.9858 - val_loss: 0.5997 - val_accuracy: 0.8919
#
# Epoch 00176: val_accuracy did not improve from 0.94595
# Epoch 177/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0336 - accuracy: 0.9879 - val_loss: 0.6135 - val_accuracy: 0.8784
#
# Epoch 00177: val_accuracy did not improve from 0.94595
# Epoch 178/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0497 - accuracy: 0.9837 - val_loss: 0.5108 - val_accuracy: 0.8784
#
# Epoch 00178: val_accuracy did not improve from 0.94595
# Epoch 179/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 0.6797 - val_accuracy: 0.8986
#
# Epoch 00179: val_accuracy did not improve from 0.94595
# Epoch 180/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0555 - accuracy: 0.9805 - val_loss: 0.6474 - val_accuracy: 0.8649
#
# Epoch 00180: val_accuracy did not improve from 0.94595
# Epoch 181/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0387 - accuracy: 0.9884 - val_loss: 0.3962 - val_accuracy: 0.9392
#
# Epoch 00181: val_accuracy did not improve from 0.94595
# Epoch 182/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.7639 - val_accuracy: 0.8851
#
# Epoch 00182: val_accuracy did not improve from 0.94595
# Epoch 183/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0369 - accuracy: 0.9889 - val_loss: 0.4918 - val_accuracy: 0.9122
#
# Epoch 00183: val_accuracy did not improve from 0.94595
# Epoch 184/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.6319 - val_accuracy: 0.9189
#
# Epoch 00184: val_accuracy did not improve from 0.94595
# Epoch 185/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0372 - accuracy: 0.9874 - val_loss: 0.6230 - val_accuracy: 0.8919
#
# Epoch 00185: val_accuracy did not improve from 0.94595
# Epoch 186/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0378 - accuracy: 0.9889 - val_loss: 0.7801 - val_accuracy: 0.8716
#
# Epoch 00186: val_accuracy did not improve from 0.94595
# Epoch 187/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.5216 - val_accuracy: 0.9054
#
# Epoch 00187: val_accuracy did not improve from 0.94595
# Epoch 188/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.3891 - val_accuracy: 0.9392
#
# Epoch 00188: val_accuracy did not improve from 0.94595
# Epoch 189/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.5382 - val_accuracy: 0.9189
#
# Epoch 00189: val_accuracy did not improve from 0.94595
# Epoch 190/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0486 - accuracy: 0.9858 - val_loss: 0.4490 - val_accuracy: 0.9054
#
# Epoch 00190: val_accuracy did not improve from 0.94595
# Epoch 191/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0326 - accuracy: 0.9916 - val_loss: 0.5658 - val_accuracy: 0.9054
#
# Epoch 00191: val_accuracy did not improve from 0.94595
# Epoch 192/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0234 - accuracy: 0.9921 - val_loss: 0.6603 - val_accuracy: 0.8784
#
# Epoch 00192: val_accuracy did not improve from 0.94595
# Epoch 193/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.7433 - val_accuracy: 0.8716
#
# Epoch 00193: val_accuracy did not improve from 0.94595
# Epoch 194/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0211 - accuracy: 0.9911 - val_loss: 0.6996 - val_accuracy: 0.8851
#
# Epoch 00194: val_accuracy did not improve from 0.94595
# Epoch 195/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0452 - accuracy: 0.9816 - val_loss: 0.8608 - val_accuracy: 0.7838
#
# Epoch 00195: val_accuracy did not improve from 0.94595
# Epoch 196/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0451 - accuracy: 0.9858 - val_loss: 0.6720 - val_accuracy: 0.9054
#
# Epoch 00196: val_accuracy did not improve from 0.94595
# Epoch 197/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0349 - accuracy: 0.9900 - val_loss: 0.5222 - val_accuracy: 0.9324
#
# Epoch 00197: val_accuracy did not improve from 0.94595
# Epoch 198/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0335 - accuracy: 0.9874 - val_loss: 2.3007 - val_accuracy: 0.6959
#
# Epoch 00198: val_accuracy did not improve from 0.94595
# Epoch 199/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0249 - accuracy: 0.9932 - val_loss: 0.7844 - val_accuracy: 0.8784
#
# Epoch 00199: val_accuracy did not improve from 0.94595
# Epoch 200/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 0.5362 - val_accuracy: 0.9189
#
# Epoch 00200: val_accuracy did not improve from 0.94595
# Epoch 201/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0174 - accuracy: 0.9953 - val_loss: 0.6636 - val_accuracy: 0.8851
#
# Epoch 00201: val_accuracy did not improve from 0.94595
# Epoch 202/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0464 - accuracy: 0.9832 - val_loss: 1.4845 - val_accuracy: 0.7230
#
# Epoch 00202: val_accuracy did not improve from 0.94595
# Epoch 203/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.5736 - val_accuracy: 0.9189
#
# Epoch 00203: val_accuracy did not improve from 0.94595
# Epoch 204/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.7790 - val_accuracy: 0.8716
#
# Epoch 00204: val_accuracy did not improve from 0.94595
# Epoch 205/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0291 - accuracy: 0.9921 - val_loss: 0.5258 - val_accuracy: 0.8919
#
# Epoch 00205: val_accuracy did not improve from 0.94595
# Epoch 206/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0384 - accuracy: 0.9889 - val_loss: 5.1588 - val_accuracy: 0.4662
#
# Epoch 00206: val_accuracy did not improve from 0.94595
# Epoch 207/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0241 - accuracy: 0.9921 - val_loss: 0.6559 - val_accuracy: 0.9054
#
# Epoch 00207: val_accuracy did not improve from 0.94595
# Epoch 208/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.5391 - val_accuracy: 0.9122
#
# Epoch 00208: val_accuracy did not improve from 0.94595
# Epoch 209/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.4660 - val_accuracy: 0.9324
#
# Epoch 00209: val_accuracy did not improve from 0.94595
# Epoch 210/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0160 - accuracy: 0.9958 - val_loss: 0.6984 - val_accuracy: 0.8851
#
# Epoch 00210: val_accuracy did not improve from 0.94595
# Epoch 211/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.6291 - val_accuracy: 0.8986
#
# Epoch 00211: val_accuracy did not improve from 0.94595
# Epoch 212/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0733 - accuracy: 0.9789 - val_loss: 3.6492 - val_accuracy: 0.5946
#
# Epoch 00212: val_accuracy did not improve from 0.94595
# Epoch 213/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0615 - accuracy: 0.9832 - val_loss: 0.5257 - val_accuracy: 0.8986
#
# Epoch 00213: val_accuracy did not improve from 0.94595
# Epoch 214/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0472 - accuracy: 0.9858 - val_loss: 0.5408 - val_accuracy: 0.9054
#
# Epoch 00214: val_accuracy did not improve from 0.94595
# Epoch 215/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0239 - accuracy: 0.9916 - val_loss: 0.5156 - val_accuracy: 0.9189
#
# Epoch 00215: val_accuracy did not improve from 0.94595
# Epoch 216/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.4972 - val_accuracy: 0.9054
#
# Epoch 00216: val_accuracy did not improve from 0.94595
# Epoch 217/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.6268 - val_accuracy: 0.8581
#
# Epoch 00217: val_accuracy did not improve from 0.94595
# Epoch 218/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0293 - accuracy: 0.9868 - val_loss: 0.5315 - val_accuracy: 0.9122
#
# Epoch 00218: val_accuracy did not improve from 0.94595
# Epoch 219/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0074 - accuracy: 0.9989 - val_loss: 0.6468 - val_accuracy: 0.8919
#
# Epoch 00219: val_accuracy did not improve from 0.94595
# Epoch 220/500
# 238/238 [==============================] - 31s 130ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.7538 - val_accuracy: 0.8649
#
# Epoch 00220: val_accuracy did not improve from 0.94595
# Epoch 221/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0178 - accuracy: 0.9958 - val_loss: 0.6366 - val_accuracy: 0.9257
#
# Epoch 00221: val_accuracy did not improve from 0.94595
# Epoch 222/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0648 - accuracy: 0.9842 - val_loss: 0.4856 - val_accuracy: 0.9122
#
# Epoch 00222: val_accuracy did not improve from 0.94595
# Epoch 223/500
# 238/238 [==============================] - 31s 131ms/step - loss: 0.0223 - accuracy: 0.9916 - val_loss: 0.5229 - val_accuracy: 0.9054
#
# Epoch 00223: val_accuracy did not improve from 0.94595
# Epoch 224/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.6001 - val_accuracy: 0.8986
#
# Epoch 00224: val_accuracy did not improve from 0.94595
# Epoch 225/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.6261 - val_accuracy: 0.9189
#
# Epoch 00225: val_accuracy did not improve from 0.94595
# Epoch 226/500
# 238/238 [==============================] - 31s 129ms/step - loss: 0.0380 - accuracy: 0.9905 - val_loss: 0.5946 - val_accuracy: 0.8851
#
# Epoch 00226: val_accuracy did not improve from 0.94595
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.94595
# Epoch 423/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.7297 - val_accuracy: 0.8851
#
# Epoch 00423: val_accuracy did not improve from 0.94595
# Epoch 424/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.5325 - val_accuracy: 0.9324
#
# Epoch 00424: val_accuracy did not improve from 0.94595
# Epoch 425/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.7304 - val_accuracy: 0.8716
#
# Epoch 00425: val_accuracy did not improve from 0.94595
# Epoch 426/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0195 - accuracy: 0.9932 - val_loss: 0.6027 - val_accuracy: 0.9054
#
# Epoch 00426: val_accuracy did not improve from 0.94595
# Epoch 427/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.7061 - val_accuracy: 0.8851
#
# Epoch 00427: val_accuracy did not improve from 0.94595
# Epoch 428/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.7937 - val_accuracy: 0.8986
#
# Epoch 00428: val_accuracy did not improve from 0.94595
# Epoch 429/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.6896 - val_accuracy: 0.8986
#
# Epoch 00429: val_accuracy did not improve from 0.94595
# Epoch 430/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0039 - accuracy: 0.9984 - val_loss: 0.7365 - val_accuracy: 0.8919
#
# Epoch 00430: val_accuracy did not improve from 0.94595
# Epoch 431/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.7927 - val_accuracy: 0.8851
#
# Epoch 00431: val_accuracy did not improve from 0.94595
# Epoch 432/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.5486 - val_accuracy: 0.9054
#
# Epoch 00432: val_accuracy did not improve from 0.94595
# Epoch 433/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.6539 - val_accuracy: 0.9122
#
# Epoch 00433: val_accuracy did not improve from 0.94595
# Epoch 434/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0426 - accuracy: 0.9884 - val_loss: 0.7264 - val_accuracy: 0.9054
#
# Epoch 00434: val_accuracy did not improve from 0.94595
# Epoch 435/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0157 - accuracy: 0.9942 - val_loss: 0.7667 - val_accuracy: 0.8919
#
# Epoch 00435: val_accuracy did not improve from 0.94595
# Epoch 436/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.7140 - val_accuracy: 0.9054
#
# Epoch 00436: val_accuracy did not improve from 0.94595
# Epoch 437/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.8527 - val_accuracy: 0.8986
#
# Epoch 00437: val_accuracy did not improve from 0.94595
# Epoch 438/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0094 - accuracy: 0.9963 - val_loss: 0.6962 - val_accuracy: 0.9122
#
# Epoch 00438: val_accuracy did not improve from 0.94595
# Epoch 439/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0452 - accuracy: 0.9921 - val_loss: 1.0245 - val_accuracy: 0.8716
#
# Epoch 00439: val_accuracy did not improve from 0.94595
# Epoch 440/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.6806 - val_accuracy: 0.8986
#
# Epoch 00440: val_accuracy did not improve from 0.94595
# Epoch 441/500
# 238/238 [==============================] - 33s 137ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.9490 - val_accuracy: 0.8716
#
# Epoch 00441: val_accuracy did not improve from 0.94595
# Epoch 442/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 0.6883 - val_accuracy: 0.8851
#
# Epoch 00442: val_accuracy did not improve from 0.94595
# Epoch 443/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.7733 - val_accuracy: 0.9054
#
# Epoch 00443: val_accuracy did not improve from 0.94595
# Epoch 444/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.6862 - val_accuracy: 0.9189
#
# Epoch 00444: val_accuracy did not improve from 0.94595
# Epoch 445/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 1.0685 - val_accuracy: 0.8649
#
# Epoch 00445: val_accuracy did not improve from 0.94595
# Epoch 446/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.9318 - val_accuracy: 0.8919
#
# Epoch 00446: val_accuracy did not improve from 0.94595
# Epoch 447/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0218 - accuracy: 0.9953 - val_loss: 0.6450 - val_accuracy: 0.9257
#
# Epoch 00447: val_accuracy did not improve from 0.94595
# Epoch 448/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0111 - accuracy: 0.9937 - val_loss: 0.7009 - val_accuracy: 0.8716
#
# Epoch 00448: val_accuracy did not improve from 0.94595
# Epoch 449/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 0.8374 - val_accuracy: 0.8649
#
# Epoch 00449: val_accuracy did not improve from 0.94595
# Epoch 450/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.7127 - val_accuracy: 0.9054
#
# Epoch 00450: val_accuracy did not improve from 0.94595
# Epoch 451/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0215 - accuracy: 0.9942 - val_loss: 0.5532 - val_accuracy: 0.9122
#
# Epoch 00451: val_accuracy did not improve from 0.94595
# Epoch 452/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0227 - accuracy: 0.9916 - val_loss: 0.5370 - val_accuracy: 0.9054
#
# Epoch 00452: val_accuracy did not improve from 0.94595
# Epoch 453/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.7637 - val_accuracy: 0.9189
#
# Epoch 00453: val_accuracy did not improve from 0.94595
# Epoch 454/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0252 - accuracy: 0.9932 - val_loss: 0.8356 - val_accuracy: 0.9054
#
# Epoch 00454: val_accuracy did not improve from 0.94595
# Epoch 455/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.5857 - val_accuracy: 0.9122
#
# Epoch 00455: val_accuracy did not improve from 0.94595
# Epoch 456/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.6648 - val_accuracy: 0.8851
#
# Epoch 00456: val_accuracy did not improve from 0.94595
# Epoch 457/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0169 - accuracy: 0.9926 - val_loss: 0.8154 - val_accuracy: 0.8919
#
# Epoch 00457: val_accuracy did not improve from 0.94595
# Epoch 458/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0220 - accuracy: 0.9947 - val_loss: 0.5485 - val_accuracy: 0.9257
#
# Epoch 00458: val_accuracy did not improve from 0.94595
# Epoch 459/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.5957 - val_accuracy: 0.9392
#
# Epoch 00459: val_accuracy did not improve from 0.94595
# Epoch 460/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.6411 - val_accuracy: 0.9122
#
# Epoch 00460: val_accuracy did not improve from 0.94595
# Epoch 461/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 0.7022 - val_accuracy: 0.9054
#
# Epoch 00461: val_accuracy did not improve from 0.94595
# Epoch 462/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0123 - accuracy: 0.9942 - val_loss: 0.9078 - val_accuracy: 0.8784
#
# Epoch 00462: val_accuracy did not improve from 0.94595
# Epoch 463/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0130 - accuracy: 0.9942 - val_loss: 0.8533 - val_accuracy: 0.8784
#
# Epoch 00463: val_accuracy did not improve from 0.94595
# Epoch 464/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0176 - accuracy: 0.9968 - val_loss: 0.6086 - val_accuracy: 0.9189
#
# Epoch 00464: val_accuracy did not improve from 0.94595
# Epoch 465/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.7089 - val_accuracy: 0.8986
#
# Epoch 00465: val_accuracy did not improve from 0.94595
# Epoch 466/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0095 - accuracy: 0.9979 - val_loss: 0.5241 - val_accuracy: 0.9054
#
# Epoch 00466: val_accuracy did not improve from 0.94595
# Epoch 467/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.6637 - val_accuracy: 0.8851
#
# Epoch 00467: val_accuracy did not improve from 0.94595
# Epoch 468/500
# 238/238 [==============================] - 32s 133ms/step - loss: 0.0194 - accuracy: 0.9942 - val_loss: 0.6989 - val_accuracy: 0.9189
#
# Epoch 00468: val_accuracy did not improve from 0.94595
# Epoch 469/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.6316 - val_accuracy: 0.9189
#
# Epoch 00469: val_accuracy did not improve from 0.94595
# Epoch 470/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.7700 - val_accuracy: 0.9122
#
# Epoch 00470: val_accuracy did not improve from 0.94595
# Epoch 471/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.7361 - val_accuracy: 0.8919
#
# Epoch 00471: val_accuracy did not improve from 0.94595
# Epoch 472/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 0.8803 - val_accuracy: 0.8919
#
# Epoch 00472: val_accuracy did not improve from 0.94595
# Epoch 473/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0085 - accuracy: 0.9958 - val_loss: 0.5672 - val_accuracy: 0.9324
#
# Epoch 00473: val_accuracy did not improve from 0.94595
# Epoch 474/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0113 - accuracy: 0.9942 - val_loss: 0.8667 - val_accuracy: 0.9054
#
# Epoch 00474: val_accuracy did not improve from 0.94595
# Epoch 475/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0124 - accuracy: 0.9947 - val_loss: 0.8440 - val_accuracy: 0.8919
#
# Epoch 00475: val_accuracy did not improve from 0.94595
# Epoch 476/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0038 - accuracy: 0.9979 - val_loss: 0.5947 - val_accuracy: 0.8986
#
# Epoch 00476: val_accuracy did not improve from 0.94595
# Epoch 477/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.5541 - val_accuracy: 0.9189
#
# Epoch 00477: val_accuracy did not improve from 0.94595
# Epoch 478/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.4954 - val_accuracy: 0.9257
#
# Epoch 00478: val_accuracy did not improve from 0.94595
# Epoch 479/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.9392
#
# Epoch 00479: val_accuracy did not improve from 0.94595
# Epoch 480/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0126 - accuracy: 0.9953 - val_loss: 0.6294 - val_accuracy: 0.8986
#
# Epoch 00480: val_accuracy did not improve from 0.94595
# Epoch 481/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0352 - accuracy: 0.9895 - val_loss: 0.9191 - val_accuracy: 0.8581
#
# Epoch 00481: val_accuracy did not improve from 0.94595
# Epoch 482/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.9056 - val_accuracy: 0.8851
#
# Epoch 00482: val_accuracy did not improve from 0.94595
# Epoch 483/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.8312 - val_accuracy: 0.8851
#
# Epoch 00483: val_accuracy did not improve from 0.94595
# Epoch 484/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.6715 - val_accuracy: 0.9054
#
# Epoch 00484: val_accuracy did not improve from 0.94595
# Epoch 485/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.5992 - val_accuracy: 0.8919
#
# Epoch 00485: val_accuracy did not improve from 0.94595
# Epoch 486/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.7438 - val_accuracy: 0.8919
#
# Epoch 00486: val_accuracy did not improve from 0.94595
# Epoch 487/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.6858 - val_accuracy: 0.8986
#
# Epoch 00487: val_accuracy did not improve from 0.94595
# Epoch 488/500
# 238/238 [==============================] - 32s 133ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.6918 - val_accuracy: 0.9054
#
# Epoch 00488: val_accuracy did not improve from 0.94595
# Epoch 489/500
# 238/238 [==============================] - 32s 133ms/step - loss: 0.0577 - accuracy: 0.9858 - val_loss: 0.7640 - val_accuracy: 0.9054
#
# Epoch 00489: val_accuracy did not improve from 0.94595
# Epoch 490/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.5340 - val_accuracy: 0.9392
#
# Epoch 00490: val_accuracy did not improve from 0.94595
# Epoch 491/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.6530 - val_accuracy: 0.9257
#
# Epoch 00491: val_accuracy did not improve from 0.94595
# Epoch 492/500
# 238/238 [==============================] - 32s 136ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.8880 - val_accuracy: 0.8649
#
# Epoch 00492: val_accuracy did not improve from 0.94595
# Epoch 493/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.5944 - val_accuracy: 0.9054
#
# Epoch 00493: val_accuracy did not improve from 0.94595
# Epoch 494/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.7851 - val_accuracy: 0.8986
#
# Epoch 00494: val_accuracy did not improve from 0.94595
# Epoch 495/500
# 238/238 [==============================] - 32s 133ms/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 0.8017 - val_accuracy: 0.8919
#
# Epoch 00495: val_accuracy did not improve from 0.94595
# Epoch 496/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0187 - accuracy: 0.9926 - val_loss: 0.8585 - val_accuracy: 0.8378
#
# Epoch 00496: val_accuracy did not improve from 0.94595
# Epoch 497/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0169 - accuracy: 0.9932 - val_loss: 2.0070 - val_accuracy: 0.7500
#
# Epoch 00497: val_accuracy did not improve from 0.94595
# Epoch 498/500
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0163 - accuracy: 0.9932 - val_loss: 0.6663 - val_accuracy: 0.8851
#
# Epoch 00498: val_accuracy did not improve from 0.94595
# Epoch 499/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.8465 - val_accuracy: 0.9054
#
# Epoch 00499: val_accuracy did not improve from 0.94595
# Epoch 500/500
# 238/238 [==============================] - 32s 135ms/step - loss: 0.0138 - accuracy: 0.9984 - val_loss: 0.8081 - val_accuracy: 0.9054
#
# Epoch 00500: val_accuracy did not improve from 0.94595

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    # 'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # meanideal96@gamil.com
    # 'iDeal02',
    # dodo402298@gmail.com
    'mean01',
    # d9249.acc002@gmail.com
    # 'mean02',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': False, 'detail': 'Over max submission count of Daily. 일일 제출 가능한 최대 횟수가 초과 되었습니다.'}
