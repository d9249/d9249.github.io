# %%
# !nvidia-smi
# Out:
# Mon Sep 27 17:44:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
model_save = 'ResNet50V2_5'
Target_model = 'ResNet50V2_model'
Target_predict = 'ResNet50V2_predict'
Target_acc = 'ResNet50V2_acc'
Target_val = 'ResNet50V2_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.ResNet50V2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 39s 70ms/step - loss: 2.0166 - accuracy: 0.3111 - val_loss: 6.8386 - val_accuracy: 0.0946
#
# Epoch 00001: val_accuracy improved from -inf to 0.09459, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 15s 64ms/step - loss: 1.3028 - accuracy: 0.5663 - val_loss: 3.3618 - val_accuracy: 0.3378
#
# Epoch 00002: val_accuracy improved from 0.09459 to 0.33784, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 3/500
# 238/238 [==============================] - 15s 64ms/step - loss: 1.0950 - accuracy: 0.6321 - val_loss: 0.9389 - val_accuracy: 0.7027
#
# Epoch 00003: val_accuracy improved from 0.33784 to 0.70270, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 4/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.9385 - accuracy: 0.6968 - val_loss: 12.0432 - val_accuracy: 0.1351
#
# Epoch 00004: val_accuracy did not improve from 0.70270
# Epoch 5/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.8342 - accuracy: 0.7253 - val_loss: 1.1312 - val_accuracy: 0.6689
#
# Epoch 00005: val_accuracy did not improve from 0.70270
# Epoch 6/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.7302 - accuracy: 0.7516 - val_loss: 14.1195 - val_accuracy: 0.1622
#
# Epoch 00006: val_accuracy did not improve from 0.70270
# Epoch 7/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.7522 - accuracy: 0.7505 - val_loss: 0.5397 - val_accuracy: 0.8108
#
# Epoch 00007: val_accuracy improved from 0.70270 to 0.81081, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 8/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.6544 - accuracy: 0.7863 - val_loss: 1.3455 - val_accuracy: 0.6486
#
# Epoch 00008: val_accuracy did not improve from 0.81081
# Epoch 9/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.5743 - accuracy: 0.8137 - val_loss: 14.4595 - val_accuracy: 0.0878
#
# Epoch 00009: val_accuracy did not improve from 0.81081
# Epoch 10/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.5492 - accuracy: 0.8226 - val_loss: 1.2421 - val_accuracy: 0.6284
#
# Epoch 00010: val_accuracy did not improve from 0.81081
# Epoch 11/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.5756 - accuracy: 0.8026 - val_loss: 0.8567 - val_accuracy: 0.7095
#
# Epoch 00011: val_accuracy did not improve from 0.81081
# Epoch 12/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.4543 - accuracy: 0.8368 - val_loss: 1.3149 - val_accuracy: 0.6959
#
# Epoch 00012: val_accuracy did not improve from 0.81081
# Epoch 13/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.5268 - accuracy: 0.8305 - val_loss: 0.7358 - val_accuracy: 0.7432
#
# Epoch 00013: val_accuracy did not improve from 0.81081
# Epoch 14/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.4193 - accuracy: 0.8547 - val_loss: 0.9251 - val_accuracy: 0.7297
#
# Epoch 00014: val_accuracy did not improve from 0.81081
# Epoch 15/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.4123 - accuracy: 0.8616 - val_loss: 0.7075 - val_accuracy: 0.7432
#
# Epoch 00015: val_accuracy did not improve from 0.81081
# Epoch 16/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3940 - accuracy: 0.8663 - val_loss: 2.1133 - val_accuracy: 0.5541
#
# Epoch 00016: val_accuracy did not improve from 0.81081
# Epoch 17/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.4373 - accuracy: 0.8568 - val_loss: 0.9850 - val_accuracy: 0.7500
#
# Epoch 00017: val_accuracy did not improve from 0.81081
# Epoch 18/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3923 - accuracy: 0.8684 - val_loss: 0.6318 - val_accuracy: 0.8108
#
# Epoch 00018: val_accuracy did not improve from 0.81081
# Epoch 19/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3705 - accuracy: 0.8700 - val_loss: 0.5846 - val_accuracy: 0.7905
#
# Epoch 00019: val_accuracy did not improve from 0.81081
# Epoch 20/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3321 - accuracy: 0.8858 - val_loss: 0.4754 - val_accuracy: 0.8581
#
# Epoch 00020: val_accuracy improved from 0.81081 to 0.85811, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 21/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.3334 - accuracy: 0.8932 - val_loss: 0.6294 - val_accuracy: 0.8176
#
# Epoch 00021: val_accuracy did not improve from 0.85811
# Epoch 22/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2947 - accuracy: 0.8932 - val_loss: 0.4886 - val_accuracy: 0.8446
#
# Epoch 00022: val_accuracy did not improve from 0.85811
# Epoch 23/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3478 - accuracy: 0.8868 - val_loss: 0.6827 - val_accuracy: 0.7905
#
# Epoch 00023: val_accuracy did not improve from 0.85811
# Epoch 24/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3123 - accuracy: 0.8932 - val_loss: 0.8945 - val_accuracy: 0.7162
#
# Epoch 00024: val_accuracy did not improve from 0.85811
# Epoch 25/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2777 - accuracy: 0.9047 - val_loss: 0.4318 - val_accuracy: 0.8649
#
# Epoch 00025: val_accuracy improved from 0.85811 to 0.86486, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 26/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.2452 - accuracy: 0.9137 - val_loss: 0.6056 - val_accuracy: 0.8108
#
# Epoch 00026: val_accuracy did not improve from 0.86486
# Epoch 27/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2779 - accuracy: 0.9084 - val_loss: 0.6103 - val_accuracy: 0.8446
#
# Epoch 00027: val_accuracy did not improve from 0.86486
# Epoch 28/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2483 - accuracy: 0.9142 - val_loss: 0.7530 - val_accuracy: 0.8108
#
# Epoch 00028: val_accuracy did not improve from 0.86486
# Epoch 29/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.3143 - accuracy: 0.8974 - val_loss: 0.4287 - val_accuracy: 0.8581
#
# Epoch 00029: val_accuracy did not improve from 0.86486
# Epoch 30/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2025 - accuracy: 0.9305 - val_loss: 0.4835 - val_accuracy: 0.8716
#
# Epoch 00030: val_accuracy improved from 0.86486 to 0.87162, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 31/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.2386 - accuracy: 0.9195 - val_loss: 0.6451 - val_accuracy: 0.8041
#
# Epoch 00031: val_accuracy did not improve from 0.87162
# Epoch 32/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2293 - accuracy: 0.9253 - val_loss: 0.6169 - val_accuracy: 0.8378
#
# Epoch 00032: val_accuracy did not improve from 0.87162
# Epoch 33/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.2535 - accuracy: 0.9205 - val_loss: 0.6712 - val_accuracy: 0.8243
#
# Epoch 00033: val_accuracy did not improve from 0.87162
# Epoch 34/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1966 - accuracy: 0.9332 - val_loss: 0.3582 - val_accuracy: 0.8716
#
# Epoch 00034: val_accuracy did not improve from 0.87162
# Epoch 35/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1927 - accuracy: 0.9342 - val_loss: 0.4562 - val_accuracy: 0.8581
#
# Epoch 00035: val_accuracy did not improve from 0.87162
# Epoch 36/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1971 - accuracy: 0.9311 - val_loss: 0.5771 - val_accuracy: 0.8649
#
# Epoch 00036: val_accuracy did not improve from 0.87162
# Epoch 37/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1811 - accuracy: 0.9389 - val_loss: 0.3656 - val_accuracy: 0.8919
#
# Epoch 00037: val_accuracy improved from 0.87162 to 0.89189, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 38/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.1716 - accuracy: 0.9395 - val_loss: 0.5373 - val_accuracy: 0.8581
#
# Epoch 00038: val_accuracy did not improve from 0.89189
# Epoch 39/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.2052 - accuracy: 0.9321 - val_loss: 0.5135 - val_accuracy: 0.8851
#
# Epoch 00039: val_accuracy did not improve from 0.89189
# Epoch 40/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1357 - accuracy: 0.9505 - val_loss: 0.4088 - val_accuracy: 0.8784
#
# Epoch 00040: val_accuracy did not improve from 0.89189
# Epoch 41/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.2143 - accuracy: 0.9279 - val_loss: 0.6471 - val_accuracy: 0.8311
#
# Epoch 00041: val_accuracy did not improve from 0.89189
# Epoch 42/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1935 - accuracy: 0.9337 - val_loss: 0.3449 - val_accuracy: 0.8581
#
# Epoch 00042: val_accuracy did not improve from 0.89189
# Epoch 43/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1610 - accuracy: 0.9458 - val_loss: 0.6356 - val_accuracy: 0.8649
#
# Epoch 00043: val_accuracy did not improve from 0.89189
# Epoch 44/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1240 - accuracy: 0.9558 - val_loss: 0.3549 - val_accuracy: 0.8649
#
# Epoch 00044: val_accuracy did not improve from 0.89189
# Epoch 45/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1023 - accuracy: 0.9647 - val_loss: 0.3582 - val_accuracy: 0.8716
#
# Epoch 00045: val_accuracy did not improve from 0.89189
# Epoch 46/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1075 - accuracy: 0.9605 - val_loss: 0.5375 - val_accuracy: 0.8851
#
# Epoch 00046: val_accuracy did not improve from 0.89189
# Epoch 47/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1756 - accuracy: 0.9411 - val_loss: 1.2703 - val_accuracy: 0.7162
#
# Epoch 00047: val_accuracy did not improve from 0.89189
# Epoch 48/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1427 - accuracy: 0.9521 - val_loss: 0.4452 - val_accuracy: 0.8784
#
# Epoch 00048: val_accuracy did not improve from 0.89189
# Epoch 49/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1254 - accuracy: 0.9579 - val_loss: 0.5199 - val_accuracy: 0.8514
#
# Epoch 00049: val_accuracy did not improve from 0.89189
# Epoch 50/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1740 - accuracy: 0.9411 - val_loss: 0.5541 - val_accuracy: 0.8243
#
# Epoch 00050: val_accuracy did not improve from 0.89189
# Epoch 51/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1190 - accuracy: 0.9600 - val_loss: 0.6297 - val_accuracy: 0.8243
#
# Epoch 00051: val_accuracy did not improve from 0.89189
# Epoch 52/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1063 - accuracy: 0.9637 - val_loss: 0.3952 - val_accuracy: 0.8784
#
# Epoch 00052: val_accuracy did not improve from 0.89189
# Epoch 53/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0836 - accuracy: 0.9721 - val_loss: 0.5255 - val_accuracy: 0.8581
#
# Epoch 00053: val_accuracy did not improve from 0.89189
# Epoch 54/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0913 - accuracy: 0.9684 - val_loss: 0.4519 - val_accuracy: 0.8986
#
# Epoch 00054: val_accuracy improved from 0.89189 to 0.89865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 55/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.1192 - accuracy: 0.9605 - val_loss: 0.4048 - val_accuracy: 0.8716
#
# Epoch 00055: val_accuracy did not improve from 0.89865
# Epoch 56/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1009 - accuracy: 0.9711 - val_loss: 0.7006 - val_accuracy: 0.8108
#
# Epoch 00056: val_accuracy did not improve from 0.89865
# Epoch 57/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1131 - accuracy: 0.9663 - val_loss: 0.3703 - val_accuracy: 0.8986
#
# Epoch 00057: val_accuracy did not improve from 0.89865
# Epoch 58/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1178 - accuracy: 0.9589 - val_loss: 0.3749 - val_accuracy: 0.9122
#
# Epoch 00058: val_accuracy improved from 0.89865 to 0.91216, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 59/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0934 - accuracy: 0.9684 - val_loss: 0.5984 - val_accuracy: 0.8446
#
# Epoch 00059: val_accuracy did not improve from 0.91216
# Epoch 60/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0969 - accuracy: 0.9663 - val_loss: 0.4368 - val_accuracy: 0.8919
#
# Epoch 00060: val_accuracy did not improve from 0.91216
# Epoch 61/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1062 - accuracy: 0.9647 - val_loss: 0.3098 - val_accuracy: 0.9122
#
# Epoch 00061: val_accuracy did not improve from 0.91216
# Epoch 62/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1092 - accuracy: 0.9653 - val_loss: 0.4312 - val_accuracy: 0.9257
#
# Epoch 00062: val_accuracy improved from 0.91216 to 0.92568, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 63/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0845 - accuracy: 0.9684 - val_loss: 0.2476 - val_accuracy: 0.9459
#
# Epoch 00063: val_accuracy improved from 0.92568 to 0.94595, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_5.h5
# Epoch 64/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0979 - accuracy: 0.9684 - val_loss: 0.6644 - val_accuracy: 0.8581
#
# Epoch 00064: val_accuracy did not improve from 0.94595
# Epoch 65/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1362 - accuracy: 0.9511 - val_loss: 0.3780 - val_accuracy: 0.8986
#
# Epoch 00065: val_accuracy did not improve from 0.94595
# Epoch 66/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0776 - accuracy: 0.9753 - val_loss: 0.3655 - val_accuracy: 0.8784
#
# Epoch 00066: val_accuracy did not improve from 0.94595
# Epoch 67/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0389 - accuracy: 0.9868 - val_loss: 0.4097 - val_accuracy: 0.8986
#
# Epoch 00067: val_accuracy did not improve from 0.94595
# Epoch 68/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0820 - accuracy: 0.9758 - val_loss: 0.3696 - val_accuracy: 0.9054
#
# Epoch 00068: val_accuracy did not improve from 0.94595
# Epoch 69/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0561 - accuracy: 0.9821 - val_loss: 0.4616 - val_accuracy: 0.8851
#
# Epoch 00069: val_accuracy did not improve from 0.94595
# Epoch 70/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0481 - accuracy: 0.9832 - val_loss: 0.4510 - val_accuracy: 0.8784
#
# Epoch 00070: val_accuracy did not improve from 0.94595
# Epoch 71/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0510 - accuracy: 0.9821 - val_loss: 0.4125 - val_accuracy: 0.8784
#
# Epoch 00071: val_accuracy did not improve from 0.94595
# Epoch 72/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1267 - accuracy: 0.9595 - val_loss: 0.6062 - val_accuracy: 0.8851
#
# Epoch 00072: val_accuracy did not improve from 0.94595
# Epoch 73/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0892 - accuracy: 0.9695 - val_loss: 0.7750 - val_accuracy: 0.8446
#
# Epoch 00073: val_accuracy did not improve from 0.94595
# Epoch 74/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.1011 - accuracy: 0.9658 - val_loss: 0.5368 - val_accuracy: 0.8649
#
# Epoch 00074: val_accuracy did not improve from 0.94595
# Epoch 75/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0921 - accuracy: 0.9663 - val_loss: 0.4766 - val_accuracy: 0.8851
#
# Epoch 00075: val_accuracy did not improve from 0.94595
# Epoch 76/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0669 - accuracy: 0.9805 - val_loss: 0.6039 - val_accuracy: 0.8446
#
# Epoch 00076: val_accuracy did not improve from 0.94595
# Epoch 77/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0597 - accuracy: 0.9805 - val_loss: 0.7422 - val_accuracy: 0.8311
#
# Epoch 00077: val_accuracy did not improve from 0.94595
# Epoch 78/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0584 - accuracy: 0.9805 - val_loss: 0.4903 - val_accuracy: 0.8784
#
# Epoch 00078: val_accuracy did not improve from 0.94595
# Epoch 79/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0441 - accuracy: 0.9874 - val_loss: 0.5585 - val_accuracy: 0.8986
#
# Epoch 00079: val_accuracy did not improve from 0.94595
# Epoch 80/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0495 - accuracy: 0.9800 - val_loss: 0.5340 - val_accuracy: 0.8784
#
# Epoch 00080: val_accuracy did not improve from 0.94595
# Epoch 81/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0607 - accuracy: 0.9811 - val_loss: 0.3820 - val_accuracy: 0.8986
#
# Epoch 00081: val_accuracy did not improve from 0.94595
# Epoch 82/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0585 - accuracy: 0.9826 - val_loss: 0.6453 - val_accuracy: 0.8514
#
# Epoch 00082: val_accuracy did not improve from 0.94595
# Epoch 83/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0859 - accuracy: 0.9674 - val_loss: 0.5917 - val_accuracy: 0.8784
#
# Epoch 00083: val_accuracy did not improve from 0.94595
# Epoch 84/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0738 - accuracy: 0.9716 - val_loss: 0.5664 - val_accuracy: 0.8581
#
# Epoch 00084: val_accuracy did not improve from 0.94595
# Epoch 85/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0927 - accuracy: 0.9726 - val_loss: 0.3730 - val_accuracy: 0.8514
#
# Epoch 00085: val_accuracy did not improve from 0.94595
# Epoch 86/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0545 - accuracy: 0.9821 - val_loss: 0.4790 - val_accuracy: 0.8919
#
# Epoch 00086: val_accuracy did not improve from 0.94595
# Epoch 87/500
# 238/238 [==============================] - 15s 62ms/step - loss: 0.0657 - accuracy: 0.9753 - val_loss: 0.2951 - val_accuracy: 0.8919
#
# Epoch 00087: val_accuracy did not improve from 0.94595
# Epoch 88/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0293 - accuracy: 0.9889 - val_loss: 0.4605 - val_accuracy: 0.8851
#
# Epoch 00088: val_accuracy did not improve from 0.94595
# Epoch 89/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.5138 - val_accuracy: 0.8716
#
# Epoch 00089: val_accuracy did not improve from 0.94595
# Epoch 90/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0812 - accuracy: 0.9753 - val_loss: 0.4763 - val_accuracy: 0.8784
#
# Epoch 00090: val_accuracy did not improve from 0.94595
# Epoch 91/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0445 - accuracy: 0.9874 - val_loss: 0.4055 - val_accuracy: 0.8851
#
# Epoch 00091: val_accuracy did not improve from 0.94595
# Epoch 92/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0419 - accuracy: 0.9842 - val_loss: 0.4204 - val_accuracy: 0.9054
#
# Epoch 00092: val_accuracy did not improve from 0.94595
# Epoch 93/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0430 - accuracy: 0.9837 - val_loss: 0.6104 - val_accuracy: 0.8851
#
# Epoch 00093: val_accuracy did not improve from 0.94595
# Epoch 94/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0485 - accuracy: 0.9842 - val_loss: 0.6170 - val_accuracy: 0.8649
#
# Epoch 00094: val_accuracy did not improve from 0.94595
# Epoch 95/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0888 - accuracy: 0.9721 - val_loss: 0.4670 - val_accuracy: 0.8919
#
# Epoch 00095: val_accuracy did not improve from 0.94595
# Epoch 96/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.1114 - accuracy: 0.9616 - val_loss: 0.8969 - val_accuracy: 0.8311
#
# Epoch 00096: val_accuracy did not improve from 0.94595
# Epoch 97/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0415 - accuracy: 0.9863 - val_loss: 0.5369 - val_accuracy: 0.8716
#
# Epoch 00097: val_accuracy did not improve from 0.94595
# Epoch 98/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0266 - accuracy: 0.9921 - val_loss: 0.3933 - val_accuracy: 0.8986
#
# Epoch 00098: val_accuracy did not improve from 0.94595
# Epoch 99/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0624 - accuracy: 0.9800 - val_loss: 0.5393 - val_accuracy: 0.8919
#
# Epoch 00099: val_accuracy did not improve from 0.94595
# Epoch 100/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0266 - accuracy: 0.9921 - val_loss: 0.3603 - val_accuracy: 0.8919
#
# Epoch 00100: val_accuracy did not improve from 0.94595
# Epoch 101/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0253 - accuracy: 0.9911 - val_loss: 0.5690 - val_accuracy: 0.9054
#
# Epoch 00101: val_accuracy did not improve from 0.94595
# Epoch 102/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0562 - accuracy: 0.9811 - val_loss: 0.4794 - val_accuracy: 0.9054
#
# Epoch 00102: val_accuracy did not improve from 0.94595
# Epoch 103/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0440 - accuracy: 0.9847 - val_loss: 0.4602 - val_accuracy: 0.8986
#
# Epoch 00103: val_accuracy did not improve from 0.94595
# Epoch 104/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0342 - accuracy: 0.9884 - val_loss: 0.3974 - val_accuracy: 0.9122
#
# Epoch 00104: val_accuracy did not improve from 0.94595
# Epoch 105/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0410 - accuracy: 0.9889 - val_loss: 0.5400 - val_accuracy: 0.9054
#
# Epoch 00105: val_accuracy did not improve from 0.94595
# Epoch 106/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0641 - accuracy: 0.9753 - val_loss: 0.3909 - val_accuracy: 0.8919
#
# Epoch 00106: val_accuracy did not improve from 0.94595
# Epoch 107/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0500 - accuracy: 0.9837 - val_loss: 0.2890 - val_accuracy: 0.9324
#
# Epoch 00107: val_accuracy did not improve from 0.94595
# Epoch 108/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0298 - accuracy: 0.9905 - val_loss: 0.4953 - val_accuracy: 0.8986
#
# Epoch 00108: val_accuracy did not improve from 0.94595
# Epoch 109/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 0.3690 - val_accuracy: 0.9054
#
# Epoch 00109: val_accuracy did not improve from 0.94595
# Epoch 110/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0290 - accuracy: 0.9905 - val_loss: 0.5194 - val_accuracy: 0.8716
#
# Epoch 00110: val_accuracy did not improve from 0.94595
# Epoch 111/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0476 - accuracy: 0.9868 - val_loss: 0.4454 - val_accuracy: 0.8851
#
# Epoch 00111: val_accuracy did not improve from 0.94595
# Epoch 112/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.3937 - val_accuracy: 0.9054
#
# Epoch 00112: val_accuracy did not improve from 0.94595
# Epoch 113/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0782 - accuracy: 0.9774 - val_loss: 0.7079 - val_accuracy: 0.8784
#
# Epoch 00113: val_accuracy did not improve from 0.94595
# Epoch 114/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0487 - accuracy: 0.9874 - val_loss: 0.4329 - val_accuracy: 0.8851
#
# Epoch 00114: val_accuracy did not improve from 0.94595
# Epoch 115/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0288 - accuracy: 0.9905 - val_loss: 0.5154 - val_accuracy: 0.8851
#
# Epoch 00115: val_accuracy did not improve from 0.94595
# Epoch 116/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0156 - accuracy: 0.9926 - val_loss: 0.4381 - val_accuracy: 0.8649
#
# Epoch 00116: val_accuracy did not improve from 0.94595
# Epoch 117/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0906 - accuracy: 0.9747 - val_loss: 0.9244 - val_accuracy: 0.8311
#
# Epoch 00117: val_accuracy did not improve from 0.94595
# Epoch 118/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0402 - accuracy: 0.9863 - val_loss: 0.5073 - val_accuracy: 0.8986
#
# Epoch 00118: val_accuracy did not improve from 0.94595
# Epoch 119/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0355 - accuracy: 0.9842 - val_loss: 5.3392 - val_accuracy: 0.4730
#
# Epoch 00119: val_accuracy did not improve from 0.94595
# Epoch 120/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0478 - accuracy: 0.9847 - val_loss: 0.6641 - val_accuracy: 0.8581
#
# Epoch 00120: val_accuracy did not improve from 0.94595
# Epoch 121/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.3864 - val_accuracy: 0.9122
#
# Epoch 00121: val_accuracy did not improve from 0.94595
# Epoch 122/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0373 - accuracy: 0.9874 - val_loss: 0.6181 - val_accuracy: 0.8716
#
# Epoch 00122: val_accuracy did not improve from 0.94595
# Epoch 123/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 1.3226 - val_accuracy: 0.7297
#
# Epoch 00123: val_accuracy did not improve from 0.94595
# Epoch 124/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0140 - accuracy: 0.9932 - val_loss: 4.7334 - val_accuracy: 0.4392
#
# Epoch 00124: val_accuracy did not improve from 0.94595
# Epoch 125/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0373 - accuracy: 0.9863 - val_loss: 0.4419 - val_accuracy: 0.9324
#
# Epoch 00125: val_accuracy did not improve from 0.94595
# Epoch 126/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0148 - accuracy: 0.9942 - val_loss: 0.4665 - val_accuracy: 0.8784
#
# Epoch 00126: val_accuracy did not improve from 0.94595
# Epoch 127/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.6653 - val_accuracy: 0.8581
#
# Epoch 00127: val_accuracy did not improve from 0.94595
# Epoch 128/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0661 - accuracy: 0.9774 - val_loss: 0.8296 - val_accuracy: 0.8243
#
# Epoch 00128: val_accuracy did not improve from 0.94595
# Epoch 129/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0318 - accuracy: 0.9884 - val_loss: 0.4381 - val_accuracy: 0.9189
#
# Epoch 00129: val_accuracy did not improve from 0.94595
# Epoch 130/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0393 - accuracy: 0.9895 - val_loss: 0.5866 - val_accuracy: 0.8446
#
# Epoch 00130: val_accuracy did not improve from 0.94595
# Epoch 131/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 0.5427 - val_accuracy: 0.8851
#
# Epoch 00131: val_accuracy did not improve from 0.94595
# Epoch 132/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.4040 - val_accuracy: 0.8716
#
# Epoch 00132: val_accuracy did not improve from 0.94595
# Epoch 133/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0323 - accuracy: 0.9895 - val_loss: 0.5916 - val_accuracy: 0.8784
#
# Epoch 00133: val_accuracy did not improve from 0.94595
# Epoch 134/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0330 - accuracy: 0.9905 - val_loss: 0.6570 - val_accuracy: 0.8716
#
# Epoch 00134: val_accuracy did not improve from 0.94595
# Epoch 135/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0271 - accuracy: 0.9905 - val_loss: 0.4041 - val_accuracy: 0.9189
#
# Epoch 00135: val_accuracy did not improve from 0.94595
# Epoch 136/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0482 - accuracy: 0.9842 - val_loss: 0.6344 - val_accuracy: 0.8986
#
# Epoch 00136: val_accuracy did not improve from 0.94595
# Epoch 137/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0485 - accuracy: 0.9832 - val_loss: 0.5530 - val_accuracy: 0.8581
#
# Epoch 00137: val_accuracy did not improve from 0.94595
# Epoch 138/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0329 - accuracy: 0.9900 - val_loss: 0.5501 - val_accuracy: 0.8784
#
# Epoch 00138: val_accuracy did not improve from 0.94595
# Epoch 139/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0245 - accuracy: 0.9926 - val_loss: 0.7960 - val_accuracy: 0.8041
#
# Epoch 00139: val_accuracy did not improve from 0.94595
# Epoch 140/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0403 - accuracy: 0.9879 - val_loss: 0.5106 - val_accuracy: 0.8851
#
# Epoch 00140: val_accuracy did not improve from 0.94595
# Epoch 141/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0232 - accuracy: 0.9916 - val_loss: 0.4395 - val_accuracy: 0.9257
#
# Epoch 00141: val_accuracy did not improve from 0.94595
# Epoch 142/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0130 - accuracy: 0.9974 - val_loss: 0.4152 - val_accuracy: 0.9054
#
# Epoch 00142: val_accuracy did not improve from 0.94595
# Epoch 143/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.3456 - val_accuracy: 0.8986
#
# Epoch 00143: val_accuracy did not improve from 0.94595
# Epoch 144/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0121 - accuracy: 0.9974 - val_loss: 0.3959 - val_accuracy: 0.9054
#
# Epoch 00144: val_accuracy did not improve from 0.94595
# Epoch 145/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0639 - accuracy: 0.9805 - val_loss: 0.6195 - val_accuracy: 0.8919
#
# Epoch 00145: val_accuracy did not improve from 0.94595
# Epoch 146/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.4664 - val_accuracy: 0.9054
#
# Epoch 00146: val_accuracy did not improve from 0.94595
# Epoch 147/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0198 - accuracy: 0.9953 - val_loss: 0.6513 - val_accuracy: 0.8581
#
# Epoch 00147: val_accuracy did not improve from 0.94595
# Epoch 148/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0261 - accuracy: 0.9926 - val_loss: 0.5520 - val_accuracy: 0.8851
#
# Epoch 00148: val_accuracy did not improve from 0.94595
# Epoch 149/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0293 - accuracy: 0.9889 - val_loss: 0.6149 - val_accuracy: 0.8784
#
# Epoch 00149: val_accuracy did not improve from 0.94595
# Epoch 150/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0357 - accuracy: 0.9868 - val_loss: 0.5003 - val_accuracy: 0.8986
#
# Epoch 00150: val_accuracy did not improve from 0.94595
# Epoch 151/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0219 - accuracy: 0.9947 - val_loss: 0.8194 - val_accuracy: 0.8581
#
# Epoch 00151: val_accuracy did not improve from 0.94595
# Epoch 152/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0314 - accuracy: 0.9895 - val_loss: 0.5916 - val_accuracy: 0.8446
#
# Epoch 00152: val_accuracy did not improve from 0.94595
# Epoch 153/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0441 - accuracy: 0.9874 - val_loss: 0.5599 - val_accuracy: 0.8581
#
# Epoch 00153: val_accuracy did not improve from 0.94595
# Epoch 154/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.3852 - val_accuracy: 0.9189
#
# Epoch 00154: val_accuracy did not improve from 0.94595
# Epoch 155/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0104 - accuracy: 0.9979 - val_loss: 0.4562 - val_accuracy: 0.9054
#
# Epoch 00155: val_accuracy did not improve from 0.94595
# Epoch 156/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.5153 - val_accuracy: 0.8784
#
# Epoch 00156: val_accuracy did not improve from 0.94595
# Epoch 157/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0224 - accuracy: 0.9932 - val_loss: 0.4871 - val_accuracy: 0.9054
#
# Epoch 00157: val_accuracy did not improve from 0.94595
# Epoch 158/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0264 - accuracy: 0.9905 - val_loss: 0.4868 - val_accuracy: 0.8986
#
# Epoch 00158: val_accuracy did not improve from 0.94595
# Epoch 159/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0227 - accuracy: 0.9921 - val_loss: 0.7137 - val_accuracy: 0.8649
#
# Epoch 00159: val_accuracy did not improve from 0.94595
# Epoch 160/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 3.5944 - val_accuracy: 0.5811
#
# Epoch 00160: val_accuracy did not improve from 0.94595
# Epoch 161/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0445 - accuracy: 0.9837 - val_loss: 0.5427 - val_accuracy: 0.9054
#
# Epoch 00161: val_accuracy did not improve from 0.94595
# Epoch 162/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0264 - accuracy: 0.9889 - val_loss: 0.4069 - val_accuracy: 0.9189
#
# Epoch 00162: val_accuracy did not improve from 0.94595
# Epoch 163/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0184 - accuracy: 0.9926 - val_loss: 0.5298 - val_accuracy: 0.8716
#
# Epoch 00163: val_accuracy did not improve from 0.94595
# Epoch 164/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.4898 - val_accuracy: 0.9054
#
# Epoch 00164: val_accuracy did not improve from 0.94595
# Epoch 165/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.3546 - val_accuracy: 0.9324
#
# Epoch 00165: val_accuracy did not improve from 0.94595
# Epoch 166/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0254 - accuracy: 0.9921 - val_loss: 0.5967 - val_accuracy: 0.8446
#
# Epoch 00166: val_accuracy did not improve from 0.94595
# Epoch 167/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.5190 - val_accuracy: 0.9054
#
# Epoch 00167: val_accuracy did not improve from 0.94595
# Epoch 168/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0426 - accuracy: 0.9842 - val_loss: 0.4697 - val_accuracy: 0.8919
#
# Epoch 00168: val_accuracy did not improve from 0.94595
# Epoch 169/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0356 - accuracy: 0.9874 - val_loss: 0.4312 - val_accuracy: 0.9054
#
# Epoch 00169: val_accuracy did not improve from 0.94595
# Epoch 170/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.7912 - val_accuracy: 0.8581
#
# Epoch 00170: val_accuracy did not improve from 0.94595
# Epoch 171/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0362 - accuracy: 0.9874 - val_loss: 0.6316 - val_accuracy: 0.8851
#
# Epoch 00171: val_accuracy did not improve from 0.94595
# Epoch 172/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0258 - accuracy: 0.9921 - val_loss: 0.4019 - val_accuracy: 0.8919
#
# Epoch 00172: val_accuracy did not improve from 0.94595
# Epoch 173/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0120 - accuracy: 0.9974 - val_loss: 0.6327 - val_accuracy: 0.8446
#
# Epoch 00173: val_accuracy did not improve from 0.94595
# Epoch 174/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0361 - accuracy: 0.9884 - val_loss: 7.4104 - val_accuracy: 0.3784
#
# Epoch 00174: val_accuracy did not improve from 0.94595
# Epoch 175/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.4248 - val_accuracy: 0.9054
#
# Epoch 00175: val_accuracy did not improve from 0.94595
# Epoch 176/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.4853 - val_accuracy: 0.8919
#
# Epoch 00176: val_accuracy did not improve from 0.94595
# Epoch 177/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 0.4113 - val_accuracy: 0.9257
#
# Epoch 00177: val_accuracy did not improve from 0.94595
# Epoch 178/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0256 - accuracy: 0.9932 - val_loss: 0.4279 - val_accuracy: 0.9392
#
# Epoch 00178: val_accuracy did not improve from 0.94595
# Epoch 179/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0153 - accuracy: 0.9968 - val_loss: 0.3655 - val_accuracy: 0.9459
#
# Epoch 00179: val_accuracy did not improve from 0.94595
# Epoch 180/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0154 - accuracy: 0.9942 - val_loss: 0.5599 - val_accuracy: 0.8919
#
# Epoch 00180: val_accuracy did not improve from 0.94595
# Epoch 181/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0331 - accuracy: 0.9874 - val_loss: 0.7196 - val_accuracy: 0.8986
#
# Epoch 00181: val_accuracy did not improve from 0.94595
# Epoch 182/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0346 - accuracy: 0.9889 - val_loss: 0.8516 - val_accuracy: 0.8514
#
# Epoch 00182: val_accuracy did not improve from 0.94595
# Epoch 183/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0093 - accuracy: 0.9963 - val_loss: 0.4666 - val_accuracy: 0.9054
#
# Epoch 00183: val_accuracy did not improve from 0.94595
# Epoch 184/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 0.4005 - val_accuracy: 0.9122
#
# Epoch 00184: val_accuracy did not improve from 0.94595
# Epoch 185/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.4985 - val_accuracy: 0.8649
#
# Epoch 00185: val_accuracy did not improve from 0.94595
# Epoch 186/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0258 - accuracy: 0.9889 - val_loss: 0.5071 - val_accuracy: 0.8986
#
# Epoch 00186: val_accuracy did not improve from 0.94595
# Epoch 187/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0321 - accuracy: 0.9889 - val_loss: 0.4041 - val_accuracy: 0.9054
#
# Epoch 00187: val_accuracy did not improve from 0.94595
# Epoch 188/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.3183 - val_accuracy: 0.9324
#
# Epoch 00188: val_accuracy did not improve from 0.94595
# Epoch 189/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.4616 - val_accuracy: 0.8649
#
# Epoch 00189: val_accuracy did not improve from 0.94595
# Epoch 190/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.4502 - val_accuracy: 0.8919
#
# Epoch 00190: val_accuracy did not improve from 0.94595
# Epoch 191/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0624 - accuracy: 0.9784 - val_loss: 0.6352 - val_accuracy: 0.8784
#
# Epoch 00191: val_accuracy did not improve from 0.94595
# Epoch 192/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0315 - accuracy: 0.9884 - val_loss: 0.3711 - val_accuracy: 0.9122
#
# Epoch 00192: val_accuracy did not improve from 0.94595
# Epoch 193/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0240 - accuracy: 0.9942 - val_loss: 0.5000 - val_accuracy: 0.8986
#
# Epoch 00193: val_accuracy did not improve from 0.94595
# Epoch 194/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0183 - accuracy: 0.9953 - val_loss: 0.7101 - val_accuracy: 0.8919
#
# Epoch 00194: val_accuracy did not improve from 0.94595
# Epoch 195/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0100 - accuracy: 0.9947 - val_loss: 0.5332 - val_accuracy: 0.8716
#
# Epoch 00195: val_accuracy did not improve from 0.94595
# Epoch 196/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0349 - accuracy: 0.9884 - val_loss: 0.4750 - val_accuracy: 0.9122
#
# Epoch 00196: val_accuracy did not improve from 0.94595
# Epoch 197/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.3487 - val_accuracy: 0.9257
#
# Epoch 00197: val_accuracy did not improve from 0.94595
# Epoch 198/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.6796 - val_accuracy: 0.8784
#
# Epoch 00198: val_accuracy did not improve from 0.94595
# Epoch 199/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.4827 - val_accuracy: 0.8851
#
# Epoch 00199: val_accuracy did not improve from 0.94595
# Epoch 200/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0313 - accuracy: 0.9895 - val_loss: 0.6569 - val_accuracy: 0.8851
#
# Epoch 00200: val_accuracy did not improve from 0.94595
# Epoch 201/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0452 - accuracy: 0.9805 - val_loss: 0.5174 - val_accuracy: 0.8919
#
# Epoch 00201: val_accuracy did not improve from 0.94595
# Epoch 202/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.3168 - val_accuracy: 0.9122
#
# Epoch 00202: val_accuracy did not improve from 0.94595
# Epoch 203/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 0.3767 - val_accuracy: 0.8986
#
# Epoch 00203: val_accuracy did not improve from 0.94595
# Epoch 204/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.3818 - val_accuracy: 0.8986
#
# Epoch 00204: val_accuracy did not improve from 0.94595
# Epoch 205/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9392
#
# Epoch 00205: val_accuracy did not improve from 0.94595
# Epoch 206/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0316 - accuracy: 0.9868 - val_loss: 0.5608 - val_accuracy: 0.8986
#
# Epoch 00206: val_accuracy did not improve from 0.94595
# Epoch 207/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0215 - accuracy: 0.9905 - val_loss: 0.5798 - val_accuracy: 0.8784
#
# Epoch 00207: val_accuracy did not improve from 0.94595
# Epoch 208/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.4398 - val_accuracy: 0.9122
#
# Epoch 00208: val_accuracy did not improve from 0.94595
# Epoch 209/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.4939 - val_accuracy: 0.9054
#
# Epoch 00209: val_accuracy did not improve from 0.94595
# Epoch 210/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.6180 - val_accuracy: 0.8919
#
# Epoch 00210: val_accuracy did not improve from 0.94595
# Epoch 211/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0196 - accuracy: 0.9947 - val_loss: 0.4551 - val_accuracy: 0.9122
#
# Epoch 00211: val_accuracy did not improve from 0.94595
# Epoch 212/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0242 - accuracy: 0.9916 - val_loss: 0.7908 - val_accuracy: 0.8716
#
# Epoch 00212: val_accuracy did not improve from 0.94595
# Epoch 213/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0611 - accuracy: 0.9847 - val_loss: 0.4065 - val_accuracy: 0.9257
#
# Epoch 00213: val_accuracy did not improve from 0.94595
# Epoch 214/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.4543 - val_accuracy: 0.9122
#
# Epoch 00214: val_accuracy did not improve from 0.94595
# Epoch 215/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 0.3784 - val_accuracy: 0.9257
#
# Epoch 00215: val_accuracy did not improve from 0.94595
# Epoch 216/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0397 - accuracy: 0.9895 - val_loss: 0.6071 - val_accuracy: 0.8649
#
# Epoch 00216: val_accuracy did not improve from 0.94595
# Epoch 217/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0271 - accuracy: 0.9926 - val_loss: 0.5515 - val_accuracy: 0.8851
#
# Epoch 00217: val_accuracy did not improve from 0.94595
# Epoch 218/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.3978 - val_accuracy: 0.8851
#
# Epoch 00218: val_accuracy did not improve from 0.94595
# Epoch 219/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0169 - accuracy: 0.9942 - val_loss: 0.4265 - val_accuracy: 0.8986
#
# Epoch 00219: val_accuracy did not improve from 0.94595
# Epoch 220/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.4230 - val_accuracy: 0.8986
#
# Epoch 00220: val_accuracy did not improve from 0.94595
# Epoch 221/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.5114 - val_accuracy: 0.8784
#
# Epoch 00221: val_accuracy did not improve from 0.94595
# Epoch 222/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.4230 - val_accuracy: 0.9122
#
# Epoch 00222: val_accuracy did not improve from 0.94595
# Epoch 223/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.3782 - val_accuracy: 0.9257
#
# Epoch 00223: val_accuracy did not improve from 0.94595
# Epoch 224/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0153 - accuracy: 0.9942 - val_loss: 0.6981 - val_accuracy: 0.9054
#
# Epoch 00224: val_accuracy did not improve from 0.94595
# Epoch 225/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.5544 - val_accuracy: 0.8851
#
# Epoch 00225: val_accuracy did not improve from 0.94595
# Epoch 226/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0207 - accuracy: 0.9947 - val_loss: 0.5894 - val_accuracy: 0.8986
#
# Epoch 00226: val_accuracy did not improve from 0.94595
# Epoch 227/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0276 - accuracy: 0.9926 - val_loss: 0.6378 - val_accuracy: 0.8446
#
# Epoch 00227: val_accuracy did not improve from 0.94595
# Epoch 228/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0628 - accuracy: 0.9800 - val_loss: 13.8041 - val_accuracy: 0.2230
#
# Epoch 00228: val_accuracy did not improve from 0.94595
# Epoch 229/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0253 - accuracy: 0.9905 - val_loss: 0.4497 - val_accuracy: 0.8851
#
# Epoch 00229: val_accuracy did not improve from 0.94595
# Epoch 230/500
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.94595
# Epoch 423/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.5612 - val_accuracy: 0.9189
#
# Epoch 00423: val_accuracy did not improve from 0.94595
# Epoch 424/500
# 238/238 [==============================] - 15s 65ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.5651 - val_accuracy: 0.9324
#
# Epoch 00424: val_accuracy did not improve from 0.94595
# Epoch 425/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0035 - accuracy: 0.9979 - val_loss: 0.5136 - val_accuracy: 0.9122
#
# Epoch 00425: val_accuracy did not improve from 0.94595
# Epoch 426/500
# 238/238 [==============================] - 15s 63ms/step - loss: 7.8610e-04 - accuracy: 0.9995 - val_loss: 0.7215 - val_accuracy: 0.8851
#
# Epoch 00426: val_accuracy did not improve from 0.94595
# Epoch 427/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.7593 - val_accuracy: 0.8851
#
# Epoch 00427: val_accuracy did not improve from 0.94595
# Epoch 428/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0106 - accuracy: 0.9958 - val_loss: 3.1055 - val_accuracy: 0.6081
#
# Epoch 00428: val_accuracy did not improve from 0.94595
# Epoch 429/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.7401 - val_accuracy: 0.8919
#
# Epoch 00429: val_accuracy did not improve from 0.94595
# Epoch 430/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.5626 - val_accuracy: 0.9392
#
# Epoch 00430: val_accuracy did not improve from 0.94595
# Epoch 431/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0093 - accuracy: 0.9942 - val_loss: 0.4801 - val_accuracy: 0.9324
#
# Epoch 00431: val_accuracy did not improve from 0.94595
# Epoch 432/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0193 - accuracy: 0.9963 - val_loss: 0.6773 - val_accuracy: 0.8986
#
# Epoch 00432: val_accuracy did not improve from 0.94595
# Epoch 433/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 0.6067 - val_accuracy: 0.9257
#
# Epoch 00433: val_accuracy did not improve from 0.94595
# Epoch 434/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.5312 - val_accuracy: 0.8986
#
# Epoch 00434: val_accuracy did not improve from 0.94595
# Epoch 435/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0023 - accuracy: 0.9984 - val_loss: 0.4491 - val_accuracy: 0.9122
#
# Epoch 00435: val_accuracy did not improve from 0.94595
# Epoch 436/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.6162 - val_accuracy: 0.9054
#
# Epoch 00436: val_accuracy did not improve from 0.94595
# Epoch 437/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.3347 - val_accuracy: 0.9324
#
# Epoch 00437: val_accuracy did not improve from 0.94595
# Epoch 438/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.7021 - val_accuracy: 0.8784
#
# Epoch 00438: val_accuracy did not improve from 0.94595
# Epoch 439/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0399 - accuracy: 0.9932 - val_loss: 0.6446 - val_accuracy: 0.8919
#
# Epoch 00439: val_accuracy did not improve from 0.94595
# Epoch 440/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0273 - accuracy: 0.9932 - val_loss: 0.5584 - val_accuracy: 0.8986
#
# Epoch 00440: val_accuracy did not improve from 0.94595
# Epoch 441/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.4454 - val_accuracy: 0.9122
#
# Epoch 00441: val_accuracy did not improve from 0.94595
# Epoch 442/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.5622 - val_accuracy: 0.8851
#
# Epoch 00442: val_accuracy did not improve from 0.94595
# Epoch 443/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.4799 - val_accuracy: 0.8851
#
# Epoch 00443: val_accuracy did not improve from 0.94595
# Epoch 444/500
# 238/238 [==============================] - 15s 63ms/step - loss: 9.1023e-04 - accuracy: 1.0000 - val_loss: 0.3849 - val_accuracy: 0.9324
#
# Epoch 00444: val_accuracy did not improve from 0.94595
# Epoch 445/500
# 238/238 [==============================] - 15s 64ms/step - loss: 4.3525e-04 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.9189
#
# Epoch 00445: val_accuracy did not improve from 0.94595
# Epoch 446/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.5162 - val_accuracy: 0.8851
#
# Epoch 00446: val_accuracy did not improve from 0.94595
# Epoch 447/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.9054
#
# Epoch 00447: val_accuracy did not improve from 0.94595
# Epoch 448/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4658 - val_accuracy: 0.8716
#
# Epoch 00448: val_accuracy did not improve from 0.94595
# Epoch 449/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.6834 - val_accuracy: 0.8851
#
# Epoch 00449: val_accuracy did not improve from 0.94595
# Epoch 450/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.6967 - val_accuracy: 0.8851
#
# Epoch 00450: val_accuracy did not improve from 0.94595
# Epoch 451/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.7470 - val_accuracy: 0.8851
#
# Epoch 00451: val_accuracy did not improve from 0.94595
# Epoch 452/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7091 - val_accuracy: 0.8851
#
# Epoch 00452: val_accuracy did not improve from 0.94595
# Epoch 453/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.4069 - val_accuracy: 0.9257
#
# Epoch 00453: val_accuracy did not improve from 0.94595
# Epoch 454/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 0.5329 - val_accuracy: 0.9122
#
# Epoch 00454: val_accuracy did not improve from 0.94595
# Epoch 455/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0204 - accuracy: 0.9953 - val_loss: 0.8347 - val_accuracy: 0.8581
#
# Epoch 00455: val_accuracy did not improve from 0.94595
# Epoch 456/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.5516 - val_accuracy: 0.8851
#
# Epoch 00456: val_accuracy did not improve from 0.94595
# Epoch 457/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.5899 - val_accuracy: 0.8851
#
# Epoch 00457: val_accuracy did not improve from 0.94595
# Epoch 458/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.4195 - val_accuracy: 0.9054
#
# Epoch 00458: val_accuracy did not improve from 0.94595
# Epoch 459/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0030 - accuracy: 0.9984 - val_loss: 0.4444 - val_accuracy: 0.9257
#
# Epoch 00459: val_accuracy did not improve from 0.94595
# Epoch 460/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0188 - accuracy: 0.9953 - val_loss: 0.2887 - val_accuracy: 0.9257
#
# Epoch 00460: val_accuracy did not improve from 0.94595
# Epoch 461/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.3664 - val_accuracy: 0.9324
#
# Epoch 00461: val_accuracy did not improve from 0.94595
# Epoch 462/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4344 - val_accuracy: 0.9189
#
# Epoch 00462: val_accuracy did not improve from 0.94595
# Epoch 463/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0155 - accuracy: 0.9968 - val_loss: 0.5095 - val_accuracy: 0.9122
#
# Epoch 00463: val_accuracy did not improve from 0.94595
# Epoch 464/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.6512 - val_accuracy: 0.9122
#
# Epoch 00464: val_accuracy did not improve from 0.94595
# Epoch 465/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.4242 - val_accuracy: 0.8986
#
# Epoch 00465: val_accuracy did not improve from 0.94595
# Epoch 466/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.4495 - val_accuracy: 0.9257
#
# Epoch 00466: val_accuracy did not improve from 0.94595
# Epoch 467/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4460 - val_accuracy: 0.9257
#
# Epoch 00467: val_accuracy did not improve from 0.94595
# Epoch 468/500
# 238/238 [==============================] - 15s 64ms/step - loss: 3.3937e-04 - accuracy: 1.0000 - val_loss: 0.4231 - val_accuracy: 0.9054
#
# Epoch 00468: val_accuracy did not improve from 0.94595
# Epoch 469/500
# 238/238 [==============================] - 15s 64ms/step - loss: 5.7901e-04 - accuracy: 1.0000 - val_loss: 0.4787 - val_accuracy: 0.9189
#
# Epoch 00469: val_accuracy did not improve from 0.94595
# Epoch 470/500
# 238/238 [==============================] - 15s 63ms/step - loss: 4.3250e-04 - accuracy: 1.0000 - val_loss: 0.4800 - val_accuracy: 0.9122
#
# Epoch 00470: val_accuracy did not improve from 0.94595
# Epoch 471/500
# 238/238 [==============================] - 15s 63ms/step - loss: 3.6488e-04 - accuracy: 1.0000 - val_loss: 0.4056 - val_accuracy: 0.9257
#
# Epoch 00471: val_accuracy did not improve from 0.94595
# Epoch 472/500
# 238/238 [==============================] - 15s 63ms/step - loss: 2.3818e-04 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.9257
#
# Epoch 00472: val_accuracy did not improve from 0.94595
# Epoch 473/500
# 238/238 [==============================] - 15s 64ms/step - loss: 1.7154e-04 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.9324
#
# Epoch 00473: val_accuracy did not improve from 0.94595
# Epoch 474/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.7040 - val_accuracy: 0.8986
#
# Epoch 00474: val_accuracy did not improve from 0.94595
# Epoch 475/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6468 - val_accuracy: 0.9122
#
# Epoch 00475: val_accuracy did not improve from 0.94595
# Epoch 476/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0521 - accuracy: 0.9895 - val_loss: 0.8640 - val_accuracy: 0.8514
#
# Epoch 00476: val_accuracy did not improve from 0.94595
# Epoch 477/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.4921 - val_accuracy: 0.8784
#
# Epoch 00477: val_accuracy did not improve from 0.94595
# Epoch 478/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.2825 - val_accuracy: 0.9324
#
# Epoch 00478: val_accuracy did not improve from 0.94595
# Epoch 479/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0060 - accuracy: 0.9968 - val_loss: 0.4778 - val_accuracy: 0.9054
#
# Epoch 00479: val_accuracy did not improve from 0.94595
# Epoch 480/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.5252 - val_accuracy: 0.9054
#
# Epoch 00480: val_accuracy did not improve from 0.94595
# Epoch 481/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 0.7320 - val_accuracy: 0.8716
#
# Epoch 00481: val_accuracy did not improve from 0.94595
# Epoch 482/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.9189
#
# Epoch 00482: val_accuracy did not improve from 0.94595
# Epoch 483/500
# 238/238 [==============================] - 15s 64ms/step - loss: 7.6068e-04 - accuracy: 1.0000 - val_loss: 0.5947 - val_accuracy: 0.8986
#
# Epoch 00483: val_accuracy did not improve from 0.94595
# Epoch 484/500
# 238/238 [==============================] - 15s 64ms/step - loss: 7.4274e-04 - accuracy: 1.0000 - val_loss: 0.4794 - val_accuracy: 0.9257
#
# Epoch 00484: val_accuracy did not improve from 0.94595
# Epoch 485/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.9054
#
# Epoch 00485: val_accuracy did not improve from 0.94595
# Epoch 486/500
# 238/238 [==============================] - 15s 63ms/step - loss: 3.4229e-04 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.9189
#
# Epoch 00486: val_accuracy did not improve from 0.94595
# Epoch 487/500
# 238/238 [==============================] - 15s 64ms/step - loss: 3.6895e-04 - accuracy: 1.0000 - val_loss: 0.4507 - val_accuracy: 0.9257
#
# Epoch 00487: val_accuracy did not improve from 0.94595
# Epoch 488/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.9189
#
# Epoch 00488: val_accuracy did not improve from 0.94595
# Epoch 489/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0456 - accuracy: 0.9900 - val_loss: 0.8823 - val_accuracy: 0.8716
#
# Epoch 00489: val_accuracy did not improve from 0.94595
# Epoch 490/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0441 - accuracy: 0.9874 - val_loss: 0.4316 - val_accuracy: 0.8986
#
# Epoch 00490: val_accuracy did not improve from 0.94595
# Epoch 491/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.7097 - val_accuracy: 0.8716
#
# Epoch 00491: val_accuracy did not improve from 0.94595
# Epoch 492/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.5337 - val_accuracy: 0.8919
#
# Epoch 00492: val_accuracy did not improve from 0.94595
# Epoch 493/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.3957 - val_accuracy: 0.9257
#
# Epoch 00493: val_accuracy did not improve from 0.94595
# Epoch 494/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0022 - accuracy: 0.9989 - val_loss: 0.6556 - val_accuracy: 0.8851
#
# Epoch 00494: val_accuracy did not improve from 0.94595
# Epoch 495/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0022 - accuracy: 0.9989 - val_loss: 0.4610 - val_accuracy: 0.8919
#
# Epoch 00495: val_accuracy did not improve from 0.94595
# Epoch 496/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.9578 - val_accuracy: 0.8581
#
# Epoch 00496: val_accuracy did not improve from 0.94595
# Epoch 497/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.6564 - val_accuracy: 0.8716
#
# Epoch 00497: val_accuracy did not improve from 0.94595
# Epoch 498/500
# 238/238 [==============================] - 15s 63ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.5014 - val_accuracy: 0.9324
#
# Epoch 00498: val_accuracy did not improve from 0.94595
# Epoch 499/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.5202 - val_accuracy: 0.9054
#
# Epoch 00499: val_accuracy did not improve from 0.94595
# Epoch 500/500
# 238/238 [==============================] - 15s 64ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.5713 - val_accuracy: 0.8851
#
# Epoch 00500: val_accuracy did not improve from 0.94595

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    # 'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # meanideal96@gamil.com
    'iDeal02',
    # dodo402298@gmail.com
    # 'mean01',
    # d9249.acc002@gmail.com
    # 'mean02',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': True, 'detail': 'Success'}
