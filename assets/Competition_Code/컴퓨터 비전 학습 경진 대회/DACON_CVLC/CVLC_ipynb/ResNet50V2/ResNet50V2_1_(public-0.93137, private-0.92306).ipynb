# %%
# !nvidia-smi
# Out:
# Sun Sep 26 09:44:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
model_save = 'ResNet50V2_1'
Target_model = 'ResNet50V2_model'
Target_predict = 'ResNet50V2_predict'
Target_acc = 'ResNet50V2_acc'
Target_val = 'ResNet50V2_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.ResNet50V2(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 37s 65ms/step - loss: 1.9449 - accuracy: 0.3305 - val_loss: 14.4352 - val_accuracy: 0.1014
#
# Epoch 00001: val_accuracy improved from -inf to 0.10135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 15s 61ms/step - loss: 1.3398 - accuracy: 0.5374 - val_loss: 2.2004 - val_accuracy: 0.3919
#
# Epoch 00002: val_accuracy improved from 0.10135 to 0.39189, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 3/500
# 238/238 [==============================] - 15s 61ms/step - loss: 1.0689 - accuracy: 0.6532 - val_loss: 2.0769 - val_accuracy: 0.4392
#
# Epoch 00003: val_accuracy improved from 0.39189 to 0.43919, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 4/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.9431 - accuracy: 0.6937 - val_loss: 2.1652 - val_accuracy: 0.5203
#
# Epoch 00004: val_accuracy improved from 0.43919 to 0.52027, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 5/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.8310 - accuracy: 0.7279 - val_loss: 1.6642 - val_accuracy: 0.6149
#
# Epoch 00005: val_accuracy improved from 0.52027 to 0.61486, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 6/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.7811 - accuracy: 0.7416 - val_loss: 1.3179 - val_accuracy: 0.6554
#
# Epoch 00006: val_accuracy improved from 0.61486 to 0.65541, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 7/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.7533 - accuracy: 0.7658 - val_loss: 3.2904 - val_accuracy: 0.4122
#
# Epoch 00007: val_accuracy did not improve from 0.65541
# Epoch 8/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.6326 - accuracy: 0.7905 - val_loss: 1.0145 - val_accuracy: 0.6554
#
# Epoch 00008: val_accuracy did not improve from 0.65541
# Epoch 9/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.5707 - accuracy: 0.8063 - val_loss: 1.4924 - val_accuracy: 0.6486
#
# Epoch 00009: val_accuracy did not improve from 0.65541
# Epoch 10/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.5242 - accuracy: 0.8284 - val_loss: 0.6657 - val_accuracy: 0.7973
#
# Epoch 00010: val_accuracy improved from 0.65541 to 0.79730, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 11/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.5558 - accuracy: 0.8205 - val_loss: 2.5863 - val_accuracy: 0.5068
#
# Epoch 00011: val_accuracy did not improve from 0.79730
# Epoch 12/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.5327 - accuracy: 0.8305 - val_loss: 1.0186 - val_accuracy: 0.6959
#
# Epoch 00012: val_accuracy did not improve from 0.79730
# Epoch 13/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.5088 - accuracy: 0.8426 - val_loss: 0.6949 - val_accuracy: 0.7703
#
# Epoch 00013: val_accuracy did not improve from 0.79730
# Epoch 14/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4397 - accuracy: 0.8563 - val_loss: 0.6172 - val_accuracy: 0.8041
#
# Epoch 00014: val_accuracy improved from 0.79730 to 0.80405, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 15/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.4537 - accuracy: 0.8532 - val_loss: 0.6654 - val_accuracy: 0.8176
#
# Epoch 00015: val_accuracy improved from 0.80405 to 0.81757, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 16/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4181 - accuracy: 0.8611 - val_loss: 0.6690 - val_accuracy: 0.7973
#
# Epoch 00016: val_accuracy did not improve from 0.81757
# Epoch 17/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4219 - accuracy: 0.8600 - val_loss: 1.2468 - val_accuracy: 0.6486
#
# Epoch 00017: val_accuracy did not improve from 0.81757
# Epoch 18/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.4397 - accuracy: 0.8489 - val_loss: 0.5687 - val_accuracy: 0.8108
#
# Epoch 00018: val_accuracy did not improve from 0.81757
# Epoch 19/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3552 - accuracy: 0.8737 - val_loss: 0.3750 - val_accuracy: 0.8851
#
# Epoch 00019: val_accuracy improved from 0.81757 to 0.88514, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 20/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3790 - accuracy: 0.8774 - val_loss: 0.6064 - val_accuracy: 0.8378
#
# Epoch 00020: val_accuracy did not improve from 0.88514
# Epoch 21/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3358 - accuracy: 0.8837 - val_loss: 0.3352 - val_accuracy: 0.8784
#
# Epoch 00021: val_accuracy did not improve from 0.88514
# Epoch 22/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3263 - accuracy: 0.8900 - val_loss: 0.4876 - val_accuracy: 0.8311
#
# Epoch 00022: val_accuracy did not improve from 0.88514
# Epoch 23/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3626 - accuracy: 0.8737 - val_loss: 0.4571 - val_accuracy: 0.8649
#
# Epoch 00023: val_accuracy did not improve from 0.88514
# Epoch 24/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.3202 - accuracy: 0.8968 - val_loss: 0.3795 - val_accuracy: 0.8716
#
# Epoch 00024: val_accuracy did not improve from 0.88514
# Epoch 25/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2909 - accuracy: 0.8963 - val_loss: 0.5235 - val_accuracy: 0.8176
#
# Epoch 00025: val_accuracy did not improve from 0.88514
# Epoch 26/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2497 - accuracy: 0.9205 - val_loss: 0.2989 - val_accuracy: 0.8851
#
# Epoch 00026: val_accuracy did not improve from 0.88514
# Epoch 27/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2589 - accuracy: 0.9142 - val_loss: 0.4814 - val_accuracy: 0.8446
#
# Epoch 00027: val_accuracy did not improve from 0.88514
# Epoch 28/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2781 - accuracy: 0.9095 - val_loss: 0.5358 - val_accuracy: 0.8176
#
# Epoch 00028: val_accuracy did not improve from 0.88514
# Epoch 29/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2328 - accuracy: 0.9263 - val_loss: 1.7295 - val_accuracy: 0.6419
#
# Epoch 00029: val_accuracy did not improve from 0.88514
# Epoch 30/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2636 - accuracy: 0.9168 - val_loss: 0.6167 - val_accuracy: 0.8108
#
# Epoch 00030: val_accuracy did not improve from 0.88514
# Epoch 31/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2088 - accuracy: 0.9342 - val_loss: 0.4048 - val_accuracy: 0.8986
#
# Epoch 00031: val_accuracy improved from 0.88514 to 0.89865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 32/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.2391 - accuracy: 0.9163 - val_loss: 0.4567 - val_accuracy: 0.8716
#
# Epoch 00032: val_accuracy did not improve from 0.89865
# Epoch 33/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2250 - accuracy: 0.9195 - val_loss: 2.8482 - val_accuracy: 0.5743
#
# Epoch 00033: val_accuracy did not improve from 0.89865
# Epoch 34/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2055 - accuracy: 0.9316 - val_loss: 0.5044 - val_accuracy: 0.8311
#
# Epoch 00034: val_accuracy did not improve from 0.89865
# Epoch 35/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2032 - accuracy: 0.9326 - val_loss: 6.2046 - val_accuracy: 0.3176
#
# Epoch 00035: val_accuracy did not improve from 0.89865
# Epoch 36/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2720 - accuracy: 0.9132 - val_loss: 0.4599 - val_accuracy: 0.8649
#
# Epoch 00036: val_accuracy did not improve from 0.89865
# Epoch 37/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1775 - accuracy: 0.9337 - val_loss: 0.4505 - val_accuracy: 0.8649
#
# Epoch 00037: val_accuracy did not improve from 0.89865
# Epoch 38/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2009 - accuracy: 0.9353 - val_loss: 0.6925 - val_accuracy: 0.8243
#
# Epoch 00038: val_accuracy did not improve from 0.89865
# Epoch 39/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1834 - accuracy: 0.9316 - val_loss: 0.4678 - val_accuracy: 0.8581
#
# Epoch 00039: val_accuracy did not improve from 0.89865
# Epoch 40/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1634 - accuracy: 0.9405 - val_loss: 4.8391 - val_accuracy: 0.3851
#
# Epoch 00040: val_accuracy did not improve from 0.89865
# Epoch 41/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1605 - accuracy: 0.9437 - val_loss: 0.3531 - val_accuracy: 0.9324
#
# Epoch 00041: val_accuracy improved from 0.89865 to 0.93243, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 42/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.2185 - accuracy: 0.9274 - val_loss: 0.4494 - val_accuracy: 0.8716
#
# Epoch 00042: val_accuracy did not improve from 0.93243
# Epoch 43/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1224 - accuracy: 0.9568 - val_loss: 0.4754 - val_accuracy: 0.8108
#
# Epoch 00043: val_accuracy did not improve from 0.93243
# Epoch 44/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1242 - accuracy: 0.9553 - val_loss: 0.6212 - val_accuracy: 0.8581
#
# Epoch 00044: val_accuracy did not improve from 0.93243
# Epoch 45/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1534 - accuracy: 0.9505 - val_loss: 0.4969 - val_accuracy: 0.8716
#
# Epoch 00045: val_accuracy did not improve from 0.93243
# Epoch 46/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1051 - accuracy: 0.9600 - val_loss: 0.3177 - val_accuracy: 0.8986
#
# Epoch 00046: val_accuracy did not improve from 0.93243
# Epoch 47/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1623 - accuracy: 0.9479 - val_loss: 0.3812 - val_accuracy: 0.8581
#
# Epoch 00047: val_accuracy did not improve from 0.93243
# Epoch 48/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1629 - accuracy: 0.9468 - val_loss: 0.4322 - val_accuracy: 0.8581
#
# Epoch 00048: val_accuracy did not improve from 0.93243
# Epoch 49/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1310 - accuracy: 0.9558 - val_loss: 0.4244 - val_accuracy: 0.8851
#
# Epoch 00049: val_accuracy did not improve from 0.93243
# Epoch 50/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1082 - accuracy: 0.9663 - val_loss: 0.3878 - val_accuracy: 0.9054
#
# Epoch 00050: val_accuracy did not improve from 0.93243
# Epoch 51/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1013 - accuracy: 0.9674 - val_loss: 0.3469 - val_accuracy: 0.8919
#
# Epoch 00051: val_accuracy did not improve from 0.93243
# Epoch 52/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0970 - accuracy: 0.9679 - val_loss: 0.4513 - val_accuracy: 0.8784
#
# Epoch 00052: val_accuracy did not improve from 0.93243
# Epoch 53/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1278 - accuracy: 0.9553 - val_loss: 0.6937 - val_accuracy: 0.8446
#
# Epoch 00053: val_accuracy did not improve from 0.93243
# Epoch 54/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1436 - accuracy: 0.9516 - val_loss: 0.9039 - val_accuracy: 0.7838
#
# Epoch 00054: val_accuracy did not improve from 0.93243
# Epoch 55/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1382 - accuracy: 0.9568 - val_loss: 0.4194 - val_accuracy: 0.8851
#
# Epoch 00055: val_accuracy did not improve from 0.93243
# Epoch 56/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1595 - accuracy: 0.9468 - val_loss: 0.5456 - val_accuracy: 0.8581
#
# Epoch 00056: val_accuracy did not improve from 0.93243
# Epoch 57/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0663 - accuracy: 0.9816 - val_loss: 0.3261 - val_accuracy: 0.9054
#
# Epoch 00057: val_accuracy did not improve from 0.93243
# Epoch 58/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0958 - accuracy: 0.9642 - val_loss: 0.6274 - val_accuracy: 0.8041
#
# Epoch 00058: val_accuracy did not improve from 0.93243
# Epoch 59/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1081 - accuracy: 0.9647 - val_loss: 2.0132 - val_accuracy: 0.6081
#
# Epoch 00059: val_accuracy did not improve from 0.93243
# Epoch 60/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1104 - accuracy: 0.9653 - val_loss: 0.4416 - val_accuracy: 0.8649
#
# Epoch 00060: val_accuracy did not improve from 0.93243
# Epoch 61/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0894 - accuracy: 0.9663 - val_loss: 0.5639 - val_accuracy: 0.8311
#
# Epoch 00061: val_accuracy did not improve from 0.93243
# Epoch 62/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1163 - accuracy: 0.9605 - val_loss: 0.4005 - val_accuracy: 0.8514
#
# Epoch 00062: val_accuracy did not improve from 0.93243
# Epoch 63/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0599 - accuracy: 0.9784 - val_loss: 0.4520 - val_accuracy: 0.9189
#
# Epoch 00063: val_accuracy did not improve from 0.93243
# Epoch 64/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1197 - accuracy: 0.9579 - val_loss: 0.5905 - val_accuracy: 0.8649
#
# Epoch 00064: val_accuracy did not improve from 0.93243
# Epoch 65/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1096 - accuracy: 0.9632 - val_loss: 1.9237 - val_accuracy: 0.6554
#
# Epoch 00065: val_accuracy did not improve from 0.93243
# Epoch 66/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0612 - accuracy: 0.9795 - val_loss: 0.4296 - val_accuracy: 0.8784
#
# Epoch 00066: val_accuracy did not improve from 0.93243
# Epoch 67/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1058 - accuracy: 0.9679 - val_loss: 0.8911 - val_accuracy: 0.8243
#
# Epoch 00067: val_accuracy did not improve from 0.93243
# Epoch 68/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0912 - accuracy: 0.9700 - val_loss: 0.7492 - val_accuracy: 0.8108
#
# Epoch 00068: val_accuracy did not improve from 0.93243
# Epoch 69/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0561 - accuracy: 0.9811 - val_loss: 0.4799 - val_accuracy: 0.8649
#
# Epoch 00069: val_accuracy did not improve from 0.93243
# Epoch 70/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0916 - accuracy: 0.9705 - val_loss: 0.4452 - val_accuracy: 0.8716
#
# Epoch 00070: val_accuracy did not improve from 0.93243
# Epoch 71/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0810 - accuracy: 0.9737 - val_loss: 0.5194 - val_accuracy: 0.8716
#
# Epoch 00071: val_accuracy did not improve from 0.93243
# Epoch 72/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.1012 - accuracy: 0.9674 - val_loss: 0.5269 - val_accuracy: 0.8784
#
# Epoch 00072: val_accuracy did not improve from 0.93243
# Epoch 73/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0685 - accuracy: 0.9816 - val_loss: 0.3971 - val_accuracy: 0.8986
#
# Epoch 00073: val_accuracy did not improve from 0.93243
# Epoch 74/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0406 - accuracy: 0.9874 - val_loss: 0.4239 - val_accuracy: 0.8986
#
# Epoch 00074: val_accuracy did not improve from 0.93243
# Epoch 75/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0955 - accuracy: 0.9721 - val_loss: 0.4485 - val_accuracy: 0.8784
#
# Epoch 00075: val_accuracy did not improve from 0.93243
# Epoch 76/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0481 - accuracy: 0.9868 - val_loss: 1.3274 - val_accuracy: 0.6689
#
# Epoch 00076: val_accuracy did not improve from 0.93243
# Epoch 77/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0746 - accuracy: 0.9753 - val_loss: 0.2980 - val_accuracy: 0.9054
#
# Epoch 00077: val_accuracy did not improve from 0.93243
# Epoch 78/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0578 - accuracy: 0.9789 - val_loss: 0.4527 - val_accuracy: 0.8919
#
# Epoch 00078: val_accuracy did not improve from 0.93243
# Epoch 79/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0696 - accuracy: 0.9758 - val_loss: 0.4437 - val_accuracy: 0.9122
#
# Epoch 00079: val_accuracy did not improve from 0.93243
# Epoch 80/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0498 - accuracy: 0.9832 - val_loss: 0.5129 - val_accuracy: 0.8649
#
# Epoch 00080: val_accuracy did not improve from 0.93243
# Epoch 81/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0527 - accuracy: 0.9805 - val_loss: 0.6427 - val_accuracy: 0.8851
#
# Epoch 00081: val_accuracy did not improve from 0.93243
# Epoch 82/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0567 - accuracy: 0.9847 - val_loss: 0.4817 - val_accuracy: 0.8716
#
# Epoch 00082: val_accuracy did not improve from 0.93243
# Epoch 83/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0768 - accuracy: 0.9742 - val_loss: 0.7147 - val_accuracy: 0.8446
#
# Epoch 00083: val_accuracy did not improve from 0.93243
# Epoch 84/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0665 - accuracy: 0.9774 - val_loss: 0.8086 - val_accuracy: 0.8446
#
# Epoch 00084: val_accuracy did not improve from 0.93243
# Epoch 85/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0780 - accuracy: 0.9711 - val_loss: 0.7103 - val_accuracy: 0.8378
#
# Epoch 00085: val_accuracy did not improve from 0.93243
# Epoch 86/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0572 - accuracy: 0.9795 - val_loss: 0.5672 - val_accuracy: 0.8514
#
# Epoch 00086: val_accuracy did not improve from 0.93243
# Epoch 87/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0803 - accuracy: 0.9726 - val_loss: 0.6130 - val_accuracy: 0.8581
#
# Epoch 00087: val_accuracy did not improve from 0.93243
# Epoch 88/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0770 - accuracy: 0.9742 - val_loss: 0.5620 - val_accuracy: 0.8649
#
# Epoch 00088: val_accuracy did not improve from 0.93243
# Epoch 89/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0369 - accuracy: 0.9868 - val_loss: 0.5479 - val_accuracy: 0.8243
#
# Epoch 00089: val_accuracy did not improve from 0.93243
# Epoch 90/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0303 - accuracy: 0.9900 - val_loss: 0.5871 - val_accuracy: 0.8986
#
# Epoch 00090: val_accuracy did not improve from 0.93243
# Epoch 91/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0457 - accuracy: 0.9874 - val_loss: 0.5229 - val_accuracy: 0.8784
#
# Epoch 00091: val_accuracy did not improve from 0.93243
# Epoch 92/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0544 - accuracy: 0.9837 - val_loss: 0.7443 - val_accuracy: 0.8514
#
# Epoch 00092: val_accuracy did not improve from 0.93243
# Epoch 93/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0582 - accuracy: 0.9795 - val_loss: 0.4730 - val_accuracy: 0.8784
#
# Epoch 00093: val_accuracy did not improve from 0.93243
# Epoch 94/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0489 - accuracy: 0.9837 - val_loss: 0.5903 - val_accuracy: 0.8649
#
# Epoch 00094: val_accuracy did not improve from 0.93243
# Epoch 95/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0333 - accuracy: 0.9874 - val_loss: 0.3654 - val_accuracy: 0.9054
#
# Epoch 00095: val_accuracy did not improve from 0.93243
# Epoch 96/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0359 - accuracy: 0.9889 - val_loss: 0.3277 - val_accuracy: 0.9054
#
# Epoch 00096: val_accuracy did not improve from 0.93243
# Epoch 97/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0464 - accuracy: 0.9837 - val_loss: 0.3612 - val_accuracy: 0.8851
#
# Epoch 00097: val_accuracy did not improve from 0.93243
# Epoch 98/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0214 - accuracy: 0.9953 - val_loss: 1.2291 - val_accuracy: 0.7770
#
# Epoch 00098: val_accuracy did not improve from 0.93243
# Epoch 99/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0864 - accuracy: 0.9700 - val_loss: 0.5274 - val_accuracy: 0.8784
#
# Epoch 00099: val_accuracy did not improve from 0.93243
# Epoch 100/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0832 - accuracy: 0.9732 - val_loss: 0.4014 - val_accuracy: 0.8986
#
# Epoch 00100: val_accuracy did not improve from 0.93243
# Epoch 101/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0478 - accuracy: 0.9842 - val_loss: 0.4762 - val_accuracy: 0.8851
#
# Epoch 00101: val_accuracy did not improve from 0.93243
# Epoch 102/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0565 - accuracy: 0.9758 - val_loss: 0.4278 - val_accuracy: 0.8784
#
# Epoch 00102: val_accuracy did not improve from 0.93243
# Epoch 103/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0296 - accuracy: 0.9921 - val_loss: 0.3920 - val_accuracy: 0.8986
#
# Epoch 00103: val_accuracy did not improve from 0.93243
# Epoch 104/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0332 - accuracy: 0.9884 - val_loss: 0.5557 - val_accuracy: 0.8784
#
# Epoch 00104: val_accuracy did not improve from 0.93243
# Epoch 105/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0399 - accuracy: 0.9863 - val_loss: 0.2854 - val_accuracy: 0.9189
#
# Epoch 00105: val_accuracy did not improve from 0.93243
# Epoch 106/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0328 - accuracy: 0.9905 - val_loss: 0.4652 - val_accuracy: 0.8649
#
# Epoch 00106: val_accuracy did not improve from 0.93243
# Epoch 107/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0385 - accuracy: 0.9837 - val_loss: 0.5734 - val_accuracy: 0.8784
#
# Epoch 00107: val_accuracy did not improve from 0.93243
# Epoch 108/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0933 - accuracy: 0.9721 - val_loss: 0.5343 - val_accuracy: 0.8716
#
# Epoch 00108: val_accuracy did not improve from 0.93243
# Epoch 109/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0615 - accuracy: 0.9789 - val_loss: 0.3643 - val_accuracy: 0.9257
#
# Epoch 00109: val_accuracy did not improve from 0.93243
# Epoch 110/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0210 - accuracy: 0.9921 - val_loss: 0.2003 - val_accuracy: 0.9324
#
# Epoch 00110: val_accuracy did not improve from 0.93243
# Epoch 111/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.3920 - val_accuracy: 0.8716
#
# Epoch 00111: val_accuracy did not improve from 0.93243
# Epoch 112/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0255 - accuracy: 0.9932 - val_loss: 0.5254 - val_accuracy: 0.8851
#
# Epoch 00112: val_accuracy did not improve from 0.93243
# Epoch 113/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0398 - accuracy: 0.9889 - val_loss: 0.4936 - val_accuracy: 0.8649
#
# Epoch 00113: val_accuracy did not improve from 0.93243
# Epoch 114/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0521 - accuracy: 0.9837 - val_loss: 0.5423 - val_accuracy: 0.8986
#
# Epoch 00114: val_accuracy did not improve from 0.93243
# Epoch 115/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0315 - accuracy: 0.9889 - val_loss: 0.5960 - val_accuracy: 0.8986
#
# Epoch 00115: val_accuracy did not improve from 0.93243
# Epoch 116/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0334 - accuracy: 0.9884 - val_loss: 0.6088 - val_accuracy: 0.8446
#
# Epoch 00116: val_accuracy did not improve from 0.93243
# Epoch 117/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0742 - accuracy: 0.9784 - val_loss: 0.5435 - val_accuracy: 0.8716
#
# Epoch 00117: val_accuracy did not improve from 0.93243
# Epoch 118/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0555 - accuracy: 0.9826 - val_loss: 0.4168 - val_accuracy: 0.8784
#
# Epoch 00118: val_accuracy did not improve from 0.93243
# Epoch 119/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 0.4977 - val_accuracy: 0.8919
#
# Epoch 00119: val_accuracy did not improve from 0.93243
# Epoch 120/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0362 - accuracy: 0.9868 - val_loss: 0.6137 - val_accuracy: 0.8784
#
# Epoch 00120: val_accuracy did not improve from 0.93243
# Epoch 121/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0450 - accuracy: 0.9842 - val_loss: 0.4921 - val_accuracy: 0.8649
#
# Epoch 00121: val_accuracy did not improve from 0.93243
# Epoch 122/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0352 - accuracy: 0.9895 - val_loss: 0.4918 - val_accuracy: 0.8986
#
# Epoch 00122: val_accuracy did not improve from 0.93243
# Epoch 123/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0282 - accuracy: 0.9932 - val_loss: 0.4789 - val_accuracy: 0.9122
#
# Epoch 00123: val_accuracy did not improve from 0.93243
# Epoch 124/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0280 - accuracy: 0.9932 - val_loss: 0.4218 - val_accuracy: 0.9122
#
# Epoch 00124: val_accuracy did not improve from 0.93243
# Epoch 125/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0307 - accuracy: 0.9916 - val_loss: 0.4906 - val_accuracy: 0.8514
#
# Epoch 00125: val_accuracy did not improve from 0.93243
# Epoch 126/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0557 - accuracy: 0.9821 - val_loss: 1.5548 - val_accuracy: 0.7027
#
# Epoch 00126: val_accuracy did not improve from 0.93243
# Epoch 127/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0453 - accuracy: 0.9842 - val_loss: 0.2791 - val_accuracy: 0.9122
#
# Epoch 00127: val_accuracy did not improve from 0.93243
# Epoch 128/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0399 - accuracy: 0.9874 - val_loss: 0.4472 - val_accuracy: 0.8851
#
# Epoch 00128: val_accuracy did not improve from 0.93243
# Epoch 129/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0491 - accuracy: 0.9842 - val_loss: 0.4050 - val_accuracy: 0.8851
#
# Epoch 00129: val_accuracy did not improve from 0.93243
# Epoch 130/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 0.5006 - val_accuracy: 0.8716
#
# Epoch 00130: val_accuracy did not improve from 0.93243
# Epoch 131/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0376 - accuracy: 0.9895 - val_loss: 0.4758 - val_accuracy: 0.8919
#
# Epoch 00131: val_accuracy did not improve from 0.93243
# Epoch 132/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0393 - accuracy: 0.9884 - val_loss: 0.4986 - val_accuracy: 0.8986
#
# Epoch 00132: val_accuracy did not improve from 0.93243
# Epoch 133/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0426 - accuracy: 0.9832 - val_loss: 0.3616 - val_accuracy: 0.9189
#
# Epoch 00133: val_accuracy did not improve from 0.93243
# Epoch 134/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0312 - accuracy: 0.9900 - val_loss: 0.5074 - val_accuracy: 0.8784
#
# Epoch 00134: val_accuracy did not improve from 0.93243
# Epoch 135/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0135 - accuracy: 0.9953 - val_loss: 0.4114 - val_accuracy: 0.8784
#
# Epoch 00135: val_accuracy did not improve from 0.93243
# Epoch 136/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.6639 - val_accuracy: 0.8446
#
# Epoch 00136: val_accuracy did not improve from 0.93243
# Epoch 137/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0259 - accuracy: 0.9905 - val_loss: 0.4158 - val_accuracy: 0.8784
#
# Epoch 00137: val_accuracy did not improve from 0.93243
# Epoch 138/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0281 - accuracy: 0.9916 - val_loss: 0.6630 - val_accuracy: 0.8716
#
# Epoch 00138: val_accuracy did not improve from 0.93243
# Epoch 139/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0570 - accuracy: 0.9858 - val_loss: 0.4487 - val_accuracy: 0.8649
#
# Epoch 00139: val_accuracy did not improve from 0.93243
# Epoch 140/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0331 - accuracy: 0.9895 - val_loss: 0.6291 - val_accuracy: 0.8514
#
# Epoch 00140: val_accuracy did not improve from 0.93243
# Epoch 141/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.4049 - val_accuracy: 0.8986
#
# Epoch 00141: val_accuracy did not improve from 0.93243
# Epoch 142/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0200 - accuracy: 0.9947 - val_loss: 0.5098 - val_accuracy: 0.9054
#
# Epoch 00142: val_accuracy did not improve from 0.93243
# Epoch 143/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0196 - accuracy: 0.9932 - val_loss: 0.5017 - val_accuracy: 0.8851
#
# Epoch 00143: val_accuracy did not improve from 0.93243
# Epoch 144/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0405 - accuracy: 0.9884 - val_loss: 0.4611 - val_accuracy: 0.8851
#
# Epoch 00144: val_accuracy did not improve from 0.93243
# Epoch 145/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0493 - accuracy: 0.9847 - val_loss: 0.4108 - val_accuracy: 0.8919
#
# Epoch 00145: val_accuracy did not improve from 0.93243
# Epoch 146/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0381 - accuracy: 0.9863 - val_loss: 0.3879 - val_accuracy: 0.9054
#
# Epoch 00146: val_accuracy did not improve from 0.93243
# Epoch 147/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0398 - accuracy: 0.9879 - val_loss: 0.5995 - val_accuracy: 0.8851
#
# Epoch 00147: val_accuracy did not improve from 0.93243
# Epoch 148/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0279 - accuracy: 0.9911 - val_loss: 0.6872 - val_accuracy: 0.8581
#
# Epoch 00148: val_accuracy did not improve from 0.93243
# Epoch 149/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0095 - accuracy: 0.9979 - val_loss: 0.4382 - val_accuracy: 0.8851
#
# Epoch 00149: val_accuracy did not improve from 0.93243
# Epoch 150/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0233 - accuracy: 0.9937 - val_loss: 0.6916 - val_accuracy: 0.8514
#
# Epoch 00150: val_accuracy did not improve from 0.93243
# Epoch 151/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0353 - accuracy: 0.9884 - val_loss: 0.4109 - val_accuracy: 0.9122
#
# Epoch 00151: val_accuracy did not improve from 0.93243
# Epoch 152/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0339 - accuracy: 0.9900 - val_loss: 0.5079 - val_accuracy: 0.8446
#
# Epoch 00152: val_accuracy did not improve from 0.93243
# Epoch 153/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.5436 - val_accuracy: 0.8919
#
# Epoch 00153: val_accuracy did not improve from 0.93243
# Epoch 154/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0121 - accuracy: 0.9974 - val_loss: 0.4371 - val_accuracy: 0.8986
#
# Epoch 00154: val_accuracy did not improve from 0.93243
# Epoch 155/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0242 - accuracy: 0.9905 - val_loss: 0.3518 - val_accuracy: 0.9122
#
# Epoch 00155: val_accuracy did not improve from 0.93243
# Epoch 156/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0369 - accuracy: 0.9884 - val_loss: 1.7191 - val_accuracy: 0.7162
#
# Epoch 00156: val_accuracy did not improve from 0.93243
# Epoch 157/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0288 - accuracy: 0.9921 - val_loss: 0.3991 - val_accuracy: 0.8919
#
# Epoch 00157: val_accuracy did not improve from 0.93243
# Epoch 158/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0210 - accuracy: 0.9900 - val_loss: 0.5378 - val_accuracy: 0.8851
#
# Epoch 00158: val_accuracy did not improve from 0.93243
# Epoch 159/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0158 - accuracy: 0.9932 - val_loss: 0.4036 - val_accuracy: 0.9054
#
# Epoch 00159: val_accuracy did not improve from 0.93243
# Epoch 160/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0208 - accuracy: 0.9942 - val_loss: 0.6515 - val_accuracy: 0.8784
#
# Epoch 00160: val_accuracy did not improve from 0.93243
# Epoch 161/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 0.5146 - val_accuracy: 0.8716
#
# Epoch 00161: val_accuracy did not improve from 0.93243
# Epoch 162/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0201 - accuracy: 0.9905 - val_loss: 0.7313 - val_accuracy: 0.8581
#
# Epoch 00162: val_accuracy did not improve from 0.93243
# Epoch 163/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0432 - accuracy: 0.9842 - val_loss: 0.8693 - val_accuracy: 0.8514
#
# Epoch 00163: val_accuracy did not improve from 0.93243
# Epoch 164/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0268 - accuracy: 0.9947 - val_loss: 0.4129 - val_accuracy: 0.8851
#
# Epoch 00164: val_accuracy did not improve from 0.93243
# Epoch 165/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.5111 - val_accuracy: 0.8784
#
# Epoch 00165: val_accuracy did not improve from 0.93243
# Epoch 166/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0309 - accuracy: 0.9916 - val_loss: 0.4399 - val_accuracy: 0.9054
#
# Epoch 00166: val_accuracy did not improve from 0.93243
# Epoch 167/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0263 - accuracy: 0.9921 - val_loss: 0.5889 - val_accuracy: 0.8649
#
# Epoch 00167: val_accuracy did not improve from 0.93243
# Epoch 168/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.4821 - val_accuracy: 0.8919
#
# Epoch 00168: val_accuracy did not improve from 0.93243
# Epoch 169/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.3954 - val_accuracy: 0.9054
#
# Epoch 00169: val_accuracy did not improve from 0.93243
# Epoch 170/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.5753 - val_accuracy: 0.8581
#
# Epoch 00170: val_accuracy did not improve from 0.93243
# Epoch 171/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0345 - accuracy: 0.9905 - val_loss: 0.7663 - val_accuracy: 0.8581
#
# Epoch 00171: val_accuracy did not improve from 0.93243
# Epoch 172/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0825 - accuracy: 0.9737 - val_loss: 0.4921 - val_accuracy: 0.9054
#
# Epoch 00172: val_accuracy did not improve from 0.93243
# Epoch 173/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 0.3100 - val_accuracy: 0.9054
#
# Epoch 00173: val_accuracy did not improve from 0.93243
# Epoch 174/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.2966 - val_accuracy: 0.9324
#
# Epoch 00174: val_accuracy did not improve from 0.93243
# Epoch 175/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.3488 - val_accuracy: 0.9257
#
# Epoch 00175: val_accuracy did not improve from 0.93243
# Epoch 176/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.4542 - val_accuracy: 0.8986
#
# Epoch 00176: val_accuracy did not improve from 0.93243
# Epoch 177/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0280 - accuracy: 0.9916 - val_loss: 0.4156 - val_accuracy: 0.9189
#
# Epoch 00177: val_accuracy did not improve from 0.93243
# Epoch 178/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.4953 - val_accuracy: 0.9189
#
# Epoch 00178: val_accuracy did not improve from 0.93243
# Epoch 179/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.3900 - val_accuracy: 0.9189
#
# Epoch 00179: val_accuracy did not improve from 0.93243
# Epoch 180/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.5031 - val_accuracy: 0.9122
#
# Epoch 00180: val_accuracy did not improve from 0.93243
# Epoch 181/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0376 - accuracy: 0.9884 - val_loss: 0.4867 - val_accuracy: 0.8649
#
# Epoch 00181: val_accuracy did not improve from 0.93243
# Epoch 182/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0256 - accuracy: 0.9895 - val_loss: 0.5201 - val_accuracy: 0.8919
#
# Epoch 00182: val_accuracy did not improve from 0.93243
# Epoch 183/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0309 - accuracy: 0.9905 - val_loss: 0.5284 - val_accuracy: 0.8986
#
# Epoch 00183: val_accuracy did not improve from 0.93243
# Epoch 184/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0303 - accuracy: 0.9916 - val_loss: 0.5155 - val_accuracy: 0.8919
#
# Epoch 00184: val_accuracy did not improve from 0.93243
# Epoch 185/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.4198 - val_accuracy: 0.9054
#
# Epoch 00185: val_accuracy did not improve from 0.93243
# Epoch 186/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.3606 - val_accuracy: 0.8986
#
# Epoch 00186: val_accuracy did not improve from 0.93243
# Epoch 187/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.3117 - val_accuracy: 0.8986
#
# Epoch 00187: val_accuracy did not improve from 0.93243
# Epoch 188/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.4381 - val_accuracy: 0.9257
#
# Epoch 00188: val_accuracy did not improve from 0.93243
# Epoch 189/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0524 - accuracy: 0.9805 - val_loss: 1.1681 - val_accuracy: 0.7568
#
# Epoch 00189: val_accuracy did not improve from 0.93243
# Epoch 190/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.4572 - val_accuracy: 0.8919
#
# Epoch 00190: val_accuracy did not improve from 0.93243
# Epoch 191/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.4111 - val_accuracy: 0.9257
#
# Epoch 00191: val_accuracy did not improve from 0.93243
# Epoch 192/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.4100 - val_accuracy: 0.9257
#
# Epoch 00192: val_accuracy did not improve from 0.93243
# Epoch 193/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.4035 - val_accuracy: 0.9054
#
# Epoch 00193: val_accuracy did not improve from 0.93243
# Epoch 194/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.8925 - val_accuracy: 0.8243
#
# Epoch 00194: val_accuracy did not improve from 0.93243
# Epoch 195/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0852 - accuracy: 0.9742 - val_loss: 0.6461 - val_accuracy: 0.8514
#
# Epoch 00195: val_accuracy did not improve from 0.93243
# Epoch 196/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.3014 - val_accuracy: 0.9459
#
# Epoch 00196: val_accuracy improved from 0.93243 to 0.94595, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 197/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.4724 - val_accuracy: 0.8649
#
# Epoch 00197: val_accuracy did not improve from 0.94595
# Epoch 198/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0322 - accuracy: 0.9916 - val_loss: 0.3424 - val_accuracy: 0.9122
#
# Epoch 00198: val_accuracy did not improve from 0.94595
# Epoch 199/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.4513 - val_accuracy: 0.8851
#
# Epoch 00199: val_accuracy did not improve from 0.94595
# Epoch 200/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0126 - accuracy: 0.9947 - val_loss: 0.4600 - val_accuracy: 0.8716
#
# Epoch 00200: val_accuracy did not improve from 0.94595
# Epoch 201/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.5121 - val_accuracy: 0.8716
#
# Epoch 00201: val_accuracy did not improve from 0.94595
# Epoch 202/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0118 - accuracy: 0.9974 - val_loss: 0.8620 - val_accuracy: 0.8514
#
# Epoch 00202: val_accuracy did not improve from 0.94595
# Epoch 203/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.4619 - val_accuracy: 0.8851
#
# Epoch 00203: val_accuracy did not improve from 0.94595
# Epoch 204/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0218 - accuracy: 0.9905 - val_loss: 0.4047 - val_accuracy: 0.9122
#
# Epoch 00204: val_accuracy did not improve from 0.94595
# Epoch 205/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0361 - accuracy: 0.9879 - val_loss: 0.5866 - val_accuracy: 0.8649
#
# Epoch 00205: val_accuracy did not improve from 0.94595
# Epoch 206/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0173 - accuracy: 0.9958 - val_loss: 0.8425 - val_accuracy: 0.8581
#
# Epoch 00206: val_accuracy did not improve from 0.94595
# Epoch 207/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.3773 - val_accuracy: 0.8919
#
# Epoch 00207: val_accuracy did not improve from 0.94595
# Epoch 208/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.3286 - val_accuracy: 0.8986
#
# Epoch 00208: val_accuracy did not improve from 0.94595
# Epoch 209/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.6267 - val_accuracy: 0.8649
#
# Epoch 00209: val_accuracy did not improve from 0.94595
# Epoch 210/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0231 - accuracy: 0.9916 - val_loss: 0.4602 - val_accuracy: 0.9189
#
# Epoch 00210: val_accuracy did not improve from 0.94595
# Epoch 211/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0226 - accuracy: 0.9905 - val_loss: 0.4018 - val_accuracy: 0.8986
#
# Epoch 00211: val_accuracy did not improve from 0.94595
# Epoch 212/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.3806 - val_accuracy: 0.8919
#
# Epoch 00212: val_accuracy did not improve from 0.94595
# Epoch 213/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0102 - accuracy: 0.9963 - val_loss: 0.3383 - val_accuracy: 0.9054
#
# Epoch 00213: val_accuracy did not improve from 0.94595
# Epoch 214/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.4427 - val_accuracy: 0.9324
#
# Epoch 00214: val_accuracy did not improve from 0.94595
# Epoch 215/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0226 - accuracy: 0.9926 - val_loss: 0.3593 - val_accuracy: 0.9189
#
# Epoch 00215: val_accuracy did not improve from 0.94595
# Epoch 216/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.4631 - val_accuracy: 0.8986
#
# Epoch 00216: val_accuracy did not improve from 0.94595
# Epoch 217/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 0.4749 - val_accuracy: 0.9122
#
# Epoch 00217: val_accuracy did not improve from 0.94595
# Epoch 218/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0132 - accuracy: 0.9947 - val_loss: 0.3974 - val_accuracy: 0.9257
#
# Epoch 00218: val_accuracy did not improve from 0.94595
# Epoch 219/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.8674 - val_accuracy: 0.8514
#
# Epoch 00219: val_accuracy did not improve from 0.94595
# Epoch 220/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0244 - accuracy: 0.9905 - val_loss: 0.4074 - val_accuracy: 0.9189
#
# Epoch 00220: val_accuracy did not improve from 0.94595
# Epoch 221/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 0.3477 - val_accuracy: 0.9459
#
# Epoch 00221: val_accuracy did not improve from 0.94595
# Epoch 222/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0333 - accuracy: 0.9895 - val_loss: 0.7167 - val_accuracy: 0.8716
#
# Epoch 00222: val_accuracy did not improve from 0.94595
# Epoch 223/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.6934 - val_accuracy: 0.8716
#
# Epoch 00223: val_accuracy did not improve from 0.94595
# Epoch 224/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0196 - accuracy: 0.9926 - val_loss: 0.3099 - val_accuracy: 0.9189
#
# Epoch 00224: val_accuracy did not improve from 0.94595
# Epoch 225/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0234 - accuracy: 0.9916 - val_loss: 0.5147 - val_accuracy: 0.9189
#
# Epoch 00225: val_accuracy did not improve from 0.94595
# Epoch 226/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0197 - accuracy: 0.9932 - val_loss: 0.3236 - val_accuracy: 0.9392
#
# Epoch 00226: val_accuracy did not improve from 0.94595
# Epoch 227/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.2489 - val_accuracy: 0.9527
#
# Epoch 00227: val_accuracy improved from 0.94595 to 0.95270, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 228/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.3441 - val_accuracy: 0.9257
#
# Epoch 00228: val_accuracy did not improve from 0.95270
# Epoch 229/500
# ...
# Epoch 423/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.6001 - val_accuracy: 0.9054
#
# Epoch 00423: val_accuracy did not improve from 0.95270
# Epoch 424/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.4144 - val_accuracy: 0.9122
#
# Epoch 00424: val_accuracy did not improve from 0.95270
# Epoch 425/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.4580 - val_accuracy: 0.9054
#
# Epoch 00425: val_accuracy did not improve from 0.95270
# Epoch 426/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.6411 - val_accuracy: 0.9054
#
# Epoch 00426: val_accuracy did not improve from 0.95270
# Epoch 427/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.2649 - val_accuracy: 0.9257
#
# Epoch 00427: val_accuracy did not improve from 0.95270
# Epoch 428/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3423 - val_accuracy: 0.9459
#
# Epoch 00428: val_accuracy did not improve from 0.95270
# Epoch 429/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.4792 - val_accuracy: 0.9054
#
# Epoch 00429: val_accuracy did not improve from 0.95270
# Epoch 430/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0125 - accuracy: 0.9968 - val_loss: 0.3953 - val_accuracy: 0.9257
#
# Epoch 00430: val_accuracy did not improve from 0.95270
# Epoch 431/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.5444 - val_accuracy: 0.8986
#
# Epoch 00431: val_accuracy did not improve from 0.95270
# Epoch 432/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0283 - accuracy: 0.9905 - val_loss: 0.5816 - val_accuracy: 0.8986
#
# Epoch 00432: val_accuracy did not improve from 0.95270
# Epoch 433/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.6779 - val_accuracy: 0.9054
#
# Epoch 00433: val_accuracy did not improve from 0.95270
# Epoch 434/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0183 - accuracy: 0.9932 - val_loss: 0.5701 - val_accuracy: 0.8986
#
# Epoch 00434: val_accuracy did not improve from 0.95270
# Epoch 435/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 0.4059 - val_accuracy: 0.9054
#
# Epoch 00435: val_accuracy did not improve from 0.95270
# Epoch 436/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.4605 - val_accuracy: 0.9122
#
# Epoch 00436: val_accuracy did not improve from 0.95270
# Epoch 437/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0033 - accuracy: 0.9984 - val_loss: 0.5456 - val_accuracy: 0.9122
#
# Epoch 00437: val_accuracy did not improve from 0.95270
# Epoch 438/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0029 - accuracy: 0.9979 - val_loss: 0.4703 - val_accuracy: 0.9054
#
# Epoch 00438: val_accuracy did not improve from 0.95270
# Epoch 439/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0146 - accuracy: 0.9974 - val_loss: 0.4722 - val_accuracy: 0.9054
#
# Epoch 00439: val_accuracy did not improve from 0.95270
# Epoch 440/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.3847 - val_accuracy: 0.9122
#
# Epoch 00440: val_accuracy did not improve from 0.95270
# Epoch 441/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.5324 - val_accuracy: 0.8986
#
# Epoch 00441: val_accuracy did not improve from 0.95270
# Epoch 442/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.4052 - val_accuracy: 0.9054
#
# Epoch 00442: val_accuracy did not improve from 0.95270
# Epoch 443/500
# 238/238 [==============================] - 14s 60ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8986
#
# Epoch 00443: val_accuracy did not improve from 0.95270
# Epoch 444/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.5366 - val_accuracy: 0.9122
#
# Epoch 00444: val_accuracy did not improve from 0.95270
# Epoch 445/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0449 - accuracy: 0.9921 - val_loss: 0.8696 - val_accuracy: 0.8446
#
# Epoch 00445: val_accuracy did not improve from 0.95270
# Epoch 446/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.4967 - val_accuracy: 0.8919
#
# Epoch 00446: val_accuracy did not improve from 0.95270
# Epoch 447/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.3148 - val_accuracy: 0.9189
#
# Epoch 00447: val_accuracy did not improve from 0.95270
# Epoch 448/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.4503 - val_accuracy: 0.9054
#
# Epoch 00448: val_accuracy did not improve from 0.95270
# Epoch 449/500
# 238/238 [==============================] - 15s 61ms/step - loss: 8.2631e-04 - accuracy: 1.0000 - val_loss: 0.4484 - val_accuracy: 0.8986
#
# Epoch 00449: val_accuracy did not improve from 0.95270
# Epoch 450/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.4521 - val_accuracy: 0.9189
#
# Epoch 00450: val_accuracy did not improve from 0.95270
# Epoch 451/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.5776 - val_accuracy: 0.8919
#
# Epoch 00451: val_accuracy did not improve from 0.95270
# Epoch 452/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0047 - accuracy: 0.9968 - val_loss: 0.5654 - val_accuracy: 0.9122
#
# Epoch 00452: val_accuracy did not improve from 0.95270
# Epoch 453/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0100 - accuracy: 0.9979 - val_loss: 0.5126 - val_accuracy: 0.9054
#
# Epoch 00453: val_accuracy did not improve from 0.95270
# Epoch 454/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0245 - accuracy: 0.9911 - val_loss: 0.6563 - val_accuracy: 0.8851
#
# Epoch 00454: val_accuracy did not improve from 0.95270
# Epoch 455/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.4214 - val_accuracy: 0.9257
#
# Epoch 00455: val_accuracy did not improve from 0.95270
# Epoch 456/500
# 238/238 [==============================] - 14s 61ms/step - loss: 8.2838e-04 - accuracy: 1.0000 - val_loss: 0.5921 - val_accuracy: 0.9054
#
# Epoch 00456: val_accuracy did not improve from 0.95270
# Epoch 457/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.3509 - val_accuracy: 0.9189
#
# Epoch 00457: val_accuracy did not improve from 0.95270
# Epoch 458/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.5183 - val_accuracy: 0.9189
#
# Epoch 00458: val_accuracy did not improve from 0.95270
# Epoch 459/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 0.5490 - val_accuracy: 0.9054
#
# Epoch 00459: val_accuracy did not improve from 0.95270
# Epoch 460/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.4452 - val_accuracy: 0.9122
#
# Epoch 00460: val_accuracy did not improve from 0.95270
# Epoch 461/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.6030 - val_accuracy: 0.9054
#
# Epoch 00461: val_accuracy did not improve from 0.95270
# Epoch 462/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.6587 - val_accuracy: 0.9189
#
# Epoch 00462: val_accuracy did not improve from 0.95270
# Epoch 463/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0031 - accuracy: 0.9995 - val_loss: 0.4057 - val_accuracy: 0.9122
#
# Epoch 00463: val_accuracy did not improve from 0.95270
# Epoch 464/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.3343 - val_accuracy: 0.9324
#
# Epoch 00464: val_accuracy did not improve from 0.95270
# Epoch 465/500
# 238/238 [==============================] - 14s 61ms/step - loss: 4.1198e-04 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9324
#
# Epoch 00465: val_accuracy did not improve from 0.95270
# Epoch 466/500
# 238/238 [==============================] - 14s 61ms/step - loss: 2.2583e-04 - accuracy: 1.0000 - val_loss: 0.2868 - val_accuracy: 0.9595
#
# Epoch 00466: val_accuracy improved from 0.95270 to 0.95946, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/ResNet50V2_1.h5
# Epoch 467/500
# 238/238 [==============================] - 15s 61ms/step - loss: 4.8527e-04 - accuracy: 1.0000 - val_loss: 0.3325 - val_accuracy: 0.9527
#
# Epoch 00467: val_accuracy did not improve from 0.95946
# Epoch 468/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.3500 - val_accuracy: 0.9189
#
# Epoch 00468: val_accuracy did not improve from 0.95946
# Epoch 469/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.9189
#
# Epoch 00469: val_accuracy did not improve from 0.95946
# Epoch 470/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0418 - accuracy: 0.9900 - val_loss: 0.7521 - val_accuracy: 0.8851
#
# Epoch 00470: val_accuracy did not improve from 0.95946
# Epoch 471/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.6473 - val_accuracy: 0.8581
#
# Epoch 00471: val_accuracy did not improve from 0.95946
# Epoch 472/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.4855 - val_accuracy: 0.9054
#
# Epoch 00472: val_accuracy did not improve from 0.95946
# Epoch 473/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.6438 - val_accuracy: 0.8986
#
# Epoch 00473: val_accuracy did not improve from 0.95946
# Epoch 474/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0021 - accuracy: 0.9989 - val_loss: 0.5782 - val_accuracy: 0.9122
#
# Epoch 00474: val_accuracy did not improve from 0.95946
# Epoch 475/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0053 - accuracy: 0.9968 - val_loss: 0.3837 - val_accuracy: 0.9257
#
# Epoch 00475: val_accuracy did not improve from 0.95946
# Epoch 476/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.5910 - val_accuracy: 0.8986
#
# Epoch 00476: val_accuracy did not improve from 0.95946
# Epoch 477/500
# 238/238 [==============================] - 14s 61ms/step - loss: 6.6882e-04 - accuracy: 1.0000 - val_loss: 0.5628 - val_accuracy: 0.8986
#
# Epoch 00477: val_accuracy did not improve from 0.95946
# Epoch 478/500
# 238/238 [==============================] - 15s 61ms/step - loss: 8.0860e-04 - accuracy: 1.0000 - val_loss: 0.5519 - val_accuracy: 0.8784
#
# Epoch 00478: val_accuracy did not improve from 0.95946
# Epoch 479/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.6569 - val_accuracy: 0.8919
#
# Epoch 00479: val_accuracy did not improve from 0.95946
# Epoch 480/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.5095 - val_accuracy: 0.8851
#
# Epoch 00480: val_accuracy did not improve from 0.95946
# Epoch 481/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.9324
#
# Epoch 00481: val_accuracy did not improve from 0.95946
# Epoch 482/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.5178 - val_accuracy: 0.9257
#
# Epoch 00482: val_accuracy did not improve from 0.95946
# Epoch 483/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0061 - accuracy: 0.9968 - val_loss: 0.5744 - val_accuracy: 0.8649
#
# Epoch 00483: val_accuracy did not improve from 0.95946
# Epoch 484/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.4658 - val_accuracy: 0.8784
#
# Epoch 00484: val_accuracy did not improve from 0.95946
# Epoch 485/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.7346 - val_accuracy: 0.8649
#
# Epoch 00485: val_accuracy did not improve from 0.95946
# Epoch 486/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.4002 - val_accuracy: 0.9189
#
# Epoch 00486: val_accuracy did not improve from 0.95946
# Epoch 487/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0025 - accuracy: 0.9984 - val_loss: 0.4510 - val_accuracy: 0.8649
#
# Epoch 00487: val_accuracy did not improve from 0.95946
# Epoch 488/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.8986
#
# Epoch 00488: val_accuracy did not improve from 0.95946
# Epoch 489/500
# 238/238 [==============================] - 15s 61ms/step - loss: 5.9056e-04 - accuracy: 1.0000 - val_loss: 0.4617 - val_accuracy: 0.9257
#
# Epoch 00489: val_accuracy did not improve from 0.95946
# Epoch 490/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.5305 - val_accuracy: 0.9122
#
# Epoch 00490: val_accuracy did not improve from 0.95946
# Epoch 491/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.5958 - val_accuracy: 0.8919
#
# Epoch 00491: val_accuracy did not improve from 0.95946
# Epoch 492/500
# 238/238 [==============================] - 14s 61ms/step - loss: 0.0149 - accuracy: 0.9968 - val_loss: 3.0605 - val_accuracy: 0.7162
#
# Epoch 00492: val_accuracy did not improve from 0.95946
# Epoch 493/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0236 - accuracy: 0.9932 - val_loss: 0.5546 - val_accuracy: 0.9122
#
# Epoch 00493: val_accuracy did not improve from 0.95946
# Epoch 494/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.7432 - val_accuracy: 0.8649
#
# Epoch 00494: val_accuracy did not improve from 0.95946
# Epoch 495/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5269 - val_accuracy: 0.8851
#
# Epoch 00495: val_accuracy did not improve from 0.95946
# Epoch 496/500
# 238/238 [==============================] - 14s 60ms/step - loss: 5.7540e-04 - accuracy: 1.0000 - val_loss: 0.5870 - val_accuracy: 0.8851
#
# Epoch 00496: val_accuracy did not improve from 0.95946
# Epoch 497/500
# 238/238 [==============================] - 15s 61ms/step - loss: 4.8572e-04 - accuracy: 1.0000 - val_loss: 0.6214 - val_accuracy: 0.8716
#
# Epoch 00497: val_accuracy did not improve from 0.95946
# Epoch 498/500
# 238/238 [==============================] - 15s 61ms/step - loss: 6.8372e-04 - accuracy: 1.0000 - val_loss: 0.4958 - val_accuracy: 0.9054
#
# Epoch 00498: val_accuracy did not improve from 0.95946
# Epoch 499/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0105 - accuracy: 0.9984 - val_loss: 0.9832 - val_accuracy: 0.8514
#
# Epoch 00499: val_accuracy did not improve from 0.95946
# Epoch 500/500
# 238/238 [==============================] - 15s 61ms/step - loss: 0.0317 - accuracy: 0.9905 - val_loss: 0.9796 - val_accuracy: 0.8919
#
# Epoch 00500: val_accuracy did not improve from 0.95946

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')

# %%
# !pip install /content/drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Out:
# Processing ./drive/MyDrive/DACON_submit_api/dacon_submit_api-0.0.4-py3-none-any.whl
# Installing collected packages: dacon-submit-api
# Successfully installed dacon-submit-api-0.0.4

# %%
from dacon_submit_api import dacon_submit_api 

result = dacon_submit_api.post_submission_file(
    # 파일경로
    '/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', 
    # d9249@kyonggi.ac.kr
    # 'c2ecc8b05a9867f71ebb86f632ae73326696cb7f6e21be07ab43a7b400ef1f11',
    # dodo9249@gmail.com
    'abc9927563b1882b2480ac943a313a002631fb00c5a0daea43b12720ed34114e',
    # d9249.acc001@gmail.com
    # 'b27d6929e0eedade68e6a882d4006ec463f061c75a81aa27561c2c606dde8ad7',
    # 대회 ID
    '235626',
    # d9249@kyonggi.ac.kr 팀이릉
    # 'iDeal9',
    # dodo9249@gmail.com 팀이름
    'iDeal96',
    # d9249.acc001@gmail.com
    # 'iDeal01',
    # memo
    'd9249_kyonggi_ac_kr' )
# Out:
# {'isSubmitted': True, 'detail': 'Success'}
