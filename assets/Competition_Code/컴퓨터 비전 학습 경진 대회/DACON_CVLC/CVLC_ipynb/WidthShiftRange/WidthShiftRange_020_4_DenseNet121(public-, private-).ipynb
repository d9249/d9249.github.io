# %%
# !nvidia-smi
# Out:
# Tue Aug 31 16:09:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
import cv2

for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
import tensorflow as tf
DenseNet121_model = tf.keras.applications.DenseNet121(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
from tensorflow.keras.optimizers import Adam
DenseNet121_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.002,epsilon=None), metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
                             rescale=1./255, 
                             validation_split=0.2,
                             rotation_range=10,
                             width_shift_range=0.2,
                             height_shift_range=0.1)

train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1642 images belonging to 10 classes.
# Found 406 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
DenseNet121_model.fit_generator(train_generator, epochs=500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 52/52 [==============================] - 53s 476ms/step - loss: 1.8472 - accuracy: 0.3563 - val_loss: 7.8464 - val_accuracy: 0.0936
#
# Epoch 00001: val_accuracy improved from -inf to 0.09360, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 2/500
# 52/52 [==============================] - 20s 375ms/step - loss: 1.1708 - accuracy: 0.6023 - val_loss: 14.8099 - val_accuracy: 0.0961
#
# Epoch 00002: val_accuracy improved from 0.09360 to 0.09606, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 3/500
# 52/52 [==============================] - 20s 379ms/step - loss: 0.9687 - accuracy: 0.6657 - val_loss: 14.5769 - val_accuracy: 0.0936
#
# Epoch 00003: val_accuracy did not improve from 0.09606
# Epoch 4/500
# 52/52 [==============================] - 20s 382ms/step - loss: 0.8089 - accuracy: 0.7339 - val_loss: 17.0950 - val_accuracy: 0.0443
#
# Epoch 00004: val_accuracy did not improve from 0.09606
# Epoch 5/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.7297 - accuracy: 0.7564 - val_loss: 10.0498 - val_accuracy: 0.1207
#
# Epoch 00005: val_accuracy improved from 0.09606 to 0.12069, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 6/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.6535 - accuracy: 0.7856 - val_loss: 19.2749 - val_accuracy: 0.1182
#
# Epoch 00006: val_accuracy did not improve from 0.12069
# Epoch 7/500
# 52/52 [==============================] - 20s 391ms/step - loss: 0.6181 - accuracy: 0.7960 - val_loss: 4.9727 - val_accuracy: 0.2389
#
# Epoch 00007: val_accuracy improved from 0.12069 to 0.23892, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 8/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.5240 - accuracy: 0.8179 - val_loss: 6.6291 - val_accuracy: 0.2611
#
# Epoch 00008: val_accuracy improved from 0.23892 to 0.26108, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 9/500
# 52/52 [==============================] - 20s 383ms/step - loss: 0.5165 - accuracy: 0.8222 - val_loss: 3.4168 - val_accuracy: 0.3768
#
# Epoch 00009: val_accuracy improved from 0.26108 to 0.37685, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 10/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.4704 - accuracy: 0.8532 - val_loss: 1.2088 - val_accuracy: 0.6897
#
# Epoch 00010: val_accuracy improved from 0.37685 to 0.68966, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 11/500
# 52/52 [==============================] - 21s 401ms/step - loss: 0.4416 - accuracy: 0.8508 - val_loss: 0.6070 - val_accuracy: 0.8177
#
# Epoch 00011: val_accuracy improved from 0.68966 to 0.81773, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 12/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.4018 - accuracy: 0.8636 - val_loss: 2.1275 - val_accuracy: 0.4951
#
# Epoch 00012: val_accuracy did not improve from 0.81773
# Epoch 13/500
# 52/52 [==============================] - 20s 390ms/step - loss: 0.3513 - accuracy: 0.8812 - val_loss: 1.2367 - val_accuracy: 0.6823
#
# Epoch 00013: val_accuracy did not improve from 0.81773
# Epoch 14/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.3648 - accuracy: 0.8806 - val_loss: 0.8458 - val_accuracy: 0.7660
#
# Epoch 00014: val_accuracy did not improve from 0.81773
# Epoch 15/500
# 52/52 [==============================] - 20s 383ms/step - loss: 0.3172 - accuracy: 0.8959 - val_loss: 0.9831 - val_accuracy: 0.7537
#
# Epoch 00015: val_accuracy did not improve from 0.81773
# Epoch 16/500
# 52/52 [==============================] - 20s 383ms/step - loss: 0.3487 - accuracy: 0.8812 - val_loss: 0.4901 - val_accuracy: 0.8374
#
# Epoch 00016: val_accuracy improved from 0.81773 to 0.83744, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 17/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.2766 - accuracy: 0.9068 - val_loss: 0.6635 - val_accuracy: 0.8177
#
# Epoch 00017: val_accuracy did not improve from 0.83744
# Epoch 18/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.2940 - accuracy: 0.8995 - val_loss: 0.7230 - val_accuracy: 0.7709
#
# Epoch 00018: val_accuracy did not improve from 0.83744
# Epoch 19/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.2668 - accuracy: 0.9147 - val_loss: 4.9631 - val_accuracy: 0.3153
#
# Epoch 00019: val_accuracy did not improve from 0.83744
# Epoch 20/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.2885 - accuracy: 0.8989 - val_loss: 1.0867 - val_accuracy: 0.7217
#
# Epoch 00020: val_accuracy did not improve from 0.83744
# Epoch 21/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.2991 - accuracy: 0.9044 - val_loss: 1.0104 - val_accuracy: 0.7512
#
# Epoch 00021: val_accuracy did not improve from 0.83744
# Epoch 22/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.2464 - accuracy: 0.9202 - val_loss: 0.4954 - val_accuracy: 0.8498
#
# Epoch 00022: val_accuracy improved from 0.83744 to 0.84975, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 23/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.2130 - accuracy: 0.9227 - val_loss: 0.6245 - val_accuracy: 0.8177
#
# Epoch 00023: val_accuracy did not improve from 0.84975
# Epoch 24/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.2179 - accuracy: 0.9233 - val_loss: 0.4489 - val_accuracy: 0.8695
#
# Epoch 00024: val_accuracy improved from 0.84975 to 0.86946, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 25/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.1961 - accuracy: 0.9421 - val_loss: 0.6406 - val_accuracy: 0.8202
#
# Epoch 00025: val_accuracy did not improve from 0.86946
# Epoch 26/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.2089 - accuracy: 0.9342 - val_loss: 0.6420 - val_accuracy: 0.8251
#
# Epoch 00026: val_accuracy did not improve from 0.86946
# Epoch 27/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.2164 - accuracy: 0.9294 - val_loss: 1.2189 - val_accuracy: 0.7537
#
# Epoch 00027: val_accuracy did not improve from 0.86946
# Epoch 28/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.1461 - accuracy: 0.9525 - val_loss: 0.8791 - val_accuracy: 0.7833
#
# Epoch 00028: val_accuracy did not improve from 0.86946
# Epoch 29/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.2051 - accuracy: 0.9342 - val_loss: 0.8037 - val_accuracy: 0.7980
#
# Epoch 00029: val_accuracy did not improve from 0.86946
# Epoch 30/500
# 52/52 [==============================] - 21s 400ms/step - loss: 0.2097 - accuracy: 0.9245 - val_loss: 0.6666 - val_accuracy: 0.8227
#
# Epoch 00030: val_accuracy did not improve from 0.86946
# Epoch 31/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.1559 - accuracy: 0.9403 - val_loss: 0.5208 - val_accuracy: 0.8350
#
# Epoch 00031: val_accuracy did not improve from 0.86946
# Epoch 32/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1291 - accuracy: 0.9580 - val_loss: 0.8517 - val_accuracy: 0.7906
#
# Epoch 00032: val_accuracy did not improve from 0.86946
# Epoch 33/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1840 - accuracy: 0.9306 - val_loss: 0.5437 - val_accuracy: 0.8473
#
# Epoch 00033: val_accuracy did not improve from 0.86946
# Epoch 34/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1496 - accuracy: 0.9440 - val_loss: 0.9143 - val_accuracy: 0.7463
#
# Epoch 00034: val_accuracy did not improve from 0.86946
# Epoch 35/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1867 - accuracy: 0.9379 - val_loss: 0.8742 - val_accuracy: 0.7857
#
# Epoch 00035: val_accuracy did not improve from 0.86946
# Epoch 36/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1361 - accuracy: 0.9519 - val_loss: 0.6693 - val_accuracy: 0.8153
#
# Epoch 00036: val_accuracy did not improve from 0.86946
# Epoch 37/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1301 - accuracy: 0.9580 - val_loss: 0.6998 - val_accuracy: 0.8300
#
# Epoch 00037: val_accuracy did not improve from 0.86946
# Epoch 38/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0954 - accuracy: 0.9641 - val_loss: 0.8107 - val_accuracy: 0.8300
#
# Epoch 00038: val_accuracy did not improve from 0.86946
# Epoch 39/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0933 - accuracy: 0.9671 - val_loss: 0.3683 - val_accuracy: 0.9064
#
# Epoch 00039: val_accuracy improved from 0.86946 to 0.90640, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 40/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0983 - accuracy: 0.9653 - val_loss: 0.5676 - val_accuracy: 0.8448
#
# Epoch 00040: val_accuracy did not improve from 0.90640
# Epoch 41/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.1088 - accuracy: 0.9659 - val_loss: 0.5822 - val_accuracy: 0.8473
#
# Epoch 00041: val_accuracy did not improve from 0.90640
# Epoch 42/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.1395 - accuracy: 0.9531 - val_loss: 1.2015 - val_accuracy: 0.7167
#
# Epoch 00042: val_accuracy did not improve from 0.90640
# Epoch 43/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1419 - accuracy: 0.9592 - val_loss: 0.6184 - val_accuracy: 0.8793
#
# Epoch 00043: val_accuracy did not improve from 0.90640
# Epoch 44/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1492 - accuracy: 0.9549 - val_loss: 0.7468 - val_accuracy: 0.7956
#
# Epoch 00044: val_accuracy did not improve from 0.90640
# Epoch 45/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1105 - accuracy: 0.9616 - val_loss: 0.4322 - val_accuracy: 0.8818
#
# Epoch 00045: val_accuracy did not improve from 0.90640
# Epoch 46/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.1060 - accuracy: 0.9635 - val_loss: 0.6619 - val_accuracy: 0.8300
#
# Epoch 00046: val_accuracy did not improve from 0.90640
# Epoch 47/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0836 - accuracy: 0.9677 - val_loss: 0.6319 - val_accuracy: 0.8448
#
# Epoch 00047: val_accuracy did not improve from 0.90640
# Epoch 48/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.1150 - accuracy: 0.9610 - val_loss: 0.7185 - val_accuracy: 0.8276
#
# Epoch 00048: val_accuracy did not improve from 0.90640
# Epoch 49/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1108 - accuracy: 0.9677 - val_loss: 0.6145 - val_accuracy: 0.8448
#
# Epoch 00049: val_accuracy did not improve from 0.90640
# Epoch 50/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0840 - accuracy: 0.9720 - val_loss: 0.8734 - val_accuracy: 0.7956
#
# Epoch 00050: val_accuracy did not improve from 0.90640
# Epoch 51/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1150 - accuracy: 0.9641 - val_loss: 0.7575 - val_accuracy: 0.8227
#
# Epoch 00051: val_accuracy did not improve from 0.90640
# Epoch 52/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0816 - accuracy: 0.9750 - val_loss: 0.5642 - val_accuracy: 0.8571
#
# Epoch 00052: val_accuracy did not improve from 0.90640
# Epoch 53/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0951 - accuracy: 0.9677 - val_loss: 0.5249 - val_accuracy: 0.8768
#
# Epoch 00053: val_accuracy did not improve from 0.90640
# Epoch 54/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0614 - accuracy: 0.9793 - val_loss: 0.4280 - val_accuracy: 0.8793
#
# Epoch 00054: val_accuracy did not improve from 0.90640
# Epoch 55/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0985 - accuracy: 0.9671 - val_loss: 0.6435 - val_accuracy: 0.8424
#
# Epoch 00055: val_accuracy did not improve from 0.90640
# Epoch 56/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0787 - accuracy: 0.9762 - val_loss: 0.8450 - val_accuracy: 0.8227
#
# Epoch 00056: val_accuracy did not improve from 0.90640
# Epoch 57/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0712 - accuracy: 0.9769 - val_loss: 0.9322 - val_accuracy: 0.7931
#
# Epoch 00057: val_accuracy did not improve from 0.90640
# Epoch 58/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.1080 - accuracy: 0.9622 - val_loss: 0.5299 - val_accuracy: 0.8621
#
# Epoch 00058: val_accuracy did not improve from 0.90640
# Epoch 59/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.1148 - accuracy: 0.9604 - val_loss: 0.7749 - val_accuracy: 0.8374
#
# Epoch 00059: val_accuracy did not improve from 0.90640
# Epoch 60/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0599 - accuracy: 0.9848 - val_loss: 0.4322 - val_accuracy: 0.8916
#
# Epoch 00060: val_accuracy did not improve from 0.90640
# Epoch 61/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 0.4930 - val_accuracy: 0.8793
#
# Epoch 00061: val_accuracy did not improve from 0.90640
# Epoch 62/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0484 - accuracy: 0.9836 - val_loss: 0.5224 - val_accuracy: 0.8621
#
# Epoch 00062: val_accuracy did not improve from 0.90640
# Epoch 63/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0442 - accuracy: 0.9848 - val_loss: 0.7707 - val_accuracy: 0.8325
#
# Epoch 00063: val_accuracy did not improve from 0.90640
# Epoch 64/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0349 - accuracy: 0.9872 - val_loss: 0.4849 - val_accuracy: 0.8842
#
# Epoch 00064: val_accuracy did not improve from 0.90640
# Epoch 65/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0582 - accuracy: 0.9787 - val_loss: 0.4876 - val_accuracy: 0.8719
#
# Epoch 00065: val_accuracy did not improve from 0.90640
# Epoch 66/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0724 - accuracy: 0.9744 - val_loss: 0.5299 - val_accuracy: 0.8818
#
# Epoch 00066: val_accuracy did not improve from 0.90640
# Epoch 67/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0412 - accuracy: 0.9854 - val_loss: 0.5807 - val_accuracy: 0.8818
#
# Epoch 00067: val_accuracy did not improve from 0.90640
# Epoch 68/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0487 - accuracy: 0.9817 - val_loss: 0.4308 - val_accuracy: 0.8941
#
# Epoch 00068: val_accuracy did not improve from 0.90640
# Epoch 69/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0588 - accuracy: 0.9817 - val_loss: 0.8663 - val_accuracy: 0.8177
#
# Epoch 00069: val_accuracy did not improve from 0.90640
# Epoch 70/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0642 - accuracy: 0.9805 - val_loss: 0.5358 - val_accuracy: 0.8916
#
# Epoch 00070: val_accuracy did not improve from 0.90640
# Epoch 71/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0702 - accuracy: 0.9811 - val_loss: 0.5413 - val_accuracy: 0.8818
#
# Epoch 00071: val_accuracy did not improve from 0.90640
# Epoch 72/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0886 - accuracy: 0.9659 - val_loss: 0.7601 - val_accuracy: 0.8621
#
# Epoch 00072: val_accuracy did not improve from 0.90640
# Epoch 73/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0897 - accuracy: 0.9695 - val_loss: 0.6692 - val_accuracy: 0.8547
#
# Epoch 00073: val_accuracy did not improve from 0.90640
# Epoch 74/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1597 - accuracy: 0.9488 - val_loss: 0.9915 - val_accuracy: 0.8276
#
# Epoch 00074: val_accuracy did not improve from 0.90640
# Epoch 75/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.1119 - accuracy: 0.9629 - val_loss: 0.9151 - val_accuracy: 0.8448
#
# Epoch 00075: val_accuracy did not improve from 0.90640
# Epoch 76/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0570 - accuracy: 0.9799 - val_loss: 0.6509 - val_accuracy: 0.8571
#
# Epoch 00076: val_accuracy did not improve from 0.90640
# Epoch 77/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0451 - accuracy: 0.9866 - val_loss: 0.4284 - val_accuracy: 0.8941
#
# Epoch 00077: val_accuracy did not improve from 0.90640
# Epoch 78/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0591 - accuracy: 0.9823 - val_loss: 0.4792 - val_accuracy: 0.8916
#
# Epoch 00078: val_accuracy did not improve from 0.90640
# Epoch 79/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0647 - accuracy: 0.9744 - val_loss: 0.6028 - val_accuracy: 0.8719
#
# Epoch 00079: val_accuracy did not improve from 0.90640
# Epoch 80/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0522 - accuracy: 0.9811 - val_loss: 0.7672 - val_accuracy: 0.8251
#
# Epoch 00080: val_accuracy did not improve from 0.90640
# Epoch 81/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0416 - accuracy: 0.9866 - val_loss: 0.6095 - val_accuracy: 0.8768
#
# Epoch 00081: val_accuracy did not improve from 0.90640
# Epoch 82/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0603 - accuracy: 0.9805 - val_loss: 0.6365 - val_accuracy: 0.8227
#
# Epoch 00082: val_accuracy did not improve from 0.90640
# Epoch 83/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0535 - accuracy: 0.9848 - val_loss: 0.5652 - val_accuracy: 0.8744
#
# Epoch 00083: val_accuracy did not improve from 0.90640
# Epoch 84/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0491 - accuracy: 0.9829 - val_loss: 0.6866 - val_accuracy: 0.8571
#
# Epoch 00084: val_accuracy did not improve from 0.90640
# Epoch 85/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0486 - accuracy: 0.9836 - val_loss: 0.5926 - val_accuracy: 0.8645
#
# Epoch 00085: val_accuracy did not improve from 0.90640
# Epoch 86/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0425 - accuracy: 0.9872 - val_loss: 0.5951 - val_accuracy: 0.8768
#
# Epoch 00086: val_accuracy did not improve from 0.90640
# Epoch 87/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0599 - accuracy: 0.9781 - val_loss: 0.6669 - val_accuracy: 0.8596
#
# Epoch 00087: val_accuracy did not improve from 0.90640
# Epoch 88/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0395 - accuracy: 0.9878 - val_loss: 0.5415 - val_accuracy: 0.8818
#
# Epoch 00088: val_accuracy did not improve from 0.90640
# Epoch 89/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0318 - accuracy: 0.9921 - val_loss: 0.4455 - val_accuracy: 0.8892
#
# Epoch 00089: val_accuracy did not improve from 0.90640
# Epoch 90/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0416 - accuracy: 0.9884 - val_loss: 0.6045 - val_accuracy: 0.8793
#
# Epoch 00090: val_accuracy did not improve from 0.90640
# Epoch 91/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0322 - accuracy: 0.9896 - val_loss: 0.5070 - val_accuracy: 0.8719
#
# Epoch 00091: val_accuracy did not improve from 0.90640
# Epoch 92/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0341 - accuracy: 0.9909 - val_loss: 0.4748 - val_accuracy: 0.8966
#
# Epoch 00092: val_accuracy did not improve from 0.90640
# Epoch 93/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 0.4713 - val_accuracy: 0.8990
#
# Epoch 00093: val_accuracy did not improve from 0.90640
# Epoch 94/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0328 - accuracy: 0.9903 - val_loss: 0.5413 - val_accuracy: 0.8768
#
# Epoch 00094: val_accuracy did not improve from 0.90640
# Epoch 95/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0359 - accuracy: 0.9848 - val_loss: 0.4905 - val_accuracy: 0.8719
#
# Epoch 00095: val_accuracy did not improve from 0.90640
# Epoch 96/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0867 - accuracy: 0.9756 - val_loss: 1.7879 - val_accuracy: 0.7438
#
# Epoch 00096: val_accuracy did not improve from 0.90640
# Epoch 97/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0796 - accuracy: 0.9714 - val_loss: 0.6342 - val_accuracy: 0.8621
#
# Epoch 00097: val_accuracy did not improve from 0.90640
# Epoch 98/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.1124 - accuracy: 0.9641 - val_loss: 1.0135 - val_accuracy: 0.8300
#
# Epoch 00098: val_accuracy did not improve from 0.90640
# Epoch 99/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0604 - accuracy: 0.9769 - val_loss: 0.5101 - val_accuracy: 0.8966
#
# Epoch 00099: val_accuracy did not improve from 0.90640
# Epoch 100/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0344 - accuracy: 0.9866 - val_loss: 0.8410 - val_accuracy: 0.8793
#
# Epoch 00100: val_accuracy did not improve from 0.90640
# Epoch 101/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 0.4295 - val_accuracy: 0.9064
#
# Epoch 00101: val_accuracy did not improve from 0.90640
# Epoch 102/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.4616 - val_accuracy: 0.8916
#
# Epoch 00102: val_accuracy did not improve from 0.90640
# Epoch 103/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.3937 - val_accuracy: 0.9212
#
# Epoch 00103: val_accuracy improved from 0.90640 to 0.92118, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 104/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0109 - accuracy: 0.9957 - val_loss: 0.5249 - val_accuracy: 0.8916
#
# Epoch 00104: val_accuracy did not improve from 0.92118
# Epoch 105/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0255 - accuracy: 0.9921 - val_loss: 0.4750 - val_accuracy: 0.8916
#
# Epoch 00105: val_accuracy did not improve from 0.92118
# Epoch 106/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0304 - accuracy: 0.9903 - val_loss: 0.4851 - val_accuracy: 0.8990
#
# Epoch 00106: val_accuracy did not improve from 0.92118
# Epoch 107/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.5434 - val_accuracy: 0.8842
#
# Epoch 00107: val_accuracy did not improve from 0.92118
# Epoch 108/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0113 - accuracy: 0.9957 - val_loss: 0.4619 - val_accuracy: 0.9015
#
# Epoch 00108: val_accuracy did not improve from 0.92118
# Epoch 109/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0656 - accuracy: 0.9799 - val_loss: 0.9093 - val_accuracy: 0.8350
#
# Epoch 00109: val_accuracy did not improve from 0.92118
# Epoch 110/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0749 - accuracy: 0.9732 - val_loss: 0.7794 - val_accuracy: 0.8522
#
# Epoch 00110: val_accuracy did not improve from 0.92118
# Epoch 111/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.1024 - accuracy: 0.9677 - val_loss: 1.9114 - val_accuracy: 0.6847
#
# Epoch 00111: val_accuracy did not improve from 0.92118
# Epoch 112/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.1237 - accuracy: 0.9525 - val_loss: 0.8248 - val_accuracy: 0.8473
#
# Epoch 00112: val_accuracy did not improve from 0.92118
# Epoch 113/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0586 - accuracy: 0.9781 - val_loss: 0.5112 - val_accuracy: 0.8744
#
# Epoch 00113: val_accuracy did not improve from 0.92118
# Epoch 114/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0373 - accuracy: 0.9896 - val_loss: 0.6328 - val_accuracy: 0.8842
#
# Epoch 00114: val_accuracy did not improve from 0.92118
# Epoch 115/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0722 - accuracy: 0.9769 - val_loss: 0.8074 - val_accuracy: 0.8522
#
# Epoch 00115: val_accuracy did not improve from 0.92118
# Epoch 116/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0345 - accuracy: 0.9878 - val_loss: 0.5460 - val_accuracy: 0.8990
#
# Epoch 00116: val_accuracy did not improve from 0.92118
# Epoch 117/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0359 - accuracy: 0.9878 - val_loss: 0.5318 - val_accuracy: 0.9015
#
# Epoch 00117: val_accuracy did not improve from 0.92118
# Epoch 118/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0166 - accuracy: 0.9963 - val_loss: 0.4015 - val_accuracy: 0.9089
#
# Epoch 00118: val_accuracy did not improve from 0.92118
# Epoch 119/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0537 - accuracy: 0.9842 - val_loss: 0.7519 - val_accuracy: 0.8571
#
# Epoch 00119: val_accuracy did not improve from 0.92118
# Epoch 120/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0455 - accuracy: 0.9854 - val_loss: 0.4881 - val_accuracy: 0.8916
#
# Epoch 00120: val_accuracy did not improve from 0.92118
# Epoch 121/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0295 - accuracy: 0.9909 - val_loss: 0.5081 - val_accuracy: 0.9064
#
# Epoch 00121: val_accuracy did not improve from 0.92118
# Epoch 122/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0162 - accuracy: 0.9945 - val_loss: 0.4386 - val_accuracy: 0.9039
#
# Epoch 00122: val_accuracy did not improve from 0.92118
# Epoch 123/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0097 - accuracy: 0.9963 - val_loss: 0.4760 - val_accuracy: 0.9187
#
# Epoch 00123: val_accuracy did not improve from 0.92118
# Epoch 124/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.4219 - val_accuracy: 0.9187
#
# Epoch 00124: val_accuracy did not improve from 0.92118
# Epoch 125/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.4885 - val_accuracy: 0.9113
#
# Epoch 00125: val_accuracy did not improve from 0.92118
# Epoch 126/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.4871 - val_accuracy: 0.8941
#
# Epoch 00126: val_accuracy did not improve from 0.92118
# Epoch 127/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.4832 - val_accuracy: 0.9039
#
# Epoch 00127: val_accuracy did not improve from 0.92118
# Epoch 128/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.0323 - accuracy: 0.9884 - val_loss: 0.6020 - val_accuracy: 0.8793
#
# Epoch 00128: val_accuracy did not improve from 0.92118
# Epoch 129/500
# 52/52 [==============================] - 20s 392ms/step - loss: 0.0607 - accuracy: 0.9781 - val_loss: 1.2590 - val_accuracy: 0.8030
#
# Epoch 00129: val_accuracy did not improve from 0.92118
# Epoch 130/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.1020 - accuracy: 0.9714 - val_loss: 0.6840 - val_accuracy: 0.8424
#
# Epoch 00130: val_accuracy did not improve from 0.92118
# Epoch 131/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0842 - accuracy: 0.9702 - val_loss: 0.7558 - val_accuracy: 0.8350
#
# Epoch 00131: val_accuracy did not improve from 0.92118
# Epoch 132/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0515 - accuracy: 0.9805 - val_loss: 0.4154 - val_accuracy: 0.8990
#
# Epoch 00132: val_accuracy did not improve from 0.92118
# Epoch 133/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0263 - accuracy: 0.9915 - val_loss: 0.5784 - val_accuracy: 0.8793
#
# Epoch 00133: val_accuracy did not improve from 0.92118
# Epoch 134/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0280 - accuracy: 0.9921 - val_loss: 0.5172 - val_accuracy: 0.8892
#
# Epoch 00134: val_accuracy did not improve from 0.92118
# Epoch 135/500
# 52/52 [==============================] - 21s 400ms/step - loss: 0.0158 - accuracy: 0.9939 - val_loss: 0.5099 - val_accuracy: 0.9015
#
# Epoch 00135: val_accuracy did not improve from 0.92118
# Epoch 136/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0138 - accuracy: 0.9939 - val_loss: 0.5561 - val_accuracy: 0.8818
#
# Epoch 00136: val_accuracy did not improve from 0.92118
# Epoch 137/500
# 52/52 [==============================] - 21s 400ms/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 0.4895 - val_accuracy: 0.9039
#
# Epoch 00137: val_accuracy did not improve from 0.92118
# Epoch 138/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0182 - accuracy: 0.9957 - val_loss: 0.4743 - val_accuracy: 0.8966
#
# Epoch 00138: val_accuracy did not improve from 0.92118
# Epoch 139/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.3873 - val_accuracy: 0.9089
#
# Epoch 00139: val_accuracy did not improve from 0.92118
# Epoch 140/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.4142 - val_accuracy: 0.9138
#
# Epoch 00140: val_accuracy did not improve from 0.92118
# Epoch 141/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.7624 - val_accuracy: 0.8571
#
# Epoch 00141: val_accuracy did not improve from 0.92118
# Epoch 142/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0435 - accuracy: 0.9896 - val_loss: 0.5726 - val_accuracy: 0.8892
#
# Epoch 00142: val_accuracy did not improve from 0.92118
# Epoch 143/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0711 - accuracy: 0.9762 - val_loss: 1.3819 - val_accuracy: 0.7931
#
# Epoch 00143: val_accuracy did not improve from 0.92118
# Epoch 144/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0679 - accuracy: 0.9787 - val_loss: 0.7705 - val_accuracy: 0.8522
#
# Epoch 00144: val_accuracy did not improve from 0.92118
# Epoch 145/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.4357 - val_accuracy: 0.9015
#
# Epoch 00145: val_accuracy did not improve from 0.92118
# Epoch 146/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0526 - accuracy: 0.9872 - val_loss: 0.6692 - val_accuracy: 0.8670
#
# Epoch 00146: val_accuracy did not improve from 0.92118
# Epoch 147/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0824 - accuracy: 0.9720 - val_loss: 0.6465 - val_accuracy: 0.8695
#
# Epoch 00147: val_accuracy did not improve from 0.92118
# Epoch 148/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0391 - accuracy: 0.9848 - val_loss: 0.6574 - val_accuracy: 0.8695
#
# Epoch 00148: val_accuracy did not improve from 0.92118
# Epoch 149/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0213 - accuracy: 0.9933 - val_loss: 0.4410 - val_accuracy: 0.9015
#
# Epoch 00149: val_accuracy did not improve from 0.92118
# Epoch 150/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.5235 - val_accuracy: 0.8966
#
# Epoch 00150: val_accuracy did not improve from 0.92118
# Epoch 151/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.4512 - val_accuracy: 0.9163
#
# Epoch 00151: val_accuracy did not improve from 0.92118
# Epoch 152/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.3186 - val_accuracy: 0.9286
#
# Epoch 00152: val_accuracy improved from 0.92118 to 0.92857, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5
# Epoch 153/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4108 - val_accuracy: 0.9212
#
# Epoch 00153: val_accuracy did not improve from 0.92857
# Epoch 154/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.3726 - val_accuracy: 0.9236
#
# Epoch 00154: val_accuracy did not improve from 0.92857
# Epoch 155/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.3811 - val_accuracy: 0.9286
#
# Epoch 00155: val_accuracy did not improve from 0.92857
# Epoch 156/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.4678 - val_accuracy: 0.9064
#
# Epoch 00156: val_accuracy did not improve from 0.92857
# Epoch 157/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.4084 - val_accuracy: 0.9236
#
# Epoch 00157: val_accuracy did not improve from 0.92857
# Epoch 158/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.4814 - val_accuracy: 0.9187
#
# Epoch 00158: val_accuracy did not improve from 0.92857
# Epoch 159/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.5339 - val_accuracy: 0.9089
#
# Epoch 00159: val_accuracy did not improve from 0.92857
# Epoch 160/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0499 - accuracy: 0.9860 - val_loss: 1.1873 - val_accuracy: 0.7980
#
# Epoch 00160: val_accuracy did not improve from 0.92857
# Epoch 161/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0408 - accuracy: 0.9872 - val_loss: 0.8992 - val_accuracy: 0.8350
#
# Epoch 00161: val_accuracy did not improve from 0.92857
# Epoch 162/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0612 - accuracy: 0.9823 - val_loss: 0.8050 - val_accuracy: 0.8522
#
# Epoch 00162: val_accuracy did not improve from 0.92857
# Epoch 163/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0264 - accuracy: 0.9909 - val_loss: 0.5838 - val_accuracy: 0.8793
#
# Epoch 00163: val_accuracy did not improve from 0.92857
# Epoch 164/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.5311 - val_accuracy: 0.8818
#
# Epoch 00164: val_accuracy did not improve from 0.92857
# Epoch 165/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0336 - accuracy: 0.9872 - val_loss: 0.7470 - val_accuracy: 0.8695
#
# Epoch 00165: val_accuracy did not improve from 0.92857
# Epoch 166/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0249 - accuracy: 0.9921 - val_loss: 0.5415 - val_accuracy: 0.8867
#
# Epoch 00166: val_accuracy did not improve from 0.92857
# Epoch 167/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0400 - accuracy: 0.9890 - val_loss: 0.4919 - val_accuracy: 0.8990
#
# Epoch 00167: val_accuracy did not improve from 0.92857
# Epoch 168/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0509 - accuracy: 0.9890 - val_loss: 0.8534 - val_accuracy: 0.8251
#
# Epoch 00168: val_accuracy did not improve from 0.92857
# Epoch 169/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0514 - accuracy: 0.9799 - val_loss: 0.7563 - val_accuracy: 0.8670
#
# Epoch 00169: val_accuracy did not improve from 0.92857
# Epoch 170/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0361 - accuracy: 0.9909 - val_loss: 0.6193 - val_accuracy: 0.8892
#
# Epoch 00170: val_accuracy did not improve from 0.92857
# Epoch 171/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0318 - accuracy: 0.9878 - val_loss: 0.8232 - val_accuracy: 0.8522
#
# Epoch 00171: val_accuracy did not improve from 0.92857
# Epoch 172/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.4337 - val_accuracy: 0.8966
#
# Epoch 00172: val_accuracy did not improve from 0.92857
# Epoch 173/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.3791 - val_accuracy: 0.9064
#
# Epoch 00173: val_accuracy did not improve from 0.92857
# Epoch 174/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.5787 - val_accuracy: 0.8892
#
# Epoch 00174: val_accuracy did not improve from 0.92857
# Epoch 175/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 0.7339 - val_accuracy: 0.8670
#
# Epoch 00175: val_accuracy did not improve from 0.92857
# Epoch 176/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0155 - accuracy: 0.9939 - val_loss: 0.4270 - val_accuracy: 0.9089
#
# Epoch 00176: val_accuracy did not improve from 0.92857
# Epoch 177/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0148 - accuracy: 0.9963 - val_loss: 0.4643 - val_accuracy: 0.8966
#
# Epoch 00177: val_accuracy did not improve from 0.92857
# Epoch 178/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0142 - accuracy: 0.9976 - val_loss: 0.4686 - val_accuracy: 0.9113
#
# Epoch 00178: val_accuracy did not improve from 0.92857
# Epoch 179/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0123 - accuracy: 0.9976 - val_loss: 0.4470 - val_accuracy: 0.9064
#
# Epoch 00179: val_accuracy did not improve from 0.92857
# Epoch 180/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.4721 - val_accuracy: 0.8990
#
# Epoch 00180: val_accuracy did not improve from 0.92857
# Epoch 181/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0099 - accuracy: 0.9951 - val_loss: 0.5840 - val_accuracy: 0.8941
#
# Epoch 00181: val_accuracy did not improve from 0.92857
# Epoch 182/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0129 - accuracy: 0.9951 - val_loss: 0.5815 - val_accuracy: 0.9039
#
# Epoch 00182: val_accuracy did not improve from 0.92857
# Epoch 183/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.5378 - val_accuracy: 0.9015
#
# Epoch 00183: val_accuracy did not improve from 0.92857
# Epoch 184/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.4877 - val_accuracy: 0.9261
#
# Epoch 00184: val_accuracy did not improve from 0.92857
# Epoch 185/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.5053 - val_accuracy: 0.9113
#
# Epoch 00185: val_accuracy did not improve from 0.92857
# Epoch 186/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.6857 - val_accuracy: 0.8941
#
# Epoch 00186: val_accuracy did not improve from 0.92857
# Epoch 187/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.4361 - val_accuracy: 0.8916
#
# Epoch 00187: val_accuracy did not improve from 0.92857
# Epoch 188/500
# 52/52 [==============================] - 20s 390ms/step - loss: 0.0453 - accuracy: 0.9866 - val_loss: 0.6543 - val_accuracy: 0.8621
#
# Epoch 00188: val_accuracy did not improve from 0.92857
# Epoch 189/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0372 - accuracy: 0.9890 - val_loss: 0.6527 - val_accuracy: 0.8768
#
# Epoch 00189: val_accuracy did not improve from 0.92857
# Epoch 190/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0395 - accuracy: 0.9842 - val_loss: 1.3198 - val_accuracy: 0.8251
#
# Epoch 00190: val_accuracy did not improve from 0.92857
# Epoch 191/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.4886 - val_accuracy: 0.8744
#
# Epoch 00191: val_accuracy did not improve from 0.92857
# Epoch 192/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0270 - accuracy: 0.9939 - val_loss: 0.5122 - val_accuracy: 0.8867
#
# Epoch 00192: val_accuracy did not improve from 0.92857
# Epoch 193/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0161 - accuracy: 0.9927 - val_loss: 0.5584 - val_accuracy: 0.9039
#
# Epoch 00193: val_accuracy did not improve from 0.92857
# Epoch 194/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0117 - accuracy: 0.9970 - val_loss: 0.5813 - val_accuracy: 0.8842
#
# Epoch 00194: val_accuracy did not improve from 0.92857
# Epoch 195/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0340 - accuracy: 0.9951 - val_loss: 0.6180 - val_accuracy: 0.9015
#
# Epoch 00195: val_accuracy did not improve from 0.92857
# Epoch 196/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.5289 - val_accuracy: 0.9015
#
# Epoch 00196: val_accuracy did not improve from 0.92857
# Epoch 197/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0138 - accuracy: 0.9951 - val_loss: 0.6516 - val_accuracy: 0.8744
#
# Epoch 00197: val_accuracy did not improve from 0.92857
# Epoch 198/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 1.2291 - val_accuracy: 0.8128
#
# Epoch 00198: val_accuracy did not improve from 0.92857
# Epoch 199/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0326 - accuracy: 0.9903 - val_loss: 0.8325 - val_accuracy: 0.8547
#
# Epoch 00199: val_accuracy did not improve from 0.92857
# Epoch 200/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0170 - accuracy: 0.9963 - val_loss: 0.5163 - val_accuracy: 0.8916
#
# Epoch 00200: val_accuracy did not improve from 0.92857
# Epoch 201/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.4936 - val_accuracy: 0.9113
#
# Epoch 00201: val_accuracy did not improve from 0.92857
# Epoch 202/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.4812 - val_accuracy: 0.9138
#
# Epoch 00202: val_accuracy did not improve from 0.92857
# Epoch 203/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.4986 - val_accuracy: 0.9064
#
# Epoch 00203: val_accuracy did not improve from 0.92857
# Epoch 204/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.5176 - val_accuracy: 0.9039
#
# Epoch 00204: val_accuracy did not improve from 0.92857
# Epoch 205/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0107 - accuracy: 0.9976 - val_loss: 0.5593 - val_accuracy: 0.8990
#
# Epoch 00205: val_accuracy did not improve from 0.92857
# Epoch 206/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.5239 - val_accuracy: 0.9236
#
# Epoch 00206: val_accuracy did not improve from 0.92857
# Epoch 207/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0132 - accuracy: 0.9945 - val_loss: 0.9907 - val_accuracy: 0.8350
#
# Epoch 00207: val_accuracy did not improve from 0.92857
# Epoch 208/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0393 - accuracy: 0.9860 - val_loss: 1.0701 - val_accuracy: 0.8276
#
# Epoch 00208: val_accuracy did not improve from 0.92857
# Epoch 209/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.1299 - accuracy: 0.9610 - val_loss: 3.6823 - val_accuracy: 0.6897
#
# Epoch 00209: val_accuracy did not improve from 0.92857
# Epoch 210/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0848 - accuracy: 0.9726 - val_loss: 1.6426 - val_accuracy: 0.7488
#
# Epoch 00210: val_accuracy did not improve from 0.92857
# Epoch 211/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0529 - accuracy: 0.9811 - val_loss: 0.7130 - val_accuracy: 0.8695
#
# Epoch 00211: val_accuracy did not improve from 0.92857
# Epoch 212/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0523 - accuracy: 0.9854 - val_loss: 5.0839 - val_accuracy: 0.5788
#
# Epoch 00212: val_accuracy did not improve from 0.92857
# Epoch 213/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.0418 - accuracy: 0.9860 - val_loss: 0.5814 - val_accuracy: 0.9039
#
# Epoch 00213: val_accuracy did not improve from 0.92857
# Epoch 214/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.4905 - val_accuracy: 0.9113
#
# Epoch 00214: val_accuracy did not improve from 0.92857
# Epoch 215/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 0.3670 - val_accuracy: 0.9212
#
# Epoch 00215: val_accuracy did not improve from 0.92857
# Epoch 216/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.3754 - val_accuracy: 0.9138
#
# Epoch 00216: val_accuracy did not improve from 0.92857
# Epoch 217/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.4733 - val_accuracy: 0.9138
#
# Epoch 00217: val_accuracy did not improve from 0.92857
# Epoch 218/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.4333 - val_accuracy: 0.9138
#
# Epoch 00218: val_accuracy did not improve from 0.92857
# Epoch 219/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.3579 - val_accuracy: 0.9187
#
# Epoch 00219: val_accuracy did not improve from 0.92857
# Epoch 220/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.4536 - val_accuracy: 0.9113
#
# Epoch 00220: val_accuracy did not improve from 0.92857
# Epoch 221/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0040 - accuracy: 0.9982 - val_loss: 0.4623 - val_accuracy: 0.9138
#
# Epoch 00221: val_accuracy did not improve from 0.92857
# Epoch 222/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.3998 - val_accuracy: 0.9212
#
# Epoch 00222: val_accuracy did not improve from 0.92857
# Epoch 223/500
# 52/52 [==============================] - 20s 390ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.9113
#
# Epoch 00223: val_accuracy did not improve from 0.92857
# Epoch 224/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.9039
#
# Epoch 00224: val_accuracy did not improve from 0.92857
# Epoch 225/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.5376 - val_accuracy: 0.9089
#
# Epoch 00225: val_accuracy did not improve from 0.92857
# Epoch 226/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.6610 - val_accuracy: 0.8818
#
# Epoch 00226: val_accuracy did not improve from 0.92857
# Epoch 227/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0100 - accuracy: 0.9976 - val_loss: 0.5155 - val_accuracy: 0.8966
#
# Epoch 00227: val_accuracy did not improve from 0.92857
# Epoch 228/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 0.4737 - val_accuracy: 0.9113
#
# Epoch 00228: val_accuracy did not improve from 0.92857
# Epoch 229/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.4551 - val_accuracy: 0.9187
#
# Epoch 00229: val_accuracy did not improve from 0.92857
# Epoch 230/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0248 - accuracy: 0.9927 - val_loss: 0.7073 - val_accuracy: 0.8842
#
# Epoch 00230: val_accuracy did not improve from 0.92857
# Epoch 231/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0706 - accuracy: 0.9823 - val_loss: 0.6551 - val_accuracy: 0.8719
#
# ...
#
# Epoch 00422: val_accuracy did not improve from 0.94335
# Epoch 423/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.3832 - val_accuracy: 0.9163
#
# Epoch 00423: val_accuracy did not improve from 0.94335
# Epoch 424/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0124 - accuracy: 0.9970 - val_loss: 0.6124 - val_accuracy: 0.8892
#
# Epoch 00424: val_accuracy did not improve from 0.94335
# Epoch 425/500
# 52/52 [==============================] - 20s 390ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.4541 - val_accuracy: 0.9187
#
# Epoch 00425: val_accuracy did not improve from 0.94335
# Epoch 426/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0060 - accuracy: 0.9970 - val_loss: 0.5270 - val_accuracy: 0.8916
#
# Epoch 00426: val_accuracy did not improve from 0.94335
# Epoch 427/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0150 - accuracy: 0.9982 - val_loss: 0.5418 - val_accuracy: 0.9187
#
# Epoch 00427: val_accuracy did not improve from 0.94335
# Epoch 428/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 0.6019 - val_accuracy: 0.9064
#
# Epoch 00428: val_accuracy did not improve from 0.94335
# Epoch 429/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.4643 - val_accuracy: 0.9212
#
# Epoch 00429: val_accuracy did not improve from 0.94335
# Epoch 430/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.5024 - val_accuracy: 0.9113
#
# Epoch 00430: val_accuracy did not improve from 0.94335
# Epoch 431/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.6017 - val_accuracy: 0.9064
#
# Epoch 00431: val_accuracy did not improve from 0.94335
# Epoch 432/500
# 52/52 [==============================] - 20s 391ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.4552 - val_accuracy: 0.9187
#
# Epoch 00432: val_accuracy did not improve from 0.94335
# Epoch 433/500
# 52/52 [==============================] - 20s 388ms/step - loss: 5.0385e-04 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.9261
#
# Epoch 00433: val_accuracy did not improve from 0.94335
# Epoch 434/500
# 52/52 [==============================] - 20s 387ms/step - loss: 3.8800e-04 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.9261
#
# Epoch 00434: val_accuracy did not improve from 0.94335
# Epoch 435/500
# 52/52 [==============================] - 20s 386ms/step - loss: 3.9180e-04 - accuracy: 1.0000 - val_loss: 0.4666 - val_accuracy: 0.9187
#
# Epoch 00435: val_accuracy did not improve from 0.94335
# Epoch 436/500
# 52/52 [==============================] - 20s 386ms/step - loss: 2.4058e-04 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9261
#
# Epoch 00436: val_accuracy did not improve from 0.94335
# Epoch 437/500
# 52/52 [==============================] - 20s 388ms/step - loss: 2.1697e-04 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.9310
#
# Epoch 00437: val_accuracy did not improve from 0.94335
# Epoch 438/500
# 52/52 [==============================] - 20s 387ms/step - loss: 2.0419e-04 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.9212
#
# Epoch 00438: val_accuracy did not improve from 0.94335
# Epoch 439/500
# 52/52 [==============================] - 20s 385ms/step - loss: 2.3092e-04 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.9138
#
# Epoch 00439: val_accuracy did not improve from 0.94335
# Epoch 440/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0100 - accuracy: 0.9957 - val_loss: 0.7160 - val_accuracy: 0.8842
#
# Epoch 00440: val_accuracy did not improve from 0.94335
# Epoch 441/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.8728 - val_accuracy: 0.8842
#
# Epoch 00441: val_accuracy did not improve from 0.94335
# Epoch 442/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0174 - accuracy: 0.9957 - val_loss: 0.8579 - val_accuracy: 0.8473
#
# Epoch 00442: val_accuracy did not improve from 0.94335
# Epoch 443/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0209 - accuracy: 0.9933 - val_loss: 0.5720 - val_accuracy: 0.8892
#
# Epoch 00443: val_accuracy did not improve from 0.94335
# Epoch 444/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0249 - accuracy: 0.9921 - val_loss: 0.6606 - val_accuracy: 0.9039
#
# Epoch 00444: val_accuracy did not improve from 0.94335
# Epoch 445/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0482 - accuracy: 0.9836 - val_loss: 0.7195 - val_accuracy: 0.8892
#
# Epoch 00445: val_accuracy did not improve from 0.94335
# Epoch 446/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0746 - accuracy: 0.9799 - val_loss: 0.7158 - val_accuracy: 0.8571
#
# Epoch 00446: val_accuracy did not improve from 0.94335
# Epoch 447/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0203 - accuracy: 0.9933 - val_loss: 0.5203 - val_accuracy: 0.8990
#
# Epoch 00447: val_accuracy did not improve from 0.94335
# Epoch 448/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.5418 - val_accuracy: 0.8990
#
# Epoch 00448: val_accuracy did not improve from 0.94335
# Epoch 449/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0270 - accuracy: 0.9927 - val_loss: 0.6067 - val_accuracy: 0.9089
#
# Epoch 00449: val_accuracy did not improve from 0.94335
# Epoch 450/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.5578 - val_accuracy: 0.9015
#
# Epoch 00450: val_accuracy did not improve from 0.94335
# Epoch 451/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.5671 - val_accuracy: 0.8867
#
# Epoch 00451: val_accuracy did not improve from 0.94335
# Epoch 452/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0091 - accuracy: 0.9982 - val_loss: 0.5527 - val_accuracy: 0.8966
#
# Epoch 00452: val_accuracy did not improve from 0.94335
# Epoch 453/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.5108 - val_accuracy: 0.9236
#
# Epoch 00453: val_accuracy did not improve from 0.94335
# Epoch 454/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.5562 - val_accuracy: 0.9039
#
# Epoch 00454: val_accuracy did not improve from 0.94335
# Epoch 455/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.4817 - val_accuracy: 0.9212
#
# Epoch 00455: val_accuracy did not improve from 0.94335
# Epoch 456/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.5367 - val_accuracy: 0.9015
#
# Epoch 00456: val_accuracy did not improve from 0.94335
# Epoch 457/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4638 - val_accuracy: 0.9138
#
# Epoch 00457: val_accuracy did not improve from 0.94335
# Epoch 458/500
# 52/52 [==============================] - 20s 387ms/step - loss: 5.3250e-04 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.9187
#
# Epoch 00458: val_accuracy did not improve from 0.94335
# Epoch 459/500
# 52/52 [==============================] - 20s 385ms/step - loss: 4.1038e-04 - accuracy: 1.0000 - val_loss: 0.4585 - val_accuracy: 0.9261
#
# Epoch 00459: val_accuracy did not improve from 0.94335
# Epoch 460/500
# 52/52 [==============================] - 20s 386ms/step - loss: 4.2117e-04 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.9113
#
# Epoch 00460: val_accuracy did not improve from 0.94335
# Epoch 461/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.9064
#
# Epoch 00461: val_accuracy did not improve from 0.94335
# Epoch 462/500
# 52/52 [==============================] - 20s 388ms/step - loss: 5.0022e-04 - accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.9187
#
# Epoch 00462: val_accuracy did not improve from 0.94335
# Epoch 463/500
# 52/52 [==============================] - 20s 388ms/step - loss: 7.3123e-04 - accuracy: 1.0000 - val_loss: 0.4679 - val_accuracy: 0.9286
#
# Epoch 00463: val_accuracy did not improve from 0.94335
# Epoch 464/500
# 52/52 [==============================] - 20s 386ms/step - loss: 4.9727e-04 - accuracy: 1.0000 - val_loss: 0.4751 - val_accuracy: 0.9187
#
# Epoch 00464: val_accuracy did not improve from 0.94335
# Epoch 465/500
# 52/52 [==============================] - 20s 386ms/step - loss: 4.2507e-04 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.9138
#
# Epoch 00465: val_accuracy did not improve from 0.94335
# Epoch 466/500
# 52/52 [==============================] - 20s 387ms/step - loss: 2.2632e-04 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.9212
#
# Epoch 00466: val_accuracy did not improve from 0.94335
# Epoch 467/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.5592 - val_accuracy: 0.9113
#
# Epoch 00467: val_accuracy did not improve from 0.94335
# Epoch 468/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.4417 - val_accuracy: 0.9236
#
# Epoch 00468: val_accuracy did not improve from 0.94335
# Epoch 469/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0062 - accuracy: 0.9970 - val_loss: 0.6865 - val_accuracy: 0.8768
#
# Epoch 00469: val_accuracy did not improve from 0.94335
# Epoch 470/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0631 - accuracy: 0.9811 - val_loss: 1.4025 - val_accuracy: 0.8251
#
# Epoch 00470: val_accuracy did not improve from 0.94335
# Epoch 471/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0380 - accuracy: 0.9854 - val_loss: 0.8873 - val_accuracy: 0.8744
#
# Epoch 00471: val_accuracy did not improve from 0.94335
# Epoch 472/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.5603 - val_accuracy: 0.9064
#
# Epoch 00472: val_accuracy did not improve from 0.94335
# Epoch 473/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.7668 - val_accuracy: 0.8645
#
# Epoch 00473: val_accuracy did not improve from 0.94335
# Epoch 474/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.4109 - val_accuracy: 0.9187
#
# Epoch 00474: val_accuracy did not improve from 0.94335
# Epoch 475/500
# 52/52 [==============================] - 20s 384ms/step - loss: 0.0124 - accuracy: 0.9951 - val_loss: 0.4019 - val_accuracy: 0.9163
#
# Epoch 00475: val_accuracy did not improve from 0.94335
# Epoch 476/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.4369 - val_accuracy: 0.9212
#
# Epoch 00476: val_accuracy did not improve from 0.94335
# Epoch 477/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.9286
#
# Epoch 00477: val_accuracy did not improve from 0.94335
# Epoch 478/500
# 52/52 [==============================] - 20s 390ms/step - loss: 0.0046 - accuracy: 0.9976 - val_loss: 0.4643 - val_accuracy: 0.9138
#
# Epoch 00478: val_accuracy did not improve from 0.94335
# Epoch 479/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.0026 - accuracy: 0.9988 - val_loss: 0.4250 - val_accuracy: 0.9310
#
# Epoch 00479: val_accuracy did not improve from 0.94335
# Epoch 480/500
# 52/52 [==============================] - 20s 390ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.5998 - val_accuracy: 0.9187
#
# Epoch 00480: val_accuracy did not improve from 0.94335
# Epoch 481/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0116 - accuracy: 0.9970 - val_loss: 0.6384 - val_accuracy: 0.9039
#
# Epoch 00481: val_accuracy did not improve from 0.94335
# Epoch 482/500
# 52/52 [==============================] - 20s 389ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4586 - val_accuracy: 0.9236
#
# Epoch 00482: val_accuracy did not improve from 0.94335
# Epoch 483/500
# 52/52 [==============================] - 20s 388ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4237 - val_accuracy: 0.9212
#
# Epoch 00483: val_accuracy did not improve from 0.94335
# Epoch 484/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.4041 - val_accuracy: 0.9163
#
# Epoch 00484: val_accuracy did not improve from 0.94335
# Epoch 485/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4239 - val_accuracy: 0.9335
#
# Epoch 00485: val_accuracy did not improve from 0.94335
# Epoch 486/500
# 52/52 [==============================] - 20s 385ms/step - loss: 0.0024 - accuracy: 0.9988 - val_loss: 0.4278 - val_accuracy: 0.9236
#
# Epoch 00486: val_accuracy did not improve from 0.94335
# Epoch 487/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3853 - val_accuracy: 0.9286
#
# Epoch 00487: val_accuracy did not improve from 0.94335
# Epoch 488/500
# 52/52 [==============================] - 20s 387ms/step - loss: 0.0027 - accuracy: 0.9988 - val_loss: 0.3473 - val_accuracy: 0.9409
#
# Epoch 00488: val_accuracy did not improve from 0.94335
# Epoch 489/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.9212
#
# Epoch 00489: val_accuracy did not improve from 0.94335
# Epoch 490/500
# 52/52 [==============================] - 20s 386ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.4097 - val_accuracy: 0.9286
#
# Epoch 00490: val_accuracy did not improve from 0.94335
# Epoch 491/500
# 52/52 [==============================] - 20s 387ms/step - loss: 8.9957e-04 - accuracy: 1.0000 - val_loss: 0.3930 - val_accuracy: 0.9360
#
# Epoch 00491: val_accuracy did not improve from 0.94335
# Epoch 492/500
# 52/52 [==============================] - 20s 387ms/step - loss: 8.2772e-04 - accuracy: 1.0000 - val_loss: 0.3787 - val_accuracy: 0.9310
#
# Epoch 00492: val_accuracy did not improve from 0.94335
# Epoch 493/500
# 52/52 [==============================] - 20s 388ms/step - loss: 5.8744e-04 - accuracy: 1.0000 - val_loss: 0.3770 - val_accuracy: 0.9310
#
# Epoch 00493: val_accuracy did not improve from 0.94335
# Epoch 494/500
# 52/52 [==============================] - 20s 386ms/step - loss: 7.5434e-04 - accuracy: 0.9994 - val_loss: 0.3575 - val_accuracy: 0.9360
#
# Epoch 00494: val_accuracy did not improve from 0.94335
# Epoch 495/500
# 52/52 [==============================] - 20s 387ms/step - loss: 9.3302e-04 - accuracy: 1.0000 - val_loss: 0.3850 - val_accuracy: 0.9384
#
# Epoch 00495: val_accuracy did not improve from 0.94335
# Epoch 496/500
# 52/52 [==============================] - 20s 386ms/step - loss: 3.3396e-04 - accuracy: 1.0000 - val_loss: 0.3930 - val_accuracy: 0.9212
#
# Epoch 00496: val_accuracy did not improve from 0.94335
# Epoch 497/500
# 52/52 [==============================] - 20s 386ms/step - loss: 2.5180e-04 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.9236
#
# Epoch 00497: val_accuracy did not improve from 0.94335
# Epoch 498/500
# 52/52 [==============================] - 20s 388ms/step - loss: 1.7926e-04 - accuracy: 1.0000 - val_loss: 0.4213 - val_accuracy: 0.9335
#
# Epoch 00498: val_accuracy did not improve from 0.94335
# Epoch 499/500
# 52/52 [==============================] - 20s 387ms/step - loss: 1.0527e-04 - accuracy: 1.0000 - val_loss: 0.3762 - val_accuracy: 0.9261
#
# Epoch 00499: val_accuracy did not improve from 0.94335
# Epoch 500/500
# 52/52 [==============================] - 20s 387ms/step - loss: 1.4483e-04 - accuracy: 1.0000 - val_loss: 0.4469 - val_accuracy: 0.9138
#
# Epoch 00500: val_accuracy did not improve from 0.94335

# %%
import matplotlib.pyplot as plt

plt.plot(DenseNet121_model.history.history["accuracy"], label='DenseNet121_acc')
plt.plot(DenseNet121_model.history.history["val_accuracy"], label='DenseNet121_val')

plt.legend()
plt.show()

# %%
DenseNet121_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/WSR_020_4_DN121.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
DenseNet121_predict = DenseNet121_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["DenseNet121_predict"] = DenseNet121_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['DenseNet121_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]
submission.head()

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/WidthShiftRange_020_4_DenseNet121_model.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/WidthShiftRange_020_4_DenseNet121_model.csv')
