# %%
# !nvidia-smi
# Out:
# Fri Oct  1 15:57:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
nunbering = '7'
model_save = 'EfficientNetB' + nunbering + '_1'
Target_model = 'EfficientNetB' + nunbering + '_model'
Target_predict = 'EfficientNetB' + nunbering + '_predict'
Target_acc = 'EfficientNetB' + nunbering + '_acc'
Target_val = 'EfficientNetB' + nunbering + '_val'

# %%
import tensorflow as tf
Target_model =  tf.keras.applications.EfficientNetB7(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
Target_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator (
    rescale = 1./255, 
    validation_split = 0.075,
    rotation_range = 15,
    width_shift_range = 0.00,
    height_shift_range = 0.05 )

batch_size = 8
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1900 images belonging to 10 classes.
# Found 148 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
Target_model.fit_generator(train_generator, epochs = 500, validation_data=val_generator, callbacks=[checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 238/238 [==============================] - 153s 425ms/step - loss: 3.9242 - accuracy: 0.1042 - val_loss: 2.3255 - val_accuracy: 0.1014
#
# Epoch 00001: val_accuracy improved from -inf to 0.10135, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB7_1.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/500
# 238/238 [==============================] - 98s 412ms/step - loss: 2.5413 - accuracy: 0.1368 - val_loss: 2.3328 - val_accuracy: 0.1014
#
# Epoch 00002: val_accuracy did not improve from 0.10135
# Epoch 3/500
# 238/238 [==============================] - 96s 402ms/step - loss: 2.4433 - accuracy: 0.1784 - val_loss: 2.4287 - val_accuracy: 0.1014
#
# Epoch 00003: val_accuracy did not improve from 0.10135
# Epoch 4/500
# 238/238 [==============================] - 96s 404ms/step - loss: 2.2758 - accuracy: 0.2495 - val_loss: 2.2645 - val_accuracy: 0.3311
#
# Epoch 00004: val_accuracy improved from 0.10135 to 0.33108, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB7_1.h5
# Epoch 5/500
# 238/238 [==============================] - 98s 410ms/step - loss: 2.1905 - accuracy: 0.2821 - val_loss: 5.2789 - val_accuracy: 0.0878
#
# Epoch 00005: val_accuracy did not improve from 0.33108
# Epoch 6/500
# 238/238 [==============================] - 97s 406ms/step - loss: 2.1622 - accuracy: 0.2937 - val_loss: 4.9922 - val_accuracy: 0.3986
#
# Epoch 00006: val_accuracy improved from 0.33108 to 0.39865, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB7_1.h5
# Epoch 7/500
# 238/238 [==============================] - 97s 408ms/step - loss: 1.8694 - accuracy: 0.4211 - val_loss: 2.0358 - val_accuracy: 0.2973
#
# Epoch 00007: val_accuracy did not improve from 0.39865
# Epoch 8/500
# 238/238 [==============================] - 96s 403ms/step - loss: 1.7747 - accuracy: 0.4521 - val_loss: 2.6846 - val_accuracy: 0.1689
#
# Epoch 00008: val_accuracy did not improve from 0.39865
# Epoch 9/500
# 238/238 [==============================] - 97s 406ms/step - loss: 1.5778 - accuracy: 0.5079 - val_loss: 4.4001 - val_accuracy: 0.3851
#
# Epoch 00009: val_accuracy did not improve from 0.39865
# Epoch 10/500
# 238/238 [==============================] - 96s 403ms/step - loss: 1.4933 - accuracy: 0.5542 - val_loss: 3.5957 - val_accuracy: 0.1689
#
# Epoch 00010: val_accuracy did not improve from 0.39865
# Epoch 11/500
# 238/238 [==============================] - 96s 404ms/step - loss: 1.3666 - accuracy: 0.5742 - val_loss: 43.8284 - val_accuracy: 0.1149
#
# Epoch 00011: val_accuracy did not improve from 0.39865
# Epoch 12/500
# 238/238 [==============================] - 96s 404ms/step - loss: 1.1382 - accuracy: 0.6411 - val_loss: 0.9344 - val_accuracy: 0.7095
#
# Epoch 00012: val_accuracy improved from 0.39865 to 0.70946, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB7_1.h5
# Epoch 13/500
# 238/238 [==============================] - 97s 407ms/step - loss: 0.9678 - accuracy: 0.6984 - val_loss: 1.6414 - val_accuracy: 0.5338
#
# Epoch 00013: val_accuracy did not improve from 0.70946
# Epoch 14/500
# 238/238 [==============================] - 96s 403ms/step - loss: 0.8745 - accuracy: 0.7300 - val_loss: 0.6789 - val_accuracy: 0.7905
#
# Epoch 00014: val_accuracy improved from 0.70946 to 0.79054, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB7_1.h5
# Epoch 15/500
# 238/238 [==============================] - 97s 408ms/step - loss: 0.7891 - accuracy: 0.7474 - val_loss: 1.2534 - val_accuracy: 0.5676
#
# Epoch 00015: val_accuracy did not improve from 0.79054
# Epoch 16/500
# 238/238 [==============================] - 96s 405ms/step - loss: 0.7009 - accuracy: 0.7774 - val_loss: 0.6164 - val_accuracy: 0.7973
#
# Epoch 00016: val_accuracy improved from 0.79054 to 0.79730, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/EfficientNetB7_1.h5
# Epoch 17/500
# 238/238 [==============================] - 97s 408ms/step - loss: 0.7270 - accuracy: 0.7621 - val_loss: 0.7845 - val_accuracy: 0.7500
#
# Epoch 00017: val_accuracy did not improve from 0.79730
# Epoch 18/500
# 238/238 [==============================] - 96s 404ms/step - loss: 0.6913 - accuracy: 0.7837 - val_loss: 0.5712 - val_accuracy: 0.7838
#
# Epoch 00018: val_accuracy did not improve from 0.79730
# Epoch 19/500
# 238/238 [==============================] - 97s 409ms/step - loss: 0.5983 - accuracy: 0.8079 - val_loss: 0.9514 - val_accuracy: 0.7365
#
# Epoch 00019: val_accuracy did not improve from 0.79730

# %%
import matplotlib.pyplot as plt

plt.plot(Target_model.history.history["accuracy"], label = Target_acc)
plt.plot(Target_model.history.history["val_accuracy"], label = Target_val)

plt.legend()
plt.show()

# %%
Target_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/'+ model_save +'.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)

# %%
Target_predict = Target_model.predict_generator(test_generator).argmax(axis=1)

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["model_predict"] = Target_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['model_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/'+ model_save +'.csv')
