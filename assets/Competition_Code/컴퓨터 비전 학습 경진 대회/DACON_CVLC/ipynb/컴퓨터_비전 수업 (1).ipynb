# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

import tensorflow.keras.utils
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping


from google.colab import auth
from google.colab import drive
auth.authenticate_user()
drive.mount('/content/gdrive')
path = '/content/gdrive/MyDrive/Colab Notebooks/DACON_CV_award/data/'
# Out:
# Mounted at /content/gdrive

# %%
train_data = pd.read_csv(path+'train.csv')
test_data  = pd.read_csv(path+'test.csv')
sub_data   = pd.read_csv(path+'submission.csv')

# %%
def x_data(data):
    cols = [ col for col in data.columns if col in ['id', 'digit', 'letter']]
    x = data.drop(cols, axis=1).values
    x = x.reshape(-1, 28, 28, 1)
    x = x/255
    return x

def one_hot_encoding(data):
    y = data['digit']
    y_train = np.zeros((len(y), len(y.unique())))
    for i, digit in enumerate(y):
        y_train[i, digit] = 1
    return y_train

# %%
x_train = x_data(train_data)
x_test  = x_data(test_data)
y_train = one_hot_encoding(train_data)

# %%
model = Sequential()
model.add( Conv2D( 32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1) ) )
model.add( BatchNormalization() )
model.add( Dropout(0.2) )

model.add( Conv2D( 128, kernel_size=(3,3), activation='relu') )
model.add( Dropout(0.2) )

model.add( Conv2D( 128, kernel_size=(3,3), activation='relu') )
model.add( Conv2D( 64, kernel_size=(3,3), activation='relu') )
model.add( MaxPooling2D(pool_size=(2,2)) )
model.add( Flatten() )

model.add( Dense( 32, activation='relu') )
model.add( Dense( 10, activation='softmax') )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 26, 26, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       36992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 128)       147584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        73792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                204832
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 463,978
# Trainable params: 463,914
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile( loss='categorical_crossentropy',
               optimizer='adam',metrics=['accuracy'])

early_stopping = EarlyStopping(patience=20)
hist = model.fit( x_train, y_train, epochs=100, batch_size=40)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 32s 13ms/step - loss: 2.1428 - accuracy: 0.2056
# Epoch 2/100
# 52/52 [==============================] - 1s 10ms/step - loss: 1.6008 - accuracy: 0.4424
# Epoch 3/100
# 52/52 [==============================] - 0s 10ms/step - loss: 1.2573 - accuracy: 0.5825
# Epoch 4/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.9418 - accuracy: 0.7021
# Epoch 5/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.7449 - accuracy: 0.7617
# Epoch 6/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.5848 - accuracy: 0.8130
# Epoch 7/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.4527 - accuracy: 0.8457
# Epoch 8/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.3692 - accuracy: 0.8770
# Epoch 9/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.3043 - accuracy: 0.9019
# Epoch 10/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.2486 - accuracy: 0.9185
# Epoch 11/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.1763 - accuracy: 0.9419
# Epoch 12/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1617 - accuracy: 0.9409
# Epoch 13/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.1825 - accuracy: 0.9365
# Epoch 14/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1262 - accuracy: 0.9570
# Epoch 15/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0844 - accuracy: 0.9707
# Epoch 16/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0561 - accuracy: 0.9814
# Epoch 17/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0790 - accuracy: 0.9741
# Epoch 18/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0651 - accuracy: 0.9731
# Epoch 19/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0887 - accuracy: 0.9697
# Epoch 20/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0472 - accuracy: 0.9829
# Epoch 21/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0439 - accuracy: 0.9868
# Epoch 22/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0247 - accuracy: 0.9927
# Epoch 23/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0141 - accuracy: 0.9961
# Epoch 24/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0633 - accuracy: 0.9810
# Epoch 25/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0773 - accuracy: 0.9775
# Epoch 26/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0246 - accuracy: 0.9922
# Epoch 27/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0295 - accuracy: 0.9893
# Epoch 28/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0587 - accuracy: 0.9819
# Epoch 29/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0505 - accuracy: 0.9839
# Epoch 30/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0258 - accuracy: 0.9897
# Epoch 31/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0169 - accuracy: 0.9941
# Epoch 32/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0265 - accuracy: 0.9917
# Epoch 33/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0126 - accuracy: 0.9971
# Epoch 34/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0117 - accuracy: 0.9941
# Epoch 35/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0171 - accuracy: 0.9946
# Epoch 36/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0492 - accuracy: 0.9849
# Epoch 37/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0513 - accuracy: 0.9834
# Epoch 38/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0253 - accuracy: 0.9902
# Epoch 39/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0193 - accuracy: 0.9951
# Epoch 40/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0181 - accuracy: 0.9932
# Epoch 41/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0350 - accuracy: 0.9888
# Epoch 42/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0632 - accuracy: 0.9800
# Epoch 43/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0789 - accuracy: 0.9731
# Epoch 44/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0361 - accuracy: 0.9897
# Epoch 45/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0259 - accuracy: 0.9932
# Epoch 46/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0076 - accuracy: 0.9980
# Epoch 47/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0070 - accuracy: 0.9966
# Epoch 48/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 49/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 50/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0164 - accuracy: 0.9941
# Epoch 51/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0130 - accuracy: 0.9961
# Epoch 52/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0063 - accuracy: 0.9980
# Epoch 53/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0318 - accuracy: 0.9907
# Epoch 54/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0174 - accuracy: 0.9932
# Epoch 55/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0090 - accuracy: 0.9966
# Epoch 56/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0368 - accuracy: 0.9883
# Epoch 57/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0475 - accuracy: 0.9839
# Epoch 58/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0617 - accuracy: 0.9790
# Epoch 59/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0415 - accuracy: 0.9858
# Epoch 60/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0096 - accuracy: 0.9961
# Epoch 61/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0092 - accuracy: 0.9971
# Epoch 62/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0123 - accuracy: 0.9966
# Epoch 63/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0293 - accuracy: 0.9897
# Epoch 64/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0676 - accuracy: 0.9800
# Epoch 65/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0086 - accuracy: 0.9966
# Epoch 66/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 67/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0157 - accuracy: 0.9946
# Epoch 68/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0144 - accuracy: 0.9966
# Epoch 69/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 70/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0039 - accuracy: 0.9980
# Epoch 71/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0054 - accuracy: 0.9976
# Epoch 72/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0041 - accuracy: 0.9995
# Epoch 73/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0099 - accuracy: 0.9956
# Epoch 74/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0366 - accuracy: 0.9888
# Epoch 75/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0225 - accuracy: 0.9941
# Epoch 76/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0211 - accuracy: 0.9946
# Epoch 77/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0145 - accuracy: 0.9966
# Epoch 78/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0070 - accuracy: 0.9971
# Epoch 79/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0069 - accuracy: 0.9976
# Epoch 80/100
# 52/52 [==============================] - 1s 10ms/step - loss: 9.0609e-04 - accuracy: 1.0000
# Epoch 81/100
# 52/52 [==============================] - 1s 10ms/step - loss: 6.9245e-04 - accuracy: 1.0000
# Epoch 82/100
# 52/52 [==============================] - 1s 10ms/step - loss: 4.2463e-04 - accuracy: 1.0000
# Epoch 83/100
# 52/52 [==============================] - 1s 10ms/step - loss: 1.6076e-04 - accuracy: 1.0000
# Epoch 84/100
# 52/52 [==============================] - 1s 10ms/step - loss: 6.5138e-04 - accuracy: 0.9995
# Epoch 85/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0128 - accuracy: 0.9956
# Epoch 86/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0870 - accuracy: 0.9761
# Epoch 87/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.1250 - accuracy: 0.9634
# Epoch 88/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0191 - accuracy: 0.9937
# Epoch 89/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 90/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0079 - accuracy: 0.9980
# Epoch 91/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0071 - accuracy: 0.9980
# Epoch 92/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 93/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0084 - accuracy: 0.9976
# Epoch 94/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0028 - accuracy: 0.9995
# Epoch 95/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 96/100
# 52/52 [==============================] - 1s 10ms/step - loss: 4.9464e-04 - accuracy: 1.0000
# Epoch 97/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 98/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 99/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0247 - accuracy: 0.9912
# Epoch 100/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0102 - accuracy: 0.9980

# %%
fig, lss = plt.subplots()
acc = lss.twinx()

lss.plot(hist.history['loss'],    'r', label='train loss')
acc.plot(hist.history['accuracy'],'b', label='train acc')

lss.set_xlabel('epoch')
lss.set_ylabel('loss')
acc.set_ylabel('accuracy')

lss.legend(loc='upper left')
acc.legend(loc='lower left')

plt.show()

# %%
sub_data['digit'] = np.argmax(model.predict(x_test), axis=1)
sub_data.to_csv(path+'baseline.csv', index=False)
