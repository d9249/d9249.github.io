# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

import tensorflow.keras.utils
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from google.colab import auth
from google.colab import drive

auth.authenticate_user()
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/MyDrive/Colab Notebooks/DACON_CV_award/data/'

# %%
train_data = pd.read_csv(path+'train.csv')
test_data  = pd.read_csv(path+'test.csv')
sub_data   = pd.read_csv(path+'submission.csv')

# %%
def x_data(data):
    cols = [ col for col in data.columns if col in ['id', 'digit', 'letter']]
    x = data.drop(cols, axis=1).values
    x = x.reshape(-1, 28, 28, 1)
    x = x/255
    return x

def one_hot_encoding(data):
    y = data['digit']
    y_train = np.zeros((len(y), len(y.unique())))
    for i, digit in enumerate(y):
        y_train[i, digit] = 1
    return y_train

# %%
x_train = x_data(train_data)
x_test  = x_data(test_data)
y_train = one_hot_encoding(train_data)

# %%
model = Sequential()
model.add( Conv2D( 32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1) ) )
model.add( BatchNormalization() )
model.add( Dropout(0.2) )

model.add( Conv2D( 128, kernel_size=(3,3), activation='relu') )
model.add( Dropout(0.2) )

model.add( Conv2D( 128, kernel_size=(3,3), activation='relu') )
model.add( Conv2D( 64, kernel_size=(3,3), activation='relu') )
model.add( MaxPooling2D(pool_size=(2,2)) )
model.add( Flatten() )

model.add( Dense( 32, activation='relu') )
model.add( Dense( 10, activation='softmax') )

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 26, 26, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       36992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 128)       147584
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        73792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                204832
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 463,978
# Trainable params: 463,914
# Non-trainable params: 64
# _________________________________________________________________

# %%
model.compile( loss='categorical_crossentropy',
               optimizer='adam',metrics=['accuracy'])

early_stopping = EarlyStopping(patience=20)
hist = model.fit( x_train, y_train, epochs=100, batch_size=40)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 32s 12ms/step - loss: 2.1727 - accuracy: 0.1948
# Epoch 2/100
# 52/52 [==============================] - 0s 9ms/step - loss: 1.4778 - accuracy: 0.5024
# Epoch 3/100
# 52/52 [==============================] - 0s 9ms/step - loss: 1.0546 - accuracy: 0.6621
# Epoch 4/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.8404 - accuracy: 0.7256
# Epoch 5/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.6393 - accuracy: 0.7939
# Epoch 6/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.5011 - accuracy: 0.8345
# Epoch 7/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4144 - accuracy: 0.8643
# Epoch 8/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.3355 - accuracy: 0.8833
# Epoch 9/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.2694 - accuracy: 0.9053
# Epoch 10/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1988 - accuracy: 0.9326
# Epoch 11/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1609 - accuracy: 0.9468
# Epoch 12/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1415 - accuracy: 0.9502
# Epoch 13/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1127 - accuracy: 0.9600
# Epoch 14/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1471 - accuracy: 0.9502
# Epoch 15/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1323 - accuracy: 0.9517
# Epoch 16/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0596 - accuracy: 0.9795
# Epoch 17/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0307 - accuracy: 0.9897
# Epoch 18/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0418 - accuracy: 0.9878
# Epoch 19/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0521 - accuracy: 0.9824
# Epoch 20/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0437 - accuracy: 0.9858
# Epoch 21/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0406 - accuracy: 0.9868
# Epoch 22/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0306 - accuracy: 0.9893
# Epoch 23/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0540 - accuracy: 0.9810
# Epoch 24/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.1255 - accuracy: 0.9609
# Epoch 25/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0625 - accuracy: 0.9819
# Epoch 26/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0336 - accuracy: 0.9888
# Epoch 27/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9976
# Epoch 28/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0178 - accuracy: 0.9951
# Epoch 29/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0173 - accuracy: 0.9927
# Epoch 30/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0598 - accuracy: 0.9810
# Epoch 31/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0647 - accuracy: 0.9785
# Epoch 32/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0341 - accuracy: 0.9897
# Epoch 33/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0314 - accuracy: 0.9893
# Epoch 34/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0267 - accuracy: 0.9897
# Epoch 35/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0276 - accuracy: 0.9922
# Epoch 36/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0188 - accuracy: 0.9937
# Epoch 37/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0826 - accuracy: 0.9780
# Epoch 38/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0380 - accuracy: 0.9897
# Epoch 39/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0246 - accuracy: 0.9907
# Epoch 40/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0234 - accuracy: 0.9927
# Epoch 41/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0133 - accuracy: 0.9966
# Epoch 42/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0375 - accuracy: 0.9888
# Epoch 43/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0097 - accuracy: 0.9976
# Epoch 44/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0111 - accuracy: 0.9946
# Epoch 45/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0196 - accuracy: 0.9932
# Epoch 46/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0482 - accuracy: 0.9863
# Epoch 47/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0323 - accuracy: 0.9868
# Epoch 48/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0458 - accuracy: 0.9829
# Epoch 49/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0286 - accuracy: 0.9912
# Epoch 50/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0109 - accuracy: 0.9956
# Epoch 51/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0087 - accuracy: 0.9985
# Epoch 52/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 0.9980
# Epoch 53/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 0.9985
# Epoch 54/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0128 - accuracy: 0.9951
# Epoch 55/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 0.9966
# Epoch 56/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 0.9971
# Epoch 57/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0255 - accuracy: 0.9912
# Epoch 58/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0516 - accuracy: 0.9839
# Epoch 59/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0466 - accuracy: 0.9854
# Epoch 60/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0165 - accuracy: 0.9917
# Epoch 61/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0127 - accuracy: 0.9961
# Epoch 62/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 63/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0141 - accuracy: 0.9976
# Epoch 64/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0143 - accuracy: 0.9961
# Epoch 65/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0164 - accuracy: 0.9956
# Epoch 66/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0245 - accuracy: 0.9922
# Epoch 67/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0166 - accuracy: 0.9946
# Epoch 68/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0274 - accuracy: 0.9922
# Epoch 69/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0171 - accuracy: 0.9937
# Epoch 70/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0390 - accuracy: 0.9893
# Epoch 71/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0403 - accuracy: 0.9883
# Epoch 72/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0434 - accuracy: 0.9819
# Epoch 73/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0185 - accuracy: 0.9937
# Epoch 74/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0397 - accuracy: 0.9854
# Epoch 75/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0212 - accuracy: 0.9922
# Epoch 76/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0227 - accuracy: 0.9917
# Epoch 77/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0357 - accuracy: 0.9897
# Epoch 78/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0287 - accuracy: 0.9902
# Epoch 79/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0413 - accuracy: 0.9883
# Epoch 80/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0107 - accuracy: 0.9980
# Epoch 81/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0092 - accuracy: 0.9966
# Epoch 82/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 83/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 0.9980
# Epoch 84/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0256 - accuracy: 0.9922
# Epoch 85/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0095 - accuracy: 0.9971
# Epoch 86/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0072 - accuracy: 0.9961
# Epoch 87/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0189 - accuracy: 0.9932
# Epoch 88/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 0.9980
# Epoch 89/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.9985
# Epoch 90/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0155 - accuracy: 0.9946
# Epoch 91/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0379 - accuracy: 0.9868
# Epoch 92/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0140 - accuracy: 0.9941
# Epoch 93/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0349 - accuracy: 0.9873
# Epoch 94/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0460 - accuracy: 0.9854
# Epoch 95/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0261 - accuracy: 0.9927
# Epoch 96/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0361 - accuracy: 0.9893
# Epoch 97/100
# 52/52 [==============================] - 0s 10ms/step - loss: 0.0250 - accuracy: 0.9937
# Epoch 98/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0302 - accuracy: 0.9922
# Epoch 99/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.0233 - accuracy: 0.9937
# Epoch 100/100
# 52/52 [==============================] - 1s 10ms/step - loss: 0.0109 - accuracy: 0.9976

# %%
fig, lss = plt.subplots()
acc = lss.twinx()

lss.plot(hist.history['loss'],    'r', label='train loss')
acc.plot(hist.history['accuracy'],'b', label='train acc')

lss.set_xlabel('epoch')
lss.set_ylabel('loss')
acc.set_ylabel('accuracy')

lss.legend(loc='upper left')
acc.legend(loc='lower left')

plt.show()

# %%
sub_data['digit'] = np.argmax(model.predict(x_test), axis=1)
sub_data.to_csv(path+'baseline.csv', index=False)
