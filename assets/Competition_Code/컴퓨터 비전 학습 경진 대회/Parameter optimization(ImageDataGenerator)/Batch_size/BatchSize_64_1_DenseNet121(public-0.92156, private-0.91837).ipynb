# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/BatchSize_64_1_DenseNet121(public-%2C%20private-).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Sep  5 12:15:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/test.csv')

# %%
# !mkdir images_train
# !mkdir images_train/0
# !mkdir images_train/1
# !mkdir images_train/2
# !mkdir images_train/3
# !mkdir images_train/4
# !mkdir images_train/5
# !mkdir images_train/6
# !mkdir images_train/7
# !mkdir images_train/8
# !mkdir images_train/9
# !mkdir images_test

# %%
import cv2

for idx in range(len(train)) :
    img = train.loc[idx, '0':].values.reshape(28, 28).astype(int)
    digit = train.loc[idx, 'digit']
    cv2.imwrite(f'./images_train/{digit}/{train["id"][idx]}.png', img)

# %%
import cv2

for idx in range(len(test)) :
    img = test.loc[idx, '0':].values.reshape(28, 28).astype(int)
    cv2.imwrite(f'./images_test/{test["id"][idx]}.png', img)

# %%
import tensorflow as tf
DenseNet121_model = tf.keras.applications.DenseNet121(weights=None, include_top=True, input_shape=(224, 224, 1), classes=10)

# %%
from tensorflow.keras.optimizers import Adam
DenseNet121_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.002,epsilon=None), metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
                             rescale=1./255, 
                             validation_split=0.2,
                             rotation_range=10,
                             width_shift_range=0.1,
                             height_shift_range=0.1)

batch_size = 64
train_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size, color_mode='grayscale', class_mode='categorical', subset='training')
val_generator = datagen.flow_from_directory('./images_train', target_size=(224,224), batch_size = batch_size,  color_mode='grayscale', class_mode='categorical', subset='validation')
# Out:
# Found 1642 images belonging to 10 classes.
# Found 406 images belonging to 10 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(f'/content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# %%
DenseNet121_model.fit_generator(train_generator, epochs = 500, validation_data = val_generator, callbacks = [checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/500
# 26/26 [==============================] - 43s 556ms/step - loss: 1.7947 - accuracy: 0.3569 - val_loss: 3.4779 - val_accuracy: 0.1552
#
# Epoch 00001: val_accuracy improved from -inf to 0.15517, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 2/500
# 26/26 [==============================] - 11s 396ms/step - loss: 1.1357 - accuracy: 0.6206 - val_loss: 8.3144 - val_accuracy: 0.0862
#
# Epoch 00002: val_accuracy did not improve from 0.15517
# Epoch 3/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.8384 - accuracy: 0.7174 - val_loss: 19.1999 - val_accuracy: 0.0936
#
# Epoch 00003: val_accuracy did not improve from 0.15517
# Epoch 4/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.7428 - accuracy: 0.7479 - val_loss: 20.2989 - val_accuracy: 0.1010
#
# Epoch 00004: val_accuracy did not improve from 0.15517
# Epoch 5/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.6262 - accuracy: 0.7996 - val_loss: 19.8856 - val_accuracy: 0.1010
#
# Epoch 00005: val_accuracy did not improve from 0.15517
# Epoch 6/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.5696 - accuracy: 0.8063 - val_loss: 12.7985 - val_accuracy: 0.0739
#
# Epoch 00006: val_accuracy did not improve from 0.15517
# Epoch 7/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.5247 - accuracy: 0.8167 - val_loss: 26.8059 - val_accuracy: 0.0739
#
# Epoch 00007: val_accuracy did not improve from 0.15517
# Epoch 8/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.4716 - accuracy: 0.8374 - val_loss: 3.9412 - val_accuracy: 0.0616
#
# Epoch 00008: val_accuracy did not improve from 0.15517
# Epoch 9/500
# 26/26 [==============================] - 11s 405ms/step - loss: 0.4145 - accuracy: 0.8642 - val_loss: 9.7177 - val_accuracy: 0.1010
#
# Epoch 00009: val_accuracy did not improve from 0.15517
# Epoch 10/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.3701 - accuracy: 0.8691 - val_loss: 6.7111 - val_accuracy: 0.1084
#
# Epoch 00010: val_accuracy did not improve from 0.15517
# Epoch 11/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.3187 - accuracy: 0.8898 - val_loss: 10.9071 - val_accuracy: 0.1281
#
# Epoch 00011: val_accuracy did not improve from 0.15517
# Epoch 12/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.3110 - accuracy: 0.8965 - val_loss: 5.6535 - val_accuracy: 0.1798
#
# Epoch 00012: val_accuracy improved from 0.15517 to 0.17980, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 13/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.2698 - accuracy: 0.9062 - val_loss: 15.0686 - val_accuracy: 0.1256
#
# Epoch 00013: val_accuracy did not improve from 0.17980
# Epoch 14/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.2835 - accuracy: 0.8989 - val_loss: 13.9685 - val_accuracy: 0.1379
#
# Epoch 00014: val_accuracy did not improve from 0.17980
# Epoch 15/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.3127 - accuracy: 0.8946 - val_loss: 4.0245 - val_accuracy: 0.3571
#
# Epoch 00015: val_accuracy improved from 0.17980 to 0.35714, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 16/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.3018 - accuracy: 0.8989 - val_loss: 2.5612 - val_accuracy: 0.4532
#
# Epoch 00016: val_accuracy improved from 0.35714 to 0.45320, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 17/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.2217 - accuracy: 0.9239 - val_loss: 2.3881 - val_accuracy: 0.5000
#
# Epoch 00017: val_accuracy improved from 0.45320 to 0.50000, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 18/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.2323 - accuracy: 0.9184 - val_loss: 1.4901 - val_accuracy: 0.6626
#
# Epoch 00018: val_accuracy improved from 0.50000 to 0.66256, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 19/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.2159 - accuracy: 0.9318 - val_loss: 2.2676 - val_accuracy: 0.5640
#
# Epoch 00019: val_accuracy did not improve from 0.66256
# Epoch 20/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.1642 - accuracy: 0.9482 - val_loss: 1.5727 - val_accuracy: 0.5936
#
# Epoch 00020: val_accuracy did not improve from 0.66256
# Epoch 21/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.1554 - accuracy: 0.9495 - val_loss: 1.1133 - val_accuracy: 0.7241
#
# Epoch 00021: val_accuracy improved from 0.66256 to 0.72414, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 22/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1563 - accuracy: 0.9488 - val_loss: 0.5937 - val_accuracy: 0.8300
#
# Epoch 00022: val_accuracy improved from 0.72414 to 0.83005, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 23/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1418 - accuracy: 0.9525 - val_loss: 0.5834 - val_accuracy: 0.8103
#
# Epoch 00023: val_accuracy did not improve from 0.83005
# Epoch 24/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1555 - accuracy: 0.9507 - val_loss: 1.0983 - val_accuracy: 0.7241
#
# Epoch 00024: val_accuracy did not improve from 0.83005
# Epoch 25/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1216 - accuracy: 0.9610 - val_loss: 0.7340 - val_accuracy: 0.8251
#
# Epoch 00025: val_accuracy did not improve from 0.83005
# Epoch 26/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1620 - accuracy: 0.9367 - val_loss: 1.3391 - val_accuracy: 0.6552
#
# Epoch 00026: val_accuracy did not improve from 0.83005
# Epoch 27/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1987 - accuracy: 0.9354 - val_loss: 0.9256 - val_accuracy: 0.7463
#
# Epoch 00027: val_accuracy did not improve from 0.83005
# Epoch 28/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.1432 - accuracy: 0.9501 - val_loss: 0.7869 - val_accuracy: 0.7980
#
# Epoch 00028: val_accuracy did not improve from 0.83005
# Epoch 29/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.1418 - accuracy: 0.9519 - val_loss: 1.3458 - val_accuracy: 0.6724
#
# Epoch 00029: val_accuracy did not improve from 0.83005
# Epoch 30/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.1395 - accuracy: 0.9586 - val_loss: 1.2313 - val_accuracy: 0.7562
#
# Epoch 00030: val_accuracy did not improve from 0.83005
# Epoch 31/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0961 - accuracy: 0.9702 - val_loss: 0.4876 - val_accuracy: 0.8818
#
# Epoch 00031: val_accuracy improved from 0.83005 to 0.88177, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 32/500
# 26/26 [==============================] - 11s 403ms/step - loss: 0.1183 - accuracy: 0.9592 - val_loss: 0.9247 - val_accuracy: 0.7660
#
# Epoch 00032: val_accuracy did not improve from 0.88177
# Epoch 33/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.1151 - accuracy: 0.9641 - val_loss: 1.0715 - val_accuracy: 0.7266
#
# Epoch 00033: val_accuracy did not improve from 0.88177
# Epoch 34/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0935 - accuracy: 0.9708 - val_loss: 0.8346 - val_accuracy: 0.7931
#
# Epoch 00034: val_accuracy did not improve from 0.88177
# Epoch 35/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0869 - accuracy: 0.9738 - val_loss: 0.8340 - val_accuracy: 0.7833
#
# Epoch 00035: val_accuracy did not improve from 0.88177
# Epoch 36/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0880 - accuracy: 0.9695 - val_loss: 0.7003 - val_accuracy: 0.8202
#
# Epoch 00036: val_accuracy did not improve from 0.88177
# Epoch 37/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.1155 - accuracy: 0.9622 - val_loss: 0.8888 - val_accuracy: 0.7906
#
# Epoch 00037: val_accuracy did not improve from 0.88177
# Epoch 38/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.1071 - accuracy: 0.9598 - val_loss: 2.1380 - val_accuracy: 0.6429
#
# Epoch 00038: val_accuracy did not improve from 0.88177
# Epoch 39/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.1127 - accuracy: 0.9629 - val_loss: 1.3290 - val_accuracy: 0.7044
#
# Epoch 00039: val_accuracy did not improve from 0.88177
# Epoch 40/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.1190 - accuracy: 0.9616 - val_loss: 0.6888 - val_accuracy: 0.8251
#
# Epoch 00040: val_accuracy did not improve from 0.88177
# Epoch 41/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0774 - accuracy: 0.9738 - val_loss: 1.1484 - val_accuracy: 0.7315
#
# Epoch 00041: val_accuracy did not improve from 0.88177
# Epoch 42/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0650 - accuracy: 0.9781 - val_loss: 0.8477 - val_accuracy: 0.7759
#
# Epoch 00042: val_accuracy did not improve from 0.88177
# Epoch 43/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0758 - accuracy: 0.9762 - val_loss: 1.2255 - val_accuracy: 0.7020
#
# Epoch 00043: val_accuracy did not improve from 0.88177
# Epoch 44/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0822 - accuracy: 0.9720 - val_loss: 0.8939 - val_accuracy: 0.7857
#
# Epoch 00044: val_accuracy did not improve from 0.88177
# Epoch 45/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0996 - accuracy: 0.9629 - val_loss: 0.9354 - val_accuracy: 0.7709
#
# Epoch 00045: val_accuracy did not improve from 0.88177
# Epoch 46/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0729 - accuracy: 0.9756 - val_loss: 0.7306 - val_accuracy: 0.8227
#
# Epoch 00046: val_accuracy did not improve from 0.88177
# Epoch 47/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0499 - accuracy: 0.9805 - val_loss: 0.5811 - val_accuracy: 0.8448
#
# Epoch 00047: val_accuracy did not improve from 0.88177
# Epoch 48/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 0.8778 - val_accuracy: 0.7783
#
# Epoch 00048: val_accuracy did not improve from 0.88177
# Epoch 49/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0846 - accuracy: 0.9732 - val_loss: 0.5210 - val_accuracy: 0.8547
#
# Epoch 00049: val_accuracy did not improve from 0.88177
# Epoch 50/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0632 - accuracy: 0.9823 - val_loss: 1.3867 - val_accuracy: 0.6798
#
# Epoch 00050: val_accuracy did not improve from 0.88177
# Epoch 51/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0620 - accuracy: 0.9823 - val_loss: 0.5502 - val_accuracy: 0.8719
#
# Epoch 00051: val_accuracy did not improve from 0.88177
# Epoch 52/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0847 - accuracy: 0.9714 - val_loss: 0.9222 - val_accuracy: 0.7759
#
# Epoch 00052: val_accuracy did not improve from 0.88177
# Epoch 53/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0754 - accuracy: 0.9714 - val_loss: 1.0781 - val_accuracy: 0.7783
#
# Epoch 00053: val_accuracy did not improve from 0.88177
# Epoch 54/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0428 - accuracy: 0.9854 - val_loss: 0.8665 - val_accuracy: 0.7808
#
# Epoch 00054: val_accuracy did not improve from 0.88177
# Epoch 55/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0322 - accuracy: 0.9896 - val_loss: 0.4843 - val_accuracy: 0.8645
#
# Epoch 00055: val_accuracy did not improve from 0.88177
# Epoch 56/500
# 26/26 [==============================] - 10s 395ms/step - loss: 0.0355 - accuracy: 0.9866 - val_loss: 0.6830 - val_accuracy: 0.8399
#
# Epoch 00056: val_accuracy did not improve from 0.88177
# Epoch 57/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0519 - accuracy: 0.9811 - val_loss: 0.5123 - val_accuracy: 0.8744
#
# Epoch 00057: val_accuracy did not improve from 0.88177
# Epoch 58/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0747 - accuracy: 0.9726 - val_loss: 0.9449 - val_accuracy: 0.7808
#
# Epoch 00058: val_accuracy did not improve from 0.88177
# Epoch 59/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0485 - accuracy: 0.9811 - val_loss: 1.2438 - val_accuracy: 0.7266
#
# Epoch 00059: val_accuracy did not improve from 0.88177
# Epoch 60/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0477 - accuracy: 0.9860 - val_loss: 1.1744 - val_accuracy: 0.7340
#
# Epoch 00060: val_accuracy did not improve from 0.88177
# Epoch 61/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0459 - accuracy: 0.9884 - val_loss: 2.1749 - val_accuracy: 0.6429
#
# Epoch 00061: val_accuracy did not improve from 0.88177
# Epoch 62/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0391 - accuracy: 0.9890 - val_loss: 0.4960 - val_accuracy: 0.8448
#
# Epoch 00062: val_accuracy did not improve from 0.88177
# Epoch 63/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0326 - accuracy: 0.9884 - val_loss: 0.8379 - val_accuracy: 0.7882
#
# Epoch 00063: val_accuracy did not improve from 0.88177
# Epoch 64/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0298 - accuracy: 0.9872 - val_loss: 0.7817 - val_accuracy: 0.8177
#
# Epoch 00064: val_accuracy did not improve from 0.88177
# Epoch 65/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0510 - accuracy: 0.9811 - val_loss: 0.7897 - val_accuracy: 0.7783
#
# Epoch 00065: val_accuracy did not improve from 0.88177
# Epoch 66/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0674 - accuracy: 0.9769 - val_loss: 0.8775 - val_accuracy: 0.8103
#
# Epoch 00066: val_accuracy did not improve from 0.88177
# Epoch 67/500
# 26/26 [==============================] - 10s 403ms/step - loss: 0.0732 - accuracy: 0.9769 - val_loss: 4.1489 - val_accuracy: 0.5665
#
# Epoch 00067: val_accuracy did not improve from 0.88177
# Epoch 68/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0354 - accuracy: 0.9884 - val_loss: 0.7479 - val_accuracy: 0.8251
#
# Epoch 00068: val_accuracy did not improve from 0.88177
# Epoch 69/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0370 - accuracy: 0.9860 - val_loss: 0.6560 - val_accuracy: 0.8350
#
# Epoch 00069: val_accuracy did not improve from 0.88177
# Epoch 70/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0290 - accuracy: 0.9903 - val_loss: 0.7547 - val_accuracy: 0.8448
#
# Epoch 00070: val_accuracy did not improve from 0.88177
# Epoch 71/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0406 - accuracy: 0.9896 - val_loss: 0.7625 - val_accuracy: 0.8276
#
# Epoch 00071: val_accuracy did not improve from 0.88177
# Epoch 72/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0345 - accuracy: 0.9903 - val_loss: 0.6003 - val_accuracy: 0.8719
#
# Epoch 00072: val_accuracy did not improve from 0.88177
# Epoch 73/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0287 - accuracy: 0.9915 - val_loss: 0.5799 - val_accuracy: 0.8744
#
# Epoch 00073: val_accuracy did not improve from 0.88177
# Epoch 74/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0422 - accuracy: 0.9866 - val_loss: 0.7993 - val_accuracy: 0.8005
#
# Epoch 00074: val_accuracy did not improve from 0.88177
# Epoch 75/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0381 - accuracy: 0.9872 - val_loss: 0.5638 - val_accuracy: 0.8325
#
# Epoch 00075: val_accuracy did not improve from 0.88177
# Epoch 76/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 0.8643 - val_accuracy: 0.8276
#
# Epoch 00076: val_accuracy did not improve from 0.88177
# Epoch 77/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0306 - accuracy: 0.9915 - val_loss: 0.4689 - val_accuracy: 0.8645
#
# Epoch 00077: val_accuracy did not improve from 0.88177
# Epoch 78/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0466 - accuracy: 0.9860 - val_loss: 0.7238 - val_accuracy: 0.8522
#
# Epoch 00078: val_accuracy did not improve from 0.88177
# Epoch 79/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0713 - accuracy: 0.9750 - val_loss: 4.0593 - val_accuracy: 0.4606
#
# Epoch 00079: val_accuracy did not improve from 0.88177
# Epoch 80/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0706 - accuracy: 0.9720 - val_loss: 2.6965 - val_accuracy: 0.6232
#
# Epoch 00080: val_accuracy did not improve from 0.88177
# Epoch 81/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0625 - accuracy: 0.9793 - val_loss: 1.0613 - val_accuracy: 0.7931
#
# Epoch 00081: val_accuracy did not improve from 0.88177
# Epoch 82/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0598 - accuracy: 0.9793 - val_loss: 0.7089 - val_accuracy: 0.8522
#
# Epoch 00082: val_accuracy did not improve from 0.88177
# Epoch 83/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0947 - accuracy: 0.9677 - val_loss: 0.7671 - val_accuracy: 0.8448
#
# Epoch 00083: val_accuracy did not improve from 0.88177
# Epoch 84/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0621 - accuracy: 0.9744 - val_loss: 1.3873 - val_accuracy: 0.7266
#
# Epoch 00084: val_accuracy did not improve from 0.88177
# Epoch 85/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0449 - accuracy: 0.9854 - val_loss: 0.6909 - val_accuracy: 0.8177
#
# Epoch 00085: val_accuracy did not improve from 0.88177
# Epoch 86/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0318 - accuracy: 0.9866 - val_loss: 1.0113 - val_accuracy: 0.7365
#
# Epoch 00086: val_accuracy did not improve from 0.88177
# Epoch 87/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0405 - accuracy: 0.9842 - val_loss: 0.6040 - val_accuracy: 0.8645
#
# Epoch 00087: val_accuracy did not improve from 0.88177
# Epoch 88/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0296 - accuracy: 0.9915 - val_loss: 0.6335 - val_accuracy: 0.8522
#
# Epoch 00088: val_accuracy did not improve from 0.88177
# Epoch 89/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0182 - accuracy: 0.9933 - val_loss: 0.9123 - val_accuracy: 0.7808
#
# Epoch 00089: val_accuracy did not improve from 0.88177
# Epoch 90/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.8139 - val_accuracy: 0.8547
#
# Epoch 00090: val_accuracy did not improve from 0.88177
# Epoch 91/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0450 - accuracy: 0.9860 - val_loss: 0.8439 - val_accuracy: 0.8251
#
# Epoch 00091: val_accuracy did not improve from 0.88177
# Epoch 92/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0369 - accuracy: 0.9890 - val_loss: 0.9581 - val_accuracy: 0.8374
#
# Epoch 00092: val_accuracy did not improve from 0.88177
# Epoch 93/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0200 - accuracy: 0.9945 - val_loss: 0.6650 - val_accuracy: 0.8695
#
# Epoch 00093: val_accuracy did not improve from 0.88177
# Epoch 94/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.5616 - val_accuracy: 0.8867
#
# Epoch 00094: val_accuracy improved from 0.88177 to 0.88670, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 95/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0062 - accuracy: 0.9988 - val_loss: 0.4287 - val_accuracy: 0.8966
#
# Epoch 00095: val_accuracy improved from 0.88670 to 0.89655, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 96/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3931 - val_accuracy: 0.9163
#
# Epoch 00096: val_accuracy improved from 0.89655 to 0.91626, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 97/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.3989 - val_accuracy: 0.9089
#
# Epoch 00097: val_accuracy did not improve from 0.91626
# Epoch 98/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.3996 - val_accuracy: 0.8916
#
# Epoch 00098: val_accuracy did not improve from 0.91626
# Epoch 99/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0166 - accuracy: 0.9939 - val_loss: 0.5993 - val_accuracy: 0.8842
#
# Epoch 00099: val_accuracy did not improve from 0.91626
# Epoch 100/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0186 - accuracy: 0.9927 - val_loss: 0.5853 - val_accuracy: 0.8842
#
# Epoch 00100: val_accuracy did not improve from 0.91626
# Epoch 101/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.6267 - val_accuracy: 0.8547
#
# Epoch 00101: val_accuracy did not improve from 0.91626
# Epoch 102/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0282 - accuracy: 0.9890 - val_loss: 1.1594 - val_accuracy: 0.7956
#
# Epoch 00102: val_accuracy did not improve from 0.91626
# Epoch 103/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0268 - accuracy: 0.9933 - val_loss: 1.0285 - val_accuracy: 0.7586
#
# Epoch 00103: val_accuracy did not improve from 0.91626
# Epoch 104/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0123 - accuracy: 0.9976 - val_loss: 0.6641 - val_accuracy: 0.8300
#
# Epoch 00104: val_accuracy did not improve from 0.91626
# Epoch 105/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 0.5985 - val_accuracy: 0.8842
#
# Epoch 00105: val_accuracy did not improve from 0.91626
# Epoch 106/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0253 - accuracy: 0.9927 - val_loss: 0.8085 - val_accuracy: 0.8177
#
# Epoch 00106: val_accuracy did not improve from 0.91626
# Epoch 107/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0350 - accuracy: 0.9860 - val_loss: 2.1321 - val_accuracy: 0.7094
#
# Epoch 00107: val_accuracy did not improve from 0.91626
# Epoch 108/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0407 - accuracy: 0.9872 - val_loss: 0.8615 - val_accuracy: 0.8251
#
# Epoch 00108: val_accuracy did not improve from 0.91626
# Epoch 109/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0804 - accuracy: 0.9769 - val_loss: 0.6248 - val_accuracy: 0.8177
#
# Epoch 00109: val_accuracy did not improve from 0.91626
# Epoch 110/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.1036 - accuracy: 0.9689 - val_loss: 1.6106 - val_accuracy: 0.6700
#
# Epoch 00110: val_accuracy did not improve from 0.91626
# Epoch 111/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0737 - accuracy: 0.9744 - val_loss: 1.0782 - val_accuracy: 0.7709
#
# Epoch 00111: val_accuracy did not improve from 0.91626
# Epoch 112/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0381 - accuracy: 0.9854 - val_loss: 1.1358 - val_accuracy: 0.7635
#
# Epoch 00112: val_accuracy did not improve from 0.91626
# Epoch 113/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0261 - accuracy: 0.9945 - val_loss: 0.6560 - val_accuracy: 0.8399
#
# Epoch 00113: val_accuracy did not improve from 0.91626
# Epoch 114/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.7752 - val_accuracy: 0.8153
#
# Epoch 00114: val_accuracy did not improve from 0.91626
# Epoch 115/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.5972 - val_accuracy: 0.8645
#
# Epoch 00115: val_accuracy did not improve from 0.91626
# Epoch 116/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.5249 - val_accuracy: 0.8768
#
# Epoch 00116: val_accuracy did not improve from 0.91626
# Epoch 117/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.5427 - val_accuracy: 0.8842
#
# Epoch 00117: val_accuracy did not improve from 0.91626
# Epoch 118/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.5059 - val_accuracy: 0.8867
#
# Epoch 00118: val_accuracy did not improve from 0.91626
# Epoch 119/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 0.5163 - val_accuracy: 0.8892
#
# Epoch 00119: val_accuracy did not improve from 0.91626
# Epoch 120/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0478 - accuracy: 0.9842 - val_loss: 0.8661 - val_accuracy: 0.8522
#
# Epoch 00120: val_accuracy did not improve from 0.91626
# Epoch 121/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0321 - accuracy: 0.9927 - val_loss: 0.7946 - val_accuracy: 0.8596
#
# Epoch 00121: val_accuracy did not improve from 0.91626
# Epoch 122/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0299 - accuracy: 0.9909 - val_loss: 1.1280 - val_accuracy: 0.8300
#
# Epoch 00122: val_accuracy did not improve from 0.91626
# Epoch 123/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0202 - accuracy: 0.9915 - val_loss: 1.0501 - val_accuracy: 0.8054
#
# Epoch 00123: val_accuracy did not improve from 0.91626
# Epoch 124/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0087 - accuracy: 0.9982 - val_loss: 0.6086 - val_accuracy: 0.8818
#
# Epoch 00124: val_accuracy did not improve from 0.91626
# Epoch 125/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.3913 - val_accuracy: 0.9015
#
# Epoch 00125: val_accuracy did not improve from 0.91626
# Epoch 126/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3807 - val_accuracy: 0.9236
#
# Epoch 00126: val_accuracy improved from 0.91626 to 0.92365, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 127/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.3902 - val_accuracy: 0.9187
#
# Epoch 00127: val_accuracy did not improve from 0.92365
# Epoch 128/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.4383 - val_accuracy: 0.9261
#
# Epoch 00128: val_accuracy improved from 0.92365 to 0.92611, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 129/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.6037 - val_accuracy: 0.8916
#
# Epoch 00129: val_accuracy did not improve from 0.92611
# Epoch 130/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0169 - accuracy: 0.9963 - val_loss: 0.7285 - val_accuracy: 0.8473
#
# Epoch 00130: val_accuracy did not improve from 0.92611
# Epoch 131/500
# 26/26 [==============================] - 10s 397ms/step - loss: 0.0382 - accuracy: 0.9884 - val_loss: 0.7656 - val_accuracy: 0.8768
#
# Epoch 00131: val_accuracy did not improve from 0.92611
# Epoch 132/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0901 - accuracy: 0.9726 - val_loss: 1.6188 - val_accuracy: 0.7365
#
# Epoch 00132: val_accuracy did not improve from 0.92611
# Epoch 133/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0985 - accuracy: 0.9708 - val_loss: 1.2725 - val_accuracy: 0.7931
#
# Epoch 00133: val_accuracy did not improve from 0.92611
# Epoch 134/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0902 - accuracy: 0.9720 - val_loss: 2.3812 - val_accuracy: 0.6379
#
# Epoch 00134: val_accuracy did not improve from 0.92611
# Epoch 135/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0880 - accuracy: 0.9714 - val_loss: 1.2113 - val_accuracy: 0.7512
#
# Epoch 00135: val_accuracy did not improve from 0.92611
# Epoch 136/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0472 - accuracy: 0.9842 - val_loss: 1.3414 - val_accuracy: 0.7143
#
# Epoch 00136: val_accuracy did not improve from 0.92611
# Epoch 137/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0464 - accuracy: 0.9872 - val_loss: 0.7968 - val_accuracy: 0.8177
#
# Epoch 00137: val_accuracy did not improve from 0.92611
# Epoch 138/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.9185 - val_accuracy: 0.8153
#
# Epoch 00138: val_accuracy did not improve from 0.92611
# Epoch 139/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.7432 - val_accuracy: 0.8153
#
# Epoch 00139: val_accuracy did not improve from 0.92611
# Epoch 140/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.8526 - val_accuracy: 0.7833
#
# Epoch 00140: val_accuracy did not improve from 0.92611
# Epoch 141/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.5932 - val_accuracy: 0.8350
#
# Epoch 00141: val_accuracy did not improve from 0.92611
# Epoch 142/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.4656 - val_accuracy: 0.8818
#
# Epoch 00142: val_accuracy did not improve from 0.92611
# Epoch 143/500
# 26/26 [==============================] - 11s 397ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3786 - val_accuracy: 0.8990
#
# Epoch 00143: val_accuracy did not improve from 0.92611
# Epoch 144/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.3394 - val_accuracy: 0.9138
#
# Epoch 00144: val_accuracy did not improve from 0.92611
# Epoch 145/500
# 26/26 [==============================] - 10s 396ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.9187
#
# Epoch 00145: val_accuracy did not improve from 0.92611
# Epoch 146/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.9236
#
# Epoch 00146: val_accuracy did not improve from 0.92611
# Epoch 147/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3622 - val_accuracy: 0.9187
#
# Epoch 00147: val_accuracy did not improve from 0.92611
# Epoch 148/500
# 26/26 [==============================] - 11s 399ms/step - loss: 6.2223e-04 - accuracy: 1.0000 - val_loss: 0.3246 - val_accuracy: 0.9163
#
# Epoch 00148: val_accuracy did not improve from 0.92611
# Epoch 149/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3933 - val_accuracy: 0.9236
#
# Epoch 00149: val_accuracy did not improve from 0.92611
# Epoch 150/500
# 26/26 [==============================] - 11s 399ms/step - loss: 6.0564e-04 - accuracy: 1.0000 - val_loss: 0.3590 - val_accuracy: 0.9212
#
# Epoch 00150: val_accuracy did not improve from 0.92611
# Epoch 151/500
# 26/26 [==============================] - 11s 398ms/step - loss: 3.6412e-04 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9310
#
# Epoch 00151: val_accuracy improved from 0.92611 to 0.93103, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 152/500
# 26/26 [==============================] - 11s 400ms/step - loss: 3.5257e-04 - accuracy: 1.0000 - val_loss: 0.3424 - val_accuracy: 0.9212
#
# Epoch 00152: val_accuracy did not improve from 0.93103
# Epoch 153/500
# 26/26 [==============================] - 10s 396ms/step - loss: 4.8833e-04 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9335
#
# Epoch 00153: val_accuracy improved from 0.93103 to 0.93350, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 154/500
# 26/26 [==============================] - 11s 401ms/step - loss: 6.9964e-04 - accuracy: 1.0000 - val_loss: 0.3629 - val_accuracy: 0.9187
#
# Epoch 00154: val_accuracy did not improve from 0.93350
# Epoch 155/500
# 26/26 [==============================] - 11s 400ms/step - loss: 4.6464e-04 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9236
#
# Epoch 00155: val_accuracy did not improve from 0.93350
# Epoch 156/500
# 26/26 [==============================] - 11s 397ms/step - loss: 4.3834e-04 - accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9236
#
# Epoch 00156: val_accuracy did not improve from 0.93350
# Epoch 157/500
# 26/26 [==============================] - 11s 400ms/step - loss: 5.1597e-04 - accuracy: 1.0000 - val_loss: 0.3496 - val_accuracy: 0.9236
#
# Epoch 00157: val_accuracy did not improve from 0.93350
# Epoch 158/500
# 26/26 [==============================] - 11s 399ms/step - loss: 3.9769e-04 - accuracy: 1.0000 - val_loss: 0.3308 - val_accuracy: 0.9286
#
# Epoch 00158: val_accuracy did not improve from 0.93350
# Epoch 159/500
# 26/26 [==============================] - 11s 399ms/step - loss: 2.3738e-04 - accuracy: 1.0000 - val_loss: 0.2975 - val_accuracy: 0.9286
#
# Epoch 00159: val_accuracy did not improve from 0.93350
# Epoch 160/500
# 26/26 [==============================] - 10s 403ms/step - loss: 3.3294e-04 - accuracy: 1.0000 - val_loss: 0.3191 - val_accuracy: 0.9360
#
# Epoch 00160: val_accuracy improved from 0.93350 to 0.93596, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 161/500
# 26/26 [==============================] - 11s 399ms/step - loss: 2.4353e-04 - accuracy: 1.0000 - val_loss: 0.3271 - val_accuracy: 0.9236
#
# Epoch 00161: val_accuracy did not improve from 0.93596
# Epoch 162/500
# 26/26 [==============================] - 11s 399ms/step - loss: 2.0539e-04 - accuracy: 1.0000 - val_loss: 0.2857 - val_accuracy: 0.9286
#
# Epoch 00162: val_accuracy did not improve from 0.93596
# Epoch 163/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.8619e-04 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9409
#
# Epoch 00163: val_accuracy improved from 0.93596 to 0.94089, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 164/500
# 26/26 [==============================] - 11s 400ms/step - loss: 3.2334e-04 - accuracy: 1.0000 - val_loss: 0.3336 - val_accuracy: 0.9261
#
# Epoch 00164: val_accuracy did not improve from 0.94089
# Epoch 165/500
# 26/26 [==============================] - 11s 400ms/step - loss: 2.3276e-04 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9261
#
# Epoch 00165: val_accuracy did not improve from 0.94089
# Epoch 166/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.8573e-04 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9236
#
# Epoch 00166: val_accuracy did not improve from 0.94089
# Epoch 167/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.8912e-04 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9212
#
# Epoch 00167: val_accuracy did not improve from 0.94089
# Epoch 168/500
# 26/26 [==============================] - 11s 399ms/step - loss: 3.3484e-04 - accuracy: 1.0000 - val_loss: 0.3270 - val_accuracy: 0.9286
#
# Epoch 00168: val_accuracy did not improve from 0.94089
# Epoch 169/500
# 26/26 [==============================] - 11s 401ms/step - loss: 3.9966e-04 - accuracy: 1.0000 - val_loss: 0.3836 - val_accuracy: 0.9212
#
# Epoch 00169: val_accuracy did not improve from 0.94089
# Epoch 170/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.7859e-04 - accuracy: 1.0000 - val_loss: 0.3563 - val_accuracy: 0.9286
#
# Epoch 00170: val_accuracy did not improve from 0.94089
# Epoch 171/500
# 26/26 [==============================] - 11s 398ms/step - loss: 2.4041e-04 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9212
#
# Epoch 00171: val_accuracy did not improve from 0.94089
# Epoch 172/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.8260e-04 - accuracy: 1.0000 - val_loss: 0.3290 - val_accuracy: 0.9409
#
# Epoch 00172: val_accuracy did not improve from 0.94089
# Epoch 173/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.2571e-04 - accuracy: 1.0000 - val_loss: 0.3473 - val_accuracy: 0.9286
#
# Epoch 00173: val_accuracy did not improve from 0.94089
# Epoch 174/500
# 26/26 [==============================] - 10s 401ms/step - loss: 1.3293e-04 - accuracy: 1.0000 - val_loss: 0.3270 - val_accuracy: 0.9335
#
# Epoch 00174: val_accuracy did not improve from 0.94089
# Epoch 175/500
# 26/26 [==============================] - 10s 396ms/step - loss: 1.0973e-04 - accuracy: 1.0000 - val_loss: 0.3538 - val_accuracy: 0.9310
#
# Epoch 00175: val_accuracy did not improve from 0.94089
# Epoch 176/500
# 26/26 [==============================] - 11s 398ms/step - loss: 2.0381e-04 - accuracy: 1.0000 - val_loss: 0.3562 - val_accuracy: 0.9310
#
# Epoch 00176: val_accuracy did not improve from 0.94089
# Epoch 177/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.8957e-04 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9286
#
# Epoch 00177: val_accuracy did not improve from 0.94089
# Epoch 178/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.3659e-04 - accuracy: 1.0000 - val_loss: 0.3567 - val_accuracy: 0.9236
#
# Epoch 00178: val_accuracy did not improve from 0.94089
# Epoch 179/500
# 26/26 [==============================] - 11s 404ms/step - loss: 1.7258e-04 - accuracy: 1.0000 - val_loss: 0.3241 - val_accuracy: 0.9261
#
# Epoch 00179: val_accuracy did not improve from 0.94089
# Epoch 180/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.5209e-04 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9187
#
# Epoch 00180: val_accuracy did not improve from 0.94089
# Epoch 181/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.7384e-04 - accuracy: 1.0000 - val_loss: 0.3919 - val_accuracy: 0.9187
#
# Epoch 00181: val_accuracy did not improve from 0.94089
# Epoch 182/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.2862e-04 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9261
#
# Epoch 00182: val_accuracy did not improve from 0.94089
# Epoch 183/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.7115e-04 - accuracy: 1.0000 - val_loss: 0.3442 - val_accuracy: 0.9212
#
# Epoch 00183: val_accuracy did not improve from 0.94089
# Epoch 184/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.0299e-04 - accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 0.9261
#
# Epoch 00184: val_accuracy did not improve from 0.94089
# Epoch 185/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.8208e-04 - accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9310
#
# Epoch 00185: val_accuracy did not improve from 0.94089
# Epoch 186/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.1890e-04 - accuracy: 1.0000 - val_loss: 0.3654 - val_accuracy: 0.9360
#
# Epoch 00186: val_accuracy did not improve from 0.94089
# Epoch 187/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.8411e-04 - accuracy: 1.0000 - val_loss: 0.3292 - val_accuracy: 0.9286
#
# Epoch 00187: val_accuracy did not improve from 0.94089
# Epoch 188/500
# 26/26 [==============================] - 11s 401ms/step - loss: 8.3300e-05 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9261
#
# Epoch 00188: val_accuracy did not improve from 0.94089
# Epoch 189/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.2343e-04 - accuracy: 1.0000 - val_loss: 0.3222 - val_accuracy: 0.9310
#
# Epoch 00189: val_accuracy did not improve from 0.94089
# Epoch 190/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.7203e-04 - accuracy: 1.0000 - val_loss: 0.3568 - val_accuracy: 0.9236
#
# Epoch 00190: val_accuracy did not improve from 0.94089
# Epoch 191/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.0716e-04 - accuracy: 1.0000 - val_loss: 0.3191 - val_accuracy: 0.9433
#
# Epoch 00191: val_accuracy improved from 0.94089 to 0.94335, saving model to /content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5
# Epoch 192/500
# 26/26 [==============================] - 11s 398ms/step - loss: 7.3963e-05 - accuracy: 1.0000 - val_loss: 0.3815 - val_accuracy: 0.9163
#
# Epoch 00192: val_accuracy did not improve from 0.94335
# Epoch 193/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.0110e-04 - accuracy: 1.0000 - val_loss: 0.3547 - val_accuracy: 0.9261
#
# Epoch 00193: val_accuracy did not improve from 0.94335
# Epoch 194/500
# 26/26 [==============================] - 11s 400ms/step - loss: 9.0968e-05 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9335
#
# Epoch 00194: val_accuracy did not improve from 0.94335
# Epoch 195/500
# 26/26 [==============================] - 11s 399ms/step - loss: 7.8259e-05 - accuracy: 1.0000 - val_loss: 0.3956 - val_accuracy: 0.9286
#
# Epoch 00195: val_accuracy did not improve from 0.94335
# Epoch 196/500
# 26/26 [==============================] - 11s 399ms/step - loss: 7.9610e-05 - accuracy: 1.0000 - val_loss: 0.3717 - val_accuracy: 0.9286
#
# Epoch 00196: val_accuracy did not improve from 0.94335
# Epoch 197/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.1034e-04 - accuracy: 1.0000 - val_loss: 0.3927 - val_accuracy: 0.9163
#
# Epoch 00197: val_accuracy did not improve from 0.94335
# Epoch 198/500
# 26/26 [==============================] - 10s 396ms/step - loss: 7.7745e-05 - accuracy: 1.0000 - val_loss: 0.3590 - val_accuracy: 0.9335
#
# Epoch 00198: val_accuracy did not improve from 0.94335
# Epoch 199/500
# 26/26 [==============================] - 11s 398ms/step - loss: 6.8344e-05 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.9335
#
# Epoch 00199: val_accuracy did not improve from 0.94335
# Epoch 200/500
# 26/26 [==============================] - 11s 400ms/step - loss: 2.8768e-04 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.9089
#
# Epoch 00200: val_accuracy did not improve from 0.94335
# Epoch 201/500
# 26/26 [==============================] - 11s 398ms/step - loss: 3.7572e-04 - accuracy: 1.0000 - val_loss: 0.3739 - val_accuracy: 0.9335
#
# Epoch 00201: val_accuracy did not improve from 0.94335
# Epoch 202/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.4521e-04 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.9360
#
# Epoch 00202: val_accuracy did not improve from 0.94335
# Epoch 203/500
# 26/26 [==============================] - 11s 397ms/step - loss: 1.7304e-04 - accuracy: 1.0000 - val_loss: 0.3753 - val_accuracy: 0.9212
#
# Epoch 00203: val_accuracy did not improve from 0.94335
# Epoch 204/500
# 26/26 [==============================] - 10s 395ms/step - loss: 1.5297e-04 - accuracy: 1.0000 - val_loss: 0.4092 - val_accuracy: 0.9187
#
# Epoch 00204: val_accuracy did not improve from 0.94335
# Epoch 205/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.4654e-04 - accuracy: 1.0000 - val_loss: 0.3187 - val_accuracy: 0.9335
#
# Epoch 00205: val_accuracy did not improve from 0.94335
# Epoch 206/500
# 26/26 [==============================] - 11s 399ms/step - loss: 2.2629e-04 - accuracy: 1.0000 - val_loss: 0.3571 - val_accuracy: 0.9187
#
# Epoch 00206: val_accuracy did not improve from 0.94335
# Epoch 207/500
# 26/26 [==============================] - 11s 399ms/step - loss: 6.4358e-05 - accuracy: 1.0000 - val_loss: 0.3760 - val_accuracy: 0.9261
#
# Epoch 00207: val_accuracy did not improve from 0.94335
# Epoch 208/500
# 26/26 [==============================] - 10s 397ms/step - loss: 7.3172e-05 - accuracy: 1.0000 - val_loss: 0.3603 - val_accuracy: 0.9310
#
# Epoch 00208: val_accuracy did not improve from 0.94335
# Epoch 209/500
# 26/26 [==============================] - 10s 396ms/step - loss: 1.3187e-04 - accuracy: 1.0000 - val_loss: 0.4340 - val_accuracy: 0.9138
#
# Epoch 00209: val_accuracy did not improve from 0.94335
# Epoch 210/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.6736e-04 - accuracy: 1.0000 - val_loss: 0.4225 - val_accuracy: 0.9138
#
# Epoch 00210: val_accuracy did not improve from 0.94335
# Epoch 211/500
# 26/26 [==============================] - 10s 396ms/step - loss: 8.4024e-05 - accuracy: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.9212
#
# Epoch 00211: val_accuracy did not improve from 0.94335
# Epoch 212/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.3982e-04 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.9261
#
# Epoch 00212: val_accuracy did not improve from 0.94335
# Epoch 213/500
# 26/26 [==============================] - 10s 403ms/step - loss: 1.6459e-04 - accuracy: 1.0000 - val_loss: 0.3417 - val_accuracy: 0.9236
#
# Epoch 00213: val_accuracy did not improve from 0.94335
# Epoch 214/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.3948e-04 - accuracy: 1.0000 - val_loss: 0.3721 - val_accuracy: 0.9261
#
# Epoch 00214: val_accuracy did not improve from 0.94335
# Epoch 215/500
# 26/26 [==============================] - 11s 398ms/step - loss: 9.3635e-05 - accuracy: 1.0000 - val_loss: 0.3439 - val_accuracy: 0.9335
#
# Epoch 00215: val_accuracy did not improve from 0.94335
# Epoch 216/500
# 26/26 [==============================] - 11s 399ms/step - loss: 5.8883e-05 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.9261
#
# Epoch 00216: val_accuracy did not improve from 0.94335
# Epoch 217/500
# 26/26 [==============================] - 11s 400ms/step - loss: 5.0157e-05 - accuracy: 1.0000 - val_loss: 0.3246 - val_accuracy: 0.9310
#
# Epoch 00217: val_accuracy did not improve from 0.94335
# Epoch 218/500
# 26/26 [==============================] - 11s 398ms/step - loss: 6.9064e-05 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.9310
#
# Epoch 00218: val_accuracy did not improve from 0.94335
# Epoch 219/500
# 26/26 [==============================] - 11s 398ms/step - loss: 4.1716e-05 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9310
#
# Epoch 00219: val_accuracy did not improve from 0.94335
# Epoch 220/500
# 26/26 [==============================] - 11s 398ms/step - loss: 5.7609e-05 - accuracy: 1.0000 - val_loss: 0.3712 - val_accuracy: 0.9236
#
# Epoch 00220: val_accuracy did not improve from 0.94335
# Epoch 221/500
# 26/26 [==============================] - 11s 397ms/step - loss: 1.4450e-04 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9261
#
# Epoch 00221: val_accuracy did not improve from 0.94335
# Epoch 222/500
# 26/26 [==============================] - 11s 400ms/step - loss: 5.2590e-05 - accuracy: 1.0000 - val_loss: 0.3674 - val_accuracy: 0.9236
#
# Epoch 00222: val_accuracy did not improve from 0.94335
# Epoch 223/500
# 26/26 [==============================] - 11s 399ms/step - loss: 8.4731e-05 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.9286
#
# Epoch 00223: val_accuracy did not improve from 0.94335
# Epoch 224/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 1.1067 - val_accuracy: 0.8276
#
# Epoch 00224: val_accuracy did not improve from 0.94335
# Epoch 225/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.4751 - accuracy: 0.8922 - val_loss: 53.1200 - val_accuracy: 0.2167
#
# Epoch 00225: val_accuracy did not improve from 0.94335
# Epoch 226/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.6533 - accuracy: 0.8246 - val_loss: 122.3370 - val_accuracy: 0.1330
#
# Epoch 00226: val_accuracy did not improve from 0.94335
# Epoch 227/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.2622 - accuracy: 0.9202 - val_loss: 12.1887 - val_accuracy: 0.3424
#
# Epoch 00227: val_accuracy did not improve from 0.94335
# Epoch 228/500
# ...
# Epoch 423/500
# 26/26 [==============================] - 11s 401ms/step - loss: 2.8991e-04 - accuracy: 1.0000 - val_loss: 0.3926 - val_accuracy: 0.9187
#
# Epoch 00423: val_accuracy did not improve from 0.94335
# Epoch 424/500
# 26/26 [==============================] - 11s 398ms/step - loss: 1.5542e-04 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.9236
#
# Epoch 00424: val_accuracy did not improve from 0.94335
# Epoch 425/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.7300e-04 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9335
#
# Epoch 00425: val_accuracy did not improve from 0.94335
# Epoch 426/500
# 26/26 [==============================] - 11s 399ms/step - loss: 1.5580e-04 - accuracy: 1.0000 - val_loss: 0.4212 - val_accuracy: 0.9236
#
# Epoch 00426: val_accuracy did not improve from 0.94335
# Epoch 427/500
# 26/26 [==============================] - 11s 400ms/step - loss: 9.8037e-05 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.9236
#
# Epoch 00427: val_accuracy did not improve from 0.94335
# Epoch 428/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.1082e-04 - accuracy: 1.0000 - val_loss: 0.3947 - val_accuracy: 0.9236
#
# Epoch 00428: val_accuracy did not improve from 0.94335
# Epoch 429/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.4434e-04 - accuracy: 1.0000 - val_loss: 0.3782 - val_accuracy: 0.9163
#
# Epoch 00429: val_accuracy did not improve from 0.94335
# Epoch 430/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.2651e-04 - accuracy: 1.0000 - val_loss: 0.4392 - val_accuracy: 0.9212
#
# Epoch 00430: val_accuracy did not improve from 0.94335
# Epoch 431/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.5581e-04 - accuracy: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.9212
#
# Epoch 00431: val_accuracy did not improve from 0.94335
# Epoch 432/500
# 26/26 [==============================] - 11s 403ms/step - loss: 2.1363e-04 - accuracy: 1.0000 - val_loss: 0.3678 - val_accuracy: 0.9212
#
# Epoch 00432: val_accuracy did not improve from 0.94335
# Epoch 433/500
# 26/26 [==============================] - 11s 397ms/step - loss: 1.1255e-04 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 0.9212
#
# Epoch 00433: val_accuracy did not improve from 0.94335
# Epoch 434/500
# 26/26 [==============================] - 11s 400ms/step - loss: 9.0331e-05 - accuracy: 1.0000 - val_loss: 0.4050 - val_accuracy: 0.9212
#
# Epoch 00434: val_accuracy did not improve from 0.94335
# Epoch 435/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.0820e-04 - accuracy: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.9187
#
# Epoch 00435: val_accuracy did not improve from 0.94335
# Epoch 436/500
# 26/26 [==============================] - 10s 404ms/step - loss: 7.5565e-05 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.9187
#
# Epoch 00436: val_accuracy did not improve from 0.94335
# Epoch 437/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.2924e-04 - accuracy: 1.0000 - val_loss: 0.4379 - val_accuracy: 0.9163
#
# Epoch 00437: val_accuracy did not improve from 0.94335
# Epoch 438/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.1438e-04 - accuracy: 1.0000 - val_loss: 0.4054 - val_accuracy: 0.9261
#
# Epoch 00438: val_accuracy did not improve from 0.94335
# Epoch 439/500
# 26/26 [==============================] - 11s 402ms/step - loss: 8.1881e-05 - accuracy: 1.0000 - val_loss: 0.4218 - val_accuracy: 0.9236
#
# Epoch 00439: val_accuracy did not improve from 0.94335
# Epoch 440/500
# 26/26 [==============================] - 11s 401ms/step - loss: 7.7646e-05 - accuracy: 1.0000 - val_loss: 0.4189 - val_accuracy: 0.9261
#
# Epoch 00440: val_accuracy did not improve from 0.94335
# Epoch 441/500
# 26/26 [==============================] - 11s 398ms/step - loss: 6.7422e-05 - accuracy: 1.0000 - val_loss: 0.4177 - val_accuracy: 0.9163
#
# Epoch 00441: val_accuracy did not improve from 0.94335
# Epoch 442/500
# 26/26 [==============================] - 11s 398ms/step - loss: 5.7067e-05 - accuracy: 1.0000 - val_loss: 0.4300 - val_accuracy: 0.9212
#
# Epoch 00442: val_accuracy did not improve from 0.94335
# Epoch 443/500
# 26/26 [==============================] - 11s 401ms/step - loss: 1.1814e-04 - accuracy: 1.0000 - val_loss: 0.3848 - val_accuracy: 0.9236
#
# Epoch 00443: val_accuracy did not improve from 0.94335
# Epoch 444/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.0841e-04 - accuracy: 1.0000 - val_loss: 0.4184 - val_accuracy: 0.9113
#
# Epoch 00444: val_accuracy did not improve from 0.94335
# Epoch 445/500
# 26/26 [==============================] - 11s 403ms/step - loss: 1.1545e-04 - accuracy: 1.0000 - val_loss: 0.3685 - val_accuracy: 0.9310
#
# Epoch 00445: val_accuracy did not improve from 0.94335
# Epoch 446/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.8555e-04 - accuracy: 1.0000 - val_loss: 0.4203 - val_accuracy: 0.9163
#
# Epoch 00446: val_accuracy did not improve from 0.94335
# Epoch 447/500
# 26/26 [==============================] - 11s 400ms/step - loss: 9.8568e-05 - accuracy: 1.0000 - val_loss: 0.3907 - val_accuracy: 0.9261
#
# Epoch 00447: val_accuracy did not improve from 0.94335
# Epoch 448/500
# 26/26 [==============================] - 11s 400ms/step - loss: 8.3567e-05 - accuracy: 1.0000 - val_loss: 0.4922 - val_accuracy: 0.9138
#
# Epoch 00448: val_accuracy did not improve from 0.94335
# Epoch 449/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.1737e-04 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.9138
#
# Epoch 00449: val_accuracy did not improve from 0.94335
# Epoch 450/500
# 26/26 [==============================] - 11s 400ms/step - loss: 8.4405e-05 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.9286
#
# Epoch 00450: val_accuracy did not improve from 0.94335
# Epoch 451/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.0987e-04 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.9212
#
# Epoch 00451: val_accuracy did not improve from 0.94335
# Epoch 452/500
# 26/26 [==============================] - 11s 407ms/step - loss: 4.9846e-05 - accuracy: 1.0000 - val_loss: 0.3921 - val_accuracy: 0.9286
#
# Epoch 00452: val_accuracy did not improve from 0.94335
# Epoch 453/500
# 26/26 [==============================] - 11s 400ms/step - loss: 7.2890e-05 - accuracy: 1.0000 - val_loss: 0.3844 - val_accuracy: 0.9261
#
# Epoch 00453: val_accuracy did not improve from 0.94335
# Epoch 454/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.0513e-04 - accuracy: 1.0000 - val_loss: 0.3994 - val_accuracy: 0.9261
#
# Epoch 00454: val_accuracy did not improve from 0.94335
# Epoch 455/500
# 26/26 [==============================] - 11s 403ms/step - loss: 1.3155e-04 - accuracy: 1.0000 - val_loss: 0.4357 - val_accuracy: 0.9261
#
# Epoch 00455: val_accuracy did not improve from 0.94335
# Epoch 456/500
# 26/26 [==============================] - 11s 400ms/step - loss: 5.0152e-05 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.9360
#
# Epoch 00456: val_accuracy did not improve from 0.94335
# Epoch 457/500
# 26/26 [==============================] - 11s 402ms/step - loss: 1.1456e-04 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 0.9212
#
# Epoch 00457: val_accuracy did not improve from 0.94335
# Epoch 458/500
# 26/26 [==============================] - 11s 399ms/step - loss: 7.3008e-05 - accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.9212
#
# Epoch 00458: val_accuracy did not improve from 0.94335
# Epoch 459/500
# 26/26 [==============================] - 11s 403ms/step - loss: 7.1774e-05 - accuracy: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.9212
#
# Epoch 00459: val_accuracy did not improve from 0.94335
# Epoch 460/500
# 26/26 [==============================] - 11s 397ms/step - loss: 8.7891e-05 - accuracy: 1.0000 - val_loss: 0.4001 - val_accuracy: 0.9089
#
# Epoch 00460: val_accuracy did not improve from 0.94335
# Epoch 461/500
# 26/26 [==============================] - 11s 400ms/step - loss: 6.6392e-05 - accuracy: 1.0000 - val_loss: 0.3856 - val_accuracy: 0.9286
#
# Epoch 00461: val_accuracy did not improve from 0.94335
# Epoch 462/500
# 26/26 [==============================] - 11s 400ms/step - loss: 5.9912e-04 - accuracy: 1.0000 - val_loss: 0.3923 - val_accuracy: 0.9113
#
# Epoch 00462: val_accuracy did not improve from 0.94335
# Epoch 463/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.6165 - val_accuracy: 0.9089
#
# Epoch 00463: val_accuracy did not improve from 0.94335
# Epoch 464/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0287 - accuracy: 0.9921 - val_loss: 0.8499 - val_accuracy: 0.8300
#
# Epoch 00464: val_accuracy did not improve from 0.94335
# Epoch 465/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.1144 - accuracy: 0.9659 - val_loss: 1.2467 - val_accuracy: 0.8177
#
# Epoch 00465: val_accuracy did not improve from 0.94335
# Epoch 466/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.1173 - accuracy: 0.9665 - val_loss: 5.0589 - val_accuracy: 0.6552
#
# Epoch 00466: val_accuracy did not improve from 0.94335
# Epoch 467/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0943 - accuracy: 0.9732 - val_loss: 5.7770 - val_accuracy: 0.5074
#
# Epoch 00467: val_accuracy did not improve from 0.94335
# Epoch 468/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0646 - accuracy: 0.9793 - val_loss: 2.4914 - val_accuracy: 0.6995
#
# Epoch 00468: val_accuracy did not improve from 0.94335
# Epoch 469/500
# 26/26 [==============================] - 11s 398ms/step - loss: 0.0709 - accuracy: 0.9787 - val_loss: 0.9444 - val_accuracy: 0.8276
#
# Epoch 00469: val_accuracy did not improve from 0.94335
# Epoch 470/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0619 - accuracy: 0.9829 - val_loss: 1.0193 - val_accuracy: 0.7734
#
# Epoch 00470: val_accuracy did not improve from 0.94335
# Epoch 471/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0253 - accuracy: 0.9921 - val_loss: 0.6338 - val_accuracy: 0.8768
#
# Epoch 00471: val_accuracy did not improve from 0.94335
# Epoch 472/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.7548 - val_accuracy: 0.8251
#
# Epoch 00472: val_accuracy did not improve from 0.94335
# Epoch 473/500
# 26/26 [==============================] - 11s 403ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.5670 - val_accuracy: 0.8719
#
# Epoch 00473: val_accuracy did not improve from 0.94335
# Epoch 474/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.5749 - val_accuracy: 0.8621
#
# Epoch 00474: val_accuracy did not improve from 0.94335
# Epoch 475/500
# 26/26 [==============================] - 11s 399ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.4262 - val_accuracy: 0.8966
#
# Epoch 00475: val_accuracy did not improve from 0.94335
# Epoch 476/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.4007 - val_accuracy: 0.9064
#
# Epoch 00476: val_accuracy did not improve from 0.94335
# Epoch 477/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.4525 - val_accuracy: 0.9015
#
# Epoch 00477: val_accuracy did not improve from 0.94335
# Epoch 478/500
# 26/26 [==============================] - 11s 401ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.4308 - val_accuracy: 0.9163
#
# Epoch 00478: val_accuracy did not improve from 0.94335
# Epoch 479/500
# 26/26 [==============================] - 11s 401ms/step - loss: 9.3782e-04 - accuracy: 1.0000 - val_loss: 0.4322 - val_accuracy: 0.9163
#
# Epoch 00479: val_accuracy did not improve from 0.94335
# Epoch 480/500
# 26/26 [==============================] - 11s 402ms/step - loss: 7.2087e-04 - accuracy: 1.0000 - val_loss: 0.4048 - val_accuracy: 0.9163
#
# Epoch 00480: val_accuracy did not improve from 0.94335
# Epoch 481/500
# 26/26 [==============================] - 11s 401ms/step - loss: 3.3001e-04 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9163
#
# Epoch 00481: val_accuracy did not improve from 0.94335
# Epoch 482/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.4057 - val_accuracy: 0.8990
#
# Epoch 00482: val_accuracy did not improve from 0.94335
# Epoch 483/500
# 26/26 [==============================] - 11s 400ms/step - loss: 0.0084 - accuracy: 0.9982 - val_loss: 0.5190 - val_accuracy: 0.8966
#
# Epoch 00483: val_accuracy did not improve from 0.94335
# Epoch 484/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.5009 - val_accuracy: 0.8916
#
# Epoch 00484: val_accuracy did not improve from 0.94335
# Epoch 485/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4700 - val_accuracy: 0.9089
#
# Epoch 00485: val_accuracy did not improve from 0.94335
# Epoch 486/500
# 26/26 [==============================] - 11s 403ms/step - loss: 8.3020e-04 - accuracy: 1.0000 - val_loss: 0.4996 - val_accuracy: 0.9015
#
# Epoch 00486: val_accuracy did not improve from 0.94335
# Epoch 487/500
# 26/26 [==============================] - 11s 400ms/step - loss: 7.2484e-04 - accuracy: 1.0000 - val_loss: 0.4709 - val_accuracy: 0.8941
#
# Epoch 00487: val_accuracy did not improve from 0.94335
# Epoch 488/500
# 26/26 [==============================] - 11s 402ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.4073 - val_accuracy: 0.9064
#
# Epoch 00488: val_accuracy did not improve from 0.94335
# Epoch 489/500
# 26/26 [==============================] - 11s 402ms/step - loss: 7.4268e-04 - accuracy: 1.0000 - val_loss: 0.4243 - val_accuracy: 0.9212
#
# Epoch 00489: val_accuracy did not improve from 0.94335
# Epoch 490/500
# 26/26 [==============================] - 11s 400ms/step - loss: 6.8837e-04 - accuracy: 1.0000 - val_loss: 0.4196 - val_accuracy: 0.9089
#
# Epoch 00490: val_accuracy did not improve from 0.94335
# Epoch 491/500
# 26/26 [==============================] - 11s 399ms/step - loss: 3.1276e-04 - accuracy: 1.0000 - val_loss: 0.4462 - val_accuracy: 0.8990
#
# Epoch 00491: val_accuracy did not improve from 0.94335
# Epoch 492/500
# 26/26 [==============================] - 10s 402ms/step - loss: 4.7688e-04 - accuracy: 1.0000 - val_loss: 0.4885 - val_accuracy: 0.9064
#
# Epoch 00492: val_accuracy did not improve from 0.94335
# Epoch 493/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.7292e-04 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 0.9163
#
# Epoch 00493: val_accuracy did not improve from 0.94335
# Epoch 494/500
# 26/26 [==============================] - 11s 401ms/step - loss: 2.3528e-04 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.9113
#
# Epoch 00494: val_accuracy did not improve from 0.94335
# Epoch 495/500
# 26/26 [==============================] - 11s 401ms/step - loss: 2.1552e-04 - accuracy: 1.0000 - val_loss: 0.5163 - val_accuracy: 0.8941
#
# Epoch 00495: val_accuracy did not improve from 0.94335
# Epoch 496/500
# 26/26 [==============================] - 12s 437ms/step - loss: 1.7983e-04 - accuracy: 1.0000 - val_loss: 0.3941 - val_accuracy: 0.9236
#
# Epoch 00496: val_accuracy did not improve from 0.94335
# Epoch 497/500
# 26/26 [==============================] - 11s 400ms/step - loss: 1.5555e-04 - accuracy: 1.0000 - val_loss: 0.4271 - val_accuracy: 0.9187
#
# Epoch 00497: val_accuracy did not improve from 0.94335
# Epoch 498/500
# 26/26 [==============================] - 11s 403ms/step - loss: 6.0485e-04 - accuracy: 1.0000 - val_loss: 0.3972 - val_accuracy: 0.9261
#
# Epoch 00498: val_accuracy did not improve from 0.94335
# Epoch 499/500
# 26/26 [==============================] - 11s 401ms/step - loss: 3.6860e-04 - accuracy: 1.0000 - val_loss: 0.5084 - val_accuracy: 0.9015
#
# Epoch 00499: val_accuracy did not improve from 0.94335
# Epoch 500/500
# 26/26 [==============================] - 11s 399ms/step - loss: 2.2611e-04 - accuracy: 1.0000 - val_loss: 0.4351 - val_accuracy: 0.9113
#
# Epoch 00500: val_accuracy did not improve from 0.94335

# %%
import matplotlib.pyplot as plt

plt.plot(DenseNet121_model.history.history["accuracy"], label='DenseNet121_acc')
plt.plot(DenseNet121_model.history.history["val_accuracy"], label='DenseNet121_val')

plt.legend()
plt.show()

# %%
DenseNet121_model = tf.keras.models.load_model('/content/drive/MyDrive/DACON_CVLC/Checkpoint/BS_64_1_DN121.h5', compile=False)

# %%
# !mkdir images_test/none
# !mv images_test/*.png images_test/none

# %%
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory('./images_test', target_size=(224,224), color_mode='grayscale', class_mode='categorical', shuffle=False)
# Out:
# Found 20480 images belonging to 1 classes.

# %%
DenseNet121_predict = DenseNet121_model.predict_generator(test_generator).argmax(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
submission = pd.read_csv('/content/drive/MyDrive/DACON_CVLC/data/submission.csv')

# %%
import numpy as np
mylist = []

for i in range(len(submission)):
    name =  test_generator.filenames
    id = name[i].split('/')[1].rstrip('.').split('.')[0]
    mylist.append(id)

# %%
for i in range(len(submission)):
    submission["id"][i] = mylist[i]

# %%
submission["DenseNet121_predict"] = DenseNet121_predict

# %%
from collections import Counter

for i in range(len(submission)) :
    predicts = submission.loc[i, ['DenseNet121_predict']]
    submission.at[i, "digit"] = Counter(predicts).most_common(n=1)[0][0]

# %%
submission = submission[['id', 'digit']]
submission.head()
# Out:
#       id  digit
# 0  10000      4
# 1  10001      4
# 2  10002      6
# 3  10003      9
# 4  10004      5

# %%
from google.colab import files

submission.to_csv('/content/drive/MyDrive/DACON_CVLC/Submission/BatchSize_64_1_DenseNet121_model.csv', index=False)
files.download('/content/drive/MyDrive/DACON_CVLC/Submission/BatchSize_64_1_DenseNet121_model.csv')
