# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/DenseNet161_epoch500_batchsize16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Oct 14 17:00:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_CropsAreSick/sicks.zip"

# %% [markdown]
# baseline.ipynb<br>
# .. ├ models<br>
# .. └ data<br>
# .... ├ train_imgs<br>
# .... ├ test_imgs<br>
# .... ├ train.csv<br>
# .... ├ test.csv<br>
# .... └ sample_submission.csv

# %% [markdown]
# # 사용 패키지

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm

import torch
from torch import nn
from torchvision import models
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# # 데이터 로드

# %%
train_total = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
train_total.head()
# Out:
#      uid              img_path    disease  disease_code
# 0  10000  train_imgs/10000.jpg    시설포도노균병             1
# 1  10001  train_imgs/10001.jpg    시설포도노균병             1
# 2  10002  train_imgs/10002.jpg  시설포도노균병반응             2
# 3  10003  train_imgs/10003.jpg        축과병             4
# 4  10004  train_imgs/10004.jpg    시설포도노균병             1

# %%
test.head()
# Out:
#      uid             img_path
# 0  20000  test_imgs/20000.jpg
# 1  20001  test_imgs/20001.jpg
# 2  20002  test_imgs/20002.jpg
# 3  20003  test_imgs/20003.jpg
# 4  20004  test_imgs/20004.jpg

# %% [markdown]
# # 하이퍼파라미터 및 변수

# %%
device = torch.device("cuda:0")
batch_size = 16
class_n = len(train_total['disease_code'].unique())
learning_rate = 0.00001
epochs = 500
save_path = '/content/drive/MyDrive/DACON_CropsAreSick/DenseNet161_model.pt'

# %% [markdown]
# # 데이터셋 구성

# %%
class CustomDataset(Dataset):
    def __init__(self, files, labels=None, mode='train'):
        self.mode = mode
        self.files = files
        if mode == 'train':
            self.labels = labels
            
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, i):
        if self.mode == 'train':
            img = cv2.imread('./train_imgs/'+self.files[i])
            img = cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_AREA)
            img = img.astype(np.float32)/255
            img = np.transpose(img, (2,0,1))
            return {
                'img' : torch.tensor(img, dtype=torch.float32),
                'label' : torch.tensor(self.labels[i], dtype=torch.long)
            }
        else:
            img = cv2.imread('./test_imgs/'+self.files[i])
            img = cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_AREA)
            img = img.astype(np.float32)/255
            img = np.transpose(img, (2,0,1))
            return {
                'img' : torch.tensor(img, dtype=torch.float32),
            }

# %%
train = train_total.iloc[:200]
val = train_total.iloc[200:]

# %%
train_dataset = CustomDataset(train['img_path'].str.split('/').str[-1].values, train['disease_code'].values)
val_dataset = CustomDataset(val['img_path'].str.split('/').str[-1].values, val['disease_code'].values)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, num_workers=16, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, num_workers=16, shuffle=False)

test_dataset = CustomDataset(test['img_path'].str.split('/').str[-1], labels=None, mode='test')
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, num_workers=16, shuffle=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # 모델

# %%
class CNN_Model(nn.Module):
    def __init__(self, class_n, rate=0.1):
        super(CNN_Model, self).__init__()
        self.model = models.densenet161(pretrained=True)
        self.dropout = nn.Dropout(rate)
        self.output_layer = nn.Linear(in_features=1000, out_features=class_n, bias=True)
    
    def forward(self, inputs):
        output = self.output_layer(self.dropout(self.model(inputs)))
        return output

# %%
model = CNN_Model(class_n).to(device)

# %%
model.model.eval()
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(816, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(912, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1008, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1008, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer33): _DenseLayer(
#         (norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer34): _DenseLayer(
#         (norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer35): _DenseLayer(
#         (norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer36): _DenseLayer(
#         (norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(2112, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2112, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(2160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2160, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(2208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=2208, out_features=1000, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # 학습

# %%
def train_step(batch_item, epoch, batch, training):
    img = batch_item['img'].to(device)
    label = batch_item['label'].to(device)
    if training is True:
        model.train()
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            output = model(img)
            loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        
        return loss
    else:
        model.eval()
        with torch.no_grad():
            output = model(img)
            loss = criterion(output, label)
            
        return loss

# %%
loss_plot, val_loss_plot = [], []

for epoch in range(epochs):
    total_loss, total_val_loss = 0, 0
    
    tqdm_dataset = tqdm(enumerate(train_dataloader))
    training = True
    for batch, batch_item in tqdm_dataset:
        batch_loss = train_step(batch_item, epoch, batch, training)
        total_loss += batch_loss
        
        tqdm_dataset.set_postfix({
            'Epoch': epoch + 1,
            'Loss': '{:06f}'.format(batch_loss.item()),
            'Total Loss' : '{:06f}'.format(total_loss/(batch+1))
        })
    loss_plot.append(total_loss/(batch+1))
    
    tqdm_dataset = tqdm(enumerate(val_dataloader))
    training = False
    for batch, batch_item in tqdm_dataset:
        batch_loss = train_step(batch_item, epoch, batch, training)
        total_val_loss += batch_loss
        
        tqdm_dataset.set_postfix({
            'Epoch': epoch + 1,
            'Val Loss': '{:06f}'.format(batch_loss.item()),
            'Total Val Loss' : '{:06f}'.format(total_val_loss/(batch+1))
        })
    val_loss_plot.append(total_val_loss/(batch+1))
    
    if np.min(val_loss_plot) == val_loss_plot[-1]:
        torch.save(model, save_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 13it [00:10,  1.26it/s, Epoch=1, Loss=1.636353, Total Loss=1.840721]
# 4it [00:02,  1.42it/s, Epoch=1, Val Loss=1.721577, Total Val Loss=1.765297]
# 13it [00:10,  1.24it/s, Epoch=2, Loss=0.632263, Total Loss=0.909183]
# 4it [00:02,  1.50it/s, Epoch=2, Val Loss=1.612498, Total Val Loss=1.319646]
# 13it [00:10,  1.19it/s, Epoch=3, Loss=0.523712, Total Loss=0.525324]
# 4it [00:02,  1.39it/s, Epoch=3, Val Loss=1.494370, Total Val Loss=1.051754]
# 13it [00:11,  1.14it/s, Epoch=4, Loss=0.206007, Total Loss=0.334827]
# 4it [00:02,  1.40it/s, Epoch=4, Val Loss=1.270288, Total Val Loss=0.837421]
# 13it [00:10,  1.19it/s, Epoch=5, Loss=0.180285, Total Loss=0.223693]
# 4it [00:02,  1.41it/s, Epoch=5, Val Loss=0.979233, Total Val Loss=0.707718]
# 13it [00:11,  1.18it/s, Epoch=6, Loss=0.121658, Total Loss=0.140752]
# 4it [00:02,  1.42it/s, Epoch=6, Val Loss=0.993633, Total Val Loss=0.668231]
# 13it [00:11,  1.16it/s, Epoch=7, Loss=0.109055, Total Loss=0.105595]
# 4it [00:02,  1.41it/s, Epoch=7, Val Loss=0.838949, Total Val Loss=0.588740]
# 13it [00:10,  1.23it/s, Epoch=8, Loss=0.089406, Total Loss=0.106130]
# 4it [00:02,  1.47it/s, Epoch=8, Val Loss=0.917012, Total Val Loss=0.584838]
# 13it [00:11,  1.16it/s, Epoch=9, Loss=0.113014, Total Loss=0.116356]
# 4it [00:02,  1.48it/s, Epoch=9, Val Loss=0.815489, Total Val Loss=0.549822]
# 13it [00:11,  1.16it/s, Epoch=10, Loss=0.159206, Total Loss=0.080639]
# 4it [00:02,  1.40it/s, Epoch=10, Val Loss=0.913877, Total Val Loss=0.557722]
# 13it [00:11,  1.16it/s, Epoch=11, Loss=0.240044, Total Loss=0.073695]
# 4it [00:02,  1.41it/s, Epoch=11, Val Loss=1.012176, Total Val Loss=0.567519]
# 13it [00:11,  1.17it/s, Epoch=12, Loss=0.054841, Total Loss=0.041345]
# 4it [00:02,  1.48it/s, Epoch=12, Val Loss=0.688672, Total Val Loss=0.470606]
# 13it [00:10,  1.19it/s, Epoch=13, Loss=0.362265, Total Loss=0.073345]
# 4it [00:02,  1.40it/s, Epoch=13, Val Loss=0.723147, Total Val Loss=0.483391]
# 13it [00:10,  1.19it/s, Epoch=14, Loss=0.059897, Total Loss=0.040857]
# 4it [00:02,  1.43it/s, Epoch=14, Val Loss=0.697248, Total Val Loss=0.447991]
# 13it [00:10,  1.21it/s, Epoch=15, Loss=0.372429, Total Loss=0.060819]
# 4it [00:02,  1.41it/s, Epoch=15, Val Loss=0.755769, Total Val Loss=0.439547]
# 13it [00:11,  1.15it/s, Epoch=16, Loss=0.068027, Total Loss=0.032377]
# 4it [00:02,  1.47it/s, Epoch=16, Val Loss=0.669519, Total Val Loss=0.422529]
# 13it [00:10,  1.25it/s, Epoch=17, Loss=0.012780, Total Loss=0.026006]
# 4it [00:02,  1.43it/s, Epoch=17, Val Loss=0.670946, Total Val Loss=0.432661]
# 13it [00:10,  1.26it/s, Epoch=18, Loss=0.036192, Total Loss=0.028857]
# 4it [00:02,  1.42it/s, Epoch=18, Val Loss=0.632726, Total Val Loss=0.420131]
# 13it [00:10,  1.19it/s, Epoch=19, Loss=0.103819, Total Loss=0.028731]
# 4it [00:02,  1.42it/s, Epoch=19, Val Loss=0.433379, Total Val Loss=0.354980]
# 13it [00:10,  1.19it/s, Epoch=20, Loss=0.043190, Total Loss=0.029040]
# 4it [00:02,  1.45it/s, Epoch=20, Val Loss=0.553552, Total Val Loss=0.382500]
# 13it [00:11,  1.16it/s, Epoch=21, Loss=0.101203, Total Loss=0.027421]
# 4it [00:02,  1.49it/s, Epoch=21, Val Loss=0.475321, Total Val Loss=0.358686]
# 13it [00:11,  1.17it/s, Epoch=22, Loss=0.037416, Total Loss=0.015532]
# 4it [00:02,  1.49it/s, Epoch=22, Val Loss=0.560480, Total Val Loss=0.383575]
# 13it [00:11,  1.17it/s, Epoch=23, Loss=0.063444, Total Loss=0.017078]
# 4it [00:02,  1.43it/s, Epoch=23, Val Loss=0.552662, Total Val Loss=0.374412]
# 13it [00:10,  1.19it/s, Epoch=24, Loss=0.023177, Total Loss=0.016485]
# 4it [00:02,  1.42it/s, Epoch=24, Val Loss=0.559371, Total Val Loss=0.369854]
# 13it [00:10,  1.24it/s, Epoch=25, Loss=0.024566, Total Loss=0.014596]
# 4it [00:02,  1.39it/s, Epoch=25, Val Loss=0.434337, Total Val Loss=0.340864]
# 13it [00:11,  1.13it/s, Epoch=26, Loss=0.085734, Total Loss=0.021174]
# 4it [00:02,  1.48it/s, Epoch=26, Val Loss=0.554343, Total Val Loss=0.373648]
# 13it [00:10,  1.25it/s, Epoch=27, Loss=0.272086, Total Loss=0.036164]
# 4it [00:02,  1.48it/s, Epoch=27, Val Loss=0.422794, Total Val Loss=0.322727]
# 13it [00:11,  1.16it/s, Epoch=28, Loss=0.038195, Total Loss=0.024229]
# 4it [00:02,  1.38it/s, Epoch=28, Val Loss=0.375569, Total Val Loss=0.289075]
# 13it [00:11,  1.18it/s, Epoch=29, Loss=0.010847, Total Loss=0.011964]
# 4it [00:02,  1.39it/s, Epoch=29, Val Loss=0.509724, Total Val Loss=0.321657]
# 13it [00:10,  1.19it/s, Epoch=30, Loss=0.041606, Total Loss=0.012946]
# 4it [00:02,  1.41it/s, Epoch=30, Val Loss=0.309092, Total Val Loss=0.289360]
# 13it [00:11,  1.13it/s, Epoch=31, Loss=0.079497, Total Loss=0.018986]
# 4it [00:02,  1.48it/s, Epoch=31, Val Loss=0.371751, Total Val Loss=0.292916]
# 13it [00:10,  1.22it/s, Epoch=32, Loss=0.036039, Total Loss=0.009584]
# 4it [00:02,  1.50it/s, Epoch=32, Val Loss=0.341117, Total Val Loss=0.274643]
# 13it [00:11,  1.16it/s, Epoch=33, Loss=0.005056, Total Loss=0.006874]
# 4it [00:02,  1.47it/s, Epoch=33, Val Loss=0.373862, Total Val Loss=0.279109]
# 13it [00:10,  1.20it/s, Epoch=34, Loss=0.015839, Total Loss=0.012027]
# 4it [00:02,  1.38it/s, Epoch=34, Val Loss=0.378634, Total Val Loss=0.282804]
# 13it [00:11,  1.14it/s, Epoch=35, Loss=0.009615, Total Loss=0.007712]
# 4it [00:02,  1.40it/s, Epoch=35, Val Loss=0.439640, Total Val Loss=0.305886]
# 13it [00:10,  1.27it/s, Epoch=36, Loss=0.027102, Total Loss=0.009301]
# 4it [00:02,  1.50it/s, Epoch=36, Val Loss=0.356746, Total Val Loss=0.273700]
# 13it [00:11,  1.16it/s, Epoch=37, Loss=0.003415, Total Loss=0.008615]
# 4it [00:02,  1.39it/s, Epoch=37, Val Loss=0.398959, Total Val Loss=0.295085]
# 13it [00:11,  1.17it/s, Epoch=38, Loss=0.026133, Total Loss=0.009786]
# 4it [00:02,  1.40it/s, Epoch=38, Val Loss=0.483114, Total Val Loss=0.301342]
# 13it [00:11,  1.17it/s, Epoch=39, Loss=0.027504, Total Loss=0.007001]
# 4it [00:02,  1.39it/s, Epoch=39, Val Loss=0.405935, Total Val Loss=0.305461]
# 13it [00:11,  1.15it/s, Epoch=40, Loss=0.008393, Total Loss=0.007898]
# 4it [00:02,  1.47it/s, Epoch=40, Val Loss=0.466192, Total Val Loss=0.294142]
# 13it [00:11,  1.18it/s, Epoch=41, Loss=0.024691, Total Loss=0.007777]
# 4it [00:02,  1.48it/s, Epoch=41, Val Loss=0.383030, Total Val Loss=0.278516]
# 13it [00:11,  1.18it/s, Epoch=42, Loss=0.015542, Total Loss=0.007546]
# 4it [00:02,  1.41it/s, Epoch=42, Val Loss=0.516348, Total Val Loss=0.321251]
# 13it [00:11,  1.18it/s, Epoch=43, Loss=0.005665, Total Loss=0.013742]
# 4it [00:02,  1.46it/s, Epoch=43, Val Loss=0.466129, Total Val Loss=0.297541]
# 13it [00:10,  1.24it/s, Epoch=44, Loss=0.234555, Total Loss=0.024317]
# 4it [00:02,  1.47it/s, Epoch=44, Val Loss=0.515789, Total Val Loss=0.291626]
# 13it [00:10,  1.19it/s, Epoch=45, Loss=0.011919, Total Loss=0.004942]
# 4it [00:02,  1.48it/s, Epoch=45, Val Loss=0.414724, Total Val Loss=0.305542]
# 13it [00:10,  1.21it/s, Epoch=46, Loss=0.003614, Total Loss=0.004528]
# 4it [00:02,  1.47it/s, Epoch=46, Val Loss=0.371010, Total Val Loss=0.325990]
# 13it [00:10,  1.19it/s, Epoch=47, Loss=0.011026, Total Loss=0.010110]
# 4it [00:02,  1.49it/s, Epoch=47, Val Loss=0.278004, Total Val Loss=0.313391]
# 13it [00:10,  1.23it/s, Epoch=48, Loss=0.002890, Total Loss=0.003255]
# 4it [00:02,  1.38it/s, Epoch=48, Val Loss=0.313838, Total Val Loss=0.286612]
# 13it [00:10,  1.18it/s, Epoch=49, Loss=0.005774, Total Loss=0.006786]
# 4it [00:02,  1.48it/s, Epoch=49, Val Loss=0.345878, Total Val Loss=0.300294]
# 13it [00:10,  1.18it/s, Epoch=50, Loss=0.002204, Total Loss=0.006698]
# 4it [00:02,  1.39it/s, Epoch=50, Val Loss=0.427283, Total Val Loss=0.306173]
# 13it [00:10,  1.26it/s, Epoch=51, Loss=0.011446, Total Loss=0.004978]
# 4it [00:02,  1.42it/s, Epoch=51, Val Loss=0.351668, Total Val Loss=0.273879]
# 13it [00:11,  1.13it/s, Epoch=52, Loss=0.018550, Total Loss=0.005222]
# 4it [00:02,  1.40it/s, Epoch=52, Val Loss=0.508447, Total Val Loss=0.305982]
# 13it [00:11,  1.17it/s, Epoch=53, Loss=0.007635, Total Loss=0.004277]
# 4it [00:02,  1.47it/s, Epoch=53, Val Loss=0.450434, Total Val Loss=0.306004]
# 13it [00:10,  1.18it/s, Epoch=54, Loss=0.031404, Total Loss=0.007510]
# 4it [00:02,  1.42it/s, Epoch=54, Val Loss=0.430494, Total Val Loss=0.306354]
# 13it [00:10,  1.24it/s, Epoch=55, Loss=0.009957, Total Loss=0.004032]
# 4it [00:02,  1.40it/s, Epoch=55, Val Loss=0.502348, Total Val Loss=0.285315]
# 13it [00:11,  1.18it/s, Epoch=56, Loss=0.027717, Total Loss=0.004018]
# 4it [00:02,  1.38it/s, Epoch=56, Val Loss=0.501756, Total Val Loss=0.280062]
# 13it [00:10,  1.19it/s, Epoch=57, Loss=0.037000, Total Loss=0.006235]
# 4it [00:02,  1.49it/s, Epoch=57, Val Loss=0.419948, Total Val Loss=0.270330]
# 13it [00:10,  1.20it/s, Epoch=58, Loss=0.001316, Total Loss=0.002859]
# 4it [00:02,  1.40it/s, Epoch=58, Val Loss=0.480902, Total Val Loss=0.284273]
# 13it [00:10,  1.22it/s, Epoch=59, Loss=0.017906, Total Loss=0.003711]
# 4it [00:02,  1.42it/s, Epoch=59, Val Loss=0.448120, Total Val Loss=0.283048]
# 13it [00:10,  1.23it/s, Epoch=60, Loss=0.004766, Total Loss=0.003350]
# 4it [00:02,  1.41it/s, Epoch=60, Val Loss=0.532341, Total Val Loss=0.288906]
# 13it [00:11,  1.16it/s, Epoch=61, Loss=0.002083, Total Loss=0.007741]
# 4it [00:02,  1.41it/s, Epoch=61, Val Loss=0.475083, Total Val Loss=0.275567]
# 13it [00:10,  1.19it/s, Epoch=62, Loss=0.011273, Total Loss=0.004340]
# 4it [00:02,  1.48it/s, Epoch=62, Val Loss=0.436337, Total Val Loss=0.277699]
# 13it [00:10,  1.20it/s, Epoch=63, Loss=0.001803, Total Loss=0.005222]
# 4it [00:02,  1.42it/s, Epoch=63, Val Loss=0.403874, Total Val Loss=0.267610]
# 13it [00:11,  1.17it/s, Epoch=64, Loss=0.005413, Total Loss=0.002974]
# 4it [00:02,  1.48it/s, Epoch=64, Val Loss=0.358399, Total Val Loss=0.263422]
# 13it [00:10,  1.18it/s, Epoch=65, Loss=0.099235, Total Loss=0.012671]
# 4it [00:02,  1.41it/s, Epoch=65, Val Loss=0.286837, Total Val Loss=0.246499]
# 13it [00:11,  1.17it/s, Epoch=66, Loss=0.005469, Total Loss=0.003670]
# 4it [00:02,  1.42it/s, Epoch=66, Val Loss=0.304582, Total Val Loss=0.249758]
# 13it [00:11,  1.16it/s, Epoch=67, Loss=0.003276, Total Loss=0.002143]
# 4it [00:02,  1.39it/s, Epoch=67, Val Loss=0.429691, Total Val Loss=0.285474]
# 13it [00:11,  1.15it/s, Epoch=68, Loss=0.000969, Total Loss=0.001800]
# 4it [00:02,  1.39it/s, Epoch=68, Val Loss=0.392076, Total Val Loss=0.289774]
# 13it [00:11,  1.18it/s, Epoch=69, Loss=0.013935, Total Loss=0.003175]
# 4it [00:02,  1.42it/s, Epoch=69, Val Loss=0.409098, Total Val Loss=0.278653]
# 13it [00:10,  1.20it/s, Epoch=70, Loss=0.005337, Total Loss=0.003286]
# 4it [00:02,  1.48it/s, Epoch=70, Val Loss=0.316485, Total Val Loss=0.259010]
# 13it [00:11,  1.13it/s, Epoch=71, Loss=0.005151, Total Loss=0.002035]
# 4it [00:02,  1.45it/s, Epoch=71, Val Loss=0.353907, Total Val Loss=0.281236]
# 13it [00:11,  1.17it/s, Epoch=72, Loss=0.006301, Total Loss=0.002710]
# 4it [00:02,  1.39it/s, Epoch=72, Val Loss=0.409089, Total Val Loss=0.289325]
# 13it [00:10,  1.22it/s, Epoch=73, Loss=0.010613, Total Loss=0.005019]
# 4it [00:02,  1.40it/s, Epoch=73, Val Loss=0.369583, Total Val Loss=0.266027]
# 13it [00:11,  1.13it/s, Epoch=74, Loss=0.008092, Total Loss=0.002238]
# 4it [00:02,  1.49it/s, Epoch=74, Val Loss=0.403615, Total Val Loss=0.271473]
# 13it [00:11,  1.12it/s, Epoch=75, Loss=0.015184, Total Loss=0.002549]
# 4it [00:02,  1.39it/s, Epoch=75, Val Loss=0.331684, Total Val Loss=0.250685]
# 13it [00:10,  1.21it/s, Epoch=76, Loss=0.000895, Total Loss=0.003609]
# 4it [00:02,  1.44it/s, Epoch=76, Val Loss=0.419362, Total Val Loss=0.262360]
# 13it [00:11,  1.13it/s, Epoch=77, Loss=0.035774, Total Loss=0.003935]
# 4it [00:02,  1.48it/s, Epoch=77, Val Loss=0.322830, Total Val Loss=0.262192]
# 13it [00:10,  1.19it/s, Epoch=78, Loss=0.008872, Total Loss=0.003234]
# 4it [00:02,  1.39it/s, Epoch=78, Val Loss=0.250436, Total Val Loss=0.237170]
# 13it [00:10,  1.29it/s, Epoch=79, Loss=0.003447, Total Loss=0.001392]
# 4it [00:02,  1.46it/s, Epoch=79, Val Loss=0.413347, Total Val Loss=0.270643]
# 13it [00:11,  1.12it/s, Epoch=80, Loss=0.005174, Total Loss=0.002794]
# 4it [00:02,  1.48it/s, Epoch=80, Val Loss=0.291421, Total Val Loss=0.248296]
# 13it [00:11,  1.17it/s, Epoch=81, Loss=0.010255, Total Loss=0.002658]
# 4it [00:02,  1.37it/s, Epoch=81, Val Loss=0.368390, Total Val Loss=0.265132]
# 13it [00:11,  1.14it/s, Epoch=82, Loss=0.001513, Total Loss=0.001424]
# 4it [00:02,  1.40it/s, Epoch=82, Val Loss=0.318892, Total Val Loss=0.238725]
# 13it [00:10,  1.19it/s, Epoch=83, Loss=0.087269, Total Loss=0.007845]
# 4it [00:02,  1.39it/s, Epoch=83, Val Loss=0.311236, Total Val Loss=0.248514]
# 13it [00:11,  1.16it/s, Epoch=84, Loss=0.008951, Total Loss=0.001965]
# 4it [00:02,  1.48it/s, Epoch=84, Val Loss=0.400891, Total Val Loss=0.265912]
# 13it [00:10,  1.23it/s, Epoch=85, Loss=0.041452, Total Loss=0.005738]
# 4it [00:02,  1.41it/s, Epoch=85, Val Loss=0.333027, Total Val Loss=0.281760]
# 13it [00:11,  1.14it/s, Epoch=86, Loss=0.009547, Total Loss=0.003442]
# 4it [00:02,  1.49it/s, Epoch=86, Val Loss=0.370130, Total Val Loss=0.293899]
# 13it [00:10,  1.22it/s, Epoch=87, Loss=0.004444, Total Loss=0.002380]
# 4it [00:02,  1.41it/s, Epoch=87, Val Loss=0.237108, Total Val Loss=0.258340]
# 13it [00:11,  1.17it/s, Epoch=88, Loss=0.090715, Total Loss=0.008290]
# 4it [00:02,  1.40it/s, Epoch=88, Val Loss=0.231986, Total Val Loss=0.233733]
# 13it [00:11,  1.18it/s, Epoch=89, Loss=0.000544, Total Loss=0.001190]
# 4it [00:02,  1.39it/s, Epoch=89, Val Loss=0.254452, Total Val Loss=0.246874]
# 13it [00:10,  1.20it/s, Epoch=90, Loss=0.003855, Total Loss=0.002528]
# 4it [00:02,  1.40it/s, Epoch=90, Val Loss=0.217260, Total Val Loss=0.255462]
# 13it [00:11,  1.16it/s, Epoch=91, Loss=0.010190, Total Loss=0.003322]
# 4it [00:02,  1.39it/s, Epoch=91, Val Loss=0.276526, Total Val Loss=0.260990]
# 13it [00:11,  1.13it/s, Epoch=92, Loss=0.001237, Total Loss=0.002356]
# 4it [00:02,  1.38it/s, Epoch=92, Val Loss=0.388864, Total Val Loss=0.267168]
# 13it [00:10,  1.20it/s, Epoch=93, Loss=0.023778, Total Loss=0.003305]
# 4it [00:02,  1.40it/s, Epoch=93, Val Loss=0.327769, Total Val Loss=0.259203]
# 13it [00:10,  1.24it/s, Epoch=94, Loss=0.000966, Total Loss=0.003429]
# 4it [00:02,  1.40it/s, Epoch=94, Val Loss=0.403999, Total Val Loss=0.259897]
# 13it [00:10,  1.20it/s, Epoch=95, Loss=0.000886, Total Loss=0.001241]
# 4it [00:02,  1.41it/s, Epoch=95, Val Loss=0.372753, Total Val Loss=0.255735]
# 13it [00:10,  1.19it/s, Epoch=96, Loss=0.001828, Total Loss=0.001478]
# 4it [00:02,  1.49it/s, Epoch=96, Val Loss=0.432461, Total Val Loss=0.263029]
# 13it [00:11,  1.13it/s, Epoch=97, Loss=0.013192, Total Loss=0.002665]
# 4it [00:02,  1.42it/s, Epoch=97, Val Loss=0.368806, Total Val Loss=0.258871]
# 13it [00:10,  1.25it/s, Epoch=98, Loss=0.013496, Total Loss=0.002119]
# 4it [00:02,  1.40it/s, Epoch=98, Val Loss=0.430501, Total Val Loss=0.277308]
# 13it [00:11,  1.12it/s, Epoch=99, Loss=0.031907, Total Loss=0.003638]
# 4it [00:02,  1.42it/s, Epoch=99, Val Loss=0.338513, Total Val Loss=0.256411]
# 13it [00:11,  1.17it/s, Epoch=100, Loss=0.002326, Total Loss=0.001440]
# 4it [00:02,  1.42it/s, Epoch=100, Val Loss=0.360481, Total Val Loss=0.251786]
# 13it [00:11,  1.12it/s, Epoch=101, Loss=0.009813, Total Loss=0.002393]
# 4it [00:02,  1.41it/s, Epoch=101, Val Loss=0.513967, Total Val Loss=0.282804]
# 13it [00:10,  1.20it/s, Epoch=102, Loss=0.002176, Total Loss=0.002120]
# 4it [00:02,  1.45it/s, Epoch=102, Val Loss=0.469436, Total Val Loss=0.264035]
# 13it [00:11,  1.13it/s, Epoch=103, Loss=0.159229, Total Loss=0.013256]
# 4it [00:02,  1.41it/s, Epoch=103, Val Loss=0.572952, Total Val Loss=0.277358]
# 13it [00:11,  1.18it/s, Epoch=104, Loss=0.002535, Total Loss=0.005254]
# 4it [00:02,  1.39it/s, Epoch=104, Val Loss=0.356013, Total Val Loss=0.310972]
# 13it [00:10,  1.19it/s, Epoch=105, Loss=0.004609, Total Loss=0.027965]
# 4it [00:02,  1.48it/s, Epoch=105, Val Loss=0.392866, Total Val Loss=0.327891]
# 13it [00:11,  1.18it/s, Epoch=106, Loss=0.023302, Total Loss=0.004083]
# 4it [00:02,  1.41it/s, Epoch=106, Val Loss=0.589132, Total Val Loss=0.318423]
# 13it [00:10,  1.20it/s, Epoch=107, Loss=0.004756, Total Loss=0.003491]
# 4it [00:02,  1.46it/s, Epoch=107, Val Loss=0.669875, Total Val Loss=0.325846]
# 13it [00:11,  1.14it/s, Epoch=108, Loss=0.012814, Total Loss=0.004410]
# 4it [00:02,  1.48it/s, Epoch=108, Val Loss=1.332777, Total Val Loss=0.484330]
# 13it [00:10,  1.22it/s, Epoch=109, Loss=0.001970, Total Loss=0.001727]
# 4it [00:02,  1.41it/s, Epoch=109, Val Loss=1.405631, Total Val Loss=0.504717]
# 13it [00:10,  1.18it/s, Epoch=110, Loss=0.001751, Total Loss=0.002489]
# 4it [00:02,  1.39it/s, Epoch=110, Val Loss=1.023713, Total Val Loss=0.405224]
# 13it [00:10,  1.23it/s, Epoch=111, Loss=0.254497, Total Loss=0.021981]
# 4it [00:02,  1.47it/s, Epoch=111, Val Loss=1.206930, Total Val Loss=0.460253]
# 13it [00:10,  1.25it/s, Epoch=112, Loss=0.001147, Total Loss=0.002596]
# 4it [00:02,  1.41it/s, Epoch=112, Val Loss=0.503437, Total Val Loss=0.288681]
# 13it [00:10,  1.19it/s, Epoch=113, Loss=0.003641, Total Loss=0.002532]
# 4it [00:02,  1.41it/s, Epoch=113, Val Loss=0.403902, Total Val Loss=0.262587]
# 13it [00:11,  1.15it/s, Epoch=114, Loss=0.002560, Total Loss=0.005606]
# 4it [00:02,  1.48it/s, Epoch=114, Val Loss=0.190878, Total Val Loss=0.233701]
# 13it [00:10,  1.22it/s, Epoch=115, Loss=0.004183, Total Loss=0.003250]
# 4it [00:02,  1.48it/s, Epoch=115, Val Loss=0.335849, Total Val Loss=0.247592]
# 13it [00:11,  1.13it/s, Epoch=116, Loss=0.002589, Total Loss=0.001996]
# 4it [00:02,  1.41it/s, Epoch=116, Val Loss=0.388757, Total Val Loss=0.260599]
# 13it [00:10,  1.24it/s, Epoch=117, Loss=0.001780, Total Loss=0.002098]
# 4it [00:02,  1.42it/s, Epoch=117, Val Loss=0.360381, Total Val Loss=0.247687]
# 13it [00:10,  1.20it/s, Epoch=118, Loss=0.004809, Total Loss=0.001854]
# 4it [00:02,  1.36it/s, Epoch=118, Val Loss=0.377983, Total Val Loss=0.256006]
# 13it [00:11,  1.16it/s, Epoch=119, Loss=0.002717, Total Loss=0.001966]
# 4it [00:02,  1.48it/s, Epoch=119, Val Loss=0.425637, Total Val Loss=0.275583]
# 13it [00:10,  1.19it/s, Epoch=120, Loss=0.010655, Total Loss=0.002549]
# 4it [00:02,  1.47it/s, Epoch=120, Val Loss=0.336456, Total Val Loss=0.244157]
# 13it [00:10,  1.19it/s, Epoch=121, Loss=0.008425, Total Loss=0.001547]
# 4it [00:02,  1.50it/s, Epoch=121, Val Loss=0.560735, Total Val Loss=0.291378]
# 13it [00:11,  1.17it/s, Epoch=122, Loss=0.005727, Total Loss=0.003403]
# 4it [00:02,  1.47it/s, Epoch=122, Val Loss=0.351629, Total Val Loss=0.250542]
# 13it [00:11,  1.16it/s, Epoch=123, Loss=0.021759, Total Loss=0.003395]
# 4it [00:02,  1.42it/s, Epoch=123, Val Loss=0.474026, Total Val Loss=0.273525]
# 13it [00:10,  1.22it/s, Epoch=124, Loss=0.002381, Total Loss=0.001780]
# 4it [00:02,  1.39it/s, Epoch=124, Val Loss=0.343747, Total Val Loss=0.241978]
# 13it [00:10,  1.19it/s, Epoch=125, Loss=0.048670, Total Loss=0.005458]
# 4it [00:02,  1.38it/s, Epoch=125, Val Loss=0.334377, Total Val Loss=0.232639]
# 13it [00:10,  1.23it/s, Epoch=126, Loss=0.000690, Total Loss=0.001699]
# 4it [00:02,  1.41it/s, Epoch=126, Val Loss=0.276436, Total Val Loss=0.227958]
# 13it [00:11,  1.11it/s, Epoch=127, Loss=0.003316, Total Loss=0.001686]
# 4it [00:02,  1.40it/s, Epoch=127, Val Loss=0.349481, Total Val Loss=0.251804]
# 13it [00:10,  1.20it/s, Epoch=128, Loss=0.017170, Total Loss=0.002974]
# 4it [00:02,  1.45it/s, Epoch=128, Val Loss=0.436474, Total Val Loss=0.272783]
# 13it [00:11,  1.16it/s, Epoch=129, Loss=0.012438, Total Loss=0.002666]
# 4it [00:02,  1.49it/s, Epoch=129, Val Loss=0.273767, Total Val Loss=0.237669]
# 13it [00:11,  1.18it/s, Epoch=130, Loss=0.005952, Total Loss=0.001229]
# 4it [00:02,  1.47it/s, Epoch=130, Val Loss=0.252497, Total Val Loss=0.230484]
# 13it [00:11,  1.13it/s, Epoch=131, Loss=0.002501, Total Loss=0.000929]
# 4it [00:02,  1.40it/s, Epoch=131, Val Loss=0.310072, Total Val Loss=0.238683]
# 13it [00:11,  1.15it/s, Epoch=132, Loss=0.006746, Total Loss=0.001415]
# 4it [00:02,  1.45it/s, Epoch=132, Val Loss=0.355561, Total Val Loss=0.255685]
# 13it [00:11,  1.16it/s, Epoch=133, Loss=0.000893, Total Loss=0.001554]
# 4it [00:02,  1.48it/s, Epoch=133, Val Loss=0.260156, Total Val Loss=0.225573]
# 13it [00:10,  1.20it/s, Epoch=134, Loss=0.054652, Total Loss=0.005758]
# 4it [00:02,  1.51it/s, Epoch=134, Val Loss=0.631153, Total Val Loss=0.303436]
# 13it [00:10,  1.24it/s, Epoch=135, Loss=0.005092, Total Loss=0.001130]
# 4it [00:02,  1.42it/s, Epoch=135, Val Loss=0.208390, Total Val Loss=0.214786]
# 13it [00:10,  1.19it/s, Epoch=136, Loss=0.002651, Total Loss=0.001996]
# 4it [00:02,  1.48it/s, Epoch=136, Val Loss=0.147944, Total Val Loss=0.198073]
# 13it [00:10,  1.19it/s, Epoch=137, Loss=0.003281, Total Loss=0.000960]
# 4it [00:02,  1.47it/s, Epoch=137, Val Loss=0.152368, Total Val Loss=0.197339]
# 13it [00:11,  1.18it/s, Epoch=138, Loss=0.002629, Total Loss=0.001250]
# 4it [00:02,  1.42it/s, Epoch=138, Val Loss=0.165378, Total Val Loss=0.195308]
# 13it [00:11,  1.17it/s, Epoch=139, Loss=0.133013, Total Loss=0.011336]
# 4it [00:02,  1.40it/s, Epoch=139, Val Loss=0.075342, Total Val Loss=0.202308]
# 13it [00:11,  1.17it/s, Epoch=140, Loss=0.004122, Total Loss=0.001136]
# 4it [00:02,  1.46it/s, Epoch=140, Val Loss=0.120933, Total Val Loss=0.188885]
# 13it [00:11,  1.14it/s, Epoch=141, Loss=0.007882, Total Loss=0.001412]
# 4it [00:02,  1.41it/s, Epoch=141, Val Loss=0.078757, Total Val Loss=0.190551]
# 13it [00:11,  1.17it/s, Epoch=142, Loss=0.016751, Total Loss=0.002171]
# 4it [00:02,  1.49it/s, Epoch=142, Val Loss=0.057372, Total Val Loss=0.196095]
# 13it [00:10,  1.27it/s, Epoch=143, Loss=0.061077, Total Loss=0.007261]
# 4it [00:02,  1.47it/s, Epoch=143, Val Loss=0.109018, Total Val Loss=0.197061]
# 13it [00:10,  1.19it/s, Epoch=144, Loss=0.003323, Total Loss=0.001022]
# 4it [00:02,  1.41it/s, Epoch=144, Val Loss=0.175819, Total Val Loss=0.196488]
# 13it [00:11,  1.16it/s, Epoch=145, Loss=0.006520, Total Loss=0.001588]
# 4it [00:02,  1.40it/s, Epoch=145, Val Loss=0.102930, Total Val Loss=0.189011]
# 13it [00:10,  1.21it/s, Epoch=146, Loss=0.001920, Total Loss=0.000987]
# 4it [00:02,  1.48it/s, Epoch=146, Val Loss=0.142468, Total Val Loss=0.189414]
# 13it [00:10,  1.20it/s, Epoch=147, Loss=0.000785, Total Loss=0.000527]
# 4it [00:02,  1.42it/s, Epoch=147, Val Loss=0.113914, Total Val Loss=0.188092]
# 13it [00:11,  1.14it/s, Epoch=148, Loss=0.003408, Total Loss=0.001519]
# 4it [00:02,  1.41it/s, Epoch=148, Val Loss=0.053515, Total Val Loss=0.188096]
# 13it [00:11,  1.15it/s, Epoch=149, Loss=0.004070, Total Loss=0.000859]
# 4it [00:02,  1.40it/s, Epoch=149, Val Loss=0.079303, Total Val Loss=0.187229]
# 13it [00:11,  1.16it/s, Epoch=150, Loss=0.038838, Total Loss=0.004230]
# 4it [00:02,  1.41it/s, Epoch=150, Val Loss=0.120846, Total Val Loss=0.179868]
# 13it [00:10,  1.27it/s, Epoch=151, Loss=0.002090, Total Loss=0.000760]
# 4it [00:02,  1.47it/s, Epoch=151, Val Loss=0.100378, Total Val Loss=0.177719]
# 13it [00:10,  1.25it/s, Epoch=152, Loss=0.011796, Total Loss=0.001693]
# 4it [00:02,  1.41it/s, Epoch=152, Val Loss=0.129291, Total Val Loss=0.180258]
# 13it [00:11,  1.16it/s, Epoch=153, Loss=0.022095, Total Loss=0.002166]
# 4it [00:02,  1.39it/s, Epoch=153, Val Loss=0.088313, Total Val Loss=0.174866]
# 13it [00:11,  1.13it/s, Epoch=154, Loss=0.001115, Total Loss=0.000734]
# 4it [00:02,  1.46it/s, Epoch=154, Val Loss=0.111036, Total Val Loss=0.184946]
# 13it [00:10,  1.19it/s, Epoch=155, Loss=0.004105, Total Loss=0.001127]
# 4it [00:02,  1.41it/s, Epoch=155, Val Loss=0.088409, Total Val Loss=0.192262]
# 13it [00:11,  1.15it/s, Epoch=156, Loss=0.003313, Total Loss=0.000761]
# 4it [00:02,  1.42it/s, Epoch=156, Val Loss=0.116912, Total Val Loss=0.197572]
# 13it [00:10,  1.19it/s, Epoch=157, Loss=0.001887, Total Loss=0.001097]
# 4it [00:02,  1.41it/s, Epoch=157, Val Loss=0.112330, Total Val Loss=0.199365]
# 13it [00:11,  1.13it/s, Epoch=158, Loss=0.013145, Total Loss=0.001534]
# 4it [00:02,  1.41it/s, Epoch=158, Val Loss=0.092025, Total Val Loss=0.192612]
# 13it [00:11,  1.16it/s, Epoch=159, Loss=0.000371, Total Loss=0.000753]
# 4it [00:02,  1.41it/s, Epoch=159, Val Loss=0.090162, Total Val Loss=0.185923]
# 13it [00:10,  1.20it/s, Epoch=160, Loss=0.008065, Total Loss=0.001363]
# 4it [00:02,  1.45it/s, Epoch=160, Val Loss=0.087066, Total Val Loss=0.191537]
# 13it [00:10,  1.21it/s, Epoch=161, Loss=0.001432, Total Loss=0.000629]
# 4it [00:02,  1.48it/s, Epoch=161, Val Loss=0.073786, Total Val Loss=0.178226]
# 13it [00:11,  1.12it/s, Epoch=162, Loss=0.000529, Total Loss=0.000443]
# 4it [00:02,  1.48it/s, Epoch=162, Val Loss=0.128035, Total Val Loss=0.192207]
# 13it [00:11,  1.16it/s, Epoch=163, Loss=0.001458, Total Loss=0.001036]
# 4it [00:02,  1.38it/s, Epoch=163, Val Loss=0.076350, Total Val Loss=0.178488]
# 13it [00:11,  1.16it/s, Epoch=164, Loss=0.002241, Total Loss=0.001035]
# 4it [00:02,  1.39it/s, Epoch=164, Val Loss=0.140371, Total Val Loss=0.183789]
# 13it [00:10,  1.21it/s, Epoch=165, Loss=0.006690, Total Loss=0.000998]
# 4it [00:02,  1.38it/s, Epoch=165, Val Loss=0.119380, Total Val Loss=0.180681]
# 13it [00:11,  1.15it/s, Epoch=166, Loss=0.000116, Total Loss=0.000379]
# 4it [00:02,  1.41it/s, Epoch=166, Val Loss=0.108543, Total Val Loss=0.181986]
# 13it [00:10,  1.25it/s, Epoch=167, Loss=0.041651, Total Loss=0.004546]
# 4it [00:02,  1.46it/s, Epoch=167, Val Loss=0.182854, Total Val Loss=0.192514]
# 13it [00:10,  1.19it/s, Epoch=168, Loss=0.018466, Total Loss=0.001873]
# 4it [00:02,  1.42it/s, Epoch=168, Val Loss=0.023445, Total Val Loss=0.181635]
# 13it [00:10,  1.21it/s, Epoch=169, Loss=0.003738, Total Loss=0.000780]
# 4it [00:02,  1.38it/s, Epoch=169, Val Loss=0.011515, Total Val Loss=0.214094]
# 13it [00:11,  1.12it/s, Epoch=170, Loss=0.000399, Total Loss=0.000588]
# 4it [00:02,  1.47it/s, Epoch=170, Val Loss=0.015342, Total Val Loss=0.216816]
# 13it [00:10,  1.29it/s, Epoch=171, Loss=0.001372, Total Loss=0.030171]
# 4it [00:02,  1.40it/s, Epoch=171, Val Loss=0.035971, Total Val Loss=0.192257]
# 13it [00:10,  1.21it/s, Epoch=172, Loss=0.000213, Total Loss=0.007910]
# 4it [00:02,  1.47it/s, Epoch=172, Val Loss=0.083978, Total Val Loss=0.193458]
# 13it [00:11,  1.17it/s, Epoch=173, Loss=0.000402, Total Loss=0.001282]
# 4it [00:02,  1.46it/s, Epoch=173, Val Loss=0.126007, Total Val Loss=0.184201]
# 13it [00:11,  1.13it/s, Epoch=174, Loss=0.002241, Total Loss=0.000900]
# 4it [00:02,  1.41it/s, Epoch=174, Val Loss=0.129271, Total Val Loss=0.178354]
# 13it [00:10,  1.19it/s, Epoch=175, Loss=0.001588, Total Loss=0.001443]
# 4it [00:02,  1.38it/s, Epoch=175, Val Loss=0.098902, Total Val Loss=0.169818]
# 13it [00:10,  1.25it/s, Epoch=176, Loss=0.012491, Total Loss=0.001698]
# 4it [00:02,  1.39it/s, Epoch=176, Val Loss=0.079780, Total Val Loss=0.169358]
# 13it [00:11,  1.18it/s, Epoch=177, Loss=0.008435, Total Loss=0.001508]
# 4it [00:02,  1.47it/s, Epoch=177, Val Loss=0.065033, Total Val Loss=0.164732]
# 13it [00:11,  1.15it/s, Epoch=178, Loss=0.003589, Total Loss=0.000774]
# 4it [00:02,  1.46it/s, Epoch=178, Val Loss=0.098858, Total Val Loss=0.168338]
# 13it [00:10,  1.24it/s, Epoch=179, Loss=0.000810, Total Loss=0.000864]
# 4it [00:02,  1.41it/s, Epoch=179, Val Loss=0.090553, Total Val Loss=0.165706]
# 13it [00:10,  1.20it/s, Epoch=180, Loss=0.385248, Total Loss=0.030157]
# 4it [00:02,  1.37it/s, Epoch=180, Val Loss=0.105482, Total Val Loss=0.160666]
# 13it [00:10,  1.24it/s, Epoch=181, Loss=0.007729, Total Loss=0.004274]
# 4it [00:02,  1.45it/s, Epoch=181, Val Loss=0.033293, Total Val Loss=0.259268]
# 13it [00:11,  1.10it/s, Epoch=182, Loss=0.002291, Total Loss=0.009490]
# 4it [00:02,  1.39it/s, Epoch=182, Val Loss=0.019463, Total Val Loss=0.295190]
# 13it [00:10,  1.28it/s, Epoch=183, Loss=0.004098, Total Loss=0.013798]
# 4it [00:02,  1.38it/s, Epoch=183, Val Loss=0.020686, Total Val Loss=0.250027]
# 13it [00:10,  1.19it/s, Epoch=184, Loss=0.017896, Total Loss=0.003469]
# 4it [00:02,  1.47it/s, Epoch=184, Val Loss=0.037606, Total Val Loss=0.206633]
# 13it [00:10,  1.20it/s, Epoch=185, Loss=0.000778, Total Loss=0.000975]
# 4it [00:02,  1.39it/s, Epoch=185, Val Loss=0.039252, Total Val Loss=0.187656]
# 13it [00:11,  1.14it/s, Epoch=186, Loss=0.008788, Total Loss=0.003772]
# 4it [00:02,  1.39it/s, Epoch=186, Val Loss=0.080056, Total Val Loss=0.174646]
# 13it [00:10,  1.26it/s, Epoch=187, Loss=0.014382, Total Loss=0.002808]
# 4it [00:02,  1.45it/s, Epoch=187, Val Loss=0.044192, Total Val Loss=0.168508]
# 13it [00:11,  1.16it/s, Epoch=188, Loss=0.041207, Total Loss=0.004184]
# 4it [00:02,  1.46it/s, Epoch=188, Val Loss=0.081429, Total Val Loss=0.157163]
# 13it [00:10,  1.24it/s, Epoch=189, Loss=0.004087, Total Loss=0.000973]
# 4it [00:02,  1.37it/s, Epoch=189, Val Loss=0.034962, Total Val Loss=0.149890]
# 13it [00:10,  1.20it/s, Epoch=190, Loss=0.003728, Total Loss=0.001054]
# 4it [00:02,  1.43it/s, Epoch=190, Val Loss=0.019792, Total Val Loss=0.157215]
# 13it [00:10,  1.22it/s, Epoch=191, Loss=0.001293, Total Loss=0.000765]
# 4it [00:02,  1.43it/s, Epoch=191, Val Loss=0.017248, Total Val Loss=0.159173]
# 13it [00:11,  1.18it/s, Epoch=192, Loss=0.000734, Total Loss=0.002304]
# 4it [00:02,  1.38it/s, Epoch=192, Val Loss=0.016887, Total Val Loss=0.160189]
# 13it [00:10,  1.18it/s, Epoch=193, Loss=0.002410, Total Loss=0.000776]
# 4it [00:02,  1.39it/s, Epoch=193, Val Loss=0.014066, Total Val Loss=0.144937]
# 13it [00:10,  1.20it/s, Epoch=194, Loss=0.018897, Total Loss=0.003960]
# 4it [00:02,  1.39it/s, Epoch=194, Val Loss=0.012045, Total Val Loss=0.139031]
# 13it [00:09,  1.31it/s, Epoch=195, Loss=0.001386, Total Loss=0.000426]
# 4it [00:02,  1.37it/s, Epoch=195, Val Loss=0.019613, Total Val Loss=0.130017]
# 13it [00:11,  1.16it/s, Epoch=196, Loss=0.009076, Total Loss=0.002392]
# 4it [00:02,  1.36it/s, Epoch=196, Val Loss=0.025048, Total Val Loss=0.145770]
# 13it [00:11,  1.14it/s, Epoch=197, Loss=0.024912, Total Loss=0.003662]
# 4it [00:02,  1.48it/s, Epoch=197, Val Loss=0.021342, Total Val Loss=0.149222]
# 13it [00:11,  1.17it/s, Epoch=198, Loss=0.001546, Total Loss=0.001434]
# 4it [00:02,  1.37it/s, Epoch=198, Val Loss=0.018846, Total Val Loss=0.137506]
# 13it [00:10,  1.21it/s, Epoch=199, Loss=0.000371, Total Loss=0.000321]
# 4it [00:02,  1.38it/s, Epoch=199, Val Loss=0.017473, Total Val Loss=0.147648]
# 13it [00:11,  1.17it/s, Epoch=200, Loss=0.001982, Total Loss=0.000574]
# 4it [00:02,  1.37it/s, Epoch=200, Val Loss=0.016152, Total Val Loss=0.145192]
# 13it [00:11,  1.14it/s, Epoch=201, Loss=0.000428, Total Loss=0.000933]
# 4it [00:02,  1.39it/s, Epoch=201, Val Loss=0.018079, Total Val Loss=0.146698]
# 13it [00:10,  1.20it/s, Epoch=202, Loss=0.003574, Total Loss=0.000883]
# 4it [00:02,  1.47it/s, Epoch=202, Val Loss=0.031674, Total Val Loss=0.155837]
# 13it [00:10,  1.23it/s, Epoch=203, Loss=0.002760, Total Loss=0.000877]
# 4it [00:02,  1.45it/s, Epoch=203, Val Loss=0.027318, Total Val Loss=0.155677]
# 13it [00:11,  1.13it/s, Epoch=204, Loss=0.001844, Total Loss=0.000366]
# 4it [00:02,  1.44it/s, Epoch=204, Val Loss=0.028219, Total Val Loss=0.139658]
# 13it [00:10,  1.20it/s, Epoch=205, Loss=0.060905, Total Loss=0.005477]
# 4it [00:02,  1.37it/s, Epoch=205, Val Loss=0.017255, Total Val Loss=0.170407]
# 13it [00:10,  1.24it/s, Epoch=206, Loss=0.001221, Total Loss=0.000456]
# 4it [00:02,  1.40it/s, Epoch=206, Val Loss=0.027904, Total Val Loss=0.137923]
# 13it [00:11,  1.15it/s, Epoch=207, Loss=0.013102, Total Loss=0.001259]
# 4it [00:02,  1.38it/s, Epoch=207, Val Loss=0.025996, Total Val Loss=0.132624]
# 13it [00:10,  1.23it/s, Epoch=208, Loss=0.000212, Total Loss=0.000382]
# 4it [00:02,  1.43it/s, Epoch=208, Val Loss=0.029969, Total Val Loss=0.127119]
# 13it [00:10,  1.21it/s, Epoch=209, Loss=0.000276, Total Loss=0.000303]
# 4it [00:02,  1.38it/s, Epoch=209, Val Loss=0.026935, Total Val Loss=0.128266]
# 13it [00:10,  1.18it/s, Epoch=210, Loss=0.001127, Total Loss=0.000468]
# 4it [00:02,  1.42it/s, Epoch=210, Val Loss=0.022816, Total Val Loss=0.126418]
# 13it [00:10,  1.21it/s, Epoch=211, Loss=0.000487, Total Loss=0.000276]
# 4it [00:02,  1.46it/s, Epoch=211, Val Loss=0.025414, Total Val Loss=0.132901]
# 13it [00:10,  1.20it/s, Epoch=212, Loss=0.000587, Total Loss=0.000363]
# 4it [00:02,  1.40it/s, Epoch=212, Val Loss=0.031309, Total Val Loss=0.131183]
# 13it [00:10,  1.19it/s, Epoch=213, Loss=0.017766, Total Loss=0.001722]
# 4it [00:02,  1.38it/s, Epoch=213, Val Loss=0.045273, Total Val Loss=0.141350]
# 13it [00:11,  1.14it/s, Epoch=214, Loss=0.004735, Total Loss=0.000620]
# 4it [00:02,  1.35it/s, Epoch=214, Val Loss=0.039144, Total Val Loss=0.126144]
# 13it [00:10,  1.19it/s, Epoch=215, Loss=0.000765, Total Loss=0.000361]
# 4it [00:02,  1.38it/s, Epoch=215, Val Loss=0.034344, Total Val Loss=0.124225]
# 13it [00:10,  1.26it/s, Epoch=216, Loss=0.000154, Total Loss=0.001488]
# 4it [00:02,  1.37it/s, Epoch=216, Val Loss=0.032468, Total Val Loss=0.125862]
# 13it [00:11,  1.17it/s, Epoch=217, Loss=0.000867, Total Loss=0.000464]
# 4it [00:02,  1.36it/s, Epoch=217, Val Loss=0.018664, Total Val Loss=0.135024]
# 13it [00:10,  1.19it/s, Epoch=218, Loss=0.008401, Total Loss=0.001046]
# 4it [00:02,  1.38it/s, Epoch=218, Val Loss=0.029610, Total Val Loss=0.123347]
# 13it [00:10,  1.24it/s, Epoch=219, Loss=0.001388, Total Loss=0.000602]
# 4it [00:02,  1.38it/s, Epoch=219, Val Loss=0.024680, Total Val Loss=0.129039]
# 13it [00:10,  1.22it/s, Epoch=220, Loss=0.011084, Total Loss=0.001392]
# 4it [00:02,  1.42it/s, Epoch=220, Val Loss=0.036516, Total Val Loss=0.126069]
# 13it [00:11,  1.18it/s, Epoch=221, Loss=0.000102, Total Loss=0.000290]
# 4it [00:02,  1.37it/s, Epoch=221, Val Loss=0.032922, Total Val Loss=0.135521]
# 13it [00:11,  1.15it/s, Epoch=222, Loss=0.001055, Total Loss=0.000443]
# 4it [00:02,  1.38it/s, Epoch=222, Val Loss=0.026916, Total Val Loss=0.129251]
# 13it [00:10,  1.24it/s, Epoch=223, Loss=0.009623, Total Loss=0.001032]
# 4it [00:02,  1.42it/s, Epoch=223, Val Loss=0.033938, Total Val Loss=0.139274]
# 13it [00:10,  1.25it/s, Epoch=224, Loss=0.000095, Total Loss=0.000272]
# 4it [00:02,  1.38it/s, Epoch=224, Val Loss=0.023952, Total Val Loss=0.138655]
# 13it [00:10,  1.20it/s, Epoch=225, Loss=0.000492, Total Loss=0.000381]
# 4it [00:02,  1.41it/s, Epoch=225, Val Loss=0.027609, Total Val Loss=0.136117]
# 13it [00:11,  1.18it/s, Epoch=226, Loss=0.005206, Total Loss=0.000859]
# 4it [00:02,  1.43it/s, Epoch=226, Val Loss=0.028449, Total Val Loss=0.128545]
# 13it [00:10,  1.24it/s, Epoch=227, Loss=0.001291, Total Loss=0.000420]
# 4it [00:02,  1.36it/s, Epoch=227, Val Loss=0.033348, Total Val Loss=0.129569]
# 13it [00:11,  1.18it/s, Epoch=228, Loss=0.000273, Total Loss=0.000397]
# 4it [00:02,  1.35it/s, Epoch=228, Val Loss=0.029646, Total Val Loss=0.127767]
# 13it [00:10,  1.20it/s, Epoch=229, Loss=0.023614, Total Loss=0.002026]
# 4it [00:02,  1.43it/s, Epoch=229, Val Loss=0.042166, Total Val Loss=0.138860]
# 13it [00:10,  1.25it/s, Epoch=230, Loss=0.006332, Total Loss=0.000759]
# 4it [00:02,  1.35it/s, Epoch=230, Val Loss=0.031107, Total Val Loss=0.135737]
# 13it [00:10,  1.19it/s, Epoch=231, Loss=0.000540, Total Loss=0.001148]
# 4it [00:02,  1.38it/s, Epoch=231, Val Loss=0.024364, Total Val Loss=0.130629]
# 13it [00:11,  1.16it/s, Epoch=232, Loss=0.000920, Total Loss=0.000302]
# 4it [00:02,  1.36it/s, Epoch=232, Val Loss=0.019839, Total Val Loss=0.138022]
# 13it [00:10,  1.20it/s, Epoch=233, Loss=0.000247, Total Loss=0.001949]
# 4it [00:02,  1.44it/s, Epoch=233, Val Loss=0.016469, Total Val Loss=0.136693]
# 13it [00:11,  1.18it/s, Epoch=234, Loss=0.000585, Total Loss=0.000393]
# 4it [00:02,  1.39it/s, Epoch=234, Val Loss=0.020139, Total Val Loss=0.133977]
# 13it [00:11,  1.17it/s, Epoch=235, Loss=0.000592, Total Loss=0.000227]
# 4it [00:03,  1.33it/s, Epoch=235, Val Loss=0.015372, Total Val Loss=0.132629]
# 13it [00:11,  1.13it/s, Epoch=236, Loss=0.002633, Total Loss=0.000414]
# 4it [00:02,  1.43it/s, Epoch=236, Val Loss=0.025713, Total Val Loss=0.123830]
# 13it [00:11,  1.14it/s, Epoch=237, Loss=0.001249, Total Loss=0.000323]
# 4it [00:02,  1.42it/s, Epoch=237, Val Loss=0.039060, Total Val Loss=0.119052]
# 13it [00:11,  1.18it/s, Epoch=238, Loss=0.007953, Total Loss=0.000803]
# 4it [00:02,  1.42it/s, Epoch=238, Val Loss=0.031417, Total Val Loss=0.119586]
# 13it [00:11,  1.16it/s, Epoch=239, Loss=0.001018, Total Loss=0.000622]
# 4it [00:02,  1.34it/s, Epoch=239, Val Loss=0.025921, Total Val Loss=0.132272]
# 13it [00:10,  1.29it/s, Epoch=240, Loss=0.000056, Total Loss=0.000340]
# 4it [00:02,  1.34it/s, Epoch=240, Val Loss=0.022091, Total Val Loss=0.133891]
# 13it [00:11,  1.14it/s, Epoch=241, Loss=0.000136, Total Loss=0.000234]
# 4it [00:02,  1.42it/s, Epoch=241, Val Loss=0.020368, Total Val Loss=0.141558]
# 13it [00:11,  1.16it/s, Epoch=242, Loss=0.000229, Total Loss=0.000145]
# 4it [00:02,  1.42it/s, Epoch=242, Val Loss=0.026229, Total Val Loss=0.135661]
# 13it [00:10,  1.19it/s, Epoch=243, Loss=0.000629, Total Loss=0.000323]
# 4it [00:02,  1.43it/s, Epoch=243, Val Loss=0.025796, Total Val Loss=0.130360]
# 13it [00:10,  1.25it/s, Epoch=244, Loss=0.000412, Total Loss=0.000207]
# 4it [00:02,  1.44it/s, Epoch=244, Val Loss=0.022678, Total Val Loss=0.136520]
# 13it [00:11,  1.18it/s, Epoch=245, Loss=0.000245, Total Loss=0.000258]
# 4it [00:02,  1.34it/s, Epoch=245, Val Loss=0.028397, Total Val Loss=0.131909]
# 13it [00:10,  1.19it/s, Epoch=246, Loss=0.001800, Total Loss=0.000315]
# 4it [00:02,  1.43it/s, Epoch=246, Val Loss=0.019843, Total Val Loss=0.134033]
# 13it [00:11,  1.14it/s, Epoch=247, Loss=0.002011, Total Loss=0.000348]
# 4it [00:02,  1.37it/s, Epoch=247, Val Loss=0.018517, Total Val Loss=0.133504]
# 13it [00:11,  1.16it/s, Epoch=248, Loss=0.000074, Total Loss=0.000168]
# 4it [00:02,  1.36it/s, Epoch=248, Val Loss=0.016956, Total Val Loss=0.132674]
# 13it [00:10,  1.28it/s, Epoch=249, Loss=0.000468, Total Loss=0.000374]
# 4it [00:02,  1.37it/s, Epoch=249, Val Loss=0.018192, Total Val Loss=0.131946]
# 13it [00:11,  1.17it/s, Epoch=250, Loss=0.000353, Total Loss=0.000495]
# 4it [00:02,  1.43it/s, Epoch=250, Val Loss=0.017626, Total Val Loss=0.136440]
# 13it [00:11,  1.17it/s, Epoch=251, Loss=0.000255, Total Loss=0.000295]
# 4it [00:02,  1.38it/s, Epoch=251, Val Loss=0.038528, Total Val Loss=0.125409]
# 13it [00:10,  1.23it/s, Epoch=252, Loss=0.001689, Total Loss=0.000381]
# 4it [00:02,  1.34it/s, Epoch=252, Val Loss=0.016412, Total Val Loss=0.130326]
# 13it [00:10,  1.23it/s, Epoch=253, Loss=0.000359, Total Loss=0.000235]
# 4it [00:02,  1.35it/s, Epoch=253, Val Loss=0.025985, Total Val Loss=0.122322]
# 13it [00:10,  1.19it/s, Epoch=254, Loss=0.007272, Total Loss=0.000888]
# 4it [00:02,  1.36it/s, Epoch=254, Val Loss=0.015323, Total Val Loss=0.134664]
# 13it [00:11,  1.16it/s, Epoch=255, Loss=0.000129, Total Loss=0.000171]
# 4it [00:02,  1.34it/s, Epoch=255, Val Loss=0.022041, Total Val Loss=0.129324]
# 13it [00:11,  1.17it/s, Epoch=256, Loss=0.000422, Total Loss=0.000440]
# 4it [00:02,  1.42it/s, Epoch=256, Val Loss=0.023645, Total Val Loss=0.122721]
# 13it [00:10,  1.21it/s, Epoch=257, Loss=0.002287, Total Loss=0.000355]
# 4it [00:02,  1.41it/s, Epoch=257, Val Loss=0.018257, Total Val Loss=0.127137]
# 13it [00:10,  1.18it/s, Epoch=258, Loss=0.002345, Total Loss=0.000412]
# 4it [00:02,  1.35it/s, Epoch=258, Val Loss=0.026381, Total Val Loss=0.120322]
# 13it [00:10,  1.22it/s, Epoch=259, Loss=0.000198, Total Loss=0.000391]
# 4it [00:02,  1.42it/s, Epoch=259, Val Loss=0.027644, Total Val Loss=0.127986]
# 13it [00:11,  1.15it/s, Epoch=260, Loss=0.000601, Total Loss=0.000180]
# 4it [00:02,  1.35it/s, Epoch=260, Val Loss=0.022299, Total Val Loss=0.122518]
# 13it [00:10,  1.19it/s, Epoch=261, Loss=0.004964, Total Loss=0.000529]
# 4it [00:02,  1.41it/s, Epoch=261, Val Loss=0.021286, Total Val Loss=0.127046]
# 13it [00:10,  1.19it/s, Epoch=262, Loss=0.000413, Total Loss=0.000281]
# 4it [00:02,  1.39it/s, Epoch=262, Val Loss=0.027753, Total Val Loss=0.124703]
# 13it [00:10,  1.24it/s, Epoch=263, Loss=0.000082, Total Loss=0.000197]
# 4it [00:02,  1.36it/s, Epoch=263, Val Loss=0.020800, Total Val Loss=0.125284]
# 13it [00:11,  1.15it/s, Epoch=264, Loss=0.000601, Total Loss=0.000236]
# 4it [00:02,  1.43it/s, Epoch=264, Val Loss=0.033218, Total Val Loss=0.126796]
# 13it [00:11,  1.17it/s, Epoch=265, Loss=0.000250, Total Loss=0.000205]
# 4it [00:03,  1.30it/s, Epoch=265, Val Loss=0.029245, Total Val Loss=0.128061]
# 13it [00:11,  1.17it/s, Epoch=266, Loss=0.000630, Total Loss=0.000255]
# 4it [00:02,  1.37it/s, Epoch=266, Val Loss=0.020948, Total Val Loss=0.134589]
# 13it [00:10,  1.20it/s, Epoch=267, Loss=0.000461, Total Loss=0.000312]
# 4it [00:02,  1.34it/s, Epoch=267, Val Loss=0.045805, Total Val Loss=0.123661]
# 13it [00:11,  1.17it/s, Epoch=268, Loss=0.000396, Total Loss=0.000210]
# 4it [00:02,  1.43it/s, Epoch=268, Val Loss=0.022525, Total Val Loss=0.129850]
# 13it [00:10,  1.21it/s, Epoch=269, Loss=0.000114, Total Loss=0.000116]
# 4it [00:02,  1.41it/s, Epoch=269, Val Loss=0.029707, Total Val Loss=0.125362]
# 13it [00:11,  1.16it/s, Epoch=270, Loss=0.000322, Total Loss=0.000214]
# 4it [00:02,  1.33it/s, Epoch=270, Val Loss=0.017705, Total Val Loss=0.124650]
# 13it [00:10,  1.21it/s, Epoch=271, Loss=0.000308, Total Loss=0.000204]
# 4it [00:02,  1.34it/s, Epoch=271, Val Loss=0.026901, Total Val Loss=0.121527]
# 13it [00:11,  1.17it/s, Epoch=272, Loss=0.001572, Total Loss=0.000231]
# 4it [00:02,  1.37it/s, Epoch=272, Val Loss=0.013995, Total Val Loss=0.140192]
# 13it [00:10,  1.19it/s, Epoch=273, Loss=0.000057, Total Loss=0.000257]
# 4it [00:02,  1.36it/s, Epoch=273, Val Loss=0.031855, Total Val Loss=0.126928]
# 13it [00:11,  1.09it/s, Epoch=274, Loss=0.003441, Total Loss=0.000554]
# 4it [00:02,  1.34it/s, Epoch=274, Val Loss=0.018955, Total Val Loss=0.121919]
# 13it [00:10,  1.24it/s, Epoch=275, Loss=0.000204, Total Loss=0.000153]
# 4it [00:02,  1.41it/s, Epoch=275, Val Loss=0.022800, Total Val Loss=0.122496]
# 13it [00:10,  1.20it/s, Epoch=276, Loss=0.000059, Total Loss=0.000136]
# 4it [00:02,  1.35it/s, Epoch=276, Val Loss=0.027986, Total Val Loss=0.117399]
# 13it [00:11,  1.17it/s, Epoch=277, Loss=0.000301, Total Loss=0.000182]
# 4it [00:02,  1.35it/s, Epoch=277, Val Loss=0.040982, Total Val Loss=0.119315]
# 13it [00:10,  1.19it/s, Epoch=278, Loss=0.000076, Total Loss=0.000215]
# 4it [00:02,  1.34it/s, Epoch=278, Val Loss=0.025728, Total Val Loss=0.126102]
# 13it [00:10,  1.20it/s, Epoch=279, Loss=0.000328, Total Loss=0.000180]
# 4it [00:02,  1.40it/s, Epoch=279, Val Loss=0.021561, Total Val Loss=0.134999]
# 13it [00:11,  1.15it/s, Epoch=280, Loss=0.001189, Total Loss=0.000349]
# 4it [00:03,  1.30it/s, Epoch=280, Val Loss=0.025870, Total Val Loss=0.123043]
# 13it [00:11,  1.17it/s, Epoch=281, Loss=0.000468, Total Loss=0.000158]
# 4it [00:02,  1.36it/s, Epoch=281, Val Loss=0.020560, Total Val Loss=0.132072]
# 13it [00:11,  1.17it/s, Epoch=282, Loss=0.000161, Total Loss=0.000155]
# 4it [00:03,  1.33it/s, Epoch=282, Val Loss=0.017007, Total Val Loss=0.131504]
# 13it [00:11,  1.16it/s, Epoch=283, Loss=0.000430, Total Loss=0.000218]
# 4it [00:02,  1.39it/s, Epoch=283, Val Loss=0.015586, Total Val Loss=0.126250]
# 13it [00:11,  1.14it/s, Epoch=284, Loss=0.000087, Total Loss=0.000251]
# 4it [00:02,  1.39it/s, Epoch=284, Val Loss=0.026186, Total Val Loss=0.121211]
# 13it [00:11,  1.17it/s, Epoch=285, Loss=0.000657, Total Loss=0.000168]
# 4it [00:02,  1.34it/s, Epoch=285, Val Loss=0.025237, Total Val Loss=0.119425]
# 13it [00:10,  1.19it/s, Epoch=286, Loss=0.000154, Total Loss=0.000185]
# 4it [00:02,  1.34it/s, Epoch=286, Val Loss=0.034208, Total Val Loss=0.117536]
# 13it [00:10,  1.22it/s, Epoch=287, Loss=0.000377, Total Loss=0.000301]
# 4it [00:02,  1.35it/s, Epoch=287, Val Loss=0.040887, Total Val Loss=0.122660]
# 13it [00:11,  1.16it/s, Epoch=288, Loss=0.000341, Total Loss=0.000174]
# 4it [00:02,  1.35it/s, Epoch=288, Val Loss=0.023107, Total Val Loss=0.129156]
# 13it [00:11,  1.17it/s, Epoch=289, Loss=0.002376, Total Loss=0.000293]
# 4it [00:03,  1.33it/s, Epoch=289, Val Loss=0.026596, Total Val Loss=0.123684]
# 13it [00:10,  1.19it/s, Epoch=290, Loss=0.000412, Total Loss=0.000216]
# 4it [00:02,  1.39it/s, Epoch=290, Val Loss=0.025361, Total Val Loss=0.121841]
# 13it [00:10,  1.25it/s, Epoch=291, Loss=0.004022, Total Loss=0.000480]
# 4it [00:02,  1.40it/s, Epoch=291, Val Loss=0.023229, Total Val Loss=0.119370]
# 13it [00:10,  1.20it/s, Epoch=292, Loss=0.000034, Total Loss=0.000097]
# 4it [00:02,  1.36it/s, Epoch=292, Val Loss=0.026466, Total Val Loss=0.127225]
# 13it [00:10,  1.18it/s, Epoch=293, Loss=0.028820, Total Loss=0.002552]
# 4it [00:02,  1.39it/s, Epoch=293, Val Loss=0.038788, Total Val Loss=0.126761]
# 13it [00:10,  1.25it/s, Epoch=294, Loss=0.000978, Total Loss=0.000316]
# 4it [00:02,  1.36it/s, Epoch=294, Val Loss=0.043292, Total Val Loss=0.126272]
# 13it [00:11,  1.18it/s, Epoch=295, Loss=0.000086, Total Loss=0.000107]
# 4it [00:03,  1.33it/s, Epoch=295, Val Loss=0.026751, Total Val Loss=0.126905]
# 13it [00:10,  1.20it/s, Epoch=296, Loss=0.002912, Total Loss=0.000361]
# 4it [00:02,  1.34it/s, Epoch=296, Val Loss=0.034728, Total Val Loss=0.125206]
# 13it [00:10,  1.21it/s, Epoch=297, Loss=0.000857, Total Loss=0.000190]
# 4it [00:02,  1.35it/s, Epoch=297, Val Loss=0.035668, Total Val Loss=0.124872]
# 13it [00:11,  1.16it/s, Epoch=298, Loss=0.001340, Total Loss=0.000317]
# 4it [00:02,  1.39it/s, Epoch=298, Val Loss=0.027903, Total Val Loss=0.137289]
# 13it [00:10,  1.20it/s, Epoch=299, Loss=0.000460, Total Loss=0.000137]
# 4it [00:02,  1.36it/s, Epoch=299, Val Loss=0.026931, Total Val Loss=0.125469]
# 13it [00:11,  1.15it/s, Epoch=300, Loss=0.000415, Total Loss=0.000152]
# 4it [00:02,  1.34it/s, Epoch=300, Val Loss=0.020796, Total Val Loss=0.130346]
# 13it [00:10,  1.22it/s, Epoch=301, Loss=0.000542, Total Loss=0.000145]
# 4it [00:02,  1.37it/s, Epoch=301, Val Loss=0.032159, Total Val Loss=0.134761]
# 13it [00:11,  1.17it/s, Epoch=302, Loss=0.000205, Total Loss=0.000384]
# 4it [00:02,  1.39it/s, Epoch=302, Val Loss=0.022701, Total Val Loss=0.134530]
# 13it [00:10,  1.19it/s, Epoch=303, Loss=0.000073, Total Loss=0.000232]
# 4it [00:02,  1.39it/s, Epoch=303, Val Loss=0.033242, Total Val Loss=0.131694]
# 13it [00:10,  1.20it/s, Epoch=304, Loss=0.000902, Total Loss=0.000539]
# 4it [00:02,  1.34it/s, Epoch=304, Val Loss=0.038150, Total Val Loss=0.132658]
# 13it [00:11,  1.18it/s, Epoch=305, Loss=0.000219, Total Loss=0.000144]
# 4it [00:03,  1.31it/s, Epoch=305, Val Loss=0.025031, Total Val Loss=0.119948]
# 13it [00:11,  1.16it/s, Epoch=306, Loss=0.001131, Total Loss=0.000495]
# 4it [00:02,  1.40it/s, Epoch=306, Val Loss=0.027145, Total Val Loss=0.128681]
# 13it [00:11,  1.15it/s, Epoch=307, Loss=0.000449, Total Loss=0.000142]
# 4it [00:03,  1.33it/s, Epoch=307, Val Loss=0.019697, Total Val Loss=0.133566]
# 13it [00:10,  1.19it/s, Epoch=308, Loss=0.000295, Total Loss=0.000136]
# 4it [00:02,  1.38it/s, Epoch=308, Val Loss=0.020874, Total Val Loss=0.145919]
# 13it [00:10,  1.19it/s, Epoch=309, Loss=0.000049, Total Loss=0.000221]
# 4it [00:02,  1.39it/s, Epoch=309, Val Loss=0.019200, Total Val Loss=0.133195]
# 13it [00:11,  1.15it/s, Epoch=310, Loss=0.000457, Total Loss=0.000202]
# 4it [00:03,  1.33it/s, Epoch=310, Val Loss=0.027144, Total Val Loss=0.125600]
# 13it [00:11,  1.13it/s, Epoch=311, Loss=0.000367, Total Loss=0.000240]
# 4it [00:02,  1.40it/s, Epoch=311, Val Loss=0.023817, Total Val Loss=0.130632]
# 13it [00:11,  1.15it/s, Epoch=312, Loss=0.003482, Total Loss=0.000400]
# 4it [00:02,  1.34it/s, Epoch=312, Val Loss=0.032879, Total Val Loss=0.126435]
# 13it [00:11,  1.17it/s, Epoch=313, Loss=0.000181, Total Loss=0.000100]
# 4it [00:03,  1.32it/s, Epoch=313, Val Loss=0.025561, Total Val Loss=0.119834]
# 13it [00:10,  1.24it/s, Epoch=314, Loss=0.000264, Total Loss=0.000092]
# 4it [00:02,  1.39it/s, Epoch=314, Val Loss=0.036551, Total Val Loss=0.122540]
# 13it [00:11,  1.14it/s, Epoch=315, Loss=0.003082, Total Loss=0.000333]
# 4it [00:03,  1.33it/s, Epoch=315, Val Loss=0.017661, Total Val Loss=0.125734]
# 13it [00:11,  1.14it/s, Epoch=316, Loss=0.000303, Total Loss=0.000135]
# 4it [00:02,  1.38it/s, Epoch=316, Val Loss=0.015407, Total Val Loss=0.129836]
# 13it [00:11,  1.17it/s, Epoch=317, Loss=0.000141, Total Loss=0.000128]
# 4it [00:03,  1.32it/s, Epoch=317, Val Loss=0.019126, Total Val Loss=0.130348]
# 13it [00:10,  1.21it/s, Epoch=318, Loss=0.000219, Total Loss=0.000102]
# 4it [00:03,  1.33it/s, Epoch=318, Val Loss=0.015814, Total Val Loss=0.132176]
# 13it [00:11,  1.18it/s, Epoch=319, Loss=0.000023, Total Loss=0.000124]
# 4it [00:03,  1.31it/s, Epoch=319, Val Loss=0.033028, Total Val Loss=0.137814]
# 13it [00:11,  1.13it/s, Epoch=320, Loss=0.001951, Total Loss=0.000304]
# 4it [00:03,  1.31it/s, Epoch=320, Val Loss=0.035679, Total Val Loss=0.123520]
# 13it [00:10,  1.21it/s, Epoch=321, Loss=0.009460, Total Loss=0.000893]
# ...
# 13it [00:10,  1.25it/s, Epoch=394, Loss=0.000050, Total Loss=0.000162]
# 4it [00:03,  1.27it/s, Epoch=394, Val Loss=0.027001, Total Val Loss=0.145377]
# 13it [00:10,  1.21it/s, Epoch=395, Loss=0.000059, Total Loss=0.000133]
# 4it [00:03,  1.27it/s, Epoch=395, Val Loss=0.017750, Total Val Loss=0.152215]
# 13it [00:11,  1.14it/s, Epoch=396, Loss=0.000709, Total Loss=0.000205]
# 4it [00:03,  1.29it/s, Epoch=396, Val Loss=0.018954, Total Val Loss=0.153867]
# 13it [00:11,  1.14it/s, Epoch=397, Loss=0.000650, Total Loss=0.000182]
# 4it [00:03,  1.30it/s, Epoch=397, Val Loss=0.019463, Total Val Loss=0.140069]
# 13it [00:11,  1.15it/s, Epoch=398, Loss=0.000387, Total Loss=0.000194]
# 4it [00:02,  1.35it/s, Epoch=398, Val Loss=0.021889, Total Val Loss=0.146679]
# 13it [00:10,  1.21it/s, Epoch=399, Loss=0.000260, Total Loss=0.000330]
# 4it [00:02,  1.36it/s, Epoch=399, Val Loss=0.019294, Total Val Loss=0.151635]
# 13it [00:11,  1.17it/s, Epoch=400, Loss=0.000288, Total Loss=0.001172]
# 4it [00:03,  1.29it/s, Epoch=400, Val Loss=0.016011, Total Val Loss=0.175183]
# 13it [00:10,  1.20it/s, Epoch=401, Loss=0.003036, Total Loss=0.000358]
# 4it [00:03,  1.27it/s, Epoch=401, Val Loss=0.026680, Total Val Loss=0.167231]
# 13it [00:11,  1.15it/s, Epoch=402, Loss=0.000365, Total Loss=0.000144]
# 4it [00:03,  1.33it/s, Epoch=402, Val Loss=0.017115, Total Val Loss=0.161777]
# 13it [00:11,  1.15it/s, Epoch=403, Loss=0.001601, Total Loss=0.000215]
# 4it [00:03,  1.30it/s, Epoch=403, Val Loss=0.019743, Total Val Loss=0.164882]
# 13it [00:11,  1.14it/s, Epoch=404, Loss=0.000035, Total Loss=0.000066]
# 4it [00:02,  1.35it/s, Epoch=404, Val Loss=0.014223, Total Val Loss=0.172116]
# 13it [00:11,  1.13it/s, Epoch=405, Loss=0.000230, Total Loss=0.000174]
# 4it [00:02,  1.37it/s, Epoch=405, Val Loss=0.016442, Total Val Loss=0.158721]
# 13it [00:10,  1.23it/s, Epoch=406, Loss=0.000175, Total Loss=0.000239]
# 4it [00:03,  1.32it/s, Epoch=406, Val Loss=0.018988, Total Val Loss=0.153338]
# 13it [00:10,  1.23it/s, Epoch=407, Loss=0.000519, Total Loss=0.000244]
# 4it [00:02,  1.34it/s, Epoch=407, Val Loss=0.022600, Total Val Loss=0.142634]
# 13it [00:11,  1.16it/s, Epoch=408, Loss=0.000269, Total Loss=0.000130]
# 4it [00:03,  1.28it/s, Epoch=408, Val Loss=0.012560, Total Val Loss=0.172549]
# 13it [00:11,  1.16it/s, Epoch=409, Loss=0.000308, Total Loss=0.000116]
# 4it [00:03,  1.29it/s, Epoch=409, Val Loss=0.012817, Total Val Loss=0.158920]
# 13it [00:11,  1.15it/s, Epoch=410, Loss=0.000433, Total Loss=0.000727]
# 4it [00:03,  1.28it/s, Epoch=410, Val Loss=0.010552, Total Val Loss=0.168920]
# 13it [00:11,  1.16it/s, Epoch=411, Loss=0.000576, Total Loss=0.000201]
# 4it [00:03,  1.30it/s, Epoch=411, Val Loss=0.018809, Total Val Loss=0.172712]
# 13it [00:11,  1.14it/s, Epoch=412, Loss=0.000544, Total Loss=0.000120]
# 4it [00:03,  1.27it/s, Epoch=412, Val Loss=0.014110, Total Val Loss=0.153638]
# 13it [00:11,  1.13it/s, Epoch=413, Loss=0.001257, Total Loss=0.000143]
# 4it [00:02,  1.34it/s, Epoch=413, Val Loss=0.013706, Total Val Loss=0.174820]
# 13it [00:11,  1.15it/s, Epoch=414, Loss=0.000156, Total Loss=0.000090]
# 4it [00:03,  1.29it/s, Epoch=414, Val Loss=0.014254, Total Val Loss=0.171175]
# 13it [00:11,  1.16it/s, Epoch=415, Loss=0.031654, Total Loss=0.002484]
# 4it [00:03,  1.25it/s, Epoch=415, Val Loss=0.014170, Total Val Loss=0.142353]
# 13it [00:11,  1.16it/s, Epoch=416, Loss=0.009873, Total Loss=0.000826]
# 4it [00:03,  1.29it/s, Epoch=416, Val Loss=0.033491, Total Val Loss=0.155975]
# 13it [00:11,  1.16it/s, Epoch=417, Loss=0.000273, Total Loss=0.000079]
# 4it [00:03,  1.27it/s, Epoch=417, Val Loss=0.005859, Total Val Loss=0.189939]
# 13it [00:10,  1.21it/s, Epoch=418, Loss=0.737303, Total Loss=0.056951]
# 4it [00:03,  1.29it/s, Epoch=418, Val Loss=0.007166, Total Val Loss=0.215949]
# 13it [00:11,  1.17it/s, Epoch=419, Loss=0.016971, Total Loss=0.002040]
# 4it [00:03,  1.29it/s, Epoch=419, Val Loss=0.010964, Total Val Loss=0.295586]
# 13it [00:11,  1.16it/s, Epoch=420, Loss=0.011962, Total Loss=0.005708]
# 4it [00:03,  1.24it/s, Epoch=420, Val Loss=0.008471, Total Val Loss=0.269147]
# 13it [00:11,  1.17it/s, Epoch=421, Loss=0.001333, Total Loss=0.002158]
# 4it [00:03,  1.31it/s, Epoch=421, Val Loss=0.014064, Total Val Loss=0.231270]
# 13it [00:11,  1.15it/s, Epoch=422, Loss=0.000333, Total Loss=0.000718]
# 4it [00:03,  1.29it/s, Epoch=422, Val Loss=0.020568, Total Val Loss=0.223076]
# 13it [00:11,  1.15it/s, Epoch=423, Loss=0.001200, Total Loss=0.000686]
# 4it [00:03,  1.28it/s, Epoch=423, Val Loss=0.024886, Total Val Loss=0.206809]
# 13it [00:11,  1.17it/s, Epoch=424, Loss=0.001564, Total Loss=0.001853]
# 4it [00:02,  1.35it/s, Epoch=424, Val Loss=0.013735, Total Val Loss=0.217269]
# 13it [00:11,  1.13it/s, Epoch=425, Loss=0.045498, Total Loss=0.003797]
# 4it [00:03,  1.31it/s, Epoch=425, Val Loss=0.009817, Total Val Loss=0.185227]
# 13it [00:11,  1.17it/s, Epoch=426, Loss=0.001182, Total Loss=0.000733]
# 4it [00:03,  1.33it/s, Epoch=426, Val Loss=0.013253, Total Val Loss=0.185855]
# 13it [00:10,  1.22it/s, Epoch=427, Loss=0.010000, Total Loss=0.001446]
# 4it [00:03,  1.30it/s, Epoch=427, Val Loss=0.014289, Total Val Loss=0.219079]
# 13it [00:11,  1.15it/s, Epoch=428, Loss=0.000112, Total Loss=0.000643]
# 4it [00:03,  1.26it/s, Epoch=428, Val Loss=0.016196, Total Val Loss=0.228766]
# 13it [00:11,  1.16it/s, Epoch=429, Loss=0.003133, Total Loss=0.000600]
# 4it [00:03,  1.33it/s, Epoch=429, Val Loss=0.016340, Total Val Loss=0.223178]
# 13it [00:11,  1.14it/s, Epoch=430, Loss=0.000169, Total Loss=0.000296]
# 4it [00:03,  1.30it/s, Epoch=430, Val Loss=0.013878, Total Val Loss=0.214527]
# 13it [00:11,  1.18it/s, Epoch=431, Loss=0.001336, Total Loss=0.000529]
# 4it [00:03,  1.25it/s, Epoch=431, Val Loss=0.013023, Total Val Loss=0.198211]
# 13it [00:10,  1.24it/s, Epoch=432, Loss=0.001009, Total Loss=0.000327]
# 4it [00:02,  1.34it/s, Epoch=432, Val Loss=0.015367, Total Val Loss=0.223061]
# 13it [00:11,  1.14it/s, Epoch=433, Loss=0.000634, Total Loss=0.000243]
# 4it [00:03,  1.27it/s, Epoch=433, Val Loss=0.012325, Total Val Loss=0.209487]
# 13it [00:10,  1.26it/s, Epoch=434, Loss=0.011166, Total Loss=0.001065]
# 4it [00:03,  1.25it/s, Epoch=434, Val Loss=0.008413, Total Val Loss=0.203441]
# 13it [00:10,  1.24it/s, Epoch=435, Loss=0.003366, Total Loss=0.000715]
# 4it [00:03,  1.28it/s, Epoch=435, Val Loss=0.016226, Total Val Loss=0.197729]
# 13it [00:11,  1.16it/s, Epoch=436, Loss=0.000562, Total Loss=0.000190]
# 4it [00:03,  1.28it/s, Epoch=436, Val Loss=0.010673, Total Val Loss=0.197432]
# 13it [00:11,  1.17it/s, Epoch=437, Loss=0.000499, Total Loss=0.000483]
# 4it [00:03,  1.28it/s, Epoch=437, Val Loss=0.010426, Total Val Loss=0.214080]
# 13it [00:11,  1.14it/s, Epoch=438, Loss=0.002439, Total Loss=0.000367]
# 4it [00:03,  1.27it/s, Epoch=438, Val Loss=0.008654, Total Val Loss=0.211455]
# 13it [00:11,  1.17it/s, Epoch=439, Loss=0.000122, Total Loss=0.000295]
# 4it [00:03,  1.27it/s, Epoch=439, Val Loss=0.012088, Total Val Loss=0.215213]
# 13it [00:11,  1.13it/s, Epoch=440, Loss=0.000801, Total Loss=0.000290]
# 4it [00:03,  1.28it/s, Epoch=440, Val Loss=0.022468, Total Val Loss=0.213091]
# 13it [00:11,  1.17it/s, Epoch=441, Loss=0.081907, Total Loss=0.006657]
# 4it [00:03,  1.27it/s, Epoch=441, Val Loss=0.010784, Total Val Loss=0.195702]
# 13it [00:11,  1.15it/s, Epoch=442, Loss=0.006857, Total Loss=0.000980]
# 4it [00:03,  1.27it/s, Epoch=442, Val Loss=0.008250, Total Val Loss=0.219569]
# 13it [00:11,  1.17it/s, Epoch=443, Loss=0.000039, Total Loss=0.000197]
# 4it [00:03,  1.25it/s, Epoch=443, Val Loss=0.006671, Total Val Loss=0.244260]
# 13it [00:11,  1.14it/s, Epoch=444, Loss=0.007555, Total Loss=0.001038]
# 4it [00:03,  1.26it/s, Epoch=444, Val Loss=0.006738, Total Val Loss=0.236248]
# 13it [00:10,  1.24it/s, Epoch=445, Loss=0.000309, Total Loss=0.000245]
# 4it [00:03,  1.29it/s, Epoch=445, Val Loss=0.007315, Total Val Loss=0.258194]
# 13it [00:10,  1.23it/s, Epoch=446, Loss=0.000128, Total Loss=0.010073]
# 4it [00:03,  1.26it/s, Epoch=446, Val Loss=0.016379, Total Val Loss=0.250438]
# 13it [00:10,  1.20it/s, Epoch=447, Loss=0.000397, Total Loss=0.000250]
# 4it [00:02,  1.35it/s, Epoch=447, Val Loss=0.015666, Total Val Loss=0.246453]
# 13it [00:11,  1.13it/s, Epoch=448, Loss=0.000188, Total Loss=0.000163]
# 4it [00:03,  1.30it/s, Epoch=448, Val Loss=0.011365, Total Val Loss=0.256374]
# 13it [00:11,  1.14it/s, Epoch=449, Loss=0.001454, Total Loss=0.000275]
# 4it [00:03,  1.29it/s, Epoch=449, Val Loss=0.007840, Total Val Loss=0.249302]
# 13it [00:11,  1.15it/s, Epoch=450, Loss=0.000191, Total Loss=0.000457]
# 4it [00:03,  1.29it/s, Epoch=450, Val Loss=0.006085, Total Val Loss=0.232034]
# 13it [00:11,  1.09it/s, Epoch=451, Loss=0.000079, Total Loss=0.000255]
# 4it [00:02,  1.34it/s, Epoch=451, Val Loss=0.009056, Total Val Loss=0.220026]
# 13it [00:11,  1.16it/s, Epoch=452, Loss=0.000433, Total Loss=0.000174]
# 4it [00:03,  1.26it/s, Epoch=452, Val Loss=0.016478, Total Val Loss=0.236555]
# 13it [00:11,  1.17it/s, Epoch=453, Loss=0.000883, Total Loss=0.000267]
# 4it [00:03,  1.27it/s, Epoch=453, Val Loss=0.008622, Total Val Loss=0.219952]
# 13it [00:10,  1.19it/s, Epoch=454, Loss=0.031352, Total Loss=0.002614]
# 4it [00:03,  1.29it/s, Epoch=454, Val Loss=0.011675, Total Val Loss=0.249666]
# 13it [00:10,  1.18it/s, Epoch=455, Loss=0.000243, Total Loss=0.000270]
# 4it [00:03,  1.28it/s, Epoch=455, Val Loss=0.012359, Total Val Loss=0.221318]
# 13it [00:11,  1.14it/s, Epoch=456, Loss=0.001409, Total Loss=0.001229]
# 4it [00:03,  1.26it/s, Epoch=456, Val Loss=0.011804, Total Val Loss=0.248197]
# 13it [00:10,  1.25it/s, Epoch=457, Loss=0.000054, Total Loss=0.000141]
# 4it [00:02,  1.34it/s, Epoch=457, Val Loss=0.007951, Total Val Loss=0.208721]
# 13it [00:10,  1.18it/s, Epoch=458, Loss=0.000357, Total Loss=0.000115]
# 4it [00:03,  1.33it/s, Epoch=458, Val Loss=0.007664, Total Val Loss=0.207255]
# 13it [00:11,  1.15it/s, Epoch=459, Loss=0.000033, Total Loss=0.000261]
# 4it [00:02,  1.35it/s, Epoch=459, Val Loss=0.004369, Total Val Loss=0.217609]
# 13it [00:10,  1.27it/s, Epoch=460, Loss=0.000220, Total Loss=0.000220]
# 4it [00:03,  1.27it/s, Epoch=460, Val Loss=0.011354, Total Val Loss=0.221008]
# 13it [00:11,  1.15it/s, Epoch=461, Loss=0.002152, Total Loss=0.000336]
# 4it [00:03,  1.32it/s, Epoch=461, Val Loss=0.015318, Total Val Loss=0.200022]
# 13it [00:11,  1.15it/s, Epoch=462, Loss=0.015292, Total Loss=0.001578]
# 4it [00:03,  1.29it/s, Epoch=462, Val Loss=0.009078, Total Val Loss=0.225694]
# 13it [00:11,  1.16it/s, Epoch=463, Loss=0.000085, Total Loss=0.000496]
# 4it [00:03,  1.24it/s, Epoch=463, Val Loss=0.007550, Total Val Loss=0.210133]
# 13it [00:11,  1.12it/s, Epoch=464, Loss=0.000056, Total Loss=0.000078]
# 4it [00:02,  1.35it/s, Epoch=464, Val Loss=0.007457, Total Val Loss=0.206462]
# 13it [00:11,  1.10it/s, Epoch=465, Loss=0.000334, Total Loss=0.000987]
# 4it [00:03,  1.26it/s, Epoch=465, Val Loss=0.010758, Total Val Loss=0.181089]
# 13it [00:11,  1.13it/s, Epoch=466, Loss=0.000102, Total Loss=0.000065]
# 4it [00:03,  1.33it/s, Epoch=466, Val Loss=0.010871, Total Val Loss=0.187640]
# 13it [00:11,  1.16it/s, Epoch=467, Loss=0.000196, Total Loss=0.000140]
# 4it [00:03,  1.24it/s, Epoch=467, Val Loss=0.006200, Total Val Loss=0.204380]
# 13it [00:11,  1.14it/s, Epoch=468, Loss=0.000103, Total Loss=0.000119]
# 4it [00:03,  1.27it/s, Epoch=468, Val Loss=0.006020, Total Val Loss=0.227207]
# 13it [00:11,  1.10it/s, Epoch=469, Loss=0.000747, Total Loss=0.000176]
# 4it [00:03,  1.29it/s, Epoch=469, Val Loss=0.014548, Total Val Loss=0.214749]
# 13it [00:11,  1.17it/s, Epoch=470, Loss=0.000091, Total Loss=0.000076]
# 4it [00:03,  1.32it/s, Epoch=470, Val Loss=0.011812, Total Val Loss=0.223254]
# 13it [00:11,  1.14it/s, Epoch=471, Loss=0.000047, Total Loss=0.000049]
# 4it [00:03,  1.26it/s, Epoch=471, Val Loss=0.009366, Total Val Loss=0.214880]
# 13it [00:11,  1.17it/s, Epoch=472, Loss=0.002055, Total Loss=0.000243]
# 4it [00:03,  1.26it/s, Epoch=472, Val Loss=0.008306, Total Val Loss=0.187640]
# 13it [00:11,  1.18it/s, Epoch=473, Loss=0.000433, Total Loss=0.000134]
# 4it [00:03,  1.28it/s, Epoch=473, Val Loss=0.011967, Total Val Loss=0.194271]
# 13it [00:10,  1.23it/s, Epoch=474, Loss=0.000359, Total Loss=0.000152]
# 4it [00:03,  1.26it/s, Epoch=474, Val Loss=0.008397, Total Val Loss=0.184993]
# 13it [00:10,  1.23it/s, Epoch=475, Loss=0.615635, Total Loss=0.047560]
# 4it [00:03,  1.30it/s, Epoch=475, Val Loss=0.010540, Total Val Loss=0.203478]
# 13it [00:11,  1.17it/s, Epoch=476, Loss=0.007034, Total Loss=0.001501]
# 4it [00:02,  1.34it/s, Epoch=476, Val Loss=0.043822, Total Val Loss=0.138274]
# 13it [00:11,  1.13it/s, Epoch=477, Loss=1.063304, Total Loss=0.082863]
# 4it [00:03,  1.31it/s, Epoch=477, Val Loss=0.058394, Total Val Loss=0.150574]
# 13it [00:11,  1.16it/s, Epoch=478, Loss=0.001156, Total Loss=0.013628]
# 4it [00:03,  1.31it/s, Epoch=478, Val Loss=0.087598, Total Val Loss=0.198494]
# 13it [00:11,  1.16it/s, Epoch=479, Loss=0.018259, Total Loss=0.005679]
# 4it [00:03,  1.28it/s, Epoch=479, Val Loss=0.138828, Total Val Loss=0.229810]
# 13it [00:11,  1.14it/s, Epoch=480, Loss=0.004887, Total Loss=0.004576]
# 4it [00:03,  1.26it/s, Epoch=480, Val Loss=0.073335, Total Val Loss=0.186664]
# 13it [00:11,  1.16it/s, Epoch=481, Loss=0.000038, Total Loss=0.000484]
# 4it [00:02,  1.33it/s, Epoch=481, Val Loss=0.042948, Total Val Loss=0.177236]
# 13it [00:10,  1.20it/s, Epoch=482, Loss=0.000032, Total Loss=0.000337]
# 4it [00:03,  1.25it/s, Epoch=482, Val Loss=0.076756, Total Val Loss=0.192368]
# 13it [00:10,  1.23it/s, Epoch=483, Loss=0.017841, Total Loss=0.002205]
# 4it [00:03,  1.28it/s, Epoch=483, Val Loss=0.089059, Total Val Loss=0.194422]
# 13it [00:11,  1.16it/s, Epoch=484, Loss=0.000026, Total Loss=0.000265]
# 4it [00:03,  1.24it/s, Epoch=484, Val Loss=0.054495, Total Val Loss=0.179640]
# 13it [00:11,  1.15it/s, Epoch=485, Loss=0.000192, Total Loss=0.000113]
# 4it [00:03,  1.26it/s, Epoch=485, Val Loss=0.030994, Total Val Loss=0.167444]
# 13it [00:11,  1.14it/s, Epoch=486, Loss=0.000351, Total Loss=0.000197]
# 4it [00:03,  1.31it/s, Epoch=486, Val Loss=0.040359, Total Val Loss=0.169402]
# 13it [00:10,  1.20it/s, Epoch=487, Loss=0.000487, Total Loss=0.000214]
# 4it [00:03,  1.33it/s, Epoch=487, Val Loss=0.048804, Total Val Loss=0.180465]
# 13it [00:10,  1.21it/s, Epoch=488, Loss=0.000078, Total Loss=0.000383]
# 4it [00:03,  1.24it/s, Epoch=488, Val Loss=0.036314, Total Val Loss=0.170748]
# 13it [00:11,  1.14it/s, Epoch=489, Loss=0.000934, Total Loss=0.000227]
# 4it [00:03,  1.31it/s, Epoch=489, Val Loss=0.028398, Total Val Loss=0.157345]
# 13it [00:10,  1.19it/s, Epoch=490, Loss=0.001133, Total Loss=0.000235]
# 4it [00:03,  1.25it/s, Epoch=490, Val Loss=0.039364, Total Val Loss=0.157261]
# 13it [00:11,  1.16it/s, Epoch=491, Loss=0.000028, Total Loss=0.000159]
# 4it [00:03,  1.24it/s, Epoch=491, Val Loss=0.046663, Total Val Loss=0.171785]
# 13it [00:11,  1.10it/s, Epoch=492, Loss=0.000156, Total Loss=0.000166]
# 4it [00:03,  1.29it/s, Epoch=492, Val Loss=0.042736, Total Val Loss=0.157601]
# 13it [00:11,  1.15it/s, Epoch=493, Loss=0.004794, Total Loss=0.000537]
# 4it [00:03,  1.25it/s, Epoch=493, Val Loss=0.043698, Total Val Loss=0.166509]
# 13it [00:11,  1.13it/s, Epoch=494, Loss=0.000322, Total Loss=0.000530]
# 4it [00:03,  1.28it/s, Epoch=494, Val Loss=0.068529, Total Val Loss=0.174373]
# 13it [00:11,  1.16it/s, Epoch=495, Loss=0.000038, Total Loss=0.000179]
# 4it [00:03,  1.25it/s, Epoch=495, Val Loss=0.063412, Total Val Loss=0.184081]
# 13it [00:11,  1.17it/s, Epoch=496, Loss=0.000133, Total Loss=0.000108]
# 4it [00:03,  1.27it/s, Epoch=496, Val Loss=0.039958, Total Val Loss=0.167793]
# 13it [00:11,  1.17it/s, Epoch=497, Loss=0.000436, Total Loss=0.000175]
# 4it [00:03,  1.24it/s, Epoch=497, Val Loss=0.036386, Total Val Loss=0.157362]
# 13it [00:11,  1.18it/s, Epoch=498, Loss=0.000273, Total Loss=0.000517]
# 4it [00:03,  1.20it/s, Epoch=498, Val Loss=0.034528, Total Val Loss=0.159535]
# 13it [00:11,  1.11it/s, Epoch=499, Loss=0.001344, Total Loss=0.000567]
# 4it [00:03,  1.23it/s, Epoch=499, Val Loss=0.045975, Total Val Loss=0.158948]
# 13it [00:10,  1.18it/s, Epoch=500, Loss=0.000085, Total Loss=0.000366]
# 4it [00:03,  1.23it/s, Epoch=500, Val Loss=0.028676, Total Val Loss=0.153062]

# %% [markdown]
# # 학습 결과

# %%
plt.plot(loss_plot, label='train_loss')
plt.plot(val_loss_plot, label='val_loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %% [markdown]
# # 추론 및 제출

# %%
def predict(dataset):
    model.eval()
    tqdm_dataset = tqdm(enumerate(dataset))
    training = False
    results = []
    for batch, batch_item in tqdm_dataset:
        img = batch_item['img'].to(device)
        with torch.no_grad():
            output = model(img)
        output = torch.tensor(torch.argmax(output, axis=-1), dtype=torch.int32).cpu().numpy()
        results.extend(output)
    return results

# %%
preds = predict(test_dataloader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.
# 297it [02:25,  2.04it/s]

# %%
submission = pd.read_csv('./sample_submission.csv')

# %%
submission.iloc[:,1] = preds

# %%
submission.to_csv('DenseNet161_epoch500_batchsize16.csv', index=False)
